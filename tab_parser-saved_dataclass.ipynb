# %%
import xmltodict
import os
import json
import pickle
from lxml import etree

encoding = "utf-8"


def load_data(file_path):
    with open(file_path, "r", encoding=encoding) as f:
        content = f.read()
    content = content.replace('%20', '')
    return content


def xml_parser(content):
    parser = etree.XMLParser(recover=True, encoding=encoding)
    root = etree.fromstring(content, parser=parser)
    return root


def get_metadata(root):
    meta_list = ['title', 'beats_in_measure', 'BPM', 'key', 'YouTubeID', 'mode']

    metadata = dict()
    for e in meta_list:
        tag = root.find('.//' + e)
        metadata[e] = tag.text if tag is not None else None

    # duration
    tag = root.find('.//duration')
    tag = root.find('.//section_duration') if tag is None else tag
    metadata['duration'] = tag.text if tag is not None else None

    version = root.find('version')
    version = version.text if version is not None else None
    return metadata, version


def get_lead_sheet(root, version):
    segments_tag = root.findall('.//segment')

    # set chord tag according to version
    chord_tag = 'chords' if root.tag == 'super' else 'harmony'

    segment_list = []
    num_measures = 0

    for segment in segments_tag:
        num_measure = float(segment.find('numMeasures').text)

        # melody
        note_tags = segment.findall('.//notes/note')
        note_list = [xmltodict.parse(etree.tostring(n))['note'] for n in note_tags] if note_tags else []

        # chord
        chord_tags = segment.findall('.//' + chord_tag + '/chord')
        chord_list = [xmltodict.parse(etree.tostring(c))['chord'] for c in chord_tags] if chord_tags else []

        segment_list.append({'notes': note_list, 'chords': chord_list, 'num_measure': num_measure})
        num_measures += num_measure

    return segment_list, num_measures


def event_localization(measure_offset, start_beat_abs, duration):
    event_on = measure_offset + start_beat_abs
    event_off = measure_offset + start_beat_abs + duration
    return event_on, event_off

def segments_parser(segments, mode, beats_in_measure):
    measure_counter = 0

    chord_track = []
    melody_track = []

    for sidx, segment in enumerate(segments):
        measure_offset = measure_counter * float(beats_in_measure)

        for chord in segment['chords']:
            chord_track.append(proc_object(chord, measure_offset, type_='chord'))
        for note in segment['notes']:
            melody_track.append(proc_object(note, measure_offset, type_='note'))

        measure_counter += int(segment['num_measure'])

    return melody_track, chord_track


def proc_xml(file_path, save_path=None, name='tab', save_type='pickle'):
    content = load_data(file_path)
    root = xml_parser(content)
    metadata, version = get_metadata(root)
    segments, num_measures = get_lead_sheet(root, version)

    mode = int(metadata['mode']) if metadata['mode'] is not None else 1
    beats_in_measure = int(metadata['beats_in_measure'])

    melody, chord = segments_parser(segments, mode, beats_in_measure)

    data = {
        'version': version,
        'metadata': metadata,
        'tracks': {
            'melody': melody,
            'chord': chord,
        },
        'num_measures': num_measures,
    }

    if save_path:
        if not os.path.exists(save_path):
            os.makedirs(save_path)

        if save_type is 'pickle':
            file_name = os.path.join(save_path, name+'.pickle')
            with open(file_name, 'wb') as handle:
                pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
        elif save_type is 'json':
            file_name = os.path.join(save_path, name+'.json')
            with open(file_name, 'w') as handle:
                json.dump(data, handle)
        else:
            raise ValueError('Unkown type for saving')

    return data


def traverse_dir(root_dir, extension='.xml'):
    file_list = []
    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith(extension):
                file_list.append(os.path.join(root, file))

    return file_list


def get_postfix_dirpath(filename, idx=-4):
    path = os.path.normpath(filename)
    dir_list = path.split(os.sep)
    new_path = ''

    for d in dir_list[idx:]:
        new_path = os.path.join(new_path, d)

    return new_path


def proc_dir(file_list, root):
    num_file = len(file_list)
    for fidx in range(num_file):
        print('(%d/%d)' % (fidx, num_file))
        file_path = file_list[fidx]
        save_path = root
        name = os.path.basename(file_path)
        proc_xml(file_path, save_path=save_path, name=name, save_type='json')

# %%
# mode = int(metadata['mode']) if metadata['mode'] is not None else 1
# beats_in_measure = int(metadata['beats_in_measure'])

# melody, chord = segments_parser(segments, mode, beats_in_measure)

# %%
from pathlib import Path

# %%
version = 'v7'
data_path = Path('data/midi')
version_path = data_path/version
orig_path = version_path/'midi_sources'

# %%
from fastai.data_block import get_files

# %%
h_path = orig_path/'hooktheory'

# %%
files = get_files(h_path, extensions=['.xml'], recurse=True); files[:10]
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/what-a-day/kiefer/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/pre-chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/freedom/chorus.xml')]

# %%
# Loading from specific file
keywords = ['get-lucky', 'daft-punk']
def contains_keywords(f): return all([k in str(f) for k in keywords])
search = [f for f in files if contains_keywords(f)]; search
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/d/daft-punk/get-lucky/outro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/d/daft-punk/get-lucky/pre-chorus-and-chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/d/daft-punk/get-lucky/verse.xml')]

# %%
import pprint

file_path = search[1]
# raw_info = proc_xml(file_path)
# pprint.pprint(raw_info)

# %%
content = load_data(file_path)
root = xml_parser(content)
metadata, version = get_metadata(root)
segments, num_measures = get_lead_sheet(root, version)

# %%
len(segments)
# Out:
# 3

# %%
segments
# Out:
# [{'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '2.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '2.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '3'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '6'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '3'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '10.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '4'),
#                 ('scale_degree', '6'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '16'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('note_length', '2.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '18.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '19'),
#                 ('start_measure', '5'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '19.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '3'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '22.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '23'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '6'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '23.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '3'),
#                 ('scale_degree', '7'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '26.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '27'),
#                 ('start_measure', '7'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '2'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '27.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '4.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '2'),
#                 ('isRest', '0')])],
#   'chords': [OrderedDict([('sd', '1'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '4'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '8'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '12'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '1'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '16'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '20'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '24'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '28'),
#                 ('isRest', '0')])],
#   'num_measure': 8.0},
#  {'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '0.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '0.75'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '1.25'),
#                 ('start_measure', '1'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '1.75'),
#                 ('start_measure', '1'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '2.25'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '2.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '4.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4.75'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5.25'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5.75'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6.25'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '8'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '8.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '8.75'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '9.25'),
#                 ('start_measure', '3'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '9.75'),
#                 ('start_measure', '3'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '10.25'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '10.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '12.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12.75'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13.25'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13.75'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14.25'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '16'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '16.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '16.75'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '17.25'),
#                 ('start_measure', '5'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '17.75'),
#                 ('start_measure', '5'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '18.25'),
#                 ('start_measure', '5'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '18.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '19'),
#                 ('start_measure', '5'),
#                 ('start_beat', '4'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '20'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '20.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '20.75'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '21.25'),
#                 ('start_measure', '6'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '21.75'),
#                 ('start_measure', '6'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '22.25'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '22.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '23'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '24'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '24.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '24.75'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '25.25'),
#                 ('start_measure', '7'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '25.75'),
#                 ('start_measure', '7'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '26.25'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '26.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '27'),
#                 ('start_measure', '7'),
#                 ('start_beat', '4'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '28'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '28.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '28.75'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '29.25'),
#                 ('start_measure', '8'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '29.75'),
#                 ('start_measure', '8'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '30.25'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '30.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '31'),
#                 ('start_measure', '8'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '31.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')])],
#   'chords': [OrderedDict([('sd', '1'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '4'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '8'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '12'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '1'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '16'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '20'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '24'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '28'),
#                 ('isRest', '0')])],
#   'num_measure': 8.0},
#  {'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '0.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '0.75'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '1.25'),
#                 ('start_measure', '1'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '1.75'),
#                 ('start_measure', '1'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '2.25'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '2.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '4.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4.75'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5.25'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5.75'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6.25'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '8'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '8.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '8.75'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '9.25'),
#                 ('start_measure', '3'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '9.75'),
#                 ('start_measure', '3'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '10.25'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '10.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '12.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12.75'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13.25'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2.25'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13.75'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2.75'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14.25'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3.25'),
#                 ('note_length', '0.25'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')])],
#   'chords': [OrderedDict([('sd', '1'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '4'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '8'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '12'),
#                 ('isRest', '0')])],
#   'num_measure': 4.0}]

# %%
import music21

# %% [markdown]
# ### Create config file

# %%
config = dict(sustain=True, sep_octave=True, default_octave=4)

# %% [markdown]
# ### Constants

# %%
# note to number
#

# %% [markdown]
# ### Classes

# %%
from dataclasses import dataclass
import dataclasses
from typing import Dict, Any, AnyStr, List, Sequence, TypeVar, Tuple, Optional, Union

# %%
@dataclass
class Base:
    @classmethod
    def parse(cls, d):
        cls_keys = cls.__dataclass_fields__.keys()
        kwargs = {key:d[key] for key in cls_keys}
        return cls(**kwargs)

# %%
@dataclass
class HMetadata(Base):
    title:str
    BPM:str='120'
    beats_in_measure:str='4'
    key:str='1'
    mode:str='1'

# %%
@dataclass
class HNote(Base):
    start_beat_abs: str
    start_measure: str
    start_beat: str
    note_length: str
    scale_degree: str
    octave: str
        
    def to_m21(self)->music21.note.Note:
        if self.scale_degree == 'rest':
            n = music21.note.Rest(quarterLength=note_length)
        else:
            n = music21.note.Note(quarterLength=note_length)
            n.octave = int(self.octave)+config.default_octave
        n.offset = self.start_beat_abs
        return n

# %%
@dataclass
class HChord(Base):
#     sd: str
#     fb: str
#     sec: str
    composition:List[int]
    chord_duration:str
    start_measure:str
    start_beat:str
    start_beat_abs:str
#     sus: str = None
#     borrowed:str = None
#     alternate:str = None
        
    def to_m21(self)->music21.chord.Chord:
        if self.scale_degree == 'rest':
            n = music21.note.Rest(quarterLength=note_length)
        else:
            n = music21.note.Note(quarterLength=note_length)
            n.octave = int(self.octave)+config.default_octave
        n.offset = self.start_beat_abs
        return n
    
    
    @classmethod
    def parse(cls, d, mode, key_offset):
        ns = [HNote.parse(n) for n in d.get('notes', [])]
        cs = [HChord.parse(c) for c in d.get('chords', [])]
        return cls(notes=ns, chords=cs)

# %%
@dataclass
class HPart(Base):
    notes: List[HNote]
    chords: List[HChord]
        
    @classmethod
    def parse(cls, d, metadata):
        metadata['key']
        ns = [HNote.parse(n) for n in d.get('notes', [])]
        cs = [HChord.parse(c) for c in d.get('chords', [])]
        return cls(notes=ns, chords=cs)

# %%
@dataclass
class HSong(Base):
    metadata: HMetadata
    parts: List[HPart]
    
    @classmethod
    def parse(cls, metadata, segments):
        m = HMetadata.parse(metadata)
        ps = [HPart.parse(s, metadata) for s in segments]
        return cls(metadata=m, parts=ps)
    
    def to_stream(self):
        # music21 stream
        return None

# %%
s = HSong.parse(metadata, segments)

# %%
# translator
class Translator():
    @classmethod
    def to_numpy(cls, s:HSong):
        pass
    @classmethod
    def to_song(cls, arr):
        pass

# %%
from src import roman_to_symbol

# %%
c = s.parts[0].chords[0]

# %%
c_d = dataclasses.asdict(c)
c_d['isRest'] = False
c_d['event_on'] = 2
c_d['event_off'] = 4
c_d['event_duration'] = 4

# %%
c
# Out:
# HChord(sd='1', fb='7', sec=None, chord_duration='4', start_measure='1', start_beat='1', start_beat_abs='0', sus=None, borrowed=None, alternate=None)

# %%
from src import to_pianoroll

# %%
parsed_c = roman_to_symbol.chord_parser(c_d, '2', 2); parsed_c
# Out:
# OrderedDict([('root', 2),
#              ('bass', 2),
#              ('comp_vec',
#               array([2, None, 5, None, 9, 12, None, None, None], dtype=object)),
#              ('composition', array([2, 5, 9, 12], dtype=object)),
#              ('quality', 'm'),
#              ('chord_type', 7),
#              ('chord_mode', -2),
#              ('isRest', False),
#              ('event_on', 2),
#              ('event_off', 4),
#              ('event_duration', 4),
#              ('inv', 0),
#              ('sus', None),
#              ('alter', None),
#              ('emb', []),
#              ('alter_map', None),
#              ('symbol', 'dm7')])

# %%
parsed_c['comp_vec']
# Out:
# array([0, None, 4, None, 7, 11, None, None, None], dtype=object)

# %%
parsed_c['composition']
# Out:
# array([2, 5, 9, 12], dtype=object)

# %%
music21.chord.Chord([0,4,7,11])
# Out:
# <music21.chord.Chord C E G B>

# %%
out = parsed_c['composition'].astype(int).tolist()

# %%
music21.chord.Chord(out)
# Out:
# <music21.chord.Chord D F A C0>

# %%
music21.chord.Chord(parsed_c['composition'].tolist())
# Out:
# ---------------------------------------------------------------------------
# ChordException                            Traceback (most recent call last)
# <ipython-input-98-9cc5a508fc6b> in <module>
# ----> 1 music21.chord.Chord(parsed_c['composition'].tolist())
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/chord/__init__.py in __init__(self, notes, **keywords)
#     222             durationKeyword = keywords['duration']
#     223
# --> 224         durationKeyword = self._add_core_or_init(notes, useDuration=durationKeyword)
#     225
#     226
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/chord/__init__.py in _add_core_or_init(self, notes, useDuration)
#     578                 #self._notes.append({'pitch':music21.pitch.Pitch(n)})
#     579             else:
# --> 580                 raise ChordException('Could not process input argument %s' % n)
#     581
#     582         return useDuration
#
# ChordException: Could not process input argument 2

# %%
to_pianoroll.voicing(parsed_c)
# Out:
# OrderedDict([('root', 0),
#              ('bass', 0),
#              ('comp_vec',
#               array([0, None, 4, None, 7, 11, None, None, None], dtype=object)),
#              ('composition', array([0, 4, 7, 11], dtype=object)),
#              ('quality', 'maj'),
#              ('chord_type', 7),
#              ('chord_mode', 0),
#              ('isRest', False),
#              ('event_on', 2),
#              ('event_off', 4),
#              ('event_duration', 4),
#              ('inv', 0),
#              ('sus', None),
#              ('alter', None),
#              ('emb', []),
#              ('alter_map', None),
#              ('symbol', 'Cmaj7')])

# %%
comp = to_pianoroll.to_chromagram(parsed_c['composition'])

# %%
comp
# Out:
# array([2, 5, 9, 0], dtype=object)

# %%
music21.chord.composition
