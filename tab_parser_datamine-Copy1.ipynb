# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import xmltodict
import os
import json
import pickle
from lxml import etree

# %%
# mode = int(metadata['mode']) if metadata['mode'] is not None else 1
# beats_in_measure = int(metadata['beats_in_measure'])

# melody, chord = segments_parser(segments, mode, beats_in_measure)

# %%
from pathlib import Path

# %%
version = 'v7'
data_path = Path('data/midi')
version_path = data_path/version
orig_path = version_path/'midi_sources'

# %%
from fastai.data_block import get_files

# %%
h_path = orig_path/'hooktheory'

# %%
files = get_files(h_path, extensions=['.xml'], recurse=True); files[:10]
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/what-a-day/kiefer/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/pre-chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/freedom/chorus.xml')]

# %%
# Loading from specific file
# keywords = ['get-lucky', 'daft-punk', 'pre-chorus']
# keywords = ['skrillex', 'scary']
keywords = ['idina', 'verse', 'let']
# keywords = ['game-of-thrones', 'intro', 'ramin']
# keywords = ['kiss-from-a-rose', 'seal']
def contains_keywords(f): return all([k in str(f) for k in keywords])
search = [f for f in files if contains_keywords(f)]; search
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/i/idina-menzel/let-it-go/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/i/idina-menzel/let-it-go/intro-and-verse.xml')]

# %%
from src.tab_parser import *

# %%
from src import roman_to_symbol
from src import to_pianoroll
from collections import defaultdict
from midi_data import keyc_offset

# %%
def parse_file(file_path):
    content = load_data(file_path)
    root = xml_parser(content)
    metadata, version = get_metadata(root)
    segments, num_measures = get_lead_sheet(root, version)
    
    song = HSong.parse(metadata, segments)
    return song

# %%
import music21

# %% [markdown]
# ### Create config file

# %%
config_opts = dict(sustain=True, sep_octave=True, note_octave=4, chord_octave=3, 
              ts='4/4', ks=0, bpm=120, freq=2, pad_idx=-1, none_idx=0, sus_idx=2, hit_idx=1)

class Config(object):
    def __init__(self, d): self.__dict__ = d
        
config = Config(config_opts)

# %% [markdown]
# ### Constants

# %%
MODE_TO_KEYOFFSET = {
    '1': 0,
    '2': 2,
    '3': 4,
    '4': 5,
    '5': 7,
    '6': 9,
    '7': 11
#     '5': -5,
#     '6': -3,
#     '7': -1
}

# %%
PITCH_TO_SD = {
    0: '1',
    1: '1#',
    2: '2',
    3: '2#',
    4: '3',
    5: '4',
    6: '4#',
    7: '5',
    8: '5#',
    9: '6',
    10:'6#',
    11:'7',
}

SD_TO_PITCH = {v:k for k,v in PITCH_TO_SD.items()}

# %% [markdown]
# ### Classes

# %%
from dataclasses import dataclass
import dataclasses
from typing import Dict, Any, AnyStr, List, Sequence, TypeVar, Tuple, Optional, Union

# %%
def parse(cls, d):
    cls_keys = cls.__dataclass_fields__.keys()
    kwargs = {key:d[key] for key in cls_keys}
    return cls(**kwargs)

@dataclass
class Base:
    @classmethod
    def from_dict(cls, d):
        cls_keys = cls.__dataclass_fields__.keys()
        kwargs = {key:d[key] for key in cls_keys}
        return cls(**kwargs)
    
    @classmethod
    def parse(cls, d):
        return cls.from_dict(d)

# %%
@dataclass
class HMetadata(Base):
    title:str
    BPM:str='120'
    beats_in_measure:str='4'
    key:str='C'
    mode:str='1'

# %%
@dataclass
class HNote(Base):
    beat_abs:float
    measure:float
    beat:float
    duration:float
    scale:str
    octave: str
        
    def to_m21(self)->music21.note.Note:
#         if self.scale_degree == 'rest': return None, None
#             n = music21.note.Rest(quarterLength=note_length)
        pitch = self.pitch() + 12*(int(self.octave)+config.note_octave)
        n = music21.note.Note(pitch, quarterLength=self.duration)
#         key.KeySignature(-1)
        return n, float(self.beat_abs)
    
    def pitch(self):
        return SD_TO_PITCH[self.scale]
    
    def end_time(self):
        return self.duration + self.beat_abs
    
    @classmethod
    def parse(cls, d, mode, key_offset):
#         if key_offset > 5: key_offset = key_offset-12
        parsed = roman_to_symbol.hnote_parser(d, mode, key_offset)
        pitch = parsed['pitch']
        scale_degree = PITCH_TO_SD[int((pitch) % 12)]
        octave = (pitch // 12) + 1
        m = {
            'scale': scale_degree,
            'octave': octave,
            'duration': float(d['note_length']),
            'measure': float(d['start_measure']),
            'beat': float(d['start_beat']),
            'beat_abs': float(d['start_beat_abs']),
        }
        return cls.from_dict({**d, **m})

# %%
def last_comp(comp):
    if comp is None: return config.none_idx
    return int(comp[-1])



@dataclass
class HChord(Base):
    # ht relative
    scale:int
    base:int
    sus:int
    
    # ht tempo
    duration:float # (AS) TODO: convert to float
    measure:float
    beat:float
    beat_abs:float # (AS) TODO: convert to float
        
    # abs
    composition:List[int]
    symbol:str=None
    quality:str=None
        
    def end_time(self):
        return self.duration + self.beat_abs
        
    def to_m21(self)->music21.chord.Chord:
        notes = [n+config.chord_octave*12 for n in self.composition]
        c = music21.chord.Chord(notes, quarterLength=self.duration)
        return c, float(self.beat_abs)

    @classmethod
    def parse(cls, d, mode, key_offset, reset_to_base=True):
        parsed = roman_to_symbol.hchord_parser(d, mode, 0)
        
        # After offset, let's reset the chord to be the lowest possible offset on new scale
#         if reset_to_base:
#             lowest = min(parsed['composition'])
#             if lowest > 12:
#                 parsed = roman_to_symbol.chord_key_shifting(parsed, -12)
#                 # reset chord name
#                 new_s = roman_to_symbol.chord_to_string(parsed)
#                 parsed['symbol'] = new_s
        
        parsed['composition'] = parsed['composition'].astype(int).tolist()
        
        m = {
            'scale': (int(d['sd']) - (1-int(mode))) % 8,
            'base': last_comp(d['fb']),
            'sus': last_comp(d['sus']),
            'duration': float(d['chord_duration']),
            'measure': float(d['start_measure']),
            'beat': float(d['start_beat']),
            'beat_abs': float(d['start_beat_abs']),
        }
        
        return cls.from_dict({**parsed, **m})

# %%
def default_stream(cls=music21.stream.Score, ts='4/4', bpm=120, ks=0):
    # (AS) TODO: use config ts or metadata
    s = cls()
    s.append(music21.instrument.Piano())
    s.append(music21.meter.TimeSignature(ts))
    s.append(music21.tempo.MetronomeMark(number=bpm))
#     s.append(music21.key.KeySignature(ks))
    s.append(music21.key.Key('C'))
    return s

# %%
@dataclass
class HPart(Base):
    notes: List[HNote]
    chords: List[HChord]
        
    @classmethod
    def parse(cls, d, metadata):
        mode = metadata['mode'] or '1'
        key_offset = MODE_TO_KEYOFFSET.get(mode, 0)
        ns = [HNote.parse(n, mode, key_offset) for n in d.get('notes', []) if n['scale_degree'] != 'rest']
        cs = [HChord.parse(c, mode, key_offset) for c in d.get('chords', []) if c['sd'] != 'rest']
        return cls(notes=ns, chords=cs)
    
    
    def duration(self):
        c_last = self.chords[-1].end_time()
        n_last = self.notes[-1].end_time()
        return max(c_last, n_last)
    
    def to_m21(self)->music21.stream.Stream:
        mc = music21.stream.Part()
        mn = music21.stream.Part()
        
        cm21 = [c.to_m21() for c in self.chords]
        for c,d in cm21: mc.insert(d,c)
            
        nm21 = [n.to_m21() for n in self.notes]
        for n,d in nm21: mn.insert(d,n)
        return mn, mc
        
    def min_pitch(self):
        return min([n.pitch for n in self.notes])

# %%
@dataclass
class HSong(Base):
    metadata: HMetadata
    parts: List[HPart]
    
    @classmethod
    def parse(cls, metadata, segments):
        m = HMetadata.parse(metadata)
        ps = [HPart.parse(s, metadata) for s in segments]
        return cls(metadata=m, parts=ps)
    
    def duration(self):
        return sum(p.duration() for p in self.parts)
    
    def to_stream(self):
        s = default_stream()
        pc = music21.stream.Part()
        pn = music21.stream.Part()
        
        for p in self.parts:
            mn, mc = p.to_m21()
            pn.append(mn)
            pc.append(mc)
            
        s.insert(0, pn)
        s.insert(0, pc)

#         s.flat.makeNotation(inPlace=True)
        s = s.transpose(0) # hack to get accidentals right. Above method does not work
        # music21 stream
        return s

# %%
from src import roman_to_symbol
from src import to_pianoroll
from collections import defaultdict
from midi_data import keyc_offset

# %%
import numpy as np
from collections import Counter

# %%
all_symbols = []
all_notes = []
all_map = []
jumps = []

# %%
s = parse_file(Path('data/midi/v7/midi_sources/hooktheory/xml/w/wyd-krakow-2016/blogoslawieni-milosierni/verse.xml'))

# %%
file_path = Path('data/midi/v7/midi_sources/hooktheory/xml/w/wyd-krakow-2016/blogoslawieni-milosierni/verse.xml')
content = load_data(file_path)
root = xml_parser(content)
metadata, version = get_metadata(root)
segments, num_measures = get_lead_sheet(root, version)

# %%
cdata = segments[-1]['chords'][-2]; cdata
# Out:
# OrderedDict([('sd', '5'),
#              ('fb', None),
#              ('sec', '4'),
#              ('sus', 'sus4'),
#              ('pedal', None),
#              ('alternate', None),
#              ('borrowed', None),
#              ('chord_duration', '4'),
#              ('start_measure', '3'),
#              ('start_beat', '1'),
#              ('start_beat_abs', '8'),
#              ('isRest', '0')])

# %%
def parse_file_emb(file_path):
    content = load_data(file_path)
    root = xml_parser(content)
    metadata, version = get_metadata(root)
    segments, num_measures = get_lead_sheet(root, version)
    for s in segments:
        for c in s['chords']:
            if 'emb' in c: 
                print('Found emb:', version, c['emb'])
                return

# %%
for f in files[:1000]:
    try: s = parse_file_emb(f)
    except Exception as e: 
        print('Exception:', e)
        continue
# Out:
# Found emb: None None
# Found emb: None None
# Found emb: None None
# Found emb: None None
# Found emb: 1.3 None
# Found emb: None None
# Found emb: 1.3 None
# Found emb: None None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: None add9
# Found emb: 1.3 None
# Found emb: 1.2 None
# Found emb: 1.3 None
# Found emb: 1.1 None
# Found emb: None add9
# Found emb: 1.3 None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.1 None
# Found emb: 1.1 None
# Found emb: 1.1 None
# Found emb: 1.1 None
# Found emb: 1.1 None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.1 None
# Found emb: 1.1 None
# Found emb: 1.3 None
# Found emb: 1.2 add9
# Found emb: 1.3 None
# Found emb: 1.1 None
# Found emb: None None
# Found emb: None add9
# Found emb: None add9
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.3 None
# Found emb: None None
# Found emb: 1.2 add9
# Found emb: 1.2 None
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: None None
# Found emb: 1.3 None
# Found emb: 1.2 None
# Found emb: 1.3 add9
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: None None
# Found emb: None None
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.1 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.1 None
# Found emb: None None
# Found emb: None None
# Found emb: None add9
# Found emb: 1.1 None
# Found emb: None add9
# Found emb: None add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.2 add9
# Found emb: 1.2 add9
# Found emb: None None
# Found emb: 1.2 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: None None
# Found emb: None add9
# Found emb: None add9
# Found emb: None None
# Found emb: 1.3 add9
# Found emb: 1.2 add9
# Found emb: 1.2 add9
# Found emb: 1.2 add9
# Found emb: 1.2 add9
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.1 #5
# Found emb: None None
# Found emb: None None
# Found emb: None None
# Found emb: None None
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.2 None
# Found emb: 1.3 add9
# Found emb: None add9
# Found emb: None None
# Found emb: 1.2 add9
# Found emb: None None
# Found emb: None None
# Found emb: None add9
# Found emb: None add9
# Found emb: None None
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: 1.2 None
# Found emb: None add9
# Found emb: None add9
# Found emb: None add9
# Found emb: None add9
# Found emb: 1.1 None
# Found emb: 1.2 add9
# Found emb: 1.3 None
# Found emb: None add9
# Found emb: None add9
# Found emb: None None
# Found emb: 1.2 add9
# Found emb: 1.2 add9
# Found emb: 1.3 None
# Found emb: None add9
# Found emb: None add9
# Found emb: None add9
# Found emb: None add9
# Found emb: None None
# Found emb: 1.3 add9
# Found emb: None None
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.2 add9
# Found emb: 1.2 None
# Found emb: 1.3 None
# Found emb: None add9
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: None None
# Found emb: 1.2 None
# Found emb: 1.1 add9
# Found emb: None None
# Found emb: None add9
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: None add9
# Found emb: 1.2 None
# Found emb: 1.2 None
# Found emb: 1.3 add9
# Found emb: 1.2 add9
# Found emb: 1.2 add9
# Found emb: None None
# Found emb: 1.2 add9
# Found emb: 1.2 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 None
# Found emb: 1.3 #5
# Found emb: 1.3 None
# Found emb: None add9
# Found emb: None None
# Found emb: None None
# Found emb: None None
# Found emb: None None
# Found emb: 1.2 None
# Found emb: None None
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: None None
# Found emb: 1.1 None
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.2 None
# Found emb: None None
# Found emb: None add9
# Found emb: 1.2 add9
# Found emb: 1.2 None
# Found emb: None None
# Found emb: 1.3 None
# Found emb: None add9
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 add9
# Found emb: 1.3 None
# Found emb: None None

# %%
parse_file_emb(file_path)
# Out:
# [{'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '2'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '2'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '1.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '9'),
#                 ('start_measure', '3'),
#                 ('start_beat', '2'),
#                 ('note_length', '3'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '2f'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2f'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2f'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.75'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14.75'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3.75'),
#                 ('note_length', '0.75'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '6'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '16'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('note_length', '2'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '18'),
#                 ('start_measure', '5'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '18.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '19.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '20'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '21'),
#                 ('start_measure', '6'),
#                 ('start_beat', '2'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '22'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '23'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '23.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '24'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '25'),
#                 ('start_measure', '7'),
#                 ('start_beat', '2'),
#                 ('note_length', '3'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '28'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '29'),
#                 ('start_measure', '8'),
#                 ('start_beat', '2'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '30'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '30.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '31.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')])],
#   'chords': [OrderedDict([('sd', '1'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus2'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '4'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '8'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '2'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '-6'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '12'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus2'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '14'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '16'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus4'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '20'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '22'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus4'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '-2'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '24'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '-2'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '26'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '28'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '30'),
#                 ('isRest', '0')])],
#   'num_measure': 8.0},
#  {'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '8'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '8'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('note_length', '2'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '10'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '1.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '17'),
#                 ('start_measure', '5'),
#                 ('start_beat', '2'),
#                 ('note_length', '3'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '20'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '2f'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '21'),
#                 ('start_measure', '6'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2f'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '21.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '2f'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '22'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.75'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '22.75'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3.75'),
#                 ('note_length', '0.75'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '23.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '6'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '24'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('note_length', '2'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '26'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '26.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '27.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '28'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '29'),
#                 ('start_measure', '8'),
#                 ('start_beat', '2'),
#                 ('note_length', '1'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '30'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '2'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '31'),
#                 ('start_measure', '8'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '31.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')])],
#   'chords': [OrderedDict([('sd', '5'),
#                 ('fb', None),
#                 ('sec', '4'),
#                 ('sus', 'sus4'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', None),
#                 ('sec', '4'),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '4'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '1'),
#                 ('fb', '7'),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '8'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus2'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '12'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '16'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '2'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '-6'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '20'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus2'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '22'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '3'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '24'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus4'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '28'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '30'),
#                 ('isRest', '0')])],
#   'num_measure': 8.0},
#  {'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '1'),
#                 ('start_measure', '1'),
#                 ('start_beat', '2'),
#                 ('note_length', '3'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '8'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('note_length', '8'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')])],
#   'chords': [OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus4'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '-2'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '4'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '-2'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '2'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '4'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '6'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', None),
#                 ('sec', '4'),
#                 ('sus', 'sus4'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '8'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', None),
#                 ('sec', '4'),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '12'),
#                 ('isRest', '0')])],
#   'num_measure': 4.0}]

# %%
# cdata['sec'] = '2'

# %%
from src.roman_to_symbol import *

# %%
KEY_TO_SCALE[MODE_TO_KEY[int('4')]]
# Out:
# [0, 2, 4, 6, 7, 9, 11]

# %%
def set_sus(comp_vec, scale, sd, input_):
    if input_ is None:
        return comp_vec
    elif input_ == 'sus2':
        comp_vec[1] = scale[sd+1]
    elif input_ == 'sus4':
        comp_vec[3] = scale[sd+3]
    elif input_ == 'sus42':
        comp_vec[1] = scale[sd+1]
        comp_vec[3] = scale[sd+3]
    else:
        raise ValueError('Unknown sus: %s' % input_)
    comp_vec[2] = None  # must omit 3
    return comp_vec

# %%
def hchord_parser(chord, mode, key_offset):
    if chord['sd'] == 'rest': return None

    # extract basic info
    sd = int(chord['sd']) - 1     # root
    fb = chord['fb']              # tension & inversion
    sec = chord['sec']            # secondary chord
    borrowed = chord.get('borrowed', None)  # borrowed mode

    # determine the mode
    borrowed = is_int(borrowed)
    chord_key = MODE_TO_KEY[int(mode)] if borrowed is None else borrowed
    chord_key = 6 if chord_key > 6 else chord_key
    chord_key = -6 if chord_key < -6 else chord_key

    # secondary chord
    sec_offset = 0
    if sec:
        # switch to 'sec' degree note within the current mode
        scale = KEY_TO_SCALE[MODE_TO_KEY[int(mode)]]
        new_key_note = scale[int(sec) - 1]

        # set that note to new key
        new_key = VAL_TO_NAME[new_key_note][0]

        # get the key shift offset
        sec_offset = NOTE_TO_OFFSET[new_key]
        chord_key = 0

    # determine the scale according to the key(mode) of the chord
    scale = get_scale(chord_key)

    # set compositional notes
    comp, chord_type = set_compositions(scale, fb, sd)

    # determine the quality by triads or seventh
    # (9, 11, 13-th chords are seen as seventh)
    comp_t = comp[0:3] if chord_type is 5 else comp[0:4]
    quality = get_quality(comp_t)

    # add shift from secondary chords
    comp = (comp + sec_offset)
    scale = [s+sec_offset for s in scale]

    # set compvec (for sus/add/omit)
    comp_vec = comp_to_compvec(comp)

    # sus (omit 3)
    sus = chord.get('sus', None)
    comp_vec = set_sus(comp_vec, scale, sd, sus)

    # emb (add/omit)
    if 'emb' in chord:
        emb = chord['emb']
        comp_vec, alter_info, emb_info = set_emb(comp_vec, scale, sd, emb)
    else:
        emb_info = []
        alter_info = []

    # alter (won't change the quality)
    alter_info = alter_info if len(alter_info) else chord.get('alternate', None)
    comp_vec, alter_map = set_alter(comp_vec, alter_info)

    # set inversion (won't change the root, but bass)
    inv = get_num_inversion(fb)
    comp_vec = set_inversion(comp_vec, inv)

    # set result
    comp = compvec_to_comp(comp_vec)
    root = (comp[0] + 120) % 12   # for chord name
    bass = np.nanmin(comp)         # for bass (real root)

    data = OrderedDict([
        # basic compositions
        ('root', root),
        ('bass', bass),
        ('comp_vec', comp_vec),
        ('composition', comp),

        # basic info
        ('quality', quality),
        ('chord_type', chord_type),
        ('chord_mode', chord_key),
        
        # additional info
        ('inv', inv),
        ('sus', sus),
        ('alter', alter_info),
        ('emb', emb_info),
        ('alter_map', alter_map),
        ])

    # key shifting of the symbol
    data = chord_key_shifting(data, key_offset)

    # set chord name
    data['symbol'] = chord_to_string(data)
    return data

# %%
hchord_parser(cdata, '6', 0)
# Out:
# OrderedDict([('root', 0),
#              ('bass', 12),
#              ('comp_vec',
#               array([12, None, None, 17, 19, None, None, None, None], dtype=object)),
#              ('composition', array([12, 17, 19], dtype=object)),
#              ('quality', ''),
#              ('chord_type', 5),
#              ('chord_mode', 0),
#              ('inv', 0),
#              ('sus', 'sus4'),
#              ('alter', None),
#              ('emb', []),
#              ('alter_map', None),
#              ('symbol', 'C sus4')])

# %%
[s['chords'] for s in segments]
# Out:
# [[OrderedDict([('sd', '1'),
#                ('fb', '7'),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '1'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '0'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '6'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus2'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '2'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '4'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '3'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '3'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '8'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '2'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', '-6'),
#                ('chord_duration', '2'),
#                ('start_measure', '4'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '12'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '6'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus2'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '4'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '14'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '3'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '5'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '16'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '7'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus4'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '6'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '20'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '7'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '6'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '22'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '4'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus4'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', '-2'),
#                ('chord_duration', '2'),
#                ('start_measure', '7'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '24'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '4'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', '-2'),
#                ('chord_duration', '2'),
#                ('start_measure', '7'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '26'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '6'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '8'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '28'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '7'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '8'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '30'),
#                ('isRest', '0')])],
#  [OrderedDict([('sd', '5'),
#                ('fb', None),
#                ('sec', '4'),
#                ('sus', 'sus4'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '1'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '0'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '5'),
#                ('fb', None),
#                ('sec', '4'),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '2'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '4'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '1'),
#                ('fb', '7'),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '3'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '8'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '6'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus2'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '4'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '12'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '3'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '5'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '16'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '2'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', '-6'),
#                ('chord_duration', '2'),
#                ('start_measure', '6'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '20'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '6'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus2'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '6'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '22'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '3'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '7'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '24'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '7'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus4'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '8'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '28'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '7'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '8'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '30'),
#                ('isRest', '0')])],
#  [OrderedDict([('sd', '4'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', 'sus4'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', '-2'),
#                ('chord_duration', '2'),
#                ('start_measure', '1'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '0'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '4'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', '-2'),
#                ('chord_duration', '2'),
#                ('start_measure', '1'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '2'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '6'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '2'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '4'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '7'),
#                ('fb', None),
#                ('sec', None),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '2'),
#                ('start_measure', '2'),
#                ('start_beat', '3'),
#                ('start_beat_abs', '6'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '5'),
#                ('fb', None),
#                ('sec', '4'),
#                ('sus', 'sus4'),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '3'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '8'),
#                ('isRest', '0')]),
#   OrderedDict([('sd', '5'),
#                ('fb', None),
#                ('sec', '4'),
#                ('sus', None),
#                ('pedal', None),
#                ('alternate', None),
#                ('borrowed', None),
#                ('chord_duration', '4'),
#                ('start_measure', '4'),
#                ('start_beat', '1'),
#                ('start_beat_abs', '12'),
#                ('isRest', '0')])]]

# %%
[p.chords for p in s.parts]
# Out:
# [[HChord(scale=6, base=7, sus=0, duration=4.0, measure=1.0, beat=1.0, beat_abs=0.0, composition=[0, 3, 7, 10], symbol='cm7', quality='m'),
#   HChord(scale=3, base=0, sus=2, duration=4.0, measure=2.0, beat=1.0, beat_abs=4.0, composition=[8, 10, 15], symbol='Ab sus2', quality=''),
#   HChord(scale=0, base=0, sus=0, duration=4.0, measure=3.0, beat=1.0, beat_abs=8.0, composition=[3, 7, 10], symbol='Eb', quality=''),
#   HChord(scale=7, base=0, sus=0, duration=2.0, measure=4.0, beat=1.0, beat_abs=12.0, composition=[1, 5, 8], symbol='Db', quality=''),
#   HChord(scale=3, base=0, sus=2, duration=2.0, measure=4.0, beat=3.0, beat_abs=14.0, composition=[8, 10, 15], symbol='Ab sus2', quality=''),
#   HChord(scale=0, base=0, sus=0, duration=4.0, measure=5.0, beat=1.0, beat_abs=16.0, composition=[3, 7, 10], symbol='Eb', quality=''),
#   HChord(scale=4, base=0, sus=4, duration=2.0, measure=6.0, beat=1.0, beat_abs=20.0, composition=[10, 15, 17], symbol='Bb sus4', quality=''),
#   HChord(scale=4, base=0, sus=0, duration=2.0, measure=6.0, beat=3.0, beat_abs=22.0, composition=[10, 14, 17], symbol='Bb', quality=''),
#   HChord(scale=1, base=0, sus=4, duration=2.0, measure=7.0, beat=1.0, beat_abs=24.0, composition=[5, 10, 12], symbol='F sus4', quality=''),
#   HChord(scale=1, base=0, sus=0, duration=2.0, measure=7.0, beat=3.0, beat_abs=26.0, composition=[5, 9, 12], symbol='F', quality=''),
#   HChord(scale=3, base=0, sus=0, duration=2.0, measure=8.0, beat=1.0, beat_abs=28.0, composition=[8, 12, 15], symbol='Ab', quality=''),
#   HChord(scale=4, base=0, sus=0, duration=2.0, measure=8.0, beat=3.0, beat_abs=30.0, composition=[10, 14, 17], symbol='Bb', quality='')],
#  [HChord(scale=2, base=0, sus=4, duration=4.0, measure=1.0, beat=1.0, beat_abs=0.0, composition=[12, 12, 19], symbol='C sus4', quality=''),
#   HChord(scale=2, base=0, sus=0, duration=4.0, measure=2.0, beat=1.0, beat_abs=4.0, composition=[12, 16, 19], symbol='C', quality=''),
#   HChord(scale=6, base=7, sus=0, duration=4.0, measure=3.0, beat=1.0, beat_abs=8.0, composition=[0, 3, 7, 10], symbol='cm7', quality='m'),
#   HChord(scale=3, base=0, sus=2, duration=4.0, measure=4.0, beat=1.0, beat_abs=12.0, composition=[8, 10, 15], symbol='Ab sus2', quality=''),
#   HChord(scale=0, base=0, sus=0, duration=4.0, measure=5.0, beat=1.0, beat_abs=16.0, composition=[3, 7, 10], symbol='Eb', quality=''),
#   HChord(scale=7, base=0, sus=0, duration=2.0, measure=6.0, beat=1.0, beat_abs=20.0, composition=[1, 5, 8], symbol='Db', quality=''),
#   HChord(scale=3, base=0, sus=2, duration=2.0, measure=6.0, beat=3.0, beat_abs=22.0, composition=[8, 10, 15], symbol='Ab sus2', quality=''),
#   HChord(scale=0, base=0, sus=0, duration=4.0, measure=7.0, beat=1.0, beat_abs=24.0, composition=[3, 7, 10], symbol='Eb', quality=''),
#   HChord(scale=4, base=0, sus=4, duration=2.0, measure=8.0, beat=1.0, beat_abs=28.0, composition=[10, 15, 17], symbol='Bb sus4', quality=''),
#   HChord(scale=4, base=0, sus=0, duration=2.0, measure=8.0, beat=3.0, beat_abs=30.0, composition=[10, 14, 17], symbol='Bb', quality='')],
#  [HChord(scale=1, base=0, sus=4, duration=2.0, measure=1.0, beat=1.0, beat_abs=0.0, composition=[5, 10, 12], symbol='F sus4', quality=''),
#   HChord(scale=1, base=0, sus=0, duration=2.0, measure=1.0, beat=3.0, beat_abs=2.0, composition=[5, 9, 12], symbol='F', quality=''),
#   HChord(scale=3, base=0, sus=0, duration=2.0, measure=2.0, beat=1.0, beat_abs=4.0, composition=[8, 12, 15], symbol='Ab', quality=''),
#   HChord(scale=4, base=0, sus=0, duration=2.0, measure=2.0, beat=3.0, beat_abs=6.0, composition=[10, 14, 17], symbol='Bb', quality=''),
#   HChord(scale=2, base=0, sus=4, duration=4.0, measure=3.0, beat=1.0, beat_abs=8.0, composition=[12, 12, 19], symbol='C sus4', quality=''),
#   HChord(scale=2, base=0, sus=0, duration=4.0, measure=4.0, beat=1.0, beat_abs=12.0, composition=[12, 16, 19], symbol='C', quality='')]]

# %%
for f in files[:300]:
    try: s = parse_file(f)
    except Exception as e: 
        print('Exception:', e)
        continue
    for p in s.parts:
        for c in p.chords:
            if len(c.composition) > 4: continue
            all_symbols.append(c.symbol)
            chords = list(([i%12 for i in sorted(c.composition)]))
            all_notes.append(str(chords))
            all_map.append(c.symbol + ' - ' + str(chords))
            jumps.append(str(np.diff(sorted(c.composition))))
            j = np.diff(c.composition)
#             if np.any(j > 6): print(c.symbol)
            if np.any(j == 0): print(c.symbol, c.composition, f)
#             print(c.symbol, c.composition, j)
# Out:
# C sus4 [12, 12, 19] data/midi/v7/midi_sources/hooktheory/xml/w/wolfgang-amadeus-mozart/kyrie-from-mass-in-c-minor-k-427/verse.xml
# C sus4 [12, 12, 19] data/midi/v7/midi_sources/hooktheory/xml/w/wolfgang-amadeus-mozart/kyrie-from-mass-in-c-minor-k-427/verse.xml
# C7 sus4 [12, 12, 19, 22] data/midi/v7/midi_sources/hooktheory/xml/w/wolfgang-amadeus-mozart/confutatis-from-requiem/bridge.xml
# C sus4 [12, 12, 19] data/midi/v7/midi_sources/hooktheory/xml/w/wyd-krakow-2016/blogoslawieni-milosierni/verse.xml
# C sus4 [12, 12, 19] data/midi/v7/midi_sources/hooktheory/xml/w/wyd-krakow-2016/blogoslawieni-milosierni/verse.xml

# %%
jumps_count = Counter(jumps); len(jumps_count)
# Out:
# 63

# %%
jumps_count.most_common()
# Out:
# [('[4 3]', 7643),
#  ('[3 4]', 3650),
#  ('[3 4 3]', 975),
#  ('[3 5]', 713),
#  ('[4 3 4]', 647),
#  ('[4 3 3]', 637),
#  ('[5 4]', 457),
#  ('[4 5]', 303),
#  ('[3 3]', 222),
#  ('[5 3]', 198),
#  ('[5 2]', 186),
#  ('[4 3 7]', 161),
#  ('[4 3 2]', 118),
#  ('[2 3 4]', 105),
#  ('[3 3 2]', 99),
#  ('[2 4 3]', 98),
#  ('[5 2 3]', 88),
#  ('[3 3 4]', 86),
#  ('[2 5]', 85),
#  ('[3 4 7]', 75),
#  ('[3 2 4]', 61),
#  ('[3 4 2]', 49),
#  ('[2 5 3]', 36),
#  ('[3 4 1]', 32),
#  ('[1 4 3]', 31),
#  ('[2 3 3]', 29),
#  ('[3 2 3]', 27),
#  ('[3 6]', 25),
#  ('[6 3]', 24),
#  ('[2 5 4]', 23),
#  ('[2 3 2]', 20),
#  ('[3 5 2]', 17),
#  ('[4 1 4]', 12),
#  ('[5 2 2]', 12),
#  ('[4 2 3]', 11),
#  ('[0 7]', 10),
#  ('[6 1]', 6),
#  ('[0 7 3]', 6),
#  ('[4 5 2]', 5),
#  ('[2 5 2]', 4),
#  ('[2 7]', 4),
#  ('[1 6 3]', 4),
#  ('[5 7 3]', 3),
#  ('[5 2 4]', 3),
#  ('[1 5 4]', 3),
#  ('[4 5 1]', 3),
#  ('[2 7 3]', 2),
#  ('[4 7 3]', 2),
#  ('[3 2 5]', 2),
#  ('[5 5]', 2),
#  ('[3 0 3]', 1),
#  ('[5 7]', 1),
#  ('[5 1]', 1),
#  ('[1 5]', 1),
#  ('[6 1 4]', 1),
#  ('[4 7]', 1),
#  ('[4 4 3]', 1),
#  ('[5 1 2]', 1),
#  ('[2 0 7]', 1),
#  ('[0 2 7]', 1),
#  ('[3 7]', 1),
#  ('[4 4]', 1),
#  ('[3 4 6]', 1)]

# %%
# quality -

# %%
symbol_count = Counter(all_symbols); len(symbol_count)
# Out:
# 299

# %%
symbol_count.most_common()
# Out:
# [('C', 2396),
#  ('F', 2085),
#  ('G', 2049),
#  ('am', 2004),
#  ('dm', 751),
#  ('em', 637),
#  ('E', 331),
#  ('Fmaj7', 328),
#  ('dm7', 315),
#  ('am7', 297),
#  ('Bb', 275),
#  ('C | E', 254),
#  ('em7', 248),
#  ('G7', 241),
#  ('G | B', 200),
#  ('C | G', 158),
#  ('Cmaj7', 138),
#  ('F | C', 134),
#  ('D', 130),
#  ('G | D', 122),
#  ('E7', 119),
#  ('A', 114),
#  ('Ab', 104),
#  ('am | E', 96),
#  ('am | C', 91),
#  ('F | A', 90),
#  ('em | G', 90),
#  ('Eb', 83),
#  ('D7', 78),
#  ('Bbmaj7', 74),
#  ('A7', 73),
#  ('dm | F', 70),
#  ('G sus4', 68),
#  ('fm', 67),
#  ('E | Ab', 65),
#  ('C7', 62),
#  ('abo', 61),
#  ('am7 | G', 60),
#  ('gm', 59),
#  ('cm', 57),
#  ('F (add9)', 55),
#  ('dm7 | F', 52),
#  ('em | B', 52),
#  ('gbo', 47),
#  ('D | Gb', 47),
#  ('bo', 44),
#  ('B', 44),
#  ('dm (add9)', 43),
#  ('G7 | F', 43),
#  ('bm', 42),
#  ('C (add9)', 42),
#  ('G (add9)', 41),
#  ('gbø7', 38),
#  ('C sus4', 37),
#  ('Abmaj7', 36),
#  ('am7 | C', 35),
#  ('G7 sus4', 30),
#  ('dm | A', 30),
#  ('bm7', 29),
#  ('Gmaj7', 29),
#  ('dm7 | C', 29),
#  ('bø7', 27),
#  ('gm7', 27),
#  ('E7 | Ab', 26),
#  ('G7 | B', 25),
#  ('F7', 25),
#  ('ebo', 25),
#  ('am (add9)', 24),
#  ('Cmaj7 | E', 23),
#  ('A sus4', 23),
#  ('Gb', 23),
#  ('E sus4', 23),
#  ('fm | Ab', 22),
#  ('D7 | A', 22),
#  ('F sus2', 22),
#  ('B | Eb', 21),
#  ('em7 | G', 21),
#  ('Ebmaj7', 21),
#  ('D7 | Gb', 20),
#  ('E7 sus4', 20),
#  ('am sus4', 19),
#  ('A7 | Db', 18),
#  ('fm7', 18),
#  ('am7 sus4', 18),
#  ('E | B', 18),
#  ('C sus2', 18),
#  ('gbø7 | A', 17),
#  ('am7 | E', 16),
#  ('D7 | C', 16),
#  ('cm7', 16),
#  ('am7 sus2', 15),
#  ('Bb | D', 15),
#  ('do', 15),
#  ('bø7 | D', 14),
#  ('Cmaj7 | B', 14),
#  ('G7 | D', 13),
#  ('A | Db', 13),
#  ('B7', 13),
#  ('cm | Eb', 13),
#  ('Fmaj7 | E', 12),
#  ('E7 | D', 12),
#  ('gbø7 | E', 12),
#  ('am sus2', 12),
#  ('Cmaj7 sus2', 12),
#  ('gm | Bb', 12),
#  ('dø7 | F', 11),
#  ('C7 | Bb', 11),
#  ('eo', 11),
#  ('em sus4', 11),
#  ('Bb (add9)', 11),
#  ('gbm', 10),
#  ('D sus4', 10),
#  ('Dbmaj7', 10),
#  ('em7 sus4', 10),
#  ('dm sus4', 10),
#  ('dm sus2', 9),
#  ('Db', 9),
#  ('am sus42', 9),
#  ('Bb7', 9),
#  ('fm7 | Ab', 8),
#  ('C7 | G', 8),
#  ('E7 | B', 8),
#  ('bø7 | A', 8),
#  ('em7 | D', 8),
#  ('Fmaj7 sus2', 8),
#  ('G sus2', 8),
#  ('dm7 | A', 8),
#  ('Gb7', 7),
#  ('abm', 7),
#  ('ao', 7),
#  ('F sus4', 7),
#  ('bo | D', 7),
#  ('gbo | C', 7),
#  ('abo | B', 7),
#  ('dø7', 7),
#  ('fm | C', 7),
#  ('dø7 | C', 7),
#  ('Bb | F', 6),
#  ('Fmaj7 | A', 6),
#  ('G | B (add9)', 6),
#  ('gbm7', 6),
#  ('A7 | G', 6),
#  ('cm | G', 6),
#  ('abo | D', 6),
#  ('B7 | A', 6),
#  ('D7 sus4', 6),
#  ('D | A', 6),
#  ('eø7', 6),
#  ('dbo', 6),
#  ('Ab | C', 6),
#  ('Fmaj7 | C', 6),
#  ('dm7 sus2', 6),
#  ('cm7 sus2', 6),
#  ('bm (add9)', 6),
#  ('bbo', 5),
#  ('dø7 | Ab', 5),
#  ('C7 | E', 5),
#  ('D (add9)', 5),
#  ('dbm7', 5),
#  ('Eb7', 5),
#  ('Bb | F (add9)', 5),
#  ('abm7', 5),
#  ('Cmaj7 | G', 5),
#  ('dbm', 5),
#  ('Bbmaj7 | A', 5),
#  ('bo | F', 5),
#  ('Amaj7', 4),
#  ('A7 | E', 4),
#  ('ebo | Gb', 4),
#  ('cm7 | Bb', 4),
#  ('bø7 | F', 4),
#  ('A7 sus4', 4),
#  ('B7 | Eb', 4),
#  ('F | A (add9)', 4),
#  ('A | E', 4),
#  ('ebm7', 4),
#  ('bbm7', 4),
#  ('Gb sus4', 4),
#  ('C | E (add9)', 4),
#  ('G sus42', 4),
#  ('Ab | Eb', 4),
#  ('dm sus42', 4),
#  ('bm7 | A', 3),
#  ('ebm', 3),
#  ('F7 sus4', 3),
#  ('gm | D', 3),
#  ('Eb (add9)', 3),
#  ('B7 | Gb', 3),
#  ('Ab7', 3),
#  ('eø7 | G', 3),
#  ('ebø7', 3),
#  ('aø7 | C', 3),
#  ('Bb7 | F', 3),
#  ('eo | G', 3),
#  ('bm7 sus4', 3),
#  ('aø7 sus2', 3),
#  ('C | G (add9)', 3),
#  ('gm | Bb (add9)', 3),
#  ('A7 sus2', 3),
#  ('Emaj7', 3),
#  ('Eb | Bb', 3),
#  ('em | G (add9)', 3),
#  ('am | D sus4', 3),
#  ('em7 sus2', 3),
#  ('Bb sus2', 3),
#  ('bbø7', 2),
#  ('co | Gb', 2),
#  ('dm | F (add9)', 2),
#  ('G7 | F sus4', 2),
#  ('am7 | G sus4', 2),
#  ('aø7 | G', 2),
#  ('gbo | A', 2),
#  ('B7 sus4', 2),
#  ('bm | D', 2),
#  ('Gmaj7 sus4', 2),
#  ('bbm', 2),
#  ('aø7', 2),
#  ('C7 sus4', 2),
#  ('ao | Eb', 2),
#  ('G7 sus2', 2),
#  ('em7 | B', 2),
#  ('B | Gb', 2),
#  ('A sus2', 2),
#  ('Ab7 | Gb', 2),
#  ('Db7', 2),
#  ('Eb sus2', 2),
#  ('bm | Gb', 2),
#  ('A (add9)', 2),
#  ('em7 | B sus4', 2),
#  ('em | B sus4', 2),
#  ('em | A sus4', 2),
#  ('em (add9)', 2),
#  ('gm7 sus2', 2),
#  ('Bb7 | Ab', 2),
#  ('Ab (add9)', 2),
#  ('Abmaj7 | C', 2),
#  ('F | C (add9)', 2),
#  ('Dmaj7', 2),
#  ('co', 1),
#  ('gbo (add9)', 1),
#  ('dbø7 | E', 1),
#  ('dbo | G', 1),
#  ('abø7', 1),
#  ('B sus4', 1),
#  ('gbø7 | C', 1),
#  ('gbm7 | A', 1),
#  ('Gb | Bb', 1),
#  ('F7 | A', 1),
#  ('ao | C', 1),
#  ('Db sus2', 1),
#  ('do sus4', 1),
#  ('Bbmaj7 sus2', 1),
#  ('dbm | E', 1),
#  ('eo sus2', 1),
#  ('dbm (add9)', 1),
#  ('abm | B', 1),
#  ('abm | Eb', 1),
#  ('Fmaj7 sus4', 1),
#  ('dbm7 sus4', 1),
#  ('gbm | A', 1),
#  ('Eb | G', 1),
#  ('gm7 | Bb', 1),
#  ('Abmaj7 (#5)', 1),
#  ('cm sus2', 1),
#  ('Ebmaj7 sus4', 1),
#  ('Gb sus2', 1),
#  ('Bmaj7', 1),
#  ('dm7 sus4', 1),
#  ('D7 sus2', 1),
#  ('em | B (add9)', 1),
#  ('bm sus4', 1),
#  ('gbm | Db', 1),
#  ('aø7 | Eb', 1),
#  ('C7 | Bb sus4', 1),
#  ('D7 | C sus4', 1),
#  ('A7 | G sus4', 1),
#  ('bm7 | Gb', 1),
#  ('G | C sus4', 1),
#  ('D | A (add9)', 1),
#  ('Dbmaj7 sus2', 1),
#  ('Gmaj7 sus2', 1),
#  ('Db | F (add9)', 1),
#  ('ebm7 sus2', 1),
#  ('Ab sus42', 1),
#  ('Bb | D (add9)', 1),
#  ('do | Ab', 1),
#  ('B | Eb (add9)', 1),
#  ('E | Ab (#5)', 1),
#  ('gm sus4', 1),
#  ('C7 sus2', 1),
#  ('Bbmaj7 | D', 1),
#  ('Dbmaj7 | Ab', 1),
#  ('Eb7 sus4', 1),
#  ('B7 sus2', 1),
#  ('do | F', 1),
#  ('Eb | Bb (add9)', 1),
#  ('fm sus42', 1),
#  ('gm sus42', 1),
#  ('Gbmaj7', 1)]

# %%
note_count = Counter(all_notes); len(note_count)
# Out:
# 294

# %%
note_count.most_common()
# Out:
# [('[0, 4, 7]', 2396),
#  ('[5, 9, 0]', 2085),
#  ('[7, 11, 2]', 2049),
#  ('[9, 0, 4]', 2008),
#  ('[2, 5, 9]', 751),
#  ('[4, 7, 11]', 637),
#  ('[4, 8, 11]', 331),
#  ('[5, 9, 0, 4]', 328),
#  ('[2, 5, 9, 0]', 315),
#  ('[9, 0, 4, 7]', 298),
#  ('[10, 2, 5]', 275),
#  ('[4, 7, 0]', 254),
#  ('[4, 7, 11, 2]', 248),
#  ('[7, 11, 2, 5]', 241),
#  ('[11, 2, 7]', 200),
#  ('[7, 0, 4]', 158),
#  ('[0, 4, 7, 11]', 138),
#  ('[0, 5, 9]', 134),
#  ('[2, 6, 9]', 130),
#  ('[2, 7, 11]', 122),
#  ('[4, 8, 11, 2]', 119),
#  ('[9, 1, 4]', 114),
#  ('[8, 0, 3]', 104),
#  ('[4, 9, 0]', 96),
#  ('[0, 4, 9]', 91),
#  ('[9, 0, 5]', 90),
#  ('[7, 11, 4]', 90),
#  ('[3, 7, 10]', 83),
#  ('[2, 6, 9, 0]', 78),
#  ('[10, 2, 5, 9]', 74),
#  ('[9, 1, 4, 7]', 73),
#  ('[5, 9, 2]', 70),
#  ('[7, 0, 2]', 68),
#  ('[5, 8, 0]', 67),
#  ('[8, 11, 4]', 65),
#  ('[0, 4, 7, 10]', 62),
#  ('[7, 9, 0, 4]', 61),
#  ('[8, 11, 2]', 61),
#  ('[7, 10, 2]', 59),
#  ('[0, 3, 7]', 57),
#  ('[5, 9, 0, 7]', 55),
#  ('[5, 9, 0, 2]', 52),
#  ('[11, 4, 7]', 52),
#  ('[6, 9, 0]', 47),
#  ('[6, 9, 2]', 47),
#  ('[11, 2, 5]', 44),
#  ('[11, 3, 6]', 44),
#  ('[2, 5, 9, 4]', 43),
#  ('[5, 7, 11, 2]', 43),
#  ('[11, 2, 6]', 42),
#  ('[0, 4, 7, 2]', 42),
#  ('[7, 11, 2, 9]', 41),
#  ('[6, 9, 0, 4]', 38),
#  ('[0, 5, 7]', 37),
#  ('[8, 0, 3, 7]', 36),
#  ('[0, 4, 7, 9]', 35),
#  ('[4, 9, 11]', 33),
#  ('[9, 2, 5]', 30),
#  ('[7, 0, 2, 5]', 29),
#  ('[11, 2, 6, 9]', 29),
#  ('[7, 11, 2, 6]', 29),
#  ('[0, 2, 5, 9]', 29),
#  ('[9, 2, 4]', 28),
#  ('[4, 9, 11, 2]', 28),
#  ('[11, 2, 5, 9]', 27),
#  ('[7, 10, 2, 5]', 27),
#  ('[8, 11, 2, 4]', 26),
#  ('[11, 2, 5, 7]', 25),
#  ('[5, 9, 0, 3]', 25),
#  ('[3, 6, 9]', 25),
#  ('[9, 0, 4, 11]', 24),
#  ('[4, 7, 11, 0]', 23),
#  ('[6, 10, 1]', 23),
#  ('[8, 0, 5]', 22),
#  ('[9, 0, 2, 6]', 22),
#  ('[5, 7, 0]', 22),
#  ('[3, 6, 11]', 21),
#  ('[7, 11, 2, 4]', 21),
#  ('[3, 7, 10, 2]', 21),
#  ('[6, 9, 0, 2]', 20),
#  ('[9, 2, 4, 7]', 20),
#  ('[0, 2, 7]', 20),
#  ('[1, 4, 7, 9]', 18),
#  ('[5, 8, 0, 3]', 18),
#  ('[11, 4, 8]', 18),
#  ('[9, 11, 4, 7]', 17),
#  ('[9, 0, 4, 6]', 17),
#  ('[4, 7, 9, 0]', 16),
#  ('[0, 2, 6, 9]', 16),
#  ('[9, 11, 4]', 16),
#  ('[2, 7, 9]', 16),
#  ('[0, 3, 7, 10]', 16),
#  ('[2, 5, 10]', 15),
#  ('[2, 5, 8]', 15),
#  ('[2, 5, 9, 11]', 14),
#  ('[11, 0, 4, 7]', 14),
#  ('[2, 5, 7, 11]', 13),
#  ('[1, 4, 9]', 13),
#  ('[11, 3, 6, 9]', 13),
#  ('[3, 7, 0]', 13),
#  ('[2, 4, 9]', 12),
#  ('[4, 5, 9, 0]', 12),
#  ('[6, 9, 1]', 12),
#  ('[2, 4, 8, 11]', 12),
#  ('[4, 6, 9, 0]', 12),
#  ('[0, 2, 7, 11]', 12),
#  ('[10, 2, 7]', 12),
#  ('[5, 8, 0, 2]', 11),
#  ('[10, 0, 4, 7]', 11),
#  ('[4, 7, 10]', 11),
#  ('[10, 2, 5, 0]', 11),
#  ('[9, 9, 4]', 10),
#  ('[1, 5, 8, 0]', 10),
#  ('[1, 5, 8]', 9),
#  ('[9, 11, 2, 4]', 9),
#  ('[7, 9, 2]', 9),
#  ('[10, 2, 5, 8]', 9),
#  ('[8, 0, 3, 5]', 8),
#  ('[7, 10, 0, 4]', 8),
#  ('[11, 2, 4, 8]', 8),
#  ('[9, 11, 2, 5]', 8),
#  ('[2, 4, 7, 11]', 8),
#  ('[5, 7, 0, 4]', 8),
#  ('[9, 0, 2, 5]', 8),
#  ('[6, 10, 1, 4]', 7),
#  ('[8, 11, 3]', 7),
#  ('[9, 0, 3]', 7),
#  ('[2, 5, 11]', 7),
#  ('[0, 6, 9]', 7),
#  ('[11, 2, 8]', 7),
#  ('[2, 4, 9, 0]', 7),
#  ('[2, 5, 8, 0]', 7),
#  ('[0, 5, 8]', 7),
#  ('[0, 2, 7, 10]', 7),
#  ('[0, 2, 5, 8]', 7),
#  ('[5, 10, 2]', 6),
#  ('[9, 0, 4, 5]', 6),
#  ('[11, 2, 7, 9]', 6),
#  ('[6, 9, 1, 4]', 6),
#  ('[7, 9, 1, 4]', 6),
#  ('[5, 11, 0]', 6),
#  ('[7, 0, 3]', 6),
#  ('[2, 8, 11]', 6),
#  ('[9, 11, 3, 6]', 6),
#  ('[9, 2, 6]', 6),
#  ('[4, 7, 10, 2]', 6),
#  ('[1, 4, 7]', 6),
#  ('[0, 3, 8]', 6),
#  ('[0, 4, 5, 9]', 6),
#  ('[11, 2, 6, 1]', 6),
#  ('[10, 1, 4]', 5),
#  ('[8, 0, 2, 5]', 5),
#  ('[4, 7, 10, 0]', 5),
#  ('[2, 6, 9, 4]', 5),
#  ('[1, 4, 8, 11]', 5),
#  ('[3, 7, 10, 1]', 5),
#  ('[5, 10, 0, 2]', 5),
#  ('[7, 9, 0, 2]', 5),
#  ('[8, 11, 3, 6]', 5),
#  ('[7, 11, 0, 4]', 5),
#  ('[1, 4, 8]', 5),
#  ('[9, 10, 2, 5]', 5),
#  ('[5, 11, 2]', 5),
#  ('[9, 1, 4, 8]', 4),
#  ('[4, 7, 9, 1]', 4),
#  ('[6, 9, 3]', 4),
#  ('[10, 0, 3, 7]', 4),
#  ('[5, 9, 11, 2]', 4),
#  ('[3, 6, 9, 11]', 4),
#  ('[9, 0, 5, 7]', 4),
#  ('[4, 9, 1]', 4),
#  ('[3, 6, 10, 1]', 4),
#  ('[10, 1, 5, 8]', 4),
#  ('[4, 7, 0, 2]', 4),
#  ('[3, 8, 0]', 4),
#  ('[2, 4, 7, 9]', 4),
#  ('[2, 2, 9, 0]', 4),
#  ('[9, 11, 2, 6]', 3),
#  ('[3, 6, 10]', 3),
#  ('[5, 10, 0, 3]', 3),
#  ('[2, 7, 10]', 3),
#  ('[3, 7, 10, 5]', 3),
#  ('[6, 9, 11, 3]', 3),
#  ('[8, 0, 3, 6]', 3),
#  ('[7, 10, 2, 4]', 3),
#  ('[3, 6, 9, 1]', 3),
#  ('[0, 3, 7, 9]', 3),
#  ('[5, 8, 10, 2]', 3),
#  ('[7, 9, 2, 5]', 3),
#  ('[7, 10, 4]', 3),
#  ('[11, 4, 6, 9]', 3),
#  ('[9, 10, 3, 7]', 3),
#  ('[7, 0, 2, 4]', 3),
#  ('[10, 2, 7, 9]', 3),
#  ('[4, 8, 11, 3]', 3),
#  ('[0, 2, 9]', 3),
#  ('[10, 3, 7]', 3),
#  ('[7, 11, 4, 5]', 3),
#  ('[10, 1, 4, 8]', 2),
#  ('[6, 0, 3]', 2),
#  ('[5, 9, 2, 4]', 2),
#  ('[5, 7, 0, 2]', 2),
#  ('[7, 9, 2, 4]', 2),
#  ('[7, 9, 0, 3]', 2),
#  ('[9, 0, 6]', 2),
#  ('[9, 2, 9, 0]', 2),
#  ('[9, 11, 6, 9]', 2),
#  ('[2, 6, 11]', 2),
#  ('[7, 0, 2, 6]', 2),
#  ('[10, 1, 5]', 2),
#  ('[9, 9, 4, 7]', 2),
#  ('[9, 0, 3, 7]', 2),
#  ('[0, 5, 7, 10]', 2),
#  ('[3, 9, 0]', 2),
#  ('[11, 2, 4, 7]', 2),
#  ('[6, 11, 3]', 2),
#  ('[0, 4, 11, 2]', 2),
#  ('[6, 8, 0, 3]', 2),
#  ('[1, 5, 8, 11]', 2),
#  ('[6, 11, 1]', 2),
#  ('[3, 5, 10]', 2),
#  ('[6, 11, 2]', 2),
#  ('[9, 1, 4, 11]', 2),
#  ('[11, 2, 4, 9]', 2),
#  ('[11, 4, 9]', 2),
#  ('[4, 5, 11, 2]', 2),
#  ('[7, 8, 2, 5]', 2),
#  ('[10, 0, 5]', 2),
#  ('[8, 10, 2, 5]', 2),
#  ('[8, 0, 3, 10]', 2),
#  ('[0, 3, 7, 8]', 2),
#  ('[0, 5, 7, 9]', 2),
#  ('[2, 6, 9, 1]', 2),
#  ('[0, 3, 6]', 1),
#  ('[6, 9, 9, 0]', 1),
#  ('[4, 7, 11, 1]', 1),
#  ('[7, 1, 4]', 1),
#  ('[8, 11, 2, 6]', 1),
#  ('[9, 11, 6]', 1),
#  ('[9, 2, 9]', 1),
#  ('[0, 4, 6, 9]', 1),
#  ('[9, 1, 4, 6]', 1),
#  ('[10, 1, 6]', 1),
#  ('[9, 0, 3, 5]', 1),
#  ('[0, 3, 9]', 1),
#  ('[1, 3, 8]', 1),
#  ('[2, 7, 8]', 1),
#  ('[10, 0, 5, 9]', 1),
#  ('[4, 8, 1]', 1),
#  ('[4, 5, 10]', 1),
#  ('[1, 4, 8, 3]', 1),
#  ('[11, 3, 8]', 1),
#  ('[3, 8, 11]', 1),
#  ('[5, 11, 0, 4]', 1),
#  ('[0, 4, 11]', 1),
#  ('[1, 6, 8, 11]', 1),
#  ('[9, 1, 6]', 1),
#  ('[7, 10, 3]', 1),
#  ('[10, 2, 5, 7]', 1),
#  ('[8, 0, 4, 7]', 1),
#  ('[3, 8, 10, 2]', 1),
#  ('[6, 8, 1]', 1),
#  ('[11, 3, 6, 10]', 1),
#  ('[2, 7, 9, 0]', 1),
#  ('[11, 4, 5, 7]', 1),
#  ('[11, 4, 6]', 1),
#  ('[1, 6, 9]', 1),
#  ('[3, 7, 9, 0]', 1),
#  ('[10, 0, 0, 7]', 1),
#  ('[0, 0, 2, 9]', 1),
#  ('[6, 9, 11, 2]', 1),
#  ('[4, 7, 11, 6]', 1),
#  ('[9, 2, 4, 6]', 1),
#  ('[1, 3, 8, 0]', 1),
#  ('[5, 10, 0]', 1),
#  ('[7, 9, 2, 6]', 1),
#  ('[7, 10, 5]', 1),
#  ('[5, 8, 1, 3]', 1),
#  ('[3, 5, 10, 1]', 1),
#  ('[8, 10, 1, 3]', 1),
#  ('[2, 5, 10, 0]', 1),
#  ('[8, 2, 5]', 1),
#  ('[3, 6, 11, 1]', 1),
#  ('[8, 0, 4]', 1),
#  ('[2, 5, 9, 10]', 1),
#  ('[8, 0, 1, 5]', 1),
#  ('[3, 8, 10, 1]', 1),
#  ('[6, 11, 6, 9]', 1),
#  ('[4, 7, 11, 5]', 1),
#  ('[5, 8, 2]', 1),
#  ('[10, 3, 5, 7]', 1),
#  ('[5, 7, 10, 0]', 1),
#  ('[4, 6, 11, 2]', 1),
#  ('[6, 10, 1, 5]', 1)]

# %% [markdown]
# chord without inversion

# %%
# def hchord_parser(chord, mode, key_offset):
#     if chord['sd'] == 'rest': return None

#     # extract basic info
#     sd = int(chord['sd']) - 1     # root
#     fb = chord['fb']              # tension & inversion
#     sec = chord['sec']            # secondary chord
#     borrowed = chord.get('borrowed', None)  # borrowed mode

#     # determine the mode
#     borrowed = is_int(borrowed)
#     chord_key = MODE_TO_KEY[int(mode)] if borrowed is None else borrowed
#     chord_key = 6 if chord_key > 6 else chord_key
#     chord_key = -6 if chord_key < -6 else chord_key

#     # secondary chord
#     sec_offset = 0
#     if sec:
#         # switch to 'sec' degree note within the current mode
#         scale = KEY_TO_SCALE[MODE_TO_KEY[int(mode)]]
#         new_key_note = scale[int(sec) - 1]

#         # set that note to new key
#         new_key = VAL_TO_NAME[new_key_note][0]

#         # get the key shift offset
#         sec_offset = NOTE_TO_OFFSET[new_key]
#         chord_key = 0

#     # determine the scale according to the key(mode) of the chord
#     scale = get_scale(chord_key)

#     # set compositional notes
#     comp, chord_type = set_compositions(scale, fb, sd)

#     # determine the quality by triads or seventh
#     # (9, 11, 13-th chords are seen as seventh)
#     comp_t = comp[0:3] if chord_type is 5 else comp[0:4]
#     quality = get_quality(comp_t)

#     # add shift from secondary chords
#     comp = (comp + sec_offset)

#     # set compvec (for sus/add/omit)
#     comp_vec = comp_to_compvec(comp)

#     # sus (omit 3)
#     sus = chord.get('sus', None)
#     comp_vec = set_sus(comp_vec, scale, sd, sus)

#     # emb (add/omit)
#     if 'emb' in chord:
#         emb = chord['emb']
#         comp_vec, alter_info, emb_info = set_emb(comp_vec, scale, sd, emb)
#     else:
#         emb_info = []
#         alter_info = []

#     # alter (won't change the quality)
#     alter_info = alter_info if len(alter_info) else chord.get('alternate']
#     comp_vec, alter_map = set_alter(comp_vec, alter_info)

#     # set inversion (won't change the root, but bass)
#     inv = get_num_inversion(fb)
#     comp_vec = set_inversion(comp_vec, inv)

#     # set result
#     comp = compvec_to_comp(comp_vec)
#     root = (comp[0] + 120) % 12   # for chord name
#     bass = np.nanmin(comp)         # for bass (real root)

#     data = OrderedDict([
#         # basic compositions
#         ('root', root),
#         ('bass', bass),
#         ('comp_vec', comp_vec),
#         ('composition', comp),

#         # basic info
#         ('quality', quality),
#         ('chord_type', chord_type),
#         ('chord_mode', chord_key),
        
#         # additional info
#         ('inv', inv),
#         ('sus', sus),
#         ('alter', alter_info),
#         ('emb', emb_info),
#         ('alter_map', alter_map),
#         ])

#     # key shifting of the symbol
#     data = chord_key_shifting(data, key_offset)

#     # set chord name
#     data['symbol'] = chord_to_string(data)
#     return data

# %%
VAL_TO_NAME = {
    1: 
}

# %%
def chord_to_string(data):
    base = to_name(data['root']) + data['quality']
    if data['quality'] in ['m', 'ø', 'o']:
        base = base.lower()
    base += ('' if data['chord_type'] is 5 else str(data['chord_type']))
    if data['inv']:
        base += (' | ' + to_name(data['bass']))
    if data['sus'] is not None:
        base += (' ' + data['sus'])
    if data['emb'] is not None:
        for e in data['emb']:
            base += ' (%s)' % e
    if data['alter'] is not None:
        for a in data['alter']:
            base += ' (%s)' % a
    return base
