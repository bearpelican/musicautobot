# %%
import xmltodict
import os
import json
import pickle
from lxml import etree

encoding = "utf-8"


def load_data(file_path):
    with open(file_path, "r", encoding=encoding) as f:
        content = f.read()
    content = content.replace('%20', '')
    return content


def xml_parser(content):
    parser = etree.XMLParser(recover=True, encoding=encoding)
    root = etree.fromstring(content, parser=parser)
    return root


def get_metadata(root):
    meta_list = ['title', 'beats_in_measure', 'BPM', 'key', 'YouTubeID', 'mode']

    metadata = dict()
    for e in meta_list:
        tag = root.find('.//' + e)
        metadata[e] = tag.text if tag is not None else None

    # duration
    tag = root.find('.//duration')
    tag = root.find('.//section_duration') if tag is None else tag
    metadata['duration'] = tag.text if tag is not None else None

    version = root.find('version')
    version = version.text if version is not None else None
    return metadata, version


def get_lead_sheet(root, version):
    segments_tag = root.findall('.//segment')

    # set chord tag according to version
    chord_tag = 'chords' if root.tag == 'super' else 'harmony'

    segment_list = []
    num_measures = 0

    for segment in segments_tag:
        num_measure = float(segment.find('numMeasures').text)

        # melody
        note_tags = segment.findall('.//notes/note')
        note_list = [xmltodict.parse(etree.tostring(n))['note'] for n in note_tags] if note_tags else []

        # chord
        chord_tags = segment.findall('.//' + chord_tag + '/chord')
        chord_list = [xmltodict.parse(etree.tostring(c))['chord'] for c in chord_tags] if chord_tags else []

        segment_list.append({'notes': note_list, 'chords': chord_list, 'num_measure': num_measure})
        num_measures += num_measure

    return segment_list, num_measures


def event_localization(measure_offset, start_beat_abs, duration):
    event_on = measure_offset + start_beat_abs
    event_off = measure_offset + start_beat_abs + duration
    return event_on, event_off


def proc_object(object_, measure_offset, type_=None):
    if type_ is 'note':
        duration = float(object_['note_length'])
        object_.pop('note_length')
    elif type_ is 'chord':
        duration = float(object_['chord_duration'])
        object_.pop('chord_duration')
    else:
        raise ValueError('Unknown object')

    event_on, event_off = event_localization(
        measure_offset,
        float(object_['start_beat_abs']),
        duration)

    # delete item
    object_.pop('start_measure')
    object_.pop('start_beat')
    object_.pop('start_beat_abs')

    # add item
    object_['event_on'] = event_on
    object_['event_off'] = event_off
    object_['event_duration'] = duration

    # change item
    object_['isRest'] = bool(int(object_['isRest']))

    return object_


def segments_parser(segments, mode, beats_in_measure):
    measure_counter = 0

    chord_track = []
    melody_track = []

    for sidx, segment in enumerate(segments):
        measure_offset = measure_counter * float(beats_in_measure)

        for chord in segment['chords']:
            chord_track.append(proc_object(chord, measure_offset, type_='chord'))
        for note in segment['notes']:
            melody_track.append(proc_object(note, measure_offset, type_='note'))

        measure_counter += int(segment['num_measure'])

    return melody_track, chord_track


def proc_xml(file_path, save_path=None, name='tab', save_type='pickle'):
    content = load_data(file_path)
    root = xml_parser(content)
    metadata, version = get_metadata(root)
    segments, num_measures = get_lead_sheet(root, version)

    mode = int(metadata['mode']) if metadata['mode'] is not None else 1
    beats_in_measure = int(metadata['beats_in_measure'])

    melody, chord = segments_parser(segments, mode, beats_in_measure)

    data = {
        'version': version,
        'metadata': metadata,
        'tracks': {
            'melody': melody,
            'chord': chord,
        },
        'num_measures': num_measures,
    }

    if save_path:
        if not os.path.exists(save_path):
            os.makedirs(save_path)

        if save_type is 'pickle':
            file_name = os.path.join(save_path, name+'.pickle')
            with open(file_name, 'wb') as handle:
                pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
        elif save_type is 'json':
            file_name = os.path.join(save_path, name+'.json')
            with open(file_name, 'w') as handle:
                json.dump(data, handle)
        else:
            raise ValueError('Unkown type for saving')

    return data


def traverse_dir(root_dir, extension='.xml'):
    file_list = []
    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith(extension):
                file_list.append(os.path.join(root, file))

    return file_list


def get_postfix_dirpath(filename, idx=-4):
    path = os.path.normpath(filename)
    dir_list = path.split(os.sep)
    new_path = ''

    for d in dir_list[idx:]:
        new_path = os.path.join(new_path, d)

    return new_path


def proc_dir(file_list, root):
    num_file = len(file_list)
    for fidx in range(num_file):
        print('(%d/%d)' % (fidx, num_file))
        file_path = file_list[fidx]
        save_path = root
        name = os.path.basename(file_path)
        proc_xml(file_path, save_path=save_path, name=name, save_type='json')

# %%
from pathlib import Path

# %%
version = 'v7'
data_path = Path('data/midi')
version_path = data_path/version
orig_path = version_path/'midi_sources'

# %%
from fastai.data_block import get_files

# %%
h_path = orig_path/'hooktheory'

# %%
files = get_files(h_path, extensions=['.xml'], recurse=True); files[:10]
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/what-a-day/kiefer/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/pre-chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/freedom/chorus.xml')]

# %%
# Loading from specific file
keywords = ['avicii', 'waiting']
def contains_keywords(f): return all([k in str(f) for k in keywords])
search = [f for f in files if contains_keywords(f)]; search
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/a/avicii/waiting-for-love/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/a/avicii/waiting-for-love/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/a/avicii/waiting-for-love/intro.xml')]

# %%
import pprint

file_path = search[0]
raw_info = proc_xml(file_path)
# pprint.pprint(raw_info)

# %%
content = load_data(file_path)
root = xml_parser(content)
metadata, version = get_metadata(root)
segments, num_measures = get_lead_sheet(root, version)

# %%
segments
# Out:
# [{'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '2.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '2.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')])],
#   'chords': [OrderedDict([('sd', 'rest'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '4'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '1')])],
#   'num_measure': 1.0},
#  {'notes': [OrderedDict([('start_beat_abs', '0'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '1'),
#                 ('start_measure', '1'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '1.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '2'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '3.5'),
#                 ('start_measure', '1'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '4.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '2'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '6'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '6.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '7.5'),
#                 ('start_measure', '2'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '8'),
#                 ('start_measure', '3'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '9'),
#                 ('start_measure', '3'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '9.5'),
#                 ('start_measure', '3'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '10'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '11'),
#                 ('start_measure', '3'),
#                 ('start_beat', '4'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '12.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '13'),
#                 ('start_measure', '4'),
#                 ('start_beat', '2'),
#                 ('note_length', '1'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '14'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '14.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '3.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '15.5'),
#                 ('start_measure', '4'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '16'),
#                 ('start_measure', '5'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '7'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '17'),
#                 ('start_measure', '5'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '17.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '18'),
#                 ('start_measure', '5'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', '1f'),
#                 ('octave', '1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '19'),
#                 ('start_measure', '5'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '19.5'),
#                 ('start_measure', '5'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '20'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '20.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '21'),
#                 ('start_measure', '6'),
#                 ('start_beat', '2'),
#                 ('note_length', '1'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '22'),
#                 ('start_measure', '6'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '23'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '1'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '23.5'),
#                 ('start_measure', '6'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '24'),
#                 ('start_measure', '7'),
#                 ('start_beat', '1'),
#                 ('note_length', '1'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '25'),
#                 ('start_measure', '7'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '25.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '26'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3'),
#                 ('note_length', '1'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')]),
#    OrderedDict([('start_beat_abs', '27'),
#                 ('start_measure', '7'),
#                 ('start_beat', '4'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '7'),
#                 ('octave', '-1'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '27.5'),
#                 ('start_measure', '7'),
#                 ('start_beat', '4.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '28'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '5'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '28.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1.5'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '4'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '29'),
#                 ('start_measure', '8'),
#                 ('start_beat', '2'),
#                 ('note_length', '0.5'),
#                 ('scale_degree', '3'),
#                 ('octave', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('start_beat_abs', '29.5'),
#                 ('start_measure', '8'),
#                 ('start_beat', '2.5'),
#                 ('note_length', '2.5'),
#                 ('scale_degree', 'rest'),
#                 ('octave', '0'),
#                 ('isRest', '1')])],
#   'chords': [OrderedDict([('sd', '1'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '1'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '0'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '0'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '1'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '2'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '6'),
#                 ('start_measure', '2'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '4'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus2'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '3'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '10'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '1'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '6'),
#                 ('start_measure', '4'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '12'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '5'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', '0'),
#                 ('chord_duration', '2'),
#                 ('start_measure', '5'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '18'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '6'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '6'),
#                 ('start_measure', '6'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '20'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '7'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', 'sus2'),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '7'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '26'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', '1'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '8'),
#                 ('start_beat', '1'),
#                 ('start_beat_abs', '28'),
#                 ('isRest', '0')]),
#    OrderedDict([('sd', 'rest'),
#                 ('fb', None),
#                 ('sec', None),
#                 ('sus', None),
#                 ('pedal', None),
#                 ('alternate', None),
#                 ('borrowed', None),
#                 ('chord_duration', '2'),
#                 ('start_measure', '8'),
#                 ('start_beat', '3'),
#                 ('start_beat_abs', '30'),
#                 ('isRest', '1')])],
#   'num_measure': 8.0}]

# %%
mode = int(metadata['mode']) if metadata['mode'] is not None else 1
beats_in_measure = int(metadata['beats_in_measure'])

melody, chord = segments_parser(segments, mode, beats_in_measure)

# %% [markdown]
# ### Create config file

# %%
config = dict(sustain=True, sep_octave=True)

# %% [markdown]
# ### Constants

# %%
# note to number
#

# %% [markdown]
# ### Classes

# %%
class Metadata():
    def __init__(self, bpm=None, beats_in_measure=None, key=None, mode=None, title=None, **kwargs):
        self.bpm,self.beats_in_measure,self.ke,self.mode,self.title = bpm,beats_in_measure,key,mode,title

# %%
class Note():
    def __init__(self, )
