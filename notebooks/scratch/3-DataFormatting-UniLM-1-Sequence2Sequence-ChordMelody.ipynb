# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')
from src.encode_data import *
from src.midi_data import *
from src.data_sources import process_all, arr2csv
from src.midi_transform import *
from src.fastai_data import *
from src.unilm import S2SFileProcessor, S2SPreloader, part_enc

# %%
import traceback
import time

# %% [markdown]
# ## Standardize and reformat raw midi files before encoding to text
# - Transform key to C major
# - Remove unused instruments
# - Combine multiple tracks with the same instrument into a single part
# - Melody, Piano, String

# %% [markdown]
# ### Load midi data

# %%
version = 'v17'
data_path = Path('data/midi')
version_path = data_path/version

# %%
import pandas as pd

# %%
# out_dir = 'midi_encode'
# duet_only = False
sf_path = f'sf{SAMPLE_FREQ}'
out_dir = Path(f'{sf_path}/s2s_encode')
duet_only = True

# %%
source_dir = 'midi_sources'
source_csv = version_path/'metadata'/f'{source_dir}.csv'
out_csv = version_path/out_dir/f'{out_dir.name}.csv'
out_csv.parent.mkdir(parents=True, exist_ok=True)
source_csv, out_csv
# Out:
# (PosixPath('data/midi/v17/metadata/midi_sources.csv'),
#  PosixPath('data/midi/v17/sf4/s2s_encode/s2s_encode.csv'))

# %%
# num_comps = 2 # note, duration
cutoff = 5 # max instruments
min_variation = 3 # minimum number of different midi notes played
# max_dur = 128

# %% [markdown]
# ### Encoding midi to numpy

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,4,7,9,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ht_time_signature  ht_offset  \
# 0                4.0        0.0
# 1                3.0        0.0
# 2                4.0       -5.0
# 3                4.0       -5.0
# 4                4.0       -5.0
#
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                      parts  ht_bpm                title  \
# 0             intro,chorus   128.0  yu-gi-oh-theme-song
# 1             intro,chorus    85.0  yu-gi-oh-theme-song
# 2                   chorus    96.0               kiefer
# 3  verse,pre-chorus,chorus   152.0         senbonzakura
# 4  verse,pre-chorus,chorus   152.0         senbonzakura
#
#                       midi_title        artist  \
# 0                      yu-gi-oh3  wayne-sharpe
# 1                       yu-gi-oh  wayne-sharpe
# 2                         kiefer    what-a-day
# 3  senbonzakura - pre-Pre-Chorus    whiteflame
# 4                   Senbonzakura    whiteflame
#
#                                             song_url     genres      source  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 1  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 2  https://www.hooktheory.com/theorytab/view/what...       Jazz  hooktheory
# 3  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
# 4  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
#
#   ht_key                               md5  mxl  ht_mode
# 0      C  bf1f29e5ff84e3e93e37fb873bfb590e  NaN      1.0
# 1      C  055f80ad67f64edb14a85ca8fbfe8c29  NaN      1.0
# 2      D  197f96f5d181f6ce1e2c5ab04ac1ff87  NaN      6.0
# 3      D  9e7ce13a35f1314423a9a6d5a5287a4a  NaN      6.0
# 4      D  d5aaf79d0989222f1362f9f46c540a27  NaN      6.0

# %%
all_records = df.to_dict(orient='records'); len(all_records)
# Out:
# 197182

# %%
def process_metadata(metadata):
    result = metadata.copy()
    
    # Part 1. Compress tracks/instruments
    if not isinstance(metadata.get('midi'), str): return None
    
    input_path = version_path/metadata['midi']
    extension = input_path.suffix.lower()
    if not input_path.exists(): 
        print('Input path does not exist:', input_path, metadata)
        return result
    
    # Get outfile and check if it exists
    out_file = Path(str(input_path).replace(f'/{source_dir}/', f'/{out_dir}/'))
    out_file = out_file.with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): 
        result['numpy'] = str(out_file.relative_to(version_path))
        return result
    
    npenc = transform_midi(input_path)
    if npenc is None: return result
    np.save(out_file, npenc)
    result['numpy'] = str(out_file.relative_to(version_path))
    return result

# %%
def transform_midi(midi_file):
    input_path = midi_file
    
    try: 
        if num_piano_tracks(input_path) not in [1, 2]: return None
        input_file = compress_midi_file(input_path, min_variation=min_variation, cutoff=cutoff) # remove non note tracks and standardize instruments
        if not input_file: return None
    except Exception as e:
        if 'badly form' in str(e): return None # ignore badly formatted midi errors
        if 'out of range' in str(e): return None # ignore badly formatted midi errors
        print('Error parsing midi', input_path, e)
        return None
        
    # Part 2. Compress rests and long notes
    stream = file2stream(input_file) # 1.
    try:
        chordarr = stream2chordarr(stream) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
    except Exception as e:
        print('Could not encode to chordarr:', input_path, e)
#         print(traceback.format_exc())
        return None
    
    chord_trim = trim_chordarr_rests(chordarr)
    chord_short = shorten_chordarr_rests(chord_trim)
    delta_trim = chord_trim.shape[0] - chord_short.shape[0]
#     if delta_trim > 300: 
#         print(f'Removed {delta_trim} rests from {input_path}. Skipping song')
#         return None
    chordarr = chord_short
    
    # Only 2 piano parts allowed
    _,num_parts,_ = chordarr.shape
    if num_parts != 2: return None
    
    # Individual parts must have notes
    parts = [part_enc(chordarr, i) for i in range(num_parts)]
    for p in parts: 
        if not is_valid_npenc(npenc, min_notes=8, input_path=input_path): return None
        
    # order by melody > chords
    p1, p2 = parts
    m, c = (p1, p2) if avg_pitch(p1) > avg_pitch(p2) else (p2, p1) # Assuming melody has higher pitch
    
    return np.array([m, c])

# %%
# transform_midi(piano_file)
midi_mxl_file = version_path/'midi_sources/from_mxl/musescore/data/49143.mid'
input_file = midi_mxl_file
stream = file2stream(input_file) # 1.
chordarr = stream2chordarr(stream)

# %%
chordarr.shape
# Out:
# (1021, 2, 128)

# %%
transform_midi(midi_mxl_file).shape
# Out:
# (2,)

# %%
def try_process_metadata(metadata):
    try:
        return process_metadata(metadata)
    except Exception:
#         print(traceback.format_exc())
        return None

# %%
# # sanity check
import random
for r in random.sample(all_records, 10):
    process_metadata(r)

# %%
def timeout_func(data, seconds):
    print("Timeout:", seconds, data.get('midi'))

# %%
processed = process_all(try_process_metadata, all_records, timeout=300, timeout_func=timeout_func)
# Out:
# Sequence too short: 6 data/midi/v17/midi_sources/hooktheory/pianoroll/w/willie-nelson/you-were-always-on-my-mind/verse_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/y/yasunori-mitsuda/black-omen/instrumental_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/y/yes/heart-of-the-sunrise/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/y/yo-la-tengo/ohm/verse_key_original.mid
# Sequence too short: 5 data/midi/v17/midi_sources/hooktheory/pianoroll/j/janet-jackson/nasty/intro_key_original.mid
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='139402' class='' max='197182', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.70% [139402/197182 41:34<17:13]
#     </div>
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/j/jose-gonzales/step-out/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/j/john-tesh/roundball-rock/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/j/jay-hardway---mike-hawkins/freedom/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/j/john-powell/how-to-train-your-dragon---test-drive/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/j/jon-lajoie/the-best-song/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/j/jon-foreman/white-as-snow/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/j/junya-nakano/passing-through-the-forest/intro_key_original.mid
# Sequence too short: 6 data/midi/v17/midi_sources/hooktheory/pianoroll/j/jon-foreman/june-and-johnny/intro-and-verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/j/john-martin/anywhere-for-you/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/g/game-freak/vs-silver/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/g/gabriel-gundacker/wii-snorkling/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/g/glenn-frey/the-heat-is-on/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/g/gizmondo-studios/sticky-balls-theme-song/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/g/grant-kirkhope/freezeezy-peak/verse_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/g/glaze/tough-luck/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/g/gustavo-santaolalla/the-last-of-us---theme/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/l/lim-kim/awoo/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/l/lynn-redgrave/while-im-still-young/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/l/lady-gaga/mary-jane-holland/intro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/l/lakme/flower-duet/intro_key_original.mid
# npenc exceeds max 161 duration: 272 data/midi/v17/midi_sources/hooktheory/pianoroll/l/la-roux/quicksand/bridge_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/v/village-people/ymca/pre-chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/l/lcd-soundsystem/dance-yrself-clean/solo-1_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/v/van-morrison/days-like-this/intro_key_original.mid
# Sequence too short: 5 data/midi/v17/midi_sources/hooktheory/pianoroll/f/fort-minor/welcome/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/b/boards-of-canada/dayvan-cowboy/instrumental_key_original.mid
# npenc exceeds max 161 duration: 216 data/midi/v17/midi_sources/hooktheory/pianoroll/b/biffy-clyro/all-the-way-down/pre-chorus-and-chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/b/big-wild/venice-venture/instrumental_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/b/baauer/harlem-shake/verse_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/b/ben-folds-five/kate/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/b/ben-prunty/faster-than-light---civil-battle/pre-chorus-and-chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/b/britney-spears/ooh-la-la/verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/b/britney-spears/break-the-ice/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/b/beyonce/single-ladies/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/b/bernstein/babel---hraach-remix/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/z/zun/a-world-of-nightmares-never-seen-before/bridge_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/z/zun/now-until-the-moment-you-die/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/z/zun/fall-of-fall---autumnal-waterfall/lead-in-alt_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/z/zun/the-wheelchairs-future-in-space/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/z/zun/eternal-shrine-maiden/outro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/z/zun/extend-ash---hourai-victim/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/d/daft-punk/the-grid/instrumental_key_original.mid
# npenc exceeds max 161 duration: 770 data/midi/v17/midi_sources/hooktheory/pianoroll/d/david-bowie/tvc15/verse-and-pre-chorus_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/d/driftless-pony-club/house-of-1982--built-like-a-ship/intro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/d/disasterpeace/compass/instrumental_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/s/stevie-wonder/sir-duke/solo_key_original.mid
# Sequence too short: 5 data/midi/v17/midi_sources/hooktheory/pianoroll/s/stevie-wonder/superstition/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/d/disasterpeace/adventure/verse_key_original.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/hooktheory/pianoroll/s/seba/never-let-you-go---blu-mar-ten-remix/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/s/schoolhouse-rock/my-hero-zero/verse_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/s/spice-girls/too-much/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/s/shiro-sagisu/evangelion---les-betes/solo_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/s/skrillex-and-wolfgang-gartner/the-devils-den/intro_key_original.mid
# npenc exceeds max 161 duration: 264 data/midi/v17/midi_sources/hooktheory/pianoroll/s/sega/space-harrier/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/s/seven-lions/below-us-feat-shaz-sparks/intro_key_original.mid
# npenc exceeds max 161 duration: 184 data/midi/v17/midi_sources/hooktheory/pianoroll/s/status-quo/whatever-you-want/intro-and-verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/s/skrillex/bangarang-feat-sirah/outro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/s/skrillex/breakn-a-sweat/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/s/say-anything/slowly-through-a-vector/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/s/say-anything/every-man-has-a-molly/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/s/steve-jablonsky/lone-survivor/verse_key_original.mid
# Sequence too short: 6 data/midi/v17/midi_sources/hooktheory/pianoroll/s/steely-dan/peg/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/c/coldplay/hurts-like-heaven/solo_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/c/childish-gambino/me-and-your-mama/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/c/c418/acid/verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/c/cysmix/aumetra-the-witch/intro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/c/creedence-clearwater-revival/born-on-the-bayou/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/c/capcom/okami---yami/intro-and-verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/c/clarian/castaway---henry-saiz-remix/chorus_key_original.mid
# npenc exceeds max 161 duration: 240 data/midi/v17/midi_sources/hooktheory/pianoroll/c/cardiacs/eat-it-up-worms-hero/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/e/exid/ddd/intro_key_original.mid
# Sequence too short: 6 data/midi/v17/midi_sources/hooktheory/pianoroll/e/elvis-presley/you-were-always-on-my-mind/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/n/noisestorm/sentinel/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/n/natalie-imbruglia/torn/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-lovers/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-downward-spiral/intro-and-verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nirvana/all-apologies/verse_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nirvana/all-apologies/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nintendo/donkey-kong/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nintendo/dark-matter/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nintendo/mario-kart-7---rainbow-road/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/n/nintendo/kirby-air-ride---machine-passage/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/i/inon-zur/fallout-4-intro/instrumental_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/i/ikke-huftgold/dicke-titten-kartoffelsalat/intro_key_original.mid
# npenc exceeds max 161 duration: 362 data/midi/v17/midi_sources/hooktheory/pianoroll/i/inxs/never-tear-us-apart/verse-and-pre-chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/i/ilan-bluestone-and-jerome-isma-ae/tension/pre-chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/h/homestuck/skies-of-skaia/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/h/homestuck/carbon-nadsat---cuestick-genius/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/h/homestuck/skies-of-skaia/chorus-lead-out_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/h/homestuck/gilded-sands/intro-and-verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/h/homestuck/three-in-the-morning/solo-2_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/h/homestuck/unite-synchronization/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/h/homestuck/vagabounce/bridge_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/p/paul-mccartney/sing-the-changes/intro_key_original.mid
# Sequence too short: 6 data/midi/v17/midi_sources/hooktheory/pianoroll/p/pet-shop-boys/you-were-always-on-my-mind/verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/p/pendulum/salt-in-the-wounds/instrumental_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/p/pendulum/blood-sugar/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/p/perry-como/catch-a-falling-star/intro-and-verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/p/pendulum/salt-in-the-wounds/verse_key_original.mid
# npenc exceeds max 161 duration: 288 data/midi/v17/midi_sources/hooktheory/pianoroll/p/penguin-cafe-orchestra/perpetuum-mobile/instrumental_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/p/peter-paul-and-mary/i-dig-rock-and-roll-music/verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/p/paris-hilton/my-bff/intro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/t/tina-turner/river-deep---mountain-high/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-flaming-lips/psychiatric-exploration-of-the-fetus-with-needles/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/t/this-town-needs-guns/zebra/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-temptations/my-girl/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/t/this-town-needs-guns/havoc-in-the-forum/intro-and-verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/t/toby-fox/his-theme/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-rembrants/ill-be-there-for-you/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/t/tool/schism/chorus_key_original.mid
# Sequence too short: 5 data/midi/v17/midi_sources/hooktheory/pianoroll/t/tupac/changes/outro-2_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-shins/caring-is-creepy/chorus-lead-out_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-stone-roses/waterfall/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/t/taylor-swift/state-of-grace/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/t/taylor-swift/state-of-grace/pre-chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/t/taylor-swift/look-what-you-made-me-do/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/t/tay-zonday/chocolate-rain/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/t/traditional/frere-jacque/chorus_key_original.mid
# npenc exceeds max 161 duration: 316 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-script/you-wont-feel-a-thing/intro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/t/tyler-the-creator/ifhy/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-crystal-method/starting-over/verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-pussycat-dolls/buttons/chorus_key_original.mid
# Sequence too short: 5 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-dispatch/how-deep-the-fathers-love-for-us/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-supremes/the-happening/verse_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-beatles/if-i-needed-someone/intro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-beatles/ticket-to-ride/outro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-lorax/let-it-grow/intro_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/t/the-beatles/you-cant-do-that/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/o/outkast/hey-ya/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/o/odd-future/analog-2/instrumental_key_original.mid
# Sequence too short: 5 data/midi/v17/midi_sources/hooktheory/pianoroll/k/koji-kondo/delfino-plaza/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/k/king-gizzard-and-the-lizard-wizard/gamma-knife/verse_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/k/king-gizzard-and-the-lizard-wizard/im-in-your-mind/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/k/koji-kondo/super-mario-bros-3---hammer-bros-battle-theme/intro_key_original.mid
# npenc exceeds max 161 duration: 177 data/midi/v17/midi_sources/hooktheory/pianoroll/k/kanye-west/ultralight-beam/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/k/konami/gradius-ii---take-care/instrumental_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/k/kyle-richards/terminal-velocity---ymir-theme/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/k/kshmr/kolkata/chorus_key_original.mid
# Sequence too short: 6 data/midi/v17/midi_sources/hooktheory/pianoroll/k/kendrick-lamar/alright/pre-chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/r/royksopp/what-else-is-there/instrumental_key_original.mid
# npenc exceeds max 161 duration: 218 data/midi/v17/midi_sources/hooktheory/pianoroll/m/mitch-murder/megamagic-theme/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/m/max-cooper/autumn-haze/chorus_key_original.mid
# Sequence too short: 4 data/midi/v17/midi_sources/hooktheory/pianoroll/m/madeon/imperium/solo_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/m/my-bloody-valentine/to-here-knows-when/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/m/madonna/bitch-im-madonna/instrumental_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/m/massive-attack/dissolved-girl/intro-and-verse_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/m/microsoft/windows-xp-startup-sound/instrumental_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/m/meghan-trainor/no/pre-chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/m/masashi-hamauzu/battle-results/pre-chorus-and-chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/a/a-lovely-war/autumn-leaves-us-blue/intro_key_original.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/hooktheory/pianoroll/a/american-football/never-meant/intro_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/a/avicii-vs-nicky-romero/i-could-be-the-one/intro_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/a/analogik/menu-theme---battleblock-theater/verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/a/armin-van-buuren-sharon/in-and-out-of-love/instrumental_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/a/augustines/cruel-city/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/a/animusic/starship-groove/chorus_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/a/animusic/aqua-harp/chorus_key_original.mid
# Sequence too short: 7 data/midi/v17/midi_sources/hooktheory/pianoroll/a/animusic/pogo-sticks/verse_key_original.mid
# Sequence too short: 3 data/midi/v17/midi_sources/hooktheory/pianoroll/a/alabama-shakes/hold-on/intro_key_original.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/hooktheory/pianoroll/a/animal-collective/for-reverend-green/intro-and-verse_key_original.mid
# npenc exceeds max 161 duration: 258 data/midi/v17/midi_sources/freemidi/genre-dance-eletric/Chemical Brothers - Loops Of Furry.mid
# npenc exceeds max 161 duration: 260 data/midi/v17/midi_sources/freemidi/genre-dance-eletric/Scooter - Last Minute.mid
# npenc exceeds max 161 duration: 264 data/midi/v17/midi_sources/freemidi/genre-dance-eletric/Kylie Minogue - Spinning Around.mid
# npenc exceeds max 161 duration: 690 data/midi/v17/midi_sources/freemidi/genre-dance-eletric/Scooter - How Much Is The Fish.mid
# npenc exceeds max 161 duration: 424 data/midi/v17/midi_sources/freemidi/genre-pop/Kinks - Fancy.mid
# npenc exceeds max 161 duration: 1100 data/midi/v17/midi_sources/freemidi/genre-pop/Toni Braxton - Another Sad Love Song.mid
# npenc exceeds max 161 duration: 1432 data/midi/v17/midi_sources/freemidi/genre-pop/Pat Benatar - Benatar Medley.mid
# npenc exceeds max 161 duration: 236 data/midi/v17/midi_sources/freemidi/genre-pop/OneRepublic - Love Runs Out.mid
# npenc exceeds max 161 duration: 219 data/midi/v17/midi_sources/freemidi/genre-pop/Delta Goodrem - Lost Without You.mid
# npenc exceeds max 161 duration: 388 data/midi/v17/midi_sources/freemidi/genre-pop/Romantics - What I Like About You.mid
# npenc exceeds max 161 duration: 238 data/midi/v17/midi_sources/freemidi/genre-pop/R.E.M. - Ignoreland.mid
# npenc exceeds max 161 duration: 280 data/midi/v17/midi_sources/freemidi/genre-pop/Sade - Siempre Hay Esperanza.mid
# npenc exceeds max 161 duration: 272 data/midi/v17/midi_sources/freemidi/genre-pop/Sade - Siempre Hay Esperanza.mid
# npenc exceeds max 161 duration: 324 data/midi/v17/midi_sources/freemidi/genre-pop/Ace of Base - Beautiful Life.mid
# npenc exceeds max 161 duration: 329 data/midi/v17/midi_sources/freemidi/genre-pop/98 Degrees - The Hardest Thing.mid
# npenc exceeds max 161 duration: 832 data/midi/v17/midi_sources/freemidi/genre-pop/98 Degrees - The Hardest Thing.mid
# npenc exceeds max 161 duration: 416 data/midi/v17/midi_sources/freemidi/genre-pop/R.E.M. - Orange Crush.mid
# Error parsing midi data/midi/v17/midi_sources/freemidi/genre-pop/PSY - gangnam style KILLYURSLEF.mid ord() expected string of length 1, but int found
# npenc exceeds max 161 duration: 1234 data/midi/v17/midi_sources/freemidi/genre-pop/Gin Blossoms - Follow You Down.mid
# npenc exceeds max 161 duration: 325 data/midi/v17/midi_sources/freemidi/genre-pop/Geoff Moore - Said And Done.mid
# npenc exceeds max 161 duration: 193 data/midi/v17/midi_sources/freemidi/genre-pop/Jay-Z - Run This Town.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/midiworld/named_midi/Bad_English_-_When_I_See_You_Smile.mid
# npenc exceeds max 161 duration: 456 data/midi/v17/midi_sources/midiworld/named_midi/Led_Zeppelin_-_Bonzo's_Montreux.mid
# Error parsing midi data/midi/v17/midi_sources/midiworld/named_midi/Nirvana_-_Drain_You.mid cannot handle ticks per frame: 77
# npenc exceeds max 161 duration: 2562 data/midi/v17/midi_sources/midiworld/named_midi/Animenz_-_This_game_by_Animenz_in_C_piano.mid
# npenc exceeds max 161 duration: 257 data/midi/v17/midi_sources/midiworld/named_midi/Notorious_BIG_-_Notorious_Thugs.mid
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/midiworld/named_midi/Notorious_BIG_-_Notorious_Thugs.mid
# npenc exceeds max 161 duration: 2562 data/midi/v17/midi_sources/midiworld/named_midi/Animenz_-_This_game_by_Animez_in_C_piano.mid
# npenc exceeds max 161 duration: 2562 data/midi/v17/midi_sources/midiworld/named_midi/Animenz_-_This_Game_OP_Piano_In_C_.mid
# npenc exceeds max 161 duration: 184 data/midi/v17/midi_sources/midiworld/named_midi/Tavares_-_Heaven_Must_Be_Missing.mid
# npenc exceeds max 161 duration: 3697 data/midi/v17/midi_sources/midiworld/named_midi/Emerson_Lake_and_Palmer_-_Karn_Evil.mid
# npenc exceeds max 161 duration: 336 data/midi/v17/midi_sources/midiworld/named_midi/Genesis_-_Misunderstanding.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Play_3_Times.mid
# npenc exceeds max 161 duration: 450 data/midi/v17/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Crystal_Gym_Play_3_Times.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/midiworld/named_midi/John_Mellencamp_-_Lonely_Ol'_Night.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Piano_Cover.mid
# npenc exceeds max 161 duration: 212 data/midi/v17/midi_sources/from_mxl/ecomp/2017/SirajA01.mid
# npenc exceeds max 161 duration: 2562 data/midi/v17/midi_sources/midiworld/named_midi/Animenz_-_This_game_OP_Animenz_In_C.mid
# npenc exceeds max 161 duration: 208 data/midi/v17/midi_sources/from_mxl/ecomp/2017/KabuliL01.mid
# npenc exceeds max 161 duration: 205 data/midi/v17/midi_sources/from_mxl/ecomp/2017/GuoE02.mid
# npenc exceeds max 161 duration: 223 data/midi/v17/midi_sources/from_mxl/ecomp/2017/GuoE02.mid
# npenc exceeds max 161 duration: 304 data/midi/v17/midi_sources/from_mxl/ecomp/2017/WangH03.mid
# npenc exceeds max 161 duration: 237 data/midi/v17/midi_sources/from_mxl/ecomp/2017/WangH03.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2017/YuP03.mid
# npenc exceeds max 161 duration: 244 data/midi/v17/midi_sources/from_mxl/ecomp/2017/CaoJ04.mid
# npenc exceeds max 161 duration: 180 data/midi/v17/midi_sources/from_mxl/ecomp/2017/TuanS02.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/ecomp/2017/TuanS02.mid
# npenc exceeds max 161 duration: 167 data/midi/v17/midi_sources/from_mxl/ecomp/2017/GuoE03.mid
# npenc exceeds max 161 duration: 200 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Song01.mid
# npenc exceeds max 161 duration: 248 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Song01.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Woo03.mid
# npenc exceeds max 161 duration: 172 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Lisiecki07.mid
# npenc exceeds max 161 duration: 260 data/midi/v17/midi_sources/from_mxl/ecomp/2008/ZhangH06.mid
# npenc exceeds max 161 duration: 532 data/midi/v17/midi_sources/from_mxl/ecomp/2008/ZhangH06.mid
# npenc exceeds max 161 duration: 244 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Nedayvoda01.mid
# npenc exceeds max 161 duration: 238 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Ladid03.mid
# npenc exceeds max 161 duration: 170 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Duepree05.mid
# npenc exceeds max 161 duration: 231 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Nikiforov03.mid
# npenc exceeds max 161 duration: 184 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Kochetkova02.mid
# npenc exceeds max 161 duration: 242 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Lisiecki15.mid
# npenc exceeds max 161 duration: 194 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Lin16.mid
# npenc exceeds max 161 duration: 181 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Sun03.mid
# npenc exceeds max 161 duration: 450 data/midi/v17/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Gym_Piano_Cover.mid
# npenc exceeds max 161 duration: 204 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Huang08.mid
# npenc exceeds max 161 duration: 280 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Nikiforov11.mid
# npenc exceeds max 161 duration: 181 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Lin15.mid
# npenc exceeds max 161 duration: 264 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Tuncali01.mid
# npenc exceeds max 161 duration: 327 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Tuncali01.mid
# npenc exceeds max 161 duration: 169 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Katyukova01.mid
# npenc exceeds max 161 duration: 200 data/midi/v17/midi_sources/from_mxl/ecomp/2008/ZhangH03.mid
# npenc exceeds max 161 duration: 165 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Arciglione11.mid
# npenc exceeds max 161 duration: 167 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Shelest01.mid
# npenc exceeds max 161 duration: 199 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Izzard03.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Bach01.mid
# npenc exceeds max 161 duration: 244 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Han01.mid
# npenc exceeds max 161 duration: 182 data/midi/v17/midi_sources/from_mxl/ecomp/2008/Duepree01.mid
# npenc exceeds max 161 duration: 175 data/midi/v17/midi_sources/from_mxl/ecomp/2006/ChenC02.mid
# npenc exceeds max 161 duration: 188 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Cai03.mid
# npenc exceeds max 161 duration: 195 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Yarden06.mid
# npenc exceeds max 161 duration: 201 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Shen06.mid
# npenc exceeds max 161 duration: 298 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Yarden10.mid
# npenc exceeds max 161 duration: 296 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Yarden01.mid
# npenc exceeds max 161 duration: 327 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Yarden01.mid
# npenc exceeds max 161 duration: 167 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Mordvinov08.mid
# npenc exceeds max 161 duration: 179 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Schneider03.mid
# npenc exceeds max 161 duration: 300 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Mordvinov02.mid
# npenc exceeds max 161 duration: 404 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Goldberg03.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Day03.mid
# npenc exceeds max 161 duration: 170 data/midi/v17/midi_sources/from_mxl/ecomp/2006/DeTurck07.mid
# npenc exceeds max 161 duration: 240 data/midi/v17/midi_sources/from_mxl/ecomp/2004/SOLOM02.mid
# npenc exceeds max 161 duration: 204 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Shybayeva03.mid
# npenc exceeds max 161 duration: 175 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Huangci02.mid
# npenc exceeds max 161 duration: 236 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Shybayeva04.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/from_mxl/ecomp/2006/WongDoe05.mid
# npenc exceeds max 161 duration: 187 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Cai01.mid
# npenc exceeds max 161 duration: 274 data/midi/v17/midi_sources/from_mxl/ecomp/2004/HONG01.mid
# npenc exceeds max 161 duration: 292 data/midi/v17/midi_sources/from_mxl/ecomp/2004/HONG01.mid
# npenc exceeds max 161 duration: 198 data/midi/v17/midi_sources/from_mxl/ecomp/2004/LUO03.mid
# npenc exceeds max 161 duration: 212 data/midi/v17/midi_sources/from_mxl/ecomp/2004/RAN03.mid
# npenc exceeds max 161 duration: 298 data/midi/v17/midi_sources/from_mxl/ecomp/2004/YOO09.mid
# npenc exceeds max 161 duration: 200 data/midi/v17/midi_sources/from_mxl/ecomp/2006/Larionova04.mid
# npenc exceeds max 161 duration: 195 data/midi/v17/midi_sources/from_mxl/ecomp/2004/BLINOV02.mid
# npenc exceeds max 161 duration: 195 data/midi/v17/midi_sources/from_mxl/ecomp/2004/ZHOU03.mid
# npenc exceeds max 161 duration: 172 data/midi/v17/midi_sources/from_mxl/ecomp/2004/KARYAG01.mid
# npenc exceeds max 161 duration: 174 data/midi/v17/midi_sources/from_mxl/ecomp/2009/ChenL04.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2004/LUO02.mid
# npenc exceeds max 161 duration: 168 data/midi/v17/midi_sources/from_mxl/ecomp/2004/RAN08.mid
# npenc exceeds max 161 duration: 262 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Yeletskiy04.mid
# npenc exceeds max 161 duration: 220 data/midi/v17/midi_sources/from_mxl/ecomp/2004/KIM_W03.mid
# npenc exceeds max 161 duration: 205 data/midi/v17/midi_sources/from_mxl/ecomp/2009/CaiC03.mid
# npenc exceeds max 161 duration: 162 data/midi/v17/midi_sources/from_mxl/ecomp/2004/YOO06.mid
# npenc exceeds max 161 duration: 277 data/midi/v17/midi_sources/from_mxl/ecomp/2004/YOO06.mid
# npenc exceeds max 161 duration: 411 data/midi/v17/midi_sources/from_mxl/ecomp/2004/UENO03.mid
# npenc exceeds max 161 duration: 250 data/midi/v17/midi_sources/from_mxl/ecomp/2004/UENO03.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/from_mxl/ecomp/2009/WongDoe02.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Gintov01.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_50_Times.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Albright02.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Staupe03.mid
# npenc exceeds max 161 duration: 196 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Toscano01.mid
# npenc exceeds max 161 duration: 287 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Lajko04.mid
# npenc exceeds max 161 duration: 287 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Albright01.mid
# npenc exceeds max 161 duration: 179 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Taverna01.mid
# npenc exceeds max 161 duration: 260 data/midi/v17/midi_sources/from_mxl/ecomp/2004/YOO07.mid
# npenc exceeds max 161 duration: 243 data/midi/v17/midi_sources/from_mxl/ecomp/2004/USHIKI05.mid
# npenc exceeds max 161 duration: 231 data/midi/v17/midi_sources/from_mxl/ecomp/2004/SHYBAY03.mid
# npenc exceeds max 161 duration: 237 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Uiasiuk02.mid
# Timeout: 300 midi_sources/midiworld/named_midi/OFMG_-_.mid
# npenc exceeds max 161 duration: 234 data/midi/v17/midi_sources/from_mxl/ecomp/2004/BLINOV06.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Gasanov10.mid
# npenc exceeds max 161 duration: 177 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Gasanov10.mid
# npenc exceeds max 161 duration: 184 data/midi/v17/midi_sources/from_mxl/ecomp/2014/MustakimovT01.mid
# npenc exceeds max 161 duration: 201 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Jia04.mid
# npenc exceeds max 161 duration: 234 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Wilshire03.mid
# npenc exceeds max 161 duration: 221 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Staupe10.mid
# npenc exceeds max 161 duration: 168 data/midi/v17/midi_sources/from_mxl/ecomp/2014/KimHJ08.mid
# npenc exceeds max 161 duration: 273 data/midi/v17/midi_sources/from_mxl/ecomp/2014/GarritsonL05.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/ecomp/2014/WangY09.mid
# npenc exceeds max 161 duration: 313 data/midi/v17/midi_sources/from_mxl/ecomp/2014/ChernovA21.mid
# npenc exceeds max 161 duration: 179 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Ahn03.mid
# npenc exceeds max 161 duration: 180 data/midi/v17/midi_sources/from_mxl/ecomp/2014/ShevchenkoO06.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2014/MaximovI07.mid
# npenc exceeds max 161 duration: 167 data/midi/v17/midi_sources/from_mxl/ecomp/2014/LiuY10.mid
# npenc exceeds max 161 duration: 191 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Gryaznov08.mid
# npenc exceeds max 161 duration: 232 data/midi/v17/midi_sources/from_mxl/ecomp/2014/ParkJH16.mid
# Timeout: 300 midi_sources/from_mxl/ecomp/2017/KaiRuiR08.mid
# npenc exceeds max 161 duration: 197 data/midi/v17/midi_sources/from_mxl/ecomp/2014/PrjevalskayaM16.mid
# npenc exceeds max 161 duration: 248 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LiYZ09.mid
# npenc exceeds max 161 duration: 175 data/midi/v17/midi_sources/from_mxl/ecomp/2014/KharselM01.mid
# npenc exceeds max 161 duration: 207 data/midi/v17/midi_sources/from_mxl/ecomp/2014/HamSY07.mid
# npenc exceeds max 161 duration: 253 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Jia03.mid
# npenc exceeds max 161 duration: 238 data/midi/v17/midi_sources/from_mxl/ecomp/2015/WuuE11.mid
# npenc exceeds max 161 duration: 244 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LuM06.mid
# npenc exceeds max 161 duration: 168 data/midi/v17/midi_sources/from_mxl/ecomp/2015/ChenW01.mid
# npenc exceeds max 161 duration: 1298 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LuoJ11.mid
# npenc exceeds max 161 duration: 239 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Sekino13.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LeeN05.mid
# npenc exceeds max 161 duration: 248 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LiYZ08.mid
# npenc exceeds max 161 duration: 272 data/midi/v17/midi_sources/from_mxl/ecomp/2009/JIa05.mid
# npenc exceeds max 161 duration: 180 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LiYZ04.mid
# npenc exceeds max 161 duration: 244 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LiYZ04.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/from_mxl/ecomp/2015/LuM04.mid
# npenc exceeds max 161 duration: 168 data/midi/v17/midi_sources/from_mxl/ecomp/2015/JeonH05.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Lou04.mid
# npenc exceeds max 161 duration: 182 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Lou04.mid
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Rizikov02.mid
# npenc exceeds max 161 duration: 204 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Rizikov02.mid
# npenc exceeds max 161 duration: 211 data/midi/v17/midi_sources/from_mxl/ecomp/2009/Sekino04.mid
# npenc exceeds max 161 duration: 188 data/midi/v17/midi_sources/from_mxl/ecomp/2015/RichardsonC07.mid
# npenc exceeds max 161 duration: 200 data/midi/v17/midi_sources/from_mxl/ecomp/2014/KimHJ05.mid
# npenc exceeds max 161 duration: 172 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Zhou05.mid
# npenc exceeds max 161 duration: 172 data/midi/v17/midi_sources/from_mxl/ecomp/2014/KimHJ06.mid
# npenc exceeds max 161 duration: 182 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Lin04.mid
# npenc exceeds max 161 duration: 195 data/midi/v17/midi_sources/from_mxl/ecomp/2014/LiuY05.mid
# npenc exceeds max 161 duration: 188 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Song02.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Guo03.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Teo02.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/ecomp/2014/JohannsonP16.mid
# npenc exceeds max 161 duration: 338 data/midi/v17/midi_sources/from_mxl/ecomp/2013/Knoll06.mid
# npenc exceeds max 161 duration: 520 data/midi/v17/midi_sources/from_mxl/ecomp/2013/Knoll06.mid
# npenc exceeds max 161 duration: 229 data/midi/v17/midi_sources/from_mxl/ecomp/2013/Yang09.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Mizumoto06.mid
# npenc exceeds max 161 duration: 164 data/midi/v17/midi_sources/from_mxl/ecomp/2013/Wong02.mid
# npenc exceeds max 161 duration: 204 data/midi/v17/midi_sources/from_mxl/ecomp/2002/hireche01.mid
# npenc exceeds max 161 duration: 223 data/midi/v17/midi_sources/from_mxl/ecomp/2013/YeF04.mid
# npenc exceeds max 161 duration: 171 data/midi/v17/midi_sources/from_mxl/ecomp/2014/WangY08.mid
# npenc exceeds max 161 duration: 238 data/midi/v17/midi_sources/from_mxl/ecomp/2014/ChernovA20.mid
# npenc exceeds max 161 duration: 196 data/midi/v17/midi_sources/from_mxl/ecomp/2011/Teo12.mid
# npenc exceeds max 161 duration: 222 data/midi/v17/midi_sources/from_mxl/ecomp/2018/FaB10.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/from_mxl/ecomp/2002/mamriev05.mid
# npenc exceeds max 161 duration: 320 data/midi/v17/midi_sources/from_mxl/ecomp/2002/mamriev03.mid
# npenc exceeds max 161 duration: 189 data/midi/v17/midi_sources/from_mxl/ecomp/2013/Lu07.mid
# npenc exceeds max 161 duration: 163 data/midi/v17/midi_sources/from_mxl/ecomp/2013/Mo12.mid
# npenc exceeds max 161 duration: 187 data/midi/v17/midi_sources/from_mxl/ecomp/2018/KiselevaD02.mid
# npenc exceeds max 161 duration: 186 data/midi/v17/midi_sources/from_mxl/ecomp/2018/KanM07.mid
# npenc exceeds max 161 duration: 247 data/midi/v17/midi_sources/from_mxl/ecomp/2018/LeeS10.mid
# npenc exceeds max 161 duration: 168 data/midi/v17/midi_sources/from_mxl/ecomp/2002/morozov02.mid
# npenc exceeds max 161 duration: 272 data/midi/v17/midi_sources/cprato/Frontliner & Wasted Penguinz - T.M.M.O.  (midi by Carlo Prato) (www.cprato.com).mid
# npenc exceeds max 161 duration: 384 data/midi/v17/midi_sources/cprato/Galimatias - Noelle's Eloquence  (midi by Carlo Prato) (www.cprato.com).mid
# npenc exceeds max 161 duration: 170 data/midi/v17/midi_sources/cprato/Madeon - Icarus  (midi by Carlo Prato) (www.cprato.com).mid
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/cprato/Blank Banshee - Frozen Flame  (midi by Carlo Prato) (www.cprato.com).mid
# npenc exceeds max 161 duration: 512 data/midi/v17/midi_sources/cprato/Kaaris - Chargé (Mr. Carmack Remix) (midi by Carlo Prato) (www.cprato.com).mid
# npenc exceeds max 161 duration: 234 data/midi/v17/midi_sources/from_mxl/classic_piano/liz_et4_format0.mid
# npenc exceeds max 161 duration: 310 data/midi/v17/midi_sources/from_mxl/ecomp/2018/KotysV11.mid
# npenc exceeds max 161 duration: 390 data/midi/v17/midi_sources/from_mxl/classic_piano/scn16_1_format0.mid
# npenc exceeds max 161 duration: 193 data/midi/v17/midi_sources/from_mxl/classic_piano/debussy_cc_1_format0.mid
# npenc exceeds max 161 duration: 168 data/midi/v17/midi_sources/from_mxl/classic_piano/liz_rhap15_format0.mid
# npenc exceeds max 161 duration: 205 data/midi/v17/midi_sources/from_mxl/classic_piano/alb_se5_format0.mid
# npenc exceeds max 161 duration: 288 data/midi/v17/midi_sources/from_mxl/classic_piano/muss_7_format0.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/from_mxl/ecomp/2018/AbdelmoulaJS10.mid
# npenc exceeds max 161 duration: 184 data/midi/v17/midi_sources/from_mxl/ecomp/2002/mamriev01.mid
# npenc exceeds max 161 duration: 208 data/midi/v17/midi_sources/from_mxl/classic_piano/appass_3_format0.mid
# npenc exceeds max 161 duration: 161 data/midi/v17/midi_sources/from_mxl/classic_piano/fruehlingsrauschen_format0.mid
# npenc exceeds max 161 duration: 217 data/midi/v17/midi_sources/from_mxl/ecomp/2018/LeeS01.mid
# npenc exceeds max 161 duration: 231 data/midi/v17/midi_sources/from_mxl/classic_piano/appass_1_format0.mid
# npenc exceeds max 161 duration: 384 data/midi/v17/midi_sources/from_mxl/classical_archives/021/bl109_08.mid
# npenc exceeds max 161 duration: 257 data/midi/v17/midi_sources/from_mxl/classical_archives/021/bl109_08.mid
# npenc exceeds max 161 duration: 176 data/midi/v17/midi_sources/from_mxl/classical_archives/021/kv_397.mid
# npenc exceeds max 161 duration: 408 data/midi/v17/midi_sources/from_mxl/classical_archives/4/grostemp.mid
# npenc exceeds max 161 duration: 230 data/midi/v17/midi_sources/from_mxl/classical_archives/4/rvsoninf.mid
# npenc exceeds max 161 duration: 254 data/midi/v17/midi_sources/from_mxl/classical_archives/023/inconclu.mid
# npenc exceeds max 161 duration: 732 data/midi/v17/midi_sources/from_mxl/classical_archives/024/htsminue.mid
# npenc exceeds max 161 duration: 632 data/midi/v17/midi_sources/from_mxl/classical_archives/024/htsminue.mid
# npenc exceeds max 161 duration: 162 data/midi/v17/midi_sources/from_mxl/classical_archives/023/kv_475.mid
# npenc exceeds max 161 duration: 196 data/midi/v17/midi_sources/from_mxl/classical_archives/022/forgtn3.mid
# npenc exceeds max 161 duration: 216 data/midi/v17/midi_sources/from_mxl/classical_archives/6/bepthtq3.mid
# npenc exceeds max 161 duration: 276 data/midi/v17/midi_sources/from_mxl/classical_archives/023/moz_300e.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/classical_archives/prs/CPE_Bach_Solfeggietto.mid
# npenc exceeds max 161 duration: 174 data/midi/v17/midi_sources/from_mxl/classical_archives/6/besntina.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/classical_archives/6/tocba.mid
# Sequence too short: 4 data/midi/v17/midi_sources/from_mxl/classical_archives/0/azbwv999.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/classical_archives/0/solfgeto.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/classical_archives/012/cpe_solf.mid
# npenc exceeds max 161 duration: 172 data/midi/v17/midi_sources/from_mxl/classical_archives/0/bcpe554a.mid
# npenc exceeds max 161 duration: 732 data/midi/v17/midi_sources/from_mxl/classical_archives/012/htsminue.mid
# npenc exceeds max 161 duration: 632 data/midi/v17/midi_sources/from_mxl/classical_archives/012/htsminue.mid
# npenc exceeds max 161 duration: 278 data/midi/v17/midi_sources/from_mxl/classical_archives/0/mussson1.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/classical_archives/0/hmoonl3.mid
# npenc exceeds max 161 duration: 191 data/midi/v17/midi_sources/from_mxl/classical_archives/6/benedict.mid
# npenc exceeds max 161 duration: 171 data/midi/v17/midi_sources/from_mxl/classical_archives/6/benedict.mid
# Sequence too short: 3 data/midi/v17/midi_sources/from_mxl/classical_archives/011/cramern3.mid
# npenc exceeds max 161 duration: 167 data/midi/v17/midi_sources/from_mxl/classical_archives/0/obermann.mid
# npenc exceeds max 161 duration: 192 data/midi/v17/midi_sources/from_mxl/classical_archives/free/cpe_bach_solfeggietto.mid
# npenc exceeds max 161 duration: 193 data/midi/v17/midi_sources/from_mxl/classical_archives/013/doctor.mid
# npenc exceeds max 161 duration: 983 data/midi/v17/midi_sources/from_mxl/classical_archives/011/bk_arp22.mid
# npenc exceeds max 161 duration: 193 data/midi/v17/midi_sources/from_mxl/classical_archives/013/estudi-6.mid
# npenc exceeds max 161 duration: 163 data/midi/v17/midi_sources/from_mxl/classical_archives/013/syss1353.mid
# npenc exceeds max 161 duration: 252 data/midi/v17/midi_sources/from_mxl/classical_archives/013/beethove.mid
# npenc exceeds max 161 duration: 182 data/midi/v17/midi_sources/from_mxl/classical_archives/4/lisztmef.mid
# npenc exceeds max 161 duration: 308 data/midi/v17/midi_sources/from_mxl/classical_archives/013/estudio.mid
# npenc exceeds max 161 duration: 466 data/midi/v17/midi_sources/from_mxl/classical_archives/5/scad345.mid
# npenc exceeds max 161 duration: 180 data/midi/v17/midi_sources/from_mxl/classical_archives/021/lisztson.mid
# npenc exceeds max 161 duration: 204 data/midi/v17/midi_sources/from_mxl/classical_archives/3/chfntimp.mid
# Sequence too short: 7 data/midi/v17/midi_sources/from_mxl/classical_archives/014/cn337_07.mid
# ...
# npenc exceeds max 161 duration: 184 data/midi/v17/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Mendelsonn/Fantaisie and Fugue.mid
# npenc exceeds max 161 duration: 165 data/midi/v17/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Classical Piano Midis/Liszt/Mephisto Waltz Mov.1.mid
# npenc exceeds max 161 duration: 720 data/midi/v17/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Mendelsonn/Ostinato.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/Classical_Guitar_classicalguitarmidi.com_MIDIRip/Pernambuco_Brasileirinho.mid ord() expected string of length 1, but int found
# npenc exceeds max 161 duration: 188 data/midi/v17/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Classical Piano Midis/Chaminade/Concertino for Flute and Piano.mid
# Timeout: 300 midi_sources/130k_reddit/M/M/mthm26b.mid
# npenc exceeds max 161 duration: 901 data/midi/v17/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Mendelsonn/Variations serieuses op54.mid
# npenc exceeds max 161 duration: 832 data/midi/v17/midi_sources/130k_reddit/C/C/crucify2.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/C/C/cantina13.mid ord() expected string of length 1, but int found
# Timeout: 300 midi_sources/130k_reddit/M/M/Medley2.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/130k_reddit/C/C/cascanueces.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/C/C/cargo.mid cannot handle midi file format: <built-in function format>
# Sequence too short: 2 data/midi/v17/midi_sources/130k_reddit/C/C/chestnut04.mid
# npenc exceeds max 161 duration: 390 data/midi/v17/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Schumann/8 Fantaisies Kreisleriana op16.mid
# Sequence too short: 2 data/midi/v17/midi_sources/130k_reddit/C/C/chestnutsroasting.mid
# npenc exceeds max 161 duration: 242 data/midi/v17/midi_sources/130k_reddit/C/C/carmen2.mid
# npenc exceeds max 161 duration: 169 data/midi/v17/midi_sources/130k_reddit/C/C/carribn1.mid
# npenc exceeds max 161 duration: 588 data/midi/v17/midi_sources/130k_reddit/C/C/Cowboy Bebop - ELM.mid
# npenc exceeds max 161 duration: 435 data/midi/v17/midi_sources/130k_reddit/C/C/ColorMyWorld3.mid
# npenc exceeds max 161 duration: 386 data/midi/v17/midi_sources/130k_reddit/C/C/Chuckie - Together.mid
# npenc exceeds max 161 duration: 777 data/midi/v17/midi_sources/130k_reddit/C/C/chimchim2.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/C/C/chuyen_doa_quynh_huong.mid ord() expected string of length 1, but int found
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/130k_reddit/C/C/Coone - The Chosen One (Brennan Heart Remix).mid
# npenc exceeds max 161 duration: 618 data/midi/v17/midi_sources/130k_reddit/C/C/Carnival-Or-Manha-De-Carnival-2.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/C/C/closcred.mid cannot handle midi file format: <built-in function format>
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/130k_reddit/C/C/Cressida_-_OnyricStonefaceTerminalRemix__defhaus_20120411205943.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/C/C/crixmus.mid cannot handle midi file format: <built-in function format>
# npenc exceeds max 161 duration: 832 data/midi/v17/midi_sources/130k_reddit/C/C/Crucify.mid
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/130k_reddit/C/C/Carunia - If You Wanna Dance.mid
# npenc exceeds max 161 duration: 830 data/midi/v17/midi_sources/130k_reddit/C/C/ConcertCelebration.mid
# npenc exceeds max 161 duration: 212 data/midi/v17/midi_sources/130k_reddit/C/C/C-emeraude.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/C/C/closcred2.mid cannot handle midi file format: <built-in function format>
# npenc exceeds max 161 duration: 372 data/midi/v17/midi_sources/130k_reddit/C/C/calypso5.mid
# npenc exceeds max 161 duration: 372 data/midi/v17/midi_sources/130k_reddit/C/C/calypso12.mid
# npenc exceeds max 161 duration: 424 data/midi/v17/midi_sources/130k_reddit/C/C/csrag.mid
# npenc exceeds max 161 duration: 416 data/midi/v17/midi_sources/130k_reddit/C/C/cherish08.mid
# npenc exceeds max 161 duration: 336 data/midi/v17/midi_sources/130k_reddit/C/C/celtic05.mid
# npenc exceeds max 161 duration: 208 data/midi/v17/midi_sources/130k_reddit/C/C/chpn_op33_4.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/130k_reddit/C/C/Clannad - Harukana Toshitsuki -Piano-.mid
# Sequence too short: 5 data/midi/v17/midi_sources/130k_reddit/C/C/CarelessWhisper2.mid
# npenc exceeds max 161 duration: 448 data/midi/v17/midi_sources/130k_reddit/C/C/Classical-Medley-(Medley).mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/C/C/cloak.mid cannot handle midi file format: <built-in function format>
# npenc exceeds max 161 duration: 686 data/midi/v17/midi_sources/130k_reddit/C/C/Carnival-Or-Manha-De-Carnival-1.mid
# npenc exceeds max 161 duration: 632 data/midi/v17/midi_sources/130k_reddit/C/C/cdsm1.mid
# npenc exceeds max 161 duration: 297 data/midi/v17/midi_sources/130k_reddit/5/5213KYRI.MID
# npenc exceeds max 161 duration: 212 data/midi/v17/midi_sources/130k_reddit/C/C/chpn_op53.mid
# npenc exceeds max 161 duration: 572 data/midi/v17/midi_sources/130k_reddit/A/A/anne.mid
# npenc exceeds max 161 duration: 512 data/midi/v17/midi_sources/130k_reddit/A/A/Alienator - This Is War (Dj D Remix).mid
# npenc exceeds max 161 duration: 180 data/midi/v17/midi_sources/130k_reddit/A/A/anastasia.mid
# npenc exceeds max 161 duration: 278 data/midi/v17/midi_sources/130k_reddit/A/A/Ashloo.mid
# npenc exceeds max 161 duration: 240 data/midi/v17/midi_sources/130k_reddit/A/A/Andy_Blueman_-_Nyctalopia__lukascich_20071213140915.mid
# npenc exceeds max 161 duration: 720 data/midi/v17/midi_sources/130k_reddit/A/A/All_Alone.mid
# npenc exceeds max 161 duration: 273 data/midi/v17/midi_sources/130k_reddit/A/A/ajaiblah.mid
# npenc exceeds max 161 duration: 416 data/midi/v17/midi_sources/130k_reddit/A/A/Airforce_And_Samuelzone_-_Source_Of_Calm__Cylum__Phaniax_20070611170907.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/A/A/animals-house_of_the_rising_sun.mid ord() expected string of length 1, but int found
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/A/A/always04.mid ord() expected string of length 1, but int found
# npenc exceeds max 161 duration: 238 data/midi/v17/midi_sources/130k_reddit/A/A/Armin van buuren - Full Focus (Ummet Ozcan Remix).mid
# npenc exceeds max 161 duration: 732 data/midi/v17/midi_sources/130k_reddit/A/A/alb_se5.mid
# npenc exceeds max 161 duration: 289 data/midi/v17/midi_sources/130k_reddit/A/A/autumn_leaves2.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/130k_reddit/A/A/anything_goes.mid
# npenc exceeds max 161 duration: 484 data/midi/v17/midi_sources/130k_reddit/A/A/Another - Another Main Theme.mid
# npenc exceeds max 161 duration: 288 data/midi/v17/midi_sources/130k_reddit/A/A/allforthebest.mid
# npenc exceeds max 161 duration: 552 data/midi/v17/midi_sources/130k_reddit/A/A/assaggia.mid
# npenc exceeds max 161 duration: 344 data/midi/v17/midi_sources/130k_reddit/A/A/assaggia.mid
# npenc exceeds max 161 duration: 274 data/midi/v17/midi_sources/130k_reddit/A/A/ALLGIRLS.MID
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/130k_reddit/A/A/ayla__ayla__cosmonova_mix__nazar.tm_trance.mid
# npenc exceeds max 161 duration: 505 data/midi/v17/midi_sources/130k_reddit/A/A/affair2.mid
# Timeout: 300 midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Rachmaninov/Concerto n3 2&3movs.mid
# Timeout: 300 midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Rachmaninov/Piano Concerto op18 n2 .mid
# npenc exceeds max 161 duration: 340 data/midi/v17/midi_sources/130k_reddit/K/K/knightswhitesatin.mid
# npenc exceeds max 161 duration: 287 data/midi/v17/midi_sources/130k_reddit/K/K/keane-broken_toy.mid
# npenc exceeds max 161 duration: 384 data/midi/v17/midi_sources/130k_reddit/K/K/Kaskade - Eyes.mid
# npenc exceeds max 161 duration: 512 data/midi/v17/midi_sources/130k_reddit/K/K/kinks-all_day_and_all_of_the_night.mid
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/130k_reddit/3/3rd_Moon_-_DNA__Cylum_20070106164112.mid
# npenc exceeds max 161 duration: 312 data/midi/v17/midi_sources/130k_reddit/V/V/Vocaloid - No More.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/V/V/Voivod-'Nothingface'.mid ord() expected string of length 1, but int found
# Timeout: 300 midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Bach/Bwv1080 The Art Of Fugue/The Art of the Fugue BWV1080.mid
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/130k_reddit/V/V/VIOLINES.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/D/D/Dark_Forces.mid cannot handle midi file format: <built-in function format>
# npenc exceeds max 161 duration: 332 data/midi/v17/midi_sources/130k_reddit/D/D/deck_the.mid
# npenc exceeds max 161 duration: 304 data/midi/v17/midi_sources/130k_reddit/D/D/Donkey Kong Country - Jungle Swing.mid
# npenc exceeds max 161 duration: 258 data/midi/v17/midi_sources/130k_reddit/D/D/Dance Nation - Sunshine (Wippenberg Remix).mid
# npenc exceeds max 161 duration: 276 data/midi/v17/midi_sources/130k_reddit/D/D/DJ_Merlin_And_DJ_C-Bass_-_The_Human_Spirit__DJ_RISE_20080324122022.mid
# Sequence too short: 5 data/midi/v17/midi_sources/130k_reddit/D/D/Dj_D_ft._MC__Justice_-_Embrace_The_Mistery__kisgabber_20100629202235.mid
# npenc exceeds max 161 duration: 312 data/midi/v17/midi_sources/130k_reddit/D/D/december2.mid
# npenc exceeds max 161 duration: 384 data/midi/v17/midi_sources/130k_reddit/D/D/december2.mid
# Timeout: 300 midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Mozart/Piano Sonatas/Nueva carpeta/K284 Piano Sonata n06 .mid
# npenc exceeds max 161 duration: 288 data/midi/v17/midi_sources/130k_reddit/D/D/Donkey_Rollers_-_mmeasurably(full)__Rufat_Y._20090530222606.mid
# npenc exceeds max 161 duration: 248 data/midi/v17/midi_sources/130k_reddit/D/D/Dj Mind-X and Friends - Love Freedom Tolerance.mid
# npenc exceeds max 161 duration: 392 data/midi/v17/midi_sources/130k_reddit/D/D/DONTLATE.MID
# Sequence too short: 5 data/midi/v17/midi_sources/130k_reddit/D/D/DmitriVegasMoguaiLikeMike_-_Mammoth__iCarroller_20130306235801.mid
# npenc exceeds max 161 duration: 312 data/midi/v17/midi_sources/130k_reddit/D/D/descent2.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/D/D/dfdemo.mid cannot handle midi file format: <built-in function format>
# npenc exceeds max 161 duration: 308 data/midi/v17/midi_sources/130k_reddit/D/D/Darker than Black, Kuro no Keiyakusha  - &#12475;&#12461;&#12505;&#12484;.mid
# npenc exceeds max 161 duration: 904 data/midi/v17/midi_sources/130k_reddit/D/D/Durarara!! - The Girl in the Drawing.mid
# Sequence too short: 7 data/midi/v17/midi_sources/130k_reddit/D/D/Depeche Mode - But Not Tonight.mid
# npenc exceeds max 161 duration: 184 data/midi/v17/midi_sources/130k_reddit/D/D/danza1.mid
# npenc exceeds max 161 duration: 396 data/midi/v17/midi_sources/130k_reddit/D/D/danu.mid
# npenc exceeds max 161 duration: 200 data/midi/v17/midi_sources/130k_reddit/D/D/danu.mid
# npenc exceeds max 161 duration: 328 data/midi/v17/midi_sources/130k_reddit/D/D/Darklich.mid
# npenc exceeds max 161 duration: 202 data/midi/v17/midi_sources/130k_reddit/D/D/Darklich.mid
# npenc exceeds max 161 duration: 432 data/midi/v17/midi_sources/130k_reddit/D/D/dueling1.mid
# npenc exceeds max 161 duration: 256 data/midi/v17/midi_sources/130k_reddit/D/D/DenizKoyu_-_BongOriginalMix__EvilGuy_20120521224424.mid
# npenc exceeds max 161 duration: 272 data/midi/v17/midi_sources/130k_reddit/D/D/DenizKoyu_-_BongOriginalMix__EvilGuy_20120521224424.mid
# npenc exceeds max 161 duration: 178 data/midi/v17/midi_sources/130k_reddit/D/D/dance-4.mid
# npenc exceeds max 161 duration: 396 data/midi/v17/midi_sources/130k_reddit/D/D/danube04.mid
# npenc exceeds max 161 duration: 200 data/midi/v17/midi_sources/130k_reddit/D/D/danube04.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/D/D/DION.Move any mountain.mid ord() expected string of length 1, but int found
# npenc exceeds max 161 duration: 365 data/midi/v17/midi_sources/130k_reddit/D/D/d-lamb4.mid
# npenc exceeds max 161 duration: 641 data/midi/v17/midi_sources/130k_reddit/7/7steps2.mid
# npenc exceeds max 161 duration: 249 data/midi/v17/midi_sources/130k_reddit/Ragtime_rtpress.com_MIDIRip/rdeer/GesuB_sk.mid
# npenc exceeds max 161 duration: 456 data/midi/v17/midi_sources/130k_reddit/Ragtime_rtpress.com_MIDIRip/rdeer/XmasC_sk.mid
# npenc exceeds max 161 duration: 459 data/midi/v17/midi_sources/130k_reddit/C/C/conc_bf.mid
# npenc exceeds max 161 duration: 651 data/midi/v17/midi_sources/130k_reddit/C/C/conc_bf.mid
# npenc exceeds max 161 duration: 6516 data/midi/v17/midi_sources/130k_reddit/D/D/dante.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/130k_reddit/Y/Y/YAZOO.Only you.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/130k_reddit/Y/Y/YAZOO.Only you.mid
# npenc exceeds max 161 duration: 262 data/midi/v17/midi_sources/130k_reddit/Y/Y/Yosuga no sora - Kioku.mid
# npenc exceeds max 161 duration: 390 data/midi/v17/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/schumann/scn16_1.mid
# npenc exceeds max 161 duration: 240 data/midi/v17/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/sinding/fruehlingsrauschen.mid
# npenc exceeds max 161 duration: 206 data/midi/v17/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/schubert/schub_d960_3.mid
# npenc exceeds max 161 duration: 242 data/midi/v17/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/tchaikovsky/ty_november.mid
# npenc exceeds max 161 duration: 416 data/midi/v17/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/schubert/schubert_D935_4.mid
# npenc exceeds max 161 duration: 166 data/midi/v17/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/liszt/liz_rhap02.mid
# npenc exceeds max 161 duration: 174 data/midi/v17/midi_sources/130k_reddit/G/G/gesubambino.mid
# Sequence too short: 4 data/midi/v17/midi_sources/130k_reddit/G/G/Gareth_Emery_-_Exposure__OCEANIC_20090710120335.mid
# npenc exceeds max 161 duration: 210 data/midi/v17/midi_sources/130k_reddit/G/G/goodchristianmen.mid
# Error parsing midi data/midi/v17/midi_sources/130k_reddit/G/G/gromas.mid cannot handle midi file format: <built-in function format>
# npenc exceeds max 161 duration: 288 data/midi/v17/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/mussorgsky/muss_7.mid
# npenc exceeds max 161 duration: 212 data/midi/v17/midi_sources/130k_reddit/G/G/G-i-28t.mid
# npenc exceeds max 161 duration: 473 data/midi/v17/midi_sources/130k_reddit/G/G/GOODMAN.Stompin' at the Savoy.mid
# npenc exceeds max 161 duration: 320 data/midi/v17/midi_sources/130k_reddit/G/G/Gmsrilan.mid
# npenc exceeds max 161 duration: 408 data/midi/v17/midi_sources/130k_reddit/G/G/Grostemps-Opus-74-Bk-4-Nr-1.mid
# Sequence too short: 7 data/midi/v17/midi_sources/130k_reddit/G/G/Gareth Emery feat. Christina Novelli - Concrete Angel.mid
# npenc exceeds max 161 duration: 232 data/midi/v17/midi_sources/130k_reddit/G/G/genealogy00iibrupaihebehungrap2.mid
# npenc exceeds max 161 duration: 186 data/midi/v17/midi_sources/130k_reddit/Classical_www.midiworld.com_MIDIRip/haydn/hay-p52c.mid
# npenc exceeds max 161 duration: 162 data/midi/v17/midi_sources/130k_reddit/Classical_www.midiworld.com_MIDIRip/mozart/mozk333a.mid
# npenc exceeds max 161 duration: 260 data/midi/v17/midi_sources/130k_reddit/AMERICANA_FOLK_www.pdmusic.org_MIDIRip/1800s/97pj.mid
# npenc exceeds max 161 duration: 224 data/midi/v17/midi_sources/130k_reddit/AMERICANA_FOLK_www.pdmusic.org_MIDIRip/1800s/49twep.mid
# npenc exceeds max 161 duration: 268 data/midi/v17/midi_sources/130k_reddit/AMERICANA_FOLK_www.pdmusic.org_MIDIRip/1800s/66iwltt.mid
# npenc exceeds max 161 duration: 232 data/midi/v17/midi_sources/130k_reddit/AMERICANA_FOLK_www.pdmusic.org_MIDIRip/1800s/20hhcfe.mid

# %%
arr2csv(processed, out_csv); len(processed)
# Out:
# 196499

# %%
df = pd.read_csv(out_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (4,7,9,11,14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ht_mode                title     genres      source     section  \
# 0      1.0  yu-gi-oh-theme-song        NaN  hooktheory      chorus
# 1      1.0  yu-gi-oh-theme-song        NaN  hooktheory       intro
# 2      6.0               kiefer       Jazz  hooktheory      chorus
# 3      6.0         senbonzakura  J-Pop,Pop  hooktheory  pre-chorus
# 4      6.0         senbonzakura  J-Pop,Pop  hooktheory       verse
#
#                                                 midi        artist  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...  wayne-sharpe
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...  wayne-sharpe
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...    what-a-day
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...    whiteflame
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...    whiteflame
#
#                      parts  ht_bpm                     midi_title  \
# 0             intro,chorus   128.0                      yu-gi-oh3
# 1             intro,chorus    85.0                       yu-gi-oh
# 2                   chorus    96.0                         kiefer
# 3  verse,pre-chorus,chorus   152.0  senbonzakura - pre-Pre-Chorus
# 4  verse,pre-chorus,chorus   152.0                   Senbonzakura
#
#    ht_time_signature ht_key  ht_offset                               md5  \
# 0                4.0      C        0.0  bf1f29e5ff84e3e93e37fb873bfb590e
# 1                3.0      C        0.0  055f80ad67f64edb14a85ca8fbfe8c29
# 2                4.0      D       -5.0  197f96f5d181f6ce1e2c5ab04ac1ff87
# 3                4.0      D       -5.0  9e7ce13a35f1314423a9a6d5a5287a4a
# 4                4.0      D       -5.0  d5aaf79d0989222f1362f9f46c540a27
#
#                                             song_url  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...
# 1  https://www.hooktheory.com/theorytab/view/wayn...
# 2  https://www.hooktheory.com/theorytab/view/what...
# 3  https://www.hooktheory.com/theorytab/view/whit...
# 4  https://www.hooktheory.com/theorytab/view/whit...
#
#                                                numpy  mxl
# 0  sf4/s2s_encode/hooktheory/pianoroll/w/wayne-sh...  NaN
# 1                                                NaN  NaN
# 2  sf4/s2s_encode/hooktheory/pianoroll/w/what-a-d...  NaN
# 3  sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...  NaN
# 4  sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...  NaN

# %%
len([f for f in df.numpy.values if isinstance(f, str)])
# Out:
# 53180

# %%
from collections import Counter

# %%
df[df.numpy.notnull()]
# Out:
#         ht_mode                           title  \
# 0           1.0             yu-gi-oh-theme-song
# 2           6.0                          kiefer
# 3           6.0                    senbonzakura
# 4           6.0                    senbonzakura
# 5           6.0                    senbonzakura
# 6           1.0                  last-christmas
# 7           1.0                  last-christmas
# 8           1.0                  last-christmas
# 9           1.0                         freedom
# 11          1.0                 west-wing-suite
# 14          NaN                 blue-eyes-cryin
# 16          1.0         family-guy---theme-song
# 17          1.0       american-dad---theme-song
# 18          1.0                the-freaking-fcc
# 19          1.0                the-freaking-fcc
# 20          6.0                 rainbow-factory
# 21          6.0                 rainbow-factory
# 22          6.0               beyond-her-garden
# 23          6.0                 nightmare-night
# 24          6.0                 nightmare-night
# 25          6.0                  piercing-light
# 26          6.0                  piercing-light
# 27          6.0                        no-hands
# 28          1.0                    fat-labrador
# 29          1.0                         donkeys
# 31          6.0                   amazing-horse
# 32          6.0                   amazing-horse
# 33          6.0                            owls
# 34          1.0                            owls
# 35          6.0                      undertaker
# ...         ...                             ...
# 196466      1.0                       superstar
# 196467      1.0                       superstar
# 196469      1.0                         igniter
# 196470      1.0                       champions
# 196471      1.0                sun-in-your-eyes
# 196472      1.0                     anjunabeach
# 196474      1.0     good-for-me---ambient-mix--
# 196475      1.0     good-for-me---ambient-mix--
# 196476      1.0     good-for-me---ambient-mix--
# 196477      1.0                          always
# 196478      1.0                    sun-and-moon
# 196480      1.0  tightrope-feat-marty-longstaff
# 196481      1.0           lovelight---bad-apple
# 196482      1.0           lovelight---bad-apple
# 196483      1.0           lovelight---bad-apple
# 196484      1.0                       bad-apple
# 196485      1.0               hand-in-my-pocket
# 196486      1.0                          ironic
# 196487      1.0                       you-learn
# 196488      1.0                       uninvited
# 196489      1.0                       uninvited
# 196490      1.0                       thank-you
# 196491      1.0                  head-over-feet
# 196492      1.0                  head-over-feet
# 196493      1.0                 you-oughta-know
# 196494      1.0                     dannys-song
# 196495      1.0                     dannys-song
# 196496      1.0                        only-one
# 196497      1.0                       promise-u
# 196498      1.0                          famous
#
#                                     genres        source  \
# 0                                      NaN    hooktheory
# 2                                     Jazz    hooktheory
# 3                                J-Pop,Pop    hooktheory
# 4                                J-Pop,Pop    hooktheory
# 5                                J-Pop,Pop    hooktheory
# 6                                  Holiday    hooktheory
# 7                                  Holiday    hooktheory
# 8                                  Holiday    hooktheory
# 9                                      NaN    hooktheory
# 11                                     NaN    hooktheory
# 14                                     NaN    hooktheory
# 16                         Jazz,Soundtrack    hooktheory
# 17                              Soundtrack    hooktheory
# 18                              Soundtrack    hooktheory
# 19                              Soundtrack    hooktheory
# 20                              Electronic    hooktheory
# 21                              Electronic    hooktheory
# 22                                     NaN    hooktheory
# 23                 Alt-Country,Hip-Hop/Rap    hooktheory
# 24                 Alt-Country,Hip-Hop/Rap    hooktheory
# 25                                     NaN    hooktheory
# 26                                     NaN    hooktheory
# 27                             Hip-Hop/Rap    hooktheory
# 28                                     NaN    hooktheory
# 29                                     NaN    hooktheory
# 31                                     NaN    hooktheory
# 32                                     NaN    hooktheory
# 33                                     NaN    hooktheory
# 34                                     NaN    hooktheory
# 35                                     NaN    hooktheory
# ...                                    ...           ...
# 196466               Pop,Singer-Songwriter  hooktheory_c
# 196467               Pop,Singer-Songwriter  hooktheory_c
# 196469                          Electronic  hooktheory_c
# 196470                          Electronic  hooktheory_c
# 196471                                 NaN  hooktheory_c
# 196472                          Electronic  hooktheory_c
# 196474                          Electronic  hooktheory_c
# 196475                          Electronic  hooktheory_c
# 196476                          Electronic  hooktheory_c
# 196477                          Electronic  hooktheory_c
# 196478                                 NaN  hooktheory_c
# 196480                                 NaN  hooktheory_c
# 196481                               J-Pop  hooktheory_c
# 196482                               J-Pop  hooktheory_c
# 196483                               J-Pop  hooktheory_c
# 196484                          Video Game  hooktheory_c
# 196485  Alternative,Rock,Singer-Songwriter  hooktheory_c
# 196486                            Pop,Rock  hooktheory_c
# 196487                Alternative,Pop,Rock  hooktheory_c
# 196488                         Alternative  hooktheory_c
# 196489                         Alternative  hooktheory_c
# 196490  Alternative,Rock,Singer-Songwriter  hooktheory_c
# 196491                                 NaN  hooktheory_c
# 196492                                 NaN  hooktheory_c
# 196493                    Alternative,Rock  hooktheory_c
# 196494                                Folk  hooktheory_c
# 196495                                Folk  hooktheory_c
# 196496                               K-pop  hooktheory_c
# 196497                               K-pop  hooktheory_c
# 196498                          Electronic  hooktheory_c
#
#                       section  \
# 0                      chorus
# 2                      chorus
# 3                  pre-chorus
# 4                       verse
# 5                      chorus
# 6                       verse
# 7                      chorus
# 8                       intro
# 9                      chorus
# 11               instrumental
# 14                     chorus
# 16                     chorus
# 17                     chorus
# 18            intro-and-verse
# 19                     bridge
# 20                     bridge
# 21                      intro
# 22                      verse
# 23               instrumental
# 24                     chorus
# 25            intro-and-verse
# 26                     chorus
# 27                     chorus
# 28                     chorus
# 29                      verse
# 31                     bridge
# 32                     chorus
# 33                      verse
# 34                      outro
# 35                      intro
# ...                       ...
# 196466                 chorus
# 196467  pre-chorus-and-chorus
# 196469                 chorus
# 196470                 chorus
# 196471                  verse
# 196472                 chorus
# 196474                 chorus
# 196475                  verse
# 196476                  intro
# 196477                 chorus
# 196478             pre-chorus
# 196480                 chorus
# 196481                 chorus
# 196482                  verse
# 196483                 bridge
# 196484                  intro
# 196485                 chorus
# 196486                 chorus
# 196487                 chorus
# 196488                 chorus
# 196489                  verse
# 196490                 chorus
# 196491                 chorus
# 196492                  verse
# 196493                 chorus
# 196494                 chorus
# 196495                  verse
# 196496                 chorus
# 196497                 chorus
# 196498                 chorus
#
#                                                      midi  \
# 0       midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 2       midi_sources/hooktheory/pianoroll/w/what-a-day...
# 3       midi_sources/hooktheory/pianoroll/w/whiteflame...
# 4       midi_sources/hooktheory/pianoroll/w/whiteflame...
# 5       midi_sources/hooktheory/pianoroll/w/whiteflame...
# 6       midi_sources/hooktheory/pianoroll/w/wham/last-...
# 7       midi_sources/hooktheory/pianoroll/w/wham/last-...
# 8       midi_sources/hooktheory/pianoroll/w/wham/last-...
# 9       midi_sources/hooktheory/pianoroll/w/wham/freed...
# 11      midi_sources/hooktheory/pianoroll/w/wg-snuffy-...
# 14      midi_sources/hooktheory/pianoroll/w/willie-nel...
# 16      midi_sources/hooktheory/pianoroll/w/walter-mur...
# 17      midi_sources/hooktheory/pianoroll/w/walter-mur...
# 18      midi_sources/hooktheory/pianoroll/w/walter-mur...
# 19      midi_sources/hooktheory/pianoroll/w/walter-mur...
# 20      midi_sources/hooktheory/pianoroll/w/woodentoas...
# 21      midi_sources/hooktheory/pianoroll/w/woodentoas...
# 22      midi_sources/hooktheory/pianoroll/w/woodentoas...
# 23      midi_sources/hooktheory/pianoroll/w/woodentoas...
# 24      midi_sources/hooktheory/pianoroll/w/woodentoas...
# 25      midi_sources/hooktheory/pianoroll/w/warsongs/p...
# 26      midi_sources/hooktheory/pianoroll/w/warsongs/p...
# 27      midi_sources/hooktheory/pianoroll/w/waka-flock...
# 28      midi_sources/hooktheory/pianoroll/w/weebl/fat-...
# 29      midi_sources/hooktheory/pianoroll/w/weebl/donk...
# 31      midi_sources/hooktheory/pianoroll/w/weebl/amaz...
# 32      midi_sources/hooktheory/pianoroll/w/weebl/amaz...
# 33      midi_sources/hooktheory/pianoroll/w/weebl/owls...
# 34      midi_sources/hooktheory/pianoroll/w/weebl/owls...
# 35      midi_sources/hooktheory/pianoroll/w/wolfgang-g...
# ...                                                   ...
# 196466  midi_sources/hooktheory/pianoroll/a/a-g-cook/s...
# 196467  midi_sources/hooktheory/pianoroll/a/a-g-cook/s...
# 196469  midi_sources/hooktheory/pianoroll/a/ark-patrol...
# 196470  midi_sources/hooktheory/pianoroll/a/astronaut-...
# 196471  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196472  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196474  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196475  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196476  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196477  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196478  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196480  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196481  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196482  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196483  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196484  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196485  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196486  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196487  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196488  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196489  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196490  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196491  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196492  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196493  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196494  midi_sources/hooktheory/pianoroll/a/anne-murra...
# 196495  midi_sources/hooktheory/pianoroll/a/anne-murra...
# 196496  midi_sources/hooktheory/pianoroll/a/apink/only...
# 196497  midi_sources/hooktheory/pianoroll/a/apink/prom...
# 196498  midi_sources/hooktheory/pianoroll/a/archie/fam...
#
#                                 artist  \
# 0                         wayne-sharpe
# 2                           what-a-day
# 3                           whiteflame
# 4                           whiteflame
# 5                           whiteflame
# 6                                 wham
# 7                                 wham
# 8                                 wham
# 9                                 wham
# 11                    wg-snuffy-walden
# 14                       willie-nelson
# 16                       walter-murphy
# 17                       walter-murphy
# 18                       walter-murphy
# 19                       walter-murphy
# 20                       woodentoaster
# 21                       woodentoaster
# 22                       woodentoaster
# 23                       woodentoaster
# 24                       woodentoaster
# 25                            warsongs
# 26                            warsongs
# 27                   waka-flocka-flame
# 28                               weebl
# 29                               weebl
# 31                               weebl
# 32                               weebl
# 33                               weebl
# 34                               weebl
# 35                    wolfgang-gartner
# ...                                ...
# 196466                        a-g-cook
# 196467                        a-g-cook
# 196469                      ark-patrol
# 196470  astronaut-ft--harry-brooks-jnr
# 196471                above-and-beyond
# 196472                above-and-beyond
# 196474                above-and-beyond
# 196475                above-and-beyond
# 196476                above-and-beyond
# 196477                above-and-beyond
# 196478                above-and-beyond
# 196480                above-and-beyond
# 196481            alstroemeria-records
# 196482            alstroemeria-records
# 196483            alstroemeria-records
# 196484            alstroemeria-records
# 196485               alanis-morissette
# 196486               alanis-morissette
# 196487               alanis-morissette
# 196488               alanis-morissette
# 196489               alanis-morissette
# 196490               alanis-morissette
# 196491               alanis-morissette
# 196492               alanis-morissette
# 196493               alanis-morissette
# 196494                     anne-murray
# 196495                     anne-murray
# 196496                           apink
# 196497                           apink
# 196498                          archie
#
#                                           parts  ht_bpm  \
# 0                                  intro,chorus   128.0
# 2                                        chorus    96.0
# 3                       verse,pre-chorus,chorus   152.0
# 4                       verse,pre-chorus,chorus   152.0
# 5                       verse,pre-chorus,chorus   152.0
# 6                            intro,verse,chorus   108.0
# 7                            intro,verse,chorus   108.0
# 8                            intro,verse,chorus   108.0
# 9                                        chorus   128.0
# 11                                 instrumental    86.0
# 14                                       chorus    58.0
# 16                                       chorus   128.0
# 17                                       chorus   149.0
# 18                       intro-and-verse,bridge   126.0
# 19                       intro-and-verse,bridge   126.0
# 20                                 intro,bridge   148.0
# 21                                 intro,bridge   148.0
# 22                                        verse   131.0
# 23                          chorus,instrumental   197.0
# 24                          chorus,instrumental   197.0
# 25                       intro-and-verse,chorus   125.0
# 26                       intro-and-verse,chorus   125.0
# 27                                       chorus   124.0
# 28                                       chorus   138.0
# 29                                  intro,verse   140.0
# 31                                chorus,bridge   149.0
# 32                                chorus,bridge   149.0
# 33                                  verse,outro   146.0
# 34                                  verse,outro   146.0
# 35                                        intro   240.0
# ...                                         ...     ...
# 196466  pre-chorus,pre-chorus-and-chorus,chorus   120.0
# 196467  pre-chorus,pre-chorus-and-chorus,chorus   128.0
# 196469                                   chorus   149.0
# 196470                                   chorus   128.0
# 196471                                    verse   128.0
# 196472                                   chorus    66.0
# 196474                       intro,verse,chorus   130.0
# 196475                       intro,verse,chorus   130.0
# 196476                       intro,verse,chorus   130.0
# 196477                                   chorus    65.0
# 196478                               pre-chorus   128.0
# 196480                                   chorus    64.0
# 196481                      verse,chorus,bridge   138.0
# 196482                      verse,chorus,bridge   138.0
# 196483                      verse,chorus,bridge   138.0
# 196484                                    intro   149.0
# 196485                                   chorus    92.0
# 196486                                   chorus    86.0
# 196487                                   chorus    84.0
# 196488                             verse,chorus    62.0
# 196489                             verse,chorus    64.0
# 196490                                   chorus    92.0
# 196491                             verse,chorus    85.0
# 196492                             verse,chorus    80.0
# 196493                                   chorus   104.0
# 196494                             verse,chorus    72.0
# 196495                             verse,chorus    74.0
# 196496                                   chorus   102.0
# 196497                                   chorus    70.0
# 196498                                   chorus   128.0
#
#                                          midi_title  ht_time_signature ht_key  \
# 0                                         yu-gi-oh3                4.0      C
# 2                                            kiefer                4.0      D
# 3                     senbonzakura - pre-Pre-Chorus                4.0      D
# 4                                      Senbonzakura                4.0      D
# 5                                      Senbonzakura                4.0      D
# 6                              Last Christmas Verse                4.0     Db
# 7                             Last Christmas Chorus                4.0     Db
# 8                              Last Christmas Intro                4.0     Db
# 9                                    Freedom Chorus                4.0      C
# 11                                           snuffy                4.0      G
# 14                                  Blue Eyes Cryin                4.0      E
# 16                          Family Guy - Theme Song                4.0      F
# 17                        American Dad - Theme Song                4.0     Bb
# 18                                 The Freaking FCC                4.0      C
# 19                               Freakin FCC Bridge                4.0      C
# 20                                  Rainbow Factory                4.0     F#
# 21                                  Rainbow Factory                4.0     F#
# 22                                Beyond Her Garden                4.0     G#
# 23                                  Nightmare Night                4.0      D
# 24                                  Nightmare Night                4.0      D
# 25                                   Piercing Light                4.0      D
# 26                                 Piercing Light 2                4.0      D
# 27                                         No Hands                4.0     C#
# 28                                     Fat Labrador                4.0      E
# 29                                          Donkeys                4.0      B
# 31                           Amazing Horse - Bridge                4.0     F#
# 32                                    Amazing Horse                4.0     F#
# 33                                    Owls - Chorus                4.0      A
# 34                                     Owls - Outro                4.0      A
# 35                                       undertaker                4.0      B
# ...                                             ...                ...    ...
# 196466                                    Superstar                4.0      C
# 196467                AG cook superstar better bmaj                4.0      C
# 196469                                      Igniter                4.0      C
# 196470                                    Champions                4.0      C
# 196471            above and beyond sun in your eyes                4.0      C
# 196472                                  Anjunabeach                4.0      C
# 196474                                  New Project                4.0      C
# 196475                  Good For Me - Ambient Mix -                4.0      C
# 196476         Above & Beyond - Good For Me (INTRO)                4.0      C
# 196477             Above and Beyond - Always Chorus                4.0      C
# 196478  above and beyond sun and moon prePre-Chorus                4.0      C
# 196480                      above and beyond thingy                4.0      C
# 196481                        Lovelight - Bad Apple                4.0      C
# 196482                        Lovelight - Bad Apple                4.0      C
# 196483                  Love Light Bad Apple Bridge                4.0      C
# 196484                                    Bad Apple                4.0      C
# 196485                                 handinpocket                4.0      C
# 196486                                  New Project                4.0      C
# 196487                                     youlearn                4.0      C
# 196488                                    Uninvited                4.0      C
# 196489                                    Uninvited                4.0      C
# 196490                               thankyoualanis                4.0      C
# 196491                               Head Over Feet                4.0      C
# 196492                            headoverfeetverse                4.0      C
# 196493                              You Oughta Know                4.0      C
# 196494                               Danny's Song B                4.0      C
# 196495                               Danny's Song A                4.0      C
# 196496                                     Only One                4.0      C
# 196497                                           pu                4.0      C
# 196498                                       Famous                4.0      C
#
#         ht_offset                               md5  \
# 0             0.0  bf1f29e5ff84e3e93e37fb873bfb590e
# 2            -5.0  197f96f5d181f6ce1e2c5ab04ac1ff87
# 3            -5.0  9e7ce13a35f1314423a9a6d5a5287a4a
# 4            -5.0  d5aaf79d0989222f1362f9f46c540a27
# 5            -5.0  e0c189ee753b30c4758d85211f13c189
# 6            -1.0  38e38402443506e326b76536e8e327a0
# 7            -1.0  75d0251177c8c1fa9a02821299fa5ba8
# 8            -1.0  83d2a800f40aeca07e30e4718cda8fe5
# 9             0.0  60fa29cfec107df27b053cf9708823d5
# 11            5.0  a856dff6c54398544c217104d047abe0
# 14           -4.0  efe067debf4ba033a81b386b56a11b12
# 16           -5.0  07fe0adbcf00ce06bfe166b66036d897
# 17            2.0  1d78ebcb686b399adf74964103b41f7a
# 18            0.0  d8b94e560404a9cde7fa3ec4e8effaef
# 19            0.0  fb7186e6ed193957e7af640656c19c46
# 20            3.0  c251b5ac5dc4ef2b4bbc04470c14fa32
# 21            3.0  e3e30de1a19e92a7637b4fadcd45de00
# 22            1.0  573ea20728eb397360f2294345411c2a
# 23           -5.0  09cb8fdc3215c58befd326b9853e80b5
# 24           -5.0  7f6664a1dd32aa2561bdb4e7e2ff46c6
# 25           -5.0  72ef530a972e28727262573858ae2eb8
# 26           -5.0  9de63b58994e36fe03aa27e632c9905c
# 27           -4.0  05de06f3fed030cd7ff64a9cad9fa97c
# 28           -4.0  a6c7a09bb1cb077b747f037dbc9f53fb
# 29            1.0  3cdbc08e4885c24e083555cb57556faa
# 31            3.0  a129f68e6b95f029539b54250260962a
# 32            3.0  e7d284f8b65d191b823b0c4823c0d2d1
# 33            0.0  7d4935f39a788dea1211b6d96f7f4ccc
# 34            3.0  4d27a08f9f5370a042b17cdb60b3c8ef
# 35           -2.0  3e50bcc9f329bef22e675cf54e4ea228
# ...           ...                               ...
# 196466        0.0  5123b47b0e295721ade01e3305c265f7
# 196467        0.0  d78504eaaf8230e0e66aa3354a4036ad
# 196469        0.0  63b6eec1747db57d7482dec99efa4dc3
# 196470        0.0  3f82e703b67bc25b290e65363138dab1
# 196471        0.0  343e5622f817bd5396196c7e497d1538
# 196472        0.0  785211e4c31b03268b38346d03a63513
# 196474        0.0  cd1ebf2487b7a5eda634fb2df4c51c49
# 196475        0.0  285d3d0cfd4625e1c0f14eda357dc795
# 196476        0.0  ab0905123ecaed999cfa5a39a053e56a
# 196477        0.0  52f99c8789e54123de7cc7fd8da45f02
# 196478        0.0  3694ce098cfc1256e639dd645cb940f3
# 196480        0.0  95303e966c4e0c2f40c4ed1147fc5c21
# 196481        0.0  806589868ad2833c60a1028a9b98d728
# 196482        0.0  4a21d392218716772bfc5c0529f33fa5
# 196483        0.0  a8c214961de4d9b7c8832738a056b174
# 196484        0.0  dc934ad4926fe855af720a51d3f27add
# 196485        0.0  0c0b8dee20d40c4ef3cbc60cefca65bf
# 196486        0.0  369373d75ebc0a0afde1e561af9fe4b6
# 196487        0.0  f9b7ea35a536655b820cc667f541d3c9
# 196488        0.0  f5393682a85b7d15297b18ef464ac3ba
# 196489        0.0  2bbc847e640c011af4872019491303dd
# 196490        0.0  35635e0df8ae7258753456ead487d66b
# 196491        0.0  806d194ba4c2f93829b8bec319fdc81b
# 196492        0.0  e8b89860b8dda437f3fb869c696a004e
# 196493        0.0  917f12f996be13cdb5c16d7da04a97e7
# 196494        0.0  ed12ace7be191bf4b63d11b8bd361f12
# 196495        0.0  de27bb229d9b2a983a8f0feb05369857
# 196496        0.0  5c717d3f4cdf6d80943fa73cab91d242
# 196497        0.0  49e4fef90cc080d43618180d4a32d0ff
# 196498        0.0  67a12c729c20a3bc49e22e1da46d472e
#
#                                                  song_url  \
# 0       https://www.hooktheory.com/theorytab/view/wayn...
# 2       https://www.hooktheory.com/theorytab/view/what...
# 3       https://www.hooktheory.com/theorytab/view/whit...
# 4       https://www.hooktheory.com/theorytab/view/whit...
# 5       https://www.hooktheory.com/theorytab/view/whit...
# 6       https://www.hooktheory.com/theorytab/view/wham...
# 7       https://www.hooktheory.com/theorytab/view/wham...
# 8       https://www.hooktheory.com/theorytab/view/wham...
# 9       https://www.hooktheory.com/theorytab/view/wham...
# 11      https://www.hooktheory.com/theorytab/view/wg-s...
# 14      https://www.hooktheory.com/theorytab/view/will...
# 16      https://www.hooktheory.com/theorytab/view/walt...
# 17      https://www.hooktheory.com/theorytab/view/walt...
# 18      https://www.hooktheory.com/theorytab/view/walt...
# 19      https://www.hooktheory.com/theorytab/view/walt...
# 20      https://www.hooktheory.com/theorytab/view/wood...
# 21      https://www.hooktheory.com/theorytab/view/wood...
# 22      https://www.hooktheory.com/theorytab/view/wood...
# 23      https://www.hooktheory.com/theorytab/view/wood...
# 24      https://www.hooktheory.com/theorytab/view/wood...
# 25      https://www.hooktheory.com/theorytab/view/wars...
# 26      https://www.hooktheory.com/theorytab/view/wars...
# 27      https://www.hooktheory.com/theorytab/view/waka...
# 28      https://www.hooktheory.com/theorytab/view/weeb...
# 29      https://www.hooktheory.com/theorytab/view/weeb...
# 31      https://www.hooktheory.com/theorytab/view/weeb...
# 32      https://www.hooktheory.com/theorytab/view/weeb...
# 33      https://www.hooktheory.com/theorytab/view/weeb...
# 34      https://www.hooktheory.com/theorytab/view/weeb...
# 35      https://www.hooktheory.com/theorytab/view/wolf...
# ...                                                   ...
# 196466  https://www.hooktheory.com/theorytab/view/a-g-...
# 196467  https://www.hooktheory.com/theorytab/view/a-g-...
# 196469  https://www.hooktheory.com/theorytab/view/ark-...
# 196470  https://www.hooktheory.com/theorytab/view/astr...
# 196471  https://www.hooktheory.com/theorytab/view/abov...
# 196472  https://www.hooktheory.com/theorytab/view/abov...
# 196474  https://www.hooktheory.com/theorytab/view/abov...
# 196475  https://www.hooktheory.com/theorytab/view/abov...
# 196476  https://www.hooktheory.com/theorytab/view/abov...
# 196477  https://www.hooktheory.com/theorytab/view/abov...
# 196478  https://www.hooktheory.com/theorytab/view/abov...
# 196480  https://www.hooktheory.com/theorytab/view/abov...
# 196481  https://www.hooktheory.com/theorytab/view/alst...
# 196482  https://www.hooktheory.com/theorytab/view/alst...
# 196483  https://www.hooktheory.com/theorytab/view/alst...
# 196484  https://www.hooktheory.com/theorytab/view/alst...
# 196485  https://www.hooktheory.com/theorytab/view/alan...
# 196486  https://www.hooktheory.com/theorytab/view/alan...
# 196487  https://www.hooktheory.com/theorytab/view/alan...
# 196488  https://www.hooktheory.com/theorytab/view/alan...
# 196489  https://www.hooktheory.com/theorytab/view/alan...
# 196490  https://www.hooktheory.com/theorytab/view/alan...
# 196491  https://www.hooktheory.com/theorytab/view/alan...
# 196492  https://www.hooktheory.com/theorytab/view/alan...
# 196493  https://www.hooktheory.com/theorytab/view/alan...
# 196494  https://www.hooktheory.com/theorytab/view/anne...
# 196495  https://www.hooktheory.com/theorytab/view/anne...
# 196496  https://www.hooktheory.com/theorytab/view/apin...
# 196497  https://www.hooktheory.com/theorytab/view/apin...
# 196498  https://www.hooktheory.com/theorytab/view/arch...
#
#                                                     numpy  mxl
# 0       sf4/s2s_encode/hooktheory/pianoroll/w/wayne-sh...  NaN
# 2       sf4/s2s_encode/hooktheory/pianoroll/w/what-a-d...  NaN
# 3       sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...  NaN
# 4       sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...  NaN
# 5       sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...  NaN
# 6       sf4/s2s_encode/hooktheory/pianoroll/w/wham/las...  NaN
# 7       sf4/s2s_encode/hooktheory/pianoroll/w/wham/las...  NaN
# 8       sf4/s2s_encode/hooktheory/pianoroll/w/wham/las...  NaN
# 9       sf4/s2s_encode/hooktheory/pianoroll/w/wham/fre...  NaN
# 11      sf4/s2s_encode/hooktheory/pianoroll/w/wg-snuff...  NaN
# 14      sf4/s2s_encode/hooktheory/pianoroll/w/willie-n...  NaN
# 16      sf4/s2s_encode/hooktheory/pianoroll/w/walter-m...  NaN
# 17      sf4/s2s_encode/hooktheory/pianoroll/w/walter-m...  NaN
# 18      sf4/s2s_encode/hooktheory/pianoroll/w/walter-m...  NaN
# 19      sf4/s2s_encode/hooktheory/pianoroll/w/walter-m...  NaN
# 20      sf4/s2s_encode/hooktheory/pianoroll/w/woodento...  NaN
# 21      sf4/s2s_encode/hooktheory/pianoroll/w/woodento...  NaN
# 22      sf4/s2s_encode/hooktheory/pianoroll/w/woodento...  NaN
# 23      sf4/s2s_encode/hooktheory/pianoroll/w/woodento...  NaN
# 24      sf4/s2s_encode/hooktheory/pianoroll/w/woodento...  NaN
# 25      sf4/s2s_encode/hooktheory/pianoroll/w/warsongs...  NaN
# 26      sf4/s2s_encode/hooktheory/pianoroll/w/warsongs...  NaN
# 27      sf4/s2s_encode/hooktheory/pianoroll/w/waka-flo...  NaN
# 28      sf4/s2s_encode/hooktheory/pianoroll/w/weebl/fa...  NaN
# 29      sf4/s2s_encode/hooktheory/pianoroll/w/weebl/do...  NaN
# 31      sf4/s2s_encode/hooktheory/pianoroll/w/weebl/am...  NaN
# 32      sf4/s2s_encode/hooktheory/pianoroll/w/weebl/am...  NaN
# 33      sf4/s2s_encode/hooktheory/pianoroll/w/weebl/ow...  NaN
# 34      sf4/s2s_encode/hooktheory/pianoroll/w/weebl/ow...  NaN
# 35      sf4/s2s_encode/hooktheory/pianoroll/w/wolfgang...  NaN
# ...                                                   ...  ...
# 196466  sf4/s2s_encode/hooktheory/pianoroll/a/a-g-cook...  NaN
# 196467  sf4/s2s_encode/hooktheory/pianoroll/a/a-g-cook...  NaN
# 196469  sf4/s2s_encode/hooktheory/pianoroll/a/ark-patr...  NaN
# 196470  sf4/s2s_encode/hooktheory/pianoroll/a/astronau...  NaN
# 196471  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196472  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196474  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196475  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196476  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196477  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196478  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196480  sf4/s2s_encode/hooktheory/pianoroll/a/above-an...  NaN
# 196481  sf4/s2s_encode/hooktheory/pianoroll/a/alstroem...  NaN
# 196482  sf4/s2s_encode/hooktheory/pianoroll/a/alstroem...  NaN
# 196483  sf4/s2s_encode/hooktheory/pianoroll/a/alstroem...  NaN
# 196484  sf4/s2s_encode/hooktheory/pianoroll/a/alstroem...  NaN
# 196485  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196486  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196487  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196488  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196489  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196490  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196491  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196492  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196493  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...  NaN
# 196494  sf4/s2s_encode/hooktheory/pianoroll/a/anne-mur...  NaN
# 196495  sf4/s2s_encode/hooktheory/pianoroll/a/anne-mur...  NaN
# 196496  sf4/s2s_encode/hooktheory/pianoroll/a/apink/on...  NaN
# 196497  sf4/s2s_encode/hooktheory/pianoroll/a/apink/pr...  NaN
# 196498  sf4/s2s_encode/hooktheory/pianoroll/a/archie/f...  NaN
#
# [53180 rows x 17 columns]

# %%
Counter(df[df.numpy.notnull()].source.values)
# Out:
# Counter({'hooktheory': 17700,
#          'freemidi': 51,
#          'midiworld': 66,
#          'ecomp': 2357,
#          'cprato': 124,
#          'classical_piano': 319,
#          'classical_archives': 2399,
#          'musescore': 6908,
#          'wikifonia': 32,
#          'lmd': 128,
#          'reddit': 5266,
#          'hooktheory_c': 17830})

# %%
len(df[df.numpy.notnull()].source.values)
# Out:
# 53180

# %%
Counter(df[df.numpy.notnull()].source.values)
# Out:
# Counter({'hooktheory': 17700,
#          'freemidi': 51,
#          'midiworld': 66,
#          'ecomp': 2357,
#          'cprato': 124,
#          'classical_piano': 319,
#          'classical_archives': 2399,
#          'musescore': 6908,
#          'wikifonia': 32,
#          'lmd': 128,
#          'reddit': 5266,
#          'hooktheory_c': 17830})

# %%
Counter(df.source.values)
# Out:
# Counter({'hooktheory': 19882,
#          'freemidi': 5166,
#          'midiworld': 4107,
#          'ecomp': 2507,
#          'cprato': 312,
#          'classical_piano': 329,
#          'classical_archives': 14641,
#          'musescore': 10928,
#          'wikifonia': 6346,
#          'lmd': 13565,
#          'reddit': 98659,
#          'hooktheory_c': 20076})

# %% [markdown]
# ## Convert to hooktheory databunch

# %%
def get_files(csv):
    files = csv['numpy']
    flist = [Path(version_path/f) for f in files.values if isinstance(f, str)]
    flist = [f for f in flist if f.exists()]
    return flist

# %%
def create_databunch(files, cache_name, batch_size=32, load_cached=False):
    if load_cached and (out_path/f'{cache_name}/train_ids.npy').exists():
        data = MusicDataBunch.load(out_path, bs=batch_size, cache_name=cache_name)
    else:
        ps = [S2SFileProcessor(), S2SPartEncProcessor()]
        data = (MusicItemList(items=files, path=out_path, processor=ps)
                .split_by_rand_pct(0.01, seed=6)
                .label_const(label_cls=LMLabelList))
#         data.x._bunch = MusicDataBunch
        data = data.databunch(bs=batch_size, preloader_cls=S2SPreloader)
        data.save(cache_name)
    return data

# %%
out_path = version_path/out_dir

# %%
csv = df

# %%
hook_csv = csv.loc[csv.source.isin(['hooktheory'])]
hook_files = get_files(hook_csv); len(hook_files)
hook_data = create_databunch(hook_files, cache_name='tmp/hook')

# %%
hook_csv = csv.loc[csv.source.isin(['hooktheory_c'])]
hook_files = get_files(hook_csv); len(hook_files)
hook_data = create_databunch(hook_files, cache_name='tmp/hook_c')

# %%
lq_csv = csv.loc[csv.source.isin(['reddit', 'classical_piano', 'ecomp', 'midiworld', 'freemidi', 'lmd', 'cprato', 'wikifonia', 'classical_archives'])]
lq_files = get_files(lq_csv); len(lq_files)
lq_data = create_databunch(lq_files, cache_name='tmp/lq')

# %%
hq_csv = csv.loc[csv.source.isin(['hooktheory', 'musescore'])]
hq_files = get_files(hq_csv); len(hq_files)
hq_data = create_databunch(hq_files, cache_name='tmp/hq')

# %%
len(hook_data.train_dl.dl.dataset)
# Out:
# 16804

# %%
all_files = get_files(csv); len(all_files)
all_data = create_databunch(all_files, cache_name='tmp/all')

# %%
import random
sample_data = create_databunch(random.sample(all_files, 1000), cache_name='tmp/sample')

# %% [markdown]
# ## Load data

# %%
single_tfm = partial(to_single_stream, vocab=vocab)
load_data =  MusicDataBunch.load(path=out_path, cache_name='tmp/hook_c', preloader_cls=S2SPreloader, train_tfms=[single_tfm])
# Out:
# You can deactivate this warning by passing `no_check=True`.
# /home/ubuntu/fastai/fastai/basic_data.py:259: UserWarning: There seems to be something wrong with your dataset, for example, in the first batch can't access any element of self.train_ds.
# Tried: 0,1,2,3,4...
#   warn(warn_msg)

# %%
load_data =  MusicDataBunch.load(path=out_path, cache_name='tmp/hook_c', preloader_cls=S2SPreloader)

# %%
load_data.one_batch()
# Out:
# (tensor([[  6, 622,  88,  ..., 143,   8, 143],
#          [  5, 622,  55,  ..., 161,  51, 161],
#          [  5, 622,  65,  ..., 149,  61, 149],
#          ...,
#          [  5, 622,  66,  ..., 185,  75, 185],
#          [  5, 622,  64,  ..., 173,  61, 173],
#          [  5, 622,  63,  ..., 185,  60, 185]]),
#  tensor([[  3,   5, 622,  ..., 167,  78, 155],
#          [  3,   6, 622,  ..., 143,   8, 143],
#          [  3,   6, 622,  ..., 140,   8, 140],
#          ...,
#          [  3,   6, 622,  ..., 143,  87, 143],
#          [  3,   6, 622,  ..., 149,   8, 149],
#          [  3,   6, 622,  ..., 149,  75, 197]]))

# %%
# ps = [S2SFileProcessor()]

# single_tfm = partial(to_single_stream, vocab=vocab)
# data = (MusicItemList(items=hook_files[:100], path=out_path, processor=ps, tfms=[single_tfm])
#         .split_by_rand_pct(0.01, seed=6)
#         .label_const(label_cls=LMLabelList))
# data.x._bunch = MusicDataBunch

# %%
# data.x.tfms = [single_tfm]

# %%
data = data.databunch(bs=4, preloader_cls=S2SPreloader, train_tfms=[single_tfm])

# %%
out = data.train_dl.dl.dataset[0]

# %%
data.one_batch()
