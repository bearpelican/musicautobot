# %% [markdown]
# ## Building flask api

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
os.chdir('../../')

# %%
import numpy as np
from pathlib import Path
import pandas as pd
import hashlib
import shutil
import json

# %%
np.set_printoptions(edgeitems=10, threshold=40, linewidth=200)

# %%
data_dir = 'data/midi/v19/'
file_path = Path().expanduser()
path = file_path/data_dir/'midi_encode'

# %%
encoded_path = Path('data/midi/examples')

# %% [markdown]
# ## Creating Subset

# %%
song_ids = [
    '99c5db9ce936b7a1c5faab57cc3f160c',
    'aeee134e4034e5f98bb630c56d2f7f8c',
    'b4c62f3d11f448db69c4fa15e27e9e8e',
    '8f10995e036c5f590ca616dee0c9c7d7',
    '58890c433f173ba77220274017b8af92',
    '19762ebd7059dd5f8809f98b2575d8c1',
    'c4d9e72a92f931b2c72e84b6efee4b51',
    'de1fa62a9c209491d4fd81f1d1ceb55e',
    'f8b65d3624d9a68e417792ec27de9296',
    '2ad86f3ecd71b058eac9cc5ceba11db8',
    '999e8169b01f59fa28e63b142f35feda',
    '7f0f162d111f880cf77ff9bed15acd5d',
    '077b40997776b84366ee18056948ae38',
    '065b1c94fe8545bbe8eeec2f1bf4efa2',
    'f2062929514d3084f73a1ad81bbbe01f',
    '68ce7fc929f395291507cc47510cd82c',
    '6ae7e284e78824ee4c17dc6e6bda361c',
    '73b2b8e7db746b7e4b6fc3fa4658671b'
]

# song_ids = [sid[::-1] for sid in song_ids]

# %%
df = pd.read_csv(path/'midi_encode.csv')
df = df.loc[df['numpy'].notna()]
df = df.loc[df.source == 'hooktheory_c']
df = df.where((pd.notnull(df)), None) # nan values break json
df.shape
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,2,5,6,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (19562, 17)

# %%
subset = df.loc[df.md5.isin(song_ids)]; subset
# Out:
#                                                  song_url  \
# 177759  https://www.hooktheory.com/theorytab/view/jack...
# 177960  https://www.hooktheory.com/theorytab/view/joha...
# 179132  https://www.hooktheory.com/theorytab/view/ludw...
# 180089  https://www.hooktheory.com/theorytab/view/vane...
# 181299  https://www.hooktheory.com/theorytab/view/blac...
# 181459  https://www.hooktheory.com/theorytab/view/brun...
# 181892  https://www.hooktheory.com/theorytab/view/zedd...
# 183236  https://www.hooktheory.com/theorytab/view/disn...
# 184965  https://www.hooktheory.com/theorytab/view/skri...
# 185750  https://www.hooktheory.com/theorytab/view/carl...
# 186123  https://www.hooktheory.com/theorytab/view/edva...
# 186335  https://www.hooktheory.com/theorytab/view/elto...
# 187839  https://www.hooktheory.com/theorytab/view/idin...
# 189004  https://www.hooktheory.com/theorytab/view/pink...
# 193196  https://www.hooktheory.com/theorytab/view/ritc...
# 194279  https://www.hooktheory.com/theorytab/view/mari...
# 195296  https://www.hooktheory.com/theorytab/view/anto...
# 195819  https://www.hooktheory.com/theorytab/view/avic...
#
#                                      md5   mxl  \
# 177759  2ad86f3ecd71b058eac9cc5ceba11db8  None
# 177960  c4d9e72a92f931b2c72e84b6efee4b51  None
# 179132  6ae7e284e78824ee4c17dc6e6bda361c  None
# 180089  58890c433f173ba77220274017b8af92  None
# 181299  68ce7fc929f395291507cc47510cd82c  None
# 181459  077b40997776b84366ee18056948ae38  None
# 181892  7f0f162d111f880cf77ff9bed15acd5d  None
# 183236  8f10995e036c5f590ca616dee0c9c7d7  None
# 184965  f8b65d3624d9a68e417792ec27de9296  None
# 185750  99c5db9ce936b7a1c5faab57cc3f160c  None
# 186123  de1fa62a9c209491d4fd81f1d1ceb55e  None
# 186335  b4c62f3d11f448db69c4fa15e27e9e8e  None
# 187839  f2062929514d3084f73a1ad81bbbe01f  None
# 189004  065b1c94fe8545bbe8eeec2f1bf4efa2  None
# 193196  aeee134e4034e5f98bb630c56d2f7f8c  None
# 194279  999e8169b01f59fa28e63b142f35feda  None
# 195296  73b2b8e7db746b7e4b6fc3fa4658671b  None
# 195819  19762ebd7059dd5f8809f98b2575d8c1  None
#
#                                         genres  ht_offset ht_key  \
# 177759                                    None        0.0      C
# 177960                                    None        0.0      C
# 179132                               Classical        0.0      C
# 180089                   Pop,Singer-Songwriter        0.0      C
# 181299                                    None        0.0      C
# 181459                                     Pop        0.0      C
# 181892                                    None        0.0      C
# 183236                                  Disney        0.0      C
# 184965                  Dance,Electronic,House        0.0      C
# 185750              Hip-Hop/Rap,Pop,R & B,Soul        0.0      C
# 186123                               Classical        0.0      C
# 186335                         Disney,Pop,Rock        0.0      C
# 187839  Dance,Disney,Electronic,Pop,Soundtrack        0.0      C
# 189004                                     Pop        0.0      C
# 193196                                Pop,Rock        0.0      C
# 194279                                    None        0.0      C
# 195296                               Classical        0.0      C
# 195819                        Electronic,House        0.0      C
#
#                       section        source  ht_bpm                artist  \
# 177759                  intro  hooktheory_c    98.0             jackson-5
# 177960                 chorus  hooktheory_c   138.0      johann-pachelbel
# 179132                  verse  hooktheory_c   139.0  ludwig-van-beethoven
# 180089   verse-and-pre-chorus  hooktheory_c    96.0       vanessa-carlton
# 181299                 chorus  hooktheory_c    93.0       black-eyed-peas
# 181459                 chorus  hooktheory_c   147.0            bruno-mars
# 181892             pre-chorus  hooktheory_c   107.0                  zedd
# 183236                 chorus  hooktheory_c   107.0                disney
# 184965             pre-chorus  hooktheory_c   140.0              skrillex
# 185750                 chorus  hooktheory_c   120.0      carly-rae-jepsen
# 186123                  intro  hooktheory_c   116.0          edvard-grieg
# 186335                  verse  hooktheory_c    62.0            elton-john
# 187839                 chorus  hooktheory_c   137.0          idina-menzel
# 189004                 chorus  hooktheory_c    94.0                  pink
# 193196                 chorus  hooktheory_c   144.0         ritchie-valen
# 194279  pre-chorus-and-chorus  hooktheory_c   151.0          mariah-carey
# 195296           instrumental  hooktheory_c    84.0       antonio-vivaldi
# 195819                  verse  hooktheory_c   126.0                avicii
#
#         ht_mode                                              numpy  \
# 177759      1.0  sf4/midi_encode/hooktheory/pianoroll/j/jackson...
# 177960      1.0  sf4/midi_encode/hooktheory/pianoroll/j/johann-...
# 179132      1.0  sf4/midi_encode/hooktheory/pianoroll/l/ludwig-...
# 180089      1.0  sf4/midi_encode/hooktheory/pianoroll/v/vanessa...
# 181299      1.0  sf4/midi_encode/hooktheory/pianoroll/b/black-e...
# 181459      1.0  sf4/midi_encode/hooktheory/pianoroll/b/bruno-m...
# 181892      1.0  sf4/midi_encode/hooktheory/pianoroll/z/zedd/mi...
# 183236      1.0  sf4/midi_encode/hooktheory/pianoroll/d/disney/...
# 184965      1.0  sf4/midi_encode/hooktheory/pianoroll/s/skrille...
# 185750      1.0  sf4/midi_encode/hooktheory/pianoroll/c/carly-r...
# 186123      1.0  sf4/midi_encode/hooktheory/pianoroll/e/edvard-...
# 186335      1.0  sf4/midi_encode/hooktheory/pianoroll/e/elton-j...
# 187839      1.0  sf4/midi_encode/hooktheory/pianoroll/i/idina-m...
# 189004      1.0  sf4/midi_encode/hooktheory/pianoroll/p/pink/ju...
# 193196      1.0  sf4/midi_encode/hooktheory/pianoroll/r/ritchie...
# 194279      1.0  sf4/midi_encode/hooktheory/pianoroll/m/mariah-...
# 195296      1.0  sf4/midi_encode/hooktheory/pianoroll/a/antonio...
# 195819      1.0  sf4/midi_encode/hooktheory/pianoroll/a/avicii/...
#
#                                   midi_title  \
# 177759                       I Want You Back
# 177960                Pachelbel Canon Chorus
# 179132                            Fuer Elise
# 180089  A thousand miles verse and prechorus
# 181299              Where is the Love Chorus
# 181459                              Locked C
# 181892                                Middle
# 183236                    Colors Of The Wind
# 184965       Scary Monsters And Nice Sprites
# 185750                         Call Me Maybe
# 186123      In The Hall Of The Mountain King
# 186335         Can You Feel the Love Tonight
# 187839                             Let It Go
# 189004                 Just Give Me A Reason
# 193196                              La Bamba
# 194279       All I Want For Christmas Is You
# 195296                                Winter
# 195819                                Levels
#
#                                         title  \
# 177759                        i-want-you-back
# 177960                       canon-in-d-major
# 179132                             fuer-elise
# 180089                       a-thousand-miles
# 181299                      where-is-the-love
# 181459                   locked-out-of-heaven
# 181892                                 middle
# 183236                     colors-of-the-wind
# 184965        scary-monsters-and-nice-sprites
# 185750                          call-me-maybe
# 186123       in-the-hall-of-the-mountain-king
# 186335          can-you-feel-the-love-tonight
# 187839                              let-it-go
# 189004                  just-give-me-a-reason
# 193196                               la-bamba
# 194279        all-i-want-for-christmas-is-you
# 195296  the-four-seasons-concerto-no-4-winter
# 195819                                 levels
#
#                                                      midi  \
# 177759  midi_sources/hooktheory/pianoroll/j/jackson-5/...
# 177960  midi_sources/hooktheory/pianoroll/j/johann-pac...
# 179132  midi_sources/hooktheory/pianoroll/l/ludwig-van...
# 180089  midi_sources/hooktheory/pianoroll/v/vanessa-ca...
# 181299  midi_sources/hooktheory/pianoroll/b/black-eyed...
# 181459  midi_sources/hooktheory/pianoroll/b/bruno-mars...
# 181892  midi_sources/hooktheory/pianoroll/z/zedd/middl...
# 183236  midi_sources/hooktheory/pianoroll/d/disney/col...
# 184965  midi_sources/hooktheory/pianoroll/s/skrillex/s...
# 185750  midi_sources/hooktheory/pianoroll/c/carly-rae-...
# 186123  midi_sources/hooktheory/pianoroll/e/edvard-gri...
# 186335  midi_sources/hooktheory/pianoroll/e/elton-john...
# 187839  midi_sources/hooktheory/pianoroll/i/idina-menz...
# 189004  midi_sources/hooktheory/pianoroll/p/pink/just-...
# 193196  midi_sources/hooktheory/pianoroll/r/ritchie-va...
# 194279  midi_sources/hooktheory/pianoroll/m/mariah-car...
# 195296  midi_sources/hooktheory/pianoroll/a/antonio-vi...
# 195819  midi_sources/hooktheory/pianoroll/a/avicii/lev...
#
#                                                     parts  ht_time_signature
# 177759                                 intro,verse,chorus                4.0
# 177960                            intro,pre-chorus,chorus                4.0
# 179132                           verse,chorus,bridge,solo                3.0
# 180089                  intro,verse-and-pre-chorus,chorus                4.0
# 181299                                             chorus                4.0
# 181459                  intro-and-verse,pre-chorus,chorus                4.0
# 181892                                         pre-chorus                4.0
# 183236                                       intro,chorus                4.0
# 184965                                         pre-chorus                4.0
# 185750                                             chorus                4.0
# 186123                                       intro,bridge                4.0
# 186335                                 intro,verse,chorus                4.0
# 187839  intro,intro-and-verse,verse,pre-chorus,chorus,...                4.0
# 189004                      intro,verse,pre-chorus,chorus                4.0
# 193196                                             chorus                4.0
# 194279                  intro,verse,pre-chorus-and-chorus                4.0
# 195296                            intro,solo,instrumental                4.0
# 195819                                        intro,verse                4.0

# %%
recordlist = subset.to_dict('records')

# %% [markdown]
# ## Saving to example Folder

# %%
def format_meta(s):
    title = s['title'].title().replace('-', ' ')
    artist = s['artist'].title().replace('-', ' ')
    display = ' - '.join([title, artist])
    if s.get('section'): display += ' - ' + s['section'].title()
        
    key_file = file_path/data_dir/s['midi']
    to_file = encoded_path/f'{display}.mid'
    if not to_file.exists():
        to_file.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy(str(key_file), str(to_file))
    return to_file

# %%
[format_meta(s) for s in recordlist]
# Out:
# [PosixPath('data/midi/examples/I Want You Back - Jackson 5 - Intro.mid'),
#  PosixPath('data/midi/examples/Canon In D Major - Johann Pachelbel - Chorus.mid'),
#  PosixPath('data/midi/examples/Fuer Elise - Ludwig Van Beethoven - Verse.mid'),
#  PosixPath('data/midi/examples/A Thousand Miles - Vanessa Carlton - Verse-And-Pre-Chorus.mid'),
#  PosixPath('data/midi/examples/Where Is The Love - Black Eyed Peas - Chorus.mid'),
#  PosixPath('data/midi/examples/Locked Out Of Heaven - Bruno Mars - Chorus.mid'),
#  PosixPath('data/midi/examples/Middle - Zedd - Pre-Chorus.mid'),
#  PosixPath('data/midi/examples/Colors Of The Wind - Disney - Chorus.mid'),
#  PosixPath('data/midi/examples/Scary Monsters And Nice Sprites - Skrillex - Pre-Chorus.mid'),
#  PosixPath('data/midi/examples/Call Me Maybe - Carly Rae Jepsen - Chorus.mid'),
#  PosixPath('data/midi/examples/In The Hall Of The Mountain King - Edvard Grieg - Intro.mid'),
#  PosixPath('data/midi/examples/Can You Feel The Love Tonight - Elton John - Verse.mid'),
#  PosixPath('data/midi/examples/Let It Go - Idina Menzel - Chorus.mid'),
#  PosixPath('data/midi/examples/Just Give Me A Reason - Pink - Chorus.mid'),
#  PosixPath('data/midi/examples/La Bamba - Ritchie Valen - Chorus.mid'),
#  PosixPath('data/midi/examples/All I Want For Christmas Is You - Mariah Carey - Pre-Chorus-And-Chorus.mid'),
#  PosixPath('data/midi/examples/The Four Seasons Concerto No 4 Winter - Antonio Vivaldi - Instrumental.mid'),
#  PosixPath('data/midi/examples/Levels - Avicii - Verse.mid')]

# %%
p = Path('../../data/midi/examples/Levels - Avicii - Verse.mid').absolute()
p, p.exists()
# Out:
# (PosixPath('/home/ubuntu/midi_generator/../../data/midi/examples/Levels - Avicii - Verse.mid'),
#  False)

# %% [markdown]
# ## Creating Asset Folder

# %%
asset_path = file_path/'data/assets/examples/seed'

# %%
def save_to_path(s):
    title = s['title'].title().replace('-', ' ')
    artist = s['artist'].title().replace('-', ' ')
    display = ' - '.join([title, artist])
    if s.get('section'): display += ' - ' + s['section'].title()
    sid = s['md5']
    
    json_data = {
        'title': title,
        'artist': artist,
        'bpm': s['ht_bpm'],
        'display': display,
        'section': s['section'],
        'genres': s['genres'],
        'sid': sid
    }
    source_file = file_path/data_dir/s['midi']
#     key_file = str(source_file).replace('cmajor', 'original')
    key_file = source_file
    to_file = asset_path/f'{sid[::-1]}.mid'
    to_json = asset_path/f'{sid[::-1]}.json'
    if not to_file.exists():
        to_file.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy(str(key_file), str(to_file))
        with open(to_json, 'w') as jp:
            json.dump(json_data, jp)
    
    return json_data

# %%
htlist = [save_to_path(s) for s in recordlist]
json_path = asset_path.parent/'json/htlist.json'
json_path.parent.mkdir(parents=True, exist_ok=True)
with open(json_path, 'w') as fp:
    json.dump(htlist, fp, separators=(',', ':'))

# %%
htlist
# Out:
# [{'title': 'I Want You Back',
#   'artist': 'Jackson 5',
#   'bpm': 98.0,
#   'display': 'I Want You Back - Jackson 5 - Intro',
#   'section': 'intro',
#   'genres': None,
#   'sid': '2ad86f3ecd71b058eac9cc5ceba11db8'},
#  {'title': 'Canon In D Major',
#   'artist': 'Johann Pachelbel',
#   'bpm': 138.0,
#   'display': 'Canon In D Major - Johann Pachelbel - Chorus',
#   'section': 'chorus',
#   'genres': None,
#   'sid': 'c4d9e72a92f931b2c72e84b6efee4b51'},
#  {'title': 'Fuer Elise',
#   'artist': 'Ludwig Van Beethoven',
#   'bpm': 139.0,
#   'display': 'Fuer Elise - Ludwig Van Beethoven - Verse',
#   'section': 'verse',
#   'genres': 'Classical',
#   'sid': '6ae7e284e78824ee4c17dc6e6bda361c'},
#  {'title': 'A Thousand Miles',
#   'artist': 'Vanessa Carlton',
#   'bpm': 96.0,
#   'display': 'A Thousand Miles - Vanessa Carlton - Verse-And-Pre-Chorus',
#   'section': 'verse-and-pre-chorus',
#   'genres': 'Pop,Singer-Songwriter',
#   'sid': '58890c433f173ba77220274017b8af92'},
#  {'title': 'Where Is The Love',
#   'artist': 'Black Eyed Peas',
#   'bpm': 93.0,
#   'display': 'Where Is The Love - Black Eyed Peas - Chorus',
#   'section': 'chorus',
#   'genres': None,
#   'sid': '68ce7fc929f395291507cc47510cd82c'},
#  {'title': 'Locked Out Of Heaven',
#   'artist': 'Bruno Mars',
#   'bpm': 147.0,
#   'display': 'Locked Out Of Heaven - Bruno Mars - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop',
#   'sid': '077b40997776b84366ee18056948ae38'},
#  {'title': 'Middle',
#   'artist': 'Zedd',
#   'bpm': 107.0,
#   'display': 'Middle - Zedd - Pre-Chorus',
#   'section': 'pre-chorus',
#   'genres': None,
#   'sid': '7f0f162d111f880cf77ff9bed15acd5d'},
#  {'title': 'Colors Of The Wind',
#   'artist': 'Disney',
#   'bpm': 107.0,
#   'display': 'Colors Of The Wind - Disney - Chorus',
#   'section': 'chorus',
#   'genres': 'Disney',
#   'sid': '8f10995e036c5f590ca616dee0c9c7d7'},
#  {'title': 'Scary Monsters And Nice Sprites',
#   'artist': 'Skrillex',
#   'bpm': 140.0,
#   'display': 'Scary Monsters And Nice Sprites - Skrillex - Pre-Chorus',
#   'section': 'pre-chorus',
#   'genres': 'Dance,Electronic,House',
#   'sid': 'f8b65d3624d9a68e417792ec27de9296'},
#  {'title': 'Call Me Maybe',
#   'artist': 'Carly Rae Jepsen',
#   'bpm': 120.0,
#   'display': 'Call Me Maybe - Carly Rae Jepsen - Chorus',
#   'section': 'chorus',
#   'genres': 'Hip-Hop/Rap,Pop,R & B,Soul',
#   'sid': '99c5db9ce936b7a1c5faab57cc3f160c'},
#  {'title': 'In The Hall Of The Mountain King',
#   'artist': 'Edvard Grieg',
#   'bpm': 116.0,
#   'display': 'In The Hall Of The Mountain King - Edvard Grieg - Intro',
#   'section': 'intro',
#   'genres': 'Classical',
#   'sid': 'de1fa62a9c209491d4fd81f1d1ceb55e'},
#  {'title': 'Can You Feel The Love Tonight',
#   'artist': 'Elton John',
#   'bpm': 62.0,
#   'display': 'Can You Feel The Love Tonight - Elton John - Verse',
#   'section': 'verse',
#   'genres': 'Disney,Pop,Rock',
#   'sid': 'b4c62f3d11f448db69c4fa15e27e9e8e'},
#  {'title': 'Let It Go',
#   'artist': 'Idina Menzel',
#   'bpm': 137.0,
#   'display': 'Let It Go - Idina Menzel - Chorus',
#   'section': 'chorus',
#   'genres': 'Dance,Disney,Electronic,Pop,Soundtrack',
#   'sid': 'f2062929514d3084f73a1ad81bbbe01f'},
#  {'title': 'Just Give Me A Reason',
#   'artist': 'Pink',
#   'bpm': 94.0,
#   'display': 'Just Give Me A Reason - Pink - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop',
#   'sid': '065b1c94fe8545bbe8eeec2f1bf4efa2'},
#  {'title': 'La Bamba',
#   'artist': 'Ritchie Valen',
#   'bpm': 144.0,
#   'display': 'La Bamba - Ritchie Valen - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop,Rock',
#   'sid': 'aeee134e4034e5f98bb630c56d2f7f8c'},
#  {'title': 'All I Want For Christmas Is You',
#   'artist': 'Mariah Carey',
#   'bpm': 151.0,
#   'display': 'All I Want For Christmas Is You - Mariah Carey - Pre-Chorus-And-Chorus',
#   'section': 'pre-chorus-and-chorus',
#   'genres': None,
#   'sid': '999e8169b01f59fa28e63b142f35feda'},
#  {'title': 'The Four Seasons Concerto No 4 Winter',
#   'artist': 'Antonio Vivaldi',
#   'bpm': 84.0,
#   'display': 'The Four Seasons Concerto No 4 Winter - Antonio Vivaldi - Instrumental',
#   'section': 'instrumental',
#   'genres': 'Classical',
#   'sid': '73b2b8e7db746b7e4b6fc3fa4658671b'},
#  {'title': 'Levels',
#   'artist': 'Avicii',
#   'bpm': 126.0,
#   'display': 'Levels - Avicii - Verse',
#   'section': 'verse',
#   'genres': 'Electronic,House',
#   'sid': '19762ebd7059dd5f8809f98b2575d8c1'}]
