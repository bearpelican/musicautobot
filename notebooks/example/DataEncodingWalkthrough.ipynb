# %% [markdown]
# # Attention Architecture

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
os.chdir('../../')

# %%
from src.numpy_encode import *
from src.config import *
from src.music_transformer import *
from src.multitask_transformer import *

# %% [markdown]
# ## Grab midi file

# %%
example_path = Path('data/midi/examples')
midi_files = get_files(example_path, recurse=True, extensions='.mid'); midi_files[:5]
# Out:
# [PosixPath('data/midi/examples/Levels - Avicii - Verse.mid'),
#  PosixPath('data/midi/examples/Colors Of The Wind - Disney - Chorus.mid'),
#  PosixPath('data/midi/examples/Where Is The Love - Black Eyed Peas - Chorus.mid'),
#  PosixPath('data/midi/examples/La Bamba - Ritchie Valen - Chorus.mid'),
#  PosixPath('data/midi/examples/I Want You Back - Jackson 5 - Intro.mid')]

# %%
idx = 2
file = midi_files[idx]; file
# Out:
# PosixPath('data/midi/examples/Where Is The Love - Black Eyed Peas - Chorus.mid')

# %%
# Encode file 
item = MusicItem.from_file(file, data.vocab)

x = item.to_tensor()
x_pos = item.get_pos_tensor()

# %%
item.show()

# %%
item.play()
# Out:
#                 <div id='midiPlayerDiv2917'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv2917');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Predict Mask

# %% [markdown]
# #### Regenerate durations

# %%
# duration mask
dur_item = item.mask_duration()

# %%
dur_pred = learn.predict_mask(dur_item, temperatures=(0.8,0.8), top_k=40, top_p=0.6)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='155' class='' max='155', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [155/155 00:01<00:00]
#     </div>

# %%
dur_pred.show()

# %% [markdown]
# #### Regenerate Notes

# %%
# Mask notes
# nr = vocab.stoi[SEP], vocab.stoi[NOTE_END]+1
note_item = item.mask_notes()
pred_note = learn.predict_mask(note_item)

pred_note.show()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='86' class='' max='86', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [86/86 00:00<00:00]
#     </div>

# %%
pred_note.play()
# Out:
#                 <div id='midiPlayerDiv10130'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv10130');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
out = mask_predict_from_midi(learn, file, predict_notes=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='86' class='' max='86', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [86/86 00:00<00:00]
#     </div>

# %%
out.show()

# %% [markdown]
# ## Prediction next word

# %%
seed_len = 4 # 4 beats = 1 bar
seed = item.trim_to_beat(seed_len)

# %%
seed.show()

# %%
pred_nw = learn.predict_nw(seed, n_words=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:02<00:00]
#     </div>

# %%
pred_nw.show()

# %%
pred_nw.play()
# Out:
#                 <div id='midiPlayerDiv16333'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv16333');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# Convenience function

# %%
out = nw_predict_from_midi(learn, file, seed_len=seed_len, top_k=30, top_p=0.5)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Predicted BOS token. Returning prediction...

# %%
out.show()

# %% [markdown]
# ## Predict Seq2Seq

# %%
from src.numpy_encode import stream2npenc_parts

# %%
multitrack_item = MultitrackItem.from_file(file, vocab)

# %%
melody, chords = multitrack_item.melody, multitrack_item.chords

# %%
melody.show()

# %%
chords.show()

# %%
multitrack_item.play()
# Out:
#                 <div id='midiPlayerDiv24250'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv24250');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Predict melody

# %%
partial_melody = melody.trim_to_beat(3)
partial_melody.show()

# %%
pred_melody = learn.predict_s2s(chords, partial_melody, use_memory=True)
pred_melody.show()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='256' class='' max='256', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [256/256 00:05<00:00]
#     </div>

# %%
pred_melody.play()
# Out:
#                 <div id='midiPlayerDiv27899'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv27899');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
combined = MultitrackItem(pred_melody, chords)
combined.show()

# %%
combined.play()
# Out:
#                 <div id='midiPlayerDiv32015'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv32015');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Predict chords

# %%
partial_chords = chords.trim_to_beat(3);
partial_chords.show()

# %%
pred_chord = learn.predict_s2s(input_item=melody, target_item=partial_chords)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='256', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Predicted past counter-part length. Returning early

# %%
pred_chord.show()

# %%
combined = MultitrackItem(melody, pred_chord)
combined.show()

# %% [markdown]
# Convenience Function

# %%
out = s2s_predict_from_midi(learn, file, seed_len=10)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Predicted past counter-part length. Returning early

# %%
out.show()
