# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')
from src.encode_data import *
from src.midi_data import *
from src.data_sources import process_all, arr2csv
from src.midi_transform import *
from src.fastai_data import *

# %%
import traceback
import time

# %% [markdown]
# ## Standardize and reformat raw midi files before encoding to text
# - Transform key to C major
# - Remove unused instruments
# - Combine multiple tracks with the same instrument into a single part
# - Melody, Piano, String

# %% [markdown]
# ### Load midi data

# %%
version = 'v15'
data_path = Path('data/midi')
version_path = data_path/version

# %%
import pandas as pd

# %%
# out_dir = 'midi_encode'
# duet_only = False
out_dir = 's2s_encode'
duet_only = True

# %%
source_dir = 'midi_sources'
source_csv = version_path/'metadata'/f'{source_dir}.csv'
out_csv = version_path/out_dir/f'{out_dir}.csv'
out_csv.parent.mkdir(parents=True, exist_ok=True)
source_csv, out_csv
# Out:
# (PosixPath('data/midi/v15/metadata/midi_sources.csv'),
#  PosixPath('data/midi/v15/s2s_encode/s2s_encode.csv'))

# %%
# num_comps = 2 # note, duration
cutoff = 5 # max instruments
min_variation = 3 # minimum number of different midi notes played
# max_dur = 128

# %% [markdown]
# ### Encoding midi to numpy

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,4,7,9,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ht_time_signature  ht_offset  \
# 0                4.0        0.0
# 1                3.0        0.0
# 2                4.0       -5.0
# 3                4.0       -5.0
# 4                4.0       -5.0
#
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                      parts  ht_bpm                title  \
# 0             intro,chorus   128.0  yu-gi-oh-theme-song
# 1             intro,chorus    85.0  yu-gi-oh-theme-song
# 2                   chorus    96.0               kiefer
# 3  verse,pre-chorus,chorus   152.0         senbonzakura
# 4  verse,pre-chorus,chorus   152.0         senbonzakura
#
#                       midi_title        artist  \
# 0                      yu-gi-oh3  wayne-sharpe
# 1                       yu-gi-oh  wayne-sharpe
# 2                         kiefer    what-a-day
# 3  senbonzakura - pre-Pre-Chorus    whiteflame
# 4                   Senbonzakura    whiteflame
#
#                                             song_url     genres      source  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 1  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 2  https://www.hooktheory.com/theorytab/view/what...       Jazz  hooktheory
# 3  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
# 4  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
#
#   ht_key                               md5  mxl  ht_mode
# 0      C  bf1f29e5ff84e3e93e37fb873bfb590e  NaN      1.0
# 1      C  055f80ad67f64edb14a85ca8fbfe8c29  NaN      1.0
# 2      D  197f96f5d181f6ce1e2c5ab04ac1ff87  NaN      6.0
# 3      D  9e7ce13a35f1314423a9a6d5a5287a4a  NaN      6.0
# 4      D  d5aaf79d0989222f1362f9f46c540a27  NaN      6.0

# %%
all_records = df.to_dict(orient='records'); len(all_records)
# Out:
# 197182

# %%
# input_file = version_path/all_records[0]['midi']

# stream = file2stream(input_file)
# chordarr = stream2chordarr(stream, max_dur=DUR_RANGE-2, flat=False)

# _,num_inst,_ = chordarr.shape

# parts = [part_enc(chordarr, i) for i in range(num_inst)]

# parts = sorted(parts, key=avg_pitch)

# %%
def avg_pitch(npenc):
    notes = npenc[:, 0]
    return notes[notes > 0].mean()

# %%
def part_enc(chordarr, part):
    partarr = chordarr[:,part:part+1,:]
    # Part 3. Chord array to numpy
    seq = chordarr2seq(partarr)
    return seq2npenc(seq)

# %%
def process_metadata(metadata):
    result = metadata.copy()
    
    # Part 1. Compress tracks/instruments
    if not isinstance(metadata.get('midi'), str): return None
    
    input_path = version_path/metadata['midi']
    extension = input_path.suffix.lower()
    if not input_path.exists(): 
        print('Input path does not exist:', input_path, metadata)
        return result
    
    # Get outfile and check if it exists
    out_file = Path(str(input_path).replace(f'/{source_dir}/', f'/{out_dir}/'))
    out_file = out_file.with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): 
        result['numpy'] = str(out_file.relative_to(version_path))
        return result
    
    npenc = transform_midi(input_path)
    if npenc is None: return result
    np.save(out_file, npenc)
    result['numpy'] = str(out_file.relative_to(version_path))
    return result

# %%
def transform_midi(midi_file):
    input_path = midi_file
    
    if duet_only:
        try: 
            if num_piano_tracks(input_path) != 2: return None
        except Exception: return None
    
    try: input_file = compress_midi_file(input_path, min_variation=min_variation, cutoff=cutoff) # remove non note tracks and standardize instruments
    except Exception as e:
        print('Error parsing midi', input_path, e)
        return None
    if not input_file: return None
        
    # Part 2. Compress rests and long notes
    stream = file2stream(input_file) # 1.
    try:
        chordarr = stream2chordarr(stream, max_dur=DUR_RANGE-2, flat=False) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
    except Exception as e:
        print('Could not encode to chordarr:', input_path, e)
#         print(traceback.format_exc())
        return None
    
    chord_trim = trim_chordarr_rests(chordarr)
    chord_short = shorten_chordarr_rests(chord_trim)
    delta_trim = chord_trim.shape[0] - chord_short.shape[0]
    if delta_trim > 300: 
        print(f'Removed {delta_trim} rests from {input_path}. Skipping song')
        return None
    chordarr = chord_short
    
    _,num_inst,_ = chordarr.shape
    if num_inst != 2: return None
    
    parts = [part_enc(chordarr, i) for i in range(num_inst)]
    
    # Part 3. Chord array to numpy
    if sum([p.shape[0] for p in parts]) < 32:
        print('Sequence too short:', len(seq), input_path)
        return None
    
    return np.array(parts)

# %%
def try_process_metadata(metadata):
    try:
        return process_metadata(metadata)
    except Exception:
#         print(traceback.format_exc())
        return None

# %%
# # sanity check
import random
for r in random.sample(all_records, 10):
    process_metadata(r)

# %%
def timeout_func(data, seconds):
    print("Timeout:", seconds, data.get('midi'))

# %%
processed = process_all(try_process_metadata, all_records, timeout=300, timeout_func=timeout_func)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='192941' class='' max='197182', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       97.85% [192941/197182 1:08:06<01:29]
#     </div>
# Removed 320 rests from data/midi/v15/midi_sources/freemidi/genre-dance-eletric/Fatboy Slim - Right Here Right Now.mid. Skipping song
# Removed 456 rests from data/midi/v15/midi_sources/freemidi/genre-pop/Sade - Siempre Hay Esperanza.mid. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/freemidi/genre-pop/Shakira - Waka Waka.mid. Skipping song
# Removed 544 rests from data/midi/v15/midi_sources/midiworld/named_midi/Tag_Team_-_Whoomp_There_It_Is.mid. Skipping song
# Removed 512 rests from data/midi/v15/midi_sources/midiworld/named_midi/Aerosmith_-_Falling_in_Love_Is_Hard_on_my_Knees.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/midiworld/named_midi/Howlin_Wolf_-_Little_Red_Rooster.mid index 1147 is out of bounds for axis 0 with size 1147
# Could not encode to chordarr: data/midi/v15/midi_sources/midiworld/named_midi/Jelly_Roll_Morton_-_Honky_Tonk_Blues.mid index 2219 is out of bounds for axis 0 with size 2219
# Removed 2064 rests from data/midi/v15/midi_sources/midiworld/named_midi/Metallica_-_One.mid. Skipping song
# Removed 14640 rests from data/midi/v15/midi_sources/midiworld/named_midi/Led_Zeppelin_-_Thank_You.mid. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/midiworld/named_midi/Fatboy_Slim_-_Right_Here_Right_Now.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/from_mxl/ecomp/2017/KaiRuiR10.mid index 3419 is out of bounds for axis 0 with size 3419
# Could not encode to chordarr: data/midi/v15/midi_sources/from_mxl/ecomp/2008/ZhangX03.mid index 1391 is out of bounds for axis 0 with size 1391
# Removed 452 rests from data/midi/v15/midi_sources/from_mxl/ecomp/2008/Denisova12.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Kociuban16.mid index 2419 is out of bounds for axis 0 with size 2419
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_FRLG_Route_1_Theme_Advanced_Version.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_50_Times.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_9_Candy_Constellation_Play_50_Times.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Gym_Piano_Cover.mid
# Timeout: 300 midi_sources/from_mxl/ecomp/2017/KaiRuiR08.mid
# Removed 320 rests from data/midi/v15/midi_sources/from_mxl/ecomp/2006/WongDoe05.mid. Skipping song
# Removed 448 rests from data/midi/v15/midi_sources/from_mxl/ecomp/2009/Erice01.mid. Skipping song
# Removed 616 rests from data/midi/v15/midi_sources/from_mxl/ecomp/2004/SCHU07.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/ecomp/2006/KorchinskayaKogan06.mid
# Timeout: 300 midi_sources/from_mxl/ecomp/2004/YOO07.mid
# Could not encode to chordarr: data/midi/v15/midi_sources/from_mxl/ecomp/2015/LeeN06.mid index 1539 is out of bounds for axis 0 with size 1539
# Removed 388 rests from data/midi/v15/midi_sources/from_mxl/ecomp/2015/LuoJ11.mid. Skipping song
# Removed 696 rests from data/midi/v15/midi_sources/from_mxl/ecomp/2015/LeeN05.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/ecomp/2014/KyykhynenT14.mid
# Could not encode to chordarr: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KaszoS07.mid index 1807 is out of bounds for axis 0 with size 1807
# Could not encode to chordarr: data/midi/v15/midi_sources/from_mxl/classic_piano/muss_1_format0.mid index 1487 is out of bounds for axis 0 with size 1487
# Removed 304 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/8/lis_sprh.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/ecomp/2002/morozov01.mid
# Removed 588 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/023/first_.mid. Skipping song
# Removed 312 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/023/tmsk1307.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/classic_piano/liz_donjuan_format0.mid
# Removed 3084 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/3/tch-pcon-1.mid. Skipping song
# Removed 360 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/012/musnobm.mid. Skipping song
# Removed 1132 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/012/chrlfant.mid. Skipping song
# Removed 1036 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/014/__24310_.mid. Skipping song
# Removed 508 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/9/bjs1046h.mid. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/031/figaro1.mid. Skipping song
# Removed 416 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/2/asfrom.mid. Skipping song
# Removed 484 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/2/btedeum2.mid. Skipping song
# Removed 324 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/032/suite_2.mid. Skipping song
# Removed 480 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/2/ds2pma.mid. Skipping song
# Removed 480 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/2/ds2pmb.mid. Skipping song
# Removed 29328 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/032/donizett.mid. Skipping song
# Removed 29328 rests from data/midi/v15/midi_sources/from_mxl/classical_archives/032/doniz1_2.mid. Skipping song
# Removed 400 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/3033781.mid. Skipping song
# Removed 312 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/714306.mid. Skipping song
# Removed 560 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/4320211.mid. Skipping song
# Removed 536 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/2800711.mid. Skipping song
# Removed 1436 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/2008321.mid. Skipping song
# Removed 728 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/1512706.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/classical_archives/7/mthm26b.mid
# Timeout: 300 midi_sources/from_mxl/classical_archives/7/mthm26d.mid
# Timeout: 300 midi_sources/from_mxl/classical_archives/9/brop24.mid
# Removed 528 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/1873581.mid. Skipping song
# Removed 1016 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/1817086.mid. Skipping song
# Removed 1016 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/1817106.mid. Skipping song
# Removed 952 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/5214948.mid. Skipping song
# Removed 312 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/1452511.mid. Skipping song
# Removed 328 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/2260596.mid. Skipping song
# Removed 420 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/4701591.mid. Skipping song
# Removed 316 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/4800687.mid. Skipping song
# Removed 512 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/439486.mid. Skipping song
# Removed 724 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/5306485.mid. Skipping song
# Removed 1244 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/5277373.mid. Skipping song
# Removed 424 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/5200032.mid. Skipping song
# Removed 484 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/5309120.mid. Skipping song
# Removed 312 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/534786.mid. Skipping song
# Removed 484 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/5303817.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/musescore/data/4453696.mid
# Could not encode to chordarr: data/midi/v15/midi_sources/lmd_clean/Jennifer Lopez/Let's Get Loud.1.mid index 2087 is out of bounds for axis 0 with size 2087
# Timeout: 300 midi_sources/from_mxl/musescore/data/1984571.mid
# Timeout: 300 midi_sources/from_mxl/musescore/data/2119261.mid
# Could not encode to chordarr: data/midi/v15/midi_sources/lmd_clean/Blondie/Dreaming.mid
# Timeout: 300 midi_sources/from_mxl/musescore/data/1671046.mid
# Timeout: 300 midi_sources/from_mxl/musescore/data/48072.mid
# Removed 532 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/1481516.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/musescore/data/1188146.mid
# Timeout: 300 midi_sources/from_mxl/musescore/data/2638111.mid
# Removed 368 rests from data/midi/v15/midi_sources/lmd_clean/The Prodigy/Breath.1.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/musescore/data/2279591.mid
# Timeout: 300 midi_sources/from_mxl/musescore/data/2430311.mid
# Removed 632 rests from data/midi/v15/midi_sources/lmd_clean/The Beatles/Tomorrow Never Knows.2.mid. Skipping song
# Removed 888 rests from data/midi/v15/midi_sources/lmd_clean/Carmina Burana/O Fortuna.mid. Skipping song
# Removed 532 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/58146.mid. Skipping song
# Removed 580 rests from data/midi/v15/midi_sources/lmd_clean/Genesis/Supper's Ready.mid. Skipping song
# Removed 416 rests from data/midi/v15/midi_sources/lmd_clean/Black Sabbath/War Pigs.1.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/musescore/data/2445146.mid
# Removed 416 rests from data/midi/v15/midi_sources/lmd_clean/Black Sabbath/War Pigs.mid. Skipping song
# Removed 888 rests from data/midi/v15/midi_sources/lmd_clean/Jeffrey Reid Baker/Carmina Burana: Fortuna Imperatrix mundi: I. O Fortuna.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/musescore/data/189697.mid
# Removed 456 rests from data/midi/v15/midi_sources/lmd_clean/Sade/Siempre Hay Esperanza.mid. Skipping song
# Removed 352 rests from data/midi/v15/midi_sources/lmd_clean/Michael George/Freedom 90.mid. Skipping song
# Removed 3212 rests from data/midi/v15/midi_sources/lmd_clean/Gershwin/Rhapsody in Blue.mid. Skipping song
# Removed 360 rests from data/midi/v15/midi_sources/from_mxl/musescore/data/5034061.mid. Skipping song
# Removed 3460 rests from data/midi/v15/midi_sources/lmd_clean/LIGABUE/Ho messo via.mid. Skipping song
# Timeout: 300 midi_sources/from_mxl/musescore/data/899556.mid
# Timeout: 300 midi_sources/from_mxl/musescore/data/760356.mid
# Removed 348 rests from data/midi/v15/midi_sources/130k_reddit/O/O/o_spirit.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/O/O/O'Scarrafone.mid index 1807 is out of bounds for axis 0 with size 1807
# Removed 476 rests from data/midi/v15/midi_sources/130k_reddit/N/N/nickelback-too_bad.mid. Skipping song
# Removed 396 rests from data/midi/v15/midi_sources/130k_reddit/B/B/BIG JAM.Mueve la cintura (mambo).mid. Skipping song
# Removed 576 rests from data/midi/v15/midi_sources/130k_reddit/B/B/basshunter-dota.mid. Skipping song
# Removed 336 rests from data/midi/v15/midi_sources/130k_reddit/N/N/namorados.mid. Skipping song
# Removed 364 rests from data/midi/v15/midi_sources/130k_reddit/B/B/Boney-M-Nr-3-(Medley).mid. Skipping song
# Removed 496 rests from data/midi/v15/midi_sources/130k_reddit/B/B/brazil_hino.mid. Skipping song
# Removed 43140 rests from data/midi/v15/midi_sources/130k_reddit/B/B/BONEY.MID. Skipping song
# Removed 748 rests from data/midi/v15/midi_sources/130k_reddit/L/L/lock_n_load__blow_ya_mind__chris_hodder.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/Guitar_midkar.com_MIDIRip/jazz/snakes_ra.mid index 2443 is out of bounds for axis 0 with size 2443
# Removed 324 rests from data/midi/v15/midi_sources/130k_reddit/Guitar_midkar.com_MIDIRip/classical/on_the_trail-Ferde-Grofe_rcg.mid. Skipping song
# Removed 312 rests from data/midi/v15/midi_sources/130k_reddit/M/M/missimp2.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/M/M/MyGuy.mid index 1795 is out of bounds for axis 0 with size 1795
# Removed 476 rests from data/midi/v15/midi_sources/130k_reddit/J/J/jammin.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/F/F/foxtrot1.mid index 519 is out of bounds for axis 0 with size 519
# Removed 460 rests from data/midi/v15/midi_sources/130k_reddit/F/F/flash2.mid. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/130k_reddit/F/F/fatboy_slim-right_here.mid. Skipping song
# Removed 2024 rests from data/midi/v15/midi_sources/130k_reddit/Guitar_midkar.com_MIDIRip/classical/grand_canyon_suite-Ferde-Grofe-1931_rcg.mid. Skipping song
# Removed 672 rests from data/midi/v15/midi_sources/130k_reddit/Dub_MIDIRip/messian_dread_babylon_unmasked/14_WaDaDa_Peace_and_Love_Dub.mid. Skipping song
# Removed 368 rests from data/midi/v15/midi_sources/130k_reddit/Metal_Rock_rock.freemidis.net_MIDIRip/midi/m/megadeth/Trust.mid. Skipping song
# Removed 612 rests from data/midi/v15/midi_sources/130k_reddit/Dub_MIDIRip/messian_dread_babylon_unmasked/01_Visions_of_Jah.mid. Skipping song
# Removed 1508 rests from data/midi/v15/midi_sources/130k_reddit/Dub_MIDIRip/messian_dread_babylon_unmasked/12_come_in_the_One_Drop.mid. Skipping song
# Removed 1140 rests from data/midi/v15/midi_sources/130k_reddit/Metal_Rock_rock.freemidis.net_MIDIRip/midi/g/green_day/Homecoming.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Czerny/Etude Op.740 No.9.mid index 991 is out of bounds for axis 0 with size 991
# Removed 444 rests from data/midi/v15/midi_sources/130k_reddit/C/C/Crematory - Tears Of Time.mid. Skipping song
# Removed 364 rests from data/midi/v15/midi_sources/130k_reddit/5/5513_MUS.MID. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/130k_reddit/A/A/Aeriths_Theme2.mid. Skipping song
# Removed 368 rests from data/midi/v15/midi_sources/130k_reddit/A/A/alsnow.mid. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/130k_reddit/A/A/aeris03.mid. Skipping song
# Timeout: 300 midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Brahms/Concerto for Piano n1 op15 1mov.mid
# Timeout: 300 midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Bach/Bwv1080 The Art Of Fugue/The Art of the Fugue BWV1080.mid
# Removed 764 rests from data/midi/v15/midi_sources/130k_reddit/V/V/vodoo2.mid. Skipping song
# Removed 408 rests from data/midi/v15/midi_sources/130k_reddit/D/D/dadada2.mid. Skipping song
# Timeout: 300 midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Schumann/8 Fantaisies Kreisleriana op16.mid
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/D/D/Doowop.mid index 783 is out of bounds for axis 0 with size 783
# Removed 432 rests from data/midi/v15/midi_sources/130k_reddit/D/D/Darklich.mid. Skipping song
# Removed 376 rests from data/midi/v15/midi_sources/130k_reddit/Classical_Piano_piano-midi.de_MIDIRip/moszkowski/mos_op36_6.mid. Skipping song
# Removed 304 rests from data/midi/v15/midi_sources/130k_reddit/G/G/givethanks08.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/G/G/game05.mid index 775 is out of bounds for axis 0 with size 775
# Removed 580 rests from data/midi/v15/midi_sources/130k_reddit/7/72-06-supper1.mid. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/130k_reddit/G/G/godavida.mid. Skipping song
# Removed 1140 rests from data/midi/v15/midi_sources/130k_reddit/G/G/green_day-homecoming.mid. Skipping song
# Removed 748 rests from data/midi/v15/midi_sources/130k_reddit/U/U/unchain_my_heart.mid. Skipping song
# Timeout: 300 midi_sources/130k_reddit/C/C/conc_bf.mid
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/G/G/gloria_estefan-hoy_version_salsa.mid index 1487 is out of bounds for axis 0 with size 1487
# Removed 484 rests from data/midi/v15/midi_sources/130k_reddit/G/G/gfr53-c02-1.mid. Skipping song
# Removed 580 rests from data/midi/v15/midi_sources/130k_reddit/7/72-06-supper2xg.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/H/H/happyorgan2.mid index 859 is out of bounds for axis 0 with size 859
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/H/H/happyorgan.mid index 859 is out of bounds for axis 0 with size 859
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/I/I/i_ran.mid
# Removed 312 rests from data/midi/v15/midi_sources/130k_reddit/I/I/ifiruled.mid. Skipping song
# Removed 7144 rests from data/midi/v15/midi_sources/130k_reddit/I/I/It'sHop.mid. Skipping song
# Removed 320 rests from data/midi/v15/midi_sources/130k_reddit/I/I/innagoddadavita.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/S/S/s2jazz.mid index 455 is out of bounds for axis 0 with size 455
# Removed 660 rests from data/midi/v15/midi_sources/130k_reddit/S/S/shirin.mid. Skipping song
# Removed 336 rests from data/midi/v15/midi_sources/130k_reddit/S/S/sayonara3.mid. Skipping song
# Removed 304 rests from data/midi/v15/midi_sources/130k_reddit/S/S/shakira-waka_waka_version_with_melody.mid. Skipping song
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/S/S/spfc.mid
# Removed 696 rests from data/midi/v15/midi_sources/130k_reddit/S/S/sing06.mid. Skipping song
# Timeout: 300 midi_sources/130k_reddit/AMERICANA_FOLK_www.pdmusic.org_MIDIRip/heinrich/aph20tdmaaoa.mid
# Removed 744 rests from data/midi/v15/midi_sources/130k_reddit/1/118UNMEX.MID. Skipping song
# Removed 460 rests from data/midi/v15/midi_sources/130k_reddit/1/1radarlv.mid. Skipping song
# Removed 364 rests from data/midi/v15/midi_sources/130k_reddit/T/T/The_Relic.mid. Skipping song
# Removed 10812 rests from data/midi/v15/midi_sources/130k_reddit/T/T/ToccataAndFugue6.mid. Skipping song
# Timeout: 300 midi_sources/130k_reddit/AMERICANA_FOLK_www.pdmusic.org_MIDIRip/hewitt/jhh51rvw1.mid
# Could not encode to chordarr: data/midi/v15/midi_sources/130k_reddit/R/R/redroost.mid index 1147 is out of bounds for axis 0 with size 1147
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
arr2csv(processed, out_csv); len(processed)
# Out:
# 196393

# %%
df = pd.read_csv(out_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7,8,12,13,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        source  ht_mode                title        artist  ht_time_signature  \
# 0  hooktheory      1.0  yu-gi-oh-theme-song  wayne-sharpe                4.0
# 1  hooktheory      1.0  yu-gi-oh-theme-song  wayne-sharpe                3.0
# 2  hooktheory      6.0               kiefer    what-a-day                4.0
# 3  hooktheory      6.0         senbonzakura    whiteflame                4.0
# 4  hooktheory      6.0         senbonzakura    whiteflame                4.0
#
#    ht_offset  ht_bpm ht_key  mxl  \
# 0        0.0   128.0      C  NaN
# 1        0.0    85.0      C  NaN
# 2       -5.0    96.0      D  NaN
# 3       -5.0   152.0      D  NaN
# 4       -5.0   152.0      D  NaN
#
#                                                 midi     genres  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...        NaN
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...        NaN
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...       Jazz
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  J-Pop,Pop
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...  J-Pop,Pop
#
#                                                numpy  \
# 0  s2s_encode/hooktheory/pianoroll/w/wayne-sharpe...
# 1                                                NaN
# 2  s2s_encode/hooktheory/pianoroll/w/what-a-day/k...
# 3  s2s_encode/hooktheory/pianoroll/w/whiteflame/s...
# 4  s2s_encode/hooktheory/pianoroll/w/whiteflame/s...
#
#                                             song_url     section  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...      chorus
# 1  https://www.hooktheory.com/theorytab/view/wayn...       intro
# 2  https://www.hooktheory.com/theorytab/view/what...      chorus
# 3  https://www.hooktheory.com/theorytab/view/whit...  pre-chorus
# 4  https://www.hooktheory.com/theorytab/view/whit...       verse
#
#                                 md5                    parts  \
# 0  bf1f29e5ff84e3e93e37fb873bfb590e             intro,chorus
# 1  055f80ad67f64edb14a85ca8fbfe8c29             intro,chorus
# 2  197f96f5d181f6ce1e2c5ab04ac1ff87                   chorus
# 3  9e7ce13a35f1314423a9a6d5a5287a4a  verse,pre-chorus,chorus
# 4  d5aaf79d0989222f1362f9f46c540a27  verse,pre-chorus,chorus
#
#                       midi_title
# 0                      yu-gi-oh3
# 1                       yu-gi-oh
# 2                         kiefer
# 3  senbonzakura - pre-Pre-Chorus
# 4                   Senbonzakura

# %%
len([f for f in df.numpy.values if isinstance(f, str)])
# Out:
# 39619

# %%
from collections import Counter

# %%
df[df.numpy.notnull()]
# Out:
#               source  ht_mode                           title  \
# 0         hooktheory      1.0             yu-gi-oh-theme-song
# 2         hooktheory      6.0                          kiefer
# 3         hooktheory      6.0                    senbonzakura
# 4         hooktheory      6.0                    senbonzakura
# 5         hooktheory      6.0                    senbonzakura
# 6         hooktheory      1.0                  last-christmas
# 7         hooktheory      1.0                  last-christmas
# 8         hooktheory      1.0                  last-christmas
# 9         hooktheory      1.0                         freedom
# 11        hooktheory      1.0                 west-wing-suite
# 14        hooktheory      NaN                 blue-eyes-cryin
# 15        hooktheory      1.0      you-were-always-on-my-mind
# 16        hooktheory      1.0         family-guy---theme-song
# 17        hooktheory      1.0       american-dad---theme-song
# 18        hooktheory      1.0                the-freaking-fcc
# 19        hooktheory      1.0                the-freaking-fcc
# 20        hooktheory      6.0                 rainbow-factory
# 21        hooktheory      6.0                 rainbow-factory
# 22        hooktheory      6.0               beyond-her-garden
# 23        hooktheory      6.0                 nightmare-night
# 24        hooktheory      6.0                 nightmare-night
# 25        hooktheory      6.0                  piercing-light
# 26        hooktheory      6.0                  piercing-light
# 27        hooktheory      6.0                        no-hands
# 28        hooktheory      1.0                    fat-labrador
# 29        hooktheory      1.0                         donkeys
# 31        hooktheory      6.0                   amazing-horse
# 32        hooktheory      6.0                   amazing-horse
# 33        hooktheory      6.0                            owls
# 34        hooktheory      1.0                            owls
# ...              ...      ...                             ...
# 196360  hooktheory_c      1.0                       superstar
# 196361  hooktheory_c      1.0                       superstar
# 196363  hooktheory_c      1.0                         igniter
# 196364  hooktheory_c      1.0                       champions
# 196365  hooktheory_c      1.0                sun-in-your-eyes
# 196366  hooktheory_c      1.0                     anjunabeach
# 196368  hooktheory_c      1.0     good-for-me---ambient-mix--
# 196369  hooktheory_c      1.0     good-for-me---ambient-mix--
# 196370  hooktheory_c      1.0     good-for-me---ambient-mix--
# 196371  hooktheory_c      1.0                          always
# 196372  hooktheory_c      1.0                    sun-and-moon
# 196374  hooktheory_c      1.0  tightrope-feat-marty-longstaff
# 196375  hooktheory_c      1.0           lovelight---bad-apple
# 196376  hooktheory_c      1.0           lovelight---bad-apple
# 196377  hooktheory_c      1.0           lovelight---bad-apple
# 196378  hooktheory_c      1.0                       bad-apple
# 196379  hooktheory_c      1.0               hand-in-my-pocket
# 196380  hooktheory_c      1.0                          ironic
# 196381  hooktheory_c      1.0                       you-learn
# 196382  hooktheory_c      1.0                       uninvited
# 196383  hooktheory_c      1.0                       uninvited
# 196384  hooktheory_c      1.0                       thank-you
# 196385  hooktheory_c      1.0                  head-over-feet
# 196386  hooktheory_c      1.0                  head-over-feet
# 196387  hooktheory_c      1.0                 you-oughta-know
# 196388  hooktheory_c      1.0                     dannys-song
# 196389  hooktheory_c      1.0                     dannys-song
# 196390  hooktheory_c      1.0                        only-one
# 196391  hooktheory_c      1.0                       promise-u
# 196392  hooktheory_c      1.0                          famous
#
#                                 artist  ht_time_signature  ht_offset  ht_bpm  \
# 0                         wayne-sharpe                4.0        0.0   128.0
# 2                           what-a-day                4.0       -5.0    96.0
# 3                           whiteflame                4.0       -5.0   152.0
# 4                           whiteflame                4.0       -5.0   152.0
# 5                           whiteflame                4.0       -5.0   152.0
# 6                                 wham                4.0       -1.0   108.0
# 7                                 wham                4.0       -1.0   108.0
# 8                                 wham                4.0       -1.0   108.0
# 9                                 wham                4.0        0.0   128.0
# 11                    wg-snuffy-walden                4.0        5.0    86.0
# 14                       willie-nelson                4.0       -4.0    58.0
# 15                       willie-nelson                4.0       -2.0    68.0
# 16                       walter-murphy                4.0       -5.0   128.0
# 17                       walter-murphy                4.0        2.0   149.0
# 18                       walter-murphy                4.0        0.0   126.0
# 19                       walter-murphy                4.0        0.0   126.0
# 20                       woodentoaster                4.0        3.0   148.0
# 21                       woodentoaster                4.0        3.0   148.0
# 22                       woodentoaster                4.0        1.0   131.0
# 23                       woodentoaster                4.0       -5.0   197.0
# 24                       woodentoaster                4.0       -5.0   197.0
# 25                            warsongs                4.0       -5.0   125.0
# 26                            warsongs                4.0       -5.0   125.0
# 27                   waka-flocka-flame                4.0       -4.0   124.0
# 28                               weebl                4.0       -4.0   138.0
# 29                               weebl                4.0        1.0   140.0
# 31                               weebl                4.0        3.0   149.0
# 32                               weebl                4.0        3.0   149.0
# 33                               weebl                4.0        0.0   146.0
# 34                               weebl                4.0        3.0   146.0
# ...                                ...                ...        ...     ...
# 196360                        a-g-cook                4.0        0.0   120.0
# 196361                        a-g-cook                4.0        0.0   128.0
# 196363                      ark-patrol                4.0        0.0   149.0
# 196364  astronaut-ft--harry-brooks-jnr                4.0        0.0   128.0
# 196365                above-and-beyond                4.0        0.0   128.0
# 196366                above-and-beyond                4.0        0.0    66.0
# 196368                above-and-beyond                4.0        0.0   130.0
# 196369                above-and-beyond                4.0        0.0   130.0
# 196370                above-and-beyond                4.0        0.0   130.0
# 196371                above-and-beyond                4.0        0.0    65.0
# 196372                above-and-beyond                4.0        0.0   128.0
# 196374                above-and-beyond                4.0        0.0    64.0
# 196375            alstroemeria-records                4.0        0.0   138.0
# 196376            alstroemeria-records                4.0        0.0   138.0
# 196377            alstroemeria-records                4.0        0.0   138.0
# 196378            alstroemeria-records                4.0        0.0   149.0
# 196379               alanis-morissette                4.0        0.0    92.0
# 196380               alanis-morissette                4.0        0.0    86.0
# 196381               alanis-morissette                4.0        0.0    84.0
# 196382               alanis-morissette                4.0        0.0    62.0
# 196383               alanis-morissette                4.0        0.0    64.0
# 196384               alanis-morissette                4.0        0.0    92.0
# 196385               alanis-morissette                4.0        0.0    85.0
# 196386               alanis-morissette                4.0        0.0    80.0
# 196387               alanis-morissette                4.0        0.0   104.0
# 196388                     anne-murray                4.0        0.0    72.0
# 196389                     anne-murray                4.0        0.0    74.0
# 196390                           apink                4.0        0.0   102.0
# 196391                           apink                4.0        0.0    70.0
# 196392                          archie                4.0        0.0   128.0
#
#        ht_key  mxl                                               midi  \
# 0           C  NaN  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 2           D  NaN  midi_sources/hooktheory/pianoroll/w/what-a-day...
# 3           D  NaN  midi_sources/hooktheory/pianoroll/w/whiteflame...
# 4           D  NaN  midi_sources/hooktheory/pianoroll/w/whiteflame...
# 5           D  NaN  midi_sources/hooktheory/pianoroll/w/whiteflame...
# 6          Db  NaN  midi_sources/hooktheory/pianoroll/w/wham/last-...
# 7          Db  NaN  midi_sources/hooktheory/pianoroll/w/wham/last-...
# 8          Db  NaN  midi_sources/hooktheory/pianoroll/w/wham/last-...
# 9           C  NaN  midi_sources/hooktheory/pianoroll/w/wham/freed...
# 11          G  NaN  midi_sources/hooktheory/pianoroll/w/wg-snuffy-...
# 14          E  NaN  midi_sources/hooktheory/pianoroll/w/willie-nel...
# 15          D  NaN  midi_sources/hooktheory/pianoroll/w/willie-nel...
# 16          F  NaN  midi_sources/hooktheory/pianoroll/w/walter-mur...
# 17         Bb  NaN  midi_sources/hooktheory/pianoroll/w/walter-mur...
# 18          C  NaN  midi_sources/hooktheory/pianoroll/w/walter-mur...
# 19          C  NaN  midi_sources/hooktheory/pianoroll/w/walter-mur...
# 20         F#  NaN  midi_sources/hooktheory/pianoroll/w/woodentoas...
# 21         F#  NaN  midi_sources/hooktheory/pianoroll/w/woodentoas...
# 22         G#  NaN  midi_sources/hooktheory/pianoroll/w/woodentoas...
# 23          D  NaN  midi_sources/hooktheory/pianoroll/w/woodentoas...
# 24          D  NaN  midi_sources/hooktheory/pianoroll/w/woodentoas...
# 25          D  NaN  midi_sources/hooktheory/pianoroll/w/warsongs/p...
# 26          D  NaN  midi_sources/hooktheory/pianoroll/w/warsongs/p...
# 27         C#  NaN  midi_sources/hooktheory/pianoroll/w/waka-flock...
# 28          E  NaN  midi_sources/hooktheory/pianoroll/w/weebl/fat-...
# 29          B  NaN  midi_sources/hooktheory/pianoroll/w/weebl/donk...
# 31         F#  NaN  midi_sources/hooktheory/pianoroll/w/weebl/amaz...
# 32         F#  NaN  midi_sources/hooktheory/pianoroll/w/weebl/amaz...
# 33          A  NaN  midi_sources/hooktheory/pianoroll/w/weebl/owls...
# 34          A  NaN  midi_sources/hooktheory/pianoroll/w/weebl/owls...
# ...       ...  ...                                                ...
# 196360      C  NaN  midi_sources/hooktheory/pianoroll/a/a-g-cook/s...
# 196361      C  NaN  midi_sources/hooktheory/pianoroll/a/a-g-cook/s...
# 196363      C  NaN  midi_sources/hooktheory/pianoroll/a/ark-patrol...
# 196364      C  NaN  midi_sources/hooktheory/pianoroll/a/astronaut-...
# 196365      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196366      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196368      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196369      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196370      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196371      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196372      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196374      C  NaN  midi_sources/hooktheory/pianoroll/a/above-and-...
# 196375      C  NaN  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196376      C  NaN  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196377      C  NaN  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196378      C  NaN  midi_sources/hooktheory/pianoroll/a/alstroemer...
# 196379      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196380      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196381      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196382      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196383      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196384      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196385      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196386      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196387      C  NaN  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196388      C  NaN  midi_sources/hooktheory/pianoroll/a/anne-murra...
# 196389      C  NaN  midi_sources/hooktheory/pianoroll/a/anne-murra...
# 196390      C  NaN  midi_sources/hooktheory/pianoroll/a/apink/only...
# 196391      C  NaN  midi_sources/hooktheory/pianoroll/a/apink/prom...
# 196392      C  NaN  midi_sources/hooktheory/pianoroll/a/archie/fam...
#
#                                     genres  \
# 0                                      NaN
# 2                                     Jazz
# 3                                J-Pop,Pop
# 4                                J-Pop,Pop
# 5                                J-Pop,Pop
# 6                                  Holiday
# 7                                  Holiday
# 8                                  Holiday
# 9                                      NaN
# 11                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                         Jazz,Soundtrack
# 17                              Soundtrack
# 18                              Soundtrack
# 19                              Soundtrack
# 20                              Electronic
# 21                              Electronic
# 22                                     NaN
# 23                 Alt-Country,Hip-Hop/Rap
# 24                 Alt-Country,Hip-Hop/Rap
# 25                                     NaN
# 26                                     NaN
# 27                             Hip-Hop/Rap
# 28                                     NaN
# 29                                     NaN
# 31                                     NaN
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
# ...                                    ...
# 196360               Pop,Singer-Songwriter
# 196361               Pop,Singer-Songwriter
# 196363                          Electronic
# 196364                          Electronic
# 196365                                 NaN
# 196366                          Electronic
# 196368                          Electronic
# 196369                          Electronic
# 196370                          Electronic
# 196371                          Electronic
# 196372                                 NaN
# 196374                                 NaN
# 196375                               J-Pop
# 196376                               J-Pop
# 196377                               J-Pop
# 196378                          Video Game
# 196379  Alternative,Rock,Singer-Songwriter
# 196380                            Pop,Rock
# 196381                Alternative,Pop,Rock
# 196382                         Alternative
# 196383                         Alternative
# 196384  Alternative,Rock,Singer-Songwriter
# 196385                                 NaN
# 196386                                 NaN
# 196387                    Alternative,Rock
# 196388                                Folk
# 196389                                Folk
# 196390                               K-pop
# 196391                               K-pop
# 196392                          Electronic
#
#                                                     numpy  \
# 0       s2s_encode/hooktheory/pianoroll/w/wayne-sharpe...
# 2       s2s_encode/hooktheory/pianoroll/w/what-a-day/k...
# 3       s2s_encode/hooktheory/pianoroll/w/whiteflame/s...
# 4       s2s_encode/hooktheory/pianoroll/w/whiteflame/s...
# 5       s2s_encode/hooktheory/pianoroll/w/whiteflame/s...
# 6       s2s_encode/hooktheory/pianoroll/w/wham/last-ch...
# 7       s2s_encode/hooktheory/pianoroll/w/wham/last-ch...
# 8       s2s_encode/hooktheory/pianoroll/w/wham/last-ch...
# 9       s2s_encode/hooktheory/pianoroll/w/wham/freedom...
# 11      s2s_encode/hooktheory/pianoroll/w/wg-snuffy-wa...
# 14      s2s_encode/hooktheory/pianoroll/w/willie-nelso...
# 15      s2s_encode/hooktheory/pianoroll/w/willie-nelso...
# 16      s2s_encode/hooktheory/pianoroll/w/walter-murph...
# 17      s2s_encode/hooktheory/pianoroll/w/walter-murph...
# 18      s2s_encode/hooktheory/pianoroll/w/walter-murph...
# 19      s2s_encode/hooktheory/pianoroll/w/walter-murph...
# 20      s2s_encode/hooktheory/pianoroll/w/woodentoaste...
# 21      s2s_encode/hooktheory/pianoroll/w/woodentoaste...
# 22      s2s_encode/hooktheory/pianoroll/w/woodentoaste...
# 23      s2s_encode/hooktheory/pianoroll/w/woodentoaste...
# 24      s2s_encode/hooktheory/pianoroll/w/woodentoaste...
# 25      s2s_encode/hooktheory/pianoroll/w/warsongs/pie...
# 26      s2s_encode/hooktheory/pianoroll/w/warsongs/pie...
# 27      s2s_encode/hooktheory/pianoroll/w/waka-flocka-...
# 28      s2s_encode/hooktheory/pianoroll/w/weebl/fat-la...
# 29      s2s_encode/hooktheory/pianoroll/w/weebl/donkey...
# 31      s2s_encode/hooktheory/pianoroll/w/weebl/amazin...
# 32      s2s_encode/hooktheory/pianoroll/w/weebl/amazin...
# 33      s2s_encode/hooktheory/pianoroll/w/weebl/owls/v...
# 34      s2s_encode/hooktheory/pianoroll/w/weebl/owls/o...
# ...                                                   ...
# 196360  s2s_encode/hooktheory/pianoroll/a/a-g-cook/sup...
# 196361  s2s_encode/hooktheory/pianoroll/a/a-g-cook/sup...
# 196363  s2s_encode/hooktheory/pianoroll/a/ark-patrol/i...
# 196364  s2s_encode/hooktheory/pianoroll/a/astronaut-ft...
# 196365  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196366  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196368  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196369  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196370  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196371  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196372  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196374  s2s_encode/hooktheory/pianoroll/a/above-and-be...
# 196375  s2s_encode/hooktheory/pianoroll/a/alstroemeria...
# 196376  s2s_encode/hooktheory/pianoroll/a/alstroemeria...
# 196377  s2s_encode/hooktheory/pianoroll/a/alstroemeria...
# 196378  s2s_encode/hooktheory/pianoroll/a/alstroemeria...
# 196379  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196380  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196381  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196382  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196383  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196384  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196385  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196386  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196387  s2s_encode/hooktheory/pianoroll/a/alanis-moris...
# 196388  s2s_encode/hooktheory/pianoroll/a/anne-murray/...
# 196389  s2s_encode/hooktheory/pianoroll/a/anne-murray/...
# 196390  s2s_encode/hooktheory/pianoroll/a/apink/only-o...
# 196391  s2s_encode/hooktheory/pianoroll/a/apink/promis...
# 196392  s2s_encode/hooktheory/pianoroll/a/archie/famou...
#
#                                                  song_url  \
# 0       https://www.hooktheory.com/theorytab/view/wayn...
# 2       https://www.hooktheory.com/theorytab/view/what...
# 3       https://www.hooktheory.com/theorytab/view/whit...
# 4       https://www.hooktheory.com/theorytab/view/whit...
# 5       https://www.hooktheory.com/theorytab/view/whit...
# 6       https://www.hooktheory.com/theorytab/view/wham...
# 7       https://www.hooktheory.com/theorytab/view/wham...
# 8       https://www.hooktheory.com/theorytab/view/wham...
# 9       https://www.hooktheory.com/theorytab/view/wham...
# 11      https://www.hooktheory.com/theorytab/view/wg-s...
# 14      https://www.hooktheory.com/theorytab/view/will...
# 15      https://www.hooktheory.com/theorytab/view/will...
# 16      https://www.hooktheory.com/theorytab/view/walt...
# 17      https://www.hooktheory.com/theorytab/view/walt...
# 18      https://www.hooktheory.com/theorytab/view/walt...
# 19      https://www.hooktheory.com/theorytab/view/walt...
# 20      https://www.hooktheory.com/theorytab/view/wood...
# 21      https://www.hooktheory.com/theorytab/view/wood...
# 22      https://www.hooktheory.com/theorytab/view/wood...
# 23      https://www.hooktheory.com/theorytab/view/wood...
# 24      https://www.hooktheory.com/theorytab/view/wood...
# 25      https://www.hooktheory.com/theorytab/view/wars...
# 26      https://www.hooktheory.com/theorytab/view/wars...
# 27      https://www.hooktheory.com/theorytab/view/waka...
# 28      https://www.hooktheory.com/theorytab/view/weeb...
# 29      https://www.hooktheory.com/theorytab/view/weeb...
# 31      https://www.hooktheory.com/theorytab/view/weeb...
# 32      https://www.hooktheory.com/theorytab/view/weeb...
# 33      https://www.hooktheory.com/theorytab/view/weeb...
# 34      https://www.hooktheory.com/theorytab/view/weeb...
# ...                                                   ...
# 196360  https://www.hooktheory.com/theorytab/view/a-g-...
# 196361  https://www.hooktheory.com/theorytab/view/a-g-...
# 196363  https://www.hooktheory.com/theorytab/view/ark-...
# 196364  https://www.hooktheory.com/theorytab/view/astr...
# 196365  https://www.hooktheory.com/theorytab/view/abov...
# 196366  https://www.hooktheory.com/theorytab/view/abov...
# 196368  https://www.hooktheory.com/theorytab/view/abov...
# 196369  https://www.hooktheory.com/theorytab/view/abov...
# 196370  https://www.hooktheory.com/theorytab/view/abov...
# 196371  https://www.hooktheory.com/theorytab/view/abov...
# 196372  https://www.hooktheory.com/theorytab/view/abov...
# 196374  https://www.hooktheory.com/theorytab/view/abov...
# 196375  https://www.hooktheory.com/theorytab/view/alst...
# 196376  https://www.hooktheory.com/theorytab/view/alst...
# 196377  https://www.hooktheory.com/theorytab/view/alst...
# 196378  https://www.hooktheory.com/theorytab/view/alst...
# 196379  https://www.hooktheory.com/theorytab/view/alan...
# 196380  https://www.hooktheory.com/theorytab/view/alan...
# 196381  https://www.hooktheory.com/theorytab/view/alan...
# 196382  https://www.hooktheory.com/theorytab/view/alan...
# 196383  https://www.hooktheory.com/theorytab/view/alan...
# 196384  https://www.hooktheory.com/theorytab/view/alan...
# 196385  https://www.hooktheory.com/theorytab/view/alan...
# 196386  https://www.hooktheory.com/theorytab/view/alan...
# 196387  https://www.hooktheory.com/theorytab/view/alan...
# 196388  https://www.hooktheory.com/theorytab/view/anne...
# 196389  https://www.hooktheory.com/theorytab/view/anne...
# 196390  https://www.hooktheory.com/theorytab/view/apin...
# 196391  https://www.hooktheory.com/theorytab/view/apin...
# 196392  https://www.hooktheory.com/theorytab/view/arch...
#
#                       section                               md5  \
# 0                      chorus  bf1f29e5ff84e3e93e37fb873bfb590e
# 2                      chorus  197f96f5d181f6ce1e2c5ab04ac1ff87
# 3                  pre-chorus  9e7ce13a35f1314423a9a6d5a5287a4a
# 4                       verse  d5aaf79d0989222f1362f9f46c540a27
# 5                      chorus  e0c189ee753b30c4758d85211f13c189
# 6                       verse  38e38402443506e326b76536e8e327a0
# 7                      chorus  75d0251177c8c1fa9a02821299fa5ba8
# 8                       intro  83d2a800f40aeca07e30e4718cda8fe5
# 9                      chorus  60fa29cfec107df27b053cf9708823d5
# 11               instrumental  a856dff6c54398544c217104d047abe0
# 14                     chorus  efe067debf4ba033a81b386b56a11b12
# 15                      verse  dbdf71cfb5941bfd7684bfc4fb76951a
# 16                     chorus  07fe0adbcf00ce06bfe166b66036d897
# 17                     chorus  1d78ebcb686b399adf74964103b41f7a
# 18            intro-and-verse  d8b94e560404a9cde7fa3ec4e8effaef
# 19                     bridge  fb7186e6ed193957e7af640656c19c46
# 20                     bridge  c251b5ac5dc4ef2b4bbc04470c14fa32
# 21                      intro  e3e30de1a19e92a7637b4fadcd45de00
# 22                      verse  573ea20728eb397360f2294345411c2a
# 23               instrumental  09cb8fdc3215c58befd326b9853e80b5
# 24                     chorus  7f6664a1dd32aa2561bdb4e7e2ff46c6
# 25            intro-and-verse  72ef530a972e28727262573858ae2eb8
# 26                     chorus  9de63b58994e36fe03aa27e632c9905c
# 27                     chorus  05de06f3fed030cd7ff64a9cad9fa97c
# 28                     chorus  a6c7a09bb1cb077b747f037dbc9f53fb
# 29                      verse  3cdbc08e4885c24e083555cb57556faa
# 31                     bridge  a129f68e6b95f029539b54250260962a
# 32                     chorus  e7d284f8b65d191b823b0c4823c0d2d1
# 33                      verse  7d4935f39a788dea1211b6d96f7f4ccc
# 34                      outro  4d27a08f9f5370a042b17cdb60b3c8ef
# ...                       ...                               ...
# 196360                 chorus  5123b47b0e295721ade01e3305c265f7
# 196361  pre-chorus-and-chorus  d78504eaaf8230e0e66aa3354a4036ad
# 196363                 chorus  63b6eec1747db57d7482dec99efa4dc3
# 196364                 chorus  3f82e703b67bc25b290e65363138dab1
# 196365                  verse  343e5622f817bd5396196c7e497d1538
# 196366                 chorus  785211e4c31b03268b38346d03a63513
# 196368                 chorus  cd1ebf2487b7a5eda634fb2df4c51c49
# 196369                  verse  285d3d0cfd4625e1c0f14eda357dc795
# 196370                  intro  ab0905123ecaed999cfa5a39a053e56a
# 196371                 chorus  52f99c8789e54123de7cc7fd8da45f02
# 196372             pre-chorus  3694ce098cfc1256e639dd645cb940f3
# 196374                 chorus  95303e966c4e0c2f40c4ed1147fc5c21
# 196375                 chorus  806589868ad2833c60a1028a9b98d728
# 196376                  verse  4a21d392218716772bfc5c0529f33fa5
# 196377                 bridge  a8c214961de4d9b7c8832738a056b174
# 196378                  intro  dc934ad4926fe855af720a51d3f27add
# 196379                 chorus  0c0b8dee20d40c4ef3cbc60cefca65bf
# 196380                 chorus  369373d75ebc0a0afde1e561af9fe4b6
# 196381                 chorus  f9b7ea35a536655b820cc667f541d3c9
# 196382                 chorus  f5393682a85b7d15297b18ef464ac3ba
# 196383                  verse  2bbc847e640c011af4872019491303dd
# 196384                 chorus  35635e0df8ae7258753456ead487d66b
# 196385                 chorus  806d194ba4c2f93829b8bec319fdc81b
# 196386                  verse  e8b89860b8dda437f3fb869c696a004e
# 196387                 chorus  917f12f996be13cdb5c16d7da04a97e7
# 196388                 chorus  ed12ace7be191bf4b63d11b8bd361f12
# 196389                  verse  de27bb229d9b2a983a8f0feb05369857
# 196390                 chorus  5c717d3f4cdf6d80943fa73cab91d242
# 196391                 chorus  49e4fef90cc080d43618180d4a32d0ff
# 196392                 chorus  67a12c729c20a3bc49e22e1da46d472e
#
#                                           parts  \
# 0                                  intro,chorus
# 2                                        chorus
# 3                       verse,pre-chorus,chorus
# 4                       verse,pre-chorus,chorus
# 5                       verse,pre-chorus,chorus
# 6                            intro,verse,chorus
# 7                            intro,verse,chorus
# 8                            intro,verse,chorus
# 9                                        chorus
# 11                                 instrumental
# 14                                       chorus
# 15                                        verse
# 16                                       chorus
# 17                                       chorus
# 18                       intro-and-verse,bridge
# 19                       intro-and-verse,bridge
# 20                                 intro,bridge
# 21                                 intro,bridge
# 22                                        verse
# 23                          chorus,instrumental
# 24                          chorus,instrumental
# 25                       intro-and-verse,chorus
# 26                       intro-and-verse,chorus
# 27                                       chorus
# 28                                       chorus
# 29                                  intro,verse
# 31                                chorus,bridge
# 32                                chorus,bridge
# 33                                  verse,outro
# 34                                  verse,outro
# ...                                         ...
# 196360  pre-chorus,pre-chorus-and-chorus,chorus
# 196361  pre-chorus,pre-chorus-and-chorus,chorus
# 196363                                   chorus
# 196364                                   chorus
# 196365                                    verse
# 196366                                   chorus
# 196368                       intro,verse,chorus
# 196369                       intro,verse,chorus
# 196370                       intro,verse,chorus
# 196371                                   chorus
# 196372                               pre-chorus
# 196374                                   chorus
# 196375                      verse,chorus,bridge
# 196376                      verse,chorus,bridge
# 196377                      verse,chorus,bridge
# 196378                                    intro
# 196379                                   chorus
# 196380                                   chorus
# 196381                                   chorus
# 196382                             verse,chorus
# 196383                             verse,chorus
# 196384                                   chorus
# 196385                             verse,chorus
# 196386                             verse,chorus
# 196387                                   chorus
# 196388                             verse,chorus
# 196389                             verse,chorus
# 196390                                   chorus
# 196391                                   chorus
# 196392                                   chorus
#
#                                          midi_title
# 0                                         yu-gi-oh3
# 2                                            kiefer
# 3                     senbonzakura - pre-Pre-Chorus
# 4                                      Senbonzakura
# 5                                      Senbonzakura
# 6                              Last Christmas Verse
# 7                             Last Christmas Chorus
# 8                              Last Christmas Intro
# 9                                    Freedom Chorus
# 11                                           snuffy
# 14                                  Blue Eyes Cryin
# 15                       You Were Always On My Mind
# 16                          Family Guy - Theme Song
# 17                        American Dad - Theme Song
# 18                                 The Freaking FCC
# 19                               Freakin FCC Bridge
# 20                                  Rainbow Factory
# 21                                  Rainbow Factory
# 22                                Beyond Her Garden
# 23                                  Nightmare Night
# 24                                  Nightmare Night
# 25                                   Piercing Light
# 26                                 Piercing Light 2
# 27                                         No Hands
# 28                                     Fat Labrador
# 29                                          Donkeys
# 31                           Amazing Horse - Bridge
# 32                                    Amazing Horse
# 33                                    Owls - Chorus
# 34                                     Owls - Outro
# ...                                             ...
# 196360                                    Superstar
# 196361                AG cook superstar better bmaj
# 196363                                      Igniter
# 196364                                    Champions
# 196365            above and beyond sun in your eyes
# 196366                                  Anjunabeach
# 196368                                  New Project
# 196369                  Good For Me - Ambient Mix -
# 196370         Above & Beyond - Good For Me (INTRO)
# 196371             Above and Beyond - Always Chorus
# 196372  above and beyond sun and moon prePre-Chorus
# 196374                      above and beyond thingy
# 196375                        Lovelight - Bad Apple
# 196376                        Lovelight - Bad Apple
# 196377                  Love Light Bad Apple Bridge
# 196378                                    Bad Apple
# 196379                                 handinpocket
# 196380                                  New Project
# 196381                                     youlearn
# 196382                                    Uninvited
# 196383                                    Uninvited
# 196384                               thankyoualanis
# 196385                               Head Over Feet
# 196386                            headoverfeetverse
# 196387                              You Oughta Know
# 196388                               Danny's Song B
# 196389                               Danny's Song A
# 196390                                     Only One
# 196391                                           pu
# 196392                                       Famous
#
# [39619 rows x 17 columns]

# %%
Counter(df[df.numpy.notnull()].source.values)
# Out:
# Counter({'hooktheory': 17807,
#          'freemidi': 24,
#          'midiworld': 49,
#          'ecomp': 1,
#          'classical_archives': 75,
#          'musescore': 65,
#          'wikifonia': 2,
#          'lmd': 85,
#          'reddit': 3574,
#          'hooktheory_c': 17937})

# %% [markdown]
# ## TODO: instead of compresssing chord array, we can just separate them out into different parts

# %% [markdown]
# ## Scratch notebook for separating MusicXML parts

# %%
piano_file = version_path/'midi_sources/musescore/data/49143.mxl'

# %%
score = music21.converter.parse(piano_file)

# %%
list(score.parts)
# Out:
# [<music21.stream.PartStaff P1-Staff1>, <music21.stream.PartStaff P1-Staff2>]

# %%
score.show('midi')
# Out:
#                 <div id='midiPlayerDiv144061'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv144061');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
score.parts[0].flat.show('midi')
# Out:
#                 <div id='midiPlayerDiv157204'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv157204');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
score.parts[1].flat.show('midi')
# Out:
#                 <div id='midiPlayerDiv164776'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv164776');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Convert to hooktheory databunch

# %%
def get_files(csv):
    files = csv['numpy']
    flist = [Path(version_path/f) for f in files.values if isinstance(f, str)]
    flist = [f for f in flist if f.exists()]
    return flist

# %%
class S2SFileProcessor(PreProcessor):
    "`PreProcessor` that opens the filenames and read the texts."
    def process_one(self,item):
        out = np.load(item, allow_pickle=True)
        if out.shape != (2,): return None
        if len(out[0]) > 1024: return None
        if len(out[1]) > 1024: return None
#         return np.array([out[0].reshape(-1), out[1].reshape(-1)])
        return out
    
    def process(self, ds:Collection):
        ds.items = [self.process_one(item) for item in ds.items]
        ds.items = [i for i in ds.items if i is not None]
#         ds.items = array([self.process_one(item) for item in ds.items], dtype=np.object)

# %%
class S2SPreloader(Callback):
    def __init__(self, dataset:LabelList, bptt:int=512, **kwargs):
        self.dataset,self.bptt = dataset,bptt
        self.vocab = vocab
        self.single_tfm = partial(to_single_stream, vocab=vocab)
#         self.transpose_tfm = partial(rand_transpose, note_range=vocab.note_range, rand_range=transpose_range)
    
    def __getitem__(self, k:int):
        item,_ = self.dataset[k]
        x,y = item
        
        melody_meta = np.array([self.vocab.stoi[MSEQ], self.vocab.stoi[avg_tempo(x)]]) # pad should be average notes - tempo
        chord_meta = np.array([self.vocab.stoi[CSEQ], self.vocab.stoi[avg_tempo(y)]])
        
        x = self.single_tfm(x, start_seq=melody_meta)
        y = self.single_tfm(y, start_seq=chord_meta)
#         x,y = [self.single_tfm(i) for i in item]
#         x,y = [self.transpose_tfm(i) for i in item]
        
        x = np.pad(x, (0,max(0,self.bptt-len(x))), 'constant', constant_values=vocab.pad_idx)[:self.bptt]
        y_offset = 1
        y = np.pad(y, (0,max(y_offset,self.bptt-len(y))), 'constant', constant_values=vocab.pad_idx)[:self.bptt]
        return x, y
    
    def __len__(self):
        return len(self.dataset)

# %%
def create_databunch(files, cache_name, batch_size=32, load_cached=False):
    if load_cached and (out_path/f'{cache_name}/train_ids.npy').exists():
        data = MusicDataBunch.load(out_path, bs=batch_size, cache_name=cache_name)
    else:
        ps = [S2SFileProcessor()]
        data = (MusicItemList(items=files, path=out_path, processor=ps)
                .split_by_rand_pct(0.01, seed=6)
                .label_const(label_cls=LMLabelList))
#         data.x._bunch = MusicDataBunch
        data = data.databunch(bs=batch_size, preloader_cls=S2SPreloader)
        data.save(cache_name)
    return data

# %%
out_path = version_path/out_dir

# %%
csv = df
hook_csv = csv.loc[csv.source.isin(['hooktheory'])]
hook_files = get_files(hook_csv); len(hook_files)
hook_data = create_databunch(hook_files, cache_name='tmp/hook')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3e4c0efc472d> in <module>
# ----> 1 csv = df
#       2 hook_csv = csv.loc[csv.source.isin(['hooktheory'])]
#       3 hook_files = get_files(hook_csv); len(hook_files)
#       4 hook_data = create_databunch(hook_files, cache_name='tmp/hook')
#
# NameError: name 'df' is not defined

# %%
hook_csv = csv.loc[csv.source.isin(['hooktheory_c'])]
hook_files = get_files(hook_csv); len(hook_files)
hook_data = create_databunch(hook_files, cache_name='tmp/hook_c')
# Out:
# DLTFMS: None

# %%
single_tfm = partial(to_single_stream, vocab=vocab)
transpose_tfm = partial(rand_transpose, note_range=vocab.note_range, rand_range=(0,12))
load_data =  MusicDataBunch.load(path=out_path, cache_name='tmp/hook_c', preloader_cls=S2SPreloader, train_tfms=[single_tfm, transpose_tfm])
# Out:
# DLTFMS: None
# You can deactivate this warning by passing `no_check=True`.
# /home/ubuntu/fastai/fastai/basic_data.py:259: UserWarning: There seems to be something wrong with your dataset, for example, in the first batch can't access any element of self.train_ds.
# Tried: 0,1,2,3,4...
#   warn(warn_msg)

# %%
load_data =  MusicDataBunch.load(path=out_path, cache_name='tmp/hook_c', preloader_cls=S2SPreloader)
# Out:
# DLTFMS: None

# %%
load_data.one_batch()
# Out:
# (tensor([[  6, 273,   8,  ...,   1,   1,   1],
#          [  6, 273,   8,  ..., 142,  88, 141],
#          [  6, 273,   8,  ..., 145,  85, 141],
#          ...,
#          [  6, 273,   8,  ..., 141,  62, 141],
#          [  6, 273,   8,  ..., 141,  54, 143],
#          [  6, 273,   8,  ..., 143,  61, 143]]),
#  tensor([[  5, 273,   8,  ..., 147,  69, 147],
#          [  5, 273,   8,  ..., 149,   8, 149],
#          [  5, 273,   8,  ..., 147,  61, 147],
#          ...,
#          [  5, 273,   8,  ..., 155,  59, 155],
#          [  5, 273,   8,  ..., 147,  64, 147],
#          [  5, 273,   8,  ..., 141,  68, 141]]))

# %%
# ps = [S2SFileProcessor()]

# single_tfm = partial(to_single_stream, vocab=vocab)
# data = (MusicItemList(items=hook_files[:100], path=out_path, processor=ps, tfms=[single_tfm])
#         .split_by_rand_pct(0.01, seed=6)
#         .label_const(label_cls=LMLabelList))
# data.x._bunch = MusicDataBunch

# %%
# data.x.tfms = [single_tfm]

# %%
data = data.databunch(bs=4, preloader_cls=S2SPreloader, train_tfms=[single_tfm])

# %%
out = data.train_dl.dl.dataset[0]

# %%
data.one_batch()

# %%
def avg_tempo(t, sep_idx=0):
    avg = t[t[:, 0] == sep_idx][:, 1].sum()/t.shape[0]
    return 'mt'+str(int(max(round(avg), 4)))

class Seq2SeqProcessor(PreProcessor):
    def __init__(self, vocab=None, ds:Collection=None):  
        self.vocab = vocab
        super().__init__(ds)
        
    "`PreProcessor` that opens the filenames and read the texts."
    def process_one(self,item):
        left, right = [np.load(i, allow_pickle=True) for i in item]
        start_seq = np.array([self.vocab.stoi[BOS], self.vocab.stoi[PAD]])
        
        chord_meta = np.array([self.vocab.stoi[CSEQ], self.vocab.stoi[avg_tempo(left)]])
        chord_seq = to_single_stream(left, self.vocab, start_seq=chord_meta)
        melody_meta = np.array([self.vocab.stoi[MSEQ], self.vocab.stoi[avg_tempo(right)]]) # pad should be average notes - tempo
        melody_seq = to_single_stream(right, self.vocab, start_seq=melody_meta)
        
        
        cat_sequence = np.concatenate([start_seq, chord_seq, melody_seq, np.array([-100]*100)])
            
        return cat_sequence
