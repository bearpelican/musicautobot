# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')
from src.encode_data import *
from src.midi_data import *
# from src.data_sources import process_parallel, transform_csv_row
from src.midi_transform import *
from concurrent.futures import ProcessPoolExecutor
from fastprogress.fastprogress import master_bar, progress_bar

# %%
import traceback
import time

# %%
from tqdm import tqdm

# %% [markdown]
# ## Standardize and reformat raw midi files before encoding to text
# - Transform key to C major
# - Remove unused instruments
# - Combine multiple tracks with the same instrument into a single part
# - Melody, Piano, String

# %% [markdown]
# ### Load midi data

# %%
version = 'v12'
data_path = Path('data/midi')
version_path = data_path/version

# %%
import pandas as pd

# %%
source_dir = 'midi_sources'
out_dir = 'midi_encode'
source_csv = version_path/'metadata'/f'{source_dir}.csv'
out_csv = version_path/out_dir/f'{out_dir}.csv'
out_csv.parent.mkdir(parents=True, exist_ok=True)
source_csv, out_csv
# Out:
# (PosixPath('data/midi/v12/metadata/midi_sources.csv'),
#  PosixPath('data/midi/v12/midi_encode/midi_encode.csv'))

# %%
num_comps = 2 # note, duration
cutoff = 4 # max instruments
max_dur = 128

# %% [markdown]
# ### Via Data Sources

# %%
import concurrent

# %%
def process_all(func, arr, total=None, max_workers=None, timeout=None):
    "Process array in parallel"
    if total is None: total = len(arr)
    results = []
    with ProcessPoolExecutor(max_workers=max_workers) as ex:
        futures = [ex.submit(func,o) for i,o in enumerate(arr)]
        for f in progress_bar(concurrent.futures.as_completed(futures, timeout=timeout), total=total):
            res = f.result(timeout=timeout)
            if res is not None:
                results.append(res)
    return results

# %% [markdown]
# ## Convert mxl to midi

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,7,8,10,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             song_url  ht_bpm  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...   128.0
# 1  https://www.hooktheory.com/theorytab/view/wayn...    85.0
# 2  https://www.hooktheory.com/theorytab/view/what...    96.0
# 3  https://www.hooktheory.com/theorytab/view/whit...   152.0
# 4  https://www.hooktheory.com/theorytab/view/whit...   152.0
#
#    ht_time_signature                                               midi  \
# 0                4.0  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 1                3.0  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 2                4.0  midi_sources/hooktheory/pianoroll/w/what-a-day...
# 3                4.0  midi_sources/hooktheory/pianoroll/w/whiteflame...
# 4                4.0  midi_sources/hooktheory/pianoroll/w/whiteflame...
#
#       genres        artist                               md5     section  \
# 0        NaN  wayne-sharpe  bf1f29e5ff84e3e93e37fb873bfb590e      chorus
# 1        NaN  wayne-sharpe  055f80ad67f64edb14a85ca8fbfe8c29       intro
# 2       Jazz    what-a-day  197f96f5d181f6ce1e2c5ab04ac1ff87      chorus
# 3  J-Pop,Pop    whiteflame  9e7ce13a35f1314423a9a6d5a5287a4a  pre-chorus
# 4  J-Pop,Pop    whiteflame  d5aaf79d0989222f1362f9f46c540a27       verse
#
#   ht_key      source                    parts                     midi_title  \
# 0      C  hooktheory             intro,chorus                      yu-gi-oh3
# 1      C  hooktheory             intro,chorus                       yu-gi-oh
# 2      D  hooktheory                   chorus                         kiefer
# 3      D  hooktheory  verse,pre-chorus,chorus  senbonzakura - pre-Pre-Chorus
# 4      D  hooktheory  verse,pre-chorus,chorus                   Senbonzakura
#
#                  title  ht_offset  ht_mode  mxl
# 0  yu-gi-oh-theme-song        0.0      1.0  NaN
# 1  yu-gi-oh-theme-song        0.0      1.0  NaN
# 2               kiefer       -5.0      6.0  NaN
# 3         senbonzakura       -5.0      6.0  NaN
# 4         senbonzakura       -5.0      6.0  NaN

# %%
all_records = df.to_dict(orient='records')

# %%
# all_records = df.loc[df.source.isin(['classical_archives'])].to_dict(orient='records'); len(all_records)
# Out:
# 14671

# %%
# mxl_records = df.loc[df.source.isin(['ecomp', 'wikifonia', 'classical_piano', 'musescore'])].to_dict(orient='records')

# %%
def mxl2midi_func(metadata):
    start = time.time()
    result = metadata.copy()
    
    if not isinstance(metadata.get('mxl'), str): return result
    
    input_path = version_path/metadata['mxl']
    
    out_file = Path(str(metadata['mxl']).replace('midi_sources/', 'midi_sources/from_mxl/')).with_suffix('.mid')
    
    output_path = version_path/out_file
    
#     if not output_path.exists():
# #         return result
#         try:
#             output_path.parent.mkdir(parents=True, exist_ok=True)
#             stream = file2stream(input_path)
#             stream.write('midi', fp=output_path)
            
#             elapsed_time = time.time() - start
#             result['sec_elapsed_mxl2midi'] = elapsed_time
#             if elapsed_time > 60:
#                 print('Super long file:', elapsed_time, input_path)
#         except Exception:
#             print(traceback.format_exc())
#             return None
    result['midi'] = out_file
    return result

# %%
# # sanity check
# import random
# for r in random.sample(mxl_records, 500):
#     mxl2midi_func(r)
#     print(r)

# %%
# processed = process_all(mxl2midi_func, all_records, timeout=10)

# %%
processed = process_all(mxl2midi_func, all_records)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='197426' class='' max='197426', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [197426/197426 01:00<00:00]
#     </div>

# %%
from src.data_sources import arr2csv
arr2csv(processed, out_csv)
df = pd.read_csv(out_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2,3,5,6,8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       genres        artist ht_key                     midi_title  ht_mode  \
# 0        NaN  wayne-sharpe      C                      yu-gi-oh3      1.0
# 1        NaN  wayne-sharpe      C                       yu-gi-oh      1.0
# 2       Jazz    what-a-day      D                         kiefer      6.0
# 3  J-Pop,Pop    whiteflame      D  senbonzakura - pre-Pre-Chorus      6.0
# 4  J-Pop,Pop    whiteflame      D                   Senbonzakura      6.0
#
#    mxl                                           song_url  ht_offset  \
# 0  NaN  https://www.hooktheory.com/theorytab/view/wayn...        0.0
# 1  NaN  https://www.hooktheory.com/theorytab/view/wayn...        0.0
# 2  NaN  https://www.hooktheory.com/theorytab/view/what...       -5.0
# 3  NaN  https://www.hooktheory.com/theorytab/view/whit...       -5.0
# 4  NaN  https://www.hooktheory.com/theorytab/view/whit...       -5.0
#
#                      parts                title  ht_bpm  ht_time_signature  \
# 0             intro,chorus  yu-gi-oh-theme-song   128.0                4.0
# 1             intro,chorus  yu-gi-oh-theme-song    85.0                3.0
# 2                   chorus               kiefer    96.0                4.0
# 3  verse,pre-chorus,chorus         senbonzakura   152.0                4.0
# 4  verse,pre-chorus,chorus         senbonzakura   152.0                4.0
#
#       section                                               midi      source  \
# 0      chorus  midi_sources/hooktheory/pianoroll/w/wayne-shar...  hooktheory
# 1       intro  midi_sources/hooktheory/pianoroll/w/wayne-shar...  hooktheory
# 2      chorus  midi_sources/hooktheory/pianoroll/w/what-a-day...  hooktheory
# 3  pre-chorus  midi_sources/hooktheory/pianoroll/w/whiteflame...  hooktheory
# 4       verse  midi_sources/hooktheory/pianoroll/w/whiteflame...  hooktheory
#
#                                 md5
# 0  bf1f29e5ff84e3e93e37fb873bfb590e
# 1  055f80ad67f64edb14a85ca8fbfe8c29
# 2  197f96f5d181f6ce1e2c5ab04ac1ff87
# 3  9e7ce13a35f1314423a9a6d5a5287a4a
# 4  d5aaf79d0989222f1362f9f46c540a27

# %% [markdown]
# ### Midi formatting

# %%
df = pd.read_csv(out_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2,3,5,6,8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       genres        artist ht_key                     midi_title  ht_mode  \
# 0        NaN  wayne-sharpe      C                      yu-gi-oh3      1.0
# 1        NaN  wayne-sharpe      C                       yu-gi-oh      1.0
# 2       Jazz    what-a-day      D                         kiefer      6.0
# 3  J-Pop,Pop    whiteflame      D  senbonzakura - pre-Pre-Chorus      6.0
# 4  J-Pop,Pop    whiteflame      D                   Senbonzakura      6.0
#
#    mxl                                           song_url  ht_offset  \
# 0  NaN  https://www.hooktheory.com/theorytab/view/wayn...        0.0
# 1  NaN  https://www.hooktheory.com/theorytab/view/wayn...        0.0
# 2  NaN  https://www.hooktheory.com/theorytab/view/what...       -5.0
# 3  NaN  https://www.hooktheory.com/theorytab/view/whit...       -5.0
# 4  NaN  https://www.hooktheory.com/theorytab/view/whit...       -5.0
#
#                      parts                title  ht_bpm  ht_time_signature  \
# 0             intro,chorus  yu-gi-oh-theme-song   128.0                4.0
# 1             intro,chorus  yu-gi-oh-theme-song    85.0                3.0
# 2                   chorus               kiefer    96.0                4.0
# 3  verse,pre-chorus,chorus         senbonzakura   152.0                4.0
# 4  verse,pre-chorus,chorus         senbonzakura   152.0                4.0
#
#       section                                               midi      source  \
# 0      chorus  midi_sources/hooktheory/pianoroll/w/wayne-shar...  hooktheory
# 1       intro  midi_sources/hooktheory/pianoroll/w/wayne-shar...  hooktheory
# 2      chorus  midi_sources/hooktheory/pianoroll/w/what-a-day...  hooktheory
# 3  pre-chorus  midi_sources/hooktheory/pianoroll/w/whiteflame...  hooktheory
# 4       verse  midi_sources/hooktheory/pianoroll/w/whiteflame...  hooktheory
#
#                                 md5
# 0  bf1f29e5ff84e3e93e37fb873bfb590e
# 1  055f80ad67f64edb14a85ca8fbfe8c29
# 2  197f96f5d181f6ce1e2c5ab04ac1ff87
# 3  9e7ce13a35f1314423a9a6d5a5287a4a
# 4  d5aaf79d0989222f1362f9f46c540a27

# %%
all_records = df.to_dict(orient='records'); len(all_records)
# Out:
# 197426

# %%
mxl_records = df.loc[df.source.isin(['classical_archives', 'hooktheory_c'])].to_dict(orient='records')
# mxl_records = df.loc[df.source.isin(['ecomp', 'wikifonia', 'classical_piano', 'musescore'])].to_dict(orient='records')

# %%
def transform_func(metadata):
    result = metadata.copy()
    start = time.time()
    
    # Part 1. Compress tracks/instruments
    if not isinstance(metadata.get('midi'), str): return None
    
    input_path = version_path/metadata['midi']
    extension = input_path.suffix.lower()
    if not input_path.exists(): 
        print('Input path does not exist:', input_path, metadata)
        return None
    
    # Get outfile and check if it exists
    out_file = Path(str(input_path).replace(f'/{source_dir}/', f'/{out_dir}/'))
    out_file = out_file.with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): 
        result['numpy'] = str(out_file.relative_to(version_path))
        return result
    
#     # DEBUG
#     return None
    
    try: input_file = compress_midi_file(input_path, cutoff=cutoff) # remove non note tracks and standardize instruments
    except music21.midi.MidiException as e:
        print('Error parsing midi', input_path, e)
        return None
    if not input_file: return None
        
    # Part 2. Compress rests and long notes
    stream = file2stream(input_file) # 1.
    try:
        chordarr = stream2chordarr(stream, max_dur=max_dur, flat=False) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
#     chordarr = stream2chordarr(stream, max_dur=max_dur, flat=(extension != '.mid')) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
    except Exception as e:
        print('Could not encode to chordarr:', input_path, e)
#         print(traceback.format_exc())
        return None
    
    chord_trim = trim_chordarr_rests(chordarr)
    chord_short = shorten_chordarr_rests(chord_trim)
    delta_trim = chord_trim.shape[0] - chord_short.shape[0]
    if delta_trim > 300: 
        print(f'Removed {delta_trim} rests from {input_path}. Skipping song')
        return None
    chordarr = chord_short
    
    # Part 3. Chord array to numpy
    seq = chordarr2seq(chordarr)
    if len(seq) < 32:
        print('Sequence too short:', len(seq), input_path)
        return None
    
#     category = ENC_OFFSET + max_dur + sources.index(metadata['source']) + 1
    category = source2encidx(metadata['source'], max_dur=max_dur)
    npenc = seq2npenc(seq, num_comps=num_comps, category=category)
    if (npenc[1:,1] > max_dur+ENC_OFFSET).any(): 
        print('npenc exceeds max 128 duration:', input_path)
        return None
    
    if ((npenc[...,0] > ENC_OFFSET) & ((npenc[...,0] < 12+ENC_OFFSET) | (npenc[...,0] >= 127-12+ENC_OFFSET))).any(): 
        print('npenc out of note range 12 - 116:', input_path)
        return None
    
    
    np.save(out_file, npenc)
    
    elapsed_time = time.time() - start
    result['sec_elapsed_tfm'] = elapsed_time
    if elapsed_time > 60:
        print('Super long file:', elapsed_time, input_path)
    
    result['numpy'] = str(out_file.relative_to(version_path))
    return result

# %%
def try_transform_func(metadata):
    try:
        return transform_func(metadata)
    except Exception:
        print(traceback.format_exc())
        return None

# %%
# # sanity check
import random
for r in random.sample(mxl_records, 500):
    transform_func(r)

# %%
### AS TOD: Fix 'info channel is not channel 0' error

# %%
processed = process_all(try_transform_func, mxl_records)
# Out:
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmbksost.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmdbshep.mid
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='34747' class='' max='34747', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [34747/34747 40:52<00:00]
#     </div>
# Error parsing midi data/midi/v12/midi_sources/from_mxl/classical_archives/021/bl109_15.mid badly formated midi bytes, got: b''
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmpanwrs.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmpchnem.mid index 127 is out of bounds for axis 2 with size 127
# Error parsing midi data/midi/v12/midi_sources/from_mxl/classical_archives/021/3_pt_15.mid badly formated midi bytes, got: b''
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmhl4611.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmslvdnc.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tm10es08.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmgypron.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmhunfk1.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmhl4605.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmcl36_3.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tm10es07.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmcl36_4.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmcpsolf.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmevvilg.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tm10es09.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmbardnc.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmhl4618.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmdedton.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmpesdnc.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmhl4622.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmcl38_1.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmzampa.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmcl38_3.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmcl36_6.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmcl38_2.mid
# Super long file: 61.82490944862366 data/midi/v12/midi_sources/from_mxl/classical_archives/021/sydvthva.mid
# Removed 1064 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/leschi3.mid. Skipping song
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmwiorg5.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 75.8824291229248 data/midi/v12/midi_sources/from_mxl/classical_archives/021/men26.mid
# Super long file: 75.86702489852905 data/midi/v12/midi_sources/from_mxl/classical_archives/021/griegp.mid
# Super long file: 69.01542592048645 data/midi/v12/midi_sources/from_mxl/classical_archives/021/wamk465d.mid
# Super long file: 82.55803155899048 data/midi/v12/midi_sources/from_mxl/classical_archives/021/dvsy41.mid
# Super long file: 62.75182580947876 data/midi/v12/midi_sources/from_mxl/classical_archives/021/brcp1_3.mid
# Super long file: 67.96431803703308 data/midi/v12/midi_sources/from_mxl/classical_archives/021/men90_1.mid
# Super long file: 70.41511654853821 data/midi/v12/midi_sources/from_mxl/classical_archives/021/jg_592_1.mid
# Removed 404 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/scheh2.mid. Skipping song
# Super long file: 69.38615441322327 data/midi/v12/midi_sources/from_mxl/classical_archives/021/griegpcm.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/021/tmbchdbl.mid index 127 is out of bounds for axis 2 with size 127
# Removed 352 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/pstrl-3.mid. Skipping song
# Removed 324 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/african.mid. Skipping song
# Super long file: 98.40406012535095 data/midi/v12/midi_sources/from_mxl/classical_archives/021/beetfuge.mid
# Super long file: 62.61351227760315 data/midi/v12/midi_sources/from_mxl/classical_archives/021/die_20me.mid
# Removed 360 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/aida_ii2.mid. Skipping song
# Super long file: 75.1716525554657 data/midi/v12/midi_sources/from_mxl/classical_archives/8/wamk265.mid
# Super long file: 67.36542081832886 data/midi/v12/midi_sources/from_mxl/classical_archives/8/lecpsa3.mid
# Super long file: 119.55014634132385 data/midi/v12/midi_sources/from_mxl/classical_archives/021/enerr1.mid
# Super long file: 113.2048659324646 data/midi/v12/midi_sources/from_mxl/classical_archives/021/jg593_34.mid
# Super long file: 138.1693148612976 data/midi/v12/midi_sources/from_mxl/classical_archives/021/op73_2_3.mid
# Super long file: 80.05937600135803 data/midi/v12/midi_sources/from_mxl/classical_archives/8/lsztjeux.mid
# Error parsing midi data/midi/v12/midi_sources/from_mxl/classical_archives/4/coqdor3.mid badly formated midi bytes, got: b''
# Super long file: 77.35980486869812 data/midi/v12/midi_sources/from_mxl/classical_archives/021/patineur.mid
# Super long file: 70.39965081214905 data/midi/v12/midi_sources/from_mxl/classical_archives/8/k254trio.mid
# Super long file: 60.569321393966675 data/midi/v12/midi_sources/from_mxl/classical_archives/8/be-ps-02.mid
# Super long file: 76.37030529975891 data/midi/v12/midi_sources/from_mxl/classical_archives/8/african2.mid
# Error parsing midi data/midi/v12/midi_sources/from_mxl/classical_archives/4/bach-565.mid badly formated midi bytes, got: b''
# Super long file: 106.16422820091248 data/midi/v12/midi_sources/from_mxl/classical_archives/021/donjunth.mid
# Super long file: 80.39043593406677 data/midi/v12/midi_sources/from_mxl/classical_archives/8/1812tcha.mid
# Super long file: 64.81908583641052 data/midi/v12/midi_sources/from_mxl/classical_archives/8/k622_1.mid
# Super long file: 96.77825570106506 data/midi/v12/midi_sources/from_mxl/classical_archives/8/tannover.mid
# Super long file: 113.98040461540222 data/midi/v12/midi_sources/from_mxl/classical_archives/021/ee2132.mid
# Super long file: 60.75811791419983 data/midi/v12/midi_sources/from_mxl/classical_archives/8/mthmronb.mid
# Super long file: 105.51396083831787 data/midi/v12/midi_sources/from_mxl/classical_archives/8/lont16.mid
# Super long file: 79.43272423744202 data/midi/v12/midi_sources/from_mxl/classical_archives/8/mend_var.mid
# Super long file: 80.76864385604858 data/midi/v12/midi_sources/from_mxl/classical_archives/8/bzsmcrmn.mid
# Super long file: 95.92660737037659 data/midi/v12/midi_sources/from_mxl/classical_archives/8/b7-4.mid
# Input path does not exist: data/midi/v12/midi_sources/from_mxl/classical_archives/4/khachtoc.mid {'genres': 'classical', 'artist': 'khachtoc', 'ht_key': nan, 'midi_title': nan, 'ht_mode': nan, 'mxl': 'midi_sources/classical_archives/4/khachtoc.mxl', 'song_url': nan, 'ht_offset': nan, 'parts': nan, 'title': 'khachtoc', 'ht_bpm': nan, 'ht_time_signature': nan, 'section': nan, 'midi': 'midi_sources/from_mxl/classical_archives/4/khachtoc.mid', 'source': 'classical_archives', 'md5': '51b5f79c3f3b4e1539ef6e84c87c6abc'}
# Super long file: 150.7940855026245 data/midi/v12/midi_sources/from_mxl/classical_archives/021/rachsona.mid
# Super long file: 96.37234497070312 data/midi/v12/midi_sources/from_mxl/classical_archives/8/menop64a.mid
# Removed 772 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/donjuan.mid. Skipping song
# Super long file: 88.70435810089111 data/midi/v12/midi_sources/from_mxl/classical_archives/8/jpgsuite.mid
# Super long file: 78.60069489479065 data/midi/v12/midi_sources/from_mxl/classical_archives/8/beet1c1t.mid
# Super long file: 66.45050835609436 data/midi/v12/midi_sources/from_mxl/classical_archives/8/be-ps-08.mid
# Super long file: 166.61050462722778 data/midi/v12/midi_sources/from_mxl/classical_archives/021/jg591_34.mid
# Super long file: 105.88474631309509 data/midi/v12/midi_sources/from_mxl/classical_archives/8/wamk283.mid
# Super long file: 179.26136660575867 data/midi/v12/midi_sources/from_mxl/classical_archives/021/rachson.mid
# Super long file: 94.24394989013672 data/midi/v12/midi_sources/from_mxl/classical_archives/8/wamk576.mid
# Super long file: 81.41929364204407 data/midi/v12/midi_sources/from_mxl/classical_archives/8/be-ps-01.mid
# Super long file: 70.23713040351868 data/midi/v12/midi_sources/from_mxl/classical_archives/8/alconspi.mid
# Super long file: 125.89174222946167 data/midi/v12/midi_sources/from_mxl/classical_archives/8/lis_sprh.mid
# Input path does not exist: data/midi/v12/midi_sources/from_mxl/classical_archives/4/rex_trem.mid {'genres': 'classical', 'artist': 'rex_trem', 'ht_key': nan, 'midi_title': nan, 'ht_mode': nan, 'mxl': 'midi_sources/classical_archives/4/rex_trem.mxl', 'song_url': nan, 'ht_offset': nan, 'parts': nan, 'title': 'rex_trem', 'ht_bpm': nan, 'ht_time_signature': nan, 'section': nan, 'midi': 'midi_sources/from_mxl/classical_archives/4/rex_trem.mid', 'source': 'classical_archives', 'md5': '7fdeed431742e707c0b2fb25feb32b50'}
# Super long file: 64.76110363006592 data/midi/v12/midi_sources/from_mxl/classical_archives/4/french6.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/4/woo32-2.mid
# Super long file: 211.2347137928009 data/midi/v12/midi_sources/from_mxl/classical_archives/021/dvsy44.mid
# Super long file: 109.55529546737671 data/midi/v12/midi_sources/from_mxl/classical_archives/8/lont32.mid
# Removed 1124 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/4/brgreq3.mid. Skipping song
# Super long file: 144.4567527770996 data/midi/v12/midi_sources/from_mxl/classical_archives/8/wamk547a.mid
# Super long file: 126.89034700393677 data/midi/v12/midi_sources/from_mxl/classical_archives/8/be-pc3-1.mid
# Super long file: 106.15912580490112 data/midi/v12/midi_sources/from_mxl/classical_archives/8/lis_lesp.mid
# Super long file: 85.93387508392334 data/midi/v12/midi_sources/from_mxl/classical_archives/8/wamk280.mid
# Super long file: 205.28360891342163 data/midi/v12/midi_sources/from_mxl/classical_archives/021/aida_20.mid
# Super long file: 190.6535038948059 data/midi/v12/midi_sources/from_mxl/classical_archives/021/niel_s21.mid
# Super long file: 101.84560990333557 data/midi/v12/midi_sources/from_mxl/classical_archives/8/weihe-ma.mid
# Super long file: 137.95751667022705 data/midi/v12/midi_sources/from_mxl/classical_archives/8/be-ps-11.mid
# Super long file: 73.60867643356323 data/midi/v12/midi_sources/from_mxl/classical_archives/4/schm_48.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/4/k424_1.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 67.42649340629578 data/midi/v12/midi_sources/from_mxl/classical_archives/4/moz-354.mid
# Super long file: 168.44825744628906 data/midi/v12/midi_sources/from_mxl/classical_archives/8/be-ps-04.mid
# Super long file: 183.39063358306885 data/midi/v12/midi_sources/from_mxl/classical_archives/8/mzrtk331.mid
# Super long file: 79.24821996688843 data/midi/v12/midi_sources/from_mxl/classical_archives/4/gium1_1.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/4/men72-2.mid
# Super long file: 239.50174474716187 data/midi/v12/midi_sources/from_mxl/classical_archives/021/op73_1.mid
# Removed 1216 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/4/miserere.mid. Skipping song
# Removed 504 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/021/brcp1_1.mid. Skipping song
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/4/852wti7.mid
# Super long file: 94.00847363471985 data/midi/v12/midi_sources/from_mxl/classical_archives/8/fmsq4431.mid
# Super long file: 78.76859545707703 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lvbsym41.mid
# Super long file: 74.64129400253296 data/midi/v12/midi_sources/from_mxl/classical_archives/4/bisymph4.mid
# npenc exceeds max 128 duration: data/midi/v12/midi_sources/from_mxl/classical_archives/4/ssbaccha.mid
# Super long file: 73.0460638999939 data/midi/v12/midi_sources/from_mxl/classical_archives/4/wamk465a.mid
# Super long file: 75.51322722434998 data/midi/v12/midi_sources/from_mxl/classical_archives/4/krakowik.mid
# Super long file: 141.358971118927 data/midi/v12/midi_sources/from_mxl/classical_archives/8/be-ps-03.mid
# Super long file: 90.89064025878906 data/midi/v12/midi_sources/from_mxl/classical_archives/4/moz6ted.mid
# Super long file: 112.66797208786011 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sorop44.mid
# Super long file: 144.764643907547 data/midi/v12/midi_sources/from_mxl/classical_archives/8/sb-imp90.mid
# Super long file: 86.86968564987183 data/midi/v12/midi_sources/from_mxl/classical_archives/4/bwv248f.mid
# Super long file: 60.688695430755615 data/midi/v12/midi_sources/from_mxl/classical_archives/4/be-pc1-1.mid
# Super long file: 184.1018054485321 data/midi/v12/midi_sources/from_mxl/classical_archives/8/immolat.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/4/men66-1.mid
# Super long file: 188.58784914016724 data/midi/v12/midi_sources/from_mxl/classical_archives/8/wamk330.mid
# Super long file: 113.02234864234924 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sorop60.mid
# Removed 548 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/4/tch363.mid. Skipping song
# Super long file: 278.96895384788513 data/midi/v12/midi_sources/from_mxl/classical_archives/021/lisztson.mid
# Super long file: 128.4678554534912 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sorop29.mid
# Super long file: 139.52376890182495 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lvbsym71.mid
# Removed 796 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/rkeaster.mid. Skipping song
# Super long file: 81.67242431640625 data/midi/v12/midi_sources/from_mxl/classical_archives/4/bachl3.mid
# Super long file: 65.42883038520813 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sc-ps-07.mid
# Removed 524 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/4/be1252.mid. Skipping song
# Super long file: 78.99003863334656 data/midi/v12/midi_sources/from_mxl/classical_archives/4/be123cr.mid
# Super long file: 88.11251449584961 data/midi/v12/midi_sources/from_mxl/classical_archives/4/hungrap2.mid
# Super long file: 104.80817174911499 data/midi/v12/midi_sources/from_mxl/classical_archives/4/symeanva.mid
# Super long file: 141.14897894859314 data/midi/v12/midi_sources/from_mxl/classical_archives/4/5be3_4mv.mid
# Super long file: 130.89648938179016 data/midi/v12/midi_sources/from_mxl/classical_archives/4/smetmol.mid
# Super long file: 91.03850078582764 data/midi/v12/midi_sources/from_mxl/classical_archives/4/brande2.mid
# Removed 1052 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/j/bwv548b.mid. Skipping song
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/4/be123ad.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1309.mid
# Removed 516 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/4/beetwell.mid. Skipping song
# Super long file: 120.7838077545166 data/midi/v12/midi_sources/from_mxl/classical_archives/4/romgiul.mid
# Removed 604 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/4/schwert.mid. Skipping song
# Super long file: 159.05739331245422 data/midi/v12/midi_sources/from_mxl/classical_archives/4/goldsoni.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1304.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmra2309.mid
# Super long file: 74.08058834075928 data/midi/v12/midi_sources/from_mxl/classical_archives/4/syslmaca.mid
# Super long file: 86.24698066711426 data/midi/v12/midi_sources/from_mxl/classical_archives/4/syblsy54.mid
# Super long file: 166.9938097000122 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lisztmef.mid
# Super long file: 91.61569809913635 data/midi/v12/midi_sources/from_mxl/classical_archives/4/tchaik54.mid
# Super long file: 86.80077385902405 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lvbsym74.mid
# Super long file: 74.12759709358215 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sc-ps-01.mid
# Super long file: 76.59929180145264 data/midi/v12/midi_sources/from_mxl/classical_archives/4/boh_m11.mid
# Super long file: 60.44866156578064 data/midi/v12/midi_sources/from_mxl/classical_archives/4/gr-peer2.mid
# Super long file: 67.3593373298645 data/midi/v12/midi_sources/from_mxl/classical_archives/4/beet9mv1.mid
# Super long file: 217.42262601852417 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lvbsym54.mid
# Super long file: 73.21222758293152 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lvbsym61.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1310.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 159.0851969718933 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sch1-1.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/023/archpasl.mid
# Super long file: 123.1369161605835 data/midi/v12/midi_sources/from_mxl/classical_archives/4/french4.mid
# Super long file: 63.1154351234436 data/midi/v12/midi_sources/from_mxl/classical_archives/4/rapespag.mid
# Super long file: 63.84785723686218 data/midi/v12/midi_sources/from_mxl/classical_archives/j/fingal.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1302.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 286.86364126205444 data/midi/v12/midi_sources/from_mxl/classical_archives/8/wamk284.mid
# Super long file: 71.7756974697113 data/midi/v12/midi_sources/from_mxl/classical_archives/4/brahm771.mid
# Super long file: 96.78752613067627 data/midi/v12/midi_sources/from_mxl/classical_archives/4/french5.mid
# Super long file: 209.25219225883484 data/midi/v12/midi_sources/from_mxl/classical_archives/4/schop103.mid
# Super long file: 92.92305564880371 data/midi/v12/midi_sources/from_mxl/classical_archives/4/mozconc1.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmprson3.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmmikado.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 70.19088363647461 data/midi/v12/midi_sources/from_mxl/classical_archives/j/dvsym8_1.mid
# Super long file: 84.47534441947937 data/midi/v12/midi_sources/from_mxl/classical_archives/4/quintet.mid
# Super long file: 68.45412516593933 data/midi/v12/midi_sources/from_mxl/classical_archives/023/5sptr4.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1305.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 74.4158205986023 data/midi/v12/midi_sources/from_mxl/classical_archives/j/mahler55.mid
# Super long file: 240.14278388023376 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lisztpc1.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1303.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 67.44539427757263 data/midi/v12/midi_sources/from_mxl/classical_archives/j/dvsym8_4.mid
# Super long file: 72.781334400177 data/midi/v12/midi_sources/from_mxl/classical_archives/023/moz_300e.mid
# Super long file: 126.67851090431213 data/midi/v12/midi_sources/from_mxl/classical_archives/4/bisymph1.mid
# Super long file: 113.97894859313965 data/midi/v12/midi_sources/from_mxl/classical_archives/4/dvs94.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmkghrup.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmbc542b.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 108.00888228416443 data/midi/v12/midi_sources/from_mxl/classical_archives/4/introduz.mid
# Super long file: 72.2482340335846 data/midi/v12/midi_sources/from_mxl/classical_archives/023/kielgc1.mid
# Super long file: 159.53998565673828 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sorop35.mid
# Super long file: 97.57018518447876 data/midi/v12/midi_sources/from_mxl/classical_archives/023/sybrsy14.mid
# Super long file: 164.28175854682922 data/midi/v12/midi_sources/from_mxl/classical_archives/4/k331-moz.mid
# Super long file: 102.94247102737427 data/midi/v12/midi_sources/from_mxl/classical_archives/j/great1.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1306.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1308.mid
# Super long file: 92.66519927978516 data/midi/v12/midi_sources/from_mxl/classical_archives/023/bach_in.mid
# Super long file: 202.0838098526001 data/midi/v12/midi_sources/from_mxl/classical_archives/4/becpn51.mid
# Super long file: 103.62847185134888 data/midi/v12/midi_sources/from_mxl/classical_archives/023/k372frag.mid
# Super long file: 80.19555473327637 data/midi/v12/midi_sources/from_mxl/classical_archives/023/mzt_hfs1.mid
# Super long file: 68.28017663955688 data/midi/v12/midi_sources/from_mxl/classical_archives/023/sybrsy11.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1301.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 125.73838400840759 data/midi/v12/midi_sources/from_mxl/classical_archives/j/moldau-n.mid
# Super long file: 215.22894597053528 data/midi/v12/midi_sources/from_mxl/classical_archives/4/hain_gs.mid
# Super long file: 120.80668616294861 data/midi/v12/midi_sources/from_mxl/classical_archives/j/lbs29_1.mid
# Super long file: 416.8421964645386 data/midi/v12/midi_sources/from_mxl/classical_archives/021/rubsonat.mid
# Super long file: 60.32574915885925 data/midi/v12/midi_sources/from_mxl/classical_archives/023/chg_fa27.mid
# Super long file: 88.16390061378479 data/midi/v12/midi_sources/from_mxl/classical_archives/023/visfugit.mid
# Super long file: 174.57947516441345 data/midi/v12/midi_sources/from_mxl/classical_archives/4/lespral.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/023/tmsk1307.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 61.64823865890503 data/midi/v12/midi_sources/from_mxl/classical_archives/023/k496_1.mid
# Super long file: 221.69600200653076 data/midi/v12/midi_sources/from_mxl/classical_archives/4/humop18.mid
# Super long file: 155.39965200424194 data/midi/v12/midi_sources/from_mxl/classical_archives/4/sorop6.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmdbelgy.mid
# Super long file: 63.937259912490845 data/midi/v12/midi_sources/from_mxl/classical_archives/023/sybrsy21.mid
# Super long file: 196.6151671409607 data/midi/v12/midi_sources/from_mxl/classical_archives/4/beet9m2.mid
# Super long file: 69.15051770210266 data/midi/v12/midi_sources/from_mxl/classical_archives/023/k502_1.mid
# Super long file: 163.91714239120483 data/midi/v12/midi_sources/from_mxl/classical_archives/j/octet1c.mid
# Super long file: 164.19328379631042 data/midi/v12/midi_sources/from_mxl/classical_archives/j/dvrak94s.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmembro3.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmb11910.mid
# Super long file: 147.597243309021 data/midi/v12/midi_sources/from_mxl/classical_archives/j/beetho92.mid
# Removed 360 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/024/be13_1.mid. Skipping song
# Super long file: 64.31943702697754 data/midi/v12/midi_sources/from_mxl/classical_archives/023/sinf2_4.mid
# Super long file: 84.58487558364868 data/midi/v12/midi_sources/from_mxl/classical_archives/023/faustact.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmb11909.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 205.72830200195312 data/midi/v12/midi_sources/from_mxl/classical_archives/4/haydlms.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmembro1.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmbcpr01.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 64.69489192962646 data/midi/v12/midi_sources/from_mxl/classical_archives/023/lis_hr2.mid
# Super long file: 213.93198776245117 data/midi/v12/midi_sources/from_mxl/classical_archives/4/schmn2-3.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmembro2.mid index 127 is out of bounds for axis 2 with size 127
# Removed 516 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/024/mthmw12b.mid. Skipping song
# Super long file: 213.41151428222656 data/midi/v12/midi_sources/from_mxl/classical_archives/4/becpn523.mid
# Super long file: 231.20231342315674 data/midi/v12/midi_sources/from_mxl/classical_archives/4/listtanz.mid
# Super long file: 71.96434545516968 data/midi/v12/midi_sources/from_mxl/classical_archives/023/k380_1.mid
# Super long file: 278.5638892650604 data/midi/v12/midi_sources/from_mxl/classical_archives/4/rach3-23.mid
# Super long file: 63.320738315582275 data/midi/v12/midi_sources/from_mxl/classical_archives/023/k442_3.mid
# Super long file: 89.57273840904236 data/midi/v12/midi_sources/from_mxl/classical_archives/023/1vanq1.mid
# Super long file: 208.81816911697388 data/midi/v12/midi_sources/from_mxl/classical_archives/4/be-pc-01.mid
# Super long file: 89.76255774497986 data/midi/v12/midi_sources/from_mxl/classical_archives/023/mozartk4.mid
# Super long file: 244.4673159122467 data/midi/v12/midi_sources/from_mxl/classical_archives/4/schop15.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/022/tmhalli.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 178.68959307670593 data/midi/v12/midi_sources/from_mxl/classical_archives/023/reger127.mid
# Super long file: 91.87601017951965 data/midi/v12/midi_sources/from_mxl/classical_archives/023/besy81.mid
# Super long file: 90.56037998199463 data/midi/v12/midi_sources/from_mxl/classical_archives/023/quintet.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/022/tmsthtla.mid
# Super long file: 126.46756482124329 data/midi/v12/midi_sources/from_mxl/classical_archives/023/lis_meph.mid
# Super long file: 64.09058833122253 data/midi/v12/midi_sources/from_mxl/classical_archives/024/dgffc49.mid
# Super long file: 75.424795627594 data/midi/v12/midi_sources/from_mxl/classical_archives/024/cnsym4p2.mid
# Removed 528 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/023/cnsym4p1.mid. Skipping song
# Super long file: 91.07999062538147 data/midi/v12/midi_sources/from_mxl/classical_archives/024/jk_dvo8a.mid
# Super long file: 150.66373229026794 data/midi/v12/midi_sources/from_mxl/classical_archives/023/besy84.mid
# Super long file: 73.63692712783813 data/midi/v12/midi_sources/from_mxl/classical_archives/024/beethov.mid
# Super long file: 96.58293414115906 data/midi/v12/midi_sources/from_mxl/classical_archives/024/creature.mid
# Removed 464 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/024/flwiege.mid. Skipping song
# Super long file: 64.94829249382019 data/midi/v12/midi_sources/from_mxl/classical_archives/b/bwv988.mid
# Super long file: 83.99303221702576 data/midi/v12/midi_sources/from_mxl/classical_archives/024/schu_unf.mid
# Super long file: 79.69119334220886 data/midi/v12/midi_sources/from_mxl/classical_archives/024/jk_dvo8d.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/022/tmrustle.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/022/tmvexton.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 101.31144762039185 data/midi/v12/midi_sources/from_mxl/classical_archives/024/crucifix.mid
# Super long file: 127.57173871994019 data/midi/v12/midi_sources/from_mxl/classical_archives/024/schum_ps.mid
# Super long file: 362.336874961853 data/midi/v12/midi_sources/from_mxl/classical_archives/4/ritepti.mid
# Removed 572 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/022/k491c_1_.mid. Skipping song
# Super long file: 234.2654242515564 data/midi/v12/midi_sources/from_mxl/classical_archives/023/bach_inv.mid
# Super long file: 65.80122089385986 data/midi/v12/midi_sources/from_mxl/classical_archives/022/brtrov.mid
# Super long file: 214.6187868118286 data/midi/v12/midi_sources/from_mxl/classical_archives/023/finale1.mid
# Super long file: 80.33689045906067 data/midi/v12/midi_sources/from_mxl/classical_archives/022/jsmuso4h.mid
# Super long file: 72.17281913757324 data/midi/v12/midi_sources/from_mxl/classical_archives/022/wagner_s.mid
# Super long file: 131.41232585906982 data/midi/v12/midi_sources/from_mxl/classical_archives/024/beethove.mid
# Super long file: 72.6582293510437 data/midi/v12/midi_sources/from_mxl/classical_archives/022/jsgrhopi.mid
# Super long file: 234.0815143585205 data/midi/v12/midi_sources/from_mxl/classical_archives/023/dg_flpc1.mid
# Super long file: 244.73984670639038 data/midi/v12/midi_sources/from_mxl/classical_archives/023/yankdood.mid
# Super long file: 76.28779578208923 data/midi/v12/midi_sources/from_mxl/classical_archives/022/norma.mid
# Removed 548456 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/6/mozhrn1.mid. Skipping song
# Removed 384 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/6/mozk491c.mid. Skipping song
# Super long file: 132.72643518447876 data/midi/v12/midi_sources/from_mxl/classical_archives/024/mahler61.mid
# Super long file: 65.17591404914856 data/midi/v12/midi_sources/from_mxl/classical_archives/022/jk_br73d.mid
# Super long file: 116.82483005523682 data/midi/v12/midi_sources/from_mxl/classical_archives/024/dgjsbi3v.mid
# Super long file: 158.12379479408264 data/midi/v12/midi_sources/from_mxl/classical_archives/024/vorspie.mid
# Super long file: 80.4157395362854 data/midi/v12/midi_sources/from_mxl/classical_archives/022/pasquale.mid
# Super long file: 63.445844650268555 data/midi/v12/midi_sources/from_mxl/classical_archives/022/dvsy93-1.mid
# Super long file: 199.56585240364075 data/midi/v12/midi_sources/from_mxl/classical_archives/023/opus041_.mid
# Super long file: 153.6763985157013 data/midi/v12/midi_sources/from_mxl/classical_archives/024/dgjsbi2v.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/022/tmhysn02.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 90.42144751548767 data/midi/v12/midi_sources/from_mxl/classical_archives/022/brck8d.mid
# Super long file: 60.65107727050781 data/midi/v12/midi_sources/from_mxl/classical_archives/022/savqueen.mid
# Removed 352 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/6/tourdion.mid. Skipping song
# Super long file: 65.39361667633057 data/midi/v12/midi_sources/from_mxl/classical_archives/022/js_cls4h.mid
# Removed 432 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/022/wagner-1.mid. Skipping song
# Super long file: 148.7957797050476 data/midi/v12/midi_sources/from_mxl/classical_archives/024/wagnerth.mid
# Super long file: 68.28381562232971 data/midi/v12/midi_sources/from_mxl/classical_archives/022/rach2_1.mid
# Removed 452 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/022/2spohsym.mid. Skipping song
# Super long file: 165.77092242240906 data/midi/v12/midi_sources/from_mxl/classical_archives/024/vorspi.mid
# Super long file: 95.7142584323883 data/midi/v12/midi_sources/from_mxl/classical_archives/022/figale1.mid
# Super long file: 87.07804536819458 data/midi/v12/midi_sources/from_mxl/classical_archives/022/st_m123.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/0/handel2.mid index 775 is out of bounds for axis 0 with size 775
# Removed 704 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/6/eroica-3.mid. Skipping song
# Super long file: 65.06366109848022 data/midi/v12/midi_sources/from_mxl/classical_archives/6/dvv2.mid
# Super long file: 180.39903378486633 data/midi/v12/midi_sources/from_mxl/classical_archives/024/syswd365.mid
# Input path does not exist: data/midi/v12/midi_sources/from_mxl/classical_archives/0/bcpe554b.mid {'genres': 'classical', 'artist': 'bcpe554b', 'ht_key': nan, 'midi_title': nan, 'ht_mode': nan, 'mxl': 'midi_sources/classical_archives/0/bcpe554b.mxl', 'song_url': nan, 'ht_offset': nan, 'parts': nan, 'title': 'bcpe554b', 'ht_bpm': nan, 'ht_time_signature': nan, 'section': nan, 'midi': 'midi_sources/from_mxl/classical_archives/0/bcpe554b.mid', 'source': 'classical_archives', 'md5': 'f81472bdaaa6594912db5abbf7598ece'}
# Super long file: 78.13237142562866 data/midi/v12/midi_sources/from_mxl/classical_archives/022/rach2_3.mid
# Super long file: 61.312527894973755 data/midi/v12/midi_sources/from_mxl/classical_archives/6/italian1.mid
# Removed 544 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/6/lamer-1.mid. Skipping song
# Super long file: 92.04993557929993 data/midi/v12/midi_sources/from_mxl/classical_archives/6/carmen.mid
# Super long file: 271.75527238845825 data/midi/v12/midi_sources/from_mxl/classical_archives/023/varsfs10.mid
# Super long file: 61.15058708190918 data/midi/v12/midi_sources/from_mxl/classical_archives/6/bach1065.mid
# Super long file: 97.59638977050781 data/midi/v12/midi_sources/from_mxl/classical_archives/6/mozk467a.mid
# Super long file: 121.82862520217896 data/midi/v12/midi_sources/from_mxl/classical_archives/022/alkan_le.mid
# Super long file: 430.2727029323578 data/midi/v12/midi_sources/from_mxl/classical_archives/4/carnaval.mid
# Super long file: 171.09801650047302 data/midi/v12/midi_sources/from_mxl/classical_archives/022/dvsy94.mid
# Super long file: 201.0977966785431 data/midi/v12/midi_sources/from_mxl/classical_archives/024/beetho-1.mid
# Removed 912 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/024/tmcarnam.mid. Skipping song
# Super long file: 74.66897177696228 data/midi/v12/midi_sources/from_mxl/classical_archives/6/be-ps-06.mid
# Super long file: 180.41130208969116 data/midi/v12/midi_sources/from_mxl/classical_archives/022/beetvio1.mid
# Removed 528 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/tcsl02.mid. Skipping song
# Super long file: 129.40231490135193 data/midi/v12/midi_sources/from_mxl/classical_archives/6/beepc3_a.mid
# Super long file: 241.36955523490906 data/midi/v12/midi_sources/from_mxl/classical_archives/024/bwv1052.mid
# Super long file: 77.73815321922302 data/midi/v12/midi_sources/from_mxl/classical_archives/6/goun4maa.mid
# Super long file: 131.10542845726013 data/midi/v12/midi_sources/from_mxl/classical_archives/6/lebwohl.mid
# Super long file: 83.10878729820251 data/midi/v12/midi_sources/from_mxl/classical_archives/6/dvv1.mid
# Super long file: 64.84075903892517 data/midi/v12/midi_sources/from_mxl/classical_archives/6/mthuo74d.mid
# Super long file: 70.29204273223877 data/midi/v12/midi_sources/from_mxl/classical_archives/6/benedict.mid
# Super long file: 73.9689621925354 data/midi/v12/midi_sources/from_mxl/classical_archives/6/beet6h_1.mid
# Super long file: 291.3424654006958 data/midi/v12/midi_sources/from_mxl/classical_archives/023/act_5.mid
# Super long file: 118.32650852203369 data/midi/v12/midi_sources/from_mxl/classical_archives/6/haydns85.mid
# Super long file: 88.75582671165466 data/midi/v12/midi_sources/from_mxl/classical_archives/6/mahsy1-1.mid
# Super long file: 287.5719561576843 data/midi/v12/midi_sources/from_mxl/classical_archives/023/wagtanov.mid
# Super long file: 67.74596667289734 data/midi/v12/midi_sources/from_mxl/classical_archives/0/azbw1060.mid
# Super long file: 131.7093517780304 data/midi/v12/midi_sources/from_mxl/classical_archives/6/be-ps-32.mid
# Super long file: 65.98047089576721 data/midi/v12/midi_sources/from_mxl/classical_archives/0/jbbrand2.mid
# Super long file: 65.604651927948 data/midi/v12/midi_sources/from_mxl/classical_archives/0/bb5m1.mid
# Removed 1316 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/bergsym.mid. Skipping song
# Super long file: 164.3160526752472 data/midi/v12/midi_sources/from_mxl/classical_archives/6/mthuo74a.mid
# Super long file: 127.61974549293518 data/midi/v12/midi_sources/from_mxl/classical_archives/6/arpviola.mid
# Super long file: 153.80464673042297 data/midi/v12/midi_sources/from_mxl/classical_archives/022/dvsy91-1.mid
# Super long file: 167.43190717697144 data/midi/v12/midi_sources/from_mxl/classical_archives/022/fs_br1_4.mid
# Super long file: 71.64301419258118 data/midi/v12/midi_sources/from_mxl/classical_archives/0/brahms2.mid
# Super long file: 69.99555444717407 data/midi/v12/midi_sources/from_mxl/classical_archives/0/kv622a.mid
# Super long file: 95.57928347587585 data/midi/v12/midi_sources/from_mxl/classical_archives/6/jsbbrc3.mid
# Super long file: 65.77969241142273 data/midi/v12/midi_sources/from_mxl/classical_archives/0/vstragic.mid
# Super long file: 80.2757740020752 data/midi/v12/midi_sources/from_mxl/classical_archives/0/double.mid
# Super long file: 91.19813776016235 data/midi/v12/midi_sources/from_mxl/classical_archives/0/beet61a2.mid
# Super long file: 65.00444269180298 data/midi/v12/midi_sources/from_mxl/classical_archives/0/brmsreq6.mid
# Super long file: 92.24186444282532 data/midi/v12/midi_sources/from_mxl/classical_archives/0/tcsl2829.mid
# Input path does not exist: data/midi/v12/midi_sources/from_mxl/classical_archives/0/p15gmaj.mid {'genres': 'classical', 'artist': 'p15gmaj', 'ht_key': nan, 'midi_title': nan, 'ht_mode': nan, 'mxl': 'midi_sources/classical_archives/0/p15gmaj.mxl', 'song_url': nan, 'ht_offset': nan, 'parts': nan, 'title': 'p15gmaj', 'ht_bpm': nan, 'ht_time_signature': nan, 'section': nan, 'midi': 'midi_sources/from_mxl/classical_archives/0/p15gmaj.mid', 'source': 'classical_archives', 'md5': '1deeb2de081ffbb2fc211a586ac679e5'}
# Super long file: 68.3051700592041 data/midi/v12/midi_sources/from_mxl/classical_archives/0/chpnc2-1.mid
# Removed 340 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/sixtine.mid. Skipping song
# Super long file: 98.86665344238281 data/midi/v12/midi_sources/from_mxl/classical_archives/0/br56b.mid
# Super long file: 106.85578274726868 data/midi/v12/midi_sources/from_mxl/classical_archives/6/alkqufa.mid
# Super long file: 92.97370266914368 data/midi/v12/midi_sources/from_mxl/classical_archives/0/brand3.mid
# Super long file: 178.61119174957275 data/midi/v12/midi_sources/from_mxl/classical_archives/6/eroica-1.mid
# Super long file: 162.97832345962524 data/midi/v12/midi_sources/from_mxl/classical_archives/6/lvbop80.mid
# Removed 508 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/hayq5014.mid. Skipping song
# Removed 360 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/tcsl19.mid. Skipping song
# Super long file: 88.18461871147156 data/midi/v12/midi_sources/from_mxl/classical_archives/0/mensy3-4.mid
# Super long file: 61.483824491500854 data/midi/v12/midi_sources/from_mxl/classical_archives/0/hp1812.mid
# Super long file: 127.36168646812439 data/midi/v12/midi_sources/from_mxl/classical_archives/0/br-ps-01.mid
# Super long file: 66.13579034805298 data/midi/v12/midi_sources/from_mxl/classical_archives/0/hungrp12.mid
# Removed 376 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/brmsreq7.mid. Skipping song
# Super long file: 101.3848865032196 data/midi/v12/midi_sources/from_mxl/classical_archives/0/spantanz.mid
# Super long file: 161.0716598033905 data/midi/v12/midi_sources/from_mxl/classical_archives/6/mthmop70.mid
# Super long file: 69.31057167053223 data/midi/v12/midi_sources/from_mxl/classical_archives/0/obermann.mid
# Removed 308 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/brmsreq1.mid. Skipping song
# Removed 712 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/brmsreq3.mid. Skipping song
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/0/mah7-1dv.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 64.35889554023743 data/midi/v12/midi_sources/from_mxl/classical_archives/0/mhqop87a.mid
# Removed 712 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/012/tallspem.mid. Skipping song
# Super long file: 79.08790445327759 data/midi/v12/midi_sources/from_mxl/classical_archives/0/tch1811.mid
# npenc exceeds max 128 duration: data/midi/v12/midi_sources/from_mxl/classical_archives/0/neptune.mid
# Super long file: 74.46997499465942 data/midi/v12/midi_sources/from_mxl/classical_archives/0/moz24cm1.mid
# Super long file: 127.63238143920898 data/midi/v12/midi_sources/from_mxl/classical_archives/0/mensy3-1.mid
# Super long file: 113.56344890594482 data/midi/v12/midi_sources/from_mxl/classical_archives/0/beet71gs.mid
# Removed 848 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/frakjuge.mid. Skipping song
# Super long file: 70.3550672531128 data/midi/v12/midi_sources/from_mxl/classical_archives/0/beeth6-1.mid
# Super long file: 81.1675853729248 data/midi/v12/midi_sources/from_mxl/classical_archives/0/italiana.mid
# Super long file: 77.99569916725159 data/midi/v12/midi_sources/from_mxl/classical_archives/0/pits4f-1.mid
# Removed 464 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/tcsl13.mid. Skipping song
# Super long file: 137.63252115249634 data/midi/v12/midi_sources/from_mxl/classical_archives/0/br56a.mid
# Super long file: 185.5758078098297 data/midi/v12/midi_sources/from_mxl/classical_archives/6/be-ps-21.mid
# Super long file: 190.3642818927765 data/midi/v12/midi_sources/from_mxl/classical_archives/6/be-ps-23.mid
# Super long file: 63.998400926589966 data/midi/v12/midi_sources/from_mxl/classical_archives/0/concp25a.mid
# Removed 320 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/6/festklng.mid. Skipping song
# Super long file: 71.24608707427979 data/midi/v12/midi_sources/from_mxl/classical_archives/0/egyptien.mid
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/012/tmgaudet.mid
# Super long file: 68.40925312042236 data/midi/v12/midi_sources/from_mxl/classical_archives/0/spohr1a.mid
# Removed 1108 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/00crnval.mid. Skipping song
# Super long file: 71.13255643844604 data/midi/v12/midi_sources/from_mxl/classical_archives/0/humm81m3.mid
# Removed 320 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/012/saturn.mid. Skipping song
# Removed 400 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/012/rg135b1b.mid. Skipping song
# Super long file: 107.05656790733337 data/midi/v12/midi_sources/from_mxl/classical_archives/0/brahms1.mid
# Removed 376 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/012/parsifal.mid. Skipping song
# Super long file: 81.55941891670227 data/midi/v12/midi_sources/from_mxl/classical_archives/0/cenerent.mid
# Super long file: 87.22090411186218 data/midi/v12/midi_sources/from_mxl/classical_archives/0/otislam.mid
# Removed 424 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/webrul.mid. Skipping song
# Super long file: 95.96663212776184 data/midi/v12/midi_sources/from_mxl/classical_archives/0/tch361.mid
# Super long file: 113.57740211486816 data/midi/v12/midi_sources/from_mxl/classical_archives/0/br-ps-03.mid
# Removed 1144 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/8/bru9_1.mid. Skipping song
# Super long file: 70.7145471572876 data/midi/v12/midi_sources/from_mxl/classical_archives/012/ee1416.mid
# Super long file: 61.70249629020691 data/midi/v12/midi_sources/from_mxl/classical_archives/012/beet_moo.mid
# Super long file: 81.23510670661926 data/midi/v12/midi_sources/from_mxl/classical_archives/0/bbdanube.mid
# Removed 488 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/012/hayq5031.mid. Skipping song
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/012/tmshurg.mid index 127 is out of bounds for axis 2 with size 127
# Super long file: 96.21350646018982 data/midi/v12/midi_sources/from_mxl/classical_archives/0/anna-02.mid
# Super long file: 101.83350968360901 data/midi/v12/midi_sources/from_mxl/classical_archives/0/sona13.mid
# Super long file: 90.91823482513428 data/midi/v12/midi_sources/from_mxl/classical_archives/0/beet74gs.mid
# Super long file: 168.53414344787598 data/midi/v12/midi_sources/from_mxl/classical_archives/0/mozk313.mid
# Super long file: 90.25303077697754 data/midi/v12/midi_sources/from_mxl/classical_archives/012/td_b1050.mid
# Removed 472 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/0/brahmpc1.mid. Skipping song
# npenc out of note range 12 - 116: data/midi/v12/midi_sources/from_mxl/classical_archives/012/debetd7.mid
# Super long file: 71.78210115432739 data/midi/v12/midi_sources/from_mxl/classical_archives/012/tod_men.mid
# Super long file: 117.96538543701172 data/midi/v12/midi_sources/from_mxl/classical_archives/0/br-ps-02.mid
# Super long file: 139.82769417762756 data/midi/v12/midi_sources/from_mxl/classical_archives/0/anspgpol.mid
# Super long file: 164.32155990600586 data/midi/v12/midi_sources/from_mxl/classical_archives/0/marchind.mid
# Super long file: 162.8228669166565 data/midi/v12/midi_sources/from_mxl/classical_archives/0/rsch31.mid
# ...
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Sequence too short: 17 data/midi/v12/midi_sources/hooktheory/pianoroll/m/men-at-work/land-down-under/intro_key_cmajor.mid
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Super long file: 92.61736273765564 data/midi/v12/midi_sources/from_mxl/classical_archives/2/lvbsym81.mid
# Sequence too short: 21 data/midi/v12/midi_sources/hooktheory/pianoroll/m/microsoft/windows-xp-startup-sound/instrumental_key_cmajor.mid
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-15-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-8ce624b49e4b>", line 32, in transform_func
#     stream = file2stream(input_file) # 1.
#   File "../../src/midi_data.py", line 78, in file2stream
#     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 2115, in midiFileToStream
#     **keywords)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/translate.py", line 1905, in midiTracksToStreams
#     p = s.getElementsByClass('Stream')[0]
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/iterator.py", line 328, in __getitem__
#     e = fe[k]
# IndexError: list index out of range
#
# Super long file: 63.1710684299469 data/midi/v12/midi_sources/from_mxl/classical_archives/032/grande_s.mid
# Super long file: 178.25520586967468 data/midi/v12/midi_sources/from_mxl/classical_archives/2/danteson.mid
# Super long file: 62.4464008808136 data/midi/v12/midi_sources/from_mxl/classical_archives/032/ajsluc02.mid
# Super long file: 109.07206130027771 data/midi/v12/midi_sources/from_mxl/classical_archives/2/fc-op2.mid
# Super long file: 72.74507069587708 data/midi/v12/midi_sources/from_mxl/classical_archives/032/violin_v.mid
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Super long file: 148.6588113307953 data/midi/v12/midi_sources/from_mxl/classical_archives/2/ee1132.mid
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Super long file: 102.31447052955627 data/midi/v12/midi_sources/from_mxl/classical_archives/2/strpetr.mid
# Super long file: 103.20752620697021 data/midi/v12/midi_sources/from_mxl/classical_archives/2/grifson.mid
# Removed 516 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/032/niel_s11.mid. Skipping song
# Super long file: 291.60509753227234 data/midi/v12/midi_sources/from_mxl/classical_archives/1/3mephis.mid
# Super long file: 92.88618898391724 data/midi/v12/midi_sources/from_mxl/classical_archives/032/humsept1.mid
# Super long file: 98.68500685691833 data/midi/v12/midi_sources/from_mxl/classical_archives/2/smetsy3.mid
# Super long file: 113.51791644096375 data/midi/v12/midi_sources/from_mxl/classical_archives/2/humm_t6.mid
# Super long file: 1191.339098930359 data/midi/v12/midi_sources/from_mxl/classical_archives/011/die_kuns.mid
# Super long file: 118.53213882446289 data/midi/v12/midi_sources/from_mxl/classical_archives/2/dj2pian1.mid
# Super long file: 188.33428263664246 data/midi/v12/midi_sources/from_mxl/classical_archives/2/lvbsym31.mid
# Super long file: 207.06468749046326 data/midi/v12/midi_sources/from_mxl/classical_archives/2/sysvasen.mid
# Super long file: 134.87902998924255 data/midi/v12/midi_sources/from_mxl/classical_archives/2/humm_t7.mid
# Super long file: 78.25460124015808 data/midi/v12/midi_sources/from_mxl/classical_archives/032/concert5.mid
# Could not encode to chordarr: data/midi/v12/midi_sources/from_mxl/classical_archives/032/brahmsqu.mid index 127 is out of bounds for axis 2 with size 127
# Removed 576 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/1/bruck3-1.mid. Skipping song
# Super long file: 112.6842668056488 data/midi/v12/midi_sources/from_mxl/classical_archives/2/djblanik.mid
# Super long file: 279.84078431129456 data/midi/v12/midi_sources/from_mxl/classical_archives/2/tasso.mid
# Super long file: 100.46584677696228 data/midi/v12/midi_sources/from_mxl/classical_archives/032/carnanim.mid
# Super long file: 78.47251582145691 data/midi/v12/midi_sources/from_mxl/classical_archives/032/scsymetu.mid
# Super long file: 574.0539107322693 data/midi/v12/midi_sources/from_mxl/classical_archives/9/be-pv20r.mid
# Super long file: 582.4275476932526 data/midi/v12/midi_sources/from_mxl/classical_archives/9/brop24.mid
# Removed 992 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/1/bwv988.mid. Skipping song
# Super long file: 1312.104087114334 data/midi/v12/midi_sources/from_mxl/classical_archives/011/hetderde.mid
# Removed 520 rests from data/midi/v12/midi_sources/from_mxl/classical_archives/011/wohl_1.mid. Skipping song

# %%
processed = process_all(try_transform_func, all_records)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='180965' class='' max='180965', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [180965/180965 00:53<00:00]
#     </div>

# %%
from src.data_sources import arr2csv

# %%
arr2csv(processed, out_csv); len(processed)

# %%
df = pd.read_csv(out_csv)

# %%
df.head()
