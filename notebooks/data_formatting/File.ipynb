# %%
test_file = 'data/midi/v10/midi_sources/ecomp/2008/Huang14.mxl'

# %%
import music21

# %%
s = music21.converter.parse(test_file)

# %%
s.show('text')
# Out:
# {0.0} <music21.metadata.Metadata object at 0x7f048c36de10>
# {0.0} <music21.stream.PartStaff P1-Staff1>
#     {0.0} <music21.instrument.Instrument P1: Piano, Paysage--Nansong Huang: Piano>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.clef.BassClef>
#         {0.0} <music21.tempo.MetronomeMark vivace Quarter=162.0>
#         {0.0} <music21.key.KeySignature of 1 flat>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.note.Rest rest>
#         {2.0} <music21.note.Rest rest>
#         {3.0} <music21.note.Rest rest>
#         {3.5} <music21.note.Rest rest>
#         {3.625} <music21.note.Note F>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest rest>
#             {0.5} <music21.note.Note F>
#             {2.0} <music21.note.Note C>
#         {0.0} <music21.stream.Voice 2>
# ...
