# %% [markdown]
# ### Create CSV from midi sources

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import glob
import os
from tqdm import tqdm
from IPython.display import Image, Audio
import traceback

# %%
# parallel
from functools import partial
from pathlib import Path

# %%
import sys
sys.path.insert(0, '../../')

# %%
from src.data_sources import *
from src.midi_data import *

# %%
version = 'v10'
data_path = Path('data/midi')
version_path = data_path/version
orig_path = version_path/'midi_sources'
metapath = version_path/'metadata'
all_csv = metapath/'midi_sources.csv'
metapath.mkdir(parents=True, exist_ok=True)

# %%
def create_paths(dirname):
    "Standardize midi_source paths"
    dir_path = orig_path/dirname
    json_path = metapath/f'{dirname}_metadata.json'
    csv_path = metapath/f'{dirname}_metadata.csv'
    return dir_path, json_path, csv_path

# %%
sources = ['hooktheory', 'freemidi', 'midiworld', 'ecomp', 'cprato', 'classic_piano', 'wikifonia', 'lmd_clean', '130k_reddit']

# %%
version_path.relative_to(data_path)
# Out:
# PosixPath('v8')

# %%
def relative_path(filepath):
    return str(Path(filepath).relative_to(version_path))

# %% [markdown]
# ### Remove corrupted file - this causes deadlock with music21 processing

# %%
corrupted_files = [
    'midiworld/named_midi/NITRO_BRO_-_IT_WONT_DIE.mid',
    'ecomp/2004/MORET02.mid',
    'ecomp/2006/Mordvinov9.MID',
    'ecomp/2006/Na06.MID',
    'ecomp/2008/Cui01.MID',
    'ecomp/2008/Cui02.MID',
    'ecomp/2008/Cui03.MID',
    'ecomp/2008/Cui04.MID',
    'ecomp/2008/Cui05.MID',
    'ecomp/2008/Cui06.MID',
    'ecomp/2008/Cui07.MID',
    'ecomp/2008/Cui08.MID',
    'ecomp/2008/Tan01.MID',
    'ecomp/2008/Tan02.MID',
    'ecomp/2008/Tan03.MID',
    'ecomp/2018/KaszoS14.MID',
    'midiworld/named_midi/Rob_Zombie_-_Demonoid_Phenomenon.mid',
    'midiworld/named_midi/Rob_Zombie_-_Demonoid_Phenomenon.mxl',
]
for f in corrupted_files:
    fp = orig_path/f
    if fp.exists(): fp.unlink()

# %% [markdown]
# ### Hooktheory

# %%
ht_path, ht_json, ht_csv = create_paths('hooktheory')
ht_song_list = metapath/'hooktheory_key2info.json'

# %%
def song_key(s): return '_'.join(s.parts[-3:-1])

# %%
ht_key2info = load_json(ht_song_list)

if ht_key2info is None:
    song_info = list((ht_path/'xml').glob('*/*/*/*.json'))
    ht_key2info = {song_key(s):json.load(open(s, 'r')) for s in song_info}
    save_json(ht_key2info, ht_song_list)
len(ht_key2info)
# Out:
# 12008

# %%
ht_midi_list = list((ht_path/'pianoroll').glob('*/*/*/*_key_cmajor.mid')); 
len(ht_midi_list)
# Out:
# 20076

# %%
def get_ht_jsonfile(midi_file): # using json instead of midi for metadata
    return str(midi_file.with_suffix('.json')).replace('pianoroll', 'event').replace('_key', '_symbol_key')

# %%
def get_hooktheory_attr(fp):
    song_info = ht_key2info[song_key(fp)]
    song_json = json.load(open(get_ht_jsonfile(fp), 'r'))
    metadata = song_json['metadata']
    artist = fp.parts[-3]
    title = fp.parts[-2]
    section = fp.name.split('_')[0]
    
    ht_key = metadata['key']
    ht_mode = metadata['mode']
    if ht_mode is None: ht_mode = 'major'
    ht_offset = keyc_offset(ht_key, ht_mode)
    
    # convert stream here
    return {
        'artist': artist,
        'title': title,
        'midi': relative_path(fp),
        'section': section,
        'parts': song_info['section'],
        'song_url': song_info['song_url'],
        'genres': song_info['genres'],
        'midi_title': metadata['title'],
        'source': 'hooktheory',
        'ht_bpm': metadata['BPM'],
        'ht_mode': metadata['mode'],
        'ht_key': metadata['key'],
        'ht_offset': ht_offset,
        'ht_time_signature': metadata['beats_in_measure']
    }

# %%
# sanity check
# hook_out = get_hooktheory_attr(song_json[1000]); hook_out

# %%
ht_metadata = parse_midi_dir(ht_midi_list, ht_json, base_path=version_path, 
                             meta_func=get_hooktheory_attr)
# Out:
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/w/weezer/beverly-hills/intro-and-verse_key_cmajor.mid list index out of range
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20076' class='' max='20076', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20076/20076 00:40<00:00]
#     </div>
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/w/wolfgang-amadeus-mozart/symphony-no-25-in-g-minor/intro-and-verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/y/ylvis/the-fox---what-does-the-fox-say/verse-and-pre-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/j/jay-z/so-ambitious-feat-pharrel-williams/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/j/johnny-cash/folsom-prison-blues/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/j/jack-johnson/do-you-remember/intro-and-verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/j/justin-moore/if-heaven-wasnt-so-far-awat/intro-and-verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/j/john-cage/433/solo_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/l/lykke-li/get-some/pre-chorus-and-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/l/lykke-li/get-some/intro-and-verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/l/legend-of-zelda---ocarina-of-time/song-of-storms/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/v/vanessa-hudgens/when-there-was-me-and-you---high-school-musical/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/b/benjamin-ingrosso/good-lovin/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/b/bobby-dreher/last-tomorrow/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/z/zun/vanishing-dream---lost-dream/instrumental_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/d/dr-dre/smoke-weed-everyday/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/x/xxxtentacion/orlando/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/x/xyconstant/white-noise/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/s/switchfoot/dare-you-to-move/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/s/snakehips/dont-leave/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/s/slam-dunk---da-funk/five/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/s/sia/titanium/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/c/clean-bandit/solo-feat-demi-lovato/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/c/cal-tjader/curacao-/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/c/carrie-underwood/before-he-cheats/pre-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/e/equinox/bones/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/e/elvis-presley/suspicious-minds/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/n/nozomi-aoki/fist-of-the-north-star---combat/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/n/nintendo/super-smash-bros-brawl/pre-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/i/ifhy/tyler-the-creator/bridge_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/i/instrumental/you-raise-me-up/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/h/harvest-moon/a-wonderful-life---breeze/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/h/hans-zimmer/the-red-capes-are-coming/instrumental_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/p/puppenhaus/untitled/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/p/pink-and-white/frank-ocean/pre-outro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/p/pearl-jam/pearl-jam/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/p/percy-mayfield/please-send-me-someone-to-love/intro-and-verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/toby-fox/determination/pre-chorus-and-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/the-meters/what-cha-say/intro-and-verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/the-good-and-the-damned/little-electric/bridge_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/twilight-soundtrack/bellas-lullaby/_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/taylor-swift/you-belong-with-me/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/taichi-mukai/reset-%2528kaze-ga-tsuyoku-fuiteiru%2529/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/taichi-mukai/reset/_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/the-waifs/london-still/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/take-us-back/alela-diane/verse-and-pre-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/take-us-back/alela-diane/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/the-rasmus/in-the-shadows/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/the-beatles/drive-my-car/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/t/the-beatles/the-end/solo_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/k/katy-pary/fireworks/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/k/kim-carnes/bette-davis-eyes/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/k/kirbys-adventure---rainbow-resort/nintendo/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/k/kelly-clarkson/breakaway/verse-and-pre-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/k/katy-perry/peacock/verse-and-pre-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/r/random-movement/down-somehow/instrumental_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/r/random-movement/down-somehow/verse_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/r/radiohead/motion-picture-soundtrack/verse-and-pre-chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/m/minae-fuji/mega-man-4---ring-man/chorus_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/m/michiru-yamane/gaze-up-at-the-darkness/instrumental_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/m/muse/muscle-museum/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/q/queen/bohemian-rhapsody/pre-outro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/q/queen/bohemian-rhapsody/outro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/q/queen/bohemian-rhapsody/instrumental_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/a/adventure-club/wonder/outro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/a/adventure-club/wonder/bridge_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/a/antonio-vivaldi/the-four-seasons-concerto-no-4-winter/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/a/adelina-tahiri/heart-on-fire/intro_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/a/antonim/melancholy-soldier/bridge_key_cmajor.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/hooktheory/pianoroll/a/asf/asdfas/intro-and-verse_key_cmajor.mid list index out of range

# %% [markdown]
# #### Save song_list

# %%
ht_metadata = load_json(ht_json)
arr2csv(ht_metadata.values(), ht_csv)
df = pd.read_csv(ht_csv); df.head()
# Out:
#    inferred_offset                                           song_url  \
# 0              0.0  https://www.hooktheory.com/theorytab/view/wayn...
# 1              0.0  https://www.hooktheory.com/theorytab/view/wayn...
# 2              5.0  https://www.hooktheory.com/theorytab/view/what...
# 3              NaN  https://www.hooktheory.com/theorytab/view/weez...
# 4              0.0  https://www.hooktheory.com/theorytab/view/weez...
#
#    instruments  ht_mode              midi_title                title  \
# 0        Piano        1                yu-gi-oh  yu-gi-oh-theme-song
# 1  Piano,Piano        1               yu-gi-oh3  yu-gi-oh-theme-song
# 2  Piano,Piano        1                  kiefer               kiefer
# 3          NaN        1             My New Song        beverly-hills
# 4  Piano,Piano        1  Weezer - Fall Together       fall-together-
#
#      seconds                                               midi inferred_key  \
# 0  25.411765  midi_sources/hooktheory/pianoroll/w/wayne-shar...      C major
# 1  15.000000  midi_sources/hooktheory/pianoroll/w/wayne-shar...      C major
# 2  10.000000  midi_sources/hooktheory/pianoroll/w/what-a-day...      E minor
# 3        NaN  midi_sources/hooktheory/pianoroll/w/weezer/bev...          NaN
# 4  10.322581  midi_sources/hooktheory/pianoroll/w/weezer/fal...      A minor
#
#    quarter_length  ...        source ht_offset  ht_bpm        artist ht_key  \
# 0            36.0  ...    hooktheory         0      85  wayne-sharpe      C
# 1            32.0  ...    hooktheory         0     128  wayne-sharpe      C
# 2            16.0  ...    hooktheory         0      96    what-a-day      C
# 3             NaN  ...    hooktheory         0     128        weezer      C
# 4            16.0  ...    hooktheory         0      93        weezer      C
#
#   ht_time_signature    bpm          section            parts genres
# 0                 3   85.0            intro     intro,chorus    NaN
# 1                 4  128.0           chorus     intro,chorus    NaN
# 2                 4   96.0           chorus           chorus   Jazz
# 3                 4    NaN  intro-and-verse  intro-and-verse    NaN
# 4                 4   93.0           chorus           chorus   Rock
#
# [5 rows x 21 columns]

# %% [markdown]
# ## FreeMidi

# %%
fm_path, _, fm_csv = create_paths('freemidi')
fm_dance_path = metapath/f'freemidi_dance_metadata.json'
fm_pop_path = metapath/f'freemidi_pop_metadata.json'
list(fm_path.glob('*'))
# Out:
# [PosixPath('data/midi/v8/midi_sources/freemidi/genre-disco'),
#  PosixPath('data/midi/v8/midi_sources/freemidi/genre-pop'),
#  PosixPath('data/midi/v8/midi_sources/freemidi/genre-dance-eletric'),
#  PosixPath('data/midi/v8/midi_sources/freemidi/genre-punk'),
#  PosixPath('data/midi/v8/midi_sources/freemidi/genre-hip-hop-rap'),
#  PosixPath('data/midi/v8/midi_sources/freemidi/genre-rock')]

# %%
def parse_freemidi_songs(fp, genres=None, source=None):
    name = fp.with_suffix('').name.split(' - ')
    artist = name[0]
    title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': genres,
        'source': source
    }

# %%
d_parse_func = partial(parse_freemidi_songs, genres='dance', source='freemidi')
dir_path = fm_path/'genre-dance-eletric'
file_list = get_files(dir_path, extensions=['.mid'], recurse=True)
fm_dance_list = parse_midi_dir(file_list, fm_dance_path,
                               base_path=version_path, meta_func=d_parse_func)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='0', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100% [0/0]
#     </div>

# %%
p_parse_func = partial(parse_freemidi_songs, genres='pop', source='freemidi')
dir_path = fm_path/'genre-pop'
file_list = get_files(dir_path, extensions=['.mid'], recurse=True)
fm_pop_list = parse_midi_dir(file_list, fm_pop_path,
                             base_path=version_path, meta_func=p_parse_func)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='0', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100% [0/0]
#     </div>

# %%
fmd = load_json(fm_dance_path)
fmp = load_json(fm_pop_path)
fm_all = list(fmd.values())+list(fmp.values())
arr2csv(fm_all, fm_csv)
df = pd.read_csv(fm_csv); df.head()
# Out:
#   genres time_signature    source  \
# 0  dance            NaN  freemidi
# 1  dance            4/4  freemidi
# 2  dance            NaN  freemidi
# 3  dance            4/4  freemidi
# 4  dance            4/4  freemidi
#
#                                                 midi                  title  \
# 0  midi_sources/freemidi/genre-dance-eletric/Glor...  I'm Not Givin' You Up
# 1  midi_sources/freemidi/genre-dance-eletric/Radi...         Fitter Happier
# 2  midi_sources/freemidi/genre-dance-eletric/Tune...                 Bounce
# 3  midi_sources/freemidi/genre-dance-eletric/Daft...               The Grid
# 4  midi_sources/freemidi/genre-dance-eletric/Prod...           Action Radar
#
#                                          instruments inferred_key    bpm  \
# 0                                                NaN          NaN    NaN
# 1                                        Piano,Piano      G minor   76.0
# 2                                                NaN      F major  142.0
# 3  StringInstrument,StringInstrument,StringInstru...     C# minor  102.0
# 4                                              Piano      A major  147.0
#
#      seconds          artist  inferred_offset quarter_length
# 0        NaN  Gloria Estefan              NaN            NaN
# 1  85.263158       Radiohead              2.0          108.0
# 2  28.732394         Tune Up             -5.0           68.0
# 3  40.000000       Daft Punk             -4.0           68.0
# 4  91.632653         Prodigy              3.0          224.5

# %% [markdown]
# ### Gather Lakh Midi Dataset

# %%
lmd_path, lmd_json, lmd_csv = create_paths('lmd_clean')

# %%
def parse_lmd_songs(fp):
    artist = fp.parts[-2]
    title = fp.parts[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': 'pop,inferred',
        'source': 'lmd'
    }

# %%
file_list = get_files(lmd_path, extensions=['.mid'], recurse=True)
lmd_md = parse_midi_dir(file_list, lmd_json, base_path=version_path, meta_func=parse_lmd_songs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17243' class='' max='17243', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [17243/17243 30:25<00:00]
#     </div>
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/The Police/So Lonely.1.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Phish/Taste.mid badly formated midi bytes, got: b'CAKEWALK\x1a\x00\x03\n\x02\x00\x00\x00x\x00\x03Y'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jennifer Lopez/If You Had My Love.mid badly formated midi bytes, got: b'RIFFN\x07\x01\x00RMIDdataA\x07\x01\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Alice in Chains/Sludge Factory.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Sarah McLachlan/Adia.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Yanni/Secret Vows.1.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Yanni/The Rain Must Fall.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Yanni/Aria.1.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Yanni/Swept Away.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Yanni/Marching Season.1.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/John Elton/Sacrifice.3.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/John Elton/I Don't Wanna Go On With You Like That.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Metallica/The Unforgiven.3.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Metallica/The Shortest Straw.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Metallica/(Anesthesia)-Pulling Teeth.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Aerosmith/Pink.3.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Buddy Holly/Peggy Sue.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/ABBA/I've Been Waiting For You.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/ABBA/Voulez Vous.1.mid cannot place n between multiples: 4.3168778689674135e+31, 4.3168778689674135e+31
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/U2/Walk On.mid badly formated midi bytes, got: b'STAR DATA V3.50\x1a\x11\x01\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Sting/Fields of Gold.1.mid badly formated midi bytes, got: b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Sting/Fields of Gold.7.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/The Stylistics/I'm Stone in Love With You.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/R.E.M./Nightswimming.mid badly formated midi bytes, got: b'RIFF\xde[\x00\x00RMIDdata\xd2[\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Daft Punk/Da Funk.mid badly formated midi bytes, got: b'%\xb1\xb9O\x15\x9d+\xe5\x1ei\xe5W\x150\xd6\xad\x1c\xb1\xc2Q'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Barbra Streisand/The Way We Were.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Frank Sinatra/New York, New York (theme du film).mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/The Prodigy/Climbatize.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Pet Shop Boys/Always on My Mind   In My House.3.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Wonder Stevie/Sir Duke.1.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Brian McKnight/On the Down Low.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Genesis/Abacab.3.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jamiroquai/Canned Heat.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Rednex/The Ultimate Rednex Mega Mix, Part 3: Cotton Eye Joe.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Third Eye Blind/Semi-Charmed Life.mid badly formated midi bytes, got: b'RIFFV\x0c\x01\x00RMIDdataI\x0c\x01\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Third Eye Blind/Semi-Charmed Life.1.mid badly formated midi bytes, got: b'RIFF\xc0\x0c\x01\x00RMIDdata\xb3\x0c\x01\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jackson Michael/Smooth Criminal.mid badly formated midi bytes, got: b'RIFF|\x9a\x00\x00RMIDdata\xb5\x99\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jackson Michael/I'll Be There.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jackson Michael/The Girl Is Mine.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jackson Michael/Thriller.3.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jackson Michael/The Girl Is Mine.3.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Jackson Michael/Don't Stop 'Til You Get Enough.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/The Offspring/No Hero.mid badly formated midi bytes, got: b'RIFF\x04N\x01\x00RMIDdata\xf7M\x01\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Mariah Carey/Long Ago.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Bryan Adams/(Everything I Do) I Do It For You.7.mid badly formated midi bytes, got: b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Garbage/Cherry Lips.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Garbage/Stupid Girl.3.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Los Del Rio/Macarena.1.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Ludwig van Beethoven/Ode to Joy from the 9th Symphony.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/The Cranberries/Promises.1.mid badly formated midi bytes, got: b'STAR DATA V3.50\x1a\x11\x01\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Pink Floyd/High Hopes.2.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Pink Floyd/Hey You.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Fleetwood Mac/Sara.1.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Fleetwood Mac/Angel.1.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Fleetwood Mac/Angel.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Eric Clapton/Tears in Heaven.7.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Madonna/Deeper and Deeper.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Negative Creep.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Mr. Moustache.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Swap Meet.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Dumb.2.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Turnaround.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Smells Like Teen Spirit.8.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/(New Wave) Polly.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/All Apologies.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Drain You.mid cannot handle ticks per frame: 77
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Hairspray Queen.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Dive.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/tourette's.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Radio Friendly Unit Shifter.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Sliver.2.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Milk It.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Aneurysm.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Downer.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Territorial Pissings.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Been a Son.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Mexican Seafood.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Lounge Act.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Scentless Apprentice.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Son of a Gun.2.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Pennyroyal Tea.2.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Heart-Shaped Box.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Polly.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Frances Farmer Will Have Her Revenge on Seattle.1.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Nirvana/Love Buzz.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Supertramp/The Logical Song.7.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Supertramp/Bloody Well Right.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/The Rolling Stones/The Last Time.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Bon Jovi/Blaze of Glory.2.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Tool/Flood.mid badly formated midi bytes, got: b'\xb0\xc7=C\x10\x85\xa3`\xb4\xd9\x96\x9e\xfd\xb2\x8ar\x01a\xf2O'
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Bee Gees/Stayin Alive.3.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Bee Gees/Too Much Heaven.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/lmd_clean/Amedeo Minghi/Decenni.1.mid badly formed midi string: missing leading MTrk

# %%
lmd = load_json(lmd_json)
arr2csv(lmd.values(), lmd_csv)
df = pd.read_csv(lmd_csv); df.head()
# Out:
#          genres time_signature source  \
# 0  pop,inferred            4/4    lmd
# 1  pop,inferred            4/4    lmd
# 2  pop,inferred            4/4    lmd
# 3  pop,inferred            4/4    lmd
# 4  pop,inferred            4/4    lmd
#
#                                                 midi  \
# 0            midi_sources/lmd_clean/Moby/J Breas.mid
# 1  midi_sources/lmd_clean/Moby/The Blue Terror of...
# 2  midi_sources/lmd_clean/Joseph Kosma/Autumn Lea...
# 3  midi_sources/lmd_clean/Anne Murray/You Needed ...
# 4            midi_sources/lmd_clean/Hanson/Weird.mid
#
#                           title                                  instruments  \
# 0                   J Breas.mid                       Piano,StringInstrument
# 1  The Blue Terror of Lawns.mid                              Electric Guitar
# 2             Autumn Leaves.mid                Vibraphone,Acoustic Bass,Oboe
# 3             You Needed Me.mid                            Guitar,Horn,Flute
# 4                     Weird.mid  Piano,Piano,Acoustic Bass,Piano,Piano,Piano
#
#   inferred_key    bpm     seconds        artist  inferred_offset  \
# 0      E minor  100.0  142.200000          Moby              5.0
# 1      A minor   86.0  199.736390          Moby              0.0
# 2      E minor   96.0  151.910112  Joseph Kosma              5.0
# 3     B- major   65.0  206.769231   Anne Murray              2.0
# 4     B- major   68.0         NaN        Hanson              2.0
#
#   quarter_length
# 0          237.0
# 1         1699/6
# 2         231.75
# 3          224.0
# 4          272.0

# %% [markdown]
# ### Gather 130k Reddit

# %%
reddit_path, reddit_json, reddit_csv = create_paths('130k_reddit')

# %%
def parse_reddit_songs(fp):
    name = fp.with_suffix('').name.replace('_', ' ').split(' - ')
    if len(name) == 1:
        artist = fp.parts[-1]
        title = name[0]
    else:
        artist = name[0]
        title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': 'anything,inferred',
        'source': 'reddit'
    }

# %%
file_list = get_files(reddit_path, extensions=['.mid'], recurse=True)
file_list = [fp for fp in file_list if fp.stat().st_size/1000 < 400] # over 200mb takes crazy long to analyze
reddit_md = parse_midi_dir(file_list, reddit_json, base_path=version_path, meta_func=parse_reddit_songs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='128461' class='' max='128461', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [128461/128461 2:46:53<00:00]
#     </div>
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/eagles_witchywoman.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/enquantohouversol.mid badly formated midi bytes, got: b'RIFF\xd9.\x06\x00WAVEfmt \x1e\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/et2.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/everybody03.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/every_little_thing.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/EddieCantorMedley.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/entertainer05.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/earthbnd.mid badly formated midi bytes, got: b'<html>\r\n<head>\r\n    '
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/electrk8.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/electrk4.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/evanescence__my_immortal_john.mid badly formated midi bytes, got: b'RIFFp\x02\x00\x00RMIDdata\n\x02\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/Evanescence - My Immortal.mid badly formated midi bytes, got: b'RIFFp\x02\x00\x00RMIDdata\n\x02\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/espanhola03.mid badly formated midi bytes, got: b'<html><head>\n<title>'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/EMAllIWantToDoIsMakeLoveToYou.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/electrk5.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/elctrk11.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/elharry_trancemixededition.mid badly formated midi bytes, got: b'<!DOCTYPE html PUBLI'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/elecstrg.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/electrk7.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/electric.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/electrk6.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/ether.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/elctrk10.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/easy12.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/EndreH - The Beginning (The Realm).mid badly formated midi bytes, got: b'Rar!\x1a\x07\x00\xcf\x90s\x00\x00\r\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/everybr.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/Ecco the Dolphin 2: Tides of Time - Title Theme.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/express.mid badly formated midi bytes, got: b'<HTML><HEAD>\r\n<TITLE'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/enoughbaby.mid badly formated midi bytes, got: b'<!DOCTYPE HTML PUBLI'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/Everything.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/E-Type_-_Life__Mayank_20070613200515.mid badly formated midi bytes, got: b'RIFF\xd6\x0c\x00\x00RMIDdata\x16\x0c\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/eranapeace.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/exodus08.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/ethniqu2.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/eldiaque.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/ebretrohippie.mid badly formated midi bytes, got: b'RIFF\x8e\x03\x01\x00RMIDdata\xb3\xfa\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/empshort.mid cannot handle midi file format: <built-in function format>
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/ethnique.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/EndreH - After Touch Fragments.mid badly formated midi bytes, got: b'Rar!\x1a\x07\x00\xcf\x90s\x00\x00\r\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/Ernesto vs Bastian - Stop 9.5 (Phynn?s Salvation Remix).mid badly formated midi bytes, got: b'Rar!\x1a\x07\x00\xcf\x90s\x00\x00\r\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/executor.mid cannot handle midi file format: <built-in function format>
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/EndreH - Teardrop.mid badly formated midi bytes, got: b'Rar!\x1a\x07\x00\xcf\x90s\x00\x00\r\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/erevshos.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/Elmer_Bernstein_-_.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/EndOfInnocence.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/EarthBound - Summers.mid badly formated midi bytes, got: b'ENIGMA BINARY FILE\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/eyes.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/everytime03.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/electrk9.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/enjoy.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/E/E/eyetiger03.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/odetobillyjoe.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass6.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/only_a_northern_song.mid badly formated midi bytes, got: b'\xdb\xc5m&\x84\xae h\x01\xf94\x98]W\x11Lv\xdd\x82\xf9'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/Otome_no_Policy.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/OCEAN2.MID badly formated midi bytes, got: b'RIFF\xbcq\x01\x00WAVEfmt \x10\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass3.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octwah2.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/One_Big_Rush.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass9.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/onelove.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/oldphone.mid badly formated midi bytes, got: b'\xff\xfb\x10\xc0\x00\x00\x04\x88w@\x18\xd3\x80\x00\xa4\x0e+\x83\x1e\x80'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass4.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/olympic_barcelona92.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/onethat.mid badly formated midi bytes, got: b'\x00\x0bonethat.mid\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/oldmill.mid cannot place n between multiples: 6.051126146570023e+95, 6.051126146570023e+95
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/ocean04.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/ordinary1.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass5.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octwah.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/only_happy_when_it_rains.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/olympic_lillihammer94.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/onlyth.mid badly formated midi bytes, got: b'<HTML>\n<HEAD>\n      '
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/one04.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/olympic1.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/odetojoy3.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass8.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass7.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/OnEaglesWings.mid badly formated midi bytes, got: b'<HTML>\n<HEAD>\n<TITLE'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/octbass2.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/opend.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/O/O/ozzy02.mid badly formated midi bytes, got: b'<ASX version = 3.0>\n'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/8/8th-Symphony-Part-4.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/4/40mozart.mid badly formated midi bytes, got: b'RIFF\xc6F\x00\x00RMIDdataFC\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/P/P/perrymas.mid badly formated midi bytes, got: b'<html>\r\r\n<title>BAYS'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/P/P/powerluv3.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/P/P/powrbas3.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/M/M/mshaddai.mid badly formated midi bytes, got: b'\x00\x00\t\xb3moov\x00\x00\x00lmvhd\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/M/M/MM-the love song.mid badly formated midi bytes, got: b'RIFF^\xc6\x00\x00RMIDdata\xc3\xc5\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/M/M/memories07.mid badly formated midi bytes, got: b'<!DOCTYPE HTML PUBLI'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/M/M/mongo.mid badly formated midi bytes, got: b'<HTML>\r\n<HEAD>\r\n<TIT'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/M/M/mohicans.mid badly formated midi bytes, got: b'\x00\x0cmohicans.mid\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/M/M/myworld2.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/M/M/MCEXTRA.MID badly formated midi bytes, got: b'\x9d,Z\x00\x9b$P\x00\x91(n5\x8d,@C\x9d,4\x1d'
# ...
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The_Shapeshifters_-_Lolas_Theme__ShapeUK_20080923123844.mid badly formated midi bytes, got: b'RIFFV\xfd\x00\x00RMIDdatal\xfc\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/torn07.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/threemice.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/Tales of Symphonia - Intro.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/threebirds.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/trulymadly.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/track5.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel\xc6\x05\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/topgun2.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/thomas.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TRAVIS.Driftwood.mid badly formated midi bytes, got: b'RIFF\xa69\x00\x00RMIDdata*9\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/toni2.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/turnaround3.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/tainted.mid badly formated midi bytes, got: b'\x00\x00\x083moov\x00\x00\x00lmvhd\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/t00118f.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/topgun03.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/thriller3.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/takethemoneyandrun.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TimeOfMyLife.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/thedance03.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TRY_KIND.MID list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The Prodigy - Wind it Up.mid badly formated midi bytes, got: b'<!DOCTYPE html PUBLI'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TuLen - %D0%9Cо%D1%8F мелоди%D1%8F (1).mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/twilight03.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TakeABow.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/ThatsWhatFriendsAreFor.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/tata5.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The way we were k.MID index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The_Offspring_-_No_Hero.mid badly formated midi bytes, got: b'RIFF\x04N\x01\x00RMIDdata\xf7M\x01\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/Tetris Attack - Froggy's Theme.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/thedance04.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/Thunder.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/track04.mid badly formated midi bytes, got: b'RIFF\xd2\x93\x01\x00WAVEfmt 2\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/two_of_us.mid badly formated midi bytes, got: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00\x96\x00\x96\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/that_why_you_go.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/thebulls.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The Legend of Zelda Oracle of Ages  Oracle of Seasons - Ancient Ruins.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/telefome.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/tarbltns.mid badly formated midi bytes, got: b'RIFF\x98e\x00\x00RMIDdata\x8be\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/torn2.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/theoly.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TuLen - Space v.2 (Спа%D1%81е ве%D1%80%D1%81и%D1%8F в%D1%82о%D1%80а%D1%8F).mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/thank_you_girl.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TAURUS.MID list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/Third_Eye_Blind_-_Semi_Charmed_Life.mid badly formated midi bytes, got: b'RIFFV\x0c\x01\x00RMIDdataI\x0c\x01\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The_matrix-protect_the_innocent__jeanskylaw.mid badly formated midi bytes, got: b'Rar!\x1a\x07\x00\xcf\x90s\x00\x00\r\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TwistAndShout2.mid badly formated midi bytes, got: b'\r\r\n<HTML>\r\r\n<HEAD><T'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/tearsihe1.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/tek3.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/thefarla.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/tiefighter.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/times2.mid badly formated midi bytes, got: b'RIFFNx\x00\x00RMIDdataBx\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/the_girl_from_yesterday.mid badly formated midi bytes, got: b'<html>\r\n\r\n\r\n<center>'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/the-memory-remains.mid badly formated midi bytes, got: b'<!DOCTYPE HTML PUBLI'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/teal2.mid badly formated midi bytes, got: b'RIFF\xb6i\x08\x00WAVEfmt \x12\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The Organ Donors - Locked Tight Trance Remix.mid badly formated midi bytes, got: b'Rar!\x1a\x07\x00\xcf\x90s\x00\x00\r\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TEENME02.MID badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/teeth.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/Takhisis2.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/track15.mid badly formated midi bytes, got: b'RIFF\xb2.\x01\x00WAVEfmt 2\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/tba12.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/Treasure MathStorm - Intro and Title Theme.mid badly formated midi bytes, got: b'<html>\r\n<head>\r\n\r\n\r\n'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/TheWayWeWere.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/T/T/The-9th-Symphony.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/2/20years.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/2/2_Become_1.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/2/200103.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/Rammstein - heirate mich (live).mid badly formated midi bytes, got: b'RIFF\x1c\xdc\x00\x00RMIDdata\x84\xdb\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/robbie_williams-rudebox.mid badly formated midi bytes, got: b'RIFF\x84\xed\x00\x00RMIDdataw\xed\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/redwine1.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/red_hot_chili_peppers-scar_tissue_remix.mid badly formated midi bytes, got: b'RIFF\xd6[\x00\x00RMIDdata\xe3Z\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/renato_russo_strani_amori.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rem2.mid badly formated midi bytes, got: b'RIFF\x08\x81\x00\x00RMIDdata\xfc\x80\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/romancedeamor.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/renato_russo_strani_amori2.mid badly formated midi bytes, got: b'RIFFb\x90\x08\x00WAVEfmt \x1e\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/red_hot_chili_peppers-under_the_bridge.mid badly formated midi bytes, got: b'RIFF\xc8L\x00\x00RMIDdataBL\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/radicalMINDOWS.mid badly formated midi bytes, got: b'<!DOCTYPE html PUBLI'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rudi.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rider2.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Ragnarok Online - Peaceful Forest.mid ord() expected string of length 1, but int found
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rescue2.mid badly formated midi bytes, got: b'<HTML><HEAD>\r\n<TITLE'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/reset.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rosanna1.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rockytop06.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rikki3.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/RELAX_BK.MID badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/reset3.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/RIDERSTM.MID badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/reach3.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rem-night_swimming.mid badly formated midi bytes, got: b'RIFF\xde[\x00\x00RMIDdata\xd2[\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Riva_-_RunAway__Zoik_20130128215905.mid badly formated midi bytes, got: b'RIFF\x90\x12\x00\x00RMIDdatag\x12\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rockymthigh.mid badly formated midi bytes, got: b'\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Riva - Run Away.mid badly formated midi bytes, got: b'RIFF\x90\x12\x00\x00RMIDdatag\x12\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Ragnarok Online - Theme of Juno (Guitar Movement).mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/READTHIS.MID badly formated midi bytes, got: b'\r\nThis sequence perf'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Ron van den Beuken presents Clokx - Overdrive (Ron van den Beuken Mix).mid badly formated midi bytes, got: b'file does not exist'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/ridelike1.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Rank 1 - It's Up To You (Symsonic).mid badly formated midi bytes, got: b'Rar!\x1a\x07\x00\xcf\x90s\x00\x00\r\x00\x00\x00\x00\x00\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rainman1.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/red_hot_chili_peppers-suck_my_kiss.mid badly formated midi bytes, got: b'RIFF*\x9e\x00\x00RMIDdata\\\x9d\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/RedemptionSong.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rain-7.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rainbow05.mid badly formated midi bytes, got: b'<HTML><HEAD><TITLE>E'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rocky05.mid index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/red_hot_chili_peppers-parallel_universe.mid badly formated midi bytes, got: b'RIFFP_\x00\x00RMIDdataz^\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rose_leaf_rag.mid badly formated midi bytes, got: b'<HTML>\r\n<HEAD>\r\n    '
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/red_hot_chili_peppers-give_it_away.mid badly formated midi bytes, got: b'RIFF\x96\x92\x00\x00RMIDdata\xc7\x91\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/ritsukotheme.mid badly formated midi bytes, got: b''
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/red_hot_chili_peppers-pea.mid badly formated midi bytes, got: b'RIFF\x82\x0b\x00\x00RMIDdata\xc7\n\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Rhapsody: A Musical Adventure - Little Love.mid list index out of range
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/radiosng.mid badly formated midi bytes, got: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rabbithill.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/RUNAWAY1.MID badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rain-g.mid badly formated midi bytes, got: b'x\x8f?\xfd\x99\x0f\xe8\xaf\r\x8a\xab\xc6\x9b\xf0\xa99W\xac\xbcC'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rasclap.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/revol.mid badly formated midi bytes, got: b'http://content.emusi'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/RODEO.MID badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/rocktree.mid badly formated midi bytes, got: b'vti_encoding:SR|utf8'
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/RUDOLFR.MID Cannot set partition by 0 (0/19807040628566084398385987584)
# Midi Exeption: data/midi/v8/midi_sources/130k_reddit/R/R/Rusch & Murray - Promise.mid badly formated midi bytes, got: b'RIFFv\x07\x00\x00RMIDdata\xed\x06\x00\x00'

# %%
reddit = load_json(reddit_json)
arr2csv(reddit.values(), reddit_csv)
df = pd.read_csv(reddit_csv); df.head()
# Out:
#               genres time_signature  source  \
# 0  anything,inferred            4/4  reddit
# 1  anything,inferred            4/4  reddit
# 2  anything,inferred            4/4  reddit
# 3  anything,inferred            4/4  reddit
# 4  anything,inferred            4/4  reddit
#
#                                                 midi         title  \
# 0  midi_sources/130k_reddit/Jazz_www.thejazzpage....  124Telephone
# 1  midi_sources/130k_reddit/Jazz_www.thejazzpage....  037SlapBass2
# 2  midi_sources/130k_reddit/Jazz_www.thejazzpage....   004ElPiano1
# 3  midi_sources/130k_reddit/Jazz_www.thejazzpage....     111Shanai
# 4  midi_sources/130k_reddit/Jazz_www.thejazzpage....   005ElPiano2
#
#        instruments inferred_key    bpm   seconds            artist  \
# 0              NaN     E- major   80.0  9.750000  124Telephone.mid
# 1              NaN      C major   78.0  6.730769  037SlapBass2.mid
# 2              NaN      D minor  120.0  7.000000   004ElPiano1.mid
# 3  Shehnai,Shehnai      D minor  110.0  6.409091     111Shanai.mid
# 4              NaN     G# minor  120.0  6.250000   005ElPiano2.mid
#
#    inferred_offset quarter_length
# 0             -3.0           13.0
# 1              0.0           8.75
# 2             -5.0           14.0
# 3             -5.0          11.75
# 4              1.0           12.5

# %% [markdown]
# ### Gather Cprato

# %%
cp_path, cp_json, cp_csv = create_paths('cprato')
list(cp_path.glob('*'))[:5]
# Out:
# [PosixPath('data/midi/v8/midi_sources/cprato/Basto - Again And Again (midi By Carlo Prato) (www.cprato.com).mid'),
#  PosixPath('data/midi/v8/midi_sources/cprato/The Weeknd ft. Lana Del Rey - Stargirl Interlude  (midi by Carlo Prato) (www.cprato.com).mid'),
#  PosixPath('data/midi/v8/midi_sources/cprato/Two Steps From Hell - Magic of Love  (midi by Carlo Prato) (www.cprato.com).mid'),
#  PosixPath('data/midi/v8/midi_sources/cprato/Bermuda Loverz - My Girl (Ladidada) (Rimini Rockaz Radio Edit) (Midi By Carlo Prato) (www.cprato.com).mid'),
#  PosixPath('data/midi/v8/midi_sources/cprato/Cascada - Everytime We Touch (Midi By Carlo Prato) (www.cprato.com).mid')]

# %%
def parse_cprato_songs(fp, genres=None, source=None):
    name = fp.with_suffix('').name.split(' - ')
    artist = name[0]
    title = name[-1].replace('(midi by Carlo Prato) (www.cprato.com)', '')
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': genres,
        'source': source
    }

# %%
cp_meta = partial(parse_cprato_songs, genres='EDM,inferred', source='cprato')
file_list = get_files(cp_path, extensions=['.mid'], recurse=True)
cp_md = parse_midi_dir(file_list, cp_json, 
                       base_path=version_path, meta_func=cp_meta)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='314' class='' max='314', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [314/314 00:06<00:00]
#     </div>

# %%
cp = load_json(cp_json)
arr2csv(cp.values(), cp_csv)
df = pd.read_csv(cp_csv); df.head()
# Out:
#          genres time_signature  source  \
# 0  EDM,inferred            4/4  cprato
# 1  EDM,inferred            4/4  cprato
# 2  EDM,inferred            4/4  cprato
# 3  EDM,inferred            4/4  cprato
# 4  EDM,inferred            4/4  cprato
#
#                                                 midi            title  \
# 0  midi_sources/cprato/DuMonde - See The Light  (...    See The Light
# 1  midi_sources/cprato/Mura Masa - Suicide Blades...   Suicide Blades
# 2  midi_sources/cprato/Avicii - Lonely Together  ...  Lonely Together
# 3  midi_sources/cprato/deadmau5 - Deus Ex Machina...  Deus Ex Machina
# 4  midi_sources/cprato/Ephixa & Stephen Walking -...          Matches
#
#                                          instruments inferred_key    bpm  \
# 0                Piano,Piano,Piano,Piano,Piano,Piano     C# minor  140.0
# 1  Piano,Piano,Piano,StringInstrument,StringInstr...      E minor   85.0
# 2                Piano,Piano,Piano,Piano,Piano,Piano      F major  103.0
# 3                Piano,Piano,Piano,Piano,Piano,Piano      F minor  128.0
# 4  Flute,Flute,Flute,Piano,Piano,Piano,Flute,Flut...     F# minor  108.0
#
#      seconds                    artist  inferred_offset  quarter_length
# 0  29.142857                   DuMonde               -4            68.0
# 1  48.000000                 Mura Masa                5            68.0
# 2  20.970874                    Avicii               -5            36.0
# 3  69.375000                  deadmau5                4           148.0
# 4  37.777778  Ephixa & Stephen Walking                3            68.0

# %% [markdown]
# ### Gather MidiWorld

# %%
mw_path, mw_json, mw_csv = create_paths('midiworld')

# %%
def parse_midiworld_songs(fp):
    name = fp.with_suffix('').name.replace('_', ' ').split(' - ')
    artist = name[0]
    title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': 'pop,inferred',
        'source': 'midiworld'
    }

# %%
file_list = get_files(mw_path/'named_midi', extensions=['.mid'], recurse=True)
mw_md = parse_midi_dir(file_list, mw_json, base_path=version_path, meta_func=parse_midiworld_songs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value
mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Lounge_Act.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Third_Eye_Blind_-_Semi_Charmed_Life.mid badly formated midi bytes, got: b'RIFFV\x0c\x01\x00RMIDdataI\x0c\x01\x00'
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_On_A_Plain.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Heart-Shaped_Box.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Mexican_Seafood.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Been_A_Son.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Aneurysm.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Dive.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Sliver.mid badly formed midi string: missing leading MTrk
# Midi Exeption: data/midi/v8/midi_sources/midiworld/named_midi/Nirvana_-_Milk_It.mid badly formed midi string: missing leading MTrk

# %%
mw = load_json(mw_json)
arr2csv(mw.values(), mw_csv)
df = pd.read_csv(mw_csv); df.head()
# Out:
#          genres time_signature     source  \
# 0  pop,inferred            4/4  midiworld
# 1  pop,inferred            4/4  midiworld
# 2  pop,inferred            4/4  midiworld
# 3  pop,inferred            4/4  midiworld
# 4  pop,inferred            2/4  midiworld
#
#                                                 midi         title  \
# 0  midi_sources/midiworld/named_midi/Kona_-_Druml...      Drumloop
# 1  midi_sources/midiworld/named_midi/Cameron_Lee_...           Cue
# 2  midi_sources/midiworld/named_midi/TV_Themes_-_...  Looney Tunes
# 3  midi_sources/midiworld/named_midi/TV_Themes_-_...     Millenium
# 4  midi_sources/midiworld/named_midi/Kaito_-_Cant...    Cantarella
#
#                                          instruments inferred_key    bpm  \
# 0                                              Piano      B minor  176.0
# 1                                              Piano      D minor   95.0
# 2  Marimba,Acoustic Bass,Trombone,StringInstrumen...      C major  160.0
# 3              Timpani,Taiko,Violin,Contrabass,Voice      A major  127.0
# 4                                              Piano     C# minor  144.0
#
#      seconds               artist  inferred_offset quarter_length
# 0   1.193182                 Kona             -2.0            3.5
# 1   2.526316  Cameron Lee Simpson             -5.0            4.0
# 2  19.250000            TV Themes              0.0          154/3
# 3  41.929134            TV Themes              3.0          88.75
# 4  67.916667                Kaito             -4.0          163.0

# %% [markdown]
# ### Gather Wikifonia

# %%
wf_path, wf_json, wf_csv = create_paths('wikifonia')

# %%
def parse_wikifonia_songs(fp):
    name = fp.with_suffix('').name.replace('_', ' ').split(' - ')
    artist = name[0]
    title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'mxl': relative_path(fp),
        'genres': 'pop,inferred',
        'source': 'wikifonia'
    }

# %%
# Warning: if you get a deadlock: 
# PosixPath('data/midi/midi_sources/midiworld/named_midi/NITRO_BRO_-_IT_WONT_DIE.mid') is broken
file_list = get_files(wf_path, extensions=['.mxl'], recurse=True)
wf_md = parse_midi_dir(file_list, wf_json, base_path=version_path, meta_func=parse_wikifonia_songs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6391' class='' max='6391', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6391/6391 01:25<00:00]
#     </div>
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Django Reinhardt - Douce Ambiance.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Charlie Parker - Scrapple From The Apple.mxl Degree not in specified chord: 9
# musicxml.xmlToM21: WARNING: Cannot put in an element with a missing voice tag when no previous voice tag was given.  Assuming voice 1...
# musicxml.xmlToM21: WARNING: Cannot put in an element with a missing voice tag when no previous voice tag was given.  Assuming voice 1...
# musicxml.xmlToM21: WARNING: Cannot put in an element with a missing voice tag when no previous voice tag was given.  Assuming voice 1...
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Bach ? - Four Part Choralforwikifoniachannel04quant.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/blah3 - blah.mxl failed to get likely keys for Stream component
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Monty Python - Always look on the bright side of kive.mxl got a negative delta time
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Fraser Smith, Adele Adkins - Set Fire To The Rain.mxl float division by zero
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Spencer, James F. Hanley - Mary Is Talking.mxl failed to get likely keys for Stream component
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Maurice Williams - Stay.mxl unsupported operand type(s) for /: 'int' and 'NoneType'
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Gigi Gryce, Jon Hendricks - Social Call.mxl unsupported operand type(s) for /: 'int' and 'NoneType'
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/William Cummings, Felix Mendolssohn, Gary Bisaga, Charles Wesley, George Whitfield - Hark the Herald Angels Sing.mxl Degree not in specified chord: 11
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Taj Mahal and Yank Rachel - She Caught The Katy And Left Me A Mule To Ride.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Johnny Mandel, Johnny Mercer - Emily.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Mike Sharpe (Shapiro), Harry Middlebrooks - Spooky.mxl Cannot make a step out of '''
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/DUKE ELLINGTON - C Jam Blues.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/William Ballet - Greensleeves.mxl unsupported operand type(s) for +: 'NoneType' and 'int'
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Vanessa da Matta - Ainda bem.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Les Kettley - Baby, Make My Day.mxl unsupported operand type(s) for /: 'int' and 'NoneType'
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Theme - Star Trek The Next Generation theme.mxl float division by zero
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Stickler, Adele - Doris On Lunch Again.mxl failed to get likely keys for Stream component
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Saxtorph-Mikkelsen J. 1906, Aakjr, Jeppe 1906 - Anna var i Anders kr.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Thomas,  Girard - RIGHT AS RAIN.mxl failed to get likely keys for Stream component
# musicxml.xmlToM21: WARNING: Line <bracket> stop without start
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Joe Harnell - The Lonely Man.mxl Degree not in specified chord: 11
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/L. van Beethoven - Himno a la Alegria.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/ARR. by Peter Sweeney - WONDERFUL TONIGHT.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Dot145 - Precession of the Equinoxes.mxl Degree not in specified chord: 9
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Ray Henderson, Joseph Widow Young, Sam M. Lewis - Five Foot Two, Eyes Of Blue .mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Clifford Brown - Daahoud.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Gerry Goffin, Michael Masser - Nothing's Gonna Change My Love For You.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Through The Fire - Chaka Khan .mxl unsupported operand type(s) for /: 'int' and 'NoneType'
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/John McLaughlin - Guardian Angel.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/gdy - test.mxl failed to get likely keys for Stream component
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Bach h? - Four Part Choral Bass Clarinet.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/J. Kosma, J. Mercer - Autumn Leaves.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Don Covay - Chain Of Fools.mxl float division by zero
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Monty Python - Always look on the bright side of life.mxl got a negative delta time
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Bach? - Four Part Choralforwikifoniapart01Quant.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Per Warming, Jens Rosenda - Du kom med alt det der var dig.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Antonio Carlos Jobim, Ray Gilbert (English Lyrics) - Dindi.mxl Degree not in specified chord: 9
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Bud Powell - Bouncin' with Bud.mxl Degree not in specified chord: 13
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/S.Sgt Barry Sadler - The Ballad of the Green Berets.mxl float division by zero
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Cole Porter - All Through the Night.mxl float division by zero
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Robert Stolz, clasic - Adieu mein kleiner Gardeoffizier.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Jazzengers - Almost 13.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Hilsen til forarssolen - Det er foraar alting klippes ned.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Bryan Adams - (Everything I Do) I Do It For You.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Bach? - Four Part ChoralforwikifoniaBb Clarinet.mxl local variable 'lyricLanguage' referenced before assignment
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/KC - Test.mxl failed to get likely keys for Stream component
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Henry Mancini - The theme from Pink Panther.mxl float division by zero
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Wakey! Wakey! - Brooklyn.mxl unsupported operand type(s) for /: 'int' and 'NoneType'
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Trevors - U R in my Undies.mxl failed to get likely keys for Stream component
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/traditional French carol (early 16th century) - Entre le Boeuf et l'Ane Gris.mxl '>=' not supported between instances of 'str' and 'int'
# Midi Exeption: data/midi/v8/midi_sources/wikifonia/Jacques Offenbach - Can-Can.mxl float division by zero

# %%
wf = load_json(wf_json)
arr2csv(wf.values(), wf_csv)
df = pd.read_csv(wf_csv); df.head()
# Out:
#          genres time_signature     source  \
# 0  pop,inferred            NaN  wikifonia
# 1  pop,inferred            NaN  wikifonia
# 2  pop,inferred            4/4  wikifonia
# 3  pop,inferred            4/4  wikifonia
# 4  pop,inferred            4/4  wikifonia
#
#                                                 midi  \
# 0                                                NaN
# 1                                                NaN
# 2  midi_sources/from_mxl/wikifonia/Joe Henderson ...
# 3  midi_sources/from_mxl/wikifonia/Joe Trohman, A...
# 4  midi_sources/from_mxl/wikifonia/Hungarian folk...
#
#                                               title  instruments inferred_key  \
# 0                                    Douce Ambiance          NaN          NaN
# 1                           Scrapple From The Apple          NaN          NaN
# 2                                          Mamacita          NaN      F minor
# 3  My Songs Know What You Did In The Dark (Light Em        Piano      D minor
# 4                  ?n az ?jjel nem aludtam egy ?r?t  Grand Piano      C major
#
#      bpm    seconds                                             artist  \
# 0    NaN        NaN                                   Django Reinhardt
# 1    NaN        NaN                                     Charlie Parker
# 2    NaN        NaN                                      Joe Henderson
# 3  155.0  99.096774  Joe Trohman, Andy Hurley, Butch Walker, John H...
# 4    NaN        NaN                                Hungarian folk song
#
#    inferred_offset                                                mxl  \
# 0              NaN  midi_sources/wikifonia/Django Reinhardt - Douc...
# 1              NaN  midi_sources/wikifonia/Charlie Parker - Scrapp...
# 2              4.0  midi_sources/wikifonia/Joe Henderson - Mamacit...
# 3             -5.0  midi_sources/wikifonia/Joe Trohman, Andy Hurle...
# 4              0.0  midi_sources/wikifonia/Hungarian folk song - ?...
#
#   quarter_length
# 0            NaN
# 1            NaN
# 2           64.0
# 3          256.0
# 4           48.0

# %% [markdown]
# ### Yamaha - piano

# %%
ec_path, ec_json, ec_csv = create_paths('ecomp')
ec_song = ec_path/'song_list.json'
list(ec_path.glob('*'))[:5]
# Out:
# [PosixPath('data/midi/v8/midi_sources/ecomp/song_list.json'),
#  PosixPath('data/midi/v8/midi_sources/ecomp/2017'),
#  PosixPath('data/midi/v8/midi_sources/ecomp/2008'),
#  PosixPath('data/midi/v8/midi_sources/ecomp/2006'),
#  PosixPath('data/midi/v8/midi_sources/ecomp/2004')]

# %%
ec_songs = load_json(ec_path/'song_list.json')

# %%
def parse_ecomp_songs(fp):
    song_info = ec_songs[fp.stem]
    return {
        'artist': song_info['artist'],
        'title': song_info['title'],
        'mxl': relative_path(fp),
        'genres': 'classical',
        'source': 'ecomp'
    }

# %%
file_list = get_files(ec_path, extensions=['.mxl'], recurse=True)

# %%
sorted_files = sorted([fp.stat().st_size/1000 for fp in file_list])[-200:]

# %%
file_list = [fp for fp in file_list if fp.stat().st_size/1000 < 400] # over 200mb takes crazy long to analyze
ec_md = parse_midi_dir(file_list, ec_json, base_path=version_path, meta_func=parse_ecomp_songs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2538' class='' max='2538', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2538/2538 19:21<00:00]
#     </div>
# Midi Exeption: data/midi/v8/midi_sources/ecomp/2017/SunY03.mxl got a negative delta time
# Midi Exeption: data/midi/v8/midi_sources/ecomp/2006/Tysman02.mxl got a negative delta time
# Midi Exeption: data/midi/v8/midi_sources/ecomp/2004/BLINOV01.mxl got a negative delta time
# Midi Exeption: data/midi/v8/midi_sources/ecomp/2009/Na03.mxl got a negative delta time
# Midi Exeption: data/midi/v8/midi_sources/ecomp/2002/sun01.mxl got a negative delta time

# %%
ec = load_json(ec_json)
arr2csv(ec.values(), ec_csv)
df = pd.read_csv(ec_csv); df.head()
# Out:
#       genres time_signature source  \
# 0  classical            3/4  ecomp
# 1  classical            4/4  ecomp
# 2  classical            4/4  ecomp
# 3  classical            4/4  ecomp
# 4  classical            4/4  ecomp
#
#                                              midi  \
# 0    midi_sources/from_mxl/ecomp/2017/WangH09.mid
# 1  midi_sources/from_mxl/ecomp/2017/KaiRuiR06.mid
# 2    midi_sources/from_mxl/ecomp/2017/LeeSH12.mid
# 3    midi_sources/from_mxl/ecomp/2017/WangH12.mid
# 4    midi_sources/from_mxl/ecomp/2017/WangA01.mid
#
#                                              title  instruments inferred_key  \
# 0                        II. Intermezzo in A Minor  Piano,Piano      A minor
# 1                 Etude Op. 10 No. 2 in    A Minor  Piano,Piano      A minor
# 2                          II. Andantino: Getragen  Piano,Piano      C major
# 3                        VII. Capriccio in D Minor  Piano,Piano      A minor
# 4  Prelude and    Fugue in E Major, WTC I, BWV 854  Piano,Piano      E major
#
#      bpm     seconds                    artist  inferred_offset  \
# 0  106.0  212.264151                                          0
# 1  160.0   79.500000       Frédéric     Chopin                0
# 2   96.0  277.500000                                          0
# 3  157.0  122.292994                                          0
# 4   74.0  149.189189  Johann    Sebastian Bach               -4
#
#                                      mxl quarter_length
# 0    midi_sources/ecomp/2017/WangH09.mxl          375.0
# 1  midi_sources/ecomp/2017/KaiRuiR06.mxl          212.0
# 2    midi_sources/ecomp/2017/LeeSH12.mxl          444.0
# 3    midi_sources/ecomp/2017/WangH12.mxl          320.0
# 4    midi_sources/ecomp/2017/WangA01.mxl          184.0

# %% [markdown]
# ### Reformatting code

# %%
# def reformat_json(out_path):
#     f2m = load_json(out_path)
#     m = {relative_path(k):v for k,v in f2m.items()}
#     save_json(m, out_path)
#     return m

# %%
# def reformat_key(k):
#     return k.replace('data/midi/midi_sources_fromxml_v3','midi_sources/from_mxl')

# %%
# def reformat_data(d):
#     if 'midi' in d: d['midi'] = reformat_key(d['midi'])
#     if 'mxl' in d: d['mxl'] = d['mxl'].replace('data/midi/midi_sources_v3', 'midi_sources')
#     return d

# %%
# f2m = load_json(clc_json)
# m = {reformat_data(v)['mxl']:reformat_data(v) for k,v in f2m.items() if 'mxl' in reformat_data(v)}
# save_json(m, clc_json)

# %% [markdown]
# ### Classic Piano

# %%
clc_path, clc_json, clc_csv = create_paths('classic_piano')
list(clc_path.glob('*'))[:5]
# Out:
# [PosixPath('data/midi/v8/midi_sources/classic_piano/liz_rhap15_format0.mxl'),
#  PosixPath('data/midi/v8/midi_sources/classic_piano/ty_september_format0.mxl'),
#  PosixPath('data/midi/v8/midi_sources/classic_piano/clementi_opus36_2_2_format0.mid'),
#  PosixPath('data/midi/v8/midi_sources/classic_piano/mz_333_2_format0.mid'),
#  PosixPath('data/midi/v8/midi_sources/classic_piano/haydn_7_1_format0.mid')]

# %%
def parse_classic_songs(fp):
    name = fp.with_suffix('').name.split('_')
    artist = name[0]
    title = ' '.join(name[1:])
    return {
        'artist': artist,
        'title': title,
        'mxl': relative_path(fp),
        'genres': 'classical',
        'source': 'classical_piano'
    }

# %%
file_list = get_files(clc_path, extensions=['.mxl'], recurse=True)

# %%
file_list = [fp for fp in file_list if fp.stat().st_size/1000 < 350] # over 200mb takes crazy long to analyze

# %%
clc_md = parse_midi_dir(file_list, clc_json, base_path=version_path, meta_func=parse_classic_songs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='328' class='' max='328', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [328/328 01:07<00:00]
#     </div>

# %%
clc = load_json(clc_json)
arr2csv(clc.values(), clc_csv)
df = pd.read_csv(clc_csv); df.head()
# Out:
#       genres time_signature           source  \
# 0  classical            6/8  classical_piano
# 1  classical            3/4  classical_piano
# 2  classical            2/4  classical_piano
# 3  classical            6/8  classical_piano
# 4  classical            4/4  classical_piano
#
#                                                 midi        title  \
# 0  midi_sources/from_mxl/classic_piano/chpn-p11_f...      format0
# 1  midi_sources/from_mxl/classic_piano/haydn_8_2_...  8 2 format0
# 2  midi_sources/from_mxl/classic_piano/scn15_3_fo...    3 format0
# 3  midi_sources/from_mxl/classic_piano/waldstein_...    2 format0
# 4  midi_sources/from_mxl/classic_piano/chpn-p18_f...      format0
#
#    instruments inferred_key    bpm     seconds     artist  inferred_offset  \
# 0  Piano,Piano      B major  111.0   29.635549   chpn-p11                1
# 1  Piano,Piano      G major  100.0   57.682776      haydn                5
# 2  Piano,Piano      E minor  115.0   31.903386      scn15                5
# 3  Piano,Piano      C major   20.0  245.746646  waldstein                0
# 4  Piano,Piano      F minor  126.0   41.887744   chpn-p18                4
#
#                                                  mxl quarter_length
# 0    midi_sources/classic_piano/chpn-p11_format0.mxl           81.0
# 1   midi_sources/classic_piano/haydn_8_2_format0.mxl           96.0
# 2     midi_sources/classic_piano/scn15_3_format0.mxl           64.0
# 3  midi_sources/classic_piano/waldstein_2_format0...           84.0
# 4    midi_sources/classic_piano/chpn-p18_format0.mxl           85.0

# %% [markdown]
# ### Creating CSV

# %%
all_csvs = [create_paths(s)[-1] for s in sources]
all_dfs = [pd.read_csv(csv) for csv in all_csvs]

# %%
merged_df = pd.concat(all_dfs, sort=False)
merged_df = merged_df.reset_index(drop=True); merged_df
# Out:
#         inferred_offset                                           song_url  \
# 0                   0.0  https://www.hooktheory.com/theorytab/view/wayn...
# 1                   0.0  https://www.hooktheory.com/theorytab/view/wayn...
# 2                   5.0  https://www.hooktheory.com/theorytab/view/what...
# 3                   NaN  https://www.hooktheory.com/theorytab/view/weez...
# 4                   0.0  https://www.hooktheory.com/theorytab/view/weez...
# 5                  -5.0  https://www.hooktheory.com/theorytab/view/wavv...
# 6                   0.0  https://www.hooktheory.com/theorytab/view/weez...
# 7                   0.0  https://www.hooktheory.com/theorytab/view/weez...
# 8                   0.0  https://www.hooktheory.com/theorytab/view/weez...
# 9                   0.0  https://www.hooktheory.com/theorytab/view/wavv...
# 10                  0.0  https://www.hooktheory.com/theorytab/view/weez...
# 11                  0.0  https://www.hooktheory.com/theorytab/view/weez...
# 12                  0.0  https://www.hooktheory.com/theorytab/view/wavv...
# 13                  0.0  https://www.hooktheory.com/theorytab/view/weez...
# 14                  0.0  https://www.hooktheory.com/theorytab/view/wavv...
# 15                  0.0  https://www.hooktheory.com/theorytab/view/weez...
# 16                  0.0  https://www.hooktheory.com/theorytab/view/weez...
# 17                 -5.0  https://www.hooktheory.com/theorytab/view/wavv...
# 18                 -5.0  https://www.hooktheory.com/theorytab/view/will...
# 19                 -5.0  https://www.hooktheory.com/theorytab/view/weez...
# 20                  0.0  https://www.hooktheory.com/theorytab/view/weez...
# 21                  0.0  https://www.hooktheory.com/theorytab/view/will...
# 22                  0.0  https://www.hooktheory.com/theorytab/view/weez...
# 23                  5.0  https://www.hooktheory.com/theorytab/view/wolf...
# 24                  0.0  https://www.hooktheory.com/theorytab/view/wavv...
# 25                  0.0  https://www.hooktheory.com/theorytab/view/wolf...
# 26                 -5.0  https://www.hooktheory.com/theorytab/view/wavv...
# 27                  0.0  https://www.hooktheory.com/theorytab/view/will...
# 28                  0.0  https://www.hooktheory.com/theorytab/view/whit...
# 29                  5.0  https://www.hooktheory.com/theorytab/view/weeb...
# ...                 ...                                                ...
# 185816              3.0                                                NaN
# 185817              0.0                                                NaN
# 185818              4.0                                                NaN
# 185819             -4.0                                                NaN
# 185820             -2.0                                                NaN
# 185821             -4.0                                                NaN
# 185822             -5.0                                                NaN
# 185823             -5.0                                                NaN
# 185824              5.0                                                NaN
# 185825              2.0                                                NaN
# 185826             -4.0                                                NaN
# 185827              0.0                                                NaN
# 185828              0.0                                                NaN
# 185829             -2.0                                                NaN
# 185830              2.0                                                NaN
# 185831              0.0                                                NaN
# 185832              5.0                                                NaN
# 185833              5.0                                                NaN
# 185834             -4.0                                                NaN
# 185835              0.0                                                NaN
# 185836              4.0                                                NaN
# 185837              2.0                                                NaN
# 185838             -5.0                                                NaN
# 185839              0.0                                                NaN
# 185840              0.0                                                NaN
# 185841              2.0                                                NaN
# 185842              2.0                                                NaN
# 185843              0.0                                                NaN
# 185844              1.0                                                NaN
# 185845              3.0                                                NaN
#
#                                               instruments  ht_mode  \
# 0                                                   Piano      1.0
# 1                                             Piano,Piano      1.0
# 2                                             Piano,Piano      1.0
# 3                                                     NaN      1.0
# 4                                             Piano,Piano      1.0
# 5                                             Piano,Piano      1.0
# 6                                             Piano,Piano      1.0
# 7                                             Piano,Piano      1.0
# 8                                             Piano,Piano      1.0
# 9                                             Piano,Piano      1.0
# 10                                            Piano,Piano      1.0
# 11                                            Piano,Piano      1.0
# 12                                                  Piano      1.0
# 13                                            Piano,Piano      1.0
# 14                                            Piano,Piano      1.0
# 15                                            Piano,Piano      1.0
# 16                                            Piano,Piano      1.0
# 17                                            Piano,Piano      1.0
# 18                                                  Piano      1.0
# 19                                            Piano,Piano      1.0
# 20                                            Piano,Piano      1.0
# 21                                                  Piano      1.0
# 22                                            Piano,Piano      1.0
# 23                                            Piano,Piano      1.0
# 24                                            Piano,Piano      1.0
# 25                                            Piano,Piano      1.0
# 26                                            Piano,Piano      1.0
# 27                                            Piano,Piano      1.0
# 28                                            Piano,Piano      1.0
# 29                                                  Piano      1.0
# ...                                                   ...      ...
# 185816                                                NaN      NaN
# 185817       Electric Bass,Piano,Electric Guitar,Recorder      NaN
# 185818                                              Piano      NaN
# 185819        Electric Bass,Flute,Steel Drum,Guitar,Voice      NaN
# 185820                                              Piano      NaN
# 185821  Brass,Electric Bass,Piano,StringInstrument,Con...      NaN
# 185822  Flute,Flute,Oboe,Clarinet,Bassoon,Horn,Horn,Tr...      NaN
# 185823  Fretless Bass,Piano,Shakuhachi,Piano,Voice,Pia...      NaN
# 185824                                              Piano      NaN
# 185825  Electric Bass,Piano,Tenor Saxophone,StringInst...      NaN
# 185826                                                NaN      NaN
# 185827  Electric Bass,Acoustic Bass,Piano,Saxophone,Vo...      NaN
# 185828           Oboe,Piano,Electric Guitar,Electric Bass      NaN
# 185829  Piano,Clarinet,Electric Bass,StringInstrument,...      NaN
# 185830  Piano,Piano,StringInstrument,Tenor Saxophone,E...      NaN
# 185831  Electric Bass,Brass,Electric Guitar,Brass,Stri...      NaN
# 185832  Piano,Piano,Piano,StringInstrument,Electric Ba...      NaN
# 185833  Electric Bass,Piano,Shakuhachi,Pan Flute,Piano...      NaN
# 185834  Pan Flute,Shakuhachi,Fretless Bass,Piano,Woodb...      NaN
# 185835  Clarinet,Timpani,Banjo,Tenor Saxophone,Saxopho...      NaN
# 185836                        Electric Organ,English Horn      NaN
# 185837  Flute,Oboe,Clarinet,Bassoon,Horn,Horn,Trumpet,...      NaN
# 185838  Flute,Oboe,Clarinet,Bassoon,Trumpet,Horn,Timpa...      NaN
# 185839  StringInstrument,Electric Bass,Flute,Voice,Bra...      NaN
# 185840  Piano,Electric Bass,Brass,Piano,Trombone,Elect...      NaN
# 185841  Flute,Oboe,Clarinet,Bassoon,Horn,Trumpet,Tromb...      NaN
# 185842  Piano,Acoustic Bass,Acoustic Bass,Trombone,Tro...      NaN
# 185843  Guitar,Guitar,Electric Guitar,Violin,Fretless ...      NaN
# 185844                                              Piano      NaN
# 185845  Saxophone,Brass,Electric Bass,Piano,Piano,Pian...      NaN
#
#                         midi_title                                   title  \
# 0                         yu-gi-oh                     yu-gi-oh-theme-song
# 1                        yu-gi-oh3                     yu-gi-oh-theme-song
# 2                           kiefer                                  kiefer
# 3                      My New Song                           beverly-hills
# 4           Weezer - Fall Together                          fall-together-
# 5             afraidofheightsintro                       afraid-of-heights
# 6                      Buddy Holly                             buddy-holly
# 7                     greatest man        the-greatest-man-that-ever-lived
# 8            falling for you intro                         falling-for-you
# 9                      afraidverse                       afraid-of-heights
# 10                     Buddy Holly                             buddy-holly
# 11              intro greatest man        the-greatest-man-that-ever-lived
# 12                    Way Too Much                            way-too-much
# 13                 Falling For You                         falling-for-you
# 14        chorus afraid of heights                       afraid-of-heights
# 15          I Want You To - Weezer                           i-want-you-to
# 16                       scorcho c                              el-scorcho
# 17              dreams of grandeur                      dreams-of-grandeur
# 18               On The Road Again                       on-the-road-again
# 19                      El Scorcho                              el-scorcho
# 20                           world   the-world-has-turned-and-left-me-here
# 21               On The Road Again                       on-the-road-again
# 22                 nooneelseCHORUS                             no-one-else
# 23                      Space Junk                              space-junk
# 24                  too much verse                            way-too-much
# 25                      undertaker                              undertaker
# 26                     pony chorus                                    pony
# 27      You Were Always On My Mind              you-were-always-on-my-mind
# 28                    Senbonzakura                            senbonzakura
# 29                   Donkeys Intro                                 donkeys
# ...                            ...                                     ...
# 185816                         NaN                              rhapsody04
# 185817                         NaN                               reu phong
# 185818                         NaN        Rhapsody-in-E-Flat-Opus-119-Nr-4
# 185819                         NaN                       R.SUGAR.Someday K
# 185820                         NaN                                ragtime3
# 185821                         NaN                     RAYBOLTZ THANKYOU1A
# 185822                         NaN                                rkeaster
# 185823                         NaN  R.STEWART.If we fall in love tonight K
# 185824                         NaN              Rondo-A-Capriccio-Opus-129
# 185825                         NaN                         R.MARTIN.Amor K
# 185826                         NaN                                   RONDO
# 185827                         NaN                    RICHIE.Do it to me K
# 185828                         NaN                                RUNAW TR
# 185829                         NaN              rung xanh vang tieng ta lu
# 185830                         NaN                           Radio-Ga-Ga-1
# 185831                         NaN            Rene-Froger-Special-(Medley)
# 185832                         NaN                             RouteVenus2
# 185820    245.317518          midi_sources/130k_reddit/R/R/ragtime3.mid
# 185821    307.008197  midi_sources/130k_reddit/R/R/RAYBOLTZ_THANKYOU...
# 185822    847.776130          midi_sources/130k_reddit/R/R/rkeaster.mid
# 185823    344.827586  midi_sources/130k_reddit/R/R/R.STEWART.If we f...
# 185824    436.166667  midi_sources/130k_reddit/R/R/Rondo-A-Capriccio...
# 185825    205.873016   midi_sources/130k_reddit/R/R/R.MARTIN.Amor K.mid
# 185826    425.708333             midi_sources/130k_reddit/R/R/RONDO.MID
# 185827    369.032258  midi_sources/130k_reddit/R/R/RICHIE.Do it to m...
# 185828    264.375000          midi_sources/130k_reddit/R/R/RUNAW_TR.MID
# 185829    236.625000  midi_sources/130k_reddit/R/R/rung_xanh_vang_ti...
# 185830    299.078947     midi_sources/130k_reddit/R/R/Radio-Ga-Ga-1.mid
# 185831    716.367188  midi_sources/130k_reddit/R/R/Rene-Froger-Speci...
# 185832    242.482759       midi_sources/130k_reddit/R/R/RouteVenus2.mid
# 185833    314.210526  midi_sources/130k_reddit/R/R/R_Kelly_-_Gotham_...
# 185834    303.857143  midi_sources/130k_reddit/R/R/Rush_Time_Stands_...
# 185835    920.806913  midi_sources/130k_reddit/R/R/rhapinbluefullcl.mid
# 185836    300.895522        midi_sources/130k_reddit/R/R/resloution.mid
# 185837    702.795244       midi_sources/130k_reddit/R/R/rach_op30_3.mid
# 185838  83319.745414          midi_sources/130k_reddit/R/R/rach3-12.mid
# 185839    259.335938  midi_sources/130k_reddit/R/R/R.MARTIN.Por arib...
# 185840    271.000000  midi_sources/130k_reddit/R/R/R.MARTIN.La copa ...
# 185841  55346.262865         midi_sources/130k_reddit/R/R/rach3-232.mid
# 185842    667.194313   midi_sources/130k_reddit/R/R/R.CONIFF.Medley.mid
# 185843   2069.225233        midi_sources/130k_reddit/R/R/rubbersoul.mid
# 185844   2130.677596        midi_sources/130k_reddit/2/24preludescl.mid
# 185845    371.655586  midi_sources/130k_reddit/R/R/Rock-Around-Medle...
#
#        inferred_key quarter_length ...  ht_offset ht_bpm  \
# 0           C major             36 ...        0.0   85.0
# 1           C major             32 ...        0.0  128.0
# 2           E minor             16 ...        0.0   96.0
# 3               NaN            NaN ...        0.0  128.0
# 4           A minor             16 ...        0.0   93.0
# 5           F major             16 ...        0.0  118.0
# 6           C major             32 ...        0.0  120.0
# 7           C major             32 ...        0.0   78.0
# 8           C major             20 ...        0.0  108.0
# 9           C major             32 ...        0.0  110.0
# 10          A minor             16 ...        0.0  122.0
# 11          C major             32 ...        0.0   75.0
# 12          C major           31.5 ...        0.0  128.0
# 13          C major             36 ...        0.0  110.0
# 14          C major             32 ...        0.0  110.0
# 15          C major             32 ...        0.0  104.0
# 16          C major             32 ...        0.0   74.0
# 17          D minor             64 ...        0.0  180.0
# 18          F major             28 ...        0.0  112.0
# 19          F major             16 ...        0.0   75.0
# 20          C major             64 ...        0.0  198.0
# 21          C major             28 ...        0.0  112.0
# 22          C major             64 ...        0.0  138.0
# 23          G major             32 ...        0.0  128.0
# 24          C major             32 ...        0.0  160.0
# 25          A minor             32 ...        0.0  240.0
# 26          F major             36 ...        0.0  165.0
# 27          C major             48 ...        0.0   68.0
# 28          A minor             32 ...        0.0  152.0
# 29          G major             32 ...        0.0  140.0
# ...             ...            ... ...        ...    ...
# 185816      A major         4813/3 ...        NaN    NaN
# 185817      C major          623.0 ...        NaN    NaN
# 185818     A- major          636.0 ...        NaN    NaN
# 185819      E major          440.0 ...        NaN    NaN
# 185820      D major         2183/3 ...        NaN    NaN
# 185821     C# minor         624.25 ...        NaN    NaN
# 185822      D minor         3139.0 ...        NaN    NaN
# 185823      F major          500.0 ...        NaN    NaN
# 185824      G major         2617/3 ...        NaN    NaN
# 185825      G minor         1297/3 ...        NaN    NaN
# 185826      E major       10217/12 ...        NaN    NaN
# 185827      C major          572.0 ...        NaN    NaN
# 185828      C major         528.75 ...        NaN    NaN
# 185829      B minor         473.25 ...        NaN    NaN
# 185830     B- major         568.25 ...        NaN    NaN
# 185831      C major        1528.25 ...        NaN    NaN
# 185832      E minor          586.0 ...        NaN    NaN
# 185833      G major          796.0 ...        NaN    NaN
# 185834      E major          709.0 ...        NaN    NaN
# 185835      C major        11077/6 ...        NaN    NaN
# 185836      F minor          672.0 ...        NaN    NaN
# 185837      G minor         2075.0 ...        NaN    NaN
# 185838      D minor       166746.0 ...        NaN    NaN
# 185839      A minor         553.25 ...        NaN    NaN
# 185840      A minor          542.0 ...        NaN    NaN
# 185841      G minor       562595/3 ...        NaN    NaN
# 185842      G minor         4115/3 ...        NaN    NaN
# 185843      A minor         3998.5 ...        NaN    NaN
# 185844     G# minor        4281.25 ...        NaN    NaN
# 185845      A major         1146.0 ...        NaN    NaN
#
#                                             artist  ht_key ht_time_signature  \
# 0                                     wayne-sharpe       C               3.0
# 1                                     wayne-sharpe       C               4.0
# 2                                       what-a-day       C               4.0
# 3                                           weezer       C               4.0
# 4                                           weezer       C               4.0
# 5                                           wavves       C               4.0
# 6                                           weezer       C               4.0
# 7                                           weezer       C               4.0
# 8                                           weezer       C               4.0
# 9                                           wavves       C               4.0
# 10                                          weezer       C               4.0
# 11                                          weezer       C               4.0
# 12                                          wavves       C               4.0
# 13                                          weezer       C               4.0
# 14                                          wavves       C               4.0
# 15                                          weezer       C               4.0
# 16                                          weezer       C               4.0
# 17                                          wavves       C               4.0
# 18                                   willie-nelson       C               4.0
# 19                                          weezer       C               4.0
# 20                                          weezer       C               4.0
# 21                                   willie-nelson       C               4.0
# 22                                          weezer       C               4.0
# 23                                wolfgang-gartner       C               4.0
# 24                                          wavves       C               4.0
# 25                                wolfgang-gartner       C               4.0
# 26                                          wavves       C               4.0
# 27                                   willie-nelson       C               4.0
# 28                                      whiteflame       C               4.0
# 29                                           weebl       C               4.0
# ...                                            ...     ...               ...
# 185816                              rhapsody04.mid     NaN               NaN
# 185817                               reu_phong.mid     NaN               NaN
# 185818        Rhapsody-in-E-Flat-Opus-119-Nr-4.mid     NaN               NaN
# 185819                       R.SUGAR.Someday K.mid     NaN               NaN
# 185820                                ragtime3.mid     NaN               NaN
# 185821                     RAYBOLTZ_THANKYOU1A.MID     NaN               NaN
# 185822                                rkeaster.mid     NaN               NaN
# 185823  R.STEWART.If we fall in love tonight K.mid     NaN               NaN
# 185824              Rondo-A-Capriccio-Opus-129.mid     NaN               NaN
# 185825                         R.MARTIN.Amor K.mid     NaN               NaN
# 185826                                   RONDO.MID     NaN               NaN
# 185827                    RICHIE.Do it to me K.mid     NaN               NaN
# 185828                                RUNAW_TR.MID     NaN               NaN
# 185829              rung_xanh_vang_tieng_ta_lu.mid     NaN               NaN
# 185830                           Radio-Ga-Ga-1.mid     NaN               NaN
# 185831            Rene-Froger-Special-(Medley).mid     NaN               NaN
# 185832                             RouteVenus2.mid     NaN               NaN
# 185833                                     R Kelly     NaN               NaN
# 185834                Rush_Time_Stands_Still-5.mid     NaN               NaN
# 185835                        rhapinbluefullcl.mid     NaN               NaN
# 185836                              resloution.mid     NaN               NaN
# 185837                             rach_op30_3.mid     NaN               NaN
# 185838                                rach3-12.mid     NaN               NaN
# 185839            R.MARTIN.Por ariba por abato.mid     NaN               NaN
# 185840           R.MARTIN.La copa de la vida k.mid     NaN               NaN
# 185841                               rach3-232.mid     NaN               NaN
# 185842                         R.CONIFF.Medley.mid     NaN               NaN
# 185843                              rubbersoul.mid     NaN               NaN
# 185844                            24preludescl.mid     NaN               NaN
# 185845             Rock-Around-Medley-(Medley).mid     NaN               NaN
#
#            bpm          section                                         parts  \
# 0        85.00            intro                                  intro,chorus
# 1       128.00           chorus                                  intro,chorus
# 2        96.00           chorus                                        chorus
# 3          NaN  intro-and-verse                               intro-and-verse
# 4        93.00           chorus                                        chorus
# 5       118.00            intro                            intro,verse,chorus
# 6       120.00           chorus           verse,pre-chorus,chorus,bridge,solo
# 7        78.00           solo-1                                  intro,solo-1
# 8       108.00            intro                       intro,verse,chorus,solo
# 9       110.00            verse                            intro,verse,chorus
# 10      122.00            verse           verse,pre-chorus,chorus,bridge,solo
# 11       75.00            intro                                  intro,solo-1
# 12      128.00            intro                     intro,verse,chorus,bridge
# 13      110.00           chorus                       intro,verse,chorus,solo
# 14      110.00           chorus                            intro,verse,chorus
# 15      104.00            verse                                         verse
# 16       74.00           chorus      intro,verse-and-pre-chorus,chorus,bridge
# 17      180.00            verse                                         verse
# 18      112.00           bridge                                  verse,bridge
# 19       75.00            intro      intro,verse-and-pre-chorus,chorus,bridge
# 20      198.00           chorus             intro,verse-and-pre-chorus,chorus
# 21      112.00            verse                                  verse,bridge
# 22      138.00           chorus  intro-and-verse,verse,pre-chorus,chorus,solo
# 23      128.00       pre-chorus                                    pre-chorus
# 24      160.00            verse                     intro,verse,chorus,bridge
# 25      240.00            intro                                         intro
# 26      165.00           chorus       verse,pre-chorus,chorus,chorus-lead-out
# 27       68.00            verse                                         verse
# 28      152.00            verse                       verse,pre-chorus,chorus
# 29      140.00            intro                                   intro,verse
# ...        ...              ...                                           ...
# 185816  120.00              NaN                                           NaN
# 185817  120.00              NaN                                           NaN
# 185818  120.00              NaN                                           NaN
# 185819  113.00              NaN                                           NaN
# 185820  175.00              NaN                                           NaN
# 185821  122.00              NaN                                           NaN
# 185822  110.00              NaN                                           NaN
# 185823   87.00              NaN                                           NaN
# 185824  120.00              NaN                                           NaN
# 185825  126.00              NaN                                           NaN
# 185826  120.00              NaN                                           NaN
# 185827   93.00              NaN                                           NaN
# 185828  120.00              NaN                                           NaN
# 185829  120.00              NaN                                           NaN
# 185830  114.00              NaN                                           NaN
# 185831  128.00              NaN                                           NaN
# 185832  145.00              NaN                                           NaN
# 185833  152.00              NaN                                           NaN
# 185834  140.00              NaN                                           NaN
# 185835   79.00              NaN                                           NaN
# 185836  134.00              NaN                                           NaN
# 185837  240.00              NaN                                           NaN
# 185838  120.00              NaN                                           NaN
# 185839  128.00              NaN                                           NaN
# 185840  120.00              NaN                                           NaN
# 185841  120.00              NaN                                           NaN
# 185842  200.00              NaN                                           NaN
# 185843  200.00              NaN                                           NaN
# 185844  136.00              NaN                                           NaN
# 185845  185.01              NaN                                           NaN
#
#                    genres  mxl
# 0                     NaN  NaN
# 1                     NaN  NaN
# 2                    Jazz  NaN
# 3                     NaN  NaN
# 4                    Rock  NaN
# 5                     NaN  NaN
# 6                Pop,Rock  NaN
# 7                     NaN  NaN
# 8                     NaN  NaN
# 9                     NaN  NaN
# 10               Pop,Rock  NaN
# 11                    NaN  NaN
# 12                    NaN  NaN
# 13                    NaN  NaN
# 14                    NaN  NaN
# 15                    NaN  NaN
# 16                    NaN  NaN
# 17                    NaN  NaN
# 18                    NaN  NaN
# 19                    NaN  NaN
# 20                    NaN  NaN
# 21                    NaN  NaN
# 22                    NaN  NaN
# 23                    NaN  NaN
# 24                    NaN  NaN
# 25                    NaN  NaN
# 26                    NaN  NaN
# 27                    NaN  NaN
# 28              J-Pop,Pop  NaN
# 29                    NaN  NaN
# ...                   ...  ...
# 185816  anything,inferred  NaN
# 185817  anything,inferred  NaN
# 185818  anything,inferred  NaN
# 185819  anything,inferred  NaN
# 185820  anything,inferred  NaN
# 185821  anything,inferred  NaN
# 185822  anything,inferred  NaN
# 185823  anything,inferred  NaN
# 185824  anything,inferred  NaN
# 185825  anything,inferred  NaN
# 185826  anything,inferred  NaN
# 185827  anything,inferred  NaN
# 185828  anything,inferred  NaN
# 185829  anything,inferred  NaN
# 185830  anything,inferred  NaN
# 185831  anything,inferred  NaN
# 185832  anything,inferred  NaN
# 185833  anything,inferred  NaN
# 185834  anything,inferred  NaN
# 185835  anything,inferred  NaN
# 185836  anything,inferred  NaN
# 185837  anything,inferred  NaN
# 185838  anything,inferred  NaN
# 185839  anything,inferred  NaN
# 185840  anything,inferred  NaN
# 185841  anything,inferred  NaN
# 185842  anything,inferred  NaN
# 185843  anything,inferred  NaN
# 185844  anything,inferred  NaN
# 185845  anything,inferred  NaN
#
# [185846 rows x 22 columns]

# %%
[df.shape for df in all_dfs], merged_df.shape
# Out:
# ([(20076, 21),
#   (5784, 12),
#   (4711, 12),
#   (2538, 13),
#   (314, 12),
#   (328, 13),
#   (6391, 13),
#   (17243, 12),
#   (128461, 12)],
#  (185846, 22))

# %%
merged_df.to_csv(all_csv, index=False)
