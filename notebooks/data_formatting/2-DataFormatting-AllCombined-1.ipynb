# %% [markdown]
# ### Create CSV from midi sources

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import glob
import os
from tqdm import tqdm
from IPython.display import Image, Audio
import traceback

# %%
import pandas as pd
from fastai.data_block import get_files

# %%
# parallel
from functools import partial
from pathlib import Path

# %%
import sys
sys.path.insert(0, '../../')

# %%
from src.data_sources import *
from src.midi_data import *

# %%
version = 'v15'
data_path = Path('data/midi')
version_path = data_path/version
orig_path = version_path/'midi_sources'
metapath = version_path/'metadata'
combined_csv = metapath/'combined.csv'
all_csv = metapath/'midi_sources.csv'
metapath.mkdir(parents=True, exist_ok=True)

# %%
def create_paths(dirname):
    "Standardize midi_source paths"
    dir_path = orig_path/dirname
    csv_path = metapath/f'{dirname}_metadata.csv'
    return dir_path, csv_path

# %%
sources = ['hooktheory', 'hooktheory_c', 'freemidi', 'midiworld', 'ecomp', 'cprato', 'classic_piano', 'classical_archives', 'musescore', 'wikifonia', 'lmd_clean', '130k_reddit']

# %%
version_path.relative_to(data_path)
# Out:
# PosixPath('v15')

# %%
def relative_path(filepath):
    return str(Path(filepath).relative_to(version_path))

# %% [markdown]
# ### Remove corrupted file - this causes deadlock with music21 processing

# %%
corrupted_files = [
    'midiworld/named_midi/NITRO_BRO_-_IT_WONT_DIE.mid',
    'ecomp/2004/MORET02.mid',
    'ecomp/2006/Mordvinov9.MID',
    'ecomp/2006/Na06.MID',
    'ecomp/2008/Cui01.MID',
    'ecomp/2008/Cui02.MID',
    'ecomp/2008/Cui03.MID',
    'ecomp/2008/Cui04.MID',
    'ecomp/2008/Cui05.MID',
    'ecomp/2008/Cui06.MID',
    'ecomp/2008/Cui07.MID',
    'ecomp/2008/Cui08.MID',
    'ecomp/2008/Tan01.MID',
    'ecomp/2008/Tan02.MID',
    'ecomp/2008/Tan03.MID',
    'ecomp/2018/KaszoS14.MID',
    'midiworld/named_midi/Rob_Zombie_-_Demonoid_Phenomenon.mid',
    'midiworld/named_midi/Rob_Zombie_-_Demonoid_Phenomenon.mxl',
]
for f in corrupted_files:
    fp = orig_path/f
    if fp.exists(): fp.unlink()

# %%
import hashlib

# %%
def arr2csv(arr, out_file):
    "Convert metadata array to csv"
    all_keys = {k for d in arr for k in d.keys()}
    arr = [format_values(x) for x in arr]
    with open(out_file, 'w') as f:
        dict_writer = csv.DictWriter(f, list(all_keys))
        dict_writer.writeheader()
        dict_writer.writerows(arr)

# %%
def directory2csv(files, meta_func, csv_path):
    "Iterate through midi_source dir and map file to metadata"
    
    def get_meta(fp):
        # over 350mb takes crazy long to analyze
        size = fp.stat().st_size/1000
        if fp.suffix == 'mid' and size > 350: 
#             print('Removing mid over 350mb', fp, dixr)
            return None
        if fp.suffix == 'mxl' and size > 420: 
#             print('Removing mxl over 420mb', fp, size)
            return None
#         try:
        m = meta_func(fp)
        if m: m['md5'] = hashlib.md5(open(fp,'rb').read()).hexdigest()
        return m
#         except Exception as e:
#             print('Error:', fp, e)
#         return None
    
    mlist = [get_meta(fp) for fp in files]
    mlist = [x for x in mlist if x is not None]
    arr2csv(mlist, csv_path)
    return mlist

# %% [markdown]
# ### Hooktheory

# %%
ht_cat = 'hooktheory'
ht_path, ht_csv = create_paths(ht_cat)
ht_midi_list = list((ht_path/'pianoroll').glob('*/*/*/*_key_original.mid')); 
len(ht_midi_list)
# Out:
# 20076

# %%
ht_cat = 'hooktheory_c'
ht_path, ht_csv = create_paths(ht_cat)
ht_path = ht_path.with_name('hooktheory')
ht_midi_list = list((ht_path/'pianoroll').glob('*/*/*/*_key_cmajor.mid'));
len(ht_midi_list)
# Out:
# 20076

# %%
ht_song_list = metapath/'hooktheory_key2info.json'

# %%
def song_key(s): return '_'.join(s.parts[-3:-1])

# %%
ht_key2info = load_json(ht_song_list)

if ht_key2info is None:
    song_info = list((ht_path/'xml').glob('*/*/*/*.json'))
    ht_key2info = {song_key(s):json.load(open(s, 'r')) for s in song_info}
    save_json(ht_key2info, ht_song_list)
len(ht_key2info)
# Out:
# 12008

# %%
# ht_midi_list = list((ht_path/'pianoroll').glob('*/*/*/*_key_cmajor.mid'));

# %%
def get_ht_jsonfile(midi_file): # using json instead of midi for metadata
    return str(midi_file.with_suffix('.json')).replace('pianoroll', 'event').replace('_key', '_symbol_key')

# %%
def get_hooktheory_attr(fp):
    song_info = ht_key2info[song_key(fp)]
    song_json = json.load(open(get_ht_jsonfile(fp), 'r'))
    metadata = song_json['metadata']
    artist = fp.parts[-3]
    title = fp.parts[-2]
    section = fp.name.split('_')[0]
    
    ht_key = metadata['key']
    ht_mode = metadata['mode']
    if ht_mode is None: ht_mode = 'major'
    ht_offset = keyc_offset(ht_key, ht_mode)
    
    # convert stream here
    return {
        'artist': artist,
        'title': title,
        'midi': relative_path(fp),
        'section': section,
        'parts': song_info['section'],
        'song_url': song_info['song_url'],
        'genres': song_info['genres'],
        'midi_title': metadata['title'],
        'source': ht_cat,
        'ht_bpm': metadata['BPM'],
        'ht_mode': metadata['mode'],
        'ht_key': metadata['key'],
        'ht_offset': ht_offset,
        'ht_time_signature': metadata['beats_in_measure']
    }

# %%
# sanity check
# hook_out = get_hooktheory_attr(song_json[1000]); hook_out

# %%
ht_metadata = directory2csv(ht_midi_list, 
                            meta_func=get_hooktheory_attr, 
                            csv_path=ht_csv)
df = pd.read_csv(ht_csv); df.head()
# Out:
#    ht_time_signature  ht_offset  \
# 0                  4          0
# 1                  3          0
# 2                  4         -5
# 3                  4         -5
# 4                  4         -5
#
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                      parts  ht_bpm  ht_mode                     midi_title  \
# 0             intro,chorus     128      1.0                      yu-gi-oh3
# 1             intro,chorus      85      1.0                       yu-gi-oh
# 2                   chorus      96      6.0                         kiefer
# 3  verse,pre-chorus,chorus     152      6.0  senbonzakura - pre-Pre-Chorus
# 4  verse,pre-chorus,chorus     152      6.0                   Senbonzakura
#
#          artist                                           song_url     genres  \
# 0  wayne-sharpe  https://www.hooktheory.com/theorytab/view/wayn...        NaN
# 1  wayne-sharpe  https://www.hooktheory.com/theorytab/view/wayn...        NaN
# 2    what-a-day  https://www.hooktheory.com/theorytab/view/what...       Jazz
# 3    whiteflame  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop
# 4    whiteflame  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop
#
#        source ht_key                               md5                title
# 0  hooktheory      C  bf1f29e5ff84e3e93e37fb873bfb590e  yu-gi-oh-theme-song
# 1  hooktheory      C  055f80ad67f64edb14a85ca8fbfe8c29  yu-gi-oh-theme-song
# 2  hooktheory      D  197f96f5d181f6ce1e2c5ab04ac1ff87               kiefer
# 3  hooktheory      D  9e7ce13a35f1314423a9a6d5a5287a4a         senbonzakura
# 4  hooktheory      D  d5aaf79d0989222f1362f9f46c540a27         senbonzakura

# %% [markdown]
# ## FreeMidi

# %%
fm_path, fm_csv = create_paths('freemidi')
fm_dance_path = metapath/f'freemidi_dance_metadata.json'
fm_pop_path = metapath/f'freemidi_pop_metadata.json'
list(fm_path.glob('*'))
# Out:
# [PosixPath('data/midi/v15/midi_sources/freemidi/genre-disco'),
#  PosixPath('data/midi/v15/midi_sources/freemidi/genre-pop'),
#  PosixPath('data/midi/v15/midi_sources/freemidi/genre-dance-eletric'),
#  PosixPath('data/midi/v15/midi_sources/freemidi/genre-punk'),
#  PosixPath('data/midi/v15/midi_sources/freemidi/genre-hip-hop-rap'),
#  PosixPath('data/midi/v15/midi_sources/freemidi/genre-rock')]

# %%
def parse_freemidi_songs(fp, genres=None, source=None):
    name = fp.with_suffix('').name.split(' - ')
    artist = name[0]
    title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': genres,
        'source': source
    }

# %%
d_parse_func = partial(parse_freemidi_songs, genres='dance', source='freemidi')
dir_path = fm_path/'genre-dance-eletric'
file_list = get_files(dir_path, extensions=['.mid'], recurse=True)
fm_dance_list = directory2csv(file_list, meta_func=d_parse_func, csv_path=fm_dance_path)

# %%
p_parse_func = partial(parse_freemidi_songs, genres='pop', source='freemidi')
dir_path = fm_path/'genre-pop'
file_list = get_files(dir_path, extensions=['.mid'], recurse=True)
fm_pop_list = directory2csv(file_list, meta_func=p_parse_func, csv_path=fm_pop_path)

# %%
fm_all = fm_dance_list + fm_pop_list
arr2csv(fm_all, fm_csv)
df = pd.read_csv(fm_csv); df.head()
# Out:
#                                                 midi     artist genres  \
# 0  midi_sources/freemidi/genre-dance-eletric/Veng...  Vengaboys  dance
# 1  midi_sources/freemidi/genre-dance-eletric/ATB ...        ATB  dance
# 2  midi_sources/freemidi/genre-dance-eletric/Mado...    Madonna  dance
# 3  midi_sources/freemidi/genre-dance-eletric/Aqua...       Aqua  dance
# 4  midi_sources/freemidi/genre-dance-eletric/Tune...    Tune Up  dance
#
#      source                               md5         title
# 0  freemidi  eb504f29b1a10567814f198e7e049d15   Up And Down
# 1  freemidi  7c461c21684baee9946019c0ed7ce102     Dont stop
# 2  freemidi  ac1e447bff339c29bccbaee3deb13b24  Dress You Up
# 3  freemidi  d0306034dbbb4bbc31a95e3232e5fb73      Dr Jones
# 4  freemidi  996662d57a8e3236b36285c54093697e        Bounce

# %% [markdown]
# ### Gather Lakh Midi Dataset

# %%
lmd_path, lmd_csv = create_paths('lmd_clean')

# %%
def parse_lmd_songs(fp):
    artist = fp.parts[-2]
    title = fp.parts[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': 'pop,inferred',
        'source': 'lmd'
    }

# %%
file_list = get_files(lmd_path, extensions=['.mid'], recurse=True)
lmd_md = directory2csv(file_list, meta_func=parse_lmd_songs, csv_path=lmd_csv)
df = pd.read_csv(lmd_csv); df.head()
# Out:
#                                                 midi         artist  \
# 0         midi_sources/lmd_clean/Peter Maffay/Du.mid   Peter Maffay
# 1      midi_sources/lmd_clean/Peter Maffay/Josie.mid   Peter Maffay
# 2    midi_sources/lmd_clean/Anne Murray/Snowbird.mid    Anne Murray
# 3  midi_sources/lmd_clean/Anne Murray/You Needed ...    Anne Murray
# 4  midi_sources/lmd_clean/The Tremeloes/Silence I...  The Tremeloes
#
#          genres source                               md5  \
# 0  pop,inferred    lmd  6d2ac0d68f5976b161afca8ce061d376
# 1  pop,inferred    lmd  6ccac8947814b6faa132cb5bec7a3bdf
# 2  pop,inferred    lmd  f5069f36a7e56475d7f706ed2d2f8517
# 3  pop,inferred    lmd  48419c2acdc476094487157582829781
# 4  pop,inferred    lmd  3befa396df58762e746c4288fa851f03
#
#                    title
# 0                 Du.mid
# 1              Josie.mid
# 2           Snowbird.mid
# 3      You Needed Me.mid
# 4  Silence Is Golden.mid

# %% [markdown]
# ### Gather 130k Reddit

# %%
reddit_path, reddit_csv = create_paths('130k_reddit')

# %%
def parse_reddit_songs(fp):
    name = fp.with_suffix('').name.replace('_', ' ').split(' - ')
    if len(name) == 1:
        artist = fp.parts[-1]
        title = name[0]
    else:
        artist = name[0]
        title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': 'anything,inferred',
        'source': 'reddit'
    }

# %%
file_list = get_files(reddit_path, extensions=['.mid'], recurse=True)
file_list = [fp for fp in file_list if fp.stat().st_size/1000 < 400] # over 200mb takes crazy long to analyze
reddit_md = directory2csv(file_list, meta_func=parse_reddit_songs, csv_path=reddit_csv)
df = pd.read_csv(reddit_csv); df.head()
# Out:
#                                                 midi              artist  \
# 0  midi_sources/130k_reddit/Jazz_www.thejazzpage....      phasedance.mid
# 1  midi_sources/130k_reddit/Jazz_www.thejazzpage....      IGotRhythm.MID
# 2  midi_sources/130k_reddit/Jazz_www.thejazzpage....  Cheek_To_Cheek.mid
# 3  midi_sources/130k_reddit/Jazz_www.thejazzpage....     16goingon17.mid
# 4  midi_sources/130k_reddit/Jazz_www.thejazzpage....       poinciana.mid
#
#               genres  source                               md5           title
# 0  anything,inferred  reddit  c175323dbdff4b676588609081bf5606      phasedance
# 1  anything,inferred  reddit  912b07a01ae9b81bc0d86118e3972a47      IGotRhythm
# 2  anything,inferred  reddit  53136c05b1dd56a9f11367f8cdda5c2e  Cheek To Cheek
# 3  anything,inferred  reddit  31ddfcdb86c20e4e67cbaa3363c88309     16goingon17
# 4  anything,inferred  reddit  d15dd01250feb42f3b17251c56e6721e       poinciana

# %% [markdown]
# ### Gather Cprato

# %%
cp_path, cp_csv = create_paths('cprato')
# list(cp_path.glob('*'))[:5]

# %%
def parse_cprato_songs(fp, genres=None, source=None):
    name = fp.with_suffix('').name.split(' - ')
    artist = name[0]
    title = name[-1].replace('(midi by Carlo Prato) (www.cprato.com)', '')
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': genres,
        'source': source
    }

# %%
cp_meta = partial(parse_cprato_songs, genres='EDM,inferred', source='cprato')
file_list = get_files(cp_path, extensions=['.mid'], recurse=True)
cp_md = directory2csv(file_list, meta_func=cp_meta, csv_path=cp_csv)
df = pd.read_csv(cp_csv); df.head()
# Out:
#                                                 midi  \
# 0  midi_sources/cprato/Basto - Again And Again (m...
# 1  midi_sources/cprato/The Weeknd ft. Lana Del Re...
# 2  midi_sources/cprato/Two Steps From Hell - Magi...
# 3  midi_sources/cprato/Bermuda Loverz - My Girl (...
# 4  midi_sources/cprato/Cascada - Everytime We Tou...
#
#                         artist        genres  source  \
# 0                        Basto  EDM,inferred  cprato
# 1  The Weeknd ft. Lana Del Rey  EDM,inferred  cprato
# 2          Two Steps From Hell  EDM,inferred  cprato
# 3               Bermuda Loverz  EDM,inferred  cprato
# 4                      Cascada  EDM,inferred  cprato
#
#                                 md5  \
# 0  44ea7e9b46e04ba6f4836f00b3cc50a3
# 1  d67ead892ee2c92cfbb5306bd47c9a0f
# 2  222db08d4744ab9a53ca0d9c6c6e5113
# 3  2befd21ebd0f0c779f7fb436ed828ba1
# 4  b53bfa6f4ab72df165e44263d50a4cbd
#
#                                                title
# 0  Again And Again (midi By Carlo Prato) (www.cpr...
# 1                                 Stargirl Interlude
# 2                                      Magic of Love
# 3  My Girl (Ladidada) (Rimini Rockaz Radio Edit) ...
# 4  Everytime We Touch (Midi By Carlo Prato) (www....

# %% [markdown]
# ### Gather MidiWorld

# %%
mw_path, mw_csv = create_paths('midiworld')

# %%
def parse_midiworld_songs(fp):
    name = fp.with_suffix('').name.replace('_', ' ').split(' - ')
    artist = name[0]
    title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'midi': relative_path(fp),
        'genres': 'pop,inferred',
        'source': 'midiworld'
    }

# %%
file_list = get_files(mw_path/'named_midi', extensions=['.mid'], recurse=True)
mw_md = directory2csv(file_list, meta_func=parse_midiworld_songs, csv_path=mw_csv)
df = pd.read_csv(mw_csv); df.head()
# Out:
#                                                 midi             artist  \
# 0  midi_sources/midiworld/named_midi/The_Carpente...     The Carpenters
# 1  midi_sources/midiworld/named_midi/Joan_Jett_-_...          Joan Jett
# 2  midi_sources/midiworld/named_midi/George_Harri...    George Harrison
# 3  midi_sources/midiworld/named_midi/Video_Game_T...  Video Game Themes
# 4  midi_sources/midiworld/named_midi/The_Corrs_-_...          The Corrs
#
#          genres     source                               md5  \
# 0  pop,inferred  midiworld  6d6e23b4f0e44537f8b5309ffeaa1880
# 1  pop,inferred  midiworld  19efd3ac590d3aede49d2e9e62209115
# 2  pop,inferred  midiworld  bea4eba9aa4e8154ab01108b2b808e3c
# 3  pop,inferred  midiworld  dfbd9c523e1846767746285281d5e971
# 4  pop,inferred  midiworld  2445fa5424432de2a40ece46cbbc853c
#
#                           title
# 0        Rainy Days and Mondays
# 1  I Hate Myself for Loving You
# 2               When We Was Fab
# 3                    Diddy Kong
# 4                       Someday

# %% [markdown]
# ### Gather Wikifonia

# %%
wf_path, wf_csv = create_paths('wikifonia')

# %%
def parse_wikifonia_songs(fp):
    name = fp.with_suffix('').name.replace('_', ' ').split(' - ')
    artist = name[0]
    title = name[-1]
    return {
        'artist': artist.strip(),
        'title': title.strip(),
        'mxl': relative_path(fp),
        'genres': 'pop,inferred',
        'source': 'wikifonia'
    }

# %%
# Warning: if you get a deadlock: 
# PosixPath('data/midi/midi_sources/midiworld/named_midi/NITRO_BRO_-_IT_WONT_DIE.mid') is broken
file_list = get_files(wf_path, extensions=['.mxl'], recurse=True)
wf_md = directory2csv(file_list, meta_func=parse_wikifonia_songs, csv_path=wf_csv)
df = pd.read_csv(wf_csv); df.head()
# Out:
#                              artist        genres     source  \
# 0                      Tommy Dorsey  pop,inferred  wikifonia
# 1                    Amanda McBroom  pop,inferred  wikifonia
# 2  Hans Leo Hassler, From the Latin  pop,inferred  wikifonia
# 3       Arthur Siegel, June Carroll  pop,inferred  wikifonia
# 4                            Unknow  pop,inferred  wikifonia
#
#                                 md5  \
# 0  f3418afa104cd03604c8831123e086e4
# 1  a01bde25baf5c5a91b9f6235bf019890
# 2  4beb6aafed89a87a8171da906d8b5ff8
# 3  a739908a6505fcbe8c7d9bf7b1e47492
# 4  cb2beddd4a86439dcf2d80b5fc6b4e4f
#
#                                                  mxl  \
# 0  midi_sources/wikifonia/Tommy Dorsey - Swingin'...
# 1  midi_sources/wikifonia/Amanda McBroom - The Ro...
# 2  midi_sources/wikifonia/Hans Leo Hassler, From ...
# 3  midi_sources/wikifonia/Arthur Siegel, June Car...
# 4  midi_sources/wikifonia/Unknow - KINDERLIEDJES ...
#
#                        title
# 0        Swingin' on Nothin'
# 1                   The Rose
# 2  O Sacred Head Now Wounded
# 3     Love Is A Simple Thing
# 4       KINDERLIEDJES MEDLEY

# %% [markdown]
# ### Gather Musescore

# %%
ms_path, ms_csv = create_paths('musescore')
ms_songs = load_json(ms_path/'song_map.json')

# %%
def get_number(num_str):
    num_str = num_str.replace(',','').split(' ')[0]
    return int(num_str)

# %%
def parse_musescore_songs(fp):
    score_id = fp.with_suffix('').name
    if score_id not in ms_songs: return None
    
    meta = ms_songs[score_id]
    parts = get_number(meta['parts'])
    views = get_number(meta['views'])
    if parts > 2 or views < 150: return None
    
    return {
        'artist': meta['author'].strip(),
        'title': meta['title'].strip(),
        'mxl': relative_path(fp),
        'genres': 'classical,pop,inferred',
        'source': 'musescore'
    }

# %%
# Warning: if you get a deadlock: 
# PosixPath('data/midi/midi_sources/midiworld/named_midi/NITRO_BRO_-_IT_WONT_DIE.mid') is broken
file_list = get_files(ms_path, extensions=['.mxl'], recurse=True)
ms_list = directory2csv(file_list, meta_func=parse_musescore_songs, csv_path=ms_csv)
df = pd.read_csv(ms_csv); df.head()
# Out:
#                               artist                  genres     source  \
# 0  000@xn--80akgejic5ahko1h.xn--p1ai  classical,pop,inferred  musescore
# 1                             sam027  classical,pop,inferred  musescore
# 2                        CrazyClique  classical,pop,inferred  musescore
# 3                       Mjmatthews51  classical,pop,inferred  musescore
# 4                 Spencer Vanderkley  classical,pop,inferred  musescore
#
#                                 md5                                      mxl  \
# 0  36fb6c38927e5e025f7f8427770cf8fa  midi_sources/musescore/data/2985741.mxl
# 1  b666753133bc72910840a97bddb1fbf9  midi_sources/musescore/data/1425126.mxl
# 2  83de066be1fa555a986376170c467f99  midi_sources/musescore/data/5370824.mxl
# 3  a85e407d2427234ee6bf5aa7ae5ce5e9  midi_sources/musescore/data/1195001.mxl
# 4  d1f72939369c106948993bba9b4fc0a9  midi_sources/musescore/data/4621586.mxl
#
#                                       title
# 0                              Упражнение 2
# 1  Place de la République - Coeur de pirate
# 2   Beyond The Trees - Original Composition
# 3                              Sister Sadie
# 4         My Top 20 Film Soundtracks Medley

# %% [markdown]
# ### Yamaha - piano

# %%
ec_path, ec_csv = create_paths('ecomp')
ec_songs = load_json(ec_path/'song_list.json')
# list(ec_path.glob('*'))[:5]

# %%
def parse_ecomp_songs(fp):
    song_info = ec_songs[fp.stem]
    return {
        'artist': song_info['artist'],
        'title': song_info['title'],
        'mxl': relative_path(fp),
        'genres': 'classical',
        'source': 'ecomp'
    }

# %%
file_list = get_files(ec_path, extensions=['.mxl'], recurse=True)

# %%
ec_md = directory2csv(file_list, meta_func=parse_ecomp_songs, csv_path=ec_csv)
df = pd.read_csv(ec_csv); df.head()
# Out:
#                      artist     genres source  \
# 0  Johann    Sebastian Bach  classical  ecomp
# 1      Moritz    Moszkowski  classical  ecomp
# 2      Nikolai     Kapustin  classical  ecomp
# 3                            classical  ecomp
# 4    Giuseppe     Scarlatti  classical  ecomp
#
#                                 md5                                   mxl  \
# 0  39099f086fdc79c2828c13274fcd0f25  midi_sources/ecomp/2017/SirajA01.mxl
# 1  fe22a58bcff66e8b724b71c10b5465b6     midi_sources/ecomp/2017/LiC05.mxl
# 2  8b38131646b8d71dc10269d3e2d608d0   midi_sources/ecomp/2017/WangY05.mxl
# 3  2637be3aec226a2fb74e86bb7a1fde81    midi_sources/ecomp/2017/SunY05.mxl
# 4  c154b4269f8c8cecdb5b2972e3e2d831  midi_sources/ecomp/2017/ZhangE06.mxl
#
#                                                title
# 0  Prelude and    Fugue in E-flat Major, WTC II, ...
# 1  Chanson Boheme de    l'Opera "Carmen" by Georg...
# 2                      Concert Etude Op. 40    No. 3
# 3     I. Con moto agitato. Andante. Con moto agitato
# 4                       Sonata in G Major, K.    455

# %% [markdown]
# ### Classic Piano

# %%
clc_path, clc_csv = create_paths('classic_piano')
# list(clc_path.glob('*'))[:5]

# %%
def parse_classic_songs(fp):
    name = fp.with_suffix('').name.split('_')
    artist = name[0]
    title = ' '.join(name[1:])
    return {
        'artist': artist,
        'title': title,
        'mxl': relative_path(fp),
        'genres': 'classical',
        'source': 'classical_piano'
    }

# %%
file_list = get_files(clc_path, extensions=['.mxl'], recurse=True)

# %%
clc_md = directory2csv(file_list, meta_func=parse_classic_songs, csv_path=clc_csv)
df = pd.read_csv(clc_csv); df.head()
# Out:
#      artist     genres           source                               md5  \
# 0       liz  classical  classical_piano  93d730fce9a3e2fabe1a0ea3e2cf80b6
# 1        ty  classical  classical_piano  d45bf8f2b4b0242879305a8423a3cb99
# 2  schumm-3  classical  classical_piano  2238d47b4162b55bafee79b16af46a37
# 3      chpn  classical  classical_piano  3d5c30ba63b886de6555a5d4911cf55f
# 4     grieg  classical  classical_piano  51758e4fb8b37d0389148d37652b1d58
#
#                                                  mxl              title
# 0  midi_sources/classic_piano/liz_rhap15_format0.mxl     rhap15 format0
# 1  midi_sources/classic_piano/ty_september_format...  september format0
# 2    midi_sources/classic_piano/schumm-3_format0.mxl            format0
# 3  midi_sources/classic_piano/chpn_op33_4_format0...     op33 4 format0
# 4  midi_sources/classic_piano/grieg_spring_format...     spring format0

# %% [markdown]
# ### Classical Music Archives

# %%
cma_path, cma_csv = create_paths('classical_archives')
# list(cma_path.glob('*'))[:5]

# %%
def parse_cma_songs(fp):
    name = fp.with_suffix('').name
    return {
        'artist': name,
        'title': name,
        'mxl': relative_path(fp),
        'genres': 'classical',
        'source': 'classical_archives'
    }

# %%
file_list = get_files(cma_path, extensions=['.mxl'], recurse=True); len(file_list)
# Out:
# 14671

# %%
cma_md = directory2csv(file_list, meta_func=parse_cma_songs, csv_path=cma_csv)
df = pd.read_csv(cma_csv); df.head()
# Out:
#      artist     genres              source                               md5  \
# 0  jsrjeuxd  classical  classical_archives  d14444f06de8a7ad6bec95c98afa566c
# 1     men26  classical  classical_archives  42c8738df5fa98fa5b715d058890e376
# 2  szecheny  classical  classical_archives  0af7005d072bc22ea2f188569adcfa9d
# 3  acocored  classical  classical_archives  e8842eb5b97285673075043aaab09ca8
# 4  op73_2_3  classical  classical_archives  be5fea22e3d87257123c98090d9f4c6c
#
#                                                 mxl     title
# 0  midi_sources/classical_archives/021/jsrjeuxd.mxl  jsrjeuxd
# 1     midi_sources/classical_archives/021/men26.mxl     men26
# 2  midi_sources/classical_archives/021/szecheny.mxl  szecheny
# 3  midi_sources/classical_archives/021/acocored.mxl  acocored
# 4  midi_sources/classical_archives/021/op73_2_3.mxl  op73_2_3

# %% [markdown]
# ### Creating CSV

# %%
combined_csvs = [create_paths(s)[-1] for s in sources if s != 'hooktheory_c']
dfs = [pd.read_csv(csv) for csv in combined_csvs]

# %%
combined_df = pd.concat(dfs, sort=False)
combined_df = combined_df.reset_index(drop=True); combined_df.head()
# Out:
#    ht_time_signature  ht_offset  \
# 0                4.0        0.0
# 1                3.0        0.0
# 2                4.0       -5.0
# 3                4.0       -5.0
# 4                4.0       -5.0
#
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                      parts  ht_bpm  ht_mode                     midi_title  \
# 0             intro,chorus   128.0      1.0                      yu-gi-oh3
# 1             intro,chorus    85.0      1.0                       yu-gi-oh
# 2                   chorus    96.0      6.0                         kiefer
# 3  verse,pre-chorus,chorus   152.0      6.0  senbonzakura - pre-Pre-Chorus
# 4  verse,pre-chorus,chorus   152.0      6.0                   Senbonzakura
#
#          artist                                           song_url     genres  \
# 0  wayne-sharpe  https://www.hooktheory.com/theorytab/view/wayn...        NaN
# 1  wayne-sharpe  https://www.hooktheory.com/theorytab/view/wayn...        NaN
# 2    what-a-day  https://www.hooktheory.com/theorytab/view/what...       Jazz
# 3    whiteflame  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop
# 4    whiteflame  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop
#
#        source ht_key                               md5                title  \
# 0  hooktheory      C  bf1f29e5ff84e3e93e37fb873bfb590e  yu-gi-oh-theme-song
# 1  hooktheory      C  055f80ad67f64edb14a85ca8fbfe8c29  yu-gi-oh-theme-song
# 2  hooktheory      D  197f96f5d181f6ce1e2c5ab04ac1ff87               kiefer
# 3  hooktheory      D  9e7ce13a35f1314423a9a6d5a5287a4a         senbonzakura
# 4  hooktheory      D  d5aaf79d0989222f1362f9f46c540a27         senbonzakura
#
#    mxl
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
deduped_df = combined_df.drop_duplicates(subset=['md5'], keep='first') #

# %% [markdown]
# Midiworld - 90% duplicates with rest
# Freemidi - 50% duplicates with rest
# LMD - 70% duplicates with rest

# %%
# from collections import Counter
# # No dedups
# print(Counter(merged_df.source.values))
# # replacing reddit
# print(Counter(merged_df.drop_duplicates(subset=['md5'], keep='first').source.values))
# # reddit replace else
# print(Counter(merged_df.drop_duplicates(subset=['md5'], keep='last').source.values))
# # Midiworld - 90% duplicates with rest, 
# # Freemidi - 50% duplicates with rest,
# # LMD - 70% duplicates with rest

# %%
from collections import Counter
Counter(deduped_df.source.values)
# Out:
# Counter({'hooktheory': 19882,
#          'freemidi': 5168,
#          'midiworld': 4109,
#          'ecomp': 2735,
#          'cprato': 312,
#          'classical_piano': 329,
#          'classical_archives': 14671,
#          'musescore': 11502,
#          'wikifonia': 6391,
#          'lmd': 13568,
#          'reddit': 98683})

# %%
# combined df does not contain hooktheory_c files
[df.shape for df in dfs], combined_df.shape, deduped_df.shape
# Out:
# ([(20076, 15),
#   (5784, 6),
#   (4711, 6),
#   (2735, 6),
#   (314, 6),
#   (329, 6),
#   (14671, 6),
#   (11504, 6),
#   (6391, 6),
#   (17243, 6),
#   (128419, 6)],
#  (212177, 16),
#  (177350, 16))

# %%
hooktheory_c_csv = pd.read_csv(create_paths('hooktheory_c')[-1])
out_df = pd.concat([deduped_df, hooktheory_c_csv], sort=False); out_df.shape
# Out:
# (197426, 16)

# %%
out_df.to_csv(combined_csv, index=False)

# %% [markdown]
# ### Convert MXL to Midi
#
# Makes it easier for us to process in part 2

# %%
from src.data_sources import process_all

# %%
df = pd.read_csv(combined_csv); df.head()
all_records = df.to_dict(orient='records'); len(all_records)
# Out:
# 197426

# %%
def mxl2midi_func(metadata):
    result = metadata.copy()
    if not isinstance(result.get('mxl'), str): return result

    input_path = version_path/metadata['mxl']
    out_file = Path(str(metadata['mxl']).replace('midi_sources/', 'midi_sources/from_mxl/')).with_suffix('.mid')
    output_path = version_path/out_file
    
    if not output_path.exists():
        try:
            output_path.parent.mkdir(parents=True, exist_ok=True)
            stream = file2stream(input_path)
            stream.write('midi', fp=output_path)
            print('Encoded:', output_path)
        except Exception:
#             print(traceback.format_exc())
            return result
        
    result['midi'] = out_file
    return result

# %%
def timeout_func(data, seconds):
    print("Timeout:", seconds, data.get('mxl'))

# %%
processed = process_all(mxl2midi_func, all_records, timeout=600, timeout_func=timeout_func)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='197426' class='' max='197426', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [197426/197426 56:59<00:00]
#     </div>
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Schneider03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/LiuY04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Abdelmola03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/WangY04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Zusko06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/ZhangE08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/YuP04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Bach03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Namirovsky05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Lee_E03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Broberg03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Yanagitani03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Avdeeva05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/LiuC04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Yarden07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Yoon03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/KabuliL09.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Shelest03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Koshoeva03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/SunY04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/WangV03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Yanagitani04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/ChenC06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Kleisen02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Duepree03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Jia03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Song03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Seo03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Huangci04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Han01.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Huangci03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Benabdallah08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Huang03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Pavlovic03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Duepree13.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Savitski05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Izzard04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Lin17.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Krasnitsky05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Hwang02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/ZhangW06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Huang11.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Lisiecki16.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/WangA03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Tysman03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Krasnitsky06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Larionova03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/WangH07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Kociuban14.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Guzman02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Namirovsky08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/ChenC03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/ChenC05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Mordvinov07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Denisova18.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Faliks03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/RAN03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Yanagitani05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Larionova07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/KaiRuiR08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Shybayeva06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Larionova04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/LeeSH10.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Avdeeva08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/WongDoe05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Avdeeva03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/DeTurck10.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2017/SunY10.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2008/Ko17.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/USHIKI04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Savitski08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/DANILO06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/RAN04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/KARYAG08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/ADIG05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Fung03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Krasnitsky07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Benabdallah09.mid
# Timeout: 600 midi_sources/ecomp/2017/KabuliL08.mxl
# Timeout: 600 midi_sources/ecomp/2008/Meng03.mxl
# Timeout: 600 midi_sources/ecomp/2006/Huangci07.mxl
# Timeout: 600 midi_sources/ecomp/2006/WongDoe07.mxl
# Timeout: 600 midi_sources/ecomp/2006/Savitski07.mxl
# Timeout: 600 midi_sources/ecomp/2006/Shen08.mxl
# Timeout: 600 midi_sources/ecomp/2006/Shen09.mxl
# Timeout: 600 midi_sources/ecomp/2006/Dulu08.mxl
# Timeout: 600 midi_sources/ecomp/2006/Namirovsky04.mxl
# Timeout: 600 midi_sources/ecomp/2006/KorchinskayaKogan07.mxl
# Timeout: 600 midi_sources/ecomp/2006/Mordvinov12.mxl
# Timeout: 600 midi_sources/ecomp/2006/ChenC07.mxl
# Timeout: 600 midi_sources/ecomp/2006/Arciglione14.mxl
# Timeout: 600 midi_sources/ecomp/2006/Larionova05.mxl
# Timeout: 600 midi_sources/ecomp/2006/Krasnitsky08.mxl
# Timeout: 600 midi_sources/ecomp/2006/Shi07.mxl
# Timeout: 600 midi_sources/ecomp/2006/Yarden09.mxl
# Timeout: 600 midi_sources/ecomp/2006/Yarden11.mxl
# Timeout: 600 midi_sources/ecomp/2006/Yanagitani07.mxl
# Timeout: 600 midi_sources/ecomp/2006/MorozovS05.mxl
# Timeout: 600 midi_sources/ecomp/2006/KorchinskayaKogan08.mxl
# Timeout: 600 midi_sources/ecomp/2006/Avdeeva06.mxl
# Timeout: 600 midi_sources/ecomp/2006/Zusko09.mxl
# Timeout: 600 midi_sources/ecomp/2006/Savitski09.mxl
# Timeout: 600 midi_sources/ecomp/2006/Shen04.mxl
# Timeout: 600 midi_sources/ecomp/2006/Huangci06.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/NAKAJI03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/SHYBAY03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/EVSTIO05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/RAN08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/SCHU06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/Park08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/IVLEVA04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/UENO03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/KIM_W03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/YOO06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/EVSTIO03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/HSU04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/IVLEVA09.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/SCHU07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/DeTurck08.mid
# Timeout: 600 midi_sources/ecomp/2006/Mordvinov11.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/YOO07.mid
# Timeout: 600 midi_sources/ecomp/2006/Namirovsky03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/HUAN_B02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2006/KorchinskayaKogan06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/KOLESO06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/FONG03.mid
# Timeout: 600 midi_sources/ecomp/2006/Dulu07.mxl
# Timeout: 600 midi_sources/ecomp/2006/Shybayeva07.mxl
# Timeout: 600 midi_sources/ecomp/2006/Shamray10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/KARYAG05.mid
# Timeout: 600 midi_sources/ecomp/2006/Arciglione05.mxl
# Timeout: 600 midi_sources/ecomp/2006/Huangci08.mxl
# Timeout: 600 midi_sources/ecomp/2006/Yanagitani08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Tak07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/BENABD05.mid
# Timeout: 600 midi_sources/ecomp/2006/DeTurck11.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/ADIG03.mid
# Timeout: 600 midi_sources/ecomp/2004/EVSTIO04.mxl
# Timeout: 600 midi_sources/ecomp/2004/USHIKI06.mxl
# Timeout: 600 midi_sources/ecomp/2004/POTAMO03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/LEE_K05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/KOLESS03.mid
# Timeout: 600 midi_sources/ecomp/2004/KRASNI15.mxl
# Timeout: 600 midi_sources/ecomp/2004/TOIVIO03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/IVLEVA08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Soukhovetski04.mid
# Timeout: 600 midi_sources/ecomp/2004/HUAN_J08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Na06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/GORDEL03.mid
# Timeout: 600 midi_sources/ecomp/2004/DANILO05.mxl
# Timeout: 600 midi_sources/ecomp/2004/LEE_K08.mxl
# Timeout: 600 midi_sources/ecomp/2004/ADIG06.mxl
# Timeout: 600 midi_sources/ecomp/2004/HONG08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Yeletskiy02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Terenkova04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Rozanski06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Zuber06.mid
# Timeout: 600 midi_sources/ecomp/2004/SHYBAY06.mxl
# Timeout: 600 midi_sources/ecomp/2004/BLINOV05.mxl
# Timeout: 600 midi_sources/ecomp/2004/YOO08.mxl
# Timeout: 600 midi_sources/ecomp/2004/RAN05.mxl
# Timeout: 600 midi_sources/ecomp/2004/KOLESO08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/EVSTIO06.mid
# Timeout: 600 midi_sources/ecomp/2004/SINKEV07.mxl
# Timeout: 600 midi_sources/ecomp/2004/FONG05.mxl
# Timeout: 600 midi_sources/ecomp/2004/DANILO04.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Zuber03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Taverna04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/HUAN_J05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/IVLEVA06.mid
# Timeout: 600 midi_sources/ecomp/2004/LEE_K07.mxl
# Timeout: 600 midi_sources/ecomp/2004/EVSTIO07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Rozanski05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Shi08.mid
# Timeout: 600 midi_sources/ecomp/2004/SINKEV12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Ahn03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Garritson09.mid
# Timeout: 600 midi_sources/ecomp/2004/YOO05.mxl
# Timeout: 600 midi_sources/ecomp/2004/FALIKS04.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/BLINOV06.mid
# Timeout: 600 midi_sources/ecomp/2004/KIM_B09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Taverna05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/USHIKI05.mid
# Timeout: 600 midi_sources/ecomp/2004/FALIKS05.mxl
# Timeout: 600 midi_sources/ecomp/2004/SHYBAY05.mxl
# Timeout: 600 midi_sources/ecomp/2004/KRASNI12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Soukhovetski07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Zukiewicz03.mid
# Timeout: 600 midi_sources/ecomp/2004/CHEN11.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Sychev02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2004/KRASNI14.mid
# Timeout: 600 midi_sources/ecomp/2004/KOLESO05.mxl
# Timeout: 600 midi_sources/ecomp/2004/SCHU09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Gryaznov08.mid
# Timeout: 600 midi_sources/ecomp/2004/KOLESO07.mxl
# Timeout: 600 midi_sources/ecomp/2004/SHYBAY07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Yang08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Tysman07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/CaiC10.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Taverna03.mid
# Timeout: 600 midi_sources/ecomp/2004/KIM_B10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Soukhovetski06.mid
# Timeout: 600 midi_sources/ecomp/2004/CHEN05.mxl
# Timeout: 600 midi_sources/ecomp/2009/Lee09.mxl
# Timeout: 600 midi_sources/ecomp/2009/Yeletskiy08.mxl
# Timeout: 600 midi_sources/ecomp/2009/Jussow06.mxl
# Timeout: 600 midi_sources/ecomp/2009/Rozanski10.mxl
# Timeout: 600 midi_sources/ecomp/2009/KimG10.mxl
# Timeout: 600 midi_sources/ecomp/2009/Taverna09.mxl
# Timeout: 600 midi_sources/ecomp/2009/Gryaznov06.mxl
# Timeout: 600 midi_sources/ecomp/2009/Shi10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Zuber04.mid
# Timeout: 600 midi_sources/ecomp/2009/Tysman09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ChernovA04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/DupreeF19.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/LeungM10.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ChernovA06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Sekino13.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Sekino04.mid
# Timeout: 600 midi_sources/ecomp/2009/KimG09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/BrendleA02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Jia03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/JIa05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/KyykhynenT05.mid
# Timeout: 600 midi_sources/ecomp/2009/Shelest03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Georgieva02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/HuangSW14.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ParkS03.mid
# Timeout: 600 midi_sources/ecomp/2009/Shi06.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2009/Falzone03.mid
# Timeout: 600 midi_sources/ecomp/2009/Taverna10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ChenGuang14.mid
# Timeout: 600 midi_sources/ecomp/2009/Jia06.mxl
# Timeout: 600 midi_sources/ecomp/2009/Soukhovetski08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/DupreeF22.mid
# Timeout: 600 midi_sources/ecomp/2009/Zuber08.mxl
# Timeout: 600 midi_sources/ecomp/2009/Na08.mxl
# Timeout: 600 midi_sources/ecomp/2009/Karpeyev03.mxl
# Timeout: 600 midi_sources/ecomp/2009/Lee08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ShevchenkoO10.mid
# Timeout: 600 midi_sources/ecomp/2009/Na10.mxl
# Timeout: 600 midi_sources/ecomp/2009/Lee10.mxl
# Timeout: 600 midi_sources/ecomp/2009/KimG06.mxl
# Timeout: 600 midi_sources/ecomp/2009/Garritson05.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/JohannsonP20.mid
# Timeout: 600 midi_sources/ecomp/2009/Staupe12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/GarritsonL04.mid
# Timeout: 600 midi_sources/ecomp/2009/Yang09.mxl
# Timeout: 600 midi_sources/ecomp/2009/Lee03.mxl
# Timeout: 600 midi_sources/ecomp/2009/Huang03.mxl
# Timeout: 600 midi_sources/ecomp/2009/Sekino05.mxl
# Timeout: 600 midi_sources/ecomp/2009/CaiC08.mxl
# Timeout: 600 midi_sources/ecomp/2009/Tak06.mxl
# Timeout: 600 midi_sources/ecomp/2009/Yeletskiy06.mxl
# Timeout: 600 midi_sources/ecomp/2009/Taverna06.mxl
# Timeout: 600 midi_sources/ecomp/2009/Yeletskiy05.mxl
# Timeout: 600 midi_sources/ecomp/2009/Gasanov06.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/DupreeF04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/LeungM14.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/GarritsonL06.mid
# Timeout: 600 midi_sources/ecomp/2009/Tysman08.mxl
# Timeout: 600 midi_sources/ecomp/2009/Zuber07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/HamSY10.mid
# Timeout: 600 midi_sources/ecomp/2009/Zhdanov10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/DupreeF09.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/LiuY05.mid
# Timeout: 600 midi_sources/ecomp/2014/MaximovI02.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ParkS11.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/HuangSW07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/MunA09.mid
# Timeout: 600 midi_sources/ecomp/2014/WangY11.mxl
# Timeout: 600 midi_sources/ecomp/2014/KharselM12.mxl
# Timeout: 600 midi_sources/ecomp/2014/LeungM11.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/LiuY11.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ChernovA20.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/ChenW04.mid
# Timeout: 600 midi_sources/ecomp/2014/PrjevalskayaM23.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/KimHJ06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/KimHJ01.mid
# Timeout: 600 midi_sources/ecomp/2014/DupreeF14.mxl
# Timeout: 600 midi_sources/ecomp/2014/ShevchenkoO04.mxl
# Timeout: 600 midi_sources/ecomp/2014/GonzalezJ09.mxl
# Timeout: 600 midi_sources/ecomp/2014/HamSY06.mxl
# Timeout: 600 midi_sources/ecomp/2014/ParkJH17.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/RichardsonC06.mid
# Timeout: 600 midi_sources/ecomp/2014/KimHJ10.mxl
# Timeout: 600 midi_sources/ecomp/2014/HamSY05.mxl
# Timeout: 600 midi_sources/ecomp/2014/GintovP09.mxl
# Timeout: 600 midi_sources/ecomp/2014/KimHJ14.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/MunA11.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/WuuE12.mid
# Timeout: 600 midi_sources/ecomp/2014/JohannsonP11.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/LuoJ11.mid
# Timeout: 600 midi_sources/ecomp/2014/GarritsonL07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/ZhaoK11.mid
# Timeout: 600 midi_sources/ecomp/2014/PrjevalskayaM17.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ChernovA23.mid
# Timeout: 600 midi_sources/ecomp/2014/MaximovI08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Colafelice03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/KimHJ05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/LeeN05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/RichardsonC07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/ZhaoK06.mid
# Timeout: 600 midi_sources/ecomp/2014/JohannsonP01.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/Chenguang02.mid
# Timeout: 600 midi_sources/ecomp/2014/ChernovA12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/JohannsonP16.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Eras07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/KyykhynenT14.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Wang07.mid
# Timeout: 600 midi_sources/ecomp/2014/ShevchenkoO03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/WangY08.mid
# Timeout: 600 midi_sources/ecomp/2014/JohannsonP15.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Park05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Teo08.mid
# Timeout: 600 midi_sources/ecomp/2014/MustakimovT08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/WangY03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2014/ChenGuang23.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/LiYZ04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Knoll04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Zhou11.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Eras08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/yamaguchi04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/YeZ05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Wang04.mid
# Timeout: 600 midi_sources/ecomp/2014/PrjevalskayaM04.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Teo12.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Mo12.mid
# Timeout: 600 midi_sources/ecomp/2014/ChenGuang18.mxl
# Timeout: 600 midi_sources/ecomp/2014/KharselM08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Knoll11.mid
# Timeout: 600 midi_sources/ecomp/2014/DupreeF01.mxl
# Timeout: 600 midi_sources/ecomp/2014/PrjevalskayaM18.mxl
# Timeout: 600 midi_sources/ecomp/2014/BrendleA08.mxl
# Timeout: 600 midi_sources/ecomp/2014/DupreeF02.mxl
# Timeout: 600 midi_sources/ecomp/2014/HuangSW11.mxl
# Timeout: 600 midi_sources/ecomp/2014/HuangSW02.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Eras09.mid
# Timeout: 600 midi_sources/ecomp/2014/ParkJH03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/mikhailoff03.mid
# Timeout: 600 midi_sources/ecomp/2014/ChernovA13.mxl
# Timeout: 600 midi_sources/ecomp/2014/GintovP08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Colafelice06.mid
# Timeout: 600 midi_sources/ecomp/2014/ChenGuang07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Yang13.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/giltburg01.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/huang02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2015/JeonH08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/morozov02.mid
# Timeout: 600 midi_sources/ecomp/2015/LiYZ07.mxl
# Timeout: 600 midi_sources/ecomp/2015/RichardsonC04.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Min10.mid
# Timeout: 600 midi_sources/ecomp/2015/LuM03.mxl
# Timeout: 600 midi_sources/ecomp/2015/WuuE01.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Hou07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/YeZ07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/hannumizzard04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/giltburg05.mid
# Timeout: 600 midi_sources/ecomp/2015/MiyashitaM02.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/franceschetti02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/mamriev02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/giltburg02.mid
# Timeout: 600 midi_sources/ecomp/2015/MunA02.mxl
# Timeout: 600 midi_sources/ecomp/2011/Sham09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/LeungM02.mid
# Timeout: 600 midi_sources/ecomp/2011/Mizumoto12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/giltburg03.mid
# Timeout: 600 midi_sources/ecomp/2011/Colafelice12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/park05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2011/Chon11.mid
# Timeout: 600 midi_sources/ecomp/2011/Kim10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/savitski01.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/morozov01.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2013/Lu10.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/victoria06.mid
# Timeout: 600 midi_sources/ecomp/2013/Knoll10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/hannumizzard03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/mamriev01.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/kolessova05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/dvorkine04.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/AbdelmoulaJS15.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KotysV13.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/GalantM05.mid
# Timeout: 600 midi_sources/ecomp/2002/kolessova02.mxl
# Timeout: 600 midi_sources/ecomp/2002/guttman04.mxl
# Timeout: 600 midi_sources/ecomp/2002/cho03.mxl
# Timeout: 600 midi_sources/ecomp/2002/malan07.mxl
# Timeout: 600 midi_sources/ecomp/2002/hannumizzard01.mxl
# Timeout: 600 midi_sources/ecomp/2002/sun06.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/kolessova04.mid
# Timeout: 600 midi_sources/ecomp/2002/park03.mxl
# Timeout: 600 midi_sources/ecomp/2002/huang03.mxl
# Timeout: 600 midi_sources/ecomp/2002/franceschetti03.mxl
# Timeout: 600 midi_sources/ecomp/2002/soloman03.mxl
# Timeout: 600 midi_sources/ecomp/2002/yamaguchi02.mxl
# Timeout: 600 midi_sources/ecomp/2002/mikhailoff01.mxl
# Timeout: 600 midi_sources/ecomp/2002/lin02.mxl
# Timeout: 600 midi_sources/ecomp/2002/victoria05.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KotysV15.mid
# Timeout: 600 midi_sources/ecomp/2002/sun07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/AbdelmoulaJS10.mid
# Timeout: 600 midi_sources/ecomp/2002/dvorkine03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KotysV01.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/LeeS01.mid
# Timeout: 600 midi_sources/ecomp/2002/huang01.mxl
# Timeout: 600 midi_sources/ecomp/2002/yamaguchi01.mxl
# Timeout: 600 midi_sources/ecomp/2002/hireche03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/ChowK06.mid
# Timeout: 600 midi_sources/ecomp/2002/hireche04.mxl
# Timeout: 600 midi_sources/ecomp/2002/soloman02.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/MaslovV01.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/gp_bal4.mid
# Timeout: 600 midi_sources/ecomp/2002/sun04.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/HouY05.mid
# Timeout: 600 midi_sources/ecomp/2002/dossin02.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/MustakimovT17.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2002/mamriev03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/BianF03.mid
# Timeout: 600 midi_sources/ecomp/2002/mikhailoff02.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/lisztson.mid
# Timeout: 600 midi_sources/ecomp/2002/savitski03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KanM10.mid
# Timeout: 600 midi_sources/ecomp/2002/savitski04.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KotysV20.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/MustakimovT05.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/LeungM07.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/8/1812tcha.mid
# Timeout: 600 midi_sources/ecomp/2002/franceschetti01.mxl
# Timeout: 600 midi_sources/ecomp/2002/chan01.mxl
# Timeout: 600 midi_sources/ecomp/2002/savitski05.mxl
# Timeout: 600 midi_sources/ecomp/2002/lim05.mxl
# Timeout: 600 midi_sources/ecomp/2018/FaB09.mxl
# Timeout: 600 midi_sources/ecomp/2018/KimSY19.mxl
# Timeout: 600 midi_sources/ecomp/2018/LeeS06.mxl
# Timeout: 600 midi_sources/ecomp/2018/TanakaM05.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/023/yankdood.mid
# Timeout: 600 midi_sources/ecomp/2018/AndreevI02.mxl
# Timeout: 600 midi_sources/ecomp/2018/AndreevI08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KaszoS01.mid
# Timeout: 600 midi_sources/ecomp/2018/KanM13.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/TanakaM11.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/be-pc-01.mid
# Timeout: 600 midi_sources/ecomp/2018/KotysV10.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/GiacomelliN06.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/8/lont32.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/smetmol.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classic_piano/liz_donjuan_format0.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/8/donjuan.mid
# Timeout: 600 midi_sources/ecomp/2018/KotysV14.mxl
# Timeout: 600 midi_sources/ecomp/2018/KimSJ05.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/AbdelmoulaJS02.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/AndreevI14.mid
# Timeout: 600 midi_sources/ecomp/2018/MaslovV05.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/AbdelmoulaJS08.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/parsifal.mid
# Timeout: 600 midi_sources/ecomp/2018/KimSY09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/ee2132.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/8/rkeaster.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/beetwell.mid
# Timeout: 600 midi_sources/ecomp/2018/AndreevI07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/WongKJ18.mid
# Timeout: 600 midi_sources/ecomp/2018/HouY06.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/ecomp/2018/KaszoS08.mid
# Timeout: 600 midi_sources/ecomp/2018/WongKJ13.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/rachsona.mid
# Timeout: 600 midi_sources/ecomp/2018/KimSJ06.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/8/bru9_1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/b/bwv988.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/6/festklng.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/beet61a1.mid
# Timeout: 600 midi_sources/ecomp/2018/WongKJ09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/schm_16.mid
# Timeout: 600 midi_sources/ecomp/2018/KiselevaD12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/6/eroica-1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/hain_gs.mid
# Timeout: 600 midi_sources/ecomp/2018/MustakimovT12.mxl
# Timeout: 600 midi_sources/ecomp/2018/HouY07.mxl
# Timeout: 600 midi_sources/ecomp/2018/KaszoS12.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/023/wagtanov.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/tcsl2829.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/enerr1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/00crnval.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/schmn2-3.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/024/cnsym4p2.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/023/cnsym4p1.mid
# Timeout: 600 midi_sources/ecomp/2018/MaslovV15.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/j/moldau-n.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/br-ps-03.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/frakjuge.mid
# Timeout: 600 midi_sources/ecomp/2018/BianF07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/012/tod_men.mid
# Timeout: 600 midi_sources/ecomp/2018/KimSY01.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/023/lis_meph.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/romgiul.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/die_20me.mid
# Timeout: 600 midi_sources/ecomp/2018/KiselevaD07.mxl
# Timeout: 600 midi_sources/ecomp/2018/WongKJ02.mxl
# Timeout: 600 midi_sources/ecomp/2018/HouY03.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/5/viv_pic.mid
# Timeout: 600 midi_sources/ecomp/2018/GalantM08.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/listtanz.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/brcp1_1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/jbop35b1.mid
# Timeout: 600 midi_sources/ecomp/2018/KanM03.mxl
# Timeout: 600 midi_sources/ecomp/2018/ChowK09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/mensy3-1.mid
# Timeout: 600 midi_sources/ecomp/2018/ChowK01.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/012/rach33.mid
# Timeout: 600 midi_sources/ecomp/2018/MustakimovT11.mxl
# Timeout: 600 midi_sources/ecomp/2018/GiacomelliN11.mxl
# Timeout: 600 midi_sources/ecomp/2018/GalantM07.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/goldberg.mid
# Timeout: 600 midi_sources/ecomp/2018/MaslovV06.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/013/bt_sy3_1.mid
# Timeout: 600 midi_sources/ecomp/2018/KiselevaD01.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/7/liszttel.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/mthmop18.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/024/mahler61.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/013/besy91.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/012/scarbo.mid
# Timeout: 600 midi_sources/ecomp/2018/KimSY14.mxl
# Timeout: 600 midi_sources/ecomp/2018/BianF12.mxl
# Timeout: 600 midi_sources/ecomp/2018/AbdelmoulaJS09.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/todnverk.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/lespral.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/ritepti.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/8/bergsym.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/caprixo.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/0/anspgpol.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/011/lvbsym92.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/023/bach_in.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/021/rachson.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/brhms73a.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/014/brck8c.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/7/mthm26b.mid
# Timeout: 600 midi_sources/classical_archives/021/rubsonat.mxl
# Timeout: 600 midi_sources/classical_archives/021/aida_20.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/6/schsin3.mid
# musicxml.xmlToM21: WARNING: Line <dashes> stop without start
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/5/mazeppa.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/011/chabespa.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/7/norma.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/5/polliszt.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/031/tmntbare.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/frsymph1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/023/bach_inv.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/4/sch1-1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/024/beetho-1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/023/faustact.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/beet9mv4.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/b9-1-maa.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/beop53n2.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/004/rach31.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/032/carnanim.mid
# musicxml.xmlToM21: WARNING: Line <bracket> stop without start
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/5297185.mid
# Timeout: 600 midi_sources/classical_archives/4/rach3-23.mxl
# Timeout: 600 midi_sources/classical_archives/4/carnaval.mxl
# musicxml.xmlToM21: WARNING: Line <dashes> stop without start
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/besym6-3.mid
# musicxml.xmlToM21: WARNING: Line <bracket> stop without start
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/blanik.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/ch-et-10.mid
# Timeout: 600 midi_sources/classical_archives/023/tris1act.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/013/alassio3.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/be-pv20r.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/014/jsrap4gm.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/tch-4-1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/duksrcap.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/bsfanctr.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/beop53n1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/gmb5m4.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/kv334.mid
# Timeout: 600 midi_sources/classical_archives/023/act_5.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/bruck3-1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/rossemir.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/dberg.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/6/mahsy1-4.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/ssmph9-1.mid
# Timeout: 600 midi_sources/classical_archives/024/vorspi.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/lucipars.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/fc-op2.mid
# Timeout: 600 midi_sources/classical_archives/024/vorspie.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/organsym.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/031/1lachqn.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/rach2-3.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/wag_tann.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2881416.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/032/jb83_1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/franck5.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/7/frchas.mid
# Timeout: 600 midi_sources/classical_archives/6/mozhrn1.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/013/bsy94.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/rach3-1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/7/mthm26c.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/sona23.mid
# Timeout: 600 midi_sources/classical_archives/6/chopop28.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/sib2-34.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/ee1132.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/tchai1-1.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/4453696.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/schm_6.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/pits5e-4.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/tasso.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/str2_don.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/3/enigma.mid
# Timeout: 600 midi_sources/classical_archives/012/mozart_f.mxl
# Timeout: 600 midi_sources/classical_archives/012/gp_bs_3.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/ds1inf.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/ee1116.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2102531.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/9/brop24.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/bwv0205.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/189697.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/danteson.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/bwv988.mid
# Timeout: 600 midi_sources/classical_archives/011/wohl_1.mxl
# Timeout: 600 midi_sources/classical_archives/011/die_kuns.mxl
# Timeout: 600 midi_sources/classical_archives/011/hetderde.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/lvbsym94.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/031/los_prel.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2119261.mid
# Timeout: 600 midi_sources/classical_archives/5/hungaria.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/7/eevar32.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/alp-sea.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/b92.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2638111.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/7/eevar16.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2445146.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/srapcon2.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2370631.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/1/ssmph9-4.mid
# Timeout: 600 midi_sources/classical_archives/014/strralp.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/032/doniz1_4.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/2/lisztson.mid
# Timeout: 600 midi_sources/classical_archives/7/gp_past.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2430311.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/1984571.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/032/doniz1_2.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/2279591.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/1671046.mid
# Encoded: data/midi/v15/midi_sources/from_mxl/classical_archives/032/donizett.mid
# Timeout: 600 midi_sources/classical_archives/1/juivela.mxl
# Encoded: data/midi/v15/midi_sources/from_mxl/musescore/data/802731.mid
# Timeout: 600 midi_sources/musescore/data/1816046.mxl
# Timeout: 600 midi_sources/musescore/data/5427389.mxl
# Timeout: 600 midi_sources/musescore/data/2377826.mxl
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# converted = [(p['midi'], p['source']) for p in processed if isinstance(p.get('mxl'), str)]

# converted

# %%
from src.data_sources import arr2csv
arr2csv(processed, all_csv)
df = pd.read_csv(all_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,4,7,9,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ht_time_signature  ht_offset  \
# 0                4.0        0.0
# 1                3.0        0.0
# 2                4.0       -5.0
# 3                4.0       -5.0
# 4                4.0       -5.0
#
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                      parts  ht_bpm                title  \
# 0             intro,chorus   128.0  yu-gi-oh-theme-song
# 1             intro,chorus    85.0  yu-gi-oh-theme-song
# 2                   chorus    96.0               kiefer
# 3  verse,pre-chorus,chorus   152.0         senbonzakura
# 4  verse,pre-chorus,chorus   152.0         senbonzakura
#
#                       midi_title        artist  \
# 0                      yu-gi-oh3  wayne-sharpe
# 1                       yu-gi-oh  wayne-sharpe
# 2                         kiefer    what-a-day
# 3  senbonzakura - pre-Pre-Chorus    whiteflame
# 4                   Senbonzakura    whiteflame
#
#                                             song_url     genres      source  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 1  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 2  https://www.hooktheory.com/theorytab/view/what...       Jazz  hooktheory
# 3  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
# 4  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
#
#   ht_key                               md5  mxl  ht_mode
# 0      C  bf1f29e5ff84e3e93e37fb873bfb590e  NaN      1.0
# 1      C  055f80ad67f64edb14a85ca8fbfe8c29  NaN      1.0
# 2      D  197f96f5d181f6ce1e2c5ab04ac1ff87  NaN      6.0
# 3      D  9e7ce13a35f1314423a9a6d5a5287a4a  NaN      6.0
# 4      D  d5aaf79d0989222f1362f9f46c540a27  NaN      6.0

# %%
df.shape
# Out:
# (197182, 16)
