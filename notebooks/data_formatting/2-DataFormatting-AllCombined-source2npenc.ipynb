# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')
from src.encode_data import *
from src.midi_data import *
from src.data_sources import process_parallel, transform_csv_row
from src.midi_transform import *

# %%
from tqdm import tqdm

# %% [markdown]
# ## Standardize and reformat raw midi files before encoding to text
# - Transform key to C major
# - Remove unused instruments
# - Combine multiple tracks with the same instrument into a single part
# - Melody, Piano, String

# %% [markdown]
# ### Load midi data

# %%
version = 'v10'
data_path = Path('data/midi')
version_path = data_path/version

# %%
import pandas as pd

# %%
source_dir = 'midi_sources'
out_dir = 'midi_encode'
source_csv = version_path/'metadata'/f'{source_dir}.csv'
out_csv = version_path/out_dir/f'{out_dir}.csv'
out_csv.parent.mkdir(parents=True, exist_ok=True)
source_csv, out_csv
# Out:
# (PosixPath('data/midi/v10/metadata/midi_sources.csv'),
#  PosixPath('data/midi/v10/midi_encode/midi_encode.csv'))

# %%
num_comps = 2 # note, duration
cutoff = 4 # max instruments

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,2,4,5,10,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                      parts                title  \
# 0             intro,chorus  yu-gi-oh-theme-song
# 1             intro,chorus  yu-gi-oh-theme-song
# 2                   chorus               kiefer
# 3  verse,pre-chorus,chorus         senbonzakura
# 4  verse,pre-chorus,chorus         senbonzakura
#
#                       midi_title ht_key      source  \
# 0                      yu-gi-oh3      C  hooktheory
# 1                       yu-gi-oh      C  hooktheory
# 2                         kiefer      D  hooktheory
# 3  senbonzakura - pre-Pre-Chorus      D  hooktheory
# 4                   Senbonzakura      D  hooktheory
#
#                                 md5     genres  ht_time_signature  \
# 0  bf1f29e5ff84e3e93e37fb873bfb590e        NaN                4.0
# 1  055f80ad67f64edb14a85ca8fbfe8c29        NaN                3.0
# 2  197f96f5d181f6ce1e2c5ab04ac1ff87       Jazz                4.0
# 3  9e7ce13a35f1314423a9a6d5a5287a4a  J-Pop,Pop                4.0
# 4  d5aaf79d0989222f1362f9f46c540a27  J-Pop,Pop                4.0
#
#                                             song_url  ht_bpm  ht_offset  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...   128.0        0.0
# 1  https://www.hooktheory.com/theorytab/view/wayn...    85.0        0.0
# 2  https://www.hooktheory.com/theorytab/view/what...    96.0       -5.0
# 3  https://www.hooktheory.com/theorytab/view/whit...   152.0       -5.0
# 4  https://www.hooktheory.com/theorytab/view/whit...   152.0       -5.0
#
#          artist  ht_mode  mxl
# 0  wayne-sharpe      1.0  NaN
# 1  wayne-sharpe      1.0  NaN
# 2    what-a-day      6.0  NaN
# 3    whiteflame      6.0  NaN
# 4    whiteflame      6.0  NaN

# %%
all_records = df.to_dict(orient='records')

# %% [markdown]
# ### Via Data Sources

# %%
def process_all(func, arr, total=None, max_workers=None, timeout=None):
    "Process array in parallel"
    if total is None: total = len(arr)
    results = []
    with ProcessPoolExecutor(max_workers=max_workers) as ex:
        futures = [ex.submit(func,o) for i,o in enumerate(arr)]
        for f in progress_bar(concurrent.futures.as_completed(futures, timeout=timeout), total=total):
            res = f.result()
            if res is not None:
                results.append(res)
    return results

# %% [markdown]
# ### Need better midi formatting

# %%
music21.midi.MidiFile
# Out:
# music21.midi.MidiFile

# %%
def transform_func(metadata):
    result = metadata.copy()
    
    # Part 1. Compress tracks/instruments
    if isinstance(metadata.get('midi'), str):
        input_path = version_path/metadata['midi']
    else:
        input_path = version_path/metadata.get('mxl', None)
    extension = input_path.suffix.lower()
    if not input_path.exists(): 
        print('Input path does not exist:', input_path, metadata)
        return None
    print(input_path)
    
    # Get outfile and check if it exists
    out_file = Path(str(input_path).replace(f'/{source_dir}/', f'/{out_dir}/'))
    out_file = out_file.with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): 
        result['numpy'] = str(out_file.relative_to(version_path))
        return result
    
    if extension == '.mid':
        input_file = compress_midi_file(input_path, cutoff=cutoff) # remove non note tracks and standardize instruments
        if not input_file: return None
    elif extension in ['.mxl', '.xml']:
        input_file = input_path
    else:
        raise Exception('Error finding extension:', input_path, extension)
        
    # Part 2. Compress rests and long notes
    stream = file2stream(input_file) # 1.
    chordarr = stream2chordarr(stream, max_dur=128) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
    
    chord_short = compress_chordarr(chordarr)
    delta_trim = chordarr.shape[0] - chord_short.shape[0]
    if delta_trim > 100: print(f'Removed {delta_trim} rests from {input_path}')
    chordarr = chord_short
    
    # Part 3. Chord array to numpy
    seq = chordarr2seq(chordarr)
    if len(seq) < 32:
        print('Sequence too short:', len(seq), input_path)
        return None
    
    npenc = seq2npenc(seq, num_comps=num_comps)
    if (npenc[...,1] > 128+ENC_OFFSET).any(): 
        print('npenc exceeds max 128 duration:', input_path)
        return None
    
    if ((npenc[...,0] > ENC_OFFSET) & ((npenc[...,0] < 12+ENC_OFFSET) | (npenc[...,0] >= 127-12+ENC_OFFSET))).any(): 
        print('npenc out of note range 12 - 116:', input_path)
        return None
    
    
    np.save(out_file, npenc)
    
    result['numpy'] = str(out_file.relative_to(version_path))
    return result

# %%
import random

# %%
# sanity check
for r in random.sample(all_records, 500):
    transform_func(r)
# Out:
# data/midi/v10/midi_sources/130k_reddit/F/F/FINESTLIGHT.mid
# data/midi/v10/midi_sources/130k_reddit/Classical_Guitar_classicalguitarmidi.com_MIDIRip/Coste_Lecon_No27.mid
# data/midi/v10/midi_sources/130k_reddit/W/W/WITHHELP.MID
# data/midi/v10/midi_sources/hooktheory/pianoroll/j/junichi-masuda/trainer-battle---pokemon-diamond-and-pearl/chorus_key_original.mid
# data/midi/v10/midi_sources/130k_reddit/C/C/chpn_op7_2.mid
# data/midi/v10/midi_sources/lmd_clean/The Doors/Hello, I Love You, Won't You Tell Me Your Name?.mid
# data/midi/v10/midi_sources/lmd_clean/Dave Matthews Band/Satellite.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/t/the-tokens/the-lion-sleeps-tonight/pre-chorus-and-chorus_key_original.mid
# data/midi/v10/midi_sources/130k_reddit/Classical_mfiles.co.uk_MIDIRip/sans-day-carol-piano.mid
# data/midi/v10/midi_sources/lmd_clean/The Everly Brothers/Crying in the Rain.mid
# data/midi/v10/midi_sources/130k_reddit/S/S/Super Mario RPG - Battle Victory.mid
# data/midi/v10/midi_sources/130k_reddit/F/F/ffa-missionofmana.mid
# data/midi/v10/midi_sources/130k_reddit/E/E/Etude-in-D-Flat-Nr-3.mid
# Removed 256 rests from data/midi/v10/midi_sources/130k_reddit/E/E/Etude-in-D-Flat-Nr-3.mid
# data/midi/v10/midi_sources/midiworld/named_midi/Rick_Astley_-_Never_Gonna_Give_You_Up.mid
# data/midi/v10/midi_sources/midiworld/named_midi/Video_Game_Themes_-_Castlevania_4.mid
# data/midi/v10/midi_sources/130k_reddit/Arabic and Tribal Rhythms/GUWAZI_01.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/y/yasunori-mitsuda/sealed-door/intro-and-verse_key_original.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/l/ladi6/like-water/chorus_key_original.mid
# data/midi/v10/midi_sources/130k_reddit/AMERICANA_FOLK_www.pdmusic.org_MIDIRip/work/hcw63d.mid
# data/midi/v10/midi_sources/freemidi/genre-pop/Taylor Swift - Begin Again.mid
# data/midi/v10/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Classical Piano Midis/Varios - Título desconocido/a_h/d_2pre.mid
# data/midi/v10/midi_sources/lmd_clean/Genesis/I Know What I Like (In Your Wardrobe).mid
# Removed 144 rests from data/midi/v10/midi_sources/lmd_clean/Genesis/I Know What I Like (In Your Wardrobe).mid
# data/midi/v10/midi_sources/freemidi/genre-pop/Tracy Chapman - Give Me One Reason.mid
# data/midi/v10/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Vivaldi/Concertos op3 01-12 ''L'estro Armonico''/Concerto op3 n07 for 4 Violins RV567 2mov.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/z/zun/emotional-skyscraper---cosmic-mind/chorus-lead-out_key_original.mid
# data/midi/v10/midi_sources/130k_reddit/Metal_Rock_wolverine-metalmidi.wen.ru_MIDIRip/Metallica/nothing_else_matters.mid
# data/midi/v10/midi_sources/130k_reddit/D/D/dixie_traditional.mid
# data/midi/v10/midi_sources/130k_reddit/A/A/anny.mid
# data/midi/v10/midi_sources/130k_reddit/S/S/SpencerHillftMimoza_-_LetOutdaFreakMaisonDragenRemix__defhaus_20130130022624.mid
# data/midi/v10/midi_sources/freemidi/genre-pop/James Taylor - Shower The People.mid
# data/midi/v10/midi_sources/lmd_clean/Pharao/I Show You Secrets.mid
# npenc out of note range 12 - 116: data/midi/v10/midi_sources/lmd_clean/Pharao/I Show You Secrets.mid
# data/midi/v10/midi_sources/130k_reddit/M/M/midnight03.mid
# data/midi/v10/midi_sources/130k_reddit/T/T/The_Bug.mid
# data/midi/v10/midi_sources/130k_reddit/M/M/MENORCH.MID
# data/midi/v10/midi_sources/130k_reddit/Classical_mfiles.co.uk_MIDIRip/legend-of-the-argonauts.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/e/edith-piaf/non-je-ne-regrette-rien/verse_key_original.mid
# data/midi/v10/midi_sources/ecomp/2009/Huang03.mxl
# Removed 7088 rests from data/midi/v10/midi_sources/ecomp/2009/Huang03.mxl
# Sequence too short: 17 data/midi/v10/midi_sources/ecomp/2009/Huang03.mxl
# data/midi/v10/midi_sources/130k_reddit/F/F/funeral05.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/h/horimitsu-kazumichi/come-here-daitarn-3/pre-chorus_key_original.mid
# data/midi/v10/midi_sources/wikifonia/Benny Andersson and Bjorn Ulvaeus, Benny Andersson, Bjorn Ulvaeus - Nina, pretty ballerina.mxl
# Removed 752 rests from data/midi/v10/midi_sources/wikifonia/Benny Andersson and Bjorn Ulvaeus, Benny Andersson, Bjorn Ulvaeus - Nina, pretty ballerina.mxl
# Sequence too short: 17 data/midi/v10/midi_sources/wikifonia/Benny Andersson and Bjorn Ulvaeus, Benny Andersson, Bjorn Ulvaeus - Nina, pretty ballerina.mxl
# data/midi/v10/midi_sources/130k_reddit/L/L/little_dreamer.mid
# data/midi/v10/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Scarlatti/v5/K525.MID
# data/midi/v10/midi_sources/130k_reddit/Guitar_midkar.com_MIDIRip/poprock/run_baby_run_gr.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/s/spice-girls/wannabe/intro_key_original.mid
# data/midi/v10/midi_sources/130k_reddit/A/A/angl.mid
# data/midi/v10/midi_sources/130k_reddit/M/M/mendel_op30_2.mid
# data/midi/v10/midi_sources/130k_reddit/N/N/Nikke Bellamamella - Move Those Feet.mid
# data/midi/v10/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-becoming/bridge_key_original.mid
# data/midi/v10/midi_sources/ecomp/2008/Ye03.mxl
# Removed 784 rests from data/midi/v10/midi_sources/ecomp/2008/Ye03.mxl
# Sequence too short: 16 data/midi/v10/midi_sources/ecomp/2008/Ye03.mxl
# data/midi/v10/midi_sources/130k_reddit/Classical Archives - The Greats (MIDI)/Classical Piano Midis/Varios - Título desconocido/i_o/op27_2_1.mid
# data/midi/v10/midi_sources/130k_reddit/Classical_Guitar_classicalguitarmidi.com_MIDIRip/Coste_Recreation_Guitariste_Op51_No12_Andante Menuet.mid
# data/midi/v10/midi_sources/130k_reddit/C/C/corchs04.mid
# data/midi/v10/midi_sources/130k_reddit/B/B/bwv805.mid
# data/midi/v10/midi_sources/lmd_clean/Chris Rea/Little Blonde Plaits.mid
# data/midi/v10/midi_sources/130k_reddit/A/A/Amor-Amor.mid
# data/midi/v10/midi_sources/freemidi/genre-pop/Sting - Beneath A Desert Moon.mid
# data/midi/v10/midi_sources/lmd_clean/R.E.M./Nightswimming.mid
# ---------------------------------------------------------------------------
# MidiException                             Traceback (most recent call last)
# <ipython-input-26-08c9907bef2a> in <module>
#       1 # sanity check
#       2 for r in random.sample(all_records, 500):
# ----> 3     transform_func(r)
#       4
#
# <ipython-input-24-76751303e5c0> in transform_func(metadata)
#      22
#      23     if extension == '.mid':
# ---> 24         input_file = compress_midi_file(input_path, cutoff=cutoff) # remove non note tracks and standardize instruments
#      25         if not input_file: return None
#      26     elif extension in ['.mxl', '.xml']:
#
# ~/midi_generator/src/midi_transform.py in compress_midi_file(fp, cutoff, unsup_types)
#      39
#      40 def compress_midi_file(fp, cutoff=6, unsup_types=set([Track.UNDEF, Track.PERC])):
# ---> 41     music_file = file2mf(fp)
#      42     supported_tracks = []
#      43     noteworthy_first = sorted(music_file.tracks, key=lambda x: len(x.events), reverse=True)
#
# ~/midi_generator/src/midi_data.py in file2mf(fp)
#      84     mf = music21.midi.MidiFile()
#      85     mf.open(fp)
# ---> 86     mf.read()
#      87     mf.close()
#      88     return mf
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py in read(self)
#    1275         Read and parse MIDI data stored in a file.
#    1276         '''
# -> 1277         self.readstr(self.file.read())
#    1278
#    1279     def readstr(self, midiStr):
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py in readstr(self, midiStr)
#    1286         '''
#    1287         if not midiStr[:4] == b'MThd':
# -> 1288             raise MidiException('badly formated midi bytes, got: %s' % midiStr[:20])
#    1289
#    1290         # we step through the str src, chopping off characters as we go
#
# MidiException: badly formated midi bytes, got: b'RIFF\xde[\x00\x00RMIDdata\xd2[\x00\x00'

# %%
# %debug
# Out:
# > /home/ubuntu/anaconda3/envs/midi/lib/python3.7/pathlib.py(633)_parse_args()
#     631                 parts += a._parts
#     632             else:
# --> 633                 a = os.fspath(a)
#     634                 if isinstance(a, str):
#     635                     # Force-cast str subclasses to str (issue #21127)
#
# ipdb> up
# > /home/ubuntu/anaconda3/envs/midi/lib/python3.7/pathlib.py(679)_make_child()
#     677
#     678     def _make_child(self, args):
# --> 679         drv, root, parts = self._parse_args(args)
#     680         drv, root, parts = self._flavour.join_parsed_parts(
#     681             self._drv, self._root, self._parts, drv, root, parts)
#
# ipdb> up
# > /home/ubuntu/anaconda3/envs/midi/lib/python3.7/pathlib.py(892)__truediv__()
#     890
#     891     def __truediv__(self, key):
# --> 892         return self._make_child((key,))
#     893
#     894     def __rtruediv__(self, key):
#
# ipdb> key
# nan
# ipdb> up
# > <ipython-input-20-4eb3d01f015e>(5)transform_func()
#       3
#       4     # Part 1. Compress tracks/instruments
# ----> 5     input_path = version_path/metadata.get('midi', metadata.get('mxl', None))
#       6     extension = input_path.suffix.lower()
#       7     if not input_path.exists():
#
# ipdb> input_path
# *** NameError: name 'input_path' is not defined
# ipdb> metadata
# {'midi': nan, 'section': nan, 'parts': nan, 'title': '8 format0', 'midi_title': nan, 'ht_key': nan, 'source': 'classical_piano', 'md5': '1d226c78f901ad23a21a89199ed2d067', 'genres': 'classical', 'ht_time_signature': nan, 'song_url': nan, 'ht_bpm': nan, 'ht_offset': nan, 'artist': 'scn16', 'ht_mode': nan, 'mxl': 'midi_sources/classic_piano/scn16_8_format0.mxl'}
# ipdb> metadata.get('midi')
# nan
# ipdb> type(metadata['midi'])
# <class 'float'>
# ipdb> quit

# %%
# %debug
# Out:
# > /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/converter/__init__.py(1123)parse()
#    1121         return parseData(value, number=number, **keywords)
#    1122     # a midi string, must come before os.path.exists test
# -> 1123     elif not isinstance(value, bytes) and valueStr.startswith('MThd'):
#    1124         return parseData(value, number=number, format=m21Format, **keywords)
#    1125     elif not isinstance(value, bytes) and os.path.exists(valueStr):
#
# ipdb> value
# ipdb> up
# > /home/ubuntu/midi_generator/src/midi_data.py(79)file2stream()
#      77 def file2stream(fp, use_parser=True):
#      78     if isinstance(fp, music21.midi.MidiFile): return music21.midi.translate.midiFileToStream(fp)
# ---> 79     if use_parser: return music21.converter.parse(fp)
#      80     mf = file2mf(fp)
#      81     return music21.midi.translate.midiFileToStream(mf)
#
# ipdb> fp
# ipdb> up
# > <ipython-input-16-dd471839f0f0>(28)transform_func()
#      26
#      27     # Part 2. Compress rests and long notes
# ---> 28     stream = file2stream(input_file) # 1.
#      29     chordarr = stream2chordarr(stream, max_dur=128) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
#      30
#
# ipdb> input_file
# ipdb> input_path
# PosixPath('data/midi/v10/midi_sources/130k_reddit/K/K/KINKADE.Dreams are ten a penny.MID')
# ipdb> quit

# %%
### AS TOD: Fix 'info channel is not channel 0' error

# %%
idx2out = process_parallel(parallel_func, result, total=df.shape[0])

# %%
tdf = pd.DataFrame(data={out_dir: list(idx2out.values())}, index=list(idx2out.keys()))

# %%
merged_df = df.join(tdf)

# %%
tdf.shape, df.shape, merged_df.shape
# Out:
# ((166644, 1), (185846, 22), (185846, 23))

# %%
merged_df.to_csv(out_csv, index=False); merged_df.head()
# Out:
#    inferred_offset                                           song_url  \
# 0              0.0  https://www.hooktheory.com/theorytab/view/wayn...
# 1              0.0  https://www.hooktheory.com/theorytab/view/wayn...
# 2              5.0  https://www.hooktheory.com/theorytab/view/what...
# 3              NaN  https://www.hooktheory.com/theorytab/view/weez...
# 4              0.0  https://www.hooktheory.com/theorytab/view/weez...
#
#    instruments  ht_mode              midi_title                title  \
# 0        Piano      1.0                yu-gi-oh  yu-gi-oh-theme-song
# 1  Piano,Piano      1.0               yu-gi-oh3  yu-gi-oh-theme-song
# 2  Piano,Piano      1.0                  kiefer               kiefer
# 3          NaN      1.0             My New Song        beverly-hills
# 4  Piano,Piano      1.0  Weezer - Fall Together       fall-together-
#
#      seconds                                               midi inferred_key  \
# 0  25.411765  midi_sources/hooktheory/pianoroll/w/wayne-shar...      C major
# 1  15.000000  midi_sources/hooktheory/pianoroll/w/wayne-shar...      C major
# 2  10.000000  midi_sources/hooktheory/pianoroll/w/what-a-day...      E minor
# 3        NaN  midi_sources/hooktheory/pianoroll/w/weezer/bev...          NaN
# 4  10.322581  midi_sources/hooktheory/pianoroll/w/weezer/fal...      A minor
#
#   quarter_length                        ...                         ht_bpm  \
# 0           36.0                        ...                           85.0
# 1           32.0                        ...                          128.0
# 2           16.0                        ...                           96.0
# 3            NaN                        ...                          128.0
# 4           16.0                        ...                           93.0
#
#          artist  ht_key  ht_time_signature    bpm          section  \
# 0  wayne-sharpe       C                3.0   85.0            intro
# 1  wayne-sharpe       C                4.0  128.0           chorus
# 2    what-a-day       C                4.0   96.0           chorus
# 3        weezer       C                4.0    NaN  intro-and-verse
# 4        weezer       C                4.0   93.0           chorus
#
#              parts  genres  mxl  \
# 0     intro,chorus     NaN  NaN
# 1     intro,chorus     NaN  NaN
# 2           chorus    Jazz  NaN
# 3  intro-and-verse     NaN  NaN
# 4           chorus    Rock  NaN
#
#                                       midi_transform
# 0  midi_transform/hooktheory/pianoroll/w/wayne-sh...
# 1  midi_transform/hooktheory/pianoroll/w/wayne-sh...
# 2  midi_transform/hooktheory/pianoroll/w/what-a-d...
# 3                                                NaN
# 4  midi_transform/hooktheory/pianoroll/w/weezer/f...
#
# [5 rows x 23 columns]
