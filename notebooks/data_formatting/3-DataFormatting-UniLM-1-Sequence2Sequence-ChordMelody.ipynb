# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')
from src.encode_data import *
from src.midi_data import *
from src.data_sources import process_all, arr2csv
from src.midi_transform import *
from src.fastai_data import *
from src.unilm import S2SFileProcessor, S2SPreloader

# %%
import traceback
import time

# %% [markdown]
# ## Standardize and reformat raw midi files before encoding to text
# - Transform key to C major
# - Remove unused instruments
# - Combine multiple tracks with the same instrument into a single part
# - Melody, Piano, String

# %% [markdown]
# ### Load midi data

# %%
version = 'v16'
data_path = Path('data/midi')
version_path = data_path/version

# %%
import pandas as pd

# %%
# out_dir = 'midi_encode'
# duet_only = False
sf_path = f'sf{SAMPLE_FREQ}'
out_dir = Path(f'{sf_path}/s2s_encode')
duet_only = True

# %%
source_dir = 'midi_sources'
source_csv = version_path/'metadata'/f'{source_dir}.csv'
out_csv = version_path/out_dir/f'{out_dir.name}.csv'
out_csv.parent.mkdir(parents=True, exist_ok=True)
source_csv, out_csv
# Out:
# (PosixPath('data/midi/v16/metadata/midi_sources.csv'),
#  PosixPath('data/midi/v16/sf4/s2s_encode/s2s_encode.csv'))

# %%
# num_comps = 2 # note, duration
cutoff = 5 # max instruments
min_variation = 3 # minimum number of different midi notes played
# max_dur = 128

# %% [markdown]
# ### Encoding midi to numpy

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,4,7,9,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ht_time_signature  ht_offset  \
# 0                4.0        0.0
# 1                3.0        0.0
# 2                4.0       -5.0
# 3                4.0       -5.0
# 4                4.0       -5.0
#
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                      parts  ht_bpm                title  \
# 0             intro,chorus   128.0  yu-gi-oh-theme-song
# 1             intro,chorus    85.0  yu-gi-oh-theme-song
# 2                   chorus    96.0               kiefer
# 3  verse,pre-chorus,chorus   152.0         senbonzakura
# 4  verse,pre-chorus,chorus   152.0         senbonzakura
#
#                       midi_title        artist  \
# 0                      yu-gi-oh3  wayne-sharpe
# 1                       yu-gi-oh  wayne-sharpe
# 2                         kiefer    what-a-day
# 3  senbonzakura - pre-Pre-Chorus    whiteflame
# 4                   Senbonzakura    whiteflame
#
#                                             song_url     genres      source  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 1  https://www.hooktheory.com/theorytab/view/wayn...        NaN  hooktheory
# 2  https://www.hooktheory.com/theorytab/view/what...       Jazz  hooktheory
# 3  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
# 4  https://www.hooktheory.com/theorytab/view/whit...  J-Pop,Pop  hooktheory
#
#   ht_key                               md5  mxl  ht_mode
# 0      C  bf1f29e5ff84e3e93e37fb873bfb590e  NaN      1.0
# 1      C  055f80ad67f64edb14a85ca8fbfe8c29  NaN      1.0
# 2      D  197f96f5d181f6ce1e2c5ab04ac1ff87  NaN      6.0
# 3      D  9e7ce13a35f1314423a9a6d5a5287a4a  NaN      6.0
# 4      D  d5aaf79d0989222f1362f9f46c540a27  NaN      6.0

# %%
all_records = df.to_dict(orient='records'); len(all_records)
# Out:
# 197182

# %%
def part_enc(chordarr, part, input_path):
    partarr = chordarr[:,part:part+1,:]
    # Part 3. Chord array to numpy
    npenc = chordarr2npenc(partarr)
    
    if npenc[-1, -1] > MAX_NOTE_DUR: 
        print('Part is shorter than song. Trimming end:', input_path)
        npenc[-1, -1] = MAX_NOTE_DUR
    if not is_valid_npenc(npenc, min_notes=8, input_path=input_path): return None
    
    return npenc

# %%
def process_metadata(metadata):
    result = metadata.copy()
    
    # Part 1. Compress tracks/instruments
    if not isinstance(metadata.get('midi'), str): return None
    
    input_path = version_path/metadata['midi']
    extension = input_path.suffix.lower()
    if not input_path.exists(): 
        print('Input path does not exist:', input_path, metadata)
        return result
    
    # Get outfile and check if it exists
    out_file = Path(str(input_path).replace(f'/{source_dir}/', f'/{out_dir}/'))
    out_file = out_file.with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): 
        result['numpy'] = str(out_file.relative_to(version_path))
        return result
    
    npenc = transform_midi(input_path)
    if npenc is None: return result
    np.save(out_file, npenc)
    result['numpy'] = str(out_file.relative_to(version_path))
    return result

# %%
def transform_midi(midi_file):
    input_path = midi_file
    
    try: 
        if num_piano_tracks(input_path) not in [1, 2]: return None
        input_file = compress_midi_file(input_path, min_variation=min_variation, cutoff=cutoff) # remove non note tracks and standardize instruments
        if not input_file: return None
    except Exception as e:
        if 'badly form' in str(e): return None # ignore badly formatted midi errors
        if 'out of range' in str(e): return None # ignore badly formatted midi errors
        print('Error parsing midi', input_path, e)
        return None
        
    # Part 2. Compress rests and long notes
    stream = file2stream(input_file) # 1.
    try:
        chordarr = stream2chordarr(stream) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
    except Exception as e:
        print('Could not encode to chordarr:', input_path, e)
#         print(traceback.format_exc())
        return None
    
    chord_trim = trim_chordarr_rests(chordarr)
    chord_short = shorten_chordarr_rests(chord_trim)
    delta_trim = chord_trim.shape[0] - chord_short.shape[0]
#     if delta_trim > 300: 
#         print(f'Removed {delta_trim} rests from {input_path}. Skipping song')
#         return None
    chordarr = chord_short
    
    _,num_parts,_ = chordarr.shape
    if num_parts != 2: return None
    
    parts = [part_enc(chordarr, i, input_path) for i in range(num_parts)]
    for p in parts: 
        if p is None: return None
    
    return np.array(parts)

# %%
# transform_midi(piano_file)
midi_mxl_file = version_path/'midi_sources/from_mxl/musescore/data/49143.mid'
input_file = midi_mxl_file
stream = file2stream(input_file) # 1.
chordarr = stream2chordarr(stream)

# %%
chordarr.shape
# Out:
# (1021, 2, 128)

# %%
transform_midi(midi_mxl_file).shape
# Out:
# (2,)

# %%
def try_process_metadata(metadata):
    try:
        return process_metadata(metadata)
    except Exception:
#         print(traceback.format_exc())
        return None

# %%
# # sanity check
import random
for r in random.sample(all_records, 10):
    process_metadata(r)

# %%
def timeout_func(data, seconds):
    print("Timeout:", seconds, data.get('midi'))

# %%
processed = process_all(try_process_metadata, all_records, timeout=300, timeout_func=timeout_func)
# Out:
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll
key_original.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/analogik/menu-theme---battleblock-theater/verse_key_original.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/analogik/menu-theme---battleblock-theater/verse_key_original.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/augustines/cruel-city/chorus_key_original.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/alice-in-chains/acid-bubble/pre-chorus-and-chorus_key_original.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/animusic/aqua-harp/chorus_key_original.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/animusic/aqua-harp/chorus_key_original.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/armin-van-buuren-sharon/in-and-out-of-love/instrumental_key_original.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/armin-van-buuren-sharon/in-and-out-of-love/instrumental_key_original.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/alabama-shakes/hold-on/intro_key_original.mid
# npenc exceeds max 161 duration: 224 data/midi/v16/midi_sources/hooktheory/pianoroll/a/animal-collective/for-reverend-green/intro-and-verse_key_original.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/freemidi/genre-dance-eletric/Madonna - I Deserve It.mid
# npenc exceeds max 161 duration: 258 data/midi/v16/midi_sources/freemidi/genre-dance-eletric/Chemical Brothers - Loops Of Furry.mid
# npenc exceeds max 161 duration: 260 data/midi/v16/midi_sources/freemidi/genre-dance-eletric/Scooter - Last Minute.mid
# npenc exceeds max 161 duration: 264 data/midi/v16/midi_sources/freemidi/genre-dance-eletric/Kylie Minogue - Spinning Around.mid
# npenc exceeds max 161 duration: 690 data/midi/v16/midi_sources/freemidi/genre-dance-eletric/Scooter - How Much Is The Fish.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/freemidi/genre-dance-eletric/Radiohead - How I Made My Millions.mid
# npenc exceeds max 161 duration: 424 data/midi/v16/midi_sources/freemidi/genre-pop/Kinks - Fancy.mid
# npenc exceeds max 161 duration: 1100 data/midi/v16/midi_sources/freemidi/genre-pop/Toni Braxton - Another Sad Love Song.mid
# npenc exceeds max 161 duration: 1432 data/midi/v16/midi_sources/freemidi/genre-pop/Pat Benatar - Benatar Medley.mid
# npenc exceeds max 161 duration: 236 data/midi/v16/midi_sources/freemidi/genre-pop/OneRepublic - Love Runs Out.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/freemidi/genre-pop/Delta Goodrem - Lost Without You.mid
# npenc exceeds max 161 duration: 219 data/midi/v16/midi_sources/freemidi/genre-pop/Delta Goodrem - Lost Without You.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/freemidi/genre-pop/Romantics - What I Like About You.mid
# npenc exceeds max 161 duration: 388 data/midi/v16/midi_sources/freemidi/genre-pop/Romantics - What I Like About You.mid
# npenc exceeds max 161 duration: 238 data/midi/v16/midi_sources/freemidi/genre-pop/R.E.M. - Ignoreland.mid
# npenc exceeds max 161 duration: 280 data/midi/v16/midi_sources/freemidi/genre-pop/Sade - Siempre Hay Esperanza.mid
# npenc exceeds max 161 duration: 272 data/midi/v16/midi_sources/freemidi/genre-pop/Sade - Siempre Hay Esperanza.mid
# npenc exceeds max 161 duration: 324 data/midi/v16/midi_sources/freemidi/genre-pop/Ace of Base - Beautiful Life.mid
# npenc exceeds max 161 duration: 329 data/midi/v16/midi_sources/freemidi/genre-pop/98 Degrees - The Hardest Thing.mid
# npenc exceeds max 161 duration: 832 data/midi/v16/midi_sources/freemidi/genre-pop/98 Degrees - The Hardest Thing.mid
# npenc exceeds max 161 duration: 416 data/midi/v16/midi_sources/freemidi/genre-pop/R.E.M. - Orange Crush.mid
# Error parsing midi data/midi/v16/midi_sources/freemidi/genre-pop/PSY - gangnam style KILLYURSLEF.mid ord() expected string of length 1, but int found
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/freemidi/genre-pop/Gin Blossoms - Follow You Down.mid
# npenc exceeds max 161 duration: 1234 data/midi/v16/midi_sources/freemidi/genre-pop/Gin Blossoms - Follow You Down.mid
# npenc exceeds max 161 duration: 193 data/midi/v16/midi_sources/freemidi/genre-pop/Jay-Z - Run This Town.mid
# npenc exceeds max 161 duration: 325 data/midi/v16/midi_sources/freemidi/genre-pop/Geoff Moore - Said And Done.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Berckmans_de_Oliveira_-_Berckmans_de_Oliveira_-_Tarde_da_noite.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Bad_English_-_When_I_See_You_Smile.mid
# npenc exceeds max 161 duration: 176 data/midi/v16/midi_sources/midiworld/named_midi/Bad_English_-_When_I_See_You_Smile.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Led_Zeppelin_-_Bonzo's_Montreux.mid
# npenc exceeds max 161 duration: 456 data/midi/v16/midi_sources/midiworld/named_midi/Led_Zeppelin_-_Bonzo's_Montreux.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Animenz_-_This_game_by_Animenz_in_C_piano.mid
# npenc exceeds max 161 duration: 2562 data/midi/v16/midi_sources/midiworld/named_midi/Animenz_-_This_game_by_Animenz_in_C_piano.mid
# Error parsing midi data/midi/v16/midi_sources/midiworld/named_midi/Nirvana_-_Drain_You.mid cannot handle ticks per frame: 77
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Animenz_-_This_game_by_Animez_in_C_piano.mid
# npenc exceeds max 161 duration: 2562 data/midi/v16/midi_sources/midiworld/named_midi/Animenz_-_This_game_by_Animez_in_C_piano.mid
# npenc exceeds max 161 duration: 257 data/midi/v16/midi_sources/midiworld/named_midi/Notorious_BIG_-_Notorious_Thugs.mid
# npenc exceeds max 161 duration: 256 data/midi/v16/midi_sources/midiworld/named_midi/Notorious_BIG_-_Notorious_Thugs.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Babyface_-_When_Can_I_See_You_Again.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Animenz_-_This_Game_OP_Piano_In_C_.mid
# npenc exceeds max 161 duration: 2562 data/midi/v16/midi_sources/midiworld/named_midi/Animenz_-_This_Game_OP_Piano_In_C_.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Tavares_-_Heaven_Must_Be_Missing.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Tavares_-_Heaven_Must_Be_Missing.mid
# npenc exceeds max 161 duration: 184 data/midi/v16/midi_sources/midiworld/named_midi/Tavares_-_Heaven_Must_Be_Missing.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Genesis_-_Misunderstanding.mid
# npenc exceeds max 161 duration: 336 data/midi/v16/midi_sources/midiworld/named_midi/Genesis_-_Misunderstanding.mid
# npenc exceeds max 161 duration: 176 data/midi/v16/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Play_3_Times.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/midiworld/named_midi/Emerson_Lake_and_Palmer_-_Karn_Evil.mid
# npenc exceeds max 161 duration: 3697 data/midi/v16/midi_sources/midiworld/named_midi/Emerson_Lake_and_Palmer_-_Karn_Evil.mid
# npenc exceeds max 161 duration: 450 data/midi/v16/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Crystal_Gym_Play_3_Times.mid
# npenc exceeds max 161 duration: 176 data/midi/v16/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Piano_Cover.mid
# npenc exceeds max 161 duration: 224 data/midi/v16/midi_sources/midiworld/named_midi/John_Mellencamp_-_Lonely_Ol'_Night.mid
# npenc exceeds max 161 duration: 212 data/midi/v16/midi_sources/from_mxl/ecomp/2017/SirajA01.mid
# npenc exceeds max 161 duration: 2562 data/midi/v16/midi_sources/midiworld/named_midi/Animenz_-_This_game_OP_Animenz_In_C.mid
# npenc exceeds max 161 duration: 205 data/midi/v16/midi_sources/from_mxl/ecomp/2017/GuoE02.mid
# npenc exceeds max 161 duration: 223 data/midi/v16/midi_sources/from_mxl/ecomp/2017/GuoE02.mid
# npenc exceeds max 161 duration: 208 data/midi/v16/midi_sources/from_mxl/ecomp/2017/KabuliL01.mid
# npenc exceeds max 161 duration: 304 data/midi/v16/midi_sources/from_mxl/ecomp/2017/WangH03.mid
# npenc exceeds max 161 duration: 237 data/midi/v16/midi_sources/from_mxl/ecomp/2017/WangH03.mid
# npenc exceeds max 161 duration: 164 data/midi/v16/midi_sources/from_mxl/ecomp/2017/YuP03.mid
# npenc exceeds max 161 duration: 180 data/midi/v16/midi_sources/from_mxl/ecomp/2017/TuanS02.mid
# npenc exceeds max 161 duration: 192 data/midi/v16/midi_sources/from_mxl/ecomp/2017/TuanS02.mid
# npenc exceeds max 161 duration: 200 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Song01.mid
# npenc exceeds max 161 duration: 248 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Song01.mid
# npenc exceeds max 161 duration: 166 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Woo03.mid
# npenc exceeds max 161 duration: 167 data/midi/v16/midi_sources/from_mxl/ecomp/2017/GuoE03.mid
# npenc exceeds max 161 duration: 244 data/midi/v16/midi_sources/from_mxl/ecomp/2017/CaoJ04.mid
# npenc exceeds max 161 duration: 172 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Lisiecki07.mid
# npenc exceeds max 161 duration: 260 data/midi/v16/midi_sources/from_mxl/ecomp/2008/ZhangH06.mid
# npenc exceeds max 161 duration: 532 data/midi/v16/midi_sources/from_mxl/ecomp/2008/ZhangH06.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/from_mxl/ecomp/2017/LiA07.mid
# npenc exceeds max 161 duration: 244 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Nedayvoda01.mid
# npenc exceeds max 161 duration: 450 data/midi/v16/midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Gym_Piano_Cover.mid
# npenc exceeds max 161 duration: 238 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Ladid03.mid
# npenc exceeds max 161 duration: 170 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Duepree05.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/from_mxl/ecomp/2008/Huang14.mid
# npenc exceeds max 161 duration: 231 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Nikiforov03.mid
# npenc exceeds max 161 duration: 184 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Kochetkova02.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/from_mxl/ecomp/2008/Tuncali03.mid
# npenc exceeds max 161 duration: 194 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Lin16.mid
# npenc exceeds max 161 duration: 181 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Sun03.mid
# npenc exceeds max 161 duration: 242 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Lisiecki15.mid
# npenc exceeds max 161 duration: 204 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Huang08.mid
# npenc exceeds max 161 duration: 280 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Nikiforov11.mid
# npenc exceeds max 161 duration: 181 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Lin15.mid
# npenc exceeds max 161 duration: 264 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Tuncali01.mid
# npenc exceeds max 161 duration: 327 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Tuncali01.mid
# npenc exceeds max 161 duration: 169 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Katyukova01.mid
# npenc exceeds max 161 duration: 200 data/midi/v16/midi_sources/from_mxl/ecomp/2008/ZhangH03.mid
# npenc exceeds max 161 duration: 165 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Arciglione11.mid
# npenc exceeds max 161 duration: 167 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Shelest01.mid
# npenc exceeds max 161 duration: 199 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Izzard03.mid
# npenc exceeds max 161 duration: 164 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Bach01.mid
# npenc exceeds max 161 duration: 244 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Han01.mid
# npenc exceeds max 161 duration: 182 data/midi/v16/midi_sources/from_mxl/ecomp/2008/Duepree01.mid
# npenc exceeds max 161 duration: 175 data/midi/v16/midi_sources/from_mxl/ecomp/2006/ChenC02.mid
# npenc exceeds max 161 duration: 188 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Cai03.mid
# npenc exceeds max 161 duration: 195 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Yarden06.mid
# Timeout: 300 midi_sources/freemidi/genre-dance-eletric/Enigma - Variations.mid
# npenc exceeds max 161 duration: 201 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Shen06.mid
# npenc exceeds max 161 duration: 296 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Yarden01.mid
# npenc exceeds max 161 duration: 327 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Yarden01.mid
# npenc exceeds max 161 duration: 298 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Yarden10.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/from_mxl/ecomp/2006/Hao01.mid
# npenc exceeds max 161 duration: 167 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Mordvinov08.mid
# npenc exceeds max 161 duration: 300 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Mordvinov02.mid
# npenc exceeds max 161 duration: 179 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Schneider03.mid
# npenc exceeds max 161 duration: 404 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Goldberg03.mid
# npenc exceeds max 161 duration: 192 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Day03.mid
# npenc exceeds max 161 duration: 166 data/midi/v16/midi_sources/from_mxl/ecomp/2006/WongDoe05.mid
# npenc exceeds max 161 duration: 236 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Shybayeva04.mid
# npenc exceeds max 161 duration: 170 data/midi/v16/midi_sources/from_mxl/ecomp/2006/DeTurck07.mid
# npenc exceeds max 161 duration: 240 data/midi/v16/midi_sources/from_mxl/ecomp/2004/SOLOM02.mid
# npenc exceeds max 161 duration: 204 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Shybayeva03.mid
# npenc exceeds max 161 duration: 175 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Huangci02.mid
# npenc exceeds max 161 duration: 187 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Cai01.mid
# npenc exceeds max 161 duration: 274 data/midi/v16/midi_sources/from_mxl/ecomp/2004/HONG01.mid
# npenc exceeds max 161 duration: 292 data/midi/v16/midi_sources/from_mxl/ecomp/2004/HONG01.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/from_mxl/ecomp/2004/RAN02.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/from_mxl/ecomp/2004/RAN02.mid
# npenc exceeds max 161 duration: 198 data/midi/v16/midi_sources/from_mxl/ecomp/2004/LUO03.mid
# npenc exceeds max 161 duration: 212 data/midi/v16/midi_sources/from_mxl/ecomp/2004/RAN03.mid
# npenc exceeds max 161 duration: 298 data/midi/v16/midi_sources/from_mxl/ecomp/2004/YOO09.mid
# npenc exceeds max 161 duration: 200 data/midi/v16/midi_sources/from_mxl/ecomp/2006/Larionova04.mid
# npenc exceeds max 161 duration: 195 data/midi/v16/midi_sources/from_mxl/ecomp/2004/BLINOV02.mid
# npenc exceeds max 161 duration: 195 data/midi/v16/midi_sources/from_mxl/ecomp/2004/ZHOU03.mid
# npenc exceeds max 161 duration: 172 data/midi/v16/midi_sources/from_mxl/ecomp/2004/KARYAG01.mid
# npenc exceeds max 161 duration: 174 data/midi/v16/midi_sources/from_mxl/ecomp/2009/ChenL04.mid
# npenc exceeds max 161 duration: 164 data/midi/v16/midi_sources/from_mxl/ecomp/2004/LUO02.mid
# npenc exceeds max 161 duration: 168 data/midi/v16/midi_sources/from_mxl/ecomp/2004/RAN08.mid
# npenc exceeds max 161 duration: 262 data/midi/v16/midi_sources/from_mxl/ecomp/2009/Yeletskiy04.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_50_Times.mid
# npenc exceeds max 161 duration: 205 data/midi/v16/midi_sources/from_mxl/ecomp/2009/CaiC03.mid
# npenc exceeds max 161 duration: 162 data/midi/v16/midi_sources/from_mxl/ecomp/2004/YOO06.mid
# npenc exceeds max 161 duration: 277 data/midi/v16/midi_sources/from_mxl/ecomp/2004/YOO06.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/from_mxl/ecomp/2009/Sekino12.mid
# npenc exceeds max 161 duration: 220 data/midi/v16/midi_sources/from_mxl/ecomp/2004/KIM_W03.mid
# npenc exceeds max 161 duration: 411 data/midi/v16/midi_sources/from_mxl/ecomp/2004/UENO03.mid
# npenc exceeds max 161 duration: 250 data/midi/v16/midi_sources/from_mxl/ecomp/2004/UENO03.mid
# npenc exceeds max 161 duration: 224 data/midi/v16/midi_sources/from_mxl/ecomp/2009/WongDoe02.mid
# npenc exceeds max 161 duration: 176 data/midi/v16/midi_sources/from_mxl/ecomp/2009/Gintov01.mid
# Timeout: 300 midi_sources/midiworld/named_midi/OFMG_-_.mid
# ...
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/e/elvis-presley/you-were-always-on-my-mind/verse_key_cmajor.mid
# Sequence too short: 7 data/midi/v16/midi_sources/hooktheory/pianoroll/e/elvis-presley/you-were-always-on-my-mind/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/niall-horan/this-town/pre-chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/niall-horan/this-town/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/natiruts/presente-de-um-beija-flor/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/nicholas-webber/metro/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-downward-spiral/intro-and-verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-downward-spiral/intro-and-verse_key_cmajor.mid
# npenc exceeds max 161 duration: 192 data/midi/v16/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-lovers/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/nirvana/all-apologies/verse_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/n/nirvana/all-apologies/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/im-looking-forward-to-joining-you-finally/verse-and-pre-chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/nintendo/c-r-o-w-n-e-d/bridge_key_cmajor.mid
# npenc exceeds max 161 duration: 192 data/midi/v16/midi_sources/hooktheory/pianoroll/n/nintendo/kirby-air-ride---machine-passage/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/n/nintendo/kirby-air-ride---machine-passage/verse_key_cmajor.mid
# npenc exceeds max 161 duration: 362 data/midi/v16/midi_sources/hooktheory/pianoroll/i/inxs/never-tear-us-apart/verse-and-pre-chorus_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/i/ikke-huftgold/dicke-titten-kartoffelsalat/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/i/iq/leap-of-faith/intro-and-verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/h/homestuck/skies-of-skaia/chorus-lead-out_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/h/homestuck/skies-of-skaia/chorus_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/h/homestuck/carbon-nadsat---cuestick-genius/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/h/homestuck/unite-synchronization/chorus_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/h/homestuck/unite-synchronization/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/h/hertzdevil/extends-levant/instrumental_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/pet-shop-boys/you-were-always-on-my-mind/verse_key_cmajor.mid
# Sequence too short: 7 data/midi/v16/midi_sources/hooktheory/pianoroll/p/pet-shop-boys/you-were-always-on-my-mind/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/pendulum/salt-in-the-wounds/verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/p/pendulum/salt-in-the-wounds/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/paul-mccartney/sing-the-changes/intro_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/p/paul-mccartney/sing-the-changes/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/pendulum/salt-in-the-wounds/instrumental_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/p/pendulum/salt-in-the-wounds/instrumental_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/p/perry-como/catch-a-falling-star/intro-and-verse_key_cmajor.mid
# npenc exceeds max 161 duration: 288 data/midi/v16/midi_sources/hooktheory/pianoroll/p/penguin-cafe-orchestra/perpetuum-mobile/instrumental_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/p/paris-hilton/my-bff/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/peter-paul-and-mary/i-dig-rock-and-roll-music/verse_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/p/peter-paul-and-mary/i-dig-rock-and-roll-music/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/pink-floyd/stay/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/pink-floyd/in-the-flesh/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/pink-floyd/eclipse/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/p/pearl-jam/indifference/verse_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/t/tina-turner/river-deep---mountain-high/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-flaming-lips/psychiatric-exploration-of-the-fetus-with-needles/intro_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-flaming-lips/psychiatric-exploration-of-the-fetus-with-needles/intro_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-temptations/my-girl/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/this-town-needs-guns/havoc-in-the-forum/intro-and-verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/t/this-town-needs-guns/havoc-in-the-forum/intro-and-verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/t/toby-fox/his-theme/verse_key_cmajor.mid
# npenc exceeds max 161 duration: 192 data/midi/v16/midi_sources/hooktheory/pianoroll/t/tool/schism/chorus_key_cmajor.mid
# Sequence too short: 6 data/midi/v16/midi_sources/hooktheory/pianoroll/t/tupac/changes/outro-2_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-shins/caring-is-creepy/chorus-lead-out_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-stone-roses/waterfall/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-velvet-underground/femme-fatale/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/taylor-swift/look-what-you-made-me-do/chorus_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/t/taylor-swift/look-what-you-made-me-do/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/taylor-swift/out-of-the-woods/bridge_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-smiths/please-please-please-let-me-get-what-i-want/verse_key_cmajor.mid
# npenc exceeds max 161 duration: 316 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-script/you-wont-feel-a-thing/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/traditional/frere-jacque/chorus_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/t/traditional/frere-jacque/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/tyler-the-creator/ifhy/intro_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/t/tyler-the-creator/ifhy/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-sing-team/satisfied-in-you/verse_key_cmajor.mid
# Sequence too short: 6 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-dispatch/how-deep-the-fathers-love-for-us/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-crystal-method/starting-over/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-blue-hearts/linda-linda/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/tricot/pool/chorus_key_cmajor.mid
# npenc exceeds max 161 duration: 192 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-supremes/the-happening/verse_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-beatles/if-i-needed-someone/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-beatles/ticket-to-ride/outro_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-beatles/ticket-to-ride/outro_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-beatles/you-cant-do-that/intro_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/t/the-lorax/let-it-grow/intro_key_cmajor.mid
# Sequence too short: 6 data/midi/v16/midi_sources/hooktheory/pianoroll/k/koji-kondo/delfino-plaza/intro_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/k/king-gizzard-and-the-lizard-wizard/im-in-your-mind/intro_key_cmajor.mid
# npenc exceeds max 161 duration: 177 data/midi/v16/midi_sources/hooktheory/pianoroll/k/kanye-west/ultralight-beam/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/k/king-gizzard-and-the-lizard-wizard/robot-stop/solo_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/k/kyle-richards/terminal-velocity---ymir-theme/intro_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/k/kyle-richards/terminal-velocity---ymir-theme/intro_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/k/kshmr/kolkata/chorus_key_cmajor.mid
# Sequence too short: 7 data/midi/v16/midi_sources/hooktheory/pianoroll/k/kendrick-lamar/alright/pre-chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/r/radiohead/motion-picture-soundtrack/chorus-lead-out_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/r/radiohead/morning-bell/bridge_key_cmajor.mid
# npenc exceeds max 161 duration: 218 data/midi/v16/midi_sources/hooktheory/pianoroll/m/mitch-murder/megamagic-theme/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/r/rustie/hover-traps/bridge_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/m83/wait/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/my-bloody-valentine/come-in-alone/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/manabu-namiki/trauma-center-under-the-knife-2---gentle-breeze/pre-chorus-and-chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/my-bloody-valentine/to-here-knows-when/intro_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/m/my-bloody-valentine/to-here-knows-when/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/mental-as-anything/the-nips-are-getting-bigger/intro-and-verse_key_cmajor.mid
# Sequence too short: 5 data/midi/v16/midi_sources/hooktheory/pianoroll/m/madeon/imperium/solo_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/miley-cyrus/malibu/verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/m/meghan-trainor/no/pre-chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/melodys-echo-chamber/i-follow-you/chorus_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/m/masashi-hamauzu/battle-results/pre-chorus-and-chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/myon-feat-alissa-feudo/omen-in-the-rain---seven-lions-remix/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/muse/hate-this-and-ill-love-you/outro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/mashina-vremeni/poka-gorit-svecha/intro-and-verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/m/maya/jindalae-koht/intro-and-verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/amy-winehouse/you-know-im-no-good/verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/a-lovely-war/autumn-leaves-us-blue/intro_key_cmajor.mid
# npenc exceeds max 161 duration: 192 data/midi/v16/midi_sources/hooktheory/pianoroll/a/american-football/never-meant/intro_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/analogik/menu-theme---battleblock-theater/verse_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/analogik/menu-theme---battleblock-theater/verse_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/axis-of-awesome/four-chord-songs/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/augustines/cruel-city/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/armin-van-buuren-sharon/in-and-out-of-love/instrumental_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/armin-van-buuren-sharon/in-and-out-of-love/instrumental_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/animusic/aqua-harp/chorus_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/animusic/aqua-harp/chorus_key_cmajor.mid
# Part is shorter than song. Trimming end: data/midi/v16/midi_sources/hooktheory/pianoroll/a/alice-in-chains/acid-bubble/pre-chorus-and-chorus_key_cmajor.mid
# Sequence too short: 4 data/midi/v16/midi_sources/hooktheory/pianoroll/a/alabama-shakes/hold-on/intro_key_cmajor.mid
# npenc exceeds max 161 duration: 224 data/midi/v16/midi_sources/hooktheory/pianoroll/a/animal-collective/for-reverend-green/intro-and-verse_key_cmajor.mid
# Timeout: 300 midi_sources/130k_reddit/S/S/spfc.mid
# Timeout: 300 midi_sources/130k_reddit/T/T/TILLOTSON.11 Piano solo.mid

# %%
arr2csv(processed, out_csv); len(processed)
# Out:
# 196518

# %%
df = pd.read_csv(out_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,2,8,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          artist     section ht_key  \
# 0  wayne-sharpe      chorus      C
# 1  wayne-sharpe       intro      C
# 2    what-a-day      chorus      D
# 3    whiteflame  pre-chorus      D
# 4    whiteflame       verse      D
#
#                                                numpy  ht_offset     genres  \
# 0  sf4/s2s_encode/hooktheory/pianoroll/w/wayne-sh...        0.0        NaN
# 1                                                NaN        0.0        NaN
# 2  sf4/s2s_encode/hooktheory/pianoroll/w/what-a-d...       -5.0       Jazz
# 3  sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...       -5.0  J-Pop,Pop
# 4  sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...       -5.0  J-Pop,Pop
#
#                  title                                               midi  \
# 0  yu-gi-oh-theme-song  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 1  yu-gi-oh-theme-song  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 2               kiefer  midi_sources/hooktheory/pianoroll/w/what-a-day...
# 3         senbonzakura  midi_sources/hooktheory/pianoroll/w/whiteflame...
# 4         senbonzakura  midi_sources/hooktheory/pianoroll/w/whiteflame...
#
#                       midi_title      source                    parts  mxl  \
# 0                      yu-gi-oh3  hooktheory             intro,chorus  NaN
# 1                       yu-gi-oh  hooktheory             intro,chorus  NaN
# 2                         kiefer  hooktheory                   chorus  NaN
# 3  senbonzakura - pre-Pre-Chorus  hooktheory  verse,pre-chorus,chorus  NaN
# 4                   Senbonzakura  hooktheory  verse,pre-chorus,chorus  NaN
#
#                                             song_url  ht_time_signature  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...                4.0
# 1  https://www.hooktheory.com/theorytab/view/wayn...                3.0
# 2  https://www.hooktheory.com/theorytab/view/what...                4.0
# 3  https://www.hooktheory.com/theorytab/view/whit...                4.0
# 4  https://www.hooktheory.com/theorytab/view/whit...                4.0
#
#    ht_mode  ht_bpm                               md5
# 0      1.0   128.0  bf1f29e5ff84e3e93e37fb873bfb590e
# 1      1.0    85.0  055f80ad67f64edb14a85ca8fbfe8c29
# 2      6.0    96.0  197f96f5d181f6ce1e2c5ab04ac1ff87
# 3      6.0   152.0  9e7ce13a35f1314423a9a6d5a5287a4a
# 4      6.0   152.0  d5aaf79d0989222f1362f9f46c540a27

# %%
len([f for f in df.numpy.values if isinstance(f, str)])
# Out:
# 53314

# %%
from collections import Counter

# %%
df[df.numpy.notnull()]
# Out:
#                                 artist                section ht_key  \
# 0                         wayne-sharpe                 chorus      C
# 2                           what-a-day                 chorus      D
# 3                           whiteflame             pre-chorus      D
# 4                           whiteflame                  verse      D
# 5                           whiteflame                 chorus      D
# 6                                 wham                  verse     Db
# 7                                 wham                 chorus     Db
# 8                                 wham                  intro     Db
# 9                                 wham                 chorus      C
# 11                    wg-snuffy-walden           instrumental      G
# 14                       willie-nelson                 chorus      E
# 16                       walter-murphy                 chorus      F
# 17                       walter-murphy                 chorus     Bb
# 18                       walter-murphy        intro-and-verse      C
# 19                       walter-murphy                 bridge      C
# 20                       woodentoaster                 bridge     F#
# 21                       woodentoaster                  intro     F#
# 22                       woodentoaster                  verse     G#
# 23                       woodentoaster           instrumental      D
# 24                       woodentoaster                 chorus      D
# 25                            warsongs        intro-and-verse      D
# 26                            warsongs                 chorus      D
# 27                   waka-flocka-flame                 chorus     C#
# 28                               weebl                 chorus      E
# 29                               weebl                  verse      B
# 31                               weebl                 bridge     F#
# 32                               weebl                 chorus     F#
# 33                               weebl                  verse      A
# 34                               weebl                  outro      A
# 35                    wolfgang-gartner                  intro      B
# ...                                ...                    ...    ...
# 196485                        a-g-cook                 chorus      C
# 196486                        a-g-cook  pre-chorus-and-chorus      C
# 196488                      ark-patrol                 chorus      C
# 196489  astronaut-ft--harry-brooks-jnr                 chorus      C
# 196490                above-and-beyond                  verse      C
# 196491                above-and-beyond                 chorus      C
# 196493                above-and-beyond                 chorus      C
# 196494                above-and-beyond                  verse      C
# 196495                above-and-beyond                  intro      C
# 196496                above-and-beyond                 chorus      C
# 196497                above-and-beyond             pre-chorus      C
# 196499                above-and-beyond                 chorus      C
# 196500            alstroemeria-records                 chorus      C
# 196501            alstroemeria-records                  verse      C
# 196502            alstroemeria-records                 bridge      C
# 196503            alstroemeria-records                  intro      C
# 196504               alanis-morissette                 chorus      C
# 196505               alanis-morissette                 chorus      C
# 196506               alanis-morissette                 chorus      C
# 196507               alanis-morissette                 chorus      C
# 196508               alanis-morissette                  verse      C
# 196509               alanis-morissette                 chorus      C
# 196510               alanis-morissette                 chorus      C
# 196511               alanis-morissette                  verse      C
# 196512               alanis-morissette                 chorus      C
# 196513                     anne-murray                 chorus      C
# 196514                     anne-murray                  verse      C
# 196515                           apink                 chorus      C
# 196516                           apink                 chorus      C
# 196517                          archie                 chorus      C
#
#                                                     numpy  ht_offset  \
# 0       sf4/s2s_encode/hooktheory/pianoroll/w/wayne-sh...        0.0
# 2       sf4/s2s_encode/hooktheory/pianoroll/w/what-a-d...       -5.0
# 3       sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...       -5.0
# 4       sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...       -5.0
# 5       sf4/s2s_encode/hooktheory/pianoroll/w/whitefla...       -5.0
# 6       sf4/s2s_encode/hooktheory/pianoroll/w/wham/las...       -1.0
# 7       sf4/s2s_encode/hooktheory/pianoroll/w/wham/las...       -1.0
# 8       sf4/s2s_encode/hooktheory/pianoroll/w/wham/las...       -1.0
# 9       sf4/s2s_encode/hooktheory/pianoroll/w/wham/fre...        0.0
# 11      sf4/s2s_encode/hooktheory/pianoroll/w/wg-snuff...        5.0
# 14      sf4/s2s_encode/hooktheory/pianoroll/w/willie-n...       -4.0
# 16      sf4/s2s_encode/hooktheory/pianoroll/w/walter-m...       -5.0
# 17      sf4/s2s_encode/hooktheory/pianoroll/w/walter-m...        2.0
# 196510  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...        0.0
# 196511  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...        0.0
# 196512  sf4/s2s_encode/hooktheory/pianoroll/a/alanis-m...        0.0
# 196513  sf4/s2s_encode/hooktheory/pianoroll/a/anne-mur...        0.0
# 196514  sf4/s2s_encode/hooktheory/pianoroll/a/anne-mur...        0.0
# 196515  sf4/s2s_encode/hooktheory/pianoroll/a/apink/on...        0.0
# 196516  sf4/s2s_encode/hooktheory/pianoroll/a/apink/pr...        0.0
# 196517  sf4/s2s_encode/hooktheory/pianoroll/a/archie/f...        0.0
#
#                                     genres                           title  \
# 0                                      NaN             yu-gi-oh-theme-song
# 2                                     Jazz                          kiefer
# 3                                J-Pop,Pop                    senbonzakura
# 4                                J-Pop,Pop                    senbonzakura
# 5                                J-Pop,Pop                    senbonzakura
# 6                                  Holiday                  last-christmas
# 7                                  Holiday                  last-christmas
# 8                                  Holiday                  last-christmas
# 9                                      NaN                         freedom
# 11                                     NaN                 west-wing-suite
# 14                                     NaN                 blue-eyes-cryin
# 16                         Jazz,Soundtrack         family-guy---theme-song
# 17                              Soundtrack       american-dad---theme-song
# 18                              Soundtrack                the-freaking-fcc
# 19                              Soundtrack                the-freaking-fcc
# 20                              Electronic                 rainbow-factory
# 21                              Electronic                 rainbow-factory
# 22                                     NaN               beyond-her-garden
# 23                 Alt-Country,Hip-Hop/Rap                 nightmare-night
# 24                 Alt-Country,Hip-Hop/Rap                 nightmare-night
# 25                                     NaN                  piercing-light
# 26                                     NaN                  piercing-light
# 27                             Hip-Hop/Rap                        no-hands
# 28                                     NaN                    fat-labrador
# 29                                     NaN                         donkeys
# 31                                     NaN                   amazing-horse
# 32                                     NaN                   amazing-horse
# 33                                     NaN                            owls
# 34                                     NaN                            owls
# 35                                     NaN                      undertaker
# ...                                    ...                             ...
# 196485               Pop,Singer-Songwriter                       superstar
# 196486               Pop,Singer-Songwriter                       superstar
# 196488                          Electronic                         igniter
# 196489                          Electronic                       champions
# 196490                                 NaN                sun-in-your-eyes
# 196491                          Electronic                     anjunabeach
# 196493                          Electronic     good-for-me---ambient-mix--
# 196494                          Electronic     good-for-me---ambient-mix--
# 196495                          Electronic     good-for-me---ambient-mix--
# 196496                          Electronic                          always
# 196497                                 NaN                    sun-and-moon
# 196499                                 NaN  tightrope-feat-marty-longstaff
# 196500                               J-Pop           lovelight---bad-apple
# 196501                               J-Pop           lovelight---bad-apple
# 196502                               J-Pop           lovelight---bad-apple
# 196503                          Video Game                       bad-apple
# 196504  Alternative,Rock,Singer-Songwriter               hand-in-my-pocket
# 196505                            Pop,Rock                          ironic
# 196506                Alternative,Pop,Rock                       you-learn
# 196507                         Alternative                       uninvited
# 196508                         Alternative                       uninvited
# 196509  Alternative,Rock,Singer-Songwriter                       thank-you
# 196510                                 NaN                  head-over-feet
# 196511                                 NaN                  head-over-feet
# 196512                    Alternative,Rock                 you-oughta-know
# 196513                                Folk                     dannys-song
# 196514                                Folk                     dannys-song
# 196505  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196506  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196507  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196508  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196509  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196510  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196511  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196512  midi_sources/hooktheory/pianoroll/a/alanis-mor...
# 196513  midi_sources/hooktheory/pianoroll/a/anne-murra...
# 196514  midi_sources/hooktheory/pianoroll/a/anne-murra...
# 196515  midi_sources/hooktheory/pianoroll/a/apink/only...
# 196516  midi_sources/hooktheory/pianoroll/a/apink/prom...
# 196517  midi_sources/hooktheory/pianoroll/a/archie/fam...
#
#                                          midi_title        source  \
# 0                                         yu-gi-oh3    hooktheory
# 2                                            kiefer    hooktheory
# 3                     senbonzakura - pre-Pre-Chorus    hooktheory
# 4                                      Senbonzakura    hooktheory
# 5                                      Senbonzakura    hooktheory
# 6                              Last Christmas Verse    hooktheory
# 7                             Last Christmas Chorus    hooktheory
# 8                              Last Christmas Intro    hooktheory
# 9                                    Freedom Chorus    hooktheory
# 11                                           snuffy    hooktheory
# 14                                  Blue Eyes Cryin    hooktheory
# 16                          Family Guy - Theme Song    hooktheory
# 17                        American Dad - Theme Song    hooktheory
# 18                                 The Freaking FCC    hooktheory
# 19                               Freakin FCC Bridge    hooktheory
# 20                                  Rainbow Factory    hooktheory
# 21                                  Rainbow Factory    hooktheory
# 22                                Beyond Her Garden    hooktheory
# 23                                  Nightmare Night    hooktheory
# 24                                  Nightmare Night    hooktheory
# 25                                   Piercing Light    hooktheory
# 26                                 Piercing Light 2    hooktheory
# 27                                         No Hands    hooktheory
# 28                                     Fat Labrador    hooktheory
# 29                                          Donkeys    hooktheory
# 31                           Amazing Horse - Bridge    hooktheory
# 32                                    Amazing Horse    hooktheory
# 33                                    Owls - Chorus    hooktheory
# 34                                     Owls - Outro    hooktheory
# 35                                       undertaker    hooktheory
# ...                                             ...           ...
# 196485                                    Superstar  hooktheory_c
# 196486                AG cook superstar better bmaj  hooktheory_c
# 196488                                      Igniter  hooktheory_c
# 196489                                    Champions  hooktheory_c
# 196490            above and beyond sun in your eyes  hooktheory_c
# 196491                                  Anjunabeach  hooktheory_c
# 196493                                  New Project  hooktheory_c
# 196494                  Good For Me - Ambient Mix -  hooktheory_c
# 196495         Above & Beyond - Good For Me (INTRO)  hooktheory_c
# 196496             Above and Beyond - Always Chorus  hooktheory_c
# 196497  above and beyond sun and moon prePre-Chorus  hooktheory_c
# 196499                      above and beyond thingy  hooktheory_c
# 196500                        Lovelight - Bad Apple  hooktheory_c
# 196501                        Lovelight - Bad Apple  hooktheory_c
# 196502                  Love Light Bad Apple Bridge  hooktheory_c
# 196503                                    Bad Apple  hooktheory_c
# 196504                                 handinpocket  hooktheory_c
# 196505                                  New Project  hooktheory_c
# 196506                                     youlearn  hooktheory_c
# 196507                                    Uninvited  hooktheory_c
# 196508                                    Uninvited  hooktheory_c
# 196509                               thankyoualanis  hooktheory_c
# 196510                               Head Over Feet  hooktheory_c
# 196511                            headoverfeetverse  hooktheory_c
# 196512                              You Oughta Know  hooktheory_c
# 196513                               Danny's Song B  hooktheory_c
# 196514                               Danny's Song A  hooktheory_c
# 196515                                     Only One  hooktheory_c
# 196516                                           pu  hooktheory_c
# 196517                                       Famous  hooktheory_c
#
#                                           parts  mxl  \
# 0                                  intro,chorus  NaN
# 2                                        chorus  NaN
# 3                       verse,pre-chorus,chorus  NaN
# 4                       verse,pre-chorus,chorus  NaN
# 5                       verse,pre-chorus,chorus  NaN
# 6                            intro,verse,chorus  NaN
# 7                            intro,verse,chorus  NaN
# 8                            intro,verse,chorus  NaN
# 9                                        chorus  NaN
# 11                                 instrumental  NaN
# 14                                       chorus  NaN
# 16                                       chorus  NaN
# 17                                       chorus  NaN
# 18                       intro-and-verse,bridge  NaN
# 19                       intro-and-verse,bridge  NaN
# 20                                 intro,bridge  NaN
# 21                                 intro,bridge  NaN
# 22                                        verse  NaN
# 23                          chorus,instrumental  NaN
# 24                          chorus,instrumental  NaN
# 25                       intro-and-verse,chorus  NaN
# 26                       intro-and-verse,chorus  NaN
# 27                                       chorus  NaN
# 28                                       chorus  NaN
# 29                                  intro,verse  NaN
# 31                                chorus,bridge  NaN
# 32                                chorus,bridge  NaN
# 33                                  verse,outro  NaN
# 34                                  verse,outro  NaN
# 35                                        intro  NaN
# ...                                         ...  ...
# 196485  pre-chorus,pre-chorus-and-chorus,chorus  NaN
# 196486  pre-chorus,pre-chorus-and-chorus,chorus  NaN
# 196488                                   chorus  NaN
# 196489                                   chorus  NaN
# 196490                                    verse  NaN
# 196491                                   chorus  NaN
# 196493                       intro,verse,chorus  NaN
# 196494                       intro,verse,chorus  NaN
# 196495                       intro,verse,chorus  NaN
# 196496                                   chorus  NaN
# 196497                               pre-chorus  NaN
# 196499                                   chorus  NaN
# 196500                      verse,chorus,bridge  NaN
# 196501                      verse,chorus,bridge  NaN
# 196502                      verse,chorus,bridge  NaN
# 196503                                    intro  NaN
# 196504                                   chorus  NaN
# 196505                                   chorus  NaN
# 196506                                   chorus  NaN
# 196507                             verse,chorus  NaN
# 196508                             verse,chorus  NaN
# 196509                                   chorus  NaN
# 196510                             verse,chorus  NaN
# 196511                             verse,chorus  NaN
# 196512                                   chorus  NaN
# 196513                             verse,chorus  NaN
# 196514                             verse,chorus  NaN
# 196515                                   chorus  NaN
# 196516                                   chorus  NaN
# 196517                                   chorus  NaN
#
#                                                  song_url  ht_time_signature  \
# 0       https://www.hooktheory.com/theorytab/view/wayn...                4.0
# 2       https://www.hooktheory.com/theorytab/view/what...                4.0
# 3       https://www.hooktheory.com/theorytab/view/whit...                4.0
# 4       https://www.hooktheory.com/theorytab/view/whit...                4.0
# 5       https://www.hooktheory.com/theorytab/view/whit...                4.0
# 6       https://www.hooktheory.com/theorytab/view/wham...                4.0
# 7       https://www.hooktheory.com/theorytab/view/wham...                4.0
# 8       https://www.hooktheory.com/theorytab/view/wham...                4.0
# 196499      1.0    64.0  95303e966c4e0c2f40c4ed1147fc5c21
# 196500      1.0   138.0  806589868ad2833c60a1028a9b98d728
# 196501      1.0   138.0  4a21d392218716772bfc5c0529f33fa5
# 196502      1.0   138.0  a8c214961de4d9b7c8832738a056b174
# 196503      1.0   149.0  dc934ad4926fe855af720a51d3f27add
# 196504      1.0    92.0  0c0b8dee20d40c4ef3cbc60cefca65bf
# 196505      1.0    86.0  369373d75ebc0a0afde1e561af9fe4b6
# 196506      1.0    84.0  f9b7ea35a536655b820cc667f541d3c9
# 196507      1.0    62.0  f5393682a85b7d15297b18ef464ac3ba
# 196508      1.0    64.0  2bbc847e640c011af4872019491303dd
# 196509      1.0    92.0  35635e0df8ae7258753456ead487d66b
# 196510      1.0    85.0  806d194ba4c2f93829b8bec319fdc81b
# 196511      1.0    80.0  e8b89860b8dda437f3fb869c696a004e
# 196512      1.0   104.0  917f12f996be13cdb5c16d7da04a97e7
# 196513      1.0    72.0  ed12ace7be191bf4b63d11b8bd361f12
# 196514      1.0    74.0  de27bb229d9b2a983a8f0feb05369857
# 196515      1.0   102.0  5c717d3f4cdf6d80943fa73cab91d242
# 196516      1.0    70.0  49e4fef90cc080d43618180d4a32d0ff
# 196517      1.0   128.0  67a12c729c20a3bc49e22e1da46d472e
#
# [53314 rows x 17 columns]

# %%
Counter(df[df.numpy.notnull()].source.values)
# Out:
# Counter({'hooktheory': 17761,
#          'freemidi': 51,
#          'midiworld': 66,
#          'ecomp': 2357,
#          'cprato': 124,
#          'classical_piano': 319,
#          'classical_archives': 2400,
#          'musescore': 6911,
#          'wikifonia': 33,
#          'lmd': 128,
#          'reddit': 5273,
#          'hooktheory_c': 17891})

# %%
len(df[df.numpy.notnull()].source.values)
# Out:
# 53314

# %%
Counter(df[df.numpy.notnull()].source.values)
# Out:
# Counter({'hooktheory': 17761,
#          'freemidi': 51,
#          'midiworld': 66,
#          'ecomp': 2357,
#          'cprato': 124,
#          'classical_piano': 319,
#          'classical_archives': 2400,
#          'musescore': 6911,
#          'wikifonia': 33,
#          'lmd': 128,
#          'reddit': 5273,
#          'hooktheory_c': 17891})

# %%
len(df[df.numpy.notnull()].source.values)
# Out:
# 53314

# %%
Counter(df.source.values)
# Out:
# Counter({'hooktheory': 19882,
#          'freemidi': 5166,
#          'midiworld': 4107,
#          'ecomp': 2507,
#          'cprato': 312,
#          'classical_piano': 329,
#          'classical_archives': 14641,
#          'musescore': 10928,
#          'wikifonia': 6346,
#          'lmd': 13565,
#          'reddit': 98659,
#          'hooktheory_c': 20076})

# %% [markdown]
# ## Convert to hooktheory databunch

# %%
def get_files(csv):
    files = csv['numpy']
    flist = [Path(version_path/f) for f in files.values if isinstance(f, str)]
    flist = [f for f in flist if f.exists()]
    return flist

# %%
def create_databunch(files, cache_name, batch_size=32, load_cached=False):
    if load_cached and (out_path/f'{cache_name}/train_ids.npy').exists():
        data = MusicDataBunch.load(out_path, bs=batch_size, cache_name=cache_name)
    else:
        ps = [S2SFileProcessor()]
        data = (MusicItemList(items=files, path=out_path, processor=ps)
                .split_by_rand_pct(0.01, seed=6)
                .label_const(label_cls=LMLabelList))
#         data.x._bunch = MusicDataBunch
        data = data.databunch(bs=batch_size, preloader_cls=S2SPreloader)
        data.save(cache_name)
    return data

# %%
out_path = version_path/out_dir

# %%
csv = df

# %%
hook_csv = csv.loc[csv.source.isin(['hooktheory'])]
hook_files = get_files(hook_csv); len(hook_files)
hook_data = create_databunch(hook_files, cache_name='tmp/hook')

# %%
hook_csv = csv.loc[csv.source.isin(['hooktheory_c'])]
hook_files = get_files(hook_csv); len(hook_files)
hook_data = create_databunch(hook_files, cache_name='tmp/hook_c')

# %%
lq_csv = csv.loc[csv.source.isin(['reddit', 'classical_piano', 'ecomp', 'midiworld', 'freemidi', 'lmd', 'cprato', 'wikifonia', 'classical_archives'])]
lq_files = get_files(lq_csv); len(lq_files)
lq_data = create_databunch(lq_files, cache_name='tmp/lq')

# %%
hq_csv = csv.loc[csv.source.isin(['hooktheory', 'musescore'])]
hq_files = get_files(hq_csv); len(hq_files)
hq_data = create_databunch(hq_files, cache_name='tmp/hq')

# %%
len(hook_data.train_dl.dl.dataset)
# Out:
# 17264

# %%
all_files = get_files(csv); len(all_files)
all_data = create_databunch(all_files, cache_name='tmp/all')

# %%
import random
sample_data = create_databunch(random.sample(all_files, 1000), cache_name='tmp/sample')

# %% [markdown]
# ## Load data

# %%
single_tfm = partial(to_single_stream, vocab=vocab)
load_data =  MusicDataBunch.load(path=out_path, cache_name='tmp/hook_c', preloader_cls=S2SPreloader, train_tfms=[single_tfm])
# Out:
# You can deactivate this warning by passing `no_check=True`.
# /home/ubuntu/fastai/fastai/basic_data.py:259: UserWarning: There seems to be something wrong with your dataset, for example, in the first batch can't access any element of self.train_ds.
# Tried: 0,1,2,3,4...
#   warn(warn_msg)

# %%
load_data =  MusicDataBunch.load(path=out_path, cache_name='tmp/hook_c', preloader_cls=S2SPreloader)

# %%
load_data.one_batch()
# Out:
# (tensor([[  6, 622,  88,  ..., 143,   8, 143],
#          [  5, 622,  55,  ..., 161,  51, 161],
#          [  5, 622,  65,  ..., 149,  61, 149],
#          ...,
#          [  5, 622,  66,  ..., 185,  75, 185],
#          [  5, 622,  64,  ..., 173,  61, 173],
#          [  5, 622,  63,  ..., 185,  60, 185]]),
#  tensor([[  3,   5, 622,  ..., 167,  78, 155],
#          [  3,   6, 622,  ..., 143,   8, 143],
#          [  3,   6, 622,  ..., 140,   8, 140],
#          ...,
#          [  3,   6, 622,  ..., 143,  87, 143],
#          [  3,   6, 622,  ..., 149,   8, 149],
#          [  3,   6, 622,  ..., 149,  75, 197]]))

# %%
# ps = [S2SFileProcessor()]

# single_tfm = partial(to_single_stream, vocab=vocab)
# data = (MusicItemList(items=hook_files[:100], path=out_path, processor=ps, tfms=[single_tfm])
#         .split_by_rand_pct(0.01, seed=6)
#         .label_const(label_cls=LMLabelList))
# data.x._bunch = MusicDataBunch

# %%
# data.x.tfms = [single_tfm]

# %%
data = data.databunch(bs=4, preloader_cls=S2SPreloader, train_tfms=[single_tfm])

# %%
out = data.train_dl.dl.dataset[0]

# %%
data.one_batch()
