# %% [markdown]
# # DUET ONLY

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')
from src.encode_data import *
from src.midi_data import *
from src.data_sources import process_all, arr2csv
from src.midi_transform import *

# %%
import traceback
import time

# %% [markdown]
# ## Standardize and reformat raw midi files before encoding to text
# - Transform key to C major
# - Remove unused instruments
# - Combine multiple tracks with the same instrument into a single part
# - Melody, Piano, String

# %% [markdown]
# ### Load midi data

# %%
version = 'v13'
data_path = Path('data/midi')
version_path = data_path/version

# %%
import pandas as pd

# %%
source_dir = 'midi_sources'
out_dir = 'piano_duet'
source_csv = version_path/'metadata'/f'{source_dir}.csv'
out_csv = version_path/out_dir/f'{out_dir}.csv'
out_csv.parent.mkdir(parents=True, exist_ok=True)
source_csv, out_csv
# Out:
# (PosixPath('data/midi/v13/metadata/midi_sources.csv'),
#  PosixPath('data/midi/v13/piano_duet/piano_duet.csv'))

# %%
num_comps = 2 # note, duration
cutoff = 2 # max instruments
max_dur = 128

# %% [markdown]
# ### Encoding midi to numpy

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,5,6,10,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                      parts                title  ht_time_signature  \
# 0             intro,chorus  yu-gi-oh-theme-song                4.0
# 1             intro,chorus  yu-gi-oh-theme-song                3.0
# 2                   chorus               kiefer                4.0
# 3  verse,pre-chorus,chorus         senbonzakura                4.0
# 4  verse,pre-chorus,chorus         senbonzakura                4.0
#
#                                                 midi  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...
#
#                                 md5     section ht_key     genres  \
# 0  bf1f29e5ff84e3e93e37fb873bfb590e      chorus      C        NaN
# 1  055f80ad67f64edb14a85ca8fbfe8c29       intro      C        NaN
# 2  197f96f5d181f6ce1e2c5ab04ac1ff87      chorus      D       Jazz
# 3  9e7ce13a35f1314423a9a6d5a5287a4a  pre-chorus      D  J-Pop,Pop
# 4  d5aaf79d0989222f1362f9f46c540a27       verse      D  J-Pop,Pop
#
#          artist      source                     midi_title  ht_mode  ht_bpm  \
# 0  wayne-sharpe  hooktheory                      yu-gi-oh3      1.0   128.0
# 1  wayne-sharpe  hooktheory                       yu-gi-oh      1.0    85.0
# 2    what-a-day  hooktheory                         kiefer      6.0    96.0
# 3    whiteflame  hooktheory  senbonzakura - pre-Pre-Chorus      6.0   152.0
# 4    whiteflame  hooktheory                   Senbonzakura      6.0   152.0
#
#    ht_offset  mxl                                           song_url
# 0        0.0  NaN  https://www.hooktheory.com/theorytab/view/wayn...
# 1        0.0  NaN  https://www.hooktheory.com/theorytab/view/wayn...
# 2       -5.0  NaN  https://www.hooktheory.com/theorytab/view/what...
# 3       -5.0  NaN  https://www.hooktheory.com/theorytab/view/whit...
# 4       -5.0  NaN  https://www.hooktheory.com/theorytab/view/whit...

# %%
all_records = df.to_dict(orient='records'); len(all_records)
# Out:
# 196588

# %%
def transform_func(metadata):
    result = metadata.copy()
    
    # Part 1. Compress tracks/instruments
    if not isinstance(metadata.get('midi'), str): return None
    
    input_path = version_path/metadata['midi']
    extension = input_path.suffix.lower()
    if not input_path.exists(): 
        print('Input path does not exist:', input_path, metadata)
        return None
    
    # Get outfile and check if it exists
    out_file = Path(str(input_path).replace(f'/{source_dir}/', f'/{out_dir}/'))
    out_file = out_file.with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): 
        result['numpy'] = str(out_file.relative_to(version_path))
        return result
    
    try: 
        if num_piano_tracks(input_path) not in [1, 2]: return None
        
        # remove non note tracks and standardize instruments
        input_file = compress_midi_file(input_path, cutoff=cutoff, supported_types=[Track.PIANO])
    except music21.midi.MidiException as e:
        print('Error parsing midi', input_path, e)
        return None
    if not input_file: return None
        
    # Part 2. Compress rests and long notes
    stream = file2stream(input_file) # 1.
    try:
        # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
        chordarr = stream2chordarr(stream, max_dur=max_dur, flat=False) 
    except Exception as e:
        print('Could not encode to chordarr:', input_path, e)
#         print(traceback.format_exc())
        return None
    
    chord_trim = trim_chordarr_rests(chordarr)
    chord_short = shorten_chordarr_rests(chord_trim)
    delta_trim = chord_trim.shape[0] - chord_short.shape[0]
    if delta_trim > 300: 
        print(f'Removed {delta_trim} rests from {input_path}.')
    chordarr = chord_short
    
    # Part 3. Chord array to numpy
    seq = chordarr2seq(chordarr)
    if len(seq) < 32:
        print('Sequence too short:', len(seq), input_path)
        return None
    
    category = source2encidx(metadata['source'], max_dur=max_dur)
    npenc = seq2npenc(seq, num_comps=num_comps, category=category)
    if (npenc[1:,1] > max_dur+ENC_OFFSET).any(): 
        print('npenc exceeds max 128 duration:', input_path)
        return None
    
    if ((npenc[...,0] > ENC_OFFSET) & ((npenc[...,0] < 12+ENC_OFFSET) | (npenc[...,0] >= 127-12+ENC_OFFSET))).any(): 
        print('npenc out of note range 12 - 116:', input_path)
        return None
    
    
    np.save(out_file, npenc)
    
    result['numpy'] = str(out_file.relative_to(version_path))
    return result

# %%
def try_transform_func(metadata):
    try:
        return transform_func(metadata)
    except Exception:
        print(traceback.format_exc())
        return None

# %%
# # sanity check
import random
for r in random.sample(all_records, 10):
    transform_func(r)
# Out:
# Sequence too short: 9 data/midi/v13/midi_sources/130k_reddit/C/C/camelia.mid

# %%
def timeout_func(data, seconds):
    print("Timeout:", seconds, data.get('midi'))

# %%
processed = process_all(try_transform_func, all_records, timeout=300, timeout_func=timeout_func)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='43051' class='' max='196588', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.90% [43051/196588 29:49<1:46:20]
#     </div>
# Sequence too short: 25 data/midi/v13/midi_sources/hooktheory/pianoroll/y/yes/heart-of-the-sunrise/intro_key_original.mid
# Sequence too short: 29 data/midi/v13/midi_sources/hooktheory/pianoroll/j/jeff-liu/steven-and-the-crystal-gems/outro_key_original.mid
# Sequence too short: 25 data/midi/v13/midi_sources/hooktheory/pianoroll/j/jamiroquai/canned-heat/intro_key_original.mid
# Sequence too short: 29 data/midi/v13/midi_sources/hooktheory/pianoroll/j/jessica-simpson/part-of-your-world/bridge_key_original.mid
# Sequence too short: 25 data/midi/v13/midi_sources/hooktheory/pianoroll/l/lildeucedeuce/mine-turtle/intro_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/f/frankie-valli/the-night/intro_key_original.mid
# Sequence too short: 25 data/midi/v13/midi_sources/hooktheory/pianoroll/n/nobuo-uematsu/final-fantasy-vi---dancing-mad-part-3/bridge_key_original.mid
# Sequence too short: 25 data/midi/v13/midi_sources/hooktheory/pianoroll/n/nobuo-uematsu/final-fantasy-vii---victory-fanfare/intro_key_original.mid
# Sequence too short: 27 data/midi/v13/midi_sources/hooktheory/pianoroll/n/nigel-tufnel/nigels-top-of-the-heap-1959-gibson-les-paul/instrumental_key_original.mid
# Sequence too short: 29 data/midi/v13/midi_sources/hooktheory/pianoroll/n/neru/law-evading-rock/chorus-lead-out_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/h/hiveswap/half-harley-manor/chorus-lead-out_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/h/homestuck/english/solo_key_original.mid
# Sequence too short: 29 data/midi/v13/midi_sources/hooktheory/pianoroll/h/homestuck/lotus/chorus-lead-out_key_original.mid
# Sequence too short: 15 data/midi/v13/midi_sources/hooktheory/pianoroll/t/this-town-needs-guns/gibbon/intro_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/t/the-beatles/a-hard-days-night/intro-and-verse_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/t/the-beatles/a-hard-days-night/intro_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/t/they-might-be-giants/everything-right-is-wrong-again/chorus-lead-out_key_original.mid
# Sequence too short: 27 data/midi/v13/midi_sources/hooktheory/pianoroll/k/koji-kondo/kaepora-gaebora/intro_key_original.mid
# Sequence too short: 31 data/midi/v13/midi_sources/hooktheory/pianoroll/k/koji-kondo/athletic-bgm-super-mario-bros-3/intro_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/k/koji-kondo/super-mario-world---athletic/intro_key_original.mid
# Sequence too short: 25 data/midi/v13/midi_sources/hooktheory/pianoroll/k/koji-kondo/link-to-the-past---minigame-theme/intro_key_original.mid
# Sequence too short: 21 data/midi/v13/midi_sources/hooktheory/pianoroll/k/koji-kondo/super-mario-bros-3---hammer-bros-battle-theme/intro_key_original.mid
# Sequence too short: 17 data/midi/v13/midi_sources/hooktheory/pianoroll/m/men-at-work/land-down-under/intro_key_original.mid
# Sequence too short: 21 data/midi/v13/midi_sources/hooktheory/pianoroll/m/microsoft/windows-xp-startup-sound/instrumental_key_original.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Atomic Kitten - Whole Again.mid badly formated midi bytes, got: b'RIFF\x08K\x00\x00RMIDdata{J\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Tatu - Ya Tvoy Vrag (I'm Your Enemy).mid badly formated midi bytes, got: b'RIFF,\xa3\x00\x00RMIDdata\xc6\xa2\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - I'm Not Givin' You Up.mid badly formated midi bytes, got: b'RIFFB\x8c\x00\x00RMIDdata~\x8b\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Get On Your Feet.mid badly formated midi bytes, got: b'RIFF\x92\xa8\x01\x00RMIDdata\xd8\xa7\x01\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Mi Tierra.mid badly formated midi bytes, got: b'RIFFz\r\x01\x00RMIDdata\xce\x0c\x01\x00'
# Traceback (most recent call last):
#   File "<ipython-input-16-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-3e69cc23f1bc>", line 22, in transform_func
#     if num_piano_tracks(input_path) not in [1, 2]: return None
#   File "../../src/midi_transform.py", line 29, in num_piano_tracks
#     music_file = file2mf(fp)
#   File "../../src/midi_data.py", line 86, in file2mf
#     mf.read()
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1277, in read
#     self.readstr(self.file.read())
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1322, in readstr
#     midiStr = trk.read(midiStr) # pass all the remaining bytes, reassining
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1118, in read
#     dt, trackStrCandidate = delta_t.read(trackStr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1054, in read
#     self.time, newstr = getVariableLengthNumber(oldstr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 204, in getVariableLengthNumber
#     if common.isNum(midiStr[i]):
# IndexError: index out of range
#
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Whitney Houston - If I Told You That.mid badly formated midi bytes, got: b'error with file'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Coming Out of The Dark.mid badly formated midi bytes, got: b'RIFF\xca)\x00\x00RMIDdata\x03)\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Tatu - Ne Ver Ne Boysia.mid badly formated midi bytes, got: b'RIFF\xa8\xbd\x00\x00RMIDdata\x13\xbd\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Enigma - Sadness.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Whitney Houston - I Believe In You And Me.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Craig David - Walking Away.mid badly formated midi bytes, got: b'RIFF\xca\xcf\x01\x00RMIDdata\x1d\xcf\x01\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gwen Stefani - Early Winter.mid badly formated midi bytes, got: b'<br />\n<b>Warning</b'
# Removed 540 rests from data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Pitbull - I Know You Want Me.mid.
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Anything For You.mid badly formated midi bytes, got: b'RIFF\x00)\x00\x00RMIDdataE(\x00\x00'
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Pitbull - I Know You Want Me.mid
# Sequence too short: 0 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Daft Punk - Aerodynamic.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Breaking Up Is Hard To Do.mid badly formated midi bytes, got: b'RIFF\x10N\x00\x00RMIDdataDM\x00\x00'
# Sequence too short: 17 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Daft Punk - Derezzed.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Whitney Houston - It's Not Right, But It's Ok.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Modern Talking - Megamix 2000.mid badly formated midi bytes, got: b'RIFFp\x91\x02\x00RMIDdata\xd1\x90\x02\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Go Away.mid badly formated midi bytes, got: b'RIFF\x84\xcd\x00\x00RMIDdata\xdb\xcc\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Kylie Minogue - Your Disco Needs You.mid badly formated midi bytes, got: b'RIFF$\xd9\x00\x00RMIDdata\x83\xd8\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Ayer.mid badly formated midi bytes, got: b'RIFF\x98\xf5\x00\x00RMIDdata\xf5\xf4\x00\x00'
# Traceback (most recent call last):
#   File "<ipython-input-16-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-3e69cc23f1bc>", line 22, in transform_func
#     if num_piano_tracks(input_path) not in [1, 2]: return None
#   File "../../src/midi_transform.py", line 29, in num_piano_tracks
#     music_file = file2mf(fp)
#   File "../../src/midi_data.py", line 86, in file2mf
#     mf.read()
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1277, in read
#     self.readstr(self.file.read())
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1322, in readstr
#     midiStr = trk.read(midiStr) # pass all the remaining bytes, reassining
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1118, in read
#     dt, trackStrCandidate = delta_t.read(trackStr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1054, in read
#     self.time, newstr = getVariableLengthNumber(oldstr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 204, in getVariableLengthNumber
#     if common.isNum(midiStr[i]):
# IndexError: index out of range
#
# Traceback (most recent call last):
#   File "<ipython-input-16-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-3e69cc23f1bc>", line 22, in transform_func
#     if num_piano_tracks(input_path) not in [1, 2]: return None
#   File "../../src/midi_transform.py", line 29, in num_piano_tracks
#     music_file = file2mf(fp)
#   File "../../src/midi_data.py", line 86, in file2mf
#     mf.read()
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1277, in read
#     self.readstr(self.file.read())
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1322, in readstr
#     midiStr = trk.read(midiStr) # pass all the remaining bytes, reassining
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1128, in read
#     trackStrCandidate = e.read(timeCandidate, trackStrCandidate)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 821, in read
#     return self._parseChannelVoiceMessage(midiStr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 720, in _parseChannelVoiceMessage
#     if common.isNum(midiStr[2]):
# IndexError: index out of range
#
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Donna Summer - Bad Girls.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Gloria Estefan - Cant Stay Away From You.mid badly formated midi bytes, got: b'RIFF^5\x00\x00RMIDdata\x934\x00\x00'
# Could not encode to chordarr: data/midi/v13/midi_sources/freemidi/genre-dance-eletric/DJ Bobo - Its My Life.mid index 27 is out of bounds for axis 0 with size 27
# Sequence too short: 17 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Radiohead - Bullet Proof.mid
# Sequence too short: 26 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/DJ Bobo - Where Is Your Love.mid
# Sequence too short: 27 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/DJ Bobo - Respect Yourself.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Tatu - Robot.mid badly formated midi bytes, got: b'RIFF\x82N\x00\x00RMIDdata\x1cN\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Whats Going On.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Who Let In The Rain.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Chemical Brothers - Loops Of Furry.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/5th Dimension - One Less Bell To Answere.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - The World Is Stone.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Change Of Heart.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Sequence too short: 0 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Radiohead - Airbag.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - If You Go Away.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Money Changes Everything.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Sequence too short: 27 data/midi/v13/midi_sources/freemidi/genre-pop/Avril Lavigne - Get Over It.mid
# Traceback (most recent call last):
#   File "<ipython-input-16-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-3e69cc23f1bc>", line 22, in transform_func
#     if num_piano_tracks(input_path) not in [1, 2]: return None
#   File "../../src/midi_transform.py", line 29, in num_piano_tracks
#     music_file = file2mf(fp)
#   File "../../src/midi_data.py", line 86, in file2mf
#     mf.read()
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1277, in read
#     self.readstr(self.file.read())
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1322, in readstr
#     midiStr = trk.read(midiStr) # pass all the remaining bytes, reassining
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1128, in read
#     trackStrCandidate = e.read(timeCandidate, trackStrCandidate)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 821, in read
#     return self._parseChannelVoiceMessage(midiStr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 720, in _parseChannelVoiceMessage
#     if common.isNum(midiStr[2]):
# IndexError: index out of range
#
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Box Car Racer - Tiny Voices (2).mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Box Car Racer - Tiny Voices.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Gipsy Kings - Bem Bem Maria.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - I Dont Want To Be Your Friend.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Could not encode to chordarr: data/midi/v13/midi_sources/freemidi/genre-pop/Tina Turner - What Ever You Want.mid index 63 is out of bounds for axis 0 with size 63
# Removed 752 rests from data/midi/v13/midi_sources/freemidi/genre-pop/Annie Lennox - Would I Lie To You.mid.
# Sequence too short: 0 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Depeche Mode - Further Excerpts From My Secret Garden.mid
# Sequence too short: 0 data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Real McCoy - Love And Devotion.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Annie Lennox - Would I Lie To You.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - La Vie En Rose.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Michael Jackson - The Way You Make Me Feel.mid badly formated midi bytes, got: b'RIFF\xe2\xfe\x00\x00RMIDdata\x16\xfe\x00\x00'
# Could not encode to chordarr: data/midi/v13/midi_sources/freemidi/genre-dance-eletric/Bjork - Aurora.mid index 127 is out of bounds for axis 2 with size 127
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Faith Hill - It Matters To Me.mid badly formated midi bytes, got: b'RIFF\x06`\x00\x00RMIDdataT_\x00\x00'
# Sequence too short: 0 data/midi/v13/midi_sources/freemidi/genre-pop/Britney Spears - Early Morning.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Boyzone - No Matter What.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Hymn To Love.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Shattered Dreams.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel\xfc0\x02\x00'
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Aha - Dark Is The Night For All.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Backstreet Boys - I Need You Tonight.mid badly formated midi bytes, got: b''
# Traceback (most recent call last):
#   File "<ipython-input-16-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-3e69cc23f1bc>", line 22, in transform_func
#     if num_piano_tracks(input_path) not in [1, 2]: return None
#   File "../../src/midi_transform.py", line 29, in num_piano_tracks
#     music_file = file2mf(fp)
#   File "../../src/midi_data.py", line 86, in file2mf
#     mf.read()
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1277, in read
#     self.readstr(self.file.read())
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1322, in readstr
#     midiStr = trk.read(midiStr) # pass all the remaining bytes, reassining
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1128, in read
#     trackStrCandidate = e.read(timeCandidate, trackStrCandidate)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 821, in read
#     return self._parseChannelVoiceMessage(midiStr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 720, in _parseChannelVoiceMessage
#     if common.isNum(midiStr[2]):
# IndexError: index out of range
#
# Removed 512 rests from data/midi/v13/midi_sources/freemidi/genre-pop/La Roux - Bulletproof.mid.
# Sequence too short: 27 data/midi/v13/midi_sources/freemidi/genre-pop/Faith Hill - Wild One.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/La Roux - Bulletproof.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Natalie Cole - I Live For Your Love.mid badly formated midi bytes, got: b'<html>\n<head>\n<title'
# Removed 496 rests from data/midi/v13/midi_sources/freemidi/genre-pop/Sting - Saint Augustine.mid.
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Amanda Lear - Blue Tango.mid badly formated midi bytes, got: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03,]u@\x93_\x17~7\xb6'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/ABC - The Look Of Love.mid badly formed midi string: missing leading MTrk
# Removed 1048 rests from data/midi/v13/midi_sources/freemidi/genre-pop/Sting - Love Is Stronger Than Justice.mid.
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Coldplay - Charlie Brown.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/ABBA - Just Like That.mid badly formed midi string: missing leading MTrk
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Sting - Saint Augustine.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Karen Carpenter - Error no title.mid badly formated midi bytes, got: b'\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYP'
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Sting - Love Is Stronger Than Justice.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Iko Iko.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Roxette - Hotblooded.mid
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/freemidi/genre-pop/Barbra Streisand - Happy Days Are Here Again.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Westlife - Fool Again.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Usher - You Got It Bad.mid badly formated midi bytes, got: b'RIFF\x80\x85\x00\x00RMIDdata\xe0\x84\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Wings - Band On The Run.mid badly formed midi string: missing leading MTrk
# Removed 1784 rests from data/midi/v13/midi_sources/freemidi/genre-pop/Peter Gabriel - In Your Eyes.mid.
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Four Seasons - I've Got You Under My Skin.mid badly formed midi string: missing leading MTrk
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Peter Gabriel - In Your Eyes.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Evanescence - Haunted.mid badly formated midi bytes, got: b'RIFF\x0e[\x00\x00RMIDdata\x01[\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Wilson Phillips - Release.mid badly formed midi string: missing leading MTrk
# Sequence too short: 17 data/midi/v13/midi_sources/freemidi/genre-pop/Jay-Z - Renagade.mid
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/freemidi/genre-pop/Sting - Fragile.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Vapors - Turning Japanese.mid badly formated midi bytes, got: b'\x00\x00\x0ecmoov\x00\x00\x00lmvhd\x00\x00\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Box Car Racer - Cat Like Thief.mid badly formated midi bytes, got: b'RIFF\xd2\x9b\x00\x00RMIDdata\x9b\x9b\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Cyndi Lauper - Sisters Of Avalon.mid badly formated midi bytes, got: b'0&\xb2u\x8ef\xcf\x11\xa6\xd9\x00\xaa\x00b\xcel?\x13\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Kenny Rogers - She Believes In Me.mid badly formated midi bytes, got: b'RIFFx\xa6\x00\x00RMIDdata\xbe\xa5\x00\x00'
# Sequence too short: 0 data/midi/v13/midi_sources/freemidi/genre-pop/Fleetwood Mac - Everywhere.mid
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Jay-Z - A Million And One Questions.mid badly formed midi string: missing leading MTrk
# Traceback (most recent call last):
#   File "<ipython-input-16-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-3e69cc23f1bc>", line 22, in transform_func
#     if num_piano_tracks(input_path) not in [1, 2]: return None
#   File "../../src/midi_transform.py", line 29, in num_piano_tracks
#     music_file = file2mf(fp)
#   File "../../src/midi_data.py", line 86, in file2mf
#     mf.read()
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1277, in read
#     self.readstr(self.file.read())
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1322, in readstr
#     midiStr = trk.read(midiStr) # pass all the remaining bytes, reassining
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1128, in read
#     trackStrCandidate = e.read(timeCandidate, trackStrCandidate)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 857, in read
#     'charToBinary(midiStr[0])', charToBinary(midiStr[0]),
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 75, in charToBinary
#     asciiValue = ord(char)
# TypeError: ord() expected string of length 1, but int found
# Error parsing midi data/midi/v13/midi_sources/freemidi/genre-pop/Guy Sebastian - Angels Brought Me Here.mid badly formated midi bytes, got: b'<!DOCTYPE HTML PUBLI'
# Sequence too short: 0 data/midi/v13/midi_sources/freemidi/genre-pop/Ricky Martin - Livin' La Vida Loca.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Bomfunk_MCs_-_Uprocking_Beats.mid badly formated midi bytes, got: b'RIFF\xb8\xa7\x00\x00RMIDdata\x04\xa7\x00\x00'
# Sequence too short: 17 data/midi/v13/midi_sources/midiworld/named_midi/Cameron_Lee_Simpson_-_Cue_.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Polly.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Pennyroyal_Tea.mid badly formed midi string: missing leading MTrk
# Removed 936 rests from data/midi/v13/midi_sources/freemidi/genre-pop/Peter Gabriel - The Family And The Fishing Net.mid.
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Radio_Friendly_Unit_Shifter.mid badly formed midi string: missing leading MTrk
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/freemidi/genre-pop/Peter Gabriel - The Family And The Fishing Net.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Bomfunk_MCs_-_B-Boys_And_Fly-Girls.mid badly formated midi bytes, got: b'RIFF^\xd8\x00\x00RMIDdata\xa1\xd7\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nightwish_-_Feel_For_You.mid badly formated midi bytes, got: b'RIFFr\x9a\x00\x00RMIDdatae\x9a\x00\x00'
# Could not encode to chordarr: data/midi/v13/midi_sources/freemidi/genre-pop/Carly Simon - Mocking Bird.mid index 127 is out of bounds for axis 2 with size 127
# Sequence too short: 19 data/midi/v13/midi_sources/midiworld/named_midi/ffffffff_-_.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Brian_McKnight_-_On_The_Down_Low.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Hairspray_Queen.mid badly formed midi string: missing leading MTrk
# Sequence too short: 0 data/midi/v13/midi_sources/midiworld/named_midi/Vassar_Clements_-_The_Orange_Blossom_Special.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Ugly_Kid_Joe_-_Everything_About_You.mid
# Sequence too short: 30 data/midi/v13/midi_sources/midiworld/named_midi/Frank_Sinatra_-_Strangers_in_the_Night.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Drain_You.mid cannot handle ticks per frame: 77
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Downer.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Itowngameplay_-_bonnies_song.mid badly formated midi bytes, got: b'ID3\x04\x00\x00\x00\x00\x01\x13TXXX\x00\x00\x00\x12\x00\x00'
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Territorial_Pissings.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Negative_Creep.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Deep_Purple_-_Deep_Cascade.mid badly formed midi string: missing leading MTrk
# Removed 1784 rests from data/midi/v13/midi_sources/midiworld/named_midi/Peter_Gabriel_-_In_Your_Eyes.mid.
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Peter_Gabriel_-_In_Your_Eyes.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Fleetwood_Mac_-_The_Chain.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Counting_Crows_-_Round_Here.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nightwish_-_Lagoon.mid badly formated midi bytes, got: b'RIFF(h\x00\x00RMIDdata\x1bh\x00\x00'
# Sequence too short: 13 data/midi/v13/midi_sources/midiworld/named_midi/Blessed_Union_Of_Souls_-_Hey_Leonardo.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Love_Buzz.mid badly formed midi string: missing leading MTrk
# Removed 752 rests from data/midi/v13/midi_sources/midiworld/named_midi/The_Eurythmics_-_Would_I_Lie_to_You.mid.
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Frances_Farmer_Will_Have_Her_Revenge_On_Seattle.mid badly formed midi string: missing leading MTrk
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/The_Eurythmics_-_Would_I_Lie_to_You.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Tourette's.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Turnaround.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Swap_Meet.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Scentless_Apprentice.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_All_Apologies.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Smells_Like_Teen_Spirit.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/John_Paul_Young_-_Love_is_in_the_Air.mid badly formed midi string: missing leading MTrk
# Removed 620 rests from data/midi/v13/midi_sources/midiworld/named_midi/Creedence_Clearwater_Revival_-_Born_on_a_Bayou.mid.
# Removed 332 rests from data/midi/v13/midi_sources/midiworld/named_midi/Led_Zeppelin_-_In_the_Evening.mid.
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Creedence_Clearwater_Revival_-_Born_on_a_Bayou.mid
# Sequence too short: 17 data/midi/v13/midi_sources/midiworld/named_midi/Alexandros_Mousafeiris_-_Sanchit's_Tune.mid
# Sequence too short: 0 data/midi/v13/midi_sources/midiworld/named_midi/Cypress_Hill_-_Rock_Superstar.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Led_Zeppelin_-_In_the_Evening.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Gabi_Fratucello_-_.mid badly formated midi bytes, got: b'ID3\x04\x00\x00\x00\x00\x01\x00TXXX\x00\x00\x00\x12\x00\x00'
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/It's_A_Beautiful_Day_-_White_Bird.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/The_Offspring_-_No_Hero.mid badly formated midi bytes, got: b'RIFF\x04N\x01\x00RMIDdata\xf7M\x01\x00'
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Son_Of_A_Gun.mid badly formed midi string: missing leading MTrk
# Sequence too short: 0 data/midi/v13/midi_sources/midiworld/named_midi/Video_Game_Themes_-_Street_Fighter_2.mid
# Traceback (most recent call last):
#   File "<ipython-input-16-c95459e3fde9>", line 3, in try_transform_func
#     return transform_func(metadata)
#   File "<ipython-input-14-3e69cc23f1bc>", line 22, in transform_func
#     if num_piano_tracks(input_path) not in [1, 2]: return None
#   File "../../src/midi_transform.py", line 29, in num_piano_tracks
#     music_file = file2mf(fp)
#   File "../../src/midi_data.py", line 86, in file2mf
#     mf.read()
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1277, in read
#     self.readstr(self.file.read())
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1322, in readstr
#     midiStr = trk.read(midiStr) # pass all the remaining bytes, reassining
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 1128, in read
#     trackStrCandidate = e.read(timeCandidate, trackStrCandidate)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 821, in read
#     return self._parseChannelVoiceMessage(midiStr)
#   File "/home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/music21/midi/__init__.py", line 720, in _parseChannelVoiceMessage
#     if common.isNum(midiStr[2]):
# IndexError: index out of range
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Mr._Moustache.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Lounge_Act.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Third_Eye_Blind_-_Semi_Charmed_Life.mid badly formated midi bytes, got: b'RIFFV\x0c\x01\x00RMIDdataI\x0c\x01\x00'
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Heart-Shaped_Box.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_On_A_Plain.mid badly formed midi string: missing leading MTrk
# Sequence too short: 1 data/midi/v13/midi_sources/midiworld/named_midi/Radiohead_-_Just.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/midiworld/named_midi/djwill96_-_Young_forever_v2.mid index 1407 is out of bounds for axis 0 with size 1407
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Mexican_Seafood.mid badly formed midi string: missing leading MTrk
# Could not encode to chordarr: data/midi/v13/midi_sources/midiworld/named_midi/Howlin_Wolf_-_Little_Red_Rooster.mid index 1147 is out of bounds for axis 0 with size 1147
# Sequence too short: 17 data/midi/v13/midi_sources/midiworld/named_midi/dragon_quest_4_-_Level_Up.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Aneurysm.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Been_A_Son.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Sliver.mid badly formed midi string: missing leading MTrk
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Dive.mid badly formed midi string: missing leading MTrk
# Sequence too short: 27 data/midi/v13/midi_sources/midiworld/named_midi/dhdizitr_-_dhdizitr.mid
# Error parsing midi data/midi/v13/midi_sources/midiworld/named_midi/Nirvana_-_Milk_It.mid badly formed midi string: missing leading MTrk
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Led_Zeppelin_-_Dancing_Days.mid
# Sequence too short: 0 data/midi/v13/midi_sources/midiworld/named_midi/Queen_-_Keep_Yourself_Alive.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Tommy_James_-_Draggin_the_Line.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/nOt_mE_-_panic_switch.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/midiworld/named_midi/Willie_Nelson_-_Always_On_My_Mind.mid index 1007 is out of bounds for axis 0 with size 1007
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/midiworld/named_midi/Foo_Fighters_-_Learn_to_Fly.mid
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/midiworld/named_midi/Babyface_-_The_Day.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/ecomp/2017/KaiRuiR10.mid index 3419 is out of bounds for axis 0 with size 3419
# Could not encode to chordarr: data/midi/v13/midi_sources/midiworld/named_midi/Jelly_Roll_Morton_-_Honky_Tonk_Blues.mid index 2219 is out of bounds for axis 0 with size 2219
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/ecomp/2008/ZhangX03.mid index 1391 is out of bounds for axis 0 with size 1391
# Removed 452 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2008/Denisova12.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/ecomp/2008/Kociuban16.mid index 2419 is out of bounds for axis 0 with size 2419
# Timeout: 300 midi_sources/freemidi/genre-dance-eletric/Enigma - Variations.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_FRLG_Route_1_Theme_Advanced_Version.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_50_Times.mid
# Timeout: 300 midi_sources/midiworld/named_midi/OFMG_-_.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_9_Candy_Constellation_Play_50_Times.mid
# Timeout: 300 midi_sources/midiworld/named_midi/Nintendo_-_Pokemon_Liquid_Crystal_Gym_Piano_Cover.mid
# Removed 320 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2006/WongDoe05.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/ecomp/2004/KARYAG04.mid index 127 is out of bounds for axis 2 with size 127
# Removed 448 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2009/Erice01.mid.
# Removed 616 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2004/SCHU07.mid.
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/from_mxl/ecomp/2009/Tysman04.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/ecomp/2015/LeeN06.mid index 1539 is out of bounds for axis 0 with size 1539
# Removed 388 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2015/LuoJ11.mid.
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/from_mxl/ecomp/2011/Lou04.mid
# Removed 696 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2015/LeeN05.mid.
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/from_mxl/ecomp/2015/RichardsonC07.mid
# Removed 652 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2015/MiyashitaM02.mid.
# Removed 500 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2015/WuuE01.mid.
# Removed 452 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2015/MunA02.mid.
# Timeout: 300 midi_sources/from_mxl/ecomp/2014/HamSY05.mid
# Timeout: 300 midi_sources/from_mxl/ecomp/2014/DupreeF02.mid
# Timeout: 300 midi_sources/from_mxl/ecomp/2011/Chon11.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/ecomp/2018/KaszoS07.mid index 1807 is out of bounds for axis 0 with size 1807
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classic_piano/muss_1_format0.mid index 1487 is out of bounds for axis 0 with size 1487
# Removed 1760 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/parhujud.mid.
# Removed 676 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/cpm17402.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmdbshep.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmbksost.mid index 127 is out of bounds for axis 2 with size 127
# Removed 4852 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/bracov.mid.
# Error parsing midi data/midi/v13/midi_sources/from_mxl/classical_archives/021/bl109_15.mid badly formated midi bytes, got: b''
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmpchnem.mid index 127 is out of bounds for axis 2 with size 127
# Removed 4696 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/gp_bal4.mid.
# Error parsing midi data/midi/v13/midi_sources/from_mxl/classical_archives/021/3_pt_15.mid badly formated midi bytes, got: b''
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmpanwrs.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tm10es07.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmhl4611.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmslvdnc.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmhl4605.mid
# Removed 640 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/cpm17408.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmhunfk1.mid index 127 is out of bounds for axis 2 with size 127
# Removed 636 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/anitrasd.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmcpsolf.mid
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmgypron.mid index 127 is out of bounds for axis 2 with size 127
# Removed 620 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/cpm17406.mid.
# Removed 324 rests from data/midi/v13/midi_sources/from_mxl/ecomp/2018/AndreevI02.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmevvilg.mid index 127 is out of bounds for axis 2 with size 127
# Removed 332 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/cpm17405.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tm10es09.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmhl4618.mid
# Removed 1152 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/tarti1.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmcl36_3.mid index 127 is out of bounds for axis 2 with size 127
# Removed 1028 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/pit_nut.mid.
# Removed 1168 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/zampa.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmpesdnc.mid
# Removed 2464 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/dvsy53.mid.
# Removed 816 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/tarti3.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmhl4622.mid
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmbardnc.mid
# Removed 796 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/brujota.mid.
# Removed 656 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/scheidt.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmcl36_4.mid
# Removed 760 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/bwv878b.mid.
# Removed 1964 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/scheh1.mid.
# Removed 3444 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/k622_1.mid.
# Removed 1476 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/suite2-4.mid.
# Removed 688 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/concp17a.mid.
# Removed 2032 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/suite2-1.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmcl38_3.mid
# Removed 452 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/faurreq2.mid.
# Error parsing midi data/midi/v13/midi_sources/from_mxl/classical_archives/4/coqdor3.mid badly formated midi bytes, got: b''
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmcl36_6.mid index 127 is out of bounds for axis 2 with size 127
# Error parsing midi data/midi/v13/midi_sources/from_mxl/classical_archives/4/bach-565.mid badly formated midi bytes, got: b''
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmcl38_1.mid index 127 is out of bounds for axis 2 with size 127
# Removed 2036 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/funeral.mid.
# Removed 500 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/souzwash.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmcl38_2.mid
# Removed 1116 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/mas13.mid.
# Removed 864 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/sltan16.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmbchdbl.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/021/tmzampa.mid index 127 is out of bounds for axis 2 with size 127
# Removed 464 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/sltan15.mid.
# Removed 312 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/op6n02m4.mid.
# Removed 548 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/griegp.mid.
# Removed 1116 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/rv540.mid.
# Sequence too short: 17 data/midi/v13/midi_sources/from_mxl/classical_archives/4/ifyouwnt.mid
# Removed 604 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/021/mspc22a.mid.
# Removed 532 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/lemexoti.mid.
# Removed 772 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/sltan27.mid.
# Removed 988 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/8/be-pc3-3.mid.
# Removed 4336 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/dvs93.mid.
# Removed 904 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/sltan14.mid.
# Removed 404 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/coqdor4.mid.
# Removed 3352 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/ritepti.mid.
# Removed 1292 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/alb_ibs.mid.
# Removed 968 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/rv263a_1.mid.
# Removed 592 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/apuffi.mid.
# Removed 1052 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/4/grtmikdo.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/4/men72-2.mid
# ...
# Removed 1080 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/finalrel.mid.
# Removed 3376 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/b_danube.mid.
# Removed 520 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/gp_ffl.mid.
# Removed 1560 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/dgnuperr.mid.
# Removed 3412 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/vna_wood.mid.
# Removed 328 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/oh_20sil.mid.
# Removed 452 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/k595b.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/014/tmgr54_3.mid index 127 is out of bounds for axis 2 with size 127
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/014/tmcl36_1.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/from_mxl/classical_archives/014/3allegr.mid
# Removed 1276 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/il_favor.mid.
# Removed 316 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/carentr1.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/014/tmrobret.mid
# Removed 716 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/gp_2_nut.mid.
# Removed 632 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/3/jsbos11.mid.
# Removed 2592 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/1812ovrt.mid.
# Removed 776 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/1066_6bo.mid.
# Removed 964 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/3/jsbos21.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/014/tmkattoc.mid
# Removed 384 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/carmprld.mid.
# Timeout: 300 midi_sources/from_mxl/classical_archives/4/carnaval.mid
# Removed 5748 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/frchas.mid.
# Removed 2848 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/hunyadi.mid.
# Removed 1908 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/eevar16.mid.
# Removed 640 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/jsbbrc43.mid.
# Removed 640 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/1066_7pa.mid.
# Removed 444 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/3/chpnc1-3.mid.
# Removed 312 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/jk_be15b.mid.
# Removed 628 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/k595c.mid.
# Removed 568 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/k595a.mid.
# Removed 2248 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/russludo.mid.
# Removed 392 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/jsbbrc61.mid.
# Removed 2924 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/gp_danse.mid.
# Removed 316 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/1066_1ov.mid.
# Removed 400 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/jsbbrc63.mid.
# Removed 376 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/jsssolgm.mid.
# Removed 1512 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/jk_dblm.mid.
# Removed 408 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/piano26.mid.
# Removed 648 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/danze1_4.mid.
# Removed 756 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/jk_dblme.mid.
# Removed 3896 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/tmntbare.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/031/tmak390.mid index 127 is out of bounds for axis 2 with size 127
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/031/tmgreen.mid index 1339 is out of bounds for axis 0 with size 1339
# Removed 1612 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/fldrmaus.mid.
# Removed 1512 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/danze1_2.mid.
# Removed 976 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/jk_be15c.mid.
# Removed 1004 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/brandenb.mid.
# Removed 792 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/v_req_08.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/014/tmcl36_5.mid
# Removed 312 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/viv3_bd.mid.
# Removed 372 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/sui4_1ov.mid.
# Removed 1824 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/dansemac.mid.
# Removed 3132 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/gp_nor_r.mid.
# Sequence too short: 14 data/midi/v13/midi_sources/from_mxl/classical_archives/9/kv334.mid
# Removed 916 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/cheerful.mid.
# Removed 508 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/bjs1046h.mid.
# Could not encode to chordarr: data/midi/v13/midi_sources/from_mxl/classical_archives/014/tmcl37_1.mid index 127 is out of bounds for axis 2 with size 127
# Removed 1652 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/destino.mid.
# Removed 444 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/tch_sy6d.mid.
# Removed 2208 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/tch_sy6b.mid.
# Removed 868 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/014/jk_be15a.mid.
# Removed 1572 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/sorcappr.mid.
# Removed 664 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/bjs1046d.mid.
# Removed 1920 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/tch_sy6a.mid.
# Removed 964 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/scaffold.mid.
# Removed 1396 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/rosscset.mid.
# Removed 2600 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/scheh4.mid.
# Removed 2768 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/tch_sy6c.mid.
# Removed 840 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/3/chpnc1-1.mid.
# Removed 704 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/3_anitra.mid.
# Removed 2488 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/jk_dbl.mid.
# Removed 468 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/magnif.mid.
# Removed 308 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/004/childr_2.mid.
# Removed 2096 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/wnwmnsng.mid.
# Removed 636 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/004/gn70an.mid.
# Removed 2832 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/gp_8_nut.mid.
# Removed 2940 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/sarka.mid.
# Removed 4244 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/mahl4_1.mid.
# Removed 1184 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/pits4f-3.mid.
# Sequence too short: 17 data/midi/v13/midi_sources/from_mxl/classical_archives/1/ingemi1.mid
# Removed 1316 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/3/vweb.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/3/vweb.mid
# Removed 5248 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/tabor.mid.
# Removed 324 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/sltan23.mid.
# Removed 868 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/piano_c.mid.
# Removed 1500 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/gp_iolan.mid.
# Removed 1108 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/gp_pinaf.mid.
# Removed 1328 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/4fincho.mid.
# Removed 3948 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/voxsprng.mid.
# Removed 568 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/summer.mid.
# Removed 388 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/sltan12.mid.
# Timeout: 300 midi_sources/from_mxl/classical_archives/6/chopop28.mid
# Removed 6756 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/sym_fan1.mid.
# npenc out of note range 12 - 116: data/midi/v13/midi_sources/from_mxl/classical_archives/1/tlmnflut.mid
# Removed 5528 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/polove.mid.
# Removed 492 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/b_minor.mid.
# Removed 908 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/pncnop15.mid.
# Removed 1164 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/004/k271_1.mid.
# Removed 508 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/sltan21.mid.
# Removed 5252 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/blanik.mid.
# Removed 840 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/pits4f-2.mid.
# Removed 2148 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/nictedeu.mid.
# Removed 2492 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/vysehrad.mid.
# Removed 1472 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/bsmetana.mid.
# Removed 4320 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/wienerbt.mid.
# Removed 532 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/031/piano_co.mid.
# Removed 632 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/alb_con1.mid.
# Removed 1916 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/9/triple-1.mid.
# Removed 2116 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/rhon2.mid.
# Removed 2996 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/swoods.mid.
# Removed 1988 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_fa_wc.mid.
# Removed 412 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/bwv232-1.mid.
# Removed 384 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/pg1ani.mid.
# Removed 1644 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/3/tch-pcon-1.mid.
# Removed 320 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/k478_2.mid.
# Removed 7088 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/tasso.mid.
# Removed 804 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_fa_gc.mid.
# Removed 368 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/mahges1.mid.
# Removed 932 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/hanme24.mid.
# Removed 4264 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/ds2pma.mid.
# Removed 1172 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/besym5-3.mid.
# Removed 1988 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/hmercury.mid.
# Removed 3748 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/mus-nite.mid.
# Removed 1256 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_fa_sc.mid.
# Removed 552 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/mrf1.mid.
# Removed 1096 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/marslav.mid.
# Removed 848 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/3/tchai1-1.mid.
# Removed 340 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/parnas.mid.
# Removed 580 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_ye_03.mid.
# Removed 380 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/asfrom.mid.
# Removed 304 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/op6n11m4.mid.
# Removed 1020 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/mg4.mid.
# Sequence too short: 25 data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_ye_10.mid
# Removed 348 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_3_fau.mid.
# Removed 796 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/hseop3-1.mid.
# Removed 604 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/mahges2.mid.
# Removed 4264 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/ds2pmb.mid.
# Removed 1192 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/btedeum2.mid.
# Removed 672 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/1/be-pc4-3.mid.
# Removed 616 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/vivmand1.mid.
# Removed 988 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_fa_ms.mid.
# Removed 332 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_4_fau.mid.
# Removed 944 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_fa_fr.mid.
# Removed 720 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/peergyn3.mid.
# Removed 628 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/03_brind.mid.
# Removed 820 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/conf-1.mid.
# Removed 1288 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/gp_yeo_2.mid.
# Removed 4300 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/smetsy3.mid.
# Removed 1952 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/bare.mid.
# Removed 764 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/032/nunwilld.mid.
# Removed 2736 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/032/ss3-2.mid.
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/from_mxl/classical_archives/032/ss3-2.mid
# Removed 576 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/mozk467c.mid.
# Timeout: 300 midi_sources/from_mxl/classical_archives/011/die_kuns.mid
# Error parsing midi data/midi/v13/midi_sources/from_mxl/musescore/data/94259.mid badly formated midi bytes, got: b''
# Timeout: 300 midi_sources/from_mxl/classical_archives/011/hetderde.mid
# Removed 392 rests from data/midi/v13/midi_sources/from_mxl/musescore/data/4765806.mid.
# Removed 1336 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/032/jb83_2.mid.
# Sequence too short: 25 data/midi/v13/midi_sources/from_mxl/musescore/data/1970711.mid
# Removed 992 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/2/k467n1.mid.
# Removed 396 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/032/jb83_4.mid.
# Sequence too short: 13 data/midi/v13/midi_sources/from_mxl/musescore/data/4168281.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/from_mxl/musescore/data/4838811.mid
# Removed 1648 rests from data/midi/v13/midi_sources/from_mxl/classical_archives/7/bepc4a.mid.
# Sequence too short: 3 data/midi/v13/midi_sources/from_mxl/musescore/data/2142646.mid
# npenc exceeds max 128 duration: data/midi/v13/midi_sources/from_mxl/musescore/data/1840291.mid
# Removed 400 rests from data/midi/v13/midi_sources/from_mxl/musescore/data/3033781.mid.

# %%
arr2csv(processed, out_csv); len(processed)

# %%
df = pd.read_csv(out_csv); df.head()

# %%
df.shape
# Out:
# (112614, 17)
