# %% [markdown]
# # Attention Architecture

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import music21

# %%
# from fastai.text import *
from enum import Enum
import torch
from fastai.text.models.awd_lstm import *
from fastai.text.models.transformer import *

# %%
import numpy as np
import torch.nn as nn

# %%
np.set_printoptions(edgeitems=10, threshold=40, linewidth=200)

# %%
import sys
sys.path.insert(0, '../../')
from src.fastai_data import *
from src.encode_data import *
from src.serve import *

# %%
from src.music_transformer import *

# %%
path = Path('../../data/midi/v15/piano_duet/')

# %% [markdown]
# ## Single Stream Encoding

# %%
config = v15m_config(vocab); config
# Out:
# {'ctx_len': 150,
#  'n_layers': 16,
#  'n_heads': 8,
#  'd_model': 512,
#  'd_head': 64,
#  'd_inner': 2048,
#  'resid_p': 0.1,
#  'attn_p': 0.1,
#  'ff_p': 0.1,
#  'embed_p': 0.2,
#  'output_p': 0.1,
#  'bias': False,
#  'scale': True,
#  'act': <Activation.GeLU: 3>,
#  'double_drop': True,
#  'tie_weights': True,
#  'out_bias': True,
#  'init': <function fastai.text.models.transformer.init_transformer(m)>,
#  'mem_len': 512,
#  'mask': True,
#  'pad_idx': 1,
#  'bos_idx': 0,
#  'sep_idx': 8,
#  'transpose_range': (0, 12),
#  'rand_transpose': True,
#  'rand_bptt': False,
#  'note_range': (9, 139),
#  'bs': 16,
#  'bptt': 256,
#  'vocab_size': 274}

# %% [markdown]
# ## Fastai Learner

# %%
# data = load_music_data(path, cache_name='tmp/sample', vocab=vocab, **config)
data = load_music_data(path/'tmp/sample', cache_name='', vocab=vocab, **config)

# %%
saved_models = get_files(path/'models', recurse=True, extensions=['.pth']); saved_models
# Out:
# [PosixPath('../../data/midi/v15/piano_duet/models/sample_train.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/tmp.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/sample_train_3.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/sample_train_2.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/sample_train_5.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/sample_train_4.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/save_s2s_1.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/unilm/all/1_ep24.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hq/2_ep40_lowerlr.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hq/1_ep40.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hq/2_60_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hq/1_ep40_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hq/2_60.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hq/2_ep40_lowerlr_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hook_c/1_ep24_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hook_c/1_ep40_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hook_c/1_ep24.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hook_c/2_24_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/hook_c/2_24.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/lq/2_ep24_cont_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/lq/1_ep24_best.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/lq/1_ep24.pth'),
#  PosixPath('../../data/midi/v15/piano_duet/models/v15m/lq/2_ep24_cont.pth')]

# %%
load_path = saved_models[-5]; load_path
# Out:
# PosixPath('../../data/midi/v15/piano_duet/models/v15m/hook_c/2_24.pth')

# %%
learn = load_music_learner(data, config.copy(), load_path)
# Out:
# False

# %%
# learn = music_model_learner(data, config.copy())

# %% [markdown]
# ## Debugging prediction values

# %%
xb,yb = data.one_batch(cpu=False)

# %%
learn.pred_batch(batch=(xb,yb))
# Out:
# tensor([[[2.6005e-05, 6.6310e-06, 1.9868e-06,  ..., 1.9813e-06,
#           1.9869e-06, 1.9891e-06],
#          [1.0236e-04, 5.9577e-07, 1.2675e-07,  ..., 1.2500e-07,
#           1.2617e-07, 1.2704e-07],
#          [5.0271e-07, 1.8509e-07, 6.4480e-08,  ..., 6.4079e-08,
#           6.4548e-08, 6.4964e-08],
#          ...,
#          [1.0518e-05, 1.6669e-06, 1.6093e-07,  ..., 1.6076e-07,
#           1.6179e-07, 1.6083e-07],
#          [3.0348e-07, 1.4310e-07, 3.0458e-08,  ..., 3.0143e-08,
#           3.0467e-08, 3.0663e-08],
#          [1.3543e-04, 2.9091e-08, 6.3267e-09,  ..., 6.2462e-09,
#           6.2705e-09, 6.1853e-09]],
#
#         [[2.6005e-05, 6.6310e-06, 1.9868e-06,  ..., 1.9813e-06,
#           1.9869e-06, 1.9891e-06],
#          [1.0236e-04, 5.9577e-07, 1.2675e-07,  ..., 1.2500e-07,
#           1.2617e-07, 1.2704e-07],
#          [5.0271e-07, 1.8509e-07, 6.4480e-08,  ..., 6.4079e-08,
#           6.4548e-08, 6.4964e-08],
#          ...,
#          [1.0518e-05, 1.6669e-06, 1.6093e-07,  ..., 1.6076e-07,
#           1.6179e-07, 1.6083e-07],
#          [3.0348e-07, 1.4310e-07, 3.0458e-08,  ..., 3.0143e-08,
#           3.0467e-08, 3.0663e-08],
#          [1.3543e-04, 2.9091e-08, 6.3267e-09,  ..., 6.2462e-09,
#           6.2705e-09, 6.1853e-09]],
#
#         [[2.6005e-05, 6.6310e-06, 1.9868e-06,  ..., 1.9813e-06,
#           1.9869e-06, 1.9891e-06],
#          [1.0236e-04, 5.9577e-07, 1.2675e-07,  ..., 1.2500e-07,
#           1.2617e-07, 1.2704e-07],
#          [5.0271e-07, 1.8509e-07, 6.4480e-08,  ..., 6.4079e-08,
#           6.4548e-08, 6.4964e-08],
#          ...,
#          [1.0518e-05, 1.6669e-06, 1.6093e-07,  ..., 1.6076e-07,
#           1.6179e-07, 1.6083e-07],
#          [3.0348e-07, 1.4310e-07, 3.0458e-08,  ..., 3.0143e-08,
#           3.0467e-08, 3.0663e-08],
#          [1.3543e-04, 2.9091e-08, 6.3267e-09,  ..., 6.2462e-09,
#           6.2705e-09, 6.1853e-09]],
#
#         ...,
#
#         [[2.6005e-05, 6.6310e-06, 1.9868e-06,  ..., 1.9813e-06,
#           1.9869e-06, 1.9891e-06],
#          [1.0236e-04, 5.9577e-07, 1.2675e-07,  ..., 1.2500e-07,
#           1.2617e-07, 1.2704e-07],
#          [5.0271e-07, 1.8509e-07, 6.4480e-08,  ..., 6.4079e-08,
#           6.4548e-08, 6.4964e-08],
#          ...,
#          [1.0518e-05, 1.6669e-06, 1.6093e-07,  ..., 1.6076e-07,
#           1.6179e-07, 1.6083e-07],
#          [3.0348e-07, 1.4310e-07, 3.0458e-08,  ..., 3.0143e-08,
#           3.0467e-08, 3.0663e-08],
#          [1.3543e-04, 2.9091e-08, 6.3267e-09,  ..., 6.2462e-09,
#           6.2705e-09, 6.1853e-09]],
#
#         [[2.6005e-05, 6.6310e-06, 1.9868e-06,  ..., 1.9813e-06,
#           1.9869e-06, 1.9891e-06],
#          [1.0236e-04, 5.9577e-07, 1.2675e-07,  ..., 1.2500e-07,
#           1.2617e-07, 1.2704e-07],
#          [5.0271e-07, 1.8509e-07, 6.4480e-08,  ..., 6.4079e-08,
#           6.4548e-08, 6.4964e-08],
#          ...,
#          [1.0518e-05, 1.6669e-06, 1.6093e-07,  ..., 1.6076e-07,
#           1.6179e-07, 1.6083e-07],
#          [3.0348e-07, 1.4310e-07, 3.0458e-08,  ..., 3.0143e-08,
#           3.0467e-08, 3.0663e-08],
#          [1.3543e-04, 2.9091e-08, 6.3267e-09,  ..., 6.2462e-09,
#           6.2705e-09, 6.1853e-09]],
#
#         [[2.6005e-05, 6.6310e-06, 1.9868e-06,  ..., 1.9813e-06,
#           1.9869e-06, 1.9891e-06],
#          [1.0236e-04, 5.9577e-07, 1.2675e-07,  ..., 1.2500e-07,
#           1.2617e-07, 1.2704e-07],
#          [5.0271e-07, 1.8509e-07, 6.4480e-08,  ..., 6.4079e-08,
#           6.4548e-08, 6.4964e-08],
#          ...,
#          [1.0518e-05, 1.6669e-06, 1.6093e-07,  ..., 1.6076e-07,
#           1.6179e-07, 1.6083e-07],
#          [3.0348e-07, 1.4310e-07, 3.0458e-08,  ..., 3.0143e-08,
#           3.0467e-08, 3.0663e-08],
#          [1.3543e-04, 2.9091e-08, 6.3267e-09,  ..., 6.2462e-09,
#           6.2705e-09, 6.1853e-09]]])

# %% [markdown]
# ## Prediction

# %%
data_dir = 'data/midi/v15/'
source_dir = 'piano_duet'
file_path = Path('../../')

csv_path = path/f'{source_dir}.csv'
csv = pd.read_csv(csv_path)
df = csv.loc[csv['numpy'].notna()];
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,1,7,10,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
keywords = 'la bamba'.replace(' ', '|')
title_filter = df['title'].str.contains('la-bamba')==True
artist_filter = df['artist'].str.contains('')==True
results = df[title_filter & artist_filter]; results.head()
results = results[results.source == 'hooktheory']; results.head()
# Out:
#                                                 song_url section  \
# 16596  https://www.hooktheory.com/theorytab/view/ritc...  chorus
#
#                                                    numpy  ht_mode  \
# 16596  piano_duet/hooktheory/pianoroll/r/ritchie-vale...      1.0
#
#                                                     midi     title  \
# 16596  midi_sources/hooktheory/pianoroll/r/ritchie-va...  la-bamba
#
#        ht_time_signature  mxl  ht_offset  ht_bpm ht_key  \
# 16596                4.0  NaN        0.0   144.0      C
#
#                                     md5 midi_title         artist    genres  \
# 16596  aeee134e4034e5f98bb630c56d2f7f8c   La Bamba  ritchie-valen  Pop,Rock
#
#         parts      source
# 16596  chorus  hooktheory

# %%
idx = 0
file = file_path/data_dir/results.numpy.values[idx]; 
# orig = file_path/data_dir/results.mxl.values[idx];
orig = file_path/data_dir/results.midi.values[idx];
file, orig
# Out:
# (PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/r/ritchie-valen/la-bamba/chorus_key_original.npy'),
#  PosixPath('../../data/midi/v15/midi_sources/hooktheory/pianoroll/r/ritchie-valen/la-bamba/chorus_key_original.mid'))

# %%
seed_len = 140
song_np = np.load(file)
seed_np = np.load(file)[:seed_len]
xb = torch.tensor(to_single_stream(seed_np, vocab=vocab))[None]
if torch.cuda.is_available(): xb = xb.cuda()

# %%
seed_stream = npenc2stream(seed_np)
seed_stream.show()

# %%
double = partial(to_double_stream, vocab=vocab)

# %%
out_s, seed_s = learn.predict(xb, n_words=400, temperatures=(1.1,0.8), min_p=1/128, min_bars=12)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Predicted BOS token. Returning prediction...

# %%
stream = npenc2stream(double(out_s))
stream.show()

# %%
out_s, seed_s = learn.predict_topk(xb, n_words=400, temperatures=(1.2,0.7), min_bars=12, top_k=40, top_p=0.9)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:11<00:00]
#     </div>

# %%
stream = npenc2stream(double(out_s))
stream.show()

# %%
stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv74467'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv74467');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
full_stream = npenc2stream(double(np.concatenate((seed_s,out_s), axis=-1)))
full_stream.show()

# %%
full_stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv62151'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv62151');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Prediction

# %%
x,y = data.one_batch(cpu=False)

# %%
out,seed = learn.predict(x, n_words=100)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:03<00:00]
#     </div>

# %%
stream = npenc2stream(double(seed))
stream.show()

# %%
stream = npenc2stream(double(out))
stream.show()

# %%
stream.show('midi')

# %% [markdown]
# ### From song

# %%
seed_len = 60
files = get_files(path/'hooktheory', extensions=['.npy'], recurse=True)

# %%
# Loading from specific file
keywords = ['third', 'eye']
def contains_keywords(f): return all([k in str(f) for k in keywords])
search = [f for f in files if contains_keywords(f)]; search
# Out:
# [PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/z/zun/satori-maiden---third-eye/verse-and-pre-chorus_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/z/zun/satori-maiden---third-eye/verse-and-pre-chorus_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/z/zun/satori-maiden---third-eye/chorus_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/z/zun/satori-maiden---third-eye/chorus_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/jumper/chorus_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/jumper/chorus_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/never-let-you-go/verse-and-pre-chorus_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/never-let-you-go/verse-and-pre-chorus_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/never-let-you-go/chorus_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/never-let-you-go/chorus_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/hows-it-going-to-be/intro_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/hows-it-going-to-be/verse_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/hows-it-going-to-be/intro_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/hows-it-going-to-be/verse_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/semi-charmed-life/intro_key_cmajor.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/semi-charmed-life/intro_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/semi-charmed-life/chorus_key_original.npy'),
#  PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/semi-charmed-life/chorus_key_cmajor.npy')]

# %%
# file = np.random.choice(files)
file = search[-2]
file
# Out:
# PosixPath('../../data/midi/v15/piano_duet/hooktheory/pianoroll/t/third-eye-blind/semi-charmed-life/chorus_key_original.npy')

# %%
#good_one = PosixPath('data/midi/v7/midi_encode/np/hook_1bar_nopos/hooktheory/c/cool-and-new-web-comic/tick---tock/chorus.npy')
# la_bamba = PosixPath('data/midi/v7/midi_encode/np/hook_1bar_nopos/hooktheory/r/ritchie-valen/la-bamba/chorus.npy')
# third_eye = PosixPath('data/midi/v7/midi_encode/np/hook_1bar_nopos/hooktheory/t/third-eye-blind/semi-charmed-life/chorus.npy')

# %%
seed_np = np.load(file)[:seed_len]
xb = torch.tensor(seed_np).cuda()[None]

# %% [markdown]
# ### Predict

# %%
out, seed = learn.predict(xb, n_words=340, temperature=.7, min_p=0.01)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='340', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-c6b679231103> in <module>
# ----> 1 out, seed = learn.predict(xb, n_words=340, temperature=.7, min_p=0.01)
#
# ~/midi_generator/src/music_transformer.py in predict(self, xb, n_words, temperature, min_p, min_bars)
#     134             running_ps = (n_words * 2 - i) / (n_words * 2)
#     135
# --> 136             res = self.pred_batch(batch=(xb,yb))[0][-1]
#     137             #if len(new_idx) == 0: self.model[0].select_hidden([0])
#     138             if min_p is not None:
#
# ~/fastai/fastai/basic_train.py in pred_batch(self, ds_type, batch, reconstruct)
#     344         cb_handler = CallbackHandler(self.callbacks)
#     345         xb,yb = cb_handler.on_batch_begin(xb,yb, train=False)
# --> 346         preds = loss_batch(self.model.eval(), xb, yb, cb_handler=cb_handler)
#     347         res = _loss_func2activ(self.loss_func)(preds[0])
#     348         if not reconstruct: return res
#
# ~/fastai/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      24     if not is_listy(xb): xb = [xb]
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#      28
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     492             result = self._slow_forward(*input, **kwargs)
#     493         else:
# --> 494             result = self.forward(*input, **kwargs)
#     495         for hook in self._forward_hooks.values():
#     496             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     492             result = self._slow_forward(*input, **kwargs)
#     493         else:
# --> 494             result = self.forward(*input, **kwargs)
#     495         for hook in self._forward_hooks.values():
#     496             hook_result = hook(self, input, result)
#
# ~/midi_generator/src/music_transformer.py in forward(self, x)
#      52             self.reset()
#      53             self.init = True
# ---> 54         bs,x_len = x.size()
#      55         inp = self.drop_emb(self.encoder(x)) #.mul_(self.d_model ** 0.5)
#      56         m_len = self.hidden[0].size(1) if hasattr(self, 'hidden') and len(self.hidden[0].size()) > 1 else 0
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ### Actual prediction

# %%
seq = npenc2seq(np.array(out))
chordarr = seq2chordarr(seq)
stream = chordarr2stream(chordarr)
# Out:
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing
# Note with 0 duration. continuing

# %%
stream.show()

# %%
stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv6557'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv6557');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Seed

# %%
seed_song = dec_arr(seed)
seed_stream = seed_song.to_stream()

# %%
seed_stream.show()

# %%
seed_stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv96214'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv96214');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
