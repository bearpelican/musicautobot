# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
os.chdir('../../../')

# %%
from musicautobot.utils.file_processing import *
from musicautobot.utils.midifile import *
from musicautobot.numpy_encode import *

# %%
import traceback
import time

# %% [markdown]
# ## Standardize and reformat raw midi files before encoding to text
# - Transform key to C major
# - Remove unused instruments
# - Combine multiple tracks with the same instrument into a single part
# - Melody, Piano, String

# %% [markdown]
# ### Load midi data

# %%
version = 'v20'
data_path = Path('data/midi')
version_path = data_path/version

# %%
import pandas as pd

# %%
# sf_path = f'sf{SAMPLE_FREQ}'
# out_dir = Path(f'{sf_path}/midi_encode')

duet_only = True
out_dir = Path('piano_duet') if duet_only else Path('midi_encode')

# %%
source_dir = 'midi_sources'
source_csv = version_path/'metadata'/f'{source_dir}.csv'
out_csv = version_path/out_dir/f'{out_dir.name}.csv'
out_csv.parent.mkdir(parents=True, exist_ok=True)
source_csv, out_csv
# Out:
# (PosixPath('data/midi/v20/metadata/midi_sources.csv'),
#  PosixPath('data/midi/v20/piano_duet/piano_duet.csv'))

# %%
# num_comps = 2 # note, duration
cutoff = 5 # max instruments
min_variation = 3 # minimum number of different midi notes played
# max_dur = 128

# %% [markdown]
# ### Encoding midi to numpy

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/musicautobot/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,4,6,11,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  title                                               midi  \
# 0  yu-gi-oh-theme-song  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 1  yu-gi-oh-theme-song  midi_sources/hooktheory/pianoroll/w/wayne-shar...
# 2               kiefer  midi_sources/hooktheory/pianoroll/w/what-a-day...
# 3         senbonzakura  midi_sources/hooktheory/pianoroll/w/whiteflame...
# 4         senbonzakura  midi_sources/hooktheory/pianoroll/w/whiteflame...
#
#        source                    parts  mxl  ht_time_signature  \
# 0  hooktheory             intro,chorus  NaN                4.0
# 1  hooktheory             intro,chorus  NaN                3.0
# 2  hooktheory                   chorus  NaN                4.0
# 3  hooktheory  verse,pre-chorus,chorus  NaN                4.0
# 4  hooktheory  verse,pre-chorus,chorus  NaN                4.0
#
#                       midi_title  ht_mode                               md5  \
# 0                      yu-gi-oh3      1.0  bf1f29e5ff84e3e93e37fb873bfb590e
# 1                       yu-gi-oh      1.0  055f80ad67f64edb14a85ca8fbfe8c29
# 2                         kiefer      6.0  197f96f5d181f6ce1e2c5ab04ac1ff87
# 3  senbonzakura - pre-Pre-Chorus      6.0  9e7ce13a35f1314423a9a6d5a5287a4a
# 4                   Senbonzakura      6.0  d5aaf79d0989222f1362f9f46c540a27
#
#       genres  ht_bpm ht_key        artist  \
# 0        NaN   128.0      C  wayne-sharpe
# 1        NaN    85.0      C  wayne-sharpe
# 2       Jazz    96.0      D    what-a-day
# 3  J-Pop,Pop   152.0      D    whiteflame
# 4  J-Pop,Pop   152.0      D    whiteflame
#
#                                             song_url     section
# 0  https://www.hooktheory.com/theorytab/view/wayn...      chorus
# 1  https://www.hooktheory.com/theorytab/view/wayn...       intro
# 2  https://www.hooktheory.com/theorytab/view/what...      chorus
# 3  https://www.hooktheory.com/theorytab/view/whit...  pre-chorus
# 4  https://www.hooktheory.com/theorytab/view/whit...       verse

# %%
all_records = df.to_dict(orient='records'); len(all_records)
# Out:
# 198757

# %%
def process_metadata(metadata):
    result = metadata.copy()
    
    # Part 1. Compress tracks/instruments
    if not isinstance(metadata.get('midi'), str): return None
    
    input_path = version_path/metadata['midi']
    extension = input_path.suffix.lower()
    if not input_path.exists(): 
        print('Input path does not exist:', input_path, metadata)
        return result
    
    # Get outfile and check if it exists
    out_file = Path(str(input_path).replace(f'/{source_dir}/', f'/{out_dir}/'))
    out_file = out_file.with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): 
        result['numpy'] = str(out_file.relative_to(version_path))
        return result
    
    npenc = transform_midi(input_path)
    if npenc is None: return result
    np.save(out_file, npenc)
    result['numpy'] = str(out_file.relative_to(version_path))
    return result

# %%
def transform_midi(midi_file):
    input_path = midi_file
    
    # Part 1: Filter out midi tracks (drums, repetitive instruments, etc.)
    try: 
        if duet_only and num_piano_tracks(input_path) not in [1, 2]: return None
        input_file = compress_midi_file(input_path, min_variation=min_variation, cutoff=cutoff) # remove non note tracks and standardize instruments
        
        if input_file is None: return None
    except Exception as e:
        if 'badly form' in str(e): return None # ignore badly formatted midi errors
        if 'out of range' in str(e): return None # ignore badly formatted midi errors
        print('Error parsing midi', input_path, e)
        return None
        
    # Part 2. Compress rests and long notes
    stream = file2stream(input_file) # 1.
    try:
        chordarr = stream2chordarr(stream) # 2. max_dur = quarter_len * sample_freq (4). 128 = 8 bars
    except Exception as e:
        print('Could not encode to chordarr:', input_path, e)
        print(traceback.format_exc())
        return None
    
    # Part 3. Compress song rests - Don't want songs with really long pauses 
    # (this happens because we filter out midi tracks).
    chord_trim = trim_chordarr_rests(chordarr)
    chord_short = shorten_chordarr_rests(chord_trim)
    delta_trim = chord_trim.shape[0] - chord_short.shape[0]
#     if delta_trim > 500: 
#         print(f'Removed {delta_trim} rests from {input_path}. Skipping song')
#         return None
    chordarr = chord_short
    
    # Part 3. Chord array to numpy
    npenc = chordarr2npenc(chordarr)
    if not is_valid_npenc(npenc, input_path=input_path):
        return None
    
    return npenc

# %%
def try_process_metadata(metadata):
    try:
        return process_metadata(metadata)
    except Exception:
#         print(traceback.format_exc())
        return None

# %%
# # sanity check
import random
for r in random.sample(all_records, 10):
    process_metadata(r)

# %%
def timeout_func(data, seconds):
    print("Timeout:", seconds, data.get('midi'))

# %%
timeout = 500
processed = process_all(try_process_metadata, all_records, timeout=timeout, timeout_func=timeout_func)
# Out:
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/w/willie-nelson/on-the-road-again/bridge_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/w/willie-nelson/on-the-road-again/verse_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/w/weebl/donkeys/intro_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/w/wolfgang-gartner/undertaker/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/w/wavves/way-too-much/intro_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/w/womack-and-womack/teardrops/intro-and-verse_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/w/wolfgang-amadeus-mozart/confutatis-from-requiem/solo-3_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/w/working-for-a-nuclear-free-city/je-suis-le-vent/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/w/weyes-blood/andromeda/verse_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/w/wilco/elt/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/w/wan-wan/sky-filling-departed-spirit---lightning-word/bridge_key_original.mid
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='198757' class='' max='198757', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [198757/198757 03:08<00:00]
#     </div>
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/y/youth-group/forever-young/chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/y/yes/ive-seen-all-good-people/bridge_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/y/yes/ive-seen-all-good-people/outro_key_original.mid
# Sequence too short: 3 data/midi/v20/midi_sources/hooktheory/pianoroll/y/ylvis/massachusetts/intro_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/y/ylvis/massachusetts/pre-chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jackson-browne/doctor-my-eyes/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/john-legend/love-me-now/bridge_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/john-legend/love-me-now/chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jackson-browne/doctor-my-eyes/chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/j/julia-holter/feel-you/pre-chorus_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/j/julia-holter/betsy-on-the-roof/verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/j/julia-holter/betsy-on-the-roof/bridge_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-wall/vigil---mass-effect-ost/intro_key_original.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jeff-liu/steven-and-the-crystal-gems/outro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jerry-lee-lewis/whole-lotta-shakin-goin-on/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jacksfilms/valentines-day-is-a-lie/verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jimi-hendrix/angel/intro_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jacksfilms/give-this-song-a-title/outro_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/j/janet-jackson/nasty/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/john-legend/love-me-now/verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/j/john-tesh/roundball-rock/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jan-and-dean/dead-mans-curve/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jason-becker/altitudes/solo-1_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/never-know/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/my-mind-is-for-sale/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/if-i-had-eyes/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/my-mind-is-for-sale/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/tape-deck/bridge_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/as-i-was-saying/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/you-and-your-heart/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/never-fade/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/you-cant-control-it/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/shot-reverse-shot/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/washing-dishes/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/breakdown/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/shot-reverse-shot/bridge_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/constellations/verse_key_original.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-white/freedom-at-21/bridge_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jill-scott/cross-my-mind/intro_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jorge-ben/errare-humanum-est/verse_key_original.mid
# Sequence too short: 3 data/midi/v20/midi_sources/hooktheory/pianoroll/j/judas-priest/breaking-the-law/chorus_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jamiroquai/canned-heat/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/j/joanna-newsom/good-intentions-paving-company/chorus_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/j/joanna-newsom/en-gallop/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/j/john-williams---harry-potter/fawkes-the-phoenix/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/j/jack-johnson/crying-shame/intro_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/g/gary-moore/still-got-the-blues/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/g/gary-jules/mad-world/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/g/godspeed-you-black-emperor/rocket-falls-on-rocket-falls/intro_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/g/gabriel-gundacker/wii-snorkling/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/g/grizzly-bear/yet-again/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/g/george-ezra/shotgun/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/g/gemini/graduation/chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/g/gemini/graduation/instrumental_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/g/gemini/fire-inside-mr-fijiwiji-remix/intro_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/g/george-mccrae/rock-your-baby/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/g/george-mccrae/rock-your-baby/bridge_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/l/little-richard/tutti-frutti/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/little-richard/long-tall-sally/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lynn-redgrave/while-im-still-young/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lindsey-stirling/beyond-the-veil/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/luke-bryan/crash-my-party/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/luke-bryan/crash-my-party/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/luke-bryan/crash-my-party/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/louis-the-child/from-here/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lady-gaga/til-it-happens-to-you/intro_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lorde/ribs/outro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/l/louisa-johnson/so-good/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/live/lightning-crashes/intro-and-verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lord-huron/the-stranger/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lord-huron/love-like-ghosts/bridge_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/led-zeppelin/thank-you/intro-and-verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lana-del-rey/never-let-me-go/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/luiz-bonfa/pernambuco/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lo-hess/never-gonna-trick-me/intro_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/l/ladi6/like-water/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lildeucedeuce/mine-turtle/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/leighton-meester/heartstrings/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/l/los-hermanos/o-vencedor/bridge_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lunice/fancy-fortie---rustie-remix/intro_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lido-and-santell/ashley/intro_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/l/lou-christie/lightnin-strikes/chorus_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/u/unknown-mortal-orchestra/so-good-at-being-in-trouble/pre-chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/u/unless/atoms-for-peace/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/u/u2/original-of-the-species/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/u/u2/love-comes-to-town/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/u/u2/love-comes-to-town/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/u/uesaka-sumire/nanatsu-no-umi-yori-kimi-no-umi/verse-and-pre-chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/v/villagers/nothing-arrived/chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/v/village-people/ymca/pre-chorus_key_original.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/v/vertical-horizon/im-still-here/chorus-lead-out_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/v/virgin-america/vxsafetydance/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/v/virgin-america/vxsafetydance/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/v/vanguart/onde-voce-parou/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/v/viper/youll-cowards-dont-even-smoke-crack/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/f/fergie/glamorous/intro_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/f/florence-and-the-machine/how-big-how-blue-how-beautiful/instrumental_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/f/frankie-goes-to-hollywood/relax/chorus_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/f/fka-twigs/hows-that/instrumental_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/f/frank-ocean/bad-religion/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/f/frank-ocean/pyramids/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/f/fiona-apple/the-child-is-gone/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/f/fiona-apple/the-child-is-gone/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/f/flow/cha-la-head-cha-la---dragon-ball-z-opening/outro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/f/foreign-air/chakra-daemon/pre-outro_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/f/filthy-frank/weeaboo-song/intro_key_original.mid
# Sequence too short: 3 data/midi/v20/midi_sources/hooktheory/pianoroll/f/frankie-valli/the-night/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/f/faul---wad-ad-vs-pnau/changes/verse_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/f/francoise-hardy/la-question/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/f/foxygen/no-destruction/pre-chorus_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/f/fort-minor/welcome/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/f/foo-fighters/the-sky-is-a-neighborhood/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/f/faith-no-more/epic/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/f/foster-the-people/pseudologia-fantastica/pre-chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/f/foster-the-people/pseudologia-fantastica/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/f/foster-the-people/pseudologia-fantastica/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bigbang/bae-bae/verse_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/new-seeds/chorus_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/new-seeds/outro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/an-eagle-in-your-mind/instrumental_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/in-a-beautiful-place-out-in-the-country/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/cold-earth/verse_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/olson/outro_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/music-is-math/intro-and-verse_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/corsair/verse_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/dayvan-cowboy/instrumental_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/boards-of-canada/sixtyniner/chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bear-mccreary/roslin-and-adama/bridge_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/b/ben-harper/steal-my-kisses/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bent-van-looy/flowers-and-balloons/outro-2_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bent-van-looy/flowers-and-balloons/outro-1_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/booka-shade/love-inc/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/belle-and-sebastian/the-stars-of-track-and-field/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/belle-and-sebastian/like-dylan-in-the-movies/chorus_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bread/diary/intro_key_original.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/b/birds-of-tokyo/plans/bridge_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bird/bird/verse_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/b/brad-paisley/time-well-wasted/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/brad-paisley/shes-everything/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beirut/a-sunday-smile/intro-and-verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bill-brown/windows-xp-startup-sound/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bee-gees/to-love-somebody/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bee-gees/to-love-somebody/chorus_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bee-gees/fanny-be-tender-with-my-love/bridge_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bubbles-and-the-shitrockers/liquor-and-whores/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bubbles-and-the-shitrockers/liquor-and-whores/solo_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bubbles-and-the-shitrockers/liquor-and-whores/chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bubbles-and-the-shitrockers/liquor-and-whores/verse_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/master-of-none/chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/the-traveller/verse_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/holy-dances/pre-chorus_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/the-traveller/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/holy-dances/chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/elegy-to-the-void/chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/home-again/chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/elegy-to-the-void/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/zebra/pre-chorus_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/tokyo-witch/outro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/zebra/verse_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/better-times/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/norway/chorus_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/myth/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/shes-so-lovely/verse_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/lovelier-girl/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/gila/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/myth/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/gila/verse_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bruno-mars/young-girls-live/outro_key_original.mid
# Sequence too short: 26 data/midi/v20/midi_sources/hooktheory/pianoroll/b/big-joe-turner/shake-rattle-and-roll/verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/b/brand-new/soco-amaretto-lime/intro_key_original.mid
# Sequence too short: 26 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bridget-st-john/city-crazy/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/b/bayside/mona-lisa/intro_key_original.mid
# Sequence too short: 26 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/heart-of-chambers/pre-chorus_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beyonce/resentment/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/b/beach-house/equal-mind/chorus_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zedd/done-with-love/bridge_key_original.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zero-7/home/chorus-lead-out_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zero-7/the-space-between/chorus_key_original.mid
# Sequence too short: 3 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zun/fall-of-fall---autumnal-waterfall/lead-in_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zun/locked-girl---the-girls-secret-room/pre-chorus_key_original.mid
# Sequence too short: 14 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zun/fall-of-fall---autumnal-waterfall/lead-in-alt_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zun/eternal-shrine-maiden/outro_key_original.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/z/zun/maniacal-princess/pre-chorus_key_original.mid
# Sequence too short: 22 data/midi/v20/midi_sources/hooktheory/pianoroll/d/de-embryos/respect/chorus_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/d/der-tourist/supergeil/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/d/deerhunter/ad-astra/verse_key_original.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dirty-vegas/days-go-by---acoustic/verse_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/d/david-holmes/rodney-yates/instrumental_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/d/duke-ellington/c-jam-blues/verse_key_original.mid
# Sequence too short: 3 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dire-straits/money-for-nothing/chorus-lead-out_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/d/deftones/minerva/intro-and-verse_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/d/desree/kissing-you/intro_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/d/drake/childs-play/intro-and-verse_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dinosaur-jr/tiny/intro-and-verse_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dinosaur-jr/tiny/chorus_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dinosaur-jr/tiny/bridge_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/d/destinys-child/say-my-name---cosmos-midnight-bootleg/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dispatch/the-general/verse_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dixie-chicks/if-i-fall-youre-going-down-with-me/pre-chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dungen/festival/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/d/david-guetta/what-i-did-for-love/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/d/d-nox-and-beckers/the-cave---original-mix/instrumental_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/d/duda-beat/todo-carinho/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dangelo/aint-that-easy/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dangelo/aint-that-easy/pre-chorus_key_original.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/d/david-bowie/starman/pre-chorus_key_original.mid
# Sequence too short: 22 data/midi/v20/midi_sources/hooktheory/pianoroll/d/david-bowie/fame/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/d/digitalism/blitz/intro_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/d/daft-punk/voyager/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dean-blunt/demon/verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dirty-projectors/impregnable-question/pre-chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/d/dirty-projectors/impregnable-question/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/d/deadmau5/i-remember/intro_key_original.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/d/disney/something-there---beauty-and-the-beast/intro_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/d/derrick-harriot/let-me-down-easy/verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/d/disasterpeace/fez---pressure/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/x/xxxtentacion/orlando/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/x/xxxtentacion/revenge/intro_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/s/stan-getz---joao-gilberto/the-girl-from-ipanema/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/stephen/crossfire/verse_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sofa-surfers/sofa-rockers/verse_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/s/stupeflip/crou-anthem/chorus_key_original.mid
# Sequence too short: 13 data/midi/v20/midi_sources/hooktheory/pianoroll/s/saves-the-day/she/outro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/s/star-control-ii-soundtrack/hyperspace/verse_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/s/star-control-ii-soundtrack/hyperspace/intro_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/s/schoolhouse-rock/my-hero-zero/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/spice-girls/goodbye/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sara-bareilles/love-song/verse_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sara-bareilles/bottle-it-up/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sara-bareilles/bottle-it-up/chorus_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/s/soundprank/a-single-many---shingo-nakamura-remix/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/survivor/eye-of-the-tiger/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/s/singularity/horizon/intro_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/s/stevie-ray-vaughn/lenny/intro-and-verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/s/soul-asylum/runaway-train/pre-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/switchfoot/all-i-need/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/switchfoot/your-love-is-a-song/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sufjan-stevens/jupiter-winter/intro_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sufjan-stevens/should-have-known-better/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sufjan-stevens/the-black-hawk-war-or-how-to-demolish-an-entire/intro_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sufjan-stevens/fourth-of-july/verse_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sufjan-stevens/john-my-beloved/intro_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sufjan-stevens/fourth-of-july/intro_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sufjan-stevens/john-wayne-gacy-jr/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sleeping-with-sirens/if-you-cant-hang/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/s/shiina-ringo/rain-in-the-darkness/intro_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/s/stereophonics/maybe-tomorrow/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sex-bob-omb/garbage-truck/verse_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/s/scott-walker/copenhagen/pre-chorus_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/s/scott-walker/copenhagen/intro_key_original.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/s/scott-walker/rosemary/verse_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/s/scott-walker/copenhagen/chorus-lead-out_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sega/sonic-lost-world---sea-bottom-segue/intro_key_original.mid
# Sequence too short: 4 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sega/gene-gadget-zone-act-1---sonic-3d-%2528saturn%2529/intro_key_original.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sega/and-fish-hits/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sega/seaside-hill-zone/chorus-lead-out_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sega/ice-cap-zone/verse_key_original.mid
# Sequence too short: 21 data/midi/v20/midi_sources/hooktheory/pianoroll/s/solar-fields/mirrors-edge---the-shard-puzzle/instrumental_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/s/slowdive/40-days/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/slowdive/star-roving/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sash/stop-pushin/intro_key_original.mid
# Sequence too short: 3 data/midi/v20/midi_sources/hooktheory/pianoroll/s/steve-earle/copperhead-road/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/slint/good-morning-captain/intro_key_original.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/s/steve-earle/copperhead-road/intro-and-verse_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/s/shinedown/shed-some-light/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/s/sonia-leigh/put-it-in-your-pocket/chorus_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/s/say-anything/shiksa/verse_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/s/say-anything/every-man-has-a-molly/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/c/carne-doce/amigo-dos-bichos/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/carne-doce/amiga/bridge_key_original.mid
# Sequence too short: 22 data/midi/v20/midi_sources/hooktheory/pianoroll/c/carne-doce/ideia/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/s/say-anything/attaboy/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/s/steve-jablonsky/lone-survivor/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/carne-doce/cliche-depre/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/c/carne-doce/amigo-dos-bichos/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/cashmere-cat/adore/instrumental_key_original.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/c/cloud-nothings/quieter-today/intro_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/s/steve-jablonsky/bumblebee/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/c/coldplay/a-rush-of-blood-to-the-head/bridge_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/c/childish-gambino/telegraph-ave-oakland-by-lloyd/chorus_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/c/childish-gambino/sober/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/c/carolina-liar/show-me-what-im-looking-for/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/canaan-smith/love-you-like-that/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/clown-core/google-your-own-death/chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/c/chuck-berry/johnny-b-goode/chorus_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/c/cave-story/pulse/verse_key_original.mid
# Sequence too short: 21 data/midi/v20/midi_sources/hooktheory/pianoroll/c/connan-mockasin/im-the-man-that-will-find-you-alternate/intro-and-verse_key_original.mid
# Sequence too short: 21 data/midi/v20/midi_sources/hooktheory/pianoroll/c/connan-mockasin/im-the-man-that-will-find-you/intro-and-verse_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/c/caro-emerald/a-night-like-this/verse_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/c/charlotte-gainsbourg/hey-joe-/verse_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/c/cults/always-forever/chorus_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/c/capcom/okami---yami/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/c/capcom/okami---yami/intro-and-verse_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/c/chris-de-burgh/lady-in-red/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/c/ceoma-feat-the-larx/love-is-more--rob-mayth-remix-/bridge_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/c/cat-stevens/wild-world/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/carrie-underwood/before-he-cheats/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/c/captain-hollywood-project/odyssey-of-emotions/instrumental_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/c/camera-obscura/if-looks-could-kill/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/counting-crows/anna-begins/chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/counting-crows/round-here/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/clint-mansell/leaving-earth-/intro_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/c/coda/bloody-stream/outro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/citizens/in-tenderness/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/c2c/the-beat/chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/c/chumbawamba/amnesia/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/c/christopher-tin/mado-kara-mieru/chorus-lead-out_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/c/crash-kings/mountain-man/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/c/cut-copy/where-im-going/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eric-clapton/you-look-wonderful-tonight/verse_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/e/everything-but-the-girl/downtown-train/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/e/everything-but-the-girl/missing/intro_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eric-clapton/i-shot-the-sheriff/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eric-hutchinson/rock-and-roll/chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/e/exuma/the-vision/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/e/evanescence/haunted/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/e/elton-john/love-song/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/e/es-posthumus/antissa/chorus-lead-out_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/c/cave-story/pulse/chorus_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/e/evanescence/going-under/pre-chorus_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/e/elton-john/dont-let-the-sun-go-down-on-me/intro_key_original.mid
# Sequence too short: 26 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eric-whitacre/fly-to-paradise/chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eminem/desperation---ft-jamie-n-commons/chorus_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eden/forever-over/verse_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eden/forever-over/chorus_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/e/earth-wind-and-fire/sun-goddess/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/e/earth-wind-and-fire/fall-in-love-with-me/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/e/elvis-presley/hound-dog/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/e/eagle-eye-cherry/save-tonight/intro_key_original.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nicola-conte-/jet-sounds---thievery-corporation-remix/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/n/naomi/three-stars-no-match/intro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/n/noiseworks/take-me-back/chorus_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/n/ninja-sex-party/orgy-for-one/pre-chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/n/natalie-imbruglia/torn/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/closer/outro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/e/evermore/running/bridge_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/n/niki-and-the-dove/tomorrow/verse_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/n/niki-and-the-dove/tomorrow/chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/n/niki-and-the-dove/tomorrow/pre-chorus_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-becoming/bridge_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nouvelle-vague/this-is-not-a-love-song/intro_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nine-inch-nails/the-downward-spiral/intro-and-verse_key_original.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/n/napalm-death/you-suffer/pre-chorus-and-chorus_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nirvana/polly/intro_key_original.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/n/naoko-mitome-and-chika-sekigawa/the-ultimate-show---super-paper-mario-ost/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nobuyoshi-sano/grip---ridge-racer-2/bridge_key_original.mid
# Sequence too short: 26 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nitrous-oxide/amnesia/chorus_key_original.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nathan-ford/for-better-or-worse---ending/outro_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nicky-tuckova/rich-boy/chorus_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nintendo/donkey-kong/intro_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nintendo/dark-matter/chorus_key_original.mid
# Sequence too short: 21 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nintendo/mario-kart-7---rainbow-road/intro_key_original.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/n/nintendo/rainbow-road---mario-kart-8/bridge_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/i/iggy-pop/the-passenger/intro_key_original.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/n/neru/the-disease-called-love/intro_key_original.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/i/inon-zur/fallout-4-intro/instrumental_key_original.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/i/inon-zur/fallout-4-main-theme/intro_key_original.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/i/iamamiwhoami/fountain/pre-chorus_key_original.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/i/inverted-silence/fusion/bridge_key_original.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/i/ian-livingston/flooded-lowlands/verse_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/i/israel-kamakawiwoole/somewhere-over-the-rainbow/bridge_key_original.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/i/instrumental-core/free-run/intro_key_original.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/i/icona-pop/i-love-it/chorus_key_original.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/i/illenium/leaving---ft-eden/intro_key_original.mid
# ...
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/k/king-gizzard-and-the-lizard-wizard/evil-death-roll/pre-chorus_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kelly-clarkson/already-gone/pre-chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kenny-chesney/the-road-and-the-radio/verse_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kasbo/kaleidoscope/verse_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/k/koven-and-memtrix/pessimist/intro_key_cmajor.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kazoo-kid/special-friends/intro_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kanye-west/yikes/verse_key_cmajor.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kanye-west/all-mine/instrumental_key_cmajor.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kanye-west/all-mine/intro_key_cmajor.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/k/konami/super-castlevania-4---forest-of-monsters/intro-and-verse_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kasabian/la-fee-verte/intro-and-verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kasey-chambers/the-captain/verse_key_cmajor.mid
# Sequence too short: 14 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kendrick-lamar/fear/instrumental_key_cmajor.mid
# Sequence too short: 21 data/midi/v20/midi_sources/hooktheory/pianoroll/k/kaskade/4am-adam-k-and-soha-mix/intro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/r/regina-spektor/laughing-with/intro_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/r/rage-against-the-machine/killing-in-the-name-of/intro_key_cmajor.mid
# Sequence too short: 21 data/midi/v20/midi_sources/hooktheory/pianoroll/r/rodriguez/sugar-man/intro_key_cmajor.mid
# Sequence too short: 22 data/midi/v20/midi_sources/hooktheory/pianoroll/r/rush/yyz/intro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/r/rush/red-barchetta/verse_key_cmajor.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/r/really-slow-motion/endlessness/pre-chorus_key_cmajor.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/r/restorations/d/intro-and-verse_key_cmajor.mid
# Sequence too short: 26 data/midi/v20/midi_sources/hooktheory/pianoroll/r/r-e-m/shiny-happy-people/pre-chorus_key_cmajor.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/r/robert-j-lake/hivebent-anthem/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/r/radix/yuki-satellites/outro_key_cmajor.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/r/royksopp/what-else-is-there/instrumental_key_cmajor.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/r/rilo-kiley/breakin-up/pre-chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/r/rilo-kiley/silver-lining/verse_key_cmajor.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/m/michael-feiner/bababa---hardwell-edit/chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/my-bloody-valentine/loomer/intro_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/m/my-bloody-valentine/to-here-knows-when/chorus_key_cmajor.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/m/my-bloody-valentine/honey-power/verse_key_cmajor.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mitis/living-color/intro_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mahotella-queens/saphel-isizwe/chorus_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/m/manu-chao/bongo-bong/intro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mason-vs-princess-superstar/perfect-exceeder/chorus_key_cmajor.mid
# Sequence too short: 21 data/midi/v20/midi_sources/hooktheory/pianoroll/m/masashi-kageyama/good-morning---gimmick/outro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/madeon/home-%2528live%2529/pre-chorus_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/m/men-at-work/land-down-under/intro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/my-bloody-valetine/loomer/verse_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/m/metallica/fade-to-black/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/motley-crue/home-sweet-home/intro-and-verse_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mac-demarco/brother/chorus_key_cmajor.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mac-demarco/brother/verse_key_cmajor.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mac-demarco/brother/pre-chorus_key_cmajor.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mac-demarco/let-my-baby-stay/intro_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/m/metric/gimme-sympathy/pre-chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/michael-buble/havent-met-you-yet/pre-chorus_key_cmajor.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/m/matt-corby/resolution/chorus_key_cmajor.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/m/madonna/beautiful-stranger/verse_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mumford-and-sons/sigh-no-more/bridge_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mumford-and-sons/lover-of-the-light/chorus_key_cmajor.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/m/microsoft/windows-xp-startup-sound/instrumental_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/melodys-echo-chamber/shirim/chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/melodys-echo-chamber/some-time-alone-alone/chorus_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/m/melodys-echo-chamber/bisou-magique/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/melodys-echo-chamber/shirim/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/melodys-echo-chamber/you-wont-be-missing-that-part-of-me/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/melodys-echo-chamber/endless-shore/chorus_key_cmajor.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/m/michael-boddicker/buckaroo-banzai-team-march/chorus_key_cmajor.mid
# Sequence too short: 13 data/midi/v20/midi_sources/hooktheory/pianoroll/m/masashi-hamauzu/battle-results/pre-chorus-and-chorus_key_cmajor.mid
# Sequence too short: 25 data/midi/v20/midi_sources/hooktheory/pianoroll/m/miike-snow/sans-soleil/intro_key_cmajor.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/m/miley-cyrus/we-cant-stop/intro_key_cmajor.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/m/minutemen/there-aint-shit-on-tv-tonight/verse_key_cmajor.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/m/michael-kiwanuka/bones/chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/michael-kiwanuka/bones/pre-chorus_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/m/muzzy/junction-seven/verse_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/m/martin-solveig/do-it-right/intro_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mrsimon/constant/intro_key_cmajor.mid
# Sequence too short: 20 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mark-isham/sense-of-touch/bridge_key_cmajor.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mark-isham/sense-of-touch/verse_key_cmajor.mid
# Sequence too short: 30 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mark-isham/sense-of-touch/outro_key_cmajor.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/m/matrix-soundtrack/clubbed-to-death/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/metronomy/she-wants/pre-chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/metronomy/she-wants/chorus_key_cmajor.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/m/mark-knopfler/boom-like-that/bridge_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/m/marian-hill/down/intro_key_cmajor.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/m/masaharu-iwata/over-horizon---stage-2/outro_key_cmajor.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/m/milow/ayo-technology/instrumental_key_cmajor.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/q/queen/play-the-game/verse_key_cmajor.mid
# Sequence too short: 28 data/midi/v20/midi_sources/hooktheory/pianoroll/q/queen/bohemian-rhapsody/pre-chorus-and-chorus_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/q/queen/we-will-rock-you/chorus_key_cmajor.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/a/ashlee-simpson/pieces-of-me/pre-chorus_key_cmajor.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alex-lloyd/amazing/intro_key_cmajor.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/a/asgeir/king-and-cross/intro_key_cmajor.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/a/a-lovely-war/autumn-leaves-us-blue/chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alvvays/in-undertow/verse_key_cmajor.mid
# Sequence too short: 3 data/midi/v20/midi_sources/hooktheory/pianoroll/a/axwell-and-ingrosso/something-new-/intro_key_cmajor.mid
# Sequence too short: 22 data/midi/v20/midi_sources/hooktheory/pianoroll/a/akito-nakatsuka/zelda-ii---the-adventure-of-link---village/intro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/aphex-twin/bucephalus-bouncing-ball/instrumental_key_cmajor.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/outro_key_cmajor.mid
# Sequence too short: 24 data/midi/v20/midi_sources/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-3_key_cmajor.mid
# Sequence too short: 29 data/midi/v20/midi_sources/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-2_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/angus-and-julia-stone/big-jet-plane/chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/azymuth/cascade-of-the-seven-waterfalls/intro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/angus-and-julia-stone/big-jet-plane/bridge_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/angus-and-julia-stone/big-jet-plane/verse_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/a/air/all-i-need/intro_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/reflektor/bridge_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/wake-up/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/neighborhood-2-laika/chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/here-comes-the-night-time/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/neighborhood-2-laika/verse_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/no-cars-go/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/porno/chorus_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/arcade-fire/haiti/verse_key_cmajor.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/a/avicii/speed---burn-and-lotus-f1-team-mix/chorus_key_cmajor.mid
# Sequence too short: 17 data/midi/v20/midi_sources/hooktheory/pianoroll/a/anamanaguchi/the-dark-one/verse_key_cmajor.mid
# Sequence too short: 22 data/midi/v20/midi_sources/hooktheory/pianoroll/a/art-of-trance/blue-owl/intro_key_cmajor.mid
# Sequence too short: 7 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alan-braxe---fred-falke/rubicon/intro_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/a/absynthe-minded/end-of-the-line/intro-and-verse_key_cmajor.mid
# Sequence too short: 11 data/midi/v20/midi_sources/hooktheory/pianoroll/a/audien/wayfarer/intro_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alice-francis/shoot-him-down/intro_key_cmajor.mid
# Sequence too short: 26 data/midi/v20/midi_sources/hooktheory/pianoroll/a/a-tribe-called-quest/word-play/instrumental_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alabama-shakes/gimme-all-your-love/bridge_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alabama-shakes/dunes/verse_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alabama-shakes/this-feeling/verse_key_cmajor.mid
# Sequence too short: 19 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alabama-shakes/sound-and-color/verse_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alabama-shakes/future-people/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alexi-murdoch/orange-sky/verse_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alabama-shakes/heartbreaker/chorus_key_cmajor.mid
# Sequence too short: 15 data/midi/v20/midi_sources/hooktheory/pianoroll/a/avril-lavigne/when-youre-gone/pre-chorus_key_cmajor.mid
# Sequence too short: 27 data/midi/v20/midi_sources/hooktheory/pianoroll/a/avril-lavigne/when-youre-gone/intro_key_cmajor.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/a/alabama-3/woke-up-this-morning/outro_key_cmajor.mid
# Sequence too short: 23 data/midi/v20/midi_sources/hooktheory/pianoroll/a/avril-lavigne/keep-holding-on/intro_key_cmajor.mid
# Sequence too short: 16 data/midi/v20/midi_sources/hooktheory/pianoroll/a/aly-and-aj/rush/verse_key_cmajor.mid
# Sequence too short: 31 data/midi/v20/midi_sources/hooktheory/pianoroll/a/absynthe-minded/papillon/intro-and-verse_key_cmajor.mid
# Sequence too short: 22 data/midi/v20/midi_sources/hooktheory/pianoroll/a/au5/tendril-ft-collin-mcloughlin/instrumental_key_cmajor.mid
# Sequence too short: 18 data/midi/v20/midi_sources/hooktheory/pianoroll/a/above-and-beyond/prelude/verse_key_cmajor.mid
# Timeout: 50 midi_sources/130k_reddit/D/D/dou_01.mid

# %%
arr2csv(processed, out_csv); len(processed)
# Out:
# 197902

# %%
df = pd.read_csv(out_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/musicautobot/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,3,4,7,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                      parts  ht_time_signature  \
# 0             intro,chorus                4.0
# 1             intro,chorus                3.0
# 2                   chorus                4.0
# 3  verse,pre-chorus,chorus                4.0
# 4  verse,pre-chorus,chorus                4.0
#
#                                                 midi     section  \
# 0  midi_sources/hooktheory/pianoroll/w/wayne-shar...      chorus
# 1  midi_sources/hooktheory/pianoroll/w/wayne-shar...       intro
# 2  midi_sources/hooktheory/pianoroll/w/what-a-day...      chorus
# 3  midi_sources/hooktheory/pianoroll/w/whiteflame...  pre-chorus
# 4  midi_sources/hooktheory/pianoroll/w/whiteflame...       verse
#
#                       midi_title                title  \
# 0                      yu-gi-oh3  yu-gi-oh-theme-song
# 1                       yu-gi-oh  yu-gi-oh-theme-song
# 2                         kiefer               kiefer
# 3  senbonzakura - pre-Pre-Chorus         senbonzakura
# 4                   Senbonzakura         senbonzakura
#
#                                                numpy  mxl  ht_bpm  \
# 0  piano_duet/hooktheory/pianoroll/w/wayne-sharpe...  NaN   128.0
# 1  piano_duet/hooktheory/pianoroll/w/wayne-sharpe...  NaN    85.0
# 2  piano_duet/hooktheory/pianoroll/w/what-a-day/k...  NaN    96.0
# 3  piano_duet/hooktheory/pianoroll/w/whiteflame/s...  NaN   152.0
# 4  piano_duet/hooktheory/pianoroll/w/whiteflame/s...  NaN   152.0
#
#                                 md5      source        artist ht_key  ht_mode  \
# 0  bf1f29e5ff84e3e93e37fb873bfb590e  hooktheory  wayne-sharpe      C      1.0
# 1  055f80ad67f64edb14a85ca8fbfe8c29  hooktheory  wayne-sharpe      C      1.0
# 2  197f96f5d181f6ce1e2c5ab04ac1ff87  hooktheory    what-a-day      D      6.0
# 3  9e7ce13a35f1314423a9a6d5a5287a4a  hooktheory    whiteflame      D      6.0
# 4  d5aaf79d0989222f1362f9f46c540a27  hooktheory    whiteflame      D      6.0
#
#       genres                                           song_url
# 0        NaN  https://www.hooktheory.com/theorytab/view/wayn...
# 1        NaN  https://www.hooktheory.com/theorytab/view/wayn...
# 2       Jazz  https://www.hooktheory.com/theorytab/view/what...
# 3  J-Pop,Pop  https://www.hooktheory.com/theorytab/view/whit...
# 4  J-Pop,Pop  https://www.hooktheory.com/theorytab/view/whit...

# %%
len([s for s in df.midi.values if isinstance(s, str)])
# Out:
# 197902

# %%
len([s for s in df.numpy.values if isinstance(s, str)])
# Out:
# 113111

# %%
from collections import Counter

# %%
Counter(df[df.midi.notnull()].source.values)
# Out:
# Counter({'hooktheory': 20544,
#          'freemidi': 5168,
#          'midiworld': 4108,
#          'ecomp': 2533,
#          'cprato': 312,
#          'classical_piano': 328,
#          'classical_archives': 14647,
#          'musescore': 10933,
#          'wikifonia': 6346,
#          'lmd': 13565,
#          'reddit': 98673,
#          'hooktheory_c': 20745})

# %%
Counter(df[df.numpy.notnull()].source.values)
# Out:
# Counter({'hooktheory': 19874,
#          'freemidi': 1872,
#          'midiworld': 1771,
#          'ecomp': 2533,
#          'cprato': 214,
#          'classical_piano': 327,
#          'classical_archives': 4883,
#          'musescore': 9195,
#          'wikifonia': 3912,
#          'lmd': 5017,
#          'reddit': 43485,
#          'hooktheory_c': 20028})
