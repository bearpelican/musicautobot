# %% [markdown]
# ## Building flask api

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '../../')

# %%
from src.serve import *
# Out:
# Failed to load FluidSynth. Must install if you want to convert to wav files.

# %%
np.set_printoptions(edgeitems=10, threshold=40, linewidth=200)

# %%
data_dir = 'data/midi/v9/'
source_dir = 'midi_encode/np/shortdur'

file_path = Path('../../')
path = file_path/data_dir/source_dir
out_path = file_path/'data/generated/'

# %% [markdown]
# ## Learn config

# %%
config = get_config(vocab_path=path/'tmp/all'); config
# Out:
# {'ctx_len': 150,
#  'n_layers': 12,
#  'n_heads': 10,
#  'd_model': 256,
#  'd_head': 41,
#  'd_inner': 2100,
#  'resid_p': 0.1,
#  'attn_p': 0.1,
#  'ff_p': 0.1,
#  'embed_p': 0.1,
#  'output_p': 0.1,
#  'bias': False,
#  'scale': True,
#  'act': <Activation.GeLU: 3>,
#  'double_drop': True,
#  'tie_weights': True,
#  'out_bias': True,
#  'init': <function fastai.text.models.transformer.init_transformer(m)>,
#  'mem_len': 512,
#  'mask': True,
#  'emb_map': [(0, 130, 128), (1, 132, 128)],
#  'idx_map': {0: (0, 130, 128), 1: (1, 132, 128)},
#  'loss_weights': [1, 1],
#  'pad_idx': 0,
#  'bos_idx': 2,
#  'enc_offset': 3,
#  'transpose_range': (0, 12),
#  'mask_type': <MaskType.RandomWindow: 3>,
#  'bs': 16,
#  'bptt': 256}

# %%
data = load_data(path=path, cache_name='tmp/hook', **config)

# %%
saved_models = get_files(path/'models/hook', recurse=True); saved_models
load_path = saved_models[0]

# %%
htlist = get_htlist(path, source_dir, use_cache=False)
# Out:
# /Users/andrewshaw/miniconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (1,4,15,18,19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
learn = load_learner(data, config, load_path)

# %%
# import pickle
# f = open("test_config.pkl","wb")
# pickle.dump(config,f)
# f.close()

# %% [markdown]
# ### Songs

# %%
htlist
# Out:
# {'5455066523491398578': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/above-and-beyond/anjunabeach',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Anjunabeach',
#   'title': 'Anjunabeach',
#   'seconds': 58.18181818181818,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/above-and-beyond/anjunabeach/chorus_key_cmajor.mid',
#   'inferred_key': 'D minor',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 66.0,
#   'artist': 'Above And Beyond',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 66.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/above-and-beyond/anjunabeach/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/above-and-beyond/anjunabeach/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/above-and-beyond/anjunabeach/chorus_key_cmajor.npy',
#   'sid': 5455066523491398578},
#  '4688764683065228625': {'inferred_offset': 5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aylictal/aeon',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'aeon',
#   'title': 'Aeon',
#   'seconds': 27.42857142857143,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aylictal/aeon/chorus_key_cmajor.mid',
#   'inferred_key': 'E minor',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 140.0,
#   'artist': 'Aylictal',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 140.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/aylictal/aeon/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/aylictal/aeon/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/aylictal/aeon/chorus_key_cmajor.npy',
#   'sid': 4688764683065228625},
#  '-2416872709557099391': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/antonim/melancholy-soldier',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Antonim',
#   'title': 'Melancholy Soldier',
#   'seconds': 26.503067484662576,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/antonim/melancholy-soldier/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '72.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 163.0,
#   'artist': 'Antonim',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 163.0,
#   'section': 'chorus',
#   'parts': 'intro,verse,pre-chorus,chorus,bridge',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/antonim/melancholy-soldier/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/antonim/melancholy-soldier/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 289.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/antonim/melancholy-soldier/chorus_key_cmajor.npy',
#   'sid': -2416872709557099391},
#  '-9031345656870404659': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/au5/snowblind-feat-tasha-baxter',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Snowblind feat Tasha Baxter',
#   'title': 'Snowblind Feat Tasha Baxter',
#   'seconds': 13.91304347826087,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/au5/snowblind-feat-tasha-baxter/intro_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 138.0,
#   'artist': 'Au5',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 138.0,
#   'section': 'intro',
#   'parts': 'intro',
#   'genres': 'Electronic,Pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/au5/snowblind-feat-tasha-baxter/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/au5/snowblind-feat-tasha-baxter/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/au5/snowblind-feat-tasha-baxter/intro_key_cmajor.npy',
#   'sid': -9031345656870404659},
#  '-8056341987307306796': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aylictal/still-waters-run-deep',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'still waters run deep',
#   'title': 'Still Waters Run Deep',
#   'seconds': 30.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aylictal/still-waters-run-deep/verse_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Aylictal',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'verse',
#   'parts': 'verse',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/aylictal/still-waters-run-deep/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/aylictal/still-waters-run-deep/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/aylictal/still-waters-run-deep/verse_key_cmajor.npy',
#   'sid': -8056341987307306796},
#  '6646318165853084443': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alice-in-chains/your-decision',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Your Decision 1',
#   'title': 'Your Decision',
#   'seconds': 37.28155339805825,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alice-in-chains/your-decision/verse_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 103.0,
#   'artist': 'Alice In Chains',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 103.0,
#   'section': 'verse',
#   'parts': 'verse,pre-chorus,chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alice-in-chains/your-decision/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alice-in-chains/your-decision/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alice-in-chains/your-decision/verse_key_cmajor.npy',
#   'sid': 6646318165853084443},
#  '8958734742542429952': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alice-deejay/better-off-alone',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Better off Alone',
#   'title': 'Better Off Alone',
#   'seconds': 15.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alice-deejay/better-off-alone/verse_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Alice Deejay',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'verse',
#   'parts': 'verse,chorus',
#   'genres': 'Dance,Electronic,Pop,Techno',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alice-deejay/better-off-alone/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alice-deejay/better-off-alone/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alice-deejay/better-off-alone/verse_key_cmajor.npy',
#   'sid': 8958734742542429952},
#  '-675805988111590392': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/animation-domination-high-def/the-singularity-song',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'The Singularity Song',
#   'title': 'The Singularity Song',
#   'seconds': 24.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/animation-domination-high-def/the-singularity-song/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '40.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 100.0,
#   'artist': 'Animation Domination High Def',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 100.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Country',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/animation-domination-high-def/the-singularity-song/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/animation-domination-high-def/the-singularity-song/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 161.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/animation-domination-high-def/the-singularity-song/chorus_key_cmajor.npy',
#   'sid': -675805988111590392},
#  '-798516109602885975': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/avicii/broken-arrows',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Broken Arrows',
#   'title': 'Broken Arrows',
#   'seconds': 68.27586206896552,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/avicii/broken-arrows/intro-and-verse_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '132.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 116.0,
#   'artist': 'Avicii',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 116.0,
#   'section': 'intro-and-verse',
#   'parts': 'intro-and-verse',
#   'genres': 'Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/avicii/broken-arrows/intro-and-verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/avicii/broken-arrows/intro-and-verse_key_cmajor.npz',
#   'midi_npz_timesteps': 529.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/avicii/broken-arrows/intro-and-verse_key_cmajor.npy',
#   'sid': -798516109602885975},
#  '-5393522201688710733': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/airplane-mode/dance-like-you-mean-it',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Dance Like You Mean It',
#   'title': 'Dance Like You Mean It',
#   'seconds': 26.12244897959184,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/airplane-mode/dance-like-you-mean-it/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 147.0,
#   'artist': 'Airplane Mode',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 147.0,
#   'section': 'chorus',
#   'parts': 'verse,chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/airplane-mode/dance-like-you-mean-it/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/airplane-mode/dance-like-you-mean-it/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/airplane-mode/dance-like-you-mean-it/chorus_key_cmajor.npy',
#   'sid': -5393522201688710733},
#  '3963217634293301644': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/ac-dc/back-in-black',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Back In Black',
#   'title': 'Back In Black',
#   'seconds': 10.434782608695652,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/ac-dc/back-in-black/verse_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '16.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 92.0,
#   'artist': 'Ac Dc',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 92.0,
#   'section': 'verse',
#   'parts': 'verse',
#   'genres': 'Rock',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/ac-dc/back-in-black/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/ac-dc/back-in-black/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 65.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/ac-dc/back-in-black/verse_key_cmajor.npy',
#   'sid': 3963217634293301644},
#  '-7374215232790855900': {'inferred_offset': 5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aivi-tran-and-steven-surasshu-velema/dance-of-swords---steven-universe',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Dance of Swords 2',
#   'title': 'Dance Of Swords   Steven Universe',
#   'seconds': 18.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aivi-tran-and-steven-surasshu-velema/dance-of-swords---steven-universe/solo-2_key_cmajor.mid',
#   'inferred_key': 'G major',
#   'quarter_length': '36.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 120.0,
#   'artist': 'Aivi Tran And Steven Surasshu Velema',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 120.0,
#   'section': 'solo-2',
#   'parts': 'solo-1,solo-2',
#   'genres': 'Blues,Soundtrack',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/aivi-tran-and-steven-surasshu-velema/dance-of-swords---steven-universe/solo-2_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/aivi-tran-and-steven-surasshu-velema/dance-of-swords---steven-universe/solo-2_key_cmajor.npz',
#   'midi_npz_timesteps': 145.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/aivi-tran-and-steven-surasshu-velema/dance-of-swords---steven-universe/solo-2_key_cmajor.npy',
#   'sid': -7374215232790855900},
#  '638661208002705835': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/above-and-beyond/always',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Above and Beyond - Always Chorus',
#   'title': 'Always',
#   'seconds': 33.230769230769226,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/above-and-beyond/always/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '36.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 65.0,
#   'artist': 'Above And Beyond',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 65.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/above-and-beyond/always/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/above-and-beyond/always/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 145.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/above-and-beyond/always/chorus_key_cmajor.npy',
#   'sid': 638661208002705835},
#  '1988146714940739935': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aura-dione/friends---piano-cover',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Friends - Piano Cover',
#   'title': 'Friends   Piano Cover',
#   'seconds': 19.2,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aura-dione/friends---piano-cover/bridge_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 100.0,
#   'artist': 'Aura Dione',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 100.0,
#   'section': 'bridge',
#   'parts': 'bridge',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/aura-dione/friends---piano-cover/bridge_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/aura-dione/friends---piano-cover/bridge_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/aura-dione/friends---piano-cover/bridge_key_cmajor.npy',
#   'sid': 1988146714940739935},
#  '-2442906483143795737': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/a-sunny-day-in-glasgow/the-body-it-bends',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'The Body It Bends',
#   'title': 'The Body It Bends',
#   'seconds': 32.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/a-sunny-day-in-glasgow/the-body-it-bends/verse_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '56.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 105.0,
#   'artist': 'A Sunny Day In Glasgow',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 105.0,
#   'section': 'verse',
#   'parts': 'verse',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/a-sunny-day-in-glasgow/the-body-it-bends/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/a-sunny-day-in-glasgow/the-body-it-bends/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 225.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/a-sunny-day-in-glasgow/the-body-it-bends/verse_key_cmajor.npy',
#   'sid': -2442906483143795737},
#  '-6936495827750699541': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alesso/heroes',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Heroes',
#   'title': 'Heroes',
#   'seconds': 15.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alesso/heroes/bridge_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Alesso',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'bridge',
#   'parts': 'pre-chorus-and-chorus,chorus,bridge',
#   'genres': 'Electronic,Pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alesso/heroes/bridge_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alesso/heroes/bridge_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alesso/heroes/bridge_key_cmajor.npy',
#   'sid': -6936495827750699541},
#  '2937873078839850075': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/a-perfect-circle/blue',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Blue',
#   'title': 'Blue',
#   'seconds': 32.359550561797754,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/a-perfect-circle/blue/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '48.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 89.0,
#   'artist': 'A Perfect Circle',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 89.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/a-perfect-circle/blue/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/a-perfect-circle/blue/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 193.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/a-perfect-circle/blue/chorus_key_cmajor.npy',
#   'sid': 2937873078839850075},
#  '-6392677880431294974': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/a-perfect-circle/passive',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Passive',
#   'title': 'Passive',
#   'seconds': 60.68965517241379,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/a-perfect-circle/passive/pre-chorus-and-chorus_key_cmajor.mid',
#   'inferred_key': 'D minor',
#   'quarter_length': '88.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 87.0,
#   'artist': 'A Perfect Circle',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 87.0,
#   'section': 'pre-chorus-and-chorus',
#   'parts': 'intro,pre-chorus-and-chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/a-perfect-circle/passive/pre-chorus-and-chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/a-perfect-circle/passive/pre-chorus-and-chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 353.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/a-perfect-circle/passive/pre-chorus-and-chorus_key_cmajor.npy',
#   'sid': -6392677880431294974},
#  '5214187384374015985': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alesso/sweet-escape',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Sweet Escape Intro and Verse',
#   'title': 'Sweet Escape',
#   'seconds': 37.5,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alesso/sweet-escape/intro-and-verse_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '80.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Alesso',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'intro-and-verse',
#   'parts': 'intro-and-verse,chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alesso/sweet-escape/intro-and-verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alesso/sweet-escape/intro-and-verse_key_cmajor.npz',
#   'midi_npz_timesteps': 321.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alesso/sweet-escape/intro-and-verse_key_cmajor.npy',
#   'sid': 5214187384374015985},
#  '6152523504187860081': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/amr-diab/nour-el-ein',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Nour El Ein',
#   'title': 'Nour El Ein',
#   'seconds': 31.2,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/amr-diab/nour-el-ein/intro_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '52.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 100.0,
#   'artist': 'Amr Diab',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 100.0,
#   'section': 'intro',
#   'parts': 'intro',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/amr-diab/nour-el-ein/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/amr-diab/nour-el-ein/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 209.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/amr-diab/nour-el-ein/intro_key_cmajor.npy',
#   'sid': 6152523504187860081},
#  '-2072429228205305182': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alstroemeria-records/lovelight---bad-apple',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Lovelight - Bad Apple',
#   'title': 'Lovelight   Bad Apple',
#   'seconds': 55.65217391304348,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alstroemeria-records/lovelight---bad-apple/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '128.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 138.0,
#   'artist': 'Alstroemeria Records',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 138.0,
#   'section': 'chorus',
#   'parts': 'verse,chorus,bridge',
#   'genres': 'J-Pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alstroemeria-records/lovelight---bad-apple/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alstroemeria-records/lovelight---bad-apple/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 513.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alstroemeria-records/lovelight---bad-apple/chorus_key_cmajor.npy',
#   'sid': -2072429228205305182},
#  '-8792653214949535374': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/angel-beats/my-soul-your-beats',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'My Soul Your Beats',
#   'title': 'My Soul Your Beats',
#   'seconds': 37.5,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/angel-beats/my-soul-your-beats/verse-and-pre-chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '80.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Angel Beats',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'verse-and-pre-chorus',
#   'parts': 'verse-and-pre-chorus,chorus',
#   'genres': 'J-Pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/angel-beats/my-soul-your-beats/verse-and-pre-chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/angel-beats/my-soul-your-beats/verse-and-pre-chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 321.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/angel-beats/my-soul-your-beats/verse-and-pre-chorus_key_cmajor.npy',
#   'sid': -8792653214949535374},
#  '-2936268813608525816': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/anne-murray/dannys-song',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': "Danny's Song B",
#   'title': 'Dannys Song',
#   'seconds': 26.66666666666667,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/anne-murray/dannys-song/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 72.0,
#   'artist': 'Anne Murray',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 72.0,
#   'section': 'chorus',
#   'parts': 'verse,chorus',
#   'genres': 'Folk',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/anne-murray/dannys-song/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/anne-murray/dannys-song/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/anne-murray/dannys-song/chorus_key_cmajor.npy',
#   'sid': -2936268813608525816},
#  '-2330535485162824845': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alesso/save-the-world-remix',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'alesso save the world remix',
#   'title': 'Save The World Remix',
#   'seconds': 15.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alesso/save-the-world-remix/pre-chorus-and-chorus_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Alesso',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'pre-chorus-and-chorus',
#   'parts': 'pre-chorus-and-chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alesso/save-the-world-remix/pre-chorus-and-chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alesso/save-the-world-remix/pre-chorus-and-chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alesso/save-the-world-remix/pre-chorus-and-chorus_key_cmajor.npy',
#   'sid': -2330535485162824845},
#  '6891228233105083819': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alanis-morissette/head-over-feet',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'headoverfeetverse',
#   'title': 'Head Over Feet',
#   'seconds': 18.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alanis-morissette/head-over-feet/verse_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '24.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 80.0,
#   'artist': 'Alanis Morissette',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 80.0,
#   'section': 'verse',
#   'parts': 'verse,chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alanis-morissette/head-over-feet/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alanis-morissette/head-over-feet/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 97.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alanis-morissette/head-over-feet/verse_key_cmajor.npy',
#   'sid': 6891228233105083819},
#  '5517363698838399051': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/astronaut-ft--harry-brooks-jnr/champions',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Champions',
#   'title': 'Champions',
#   'seconds': 15.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/astronaut-ft--harry-brooks-jnr/champions/chorus_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Astronaut Ft  Harry Brooks Jnr',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/astronaut-ft--harry-brooks-jnr/champions/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/astronaut-ft--harry-brooks-jnr/champions/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/astronaut-ft--harry-brooks-jnr/champions/chorus_key_cmajor.npy',
#   'sid': 5517363698838399051},
#  '-6714013582965148475': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alanis-morissette/thank-you',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'thankyoualanis',
#   'title': 'Thank You',
#   'seconds': 23.47826086956522,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alanis-morissette/thank-you/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '36.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 92.0,
#   'artist': 'Alanis Morissette',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 92.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Alternative,Rock,Singer-Songwriter',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alanis-morissette/thank-you/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alanis-morissette/thank-you/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 145.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alanis-morissette/thank-you/chorus_key_cmajor.npy',
#   'sid': -6714013582965148475},
#  '-6203587564355168687': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/anne-murray/dannys-song',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': "Danny's Song A",
#   'title': 'Dannys Song',
#   'seconds': 25.94594594594595,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/anne-murray/dannys-song/verse_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 74.0,
#   'artist': 'Anne Murray',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 74.0,
#   'section': 'verse',
#   'parts': 'verse,chorus',
#   'genres': 'Folk',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/anne-murray/dannys-song/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/anne-murray/dannys-song/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/anne-murray/dannys-song/verse_key_cmajor.npy',
#   'sid': -6203587564355168687},
#  '2468846486791988367': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aylictal/the-pursuit-of-happiness',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'the pursuit of happiness',
#   'title': 'The Pursuit Of Happiness',
#   'seconds': 30.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aylictal/the-pursuit-of-happiness/intro-and-verse_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 64.0,
#   'artist': 'Aylictal',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 64.0,
#   'section': 'intro-and-verse',
#   'parts': 'intro-and-verse',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/aylictal/the-pursuit-of-happiness/intro-and-verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/aylictal/the-pursuit-of-happiness/intro-and-verse_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/aylictal/the-pursuit-of-happiness/intro-and-verse_key_cmajor.npy',
#   'sid': 2468846486791988367},
#  '7295423970857418312': {'inferred_offset': 5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/a-g-cook/superstar',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Superstar',
#   'title': 'Superstar',
#   'seconds': 16.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/a-g-cook/superstar/chorus_key_cmajor.mid',
#   'inferred_key': 'G major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 120.0,
#   'artist': 'A G Cook',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 120.0,
#   'section': 'chorus',
#   'parts': 'pre-chorus,pre-chorus-and-chorus,chorus',
#   'genres': 'Pop,Singer-Songwriter',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/a-g-cook/superstar/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/a-g-cook/superstar/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/a-g-cook/superstar/chorus_key_cmajor.npy',
#   'sid': 7295423970857418312},
#  '8404090293357773144': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aylictal/anxiety-avenue',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'anxiety avenue',
#   'title': 'Anxiety Avenue',
#   'seconds': 60.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aylictal/anxiety-avenue/pre-chorus-and-chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '128.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Aylictal',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'pre-chorus-and-chorus',
#   'parts': 'pre-chorus-and-chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/aylictal/anxiety-avenue/pre-chorus-and-chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/aylictal/anxiety-avenue/pre-chorus-and-chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 513.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/aylictal/anxiety-avenue/pre-chorus-and-chorus_key_cmajor.npy',
#   'sid': 8404090293357773144},
#  '-2404972493531600853': {'inferred_offset': 5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/above-and-beyond/good-for-me---ambient-mix--',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Above & Beyond - Good For Me (INTRO)',
#   'title': 'Good For Me   Ambient Mix  ',
#   'seconds': 29.538461538461537,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/above-and-beyond/good-for-me---ambient-mix--/intro_key_cmajor.mid',
#   'inferred_key': 'G major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 130.0,
#   'artist': 'Above And Beyond',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 130.0,
#   'section': 'intro',
#   'parts': 'intro,verse,chorus',
#   'genres': 'Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/above-and-beyond/good-for-me---ambient-mix--/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/above-and-beyond/good-for-me---ambient-mix--/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/above-and-beyond/good-for-me---ambient-mix--/intro_key_cmajor.npy',
#   'sid': -2404972493531600853},
#  '1234772262849509787': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/amy-grant/every-heartbeat',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Untitled',
#   'title': 'Every Heartbeat',
#   'seconds': 14.769230769230768,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/amy-grant/every-heartbeat/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 130.0,
#   'artist': 'Amy Grant',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 130.0,
#   'section': 'chorus',
#   'parts': 'verse-and-pre-chorus,chorus',
#   'genres': 'Pop,Rock,Worship',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/amy-grant/every-heartbeat/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/amy-grant/every-heartbeat/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/amy-grant/every-heartbeat/chorus_key_cmajor.npy',
#   'sid': 1234772262849509787},
#  '5966767858721024490': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/archie/famous',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Famous',
#   'title': 'Famous',
#   'seconds': 15.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/archie/famous/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Archie',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/archie/famous/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/archie/famous/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/archie/famous/chorus_key_cmajor.npy',
#   'sid': 5966767858721024490},
#  '2724921975456128271': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alanis-morissette/hand-in-my-pocket',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'handinpocket',
#   'title': 'Hand In My Pocket',
#   'seconds': 20.869565217391305,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alanis-morissette/hand-in-my-pocket/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 92.0,
#   'artist': 'Alanis Morissette',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 92.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Alternative,Rock,Singer-Songwriter',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alanis-morissette/hand-in-my-pocket/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alanis-morissette/hand-in-my-pocket/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alanis-morissette/hand-in-my-pocket/chorus_key_cmajor.npy',
#   'sid': 2724921975456128271},
#  '-6866914920520519214': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/apink/only-one',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Only One',
#   'title': 'Only One',
#   'seconds': 18.823529411764707,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/apink/only-one/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 102.0,
#   'artist': 'Apink',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 102.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'K-pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/apink/only-one/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/apink/only-one/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/apink/only-one/chorus_key_cmajor.npy',
#   'sid': -6866914920520519214},
#  '6275816442346808212': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/a-g-cook/superstar',
#   'instruments': 'Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Superstar',
#   'title': 'Superstar',
#   'seconds': 16.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/a-g-cook/superstar/pre-chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 120.0,
#   'artist': 'A G Cook',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 120.0,
#   'section': 'pre-chorus',
#   'parts': 'pre-chorus,pre-chorus-and-chorus,chorus',
#   'genres': 'Pop,Singer-Songwriter',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/a-g-cook/superstar/pre-chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/a-g-cook/superstar/pre-chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/a-g-cook/superstar/pre-chorus_key_cmajor.npy',
#   'sid': 6275816442346808212},
#  '2819494949840864882': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/adrianna/so-sick-ne-yo',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'So Sick Ne-Yo',
#   'title': 'So Sick Ne Yo',
#   'seconds': 20.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/adrianna/so-sick-ne-yo/pre-chorus-and-chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 96.0,
#   'artist': 'Adrianna',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 96.0,
#   'section': 'pre-chorus-and-chorus',
#   'parts': 'pre-chorus-and-chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/adrianna/so-sick-ne-yo/pre-chorus-and-chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/adrianna/so-sick-ne-yo/pre-chorus-and-chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/adrianna/so-sick-ne-yo/pre-chorus-and-chorus_key_cmajor.npy',
#   'sid': 2819494949840864882},
#  '-8581420289554038752': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/austin-jorgensen/goodbye-baby',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'goodbye baby',
#   'title': 'Goodbye Baby',
#   'seconds': 19.2,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/austin-jorgensen/goodbye-baby/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 100.0,
#   'artist': 'Austin Jorgensen',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 100.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/austin-jorgensen/goodbye-baby/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/austin-jorgensen/goodbye-baby/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/austin-jorgensen/goodbye-baby/chorus_key_cmajor.npy',
#   'sid': -8581420289554038752},
#  '595740588139778501': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/ark-patrol/igniter',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Igniter',
#   'title': 'Igniter',
#   'seconds': 25.771812080536908,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/ark-patrol/igniter/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 149.0,
#   'artist': 'Ark Patrol',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 149.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/ark-patrol/igniter/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/ark-patrol/igniter/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/ark-patrol/igniter/chorus_key_cmajor.npy',
#   'sid': 595740588139778501},
#  '-4210785333670986027': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alesso/sweet-escape',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Sweet Escape',
#   'title': 'Sweet Escape',
#   'seconds': 15.36,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alesso/sweet-escape/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 125.0,
#   'artist': 'Alesso',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 125.0,
#   'section': 'chorus',
#   'parts': 'intro-and-verse,chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alesso/sweet-escape/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alesso/sweet-escape/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alesso/sweet-escape/chorus_key_cmajor.npy',
#   'sid': -4210785333670986027},
#  '-3627329316357341237': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/au5/crossroad-ft-danyka-nadeau',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Crossroad Ft Danyka Nadeau',
#   'title': 'Crossroad Ft Danyka Nadeau',
#   'seconds': 30.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/au5/crossroad-ft-danyka-nadeau/solo_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Au5',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'solo',
#   'parts': 'solo',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/au5/crossroad-ft-danyka-nadeau/solo_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/au5/crossroad-ft-danyka-nadeau/solo_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/au5/crossroad-ft-danyka-nadeau/solo_key_cmajor.npy',
#   'sid': -3627329316357341237},
#  '-6921304291032054930': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/andreas-schuller/mobo-2012',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'New Project',
#   'title': 'Mobo 2012',
#   'seconds': 14.883720930232556,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/andreas-schuller/mobo-2012/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 129.0,
#   'artist': 'Andreas Schuller',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 129.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Dance,Electronic',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/andreas-schuller/mobo-2012/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/andreas-schuller/mobo-2012/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/andreas-schuller/mobo-2012/chorus_key_cmajor.npy',
#   'sid': -6921304291032054930},
#  '1933777781678985517': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alstroemeria-records/bad-apple',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Bad Apple',
#   'title': 'Bad Apple',
#   'seconds': 12.885906040268454,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alstroemeria-records/bad-apple/intro_key_cmajor.mid',
#   'inferred_key': 'D minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 149.0,
#   'artist': 'Alstroemeria Records',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
# ...
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Andrew Lloyd Webber',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'chorus-lead-out',
#   'parts': 'chorus-lead-out',
#   'genres': 'Classical,Rock,Soundtrack',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/andrew-lloyd-webber/jesus-christ-superstar/chorus-lead-out_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/andrew-lloyd-webber/jesus-christ-superstar/chorus-lead-out_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/andrew-lloyd-webber/jesus-christ-superstar/chorus-lead-out_key_cmajor.npy',
#   'sid': -1856364764973487576},
#  '-8191391493997512730': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/ariana-grande/side-to-side-ft-nicki-minaj',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'side2side',
#   'title': 'Side To Side Ft Nicki Minaj',
#   'seconds': 25.5,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/ariana-grande/side-to-side-ft-nicki-minaj/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '68.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 160.0,
#   'artist': 'Ariana Grande',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 160.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/ariana-grande/side-to-side-ft-nicki-minaj/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/ariana-grande/side-to-side-ft-nicki-minaj/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 273.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/ariana-grande/side-to-side-ft-nicki-minaj/chorus_key_cmajor.npy',
#   'sid': -8191391493997512730},
#  '6907677361858357129': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/armin-van-buuren-featuring-laura-v---avicii-remix/drowning',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Drowning',
#   'title': 'Drowning',
#   'seconds': 30.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/armin-van-buuren-featuring-laura-v---avicii-remix/drowning/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 128.0,
#   'artist': 'Armin Van Buuren Featuring Laura V   Avicii Remix',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 128.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/armin-van-buuren-featuring-laura-v---avicii-remix/drowning/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/armin-van-buuren-featuring-laura-v---avicii-remix/drowning/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/armin-van-buuren-featuring-laura-v---avicii-remix/drowning/chorus_key_cmajor.npy',
#   'sid': 6907677361858357129},
#  '8367493070448154999': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/abba/gimme-gimme-gimme-a-man-after-midnight',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Gimme Gimme Gimme A Man After Midnight',
#   'title': 'Gimme Gimme Gimme A Man After Midnight',
#   'seconds': 16.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/abba/gimme-gimme-gimme-a-man-after-midnight/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 120.0,
#   'artist': 'Abba',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 120.0,
#   'section': 'chorus',
#   'parts': 'intro,intro-and-verse,verse,chorus',
#   'genres': 'Pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/abba/gimme-gimme-gimme-a-man-after-midnight/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/abba/gimme-gimme-gimme-a-man-after-midnight/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/abba/gimme-gimme-gimme-a-man-after-midnight/chorus_key_cmajor.npy',
#   'sid': 8367493070448154999},
#  '7376105036803430848': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/andrew-lloyd-webber/dont-cry-for-me-argentina',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': "Don't Cry For Me Argentina - verse",
#   'title': 'Dont Cry For Me Argentina',
#   'seconds': 42.352941176470594,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/andrew-lloyd-webber/dont-cry-for-me-argentina/verse_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '60.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 85.0,
#   'artist': 'Andrew Lloyd Webber',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 85.0,
#   'section': 'verse',
#   'parts': 'verse,chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/andrew-lloyd-webber/dont-cry-for-me-argentina/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/andrew-lloyd-webber/dont-cry-for-me-argentina/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 241.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/andrew-lloyd-webber/dont-cry-for-me-argentina/verse_key_cmajor.npy',
#   'sid': 7376105036803430848},
#  '-6170357139243895396': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/abba/sos',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'New Project',
#   'title': 'Sos',
#   'seconds': 30.967741935483872,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/abba/sos/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 124.0,
#   'artist': 'Abba',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 124.0,
#   'section': 'chorus',
#   'parts': 'verse,chorus',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/abba/sos/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/abba/sos/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/abba/sos/chorus_key_cmajor.npy',
#   'sid': -6170357139243895396},
#  '-716769914811228397': {'inferred_offset': 2.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/akiko-yano/water-ways-flow-backward-again',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': "'Water Ways Flow Backward Again' Akiko Yano",
#   'title': 'Water Ways Flow Backward Again',
#   'seconds': 17.454545454545453,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/akiko-yano/water-ways-flow-backward-again/intro_key_cmajor.mid',
#   'inferred_key': 'G minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 110.0,
#   'artist': 'Akiko Yano',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 110.0,
#   'section': 'intro',
#   'parts': 'intro',
#   'genres': 'Jazz',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/akiko-yano/water-ways-flow-backward-again/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/akiko-yano/water-ways-flow-backward-again/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/akiko-yano/water-ways-flow-backward-again/intro_key_cmajor.npy',
#   'sid': -716769914811228397},
#  '-9163346471319874587': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alan-parsons-project/eye-in-the-sky',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'New Project',
#   'title': 'Eye In The Sky',
#   'seconds': 17.142857142857142,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alan-parsons-project/eye-in-the-sky/intro_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 112.0,
#   'artist': 'Alan Parsons Project',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 112.0,
#   'section': 'intro',
#   'parts': 'intro,intro-and-verse,pre-chorus,chorus',
#   'genres': 'Rock',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alan-parsons-project/eye-in-the-sky/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alan-parsons-project/eye-in-the-sky/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alan-parsons-project/eye-in-the-sky/intro_key_cmajor.npy',
#   'sid': -9163346471319874587},
#  '1592106191406549518': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/au5-and-fractal/subvert---haywyre-remix',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Subvert Haywyre',
#   'title': 'Subvert   Haywyre Remix',
#   'seconds': 18.285714285714285,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/au5-and-fractal/subvert---haywyre-remix/solo-1_key_cmajor.mid',
#   'inferred_key': 'D minor',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 210.0,
#   'artist': 'Au5 And Fractal',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 210.0,
#   'section': 'solo-1',
#   'parts': 'solo-1',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/au5-and-fractal/subvert---haywyre-remix/solo-1_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/au5-and-fractal/subvert---haywyre-remix/solo-1_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/au5-and-fractal/subvert---haywyre-remix/solo-1_key_cmajor.npy',
#   'sid': 1592106191406549518},
#  '8863706351540762955': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aandg/lucid',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Lucid',
#   'title': 'Lucid',
#   'seconds': 15.118110236220472,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aandg/lucid/chorus_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 127.0,
#   'artist': 'Aandg',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 127.0,
#   'section': 'chorus',
#   'parts': 'chorus',
#   'genres': 'Dance,Electronic,House',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/aandg/lucid/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/aandg/lucid/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/aandg/lucid/chorus_key_cmajor.npy',
#   'sid': 8863706351540762955},
#  '6047509004651688019': {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/ace-of-base/all-that-she-wants',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'allThatSheWants chorus',
#   'title': 'All That She Wants',
#   'seconds': 20.645161290322573,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/ace-of-base/all-that-she-wants/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 93.0,
#   'artist': 'Ace Of Base',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 93.0,
#   'section': 'chorus',
#   'parts': 'intro,verse,pre-chorus,chorus',
#   'genres': 'Pop',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/ace-of-base/all-that-she-wants/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/ace-of-base/all-that-she-wants/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/ace-of-base/all-that-she-wants/chorus_key_cmajor.npy',
#   'sid': 6047509004651688019},
#  '-1574050797975453767': {'inferred_offset': 3.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/andrew-lloyd-webber/music-of-the-night',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'phantom bridge p4',
#   'title': 'Music Of The Night',
#   'seconds': 8.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-3_key_cmajor.mid',
#   'inferred_key': 'A major',
#   'quarter_length': '16.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 120.0,
#   'artist': 'Andrew Lloyd Webber',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 120.0,
#   'section': 'solo-3',
#   'parts': 'chorus,solo,solo-1,solo-2,solo-3,outro',
#   'genres': 'Classical,Disney,Soundtrack',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-3_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-3_key_cmajor.npz',
#   'midi_npz_timesteps': 65.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-3_key_cmajor.npy',
#   'sid': -1574050797975453767},
#  '1523278769338714125': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/andrew-lloyd-webber/music-of-the-night',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Music Of The Night',
#   'title': 'Music Of The Night',
#   'seconds': 8.205128205128204,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-2_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '16.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 117.0,
#   'artist': 'Andrew Lloyd Webber',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 117.0,
#   'section': 'solo-2',
#   'parts': 'chorus,solo,solo-1,solo-2,solo-3,outro',
#   'genres': 'Classical,Disney,Soundtrack',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-2_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-2_key_cmajor.npz',
#   'midi_npz_timesteps': 65.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/andrew-lloyd-webber/music-of-the-night/solo-2_key_cmajor.npy',
#   'sid': 1523278769338714125},
#  '7864085806841424829': {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/alexandre-desplat/statues---harry-potter-deathly-hallows-pt-2-ost',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Statues - Harry Potter Deathly Hallows Pt 2 OST',
#   'title': 'Statues   Harry Potter Deathly Hallows Pt 2 Ost',
#   'seconds': 15.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/alexandre-desplat/statues---harry-potter-deathly-hallows-pt-2-ost/intro_key_cmajor.mid',
#   'inferred_key': 'D minor',
#   'quarter_length': '16.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 64.0,
#   'artist': 'Alexandre Desplat',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 64.0,
#   'section': 'intro',
#   'parts': 'intro',
#   'genres': 'Soundtrack',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/a/alexandre-desplat/statues---harry-potter-deathly-hallows-pt-2-ost/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/a/alexandre-desplat/statues---harry-potter-deathly-hallows-pt-2-ost/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 65.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/a/alexandre-desplat/statues---harry-potter-deathly-hallows-pt-2-ost/intro_key_cmajor.npy',
#   'sid': 7864085806841424829},
#  ...}

# %%
search_htlist(htlist, 'country ')
# Out:
# [{'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/keith-jarrett/country',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Country',
#   'title': 'Country',
#   'seconds': 28.8,
#   'midi': 'midi_sources/hooktheory/pianoroll/k/keith-jarrett/country/intro_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '72.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 150.0,
#   'artist': 'Keith Jarrett',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 150.0,
#   'section': 'intro',
#   'parts': 'intro',
#   'genres': None,
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/k/keith-jarrett/country/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/k/keith-jarrett/country/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 289.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/k/keith-jarrett/country/intro_key_cmajor.npy',
#   'sid': -1244523610786982139},
#  {'inferred_offset': 5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/nintendo/donkey-kong-country-2---forest-interlude',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'DKC2 Forest Interlude 1',
#   'title': 'Donkey Kong Country 2   Forest Interlude',
#   'seconds': 39.58762886597938,
#   'midi': 'midi_sources/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/intro_key_cmajor.mid',
#   'inferred_key': 'G major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 97.0,
#   'artist': 'Nintendo',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 97.0,
#   'section': 'intro',
#   'parts': 'intro,verse',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/intro_key_cmajor.npy',
#   'sid': -6032940863300869581},
#  {'inferred_offset': -5.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/nintendo/donkey-kong-country-2---forest-interlude',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Donkey Kong Country 2 - Forest Interlude',
#   'title': 'Donkey Kong Country 2   Forest Interlude',
#   'seconds': 39.58762886597938,
#   'midi': 'midi_sources/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/verse_key_cmajor.mid',
#   'inferred_key': 'F major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 97.0,
#   'artist': 'Nintendo',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 97.0,
#   'section': 'verse',
#   'parts': 'intro,verse',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/n/nintendo/donkey-kong-country-2---forest-interlude/verse_key_cmajor.npy',
#   'sid': 6301219067404236060},
#  {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/david-wise/donkey-kong-country---aquatic-ambience',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Donkey Kong Country - Aquatic Ambience',
#   'title': 'Donkey Kong Country   Aquatic Ambience',
#   'seconds': 46.66666666666667,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/intro_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '56.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 72.0,
#   'artist': 'David Wise',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 72.0,
#   'section': 'intro',
#   'parts': 'intro,verse,chorus',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 225.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/intro_key_cmajor.npy',
#   'sid': 8452080855654107529},
#  {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/david-wise/donkey-kong-country---aquatic-ambience',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Donkey Kong Country - Aquatic Ambience',
#   'title': 'Donkey Kong Country   Aquatic Ambience',
#   'seconds': 40.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '48.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 72.0,
#   'artist': 'David Wise',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 72.0,
#   'section': 'chorus',
#   'parts': 'intro,verse,chorus',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 193.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/chorus_key_cmajor.npy',
#   'sid': 4116580464457808849},
#  {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/david-wise/donkey-kong-country---aquatic-ambience',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'Donkey Kong Country - Aquatic Ambience',
#   'title': 'Donkey Kong Country   Aquatic Ambience',
#   'seconds': 40.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/verse_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '48.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 72.0,
#   'artist': 'David Wise',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 72.0,
#   'section': 'verse',
#   'parts': 'intro,verse,chorus',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/verse_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/verse_key_cmajor.npz',
#   'midi_npz_timesteps': 193.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/d/david-wise/donkey-kong-country---aquatic-ambience/verse_key_cmajor.npy',
#   'sid': 758590175571140457},
#  {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/david-wise/donkey-kong-country---gang-plank-galleon',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'DKC Gangplank Galleon Intro',
#   'title': 'Donkey Kong Country   Gang Plank Galleon',
#   'seconds': 28.36363636363636,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/david-wise/donkey-kong-country---gang-plank-galleon/intro_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '52.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 110.0,
#   'artist': 'David Wise',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 110.0,
#   'section': 'intro',
#   'parts': 'intro,verse,chorus',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/d/david-wise/donkey-kong-country---gang-plank-galleon/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/d/david-wise/donkey-kong-country---gang-plank-galleon/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 209.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/d/david-wise/donkey-kong-country---gang-plank-galleon/intro_key_cmajor.npy',
#   'sid': -6295949859424704983},
#  {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/david-wise/donkey-kong-country-theme-song',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'dkc theme chorus',
#   'title': 'Donkey Kong Country Theme Song',
#   'seconds': 14.769230769230768,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/david-wise/donkey-kong-country-theme-song/chorus_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '32.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 130.0,
#   'artist': 'David Wise',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 130.0,
#   'section': 'chorus',
#   'parts': 'intro-and-verse,chorus',
#   'genres': 'Soundtrack,Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/d/david-wise/donkey-kong-country-theme-song/chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/d/david-wise/donkey-kong-country-theme-song/chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 129.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/d/david-wise/donkey-kong-country-theme-song/chorus_key_cmajor.npy',
#   'sid': -1080776865197839393},
#  {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/david-wise/hot-head-bop---donkey-kong-country-2',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'DKC2 Hot-Head Bop PrePre-Chorus',
#   'title': 'Hot Head Bop   Donkey Kong Country 2',
#   'seconds': 17.454545454545453,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/david-wise/hot-head-bop---donkey-kong-country-2/pre-chorus_key_cmajor.mid',
#   'inferred_key': 'A minor',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 220.0,
#   'artist': 'David Wise',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 220.00000000000003,
#   'section': 'pre-chorus',
#   'parts': 'verse,pre-chorus,chorus',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/d/david-wise/hot-head-bop---donkey-kong-country-2/pre-chorus_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/d/david-wise/hot-head-bop---donkey-kong-country-2/pre-chorus_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/d/david-wise/hot-head-bop---donkey-kong-country-2/pre-chorus_key_cmajor.npy',
#   'sid': 8230439981230451319},
#  {'inferred_offset': 0.0,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/david-wise/dk-island-swing---donkey-kong-country',
#   'instruments': 'Piano,Piano',
#   'ht_mode': 1.0,
#   'midi_title': 'DK Island Swing Intro',
#   'title': 'Dk Island Swing   Donkey Kong Country',
#   'seconds': 19.2,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/david-wise/dk-island-swing---donkey-kong-country/intro_key_cmajor.mid',
#   'inferred_key': 'C major',
#   'quarter_length': '64.0',
#   'time_signature': '4/4',
#   'source': 'hooktheory',
#   'ht_offset': 0.0,
#   'ht_bpm': 200.0,
#   'artist': 'David Wise',
#   'ht_key': 'C',
#   'ht_time_signature': 4.0,
#   'bpm': 200.0,
#   'section': 'intro',
#   'parts': 'intro',
#   'genres': 'Video Game',
#   'mxl': None,
#   'midi_transform': 'midi_transform/hooktheory/pianoroll/d/david-wise/dk-island-swing---donkey-kong-country/intro_key_cmajor.mid',
#   'midi_npz': 'midi_npz/hooktheory/pianoroll/d/david-wise/dk-island-swing---donkey-kong-country/intro_key_cmajor.npz',
#   'midi_npz_timesteps': 257.0,
#   'numpy': 'midi_encode/np/shortdur/hooktheory/pianoroll/d/david-wise/dk-island-swing---donkey-kong-country/intro_key_cmajor.npy',
#   'sid': -2495064133964913258}]

# %% [markdown]
# ### Predict

# %%
fsong = search_htlist(htlist, 'country road')[0]

# %%
midi_file = fsong['midi']
midi_path = file_path/data_dir/midi_file; midi_path
# Out:
# PosixPath('../../data/midi/v9/midi_sources/hooktheory/pianoroll/j/john-denver/take-me-home-country-roads/bridge_key_cmajor.mid')

# %%
def midi2npenc(midi_file, num_comps=2):
    "Converts midi file to numpy encoding for language model"
    stream = file2stream(midi_file) # 1.
    s_arr = stream2chordarr(stream) # 2.
    seq = chordarr2seq(s_arr) # 3.
    return seq2npenc(seq, num_comps=num_comps)

# %%
npenc = midi2npenc(midi_path); npenc

# %% [markdown]
# ### NOTE: looks like npenc does not include the separator. This means we don't have to remove the last step in order to keep predicting

# %%
npenc
# Out:
# array([[ 2,  0],
#        [ 1,  3],
#        [55, 11],
#        [51, 11],
#        [48, 11],
#        [ 1,  4],
#        [63,  5],
#        [ 1,  4],
#        [63,  5],
#        [ 1,  4],
#        ...,
#        [ 1, 10],
#        [65,  5],
#        [ 1,  4],
#        [67,  5],
#        [ 1,  4],
#        [68, 11],
#        [56, 19],
#        [53, 19],
#        [50, 19],
#        [46, 19]])

# %%
sorig = file2stream(midi_path)
sorig.show()

# %%
sorig.show('midi')
# Out:
#                 <div id='midiPlayerDiv4728'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4728');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
stream = npenc2stream(npenc)

# %%
stream.show()

# %%
stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv6932'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv6932');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
pred, seed, full = generate_predictions(learn, np_file=np_path)
pid = save_preds(pred, seed, full, out_path)
bpm = htlist[np_file]['ht_bpm']
midi, score = save_comps(out_path, pid, bpm=bpm)

# %%
np_file = fsong['numpy']
np_path = file_path/data_dir/np_file
pred, seed, full = generate_predictions(learn, np_file=np_path)
pid = save_preds(pred, seed, full, out_path)
bpm = htlist[np_file]['ht_bpm']
midi, score = save_comps(out_path, pid, bpm=bpm)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='340', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Predicted BOS token. Returning prediction...

# %%
from PIL import Image

# %%
Image.open(score)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1543x165 at 0x14E5A0F98>

# %% [markdown]
# ## Flask App

# %%
from flask import Flask, Response, send_from_directory, send_file, request, jsonify

# %%
app = Flask(__name__)

# %%
@app.route('/hello/', methods=['GET', 'POST'])
def hello_world():
    return 'Hello, World!'

# %%
@app.route('/songs/all', methods=['GET', 'POST'])
def song_list():
    # get song name and artist from csv
    result = {
        'result': list(htlist.values())[:100]
    }
    return jsonify(result)

@app.route('/songs/search', methods=['GET', 'POST'])
def song_search():
    keywords = request.values.get('keywords', '')
    res = search_htlist(files, config, keywords)
    result = {
        'result': res
    }
    return jsonify(result)

# %%
@app.route('/midi/score')
def midi_score():
    'Show piano score image'
    pass

@app.route('/midi/file')
def midi_file():
    'Return npenc to midi'
    pass

@app.route('/midi/save')
def midi_save():
    'Save sequence from key-editor to midi'
    pass

# %%
@app.route('/predict', methods=['POST'])
def predict():
    args = request.json
    np_file = args['np_file']
    args['np_file'] = file_path/data_dir/np_file
    pred, seed, full = generate_predictions(learn, **args)
    pid = save_preds(pred, seed, full, out_path)
    bpm = htlist[np_file]['ht_bpm']
    midi, score = save_comps(out_path, pid, bpm=bpm)
    
    res = {
        'midi': midi.name,
        'score': score.name,
        'pid': pid
    }
    result = { 'result': res }
    return jsonify(result)

# %%
@app.route("/predict/<path:pid>/score/")
def pred_score(pid):
    return send_from_directory(out_path, f'{pid}/pred-1.png', mimetype='image/png')

# %%
@app.route("/predict/<path:pid>/midi/")
def pred_midi(pid):
#     path = out_path/pid/'pred.mid'
#     return send_file(path, mimetype='audio/midi')
    return send_from_directory(out_path, f'{pid}/pred.mid', mimetype='audio/midi')

# %%
# test_file = '../../data/midi/v9/midi_encode/np/shortdur/hooktheory/pianoroll/j/john-denver/take-me-home-country-roads/bridge_key_cmajor.npy'
# pred, seed, full = generate_predictions(np_file=test_file)
# pid = save_preds(pred, seed, full)
# midi, score = save_comps(pid)
# midi, score

# %%
# resp = pred_score('41111774-ce6c-4813-9501-ea2cf2711f68')

# %%
@app.route('/health')
def health_check():
    return Response("", status = 200)

# if __name__ == '__main__':
#     app.run(debug=True,host='0.0.0.0')

# %%
from werkzeug.serving import run_simple
run_simple('localhost', 6006, app)
# Out:
#  * Running on http://localhost:6006/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Mar/2019 20:45:09] "POST /hello HTTP/1.1" 301 -
# 127.0.0.1 - - [25/Mar/2019 20:45:09] "GET /hello/ HTTP/1.1" 200 -
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='340', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Predicted BOS token. Returning prediction...
# 127.0.0.1 - - [25/Mar/2019 20:45:17] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2019 20:45:17] "GET /predict/29ca7708-0efc-491c-a5a6-210d403ab41b/score HTTP/1.1" 301 -
# 127.0.0.1 - - [25/Mar/2019 20:45:17] "GET /predict/29ca7708-0efc-491c-a5a6-210d403ab41b/score/ HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Mar/2019 20:45:17] "GET /predict/29ca7708-0efc-491c-a5a6-210d403ab41b/midi HTTP/1.1" 301 -
# 127.0.0.1 - - [25/Mar/2019 20:45:17] "GET /predict/29ca7708-0efc-491c-a5a6-210d403ab41b/midi/ HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Mar/2019 20:45:44] "GET /predict/29ca7708-0efc-491c-a5a6-210d403ab41b/score HTTP/1.1" 301 -
# 127.0.0.1 - - [25/Mar/2019 20:45:44] "GET /predict/29ca7708-0efc-491c-a5a6-210d403ab41b/score/ HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Mar/2019 20:45:52] "POST /songs/search HTTP/1.1" 200 -

# %% [markdown]
# ### Music xml testing

# %% [markdown]
# Valid formats include (but are not limited to)::
#     musicxml
#     text
#     midi
#     lily (or lilypond)
#     lily.png
#     lily.pdf
#     lily.svg
#     braille
#     vexflow
#     musicxml.png

# %%
stream.write('musicxml.png', '/tmp/abc.xml')
# Out:
# '/tmp/abc-1.png'

# %%
midi.absolute()
# Out:
# PosixPath('/home/ubuntu/midi_generator/notebooks/numpy_encoding/../../data/generated/8ed91017-81f0-4c8e-8643-625b6b569527/pred.mid')

# %%
midi, score
# Out:
# (PosixPath('../../data/generated/8ed91017-81f0-4c8e-8643-625b6b569527/pred.mid'),
#  PosixPath('/home/ubuntu/midi_generator/data/generated/8ed91017-81f0-4c8e-8643-625b6b569527/pred.xml'))

# %%
stream.show('musicxml.png')
# Out:
# ---------------------------------------------------------------------------
# SubConverterException                     Traceback (most recent call last)
# <ipython-input-37-bea4f056d15a> in <module>
# ----> 1 stream.show('musicxml.png')
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/__init__.py in show(self, *args, **kwargs)
#     256         if self.isSorted is False and self.autoSort:
#     257             self.sort()
# --> 258         return super().show(*args, **kwargs)
#     259
#     260     #---------------------------------------------------------------------------
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/base.py in show(self, fmt, app, **keywords)
#    2578                                  app=app,
#    2579                                  subformats=subformats,
# -> 2580                                  **keywords)
#    2581
#    2582     #--------------------------------------------------------------------------
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/converter/subConverters.py in show(self, obj, fmt, app, subformats, **keywords)
#     950             elif 'pdf' in subformats:
#     951                 fmt = 'pdf'
# --> 952         self.launch(returnedFilePath, fmt=fmt, app=app)
#     953
#     954
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/converter/subConverters.py in launch(self, filePath, fmt, options, app, launchKey)
#     170                     "Specify this in your Environment by calling "
#     171                     "environment.set({!r}, '/path/to/application')".format(
# --> 172                         fmt, launchKey))
#     173         elif platform == 'win':  # note extra set of quotes!
#     174             cmd = '""%s" %s "%s""' % (app, options, filePath)
#
# SubConverterException: Cannot find a valid application path for format png. Specify this in your Environment by calling environment.set('graphicsPath', '/path/to/application')

# %%
from PIL import Image

# %%
Image.open('/tmp/abc-1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1507x1193 at 0x7FC804A616D8>
