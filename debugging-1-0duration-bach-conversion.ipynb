# %% [markdown]
# # Music

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *

# %%
import music21
from music21 import *
from IPython.display import Image, Audio

# %% [markdown]
# ## Let's find a short song

# %%
predicate = lambda x: 400 < x < 500
s = corpus.corpora.CoreCorpus().search(predicate, 'noteCount')

# %%
list(s)[:10]
# Out:
# [<music21.metadata.bundles.MetadataEntry: bach_bwv126_6_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv137_5_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv185_6_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv19_7_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv190_7_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv195_6_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv226_2_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv245_40_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv340_mxl>,
#  <music21.metadata.bundles.MetadataEntry: bach_bwv362_mxl>]

# %%
b = corpus.parse('bach/bwv126.6')
# b = corpus.parse('schoenberg/opus19', 6)

# %%
list(b.flat)
# Out:
# [<music21.text.TextBox "PDF © 2004...">,
#  <music21.text.TextBox "BWV 126.6">,
#  <music21.metadata.Metadata at 0x7f2ee9e27400>,
#  <music21.instrument.Instrument P1: Soprano: >,
#  <music21.instrument.Instrument P2: Alto: >,
#  <music21.instrument.Instrument P3: Tenor: >,
#  <music21.instrument.Instrument P4: Bass: >,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.ScoreLayout>,
#  <music21.clef.TrebleClef>,
#  <music21.clef.TrebleClef>,
#  <music21.clef.BassClef>,
#  <music21.clef.BassClef>,
#  <music21.key.Key of a minor>,
#  <music21.key.KeySignature of no sharps or flats>,
#  <music21.key.KeySignature of no sharps or flats>,
#  <music21.key.KeySignature of no sharps or flats>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.layout.StaffGroup <music21.stream.Part Soprano><music21.stream.Part Alto><music21.stream.Part Tenor><music21.stream.Part Bass>>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note G#>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note G#>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note G#>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note G#>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note G#>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.layout.PageLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.PageLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.PageLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.PageLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note D#>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Rest rest>,
#  <music21.note.Rest rest>,
#  <music21.note.Rest rest>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note B->,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note B->,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.layout.PageLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.PageLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.PageLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.layout.PageLayout>,
#  <music21.layout.StaffLayout distance 130, staffNumber 1, staffSize None, staffLines None>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note G#>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note G#>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note C#>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note G#>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.bar.Barline style=final>,
#  <music21.bar.Barline style=final>,
#  <music21.bar.Barline style=final>,
#  <music21.bar.Barline style=final>]

# %%
b.flat.show('midi')
# Out:
#                 <div id='midiPlayerDiv47247'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv47247');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
Image(filename=str(b.flat.write('lily.png')))

# %%
dir(b)
# Out:
# ['_DOC_ATTR',
#  '_DOC_ORDER',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accumulatedSeconds',
#  '_activeSite',
#  '_activeSiteStoredOffset',
#  '_atSoundingPitch',
#  '_cache',
#  '_classListFullyQualifiedCacheDict',
#  '_classSetCacheDict',
#  '_classTupleCacheDict',
#  '_consolidateLayering',
#  '_deepcopySubclassable',
#  '_derivation',
#  '_durSpanOverlap',
#  '_duration',
#  '_editorial',
#  '_elements',
#  '_endElements',
#  '_findLayering',
#  '_fixMeasureNumbers',
#  '_getActiveSite',
#  '_getAtSoundingPitch',
#  '_getClef',
#  '_getDerivation',
#  '_getDurSpan',
#  '_getDuration',
#  '_getElements',
#  '_getFinalBarline',
#  '_getFlatOrSemiFlat',
#  '_getKeySignature',
#  '_getMeasureOffset',
#  '_getMetadata',
#  '_getOffset',
#  '_getPriority',
#  '_getQuarterLength',
#  '_getSeconds',
#  '_getSecondsMap',
#  '_getTimeSignature',
#  '_getTimeSignatureForBeat',
#  '_insertDeletionVariant',
#  '_insertInsertionVariant',
#  '_insertReplacementVariant',
#  '_maxVoiceCount',
#  '_mutable',
#  '_naiveOffset',
#  '_offsetDict',
#  '_priority',
#  '_recurseRepr',
#  '_removeIteration',
#  '_removeOrExpandGaps',
#  '_replaceSpannerBundleForDeepcopy',
#  '_reprText',
#  '_reprTextLine',
#  '_setActiveSite',
#  '_setAtSoundingPitch',
#  '_setClef',
#  '_setDerivation',
#  '_setDuration',
#  '_setElements',
#  '_setFinalBarline',
#  '_setHighestTime',
#  '_setKeySignature',
#  '_setMetadata',
#  '_setOffset',
#  '_setPriority',
#  '_setQuarterLength',
#  '_setSeconds',
#  '_setTimeSignature',
#  '_style',
#  '_styleClass',
#  '_transposeByInstrument',
#  '_uniqueOffsetsAndEndTimes',
#  '_unlinkedDuration',
#  '_yieldReverseUpwardsSearch',
#  'activateVariants',
#  'activeSite',
#  'addGroupForElements',
#  'allPlayingWhileSounding',
#  'analyze',
#  'append',
#  'asTimespans',
#  'asTree',
#  'atSoundingPitch',
#  'attachIntervalsBetweenStreams',
#  'attachMelodicIntervals',
#  'augmentOrDiminish',
#  'autoSort',
#  'beat',
#  'beatAndMeasureFromOffset',
#  'beatDuration',
#  'beatStr',
#  'beatStrength',
#  'chordify',
#  'classSet',
#  'classSortOrder',
#  'classes',
#  'clear',
#  'clef',
#  'cloneEmpty',
#  'containerHierarchy',
#  'containerInHierarchy',
#  'contextSites',
#  'coreAppend',
#  'coreElementsChanged',
#  'coreGatherMissingSpanners',
#  'coreGetElementByMemoryLocation',
#  'coreGuardBeforeAddElement',
#  'coreHasElementByMemoryLocation',
#  'coreInsert',
#  'coreStoreAtEnd',
#  'corpusFilepath',
#  'definesExplicitPageBreaks',
#  'definesExplicitSystemBreaks',
#  'derivation',
#  'duration',
#  'editorial',
#  'elementOffset',
#  'elements',
#  'expandRepeats',
#  'explode',
#  'extendDuration',
#  'extendDurationAndGetBoundaries',
#  'extendTies',
#  'extractContext',
#  'fileFormat',
#  'fileNumber',
#  'filePath',
#  'finalBarline',
#  'findConsecutiveNotes',
#  'findGaps',
#  'flat',
#  'flattenParts',
#  'flattenUnnecessaryVoices',
#  'getAllContextsByClass',
#  'getClefs',
#  'getContextByClass',
#  'getElementAfterElement',
#  'getElementAtOrBefore',
#  'getElementBeforeOffset',
#  'getElementById',
#  'getElementsByClass',
#  'getElementsByGroup',
#  'getElementsByOffset',
#  'getElementsNotOfClass',
#  'getInstrument',
#  'getInstruments',
#  'getKeySignatures',
#  'getOffsetBySite',
#  'getOffsetInHierarchy',
#  'getOverlaps',
#  'getSpannerSites',
#  'getTimeSignatures',
#  'groups',
#  'hasEditorialInformation',
#  'hasElement',
#  'hasElementOfClass',
#  'hasMeasures',
#  'hasPartLikeStreams',
#  'hasStyleInformation',
#  'hasVoices',
#  'haveAccidentalsBeenMade',
#  'highestOffset',
#  'highestTime',
#  'id',
#  'implode',
#  'index',
#  'informSites',
#  'insert',
#  'insertAndShift',
#  'insertIntoNoteOrChord',
#  'invertDiatonic',
#  'isClassOrSubclass',
#  'isFlat',
#  'isGapless',
#  'isMeasure',
#  'isSequence',
#  'isSorted',
#  'isStream',
#  'isTwelveTone',
#  'isWellFormedNotation',
#  'iter',
#  'keySignature',
#  'lowestOffset',
#  'lyrics',
#  'makeAccidentals',
#  'makeBeams',
#  'makeChords',
#  'makeImmutable',
#  'makeMeasures',
#  'makeMutable',
#  'makeNotation',
#  'makeRests',
#  'makeTies',
#  'makeVariantBlocks',
#  'makeVoices',
#  'measure',
#  'measureNumber',
#  'measureOffsetMap',
#  'measures',
#  'melodicIntervals',
#  'mergeAttributes',
#  'mergeElements',
#  'metadata',
#  'metronomeMarkBoundaries',
#  'next',
#  'notes',
#  'notesAndRests',
#  'offset',
#  'offsetMap',
#  'parts',
#  'partsToVoices',
#  'pitches',
#  'playingWhenAttacked',
#  'plot',
#  'pop',
#  'previous',
#  'priority',
#  'purgeLocations',
#  'purgeOrphans',
#  'quantize',
#  'quarterLength',
#  'recurse',
#  'recursionType',
#  'remove',
#  'removeByClass',
#  'removeByNotOfClass',
#  'repeatAppend',
#  'repeatInsert',
#  'replace',
#  'restoreActiveSites',
#  'scaleDurations',
#  'scaleOffsets',
#  'seconds',
#  'secondsMap',
#  'semiFlat',
#  'setDerivationMethod',
#  'setElementOffset',
#  'setOffsetBySite',
#  'shiftElements',
#  'show',
#  'showVariantAsOssialikePart',
#  'simultaneousAttacks',
#  'sites',
#  'sliceAtOffsets',
#  'sliceByBeat',
#  'sliceByGreatestDivisor',
#  'sliceByQuarterLengths',
#  'sort',
#  'sortTuple',
#  'sorted',
#  'spannerBundle',
#  'spanners',
#  'splitAtDurations',
#  'splitAtQuarterLength',
#  'splitByClass',
#  'splitByQuarterLengths',
#  'storeAtEnd',
#  'streamStatus',
#  'stripTies',
#  'style',
#  'template',
#  'timeSignature',
#  'toSoundingPitch',
#  'toWrittenPitch',
#  'transferOffsetToElements',
#  'transpose',
#  'variants',
#  'voices',
#  'voicesToParts',
#  'write']

# %%
list(b)
# Out:
# [<music21.text.TextBox "PDF © 2004...">,
#  <music21.text.TextBox "BWV 126.6">,
#  <music21.metadata.Metadata at 0x7f2eeb3555c0>,
#  <music21.stream.Part Soprano>,
#  <music21.stream.Part Alto>,
#  <music21.stream.Part Tenor>,
#  <music21.stream.Part Bass>,
#  <music21.layout.ScoreLayout>,
#  <music21.layout.StaffGroup <music21.stream.Part Soprano><music21.stream.Part Alto><music21.stream.Part Tenor><music21.stream.Part Bass>>]

# %%
ts = b.flat.timeSignature

# %%
ts.beatDuration
# Out:
# <music21.duration.Duration 1.0>

# %%
b.timeSignature = meter.TimeSignature('4/4', )

# %%
b.timeSignature.beatDivisionCount
# Out:
# 2

# %%
b.show('midi')
# Out:
#                 <div id='midiPlayerDiv41052'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv41052');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
b.show('midi')
# Out:
#                 <div id='midiPlayerDiv29472'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv29472');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
b.show('midi')
# Out:
#                 <div id='midiPlayerDiv9519'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv9519');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
Image(filename=str(b.write('lily.png')))

# %%
bChords = b.chordify()

# %%
list(bChords.flat)
# Out:
# [<music21.metadata.Metadata at 0x7f2eeab30f98>,
#  <music21.instrument.Instrument P1: Soprano: >,
#  <music21.layout.SystemLayout>,
#  <music21.clef.TrebleClef>,
#  <music21.key.Key of a minor>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.chord.Chord A3 C4 E4 A4>,
#  <music21.chord.Chord D3 C4 F4 A4>,
#  <music21.chord.Chord E3 C4 E4 A4>,
#  <music21.chord.Chord F3 B3 D4 A4>,
#  <music21.chord.Chord F3 A3 D4 A4>,
#  <music21.chord.Chord E3 B3 E4 G#4>,
#  <music21.chord.Chord D3 B3 E4 G#4>,
#  <music21.chord.Chord C3 C4 E4 A4>,
#  <music21.chord.Chord B2 D4 G#4 B4>,
#  <music21.chord.Chord A2 E4 A4 C5>,
#  <music21.chord.Chord E2 E4 G#4 B4>,
#  <music21.chord.Chord E2 D4 G#4 B4>,
#  <music21.chord.Chord A2 C4 E4 A4>,
#  <music21.chord.Chord A3 C4 E4 C5>,
#  <music21.chord.Chord G3 B3 G4 D5>,
#  <music21.chord.Chord F3 B3 G4 D5>,
#  <music21.chord.Chord E3 B3 G4 D5>,
#  <music21.chord.Chord D3 B3 G4 D5>,
#  <music21.chord.Chord C3 C4 G4 E5>,
#  <music21.chord.Chord D3 C4 G4 E5>,
#  <music21.chord.Chord E3 C4 G4 C5>,
#  <music21.chord.Chord C3 C4 G4 C5>,
#  <music21.chord.Chord F3 C4 A4 D5>,
#  <music21.chord.Chord F3 B3 A4 D5>,
#  <music21.chord.Chord F3 A3 A4 D5>,
#  <music21.chord.Chord E3 B3 G#4 E5>,
#  <music21.chord.Chord E3 B3 G#4 E5>,
#  <music21.chord.Chord A3 C4 A4 E5>,
#  <music21.chord.Chord G3 C4 A4 E5>,
#  <music21.chord.Chord F#3 D4 A4 D5>,
#  <music21.chord.Chord F#3 C4 A4 D5>,
#  <music21.chord.Chord G#3 B3 E4 E5>,
#  <music21.chord.Chord G#3 B3 E4 D5>,
#  <music21.chord.Chord A3 C4 E4 C5>,
#  <music21.chord.Chord G3 B3 E4 C5>,
#  <music21.layout.SystemLayout>,
#  <music21.chord.Chord F3 A3 A4 D5>,
#  <music21.chord.Chord D3 A3 A4 C5>,
#  <music21.chord.Chord E3 E4 A4 B4>,
#  <music21.chord.Chord E3 E4 G#4 B4>,
#  <music21.chord.Chord A2 C4 E4 A4>,
#  <music21.chord.Chord F3 C4 F4 A4>,
#  <music21.chord.Chord F3 D4 F4 B4>,
#  <music21.chord.Chord E3 E4 G4 C5>,
#  <music21.chord.Chord E3 D4 F4 C5>,
#  <music21.chord.Chord A3 C4 E4 C5>,
#  <music21.chord.Chord G3 B3 E4 C5>,
#  <music21.chord.Chord F3 A3 A4 D5>,
#  <music21.chord.Chord F3 B3 A4 D5>,
#  <music21.chord.Chord E3 C4 G4 C5>,
#  <music21.chord.Chord D3 D4 F4 B4>,
#  <music21.chord.Chord C#3 E4 A4>,
#  <music21.chord.Chord C#3 E4 G4 A4>,
#  <music21.chord.Chord D3 D4 F4 A4>,
#  <music21.chord.Chord D3 C#4 E4 A4>,
#  <music21.chord.Chord D3 D4 F4 A4>,
#  <music21.chord.Chord A2 C#4 E4 A4>,
#  <music21.chord.Chord B2 D4 G4 D5>,
#  <music21.chord.Chord C3 C4 G4 E5>,
#  <music21.chord.Chord C3 B3 G4 E5>,
#  <music21.chord.Chord D3 A3 F4 D5>,
#  <music21.chord.Chord E3 A3 F4 D5>,
#  <music21.chord.Chord F3 A3 C4 A4>,
#  <music21.chord.Chord F3 A3 D4 B4>,
#  <music21.chord.Chord E3 G3 E4 C5>,
#  <music21.chord.Chord F#3 A3 E4 C5>,
#  <music21.chord.Chord G#3 B3 E4 B4>,
#  <music21.chord.Chord A3 C4 A4>,
#  <music21.chord.Chord E3 D4 A4 B4>,
#  <music21.chord.Chord E3 D4 G#4 B4>,
#  <music21.chord.Chord A2 C4 E4 A4>,
#  <music21.layout.PageLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.chord.Chord A3 C4 E4 A4>,
#  <music21.chord.Chord D#3 B3 F#4 A4>,
#  <music21.chord.Chord E3 B3 E4 G4>,
#  <music21.chord.Chord A3 E4 C5>,
#  <music21.chord.Chord A3 F#4 C5>,
#  <music21.chord.Chord G3 B3 G4 D5>,
#  <music21.chord.Chord C4 G4 E5>,
#  <music21.chord.Chord B3 D4 G4 D5>,
#  <music21.chord.Chord A3 E4 A4 C5>,
#  <music21.chord.Chord G3 E4 A4 C5>,
#  <music21.chord.Chord F3 A3 A4 D5>,
#  <music21.chord.Chord F3 B3 A4 D5>,
#  <music21.chord.Chord F3 C4 A4 D5>,
#  <music21.chord.Chord G3 B3 G4 D5>,
#  <music21.chord.Chord C3 C4 G4 E5>,
#  <music21.chord.Chord A3 C4 F4 F5>,
#  <music21.chord.Chord G3 C4 G4 E5>,
#  <music21.chord.Chord F3 C4 A4 D5>,
#  <music21.chord.Chord G3 C4 G4 D5>,
#  <music21.chord.Chord G3 C4 E4 D5>,
#  <music21.chord.Chord G2 B3 F4 D5>,
#  <music21.chord.Chord G2 B3 F4 C5>,
#  <music21.chord.Chord C3 G3 E4 C5>,
#  <music21.note.Rest rest>,
#  <music21.layout.SystemLayout>,
#  <music21.chord.Chord C4 G4 E5>,
#  <music21.chord.Chord C4 A4 E5>,
#  <music21.chord.Chord G#3 B3 B4 E5>,
#  <music21.chord.Chord A3 E4 A4 C5>,
#  <music21.chord.Chord G3 E4 A4 C5>,
#  <music21.chord.Chord F3 A3 A4 D5>,
#  <music21.chord.Chord E3 A3 A4 E5>,
#  <music21.chord.Chord D3 D4 A4 F5>,
#  <music21.chord.Chord A2 C#4 A4 E5>,
#  <music21.chord.Chord B2 D4 G4 G5>,
#  <music21.chord.Chord C3 C4 G4 E5>,
#  <music21.chord.Chord C3 B-3 G4 E5>,
#  <music21.chord.Chord C3 A3 C4 F5>,
#  <music21.chord.Chord C3 A3 D4 F5>,
#  <music21.chord.Chord C3 G3 E4 E5>,
#  <music21.chord.Chord C3 G3 F4 D5>,
#  <music21.chord.Chord C3 C4 G4 E5>,
#  <music21.chord.Chord C3 B-3 G4 E5>,
#  <music21.chord.Chord C3 B-3 G4 E5>,
#  <music21.chord.Chord C3 A3 G4 E5>,
#  <music21.chord.Chord C3 A3 A4 F5>,
#  <music21.chord.Chord C3 B3 G4 F5>,
#  <music21.chord.Chord C3 C4 G4 E5>,
#  <music21.chord.Chord D3 C4 F4 E5>,
#  <music21.chord.Chord E3 C4 E4 G5>,
#  <music21.chord.Chord D3 C4 F4 F5>,
#  <music21.chord.Chord E3 C4 G4 E5>,
#  <music21.chord.Chord F3 C4 G4 E5>,
#  <music21.chord.Chord G3 C4 G4 D5>,
#  <music21.chord.Chord G3 A3 G4 D5>,
#  <music21.chord.Chord G2 B3 G4 D5>,
#  <music21.chord.Chord G2 B3 F4 D5>,
#  <music21.chord.Chord C3 G3 E4 C5>,
#  <music21.layout.PageLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.chord.Chord C4 G4 E5>,
#  <music21.chord.Chord B3 C4 A4 E5>,
#  <music21.chord.Chord A3 B3 B4 E5>,
#  <music21.chord.Chord G#3 B3 B4 E5>,
#  <music21.chord.Chord A3 C4 E4 C5>,
#  <music21.chord.Chord G3 B3 E4 C5>,
#  <music21.chord.Chord F3 A3 D4 D5>,
#  <music21.chord.Chord E3 A3 D4 D5>,
#  <music21.chord.Chord F3 F4 A4 C5>,
#  <music21.chord.Chord E3 F4 A4 C5>,
#  <music21.chord.Chord D3 F4 A4 B4>,
#  <music21.chord.Chord E3 E4 G#4 B4>,
#  <music21.chord.Chord E3 D4 G#4 B4>,
#  <music21.chord.Chord F3 C4 A4>,
#  <music21.chord.Chord C3 C4 E4 G4>,
#  <music21.chord.Chord C3 B3 D4 G4>,
#  <music21.chord.Chord F3 A3 C4 A4>,
#  <music21.chord.Chord F3 A3 D4 B4>,
#  <music21.chord.Chord E3 G3 E4 C5>,
#  <music21.chord.Chord E3 F3 D4 C5>,
#  <music21.chord.Chord D3 G3 E4 A4>,
#  <music21.chord.Chord C#3 G3 E4 A4>,
#  <music21.chord.Chord D3 F3 D4 A4>,
#  <music21.chord.Chord E3 G3 B3 G4>,
#  <music21.chord.Chord E3 F3 C4 A4>,
#  <music21.chord.Chord E3 F3 D4 A4>,
#  <music21.chord.Chord E3 F3 E4 A4>,
#  <music21.chord.Chord D3 F3 F4 B4>,
#  <music21.chord.Chord D3 E3 F4 B4>,
#  <music21.chord.Chord D3 F3 F4 B4>,
#  <music21.chord.Chord E3 G3 E4 C5>,
#  <music21.chord.Chord F3 A3 E4 C5>,
#  <music21.chord.Chord G3 B3 E4 B4>,
#  <music21.chord.Chord G3 B3 F4 B4>,
#  <music21.chord.Chord G3 B3 G4 B4>,
#  <music21.chord.Chord G3 C#4 A4>,
#  <music21.chord.Chord F3 D4 A4>,
#  <music21.chord.Chord E3 E4 A4>,
#  <music21.chord.Chord F3 A3 A4>,
#  <music21.chord.Chord D3 D4 G4 A4>,
#  <music21.chord.Chord D3 D4 F4 A4>,
#  <music21.chord.Chord E3 C4 E4 A4>,
#  <music21.chord.Chord E3 B3 E4 A4>,
#  <music21.chord.Chord E3 A3 E4 A4>,
#  <music21.chord.Chord E3 B3 E4 G#4>,
#  <music21.chord.Chord A2 C#4 E4 A4>,
#  <music21.bar.Barline style=final>]

# %%
bChords.show('midi')
# Out:
#                 <div id='midiPlayerDiv13633'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv13633');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
Image(filename=str(bChords.write('lily.png')))

# %%
list(b.chordify())
# Out:
# [<music21.metadata.Metadata at 0x7f439cc05710>,
#  <music21.instrument.Instrument P1: Soprano: >,
#  <music21.stream.Measure 0 offset=0.0>,
#  <music21.stream.Measure 1 offset=1.0>,
#  <music21.stream.Measure 2 offset=5.0>,
#  <music21.stream.Measure 3 offset=9.0>,
#  <music21.stream.Measure 4 offset=13.0>,
#  <music21.stream.Measure 5 offset=17.0>,
#  <music21.stream.Measure 6 offset=21.0>,
#  <music21.stream.Measure 7 offset=25.0>,
#  <music21.stream.Measure 8 offset=29.0>,
#  <music21.stream.Measure 9 offset=33.0>,
#  <music21.stream.Measure 10 offset=37.0>,
#  <music21.stream.Measure 10a offset=40.0>,
#  <music21.stream.Measure 11 offset=41.0>,
#  <music21.stream.Measure 12 offset=45.0>,
#  <music21.stream.Measure 13 offset=49.0>,
#  <music21.stream.Measure 14 offset=53.0>,
#  <music21.stream.Measure 15 offset=57.0>,
#  <music21.stream.Measure 15a offset=60.0>,
#  <music21.stream.Measure 16 offset=61.0>,
#  <music21.stream.Measure 17 offset=65.0>,
#  <music21.stream.Measure 18 offset=69.0>,
#  <music21.stream.Measure 19 offset=73.0>,
#  <music21.stream.Measure 20 offset=77.0>,
#  <music21.stream.Measure 21 offset=81.0>,
#  <music21.stream.Measure 22 offset=85.0>,
#  <music21.stream.Measure 23 offset=89.0>,
#  <music21.stream.Measure 24 offset=93.0>,
#  <music21.stream.Measure 25 offset=97.0>,
#  <music21.stream.Measure 26 offset=101.0>,
#  <music21.stream.Measure 27 offset=105.0>]

# %% [markdown]
# ## Chordify sounds different. Hopefully fluidsynth changes that

# %%
from midi2audio import FluidSynth

sound_font = '/usr/share/sounds/sf2/FluidR3_GM.sf2'

out_file = path/'test_out_3.wav'

player = FluidSynth(sound_font)

# player.play_midi(str(midi_file)) # does not work

player.midi_to_audio(str(midi_file), out_file)

Audio(str(out_file))

# %%
idx = 8
folder_idx = 2 # 2 = bach
seed_len = 250

file = path.ls()[folder_idx].ls()[idx]
with open(file, 'r') as f:
    txt_out = f.read()
notes = txt_out.split(' ')
seed = ' '.join(notes[:seed_len])

note_offset = 45 if 'note_range38' in str(file) else 33
sample_freq = 12 if 'sample_freq12' in str(file) else 4

# %%
seed
# Out:
# 'wait25 wait20 p32 wait3 p16 p32 wait3 p20 wait2 endp20 wait1 p23 wait2 endp23 endp32 wait1 p28 p33 wait2 endp16 wait1 p18 p33 wait3 p28 wait2 endp28 wait1 p27 wait2 endp27 wait1 p25 p32 endp32 p33 endp33 wait2 endp18 endp25 wait1 p20 p35 wait3 p23 wait2 endp23 wait1 p27 wait2 endp27 wait1 p28 wait3 p32 wait3 p35 wait2 endp32 endp35 wait1 p20 wait5 endp20 wait1 p21 p37 wait2 endp37 wait3 endp21 wait1 p20 p35 wait2 endp35 wait3 endp20 wait1 p18 p33 wait2 endp33 wait1 p32 wait2 endp28 endp32 wait1 p27 p33 wait2 endp33 wait3 endp18 endp27 wait1 p16 p33 wait2 endp33 wait1 p32 wait2 endp32 wait1 p20 p30 wait2 endp30 wait1 p28 wait2 endp20 endp28 wait1 p23 p32 wait2 endp16 wait1 p15 wait2 endp15 endp23 wait1 p13 p28 wait2 endp13 wait1 p11 wait2 endp11 endp28 wait1 p10 p25 wait2 endp32 wait1 p37 wait2 endp25 endp37 wait1 p13 p30 wait2 endp30 wait1 p37 wait2 endp13 endp37 wait1 p18 p28 wait2 endp28 wait1 p27 wait2 endp27 wait1 p10 p28 wait2 endp28 wait1 p37 wait2 endp10 endp18 endp37 wait1 p11 p28 wait2 endp28 wait1 p27 wait2 endp27 wait1 p15 p25 wait2 endp25 wait1 p23 wait2 endp15 endp23 wait1 p18 p25 wait2 endp25 wait1 p27 wait2 endp11 endp27 wait1 p9 p28 wait2 endp28 wait1 p27 wait2 endp9 endp18 endp27 wait1 p8 p11 p28 wait2 endp28 wait1 p30 wait2 endp11 endp30 wait1 p16 p28 wait2 endp28 wait1 p30 wait2 endp8 wait1 p6 p30 wait5 endp16 wait1 p15 wait3 p28 endp28 p30 endp30 wait2 endp6 endp15'

# %% [markdown]
# ### Generate from predictions

# %%
from utils import *

# %%
def write_midi(s, filename, output_folder):
    fp = s.write('midi', fp=output_folder/filename)
    
def string_inds_to_stream(string, sample_freq, note_offset, chordwise):
    score_i = string.split(" ")
    return arrToStreamNotewise(score_i, sample_freq, note_offset)
      
def arrToStreamNotewise(score, sample_freq, note_offset):
    speed=1./sample_freq
    piano_notes=[]
    violin_notes=[]
    time_offset=0
    
    i=0
    while i<len(score):
        if score[i][:9]=="p_octave_":
            add_wait=""
            if score[i][-3:]=="eoc":
                add_wait="eoc"
                score[i]=score[i][:-3]
            this_note=score[i][9:]
            score[i]="p"+this_note
            score.insert(i+1, "p"+str(int(this_note)+12)+add_wait)
            i+=1
        i+=1
        
    for i in range(len(score)):
        if score[i] in ["", " ", "<eos>", "<unk>"]:
            continue
        elif score[i][:3]=="end":
            if score[i][-3:]=="eoc":
                time_offset+=1
            continue
        elif score[i][:4]=="wait":
            time_offset+=int(score[i][4:])
            continue
        else:
            # Look ahead to see if an end<noteid> was generated
            # soon after.  
            duration=1
            has_end=False
            note_string_len = len(score[i])
            for j in range(1,200):
                if i+j==len(score):
                    break
                if score[i+j][:4]=="wait":
                    duration+=int(score[i+j][4:])
                if score[i+j][:3+note_string_len]=="end"+score[i] or score[i+j][:note_string_len]==score[i]:
                    has_end=True
                    break
                if score[i+j][-3:]=="eoc":
                    duration+=1

            if not has_end:
                duration=12

            add_wait = 0
            if score[i][-3:]=="eoc":
                score[i]=score[i][:-3]
                add_wait = 1

            try: 
                new_note=music21.note.Note(int(score[i][1:])+note_offset)    
                new_note.duration = music21.duration.Duration(duration*speed)
#                 print(new_note, new_note.duration)
                new_note.offset=time_offset*speed
                if score[i][0]=="v":
                    violin_notes.append(new_note)
                else:
                    piano_notes.append(new_note)                
            except:
                print("Unknown note: " + score[i])

            

            
            time_offset+=add_wait
                
    violin=music21.instrument.fromString("Violin")
    piano=music21.instrument.fromString("Piano")
    violin_notes.insert(0, violin)
    piano_notes.insert(0, piano)
    violin_stream=music21.stream.Stream(violin_notes)
    piano_stream=music21.stream.Stream(piano_notes)
    main_stream = music21.stream.Stream([violin_stream, piano_stream])
    return piano_stream, violin_stream, main_stream

# %%
import music21

# %%
piano_stream, violin_stream, stream_out=string_inds_to_stream(seed, sample_freq, note_offset, False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-798d04d1881a> in <module>
# ----> 1 piano_stream, violin_stream, stream_out=string_inds_to_stream(seed, sample_freq, note_offset, False)
#
# NameError: name 'seed' is not defined

# %%
[(n, n.offset, n.duration) for n in stream_out.flat]

# %%
c = s[0].flat[15]

# %%
[(n, n.offset, n.duration) for n in s[0].flat]

# %%
stream_out
# Out:
# <music21.stream.Stream 0x7fe112ae8978>

# %%
s.show('midi')

# %%
stream_out.show('midi')

# %%
Image(filename=str(s.write('lily.png')))

# %%
Image(filename=str(stream_out.write('lily.png')))

# %%
def write_mid_mp3_wav(stream, fname, sample_freq, note_offset, out, chordwise):
    stream_out=string_inds_to_stream(stream, sample_freq, note_offset, chordwise)
    write_midi(stream_out, fname, out)
    base=out/fname[:-4]
    os.system(f'./data/mid2mp3.sh {base}.mid')
    os.system(f'mpg123 -w {base}.wav {base}.mp3')

# %%
out_dir = Path('tmp_out')
tmp_file = 'testfile.mid'
midi_file = out_dir/tmp_file
if midi_file.exists(): midi_file.unlink()

# %%
result = write_mid_mp3_wav(seed, fname=tmp_file, 
                           sample_freq=sample_freq, note_offset=note_offset, 
                           out=out_dir, chordwise=False)

# %%
from music21 import *
from IPython.display import Image

# %%
mf = midi.MidiFile()
mf.open(midi_file)
mf.read()
mf.close()
s = midi.translate.midiFileToStream(mf)

# %%
d0 = s.flat[15]

# %%
d0.duration
# Out:
# <music21.duration.Duration 0.0>

# %%
[(n,n.duration) for n in s.flat]

# %%
s.show('midi')
# Out:
#                 <div id='midiPlayerDiv1634'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1634');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
Image(filename=str(s.write('lily.png')))

# %%
# %debug
# Out:
# > /home/ubuntu/anaconda3/envs/musical_neural_net/lib/python3.7/site-packages/music21/musicxml/m21ToXml.py(680)addDividerComment()
#     678
#     679         divider = ET.Comment(commentText)
# --> 680         self.xmlRoot.append(divider)
#     681
#     682     #-------------------------------------------------------------------------------
#
# ipdb> quit

# %% [markdown]
# #

# %%
list(b.flat)
# Out:
# [<music21.metadata.Metadata at 0x7fe0feffb5f8>,
#  <music21.instrument.Instrument P1: Soprano: Instrument 1>,
#  <music21.instrument.Instrument P2: Alto: Instrument 2>,
#  <music21.instrument.Instrument P3: Tenor: Instrument 3>,
#  <music21.instrument.Instrument P4: Bass: Instrument 4>,
#  <music21.clef.TrebleClef>,
#  <music21.clef.TrebleClef>,
#  <music21.clef.BassClef>,
#  <music21.clef.BassClef>,
#  <music21.key.Key of f# minor>,
#  <music21.key.Key of f# minor>,
#  <music21.key.Key of f# minor>,
#  <music21.key.Key of f# minor>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.layout.StaffGroup <music21.stream.Part Soprano><music21.stream.Part Alto><music21.stream.Part Tenor><music21.stream.Part Bass>>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.note.Note C#>,
#  <music21.note.Note G#>,
#  <music21.note.Note C#>,
#  <music21.note.Note E#>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note E#>,
#  <music21.note.Note C#>,
#  <music21.note.Note C#>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note D#>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note G#>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note F#>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note G#>,
#  <music21.note.Note B>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.layout.SystemLayout>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C#>,
#  <music21.note.Note G#>,
#  <music21.note.Note C#>,
#  <music21.note.Note E#>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note G#>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note E#>,
#  <music21.note.Note C#>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note C#>,
#  <music21.note.Note E#>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note A#>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note C#>,
#  <music21.note.Note C#>,
#  <music21.note.Note A#>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note E#>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.note.Note A#>,
#  <music21.note.Note F#>,
#  <music21.bar.Barline style=final>,
#  <music21.bar.Barline style=final>,
#  <music21.bar.Barline style=final>,
#  <music21.bar.Barline style=final>]
