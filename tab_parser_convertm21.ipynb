# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import xmltodict
import os
import json
import pickle
from lxml import etree

encoding = "utf-8"


def load_data(file_path):
    with open(file_path, "r", encoding=encoding) as f:
        content = f.read()
    content = content.replace('%20', '')
    return content


def xml_parser(content):
    parser = etree.XMLParser(recover=True, encoding=encoding)
    root = etree.fromstring(content, parser=parser)
    return root


def get_metadata(root):
    meta_list = ['title', 'beats_in_measure', 'BPM', 'key', 'YouTubeID', 'mode']

    metadata = dict()
    for e in meta_list:
        tag = root.find('.//' + e)
        metadata[e] = tag.text if tag is not None else None

    # duration
    tag = root.find('.//duration')
    tag = root.find('.//section_duration') if tag is None else tag
    metadata['duration'] = tag.text if tag is not None else None

    version = root.find('version')
    version = version.text if version is not None else None
    return metadata, version


def get_lead_sheet(root, version):
    segments_tag = root.findall('.//segment')

    # set chord tag according to version
    chord_tag = 'chords' if root.tag == 'super' else 'harmony'

    segment_list = []
    num_measures = 0

    for segment in segments_tag:
        num_measure = float(segment.find('numMeasures').text)

        # melody
        note_tags = segment.findall('.//notes/note')
        note_list = [xmltodict.parse(etree.tostring(n))['note'] for n in note_tags] if note_tags else []

        # chord
        chord_tags = segment.findall('.//' + chord_tag + '/chord')
        chord_list = [xmltodict.parse(etree.tostring(c))['chord'] for c in chord_tags] if chord_tags else []

        segment_list.append({'notes': note_list, 'chords': chord_list, 'num_measure': num_measure})
        num_measures += num_measure

    return segment_list, num_measures


def event_localization(measure_offset, start_beat_abs, duration):
    event_on = measure_offset + start_beat_abs
    event_off = measure_offset + start_beat_abs + duration
    return event_on, event_off

def segments_parser(segments, mode, beats_in_measure):
    measure_counter = 0

    chord_track = []
    melody_track = []

    for sidx, segment in enumerate(segments):
        measure_offset = measure_counter * float(beats_in_measure)

        for chord in segment['chords']:
            chord_track.append(proc_object(chord, measure_offset, type_='chord'))
        for note in segment['notes']:
            melody_track.append(proc_object(note, measure_offset, type_='note'))

        measure_counter += int(segment['num_measure'])

    return melody_track, chord_track

def traverse_dir(root_dir, extension='.xml'):
    file_list = []
    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith(extension):
                file_list.append(os.path.join(root, file))

    return file_list


def get_postfix_dirpath(filename, idx=-4):
    path = os.path.normpath(filename)
    dir_list = path.split(os.sep)
    new_path = ''

    for d in dir_list[idx:]:
        new_path = os.path.join(new_path, d)

    return new_path


def proc_dir(file_list, root):
    num_file = len(file_list)
    for fidx in range(num_file):
        print('(%d/%d)' % (fidx, num_file))
        file_path = file_list[fidx]
        save_path = root
        name = os.path.basename(file_path)
        proc_xml(file_path, save_path=save_path, name=name, save_type='json')

# %%
# mode = int(metadata['mode']) if metadata['mode'] is not None else 1
# beats_in_measure = int(metadata['beats_in_measure'])

# melody, chord = segments_parser(segments, mode, beats_in_measure)

# %%
from pathlib import Path

# %%
version = 'v7'
data_path = Path('data/midi')
version_path = data_path/version
orig_path = version_path/'midi_sources'

# %%
from fastai.data_block import get_files

# %%
h_path = orig_path/'hooktheory'

# %%
files = get_files(h_path, extensions=['.xml'], recurse=True); files[:10]
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wayne-sharpe/yu-gi-oh-theme-song/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/what-a-day/kiefer/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/pre-chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/whiteflame/senbonzakura/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/verse.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/chorus.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/last-christmas/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/w/wham/freedom/chorus.xml')]

# %%
# Loading from specific file
# keywords = ['get-lucky', 'daft-punk', 'pre-chorus']
# keywords = ['skrillex', 'scary']
keywords = ['idina', 'intro', 'let']
def contains_keywords(f): return all([k in str(f) for k in keywords])
search = [f for f in files if contains_keywords(f)]; search
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/i/idina-menzel/let-it-go/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/i/idina-menzel/let-it-go/intro-and-verse.xml')]

# %%
import pprint

file_path = search[0]
# raw_info = proc_xml(file_path)
# pprint.pprint(raw_info)

# %%
content = load_data(file_path)
root = xml_parser(content)
metadata, version = get_metadata(root)
segments, num_measures = get_lead_sheet(root, version)

# %%
import music21

# %% [markdown]
# ### Create config file

# %%
config = dict(sustain=True, sep_octave=True, note_octave=4, chord_octave=2, ts='4/4', ks=0, bpm=120)

# %% [markdown]
# ### Constants

# %% [markdown]
# ### Classes

# %%
MODE_TO_KEYOFFSET = {
    '1': 0,
    '2': 2,
    '3': 4,
    '4': 5,
    '5': 7,
    '6': 9,
    '7': 11
#     '5': -5,
#     '6': -3,
#     '7': -1
}

# %%
PITCH_TO_SD = {
    0: '1',
    1: '1#',
    2: '2',
    3: '2#',
    4: '3',
    5: '4',
    6: '4#',
    7: '5',
    8: '5#',
    9: '6',
    10:'6#',
    11:'7',
}

SD_TO_PITCH = {v:k for k,v in PITCH_TO_SD.items()}

# %%
from dataclasses import dataclass
import dataclasses
from typing import Dict, Any, AnyStr, List, Sequence, TypeVar, Tuple, Optional, Union

# %%
def parse(cls, d):
    cls_keys = cls.__dataclass_fields__.keys()
    kwargs = {key:d[key] for key in cls_keys}
    return cls(**kwargs)

@dataclass
class Base:
    @classmethod
    def from_dict(cls, d):
        cls_keys = cls.__dataclass_fields__.keys()
        kwargs = {key:d[key] for key in cls_keys}
        return cls(**kwargs)
    
    @classmethod
    def parse(cls, d):
        return cls.from_dict(d)

# %%
@dataclass
class HMetadata(Base):
    title:str
    BPM:str='120'
    beats_in_measure:str='4'
    key:str='C'
    mode:str='1'

# %%
@dataclass
class HNote(Base):
    start_beat_abs: str
    start_measure: str
    start_beat: str
    note_length: str
    scale_degree: str
    octave: str
        
    def to_m21(self)->music21.note.Note:
#         if self.scale_degree == 'rest': return None, None
#             n = music21.note.Rest(quarterLength=note_length)
        pitch = self.pitch() + 12*(int(self.octave)+config.note_octave)
        n = music21.note.Note(pitch, quarterLength=note_length)
        return n, self.start_beat_abs
    
    def pitch(self):
        return SD_TO_PITCH[self.scale_degree]
    
    @classmethod
    def parse(cls, d, mode, key_offset):
        if key_offset > 5: key_offset = key_offset-12
        parsed = roman_to_symbol.hnote_parser(d, mode, key_offset)
        pitch = parsed['pitch']
        scale_degree = PITCH_TO_SD[int((pitch+12) % 12)]
        octave = (pitch // 12)
        m = {
            'scale_degree': scale_degree,
            'octave': octave
        }
        return cls.from_dict({**d, **m})

# %%
@dataclass
class HChord(Base):
    # ht relative
    sd:str
    fb:str
    sus:str
    
    # ht tempo
    chord_duration:str
    start_measure:str
    start_beat:str
    start_beat_abs:str
        
    # abs
    symbol:str
    quality:str
    composition:List[int]
        
    def to_m21(self)->music21.chord.Chord:
        c = music21.chord.Chord(self.composition, quarterLength=self.note_length)
        c.octave = config.chord_octave
        return c, self.start_beat_abs
    
    @classmethod
    def parse(cls, d, mode, key_offset):
        parsed = roman_to_symbol.hchord_parser(d, mode, key_offset)
        parsed['composition'] = parsed['composition'].astype(int).tolist()
        return cls.from_dict({**d, **parsed})

# %%
def default_stream(cls=music21.stream.Stream, ts='4/4', bpm=120, ks=0)
    # (AS) TODO: use config ts or metadata
    s = cls()
    s.append(music21.instrument.Piano())
    s.append(music21.meter.TimeSignature(ts))
    s.append(music21.tempo.MetronomeMark(number=bpm))
    s.append(music21.key.KeySignature(ks))
    return s
# Out:
#   File "<ipython-input-21-f289284bb8df>", line 1
#     def default_stream(cls=music21.stream.Stream, ts='4/4', bpm=120, ks=0)
#                                                                           ^
# SyntaxError: invalid syntax

# %%
@dataclass
class HPart(Base):
    notes: List[HNote]
    chords: List[HChord]
        
    @classmethod
    def parse(cls, d, metadata):
        mode = metadata['mode']
        key_offset = MODE_TO_KEYOFFSET.get(mode, 0)
        ns = [HNote.parse(n, mode, key_offset) for n in d.get('notes', []) if n['scale_degree'] != 'rest']
        cs = [HChord.parse(c, mode, key_offset) for c in d.get('chords', []) if c['sd'] != 'rest']
        return cls(notes=ns, chords=cs)
    
    def to_m21(self)->music21.stream.Stream:
#         s = music21.stream.Stream
        pc = music21.stream.Part()
        pn = music21.stream.Part()
        
        cm21 = [c.to_m21() for c in self.chords]
        for c,d in cm21: pc.insert(d,c)
            
        nm21 = [n.to_m21() for n in self.notes]
        for n,d in nm21: pn.insert(d,n)
            
        return nm21, cm21
        
    def min_pitch(self):
        return min([n.pitch for n in self.notes])

# %%
@dataclass
class HSong(Base):
    metadata: HMetadata
    parts: List[HPart]
    
    @classmethod
    def parse(cls, metadata, segments):
        m = HMetadata.parse(metadata)
        ps = [HPart.parse(s, metadata) for s in segments]
        return cls(metadata=m, parts=ps)
    
    def to_stream(self):
        # music21 stream
        return None

# %%
# s = HSong.parse(metadata, segments)

# %%
# translator
class Translator():
    @classmethod
    def to_numpy(cls, s:HSong):
        pass
    @classmethod
    def to_song(cls, arr):
        pass

# %%
from src import roman_to_symbol
from src import to_pianoroll
from collections import defaultdict
from midi_data import keyc_offset

# %%
# parsed = [roman_to_symbol.hchord_parser(c, metadata['mode'], 7) for c in segments[0]['chords']]

# %% [markdown]
# Skrillex
# G minor -> 9 offset -> C major
#
# minor = 5, G->C=
#
# Daft Punk
# B dorian -> 2 offset -> C major
#
# Let it go
# F minor -> 9 offset -> C major
#
# Game of thrones
# C minor -> 9 offset -> C major

# %%
# Loading from specific file
# keywords = ['get-lucky', 'daft-punk', 'pre-chorus']
# keywords = ['skrillex', 'scary']
keywords = ['idina', 'intro', 'let']
# keywords = ['game-of-thrones', 'intro', 'ramin']
# keywords = ['kiss-from-a-rose', 'seal']
def contains_keywords(f): return all([k in str(f) for k in keywords])
search = [f for f in files if contains_keywords(f)]; search
# Out:
# [PosixPath('data/midi/v7/midi_sources/hooktheory/xml/i/idina-menzel/let-it-go/intro.xml'),
#  PosixPath('data/midi/v7/midi_sources/hooktheory/xml/i/idina-menzel/let-it-go/intro-and-verse.xml')]

# %%
file_path = search[0]
content = load_data(file_path)
root = xml_parser(content)
metadata, version = get_metadata(root)
segments, num_measures = get_lead_sheet(root, version)

# %%
key_offset = MODE_TO_KEYOFFSET.get(metadata['mode'], 0)
# key_offset = roman_to_symbol.get_key_offset(metadata['key']); key_offset # this is offset to key not to c

# %%
parsed = [roman_to_symbol.hchord_parser(c, metadata['mode'], key_offset) for c in segments[0]['chords']]

# %%
s = HSong.parse(metadata, segments)

# %%
s.parts[0].notes
# Out:
# [HNote(start_beat_abs='0', start_measure='1', start_beat='1', note_length='0.5', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='0.5', start_measure='1', start_beat='1.5', note_length='0.5', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='1', start_measure='1', start_beat='2', note_length='0.5', scale_degree='3', octave=0.0),
#  HNote(start_beat_abs='1.5', start_measure='1', start_beat='2.5', note_length='1', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='2.5', start_measure='1', start_beat='3.5', note_length='0.5', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='4', start_measure='2', start_beat='1', note_length='0.5', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='4.5', start_measure='2', start_beat='1.5', note_length='0.5', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='5', start_measure='2', start_beat='2', note_length='0.5', scale_degree='3', octave=0.0),
#  HNote(start_beat_abs='5.5', start_measure='2', start_beat='2.5', note_length='1', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='6.5', start_measure='2', start_beat='3.5', note_length='1', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='7.5', start_measure='2', start_beat='4.5', note_length='0.5', scale_degree='2', octave=0.0),
#  HNote(start_beat_abs='8', start_measure='3', start_beat='1', note_length='0.5', scale_degree='6', octave=0.0),
#  HNote(start_beat_abs='8.5', start_measure='3', start_beat='1.5', note_length='0.5', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='9', start_measure='3', start_beat='2', note_length='0.5', scale_degree='2', octave=0.0),
#  HNote(start_beat_abs='9.5', start_measure='3', start_beat='2.5', note_length='1', scale_degree='6', octave=0.0),
#  HNote(start_beat_abs='10.5', start_measure='3', start_beat='3.5', note_length='1', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='11.5', start_measure='3', start_beat='4.5', note_length='0.5', scale_degree='2', octave=0.0),
#  HNote(start_beat_abs='12', start_measure='4', start_beat='1', note_length='2', scale_degree='5', octave=0.0),
#  HNote(start_beat_abs='14', start_measure='4', start_beat='3', note_length='2', scale_degree='4', octave=0.0),
#  HNote(start_beat_abs='16', start_measure='5', start_beat='1', note_length='0.5', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='16.5', start_measure='5', start_beat='1.5', note_length='0.5', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='17', start_measure='5', start_beat='2', note_length='0.5', scale_degree='3', octave=0.0),
#  HNote(start_beat_abs='17.5', start_measure='5', start_beat='2.5', note_length='1', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='18.5', start_measure='5', start_beat='3.5', note_length='0.5', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='20', start_measure='6', start_beat='1', note_length='0.5', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='20.5', start_measure='6', start_beat='1.5', note_length='0.5', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='21', start_measure='6', start_beat='2', note_length='0.5', scale_degree='3', octave=0.0),
#  HNote(start_beat_abs='21.5', start_measure='6', start_beat='2.5', note_length='1', scale_degree='1', octave=1.0),
#  HNote(start_beat_abs='22.5', start_measure='6', start_beat='3.5', note_length='1', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='23.5', start_measure='6', start_beat='4.5', note_length='0.5', scale_degree='2', octave=0.0),
#  HNote(start_beat_abs='24', start_measure='7', start_beat='1', note_length='0.5', scale_degree='6', octave=0.0),
#  HNote(start_beat_abs='24.5', start_measure='7', start_beat='1.5', note_length='0.5', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='25', start_measure='7', start_beat='2', note_length='0.5', scale_degree='2', octave=0.0),
#  HNote(start_beat_abs='25.5', start_measure='7', start_beat='2.5', note_length='1', scale_degree='6', octave=0.0),
#  HNote(start_beat_abs='26.5', start_measure='7', start_beat='3.5', note_length='1', scale_degree='7', octave=0.0),
#  HNote(start_beat_abs='27.5', start_measure='7', start_beat='4.5', note_length='0.5', scale_degree='2', octave=0.0),
#  HNote(start_beat_abs='28', start_measure='8', start_beat='1', note_length='2', scale_degree='5', octave=0.0),
#  HNote(start_beat_abs='30', start_measure='8', start_beat='3', note_length='2', scale_degree='4#', octave=0.0)]

# %%
# %debug
# Out:
# > <ipython-input-20-94ac2517c786>(27)parse()
#      24     @classmethod
#      25     def parse(cls, d, mode, key_offset):
#      26         parsed = [roman_to_symbol.hchord_parser(d, mode, key_offset)]
# ---> 27         parsed['composition'] = parsed['composition'].astype(int).tolist()
#      28         return cls.from_dict({**d, **parsed})
#
# ipdb> parsed
# [OrderedDict([('root', 9), ('bass', 9), ('comp_vec', array([9, None, 12, None, 16, None, None, None, None], dtype=object)), ('composition', array([9, 12, 16], dtype=object)), ('quality', 'm'), ('chord_type', 5), ('chord_mode', -3), ('inv', 0), ('sus', None), ('alter', None), ('emb', []), ('alter_map', None), ('symbol', 'am')])]
# ipdb> parsed['composition']
# *** TypeError: list indices must be integers or slices, not str
# ipdb> parsed[0]
# OrderedDict([('root', 9), ('bass', 9), ('comp_vec', array([9, None, 12, None, 16, None, None, None, None], dtype=object)), ('composition', array([9, 12, 16], dtype=object)), ('quality', 'm'), ('chord_type', 5), ('chord_mode', -3), ('inv', 0), ('sus', None), ('alter', None), ('emb', []), ('alter_map', None), ('symbol', 'am')])
# ipdb> quit

# %%
# %debug
# Out:
# > <ipython-input-49-0d71b7202dfa>(24)parse()
#      22         if key_offset > 5: key_offset = key_offset-12
#      23         parsed = roman_to_symbol.hnote_parser(d, mode, key_offset)
# ---> 24         pitch = parsed['pitch']
#      25         scale_degree = PITCH_TO_SD[int((pitch+12) % 12)]
#      26         octave = (pitch // 12)
#
# ipdb> parsed
# ipdb> d
# *** Newest frame
# ipdb> !d
# OrderedDict([('start_beat_abs', '3'), ('start_measure', '1'), ('start_beat', '4'), ('note_length', '1'), ('scale_degree', 'rest'), ('octave', '0'), ('isRest', '1')])
# ipdb> mode
# '6'
# ipdb> key_offset
# -3
# ipdb> quit

# %%
[(p['symbol'], p['chord_type']) for p in parsed]
# Out:
# [('am', 5),
#  ('Fmaj7', 7),
#  ('G sus2', 5),
#  ('dm sus4', 5),
#  ('dm', 5),
#  ('am', 5),
#  ('Fmaj7', 7),
#  ('G sus2', 5),
#  ('D sus4', 5),
#  ('D', 5)]

# %%
segments[0]['chords']
# Out:
# [OrderedDict([('sd', '1'),
#               ('fb', None),
#               ('sec', None),
#               ('sus', None),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', None),
#               ('chord_duration', '4'),
#               ('start_measure', '1'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '6'),
#               ('fb', '7'),
#               ('sec', None),
#               ('emb', None),
#               ('sus', None),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', None),
#               ('chord_duration', '4'),
#               ('start_measure', '2'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '4'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '7'),
#               ('fb', None),
#               ('sec', None),
#               ('emb', None),
#               ('sus', 'sus2'),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', '-2'),
#               ('chord_duration', '4'),
#               ('start_measure', '3'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '8'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '4'),
#               ('fb', None),
#               ('sec', None),
#               ('sus', 'sus4'),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', None),
#               ('chord_duration', '2'),
#               ('start_measure', '4'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '12'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '4'),
#               ('fb', None),
#               ('sec', None),
#               ('sus', None),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', None),
#               ('chord_duration', '2'),
#               ('start_measure', '4'),
#               ('start_beat', '3'),
#               ('start_beat_abs', '14'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '1'),
#               ('fb', None),
#               ('sec', None),
#               ('sus', None),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', None),
#               ('chord_duration', '4'),
#               ('start_measure', '5'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '16'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '6'),
#               ('fb', '7'),
#               ('sec', None),
#               ('sus', None),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', None),
#               ('chord_duration', '4'),
#               ('start_measure', '6'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '20'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '7'),
#               ('fb', None),
#               ('sec', None),
#               ('sus', 'sus2'),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', None),
#               ('chord_duration', '4'),
#               ('start_measure', '7'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '24'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '4'),
#               ('fb', None),
#               ('sec', None),
#               ('sus', 'sus4'),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', '-2'),
#               ('chord_duration', '2'),
#               ('start_measure', '8'),
#               ('start_beat', '1'),
#               ('start_beat_abs', '28'),
#               ('isRest', '0')]),
#  OrderedDict([('sd', '4'),
#               ('fb', None),
#               ('sec', None),
#               ('sus', None),
#               ('pedal', None),
#               ('alternate', None),
#               ('borrowed', '-2'),
#               ('chord_duration', '2'),
#               ('start_measure', '8'),
#               ('start_beat', '3'),
#               ('start_beat_abs', '30'),
#               ('isRest', '0')])]

# %%
parsed # no offset
# Out:
# [OrderedDict([('root', 9),
#               ('bass', 9),
#               ('comp_vec',
#                array([9, None, 12, None, 16, None, None, None, None], dtype=object)),
#               ('composition', array([9, 12, 16], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'am')]),
#  OrderedDict([('root', 5),
#               ('bass', 5),
#               ('comp_vec',
#                array([5, None, 9, None, 12, 16, None, None, None], dtype=object)),
#               ('composition', array([5, 9, 12, 16], dtype=object)),
#               ('quality', 'maj'),
#               ('chord_type', 7),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'Fmaj7')]),
#  OrderedDict([('root', 7),
#               ('bass', 7),
#               ('comp_vec',
#                array([7, 9, None, None, 14, None, None, None, None], dtype=object)),
#               ('composition', array([7, 9, 14], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', 'sus2'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'G sus2')]),
#  OrderedDict([('root', 2),
#               ('bass', 2),
#               ('comp_vec',
#                array([2, None, None, 7, 9, None, None, None, None], dtype=object)),
#               ('composition', array([2, 7, 9], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', 'sus4'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'dm sus4')]),
#  OrderedDict([('root', 2),
#               ('bass', 2),
#               ('comp_vec',
#                array([2, None, 5, None, 9, None, None, None, None], dtype=object)),
#               ('composition', array([2, 5, 9], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'dm')]),
#  OrderedDict([('root', 9),
#               ('bass', 9),
#               ('comp_vec',
#                array([9, None, 12, None, 16, None, None, None, None], dtype=object)),
#               ('composition', array([9, 12, 16], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'am')]),
#  OrderedDict([('root', 5),
#               ('bass', 5),
#               ('comp_vec',
#                array([5, None, 9, None, 12, 16, None, None, None], dtype=object)),
#               ('composition', array([5, 9, 12, 16], dtype=object)),
#               ('quality', 'maj'),
#               ('chord_type', 7),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'Fmaj7')]),
#  OrderedDict([('root', 7),
#               ('bass', 7),
#               ('comp_vec',
#                array([7, 9, None, None, 14, None, None, None, None], dtype=object)),
#               ('composition', array([7, 9, 14], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', 'sus2'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'G sus2')]),
#  OrderedDict([('root', 2),
#               ('bass', 2),
#               ('comp_vec',
#                array([2, None, None, 7, 9, None, None, None, None], dtype=object)),
#               ('composition', array([2, 7, 9], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', 'sus4'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'D sus4')]),
#  OrderedDict([('root', 2),
#               ('bass', 2),
#               ('comp_vec',
#                array([2, None, 6, None, 9, None, None, None, None], dtype=object)),
#               ('composition', array([2, 6, 9], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'D')])]

# %%
parsed
# Out:
# [OrderedDict([('root', 9),
#               ('bass', 21),
#               ('comp_vec',
#                array([21, None, 24, None, 28, None, None, None, None], dtype=object)),
#               ('composition', array([21, 24, 28], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'am')]),
#  OrderedDict([('root', 5),
#               ('bass', 29),
#               ('comp_vec',
#                array([29, None, 33, None, 36, 40, None, None, None], dtype=object)),
#               ('composition', array([29, 33, 36, 40], dtype=object)),
#               ('quality', 'maj'),
#               ('chord_type', 7),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'Fmaj7')]),
#  OrderedDict([('root', 7),
#               ('bass', 31),
#               ('comp_vec',
#                array([31, 33, None, None, 38, None, None, None, None], dtype=object)),
#               ('composition', array([31, 33, 38], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', 'sus2'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'G sus2')]),
#  OrderedDict([('root', 2),
#               ('bass', 26),
#               ('comp_vec',
#                array([26, None, None, 31, 33, None, None, None, None], dtype=object)),
#               ('composition', array([26, 31, 33], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', 'sus4'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'dm sus4')]),
#  OrderedDict([('root', 2),
#               ('bass', 26),
#               ('comp_vec',
#                array([26, None, 29, None, 33, None, None, None, None], dtype=object)),
#               ('composition', array([26, 29, 33], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'dm')]),
#  OrderedDict([('root', 9),
#               ('bass', 21),
#               ('comp_vec',
#                array([21, None, 24, None, 28, None, None, None, None], dtype=object)),
#               ('composition', array([21, 24, 28], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'am')]),
#  OrderedDict([('root', 5),
#               ('bass', 29),
#               ('comp_vec',
#                array([29, None, 33, None, 36, 40, None, None, None], dtype=object)),
#               ('composition', array([29, 33, 36, 40], dtype=object)),
#               ('quality', 'maj'),
#               ('chord_type', 7),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'Fmaj7')]),
#  OrderedDict([('root', 7),
#               ('bass', 31),
#               ('comp_vec',
#                array([31, 33, None, None, 38, None, None, None, None], dtype=object)),
#               ('composition', array([31, 33, 38], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', 'sus2'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'G sus2')]),
#  OrderedDict([('root', 2),
#               ('bass', 26),
#               ('comp_vec',
#                array([26, None, None, 31, 33, None, None, None, None], dtype=object)),
#               ('composition', array([26, 31, 33], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', 'sus4'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'D sus4')]),
#  OrderedDict([('root', 2),
#               ('bass', 26),
#               ('comp_vec',
#                array([26, None, 30, None, 33, None, None, None, None], dtype=object)),
#               ('composition', array([26, 30, 33], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'D')])]

# %%
parsed
# Out:
# [OrderedDict([('root', 9),
#               ('bass', 9),
#               ('comp_vec',
#                array([9, None, 12, None, 16, None, None, None, None], dtype=object)),
#               ('composition', array([9, 12, 16], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'am')]),
#  OrderedDict([('root', 5),
#               ('bass', 17),
#               ('comp_vec',
#                array([17, None, 21, None, 24, 28, None, None, None], dtype=object)),
#               ('composition', array([17, 21, 24, 28], dtype=object)),
#               ('quality', 'maj'),
#               ('chord_type', 7),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'Fmaj7')]),
#  OrderedDict([('root', 7),
#               ('bass', 19),
#               ('comp_vec',
#                array([19, 21, None, None, 26, None, None, None, None], dtype=object)),
#               ('composition', array([19, 21, 26], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', 'sus2'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'G sus2')]),
#  OrderedDict([('root', 2),
#               ('bass', 14),
#               ('comp_vec',
#                array([14, None, None, 19, 21, None, None, None, None], dtype=object)),
#               ('composition', array([14, 19, 21], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', 'sus4'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'dm sus4')]),
#  OrderedDict([('root', 2),
#               ('bass', 14),
#               ('comp_vec',
#                array([14, None, 17, None, 21, None, None, None, None], dtype=object)),
#               ('composition', array([14, 17, 21], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'dm')]),
#  OrderedDict([('root', 9),
#               ('bass', 9),
#               ('comp_vec',
#                array([9, None, 12, None, 16, None, None, None, None], dtype=object)),
#               ('composition', array([9, 12, 16], dtype=object)),
#               ('quality', 'm'),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'am')]),
#  OrderedDict([('root', 5),
#               ('bass', 17),
#               ('comp_vec',
#                array([17, None, 21, None, 24, 28, None, None, None], dtype=object)),
#               ('composition', array([17, 21, 24, 28], dtype=object)),
#               ('quality', 'maj'),
#               ('chord_type', 7),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'Fmaj7')]),
#  OrderedDict([('root', 7),
#               ('bass', 19),
#               ('comp_vec',
#                array([19, 21, None, None, 26, None, None, None, None], dtype=object)),
#               ('composition', array([19, 21, 26], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -3),
#               ('inv', 0),
#               ('sus', 'sus2'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'G sus2')]),
#  OrderedDict([('root', 2),
#               ('bass', 14),
#               ('comp_vec',
#                array([14, None, None, 19, 21, None, None, None, None], dtype=object)),
#               ('composition', array([14, 19, 21], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', 'sus4'),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'D sus4')]),
#  OrderedDict([('root', 2),
#               ('bass', 14),
#               ('comp_vec',
#                array([14, None, 18, None, 21, None, None, None, None], dtype=object)),
#               ('composition', array([14, 18, 21], dtype=object)),
#               ('quality', ''),
#               ('chord_type', 5),
#               ('chord_mode', -2),
#               ('inv', 0),
#               ('sus', None),
#               ('alter', None),
#               ('emb', []),
#               ('alter_map', None),
#               ('symbol', 'D')])]

# %%
segments[0]['notes']
# Out:
# [OrderedDict([('start_beat_abs', '0'),
#               ('start_measure', '1'),
#               ('start_beat', '1'),
#               ('note_length', '0.5'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '0.5'),
#               ('start_measure', '1'),
#               ('start_beat', '1.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '1'),
#               ('start_measure', '1'),
#               ('start_beat', '2'),
#               ('note_length', '0.5'),
#               ('scale_degree', '5'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '1.5'),
#               ('start_measure', '1'),
#               ('start_beat', '2.5'),
#               ('note_length', '1'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '2.5'),
#               ('start_measure', '1'),
#               ('start_beat', '3.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '3'),
#               ('start_measure', '1'),
#               ('start_beat', '4'),
#               ('note_length', '1'),
#               ('scale_degree', 'rest'),
#               ('octave', '0'),
#               ('isRest', '1')]),
#  OrderedDict([('start_beat_abs', '4'),
#               ('start_measure', '2'),
#               ('start_beat', '1'),
#               ('note_length', '0.5'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '4.5'),
#               ('start_measure', '2'),
#               ('start_beat', '1.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '5'),
#               ('start_measure', '2'),
#               ('start_beat', '2'),
#               ('note_length', '0.5'),
#               ('scale_degree', '5'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '5.5'),
#               ('start_measure', '2'),
#               ('start_beat', '2.5'),
#               ('note_length', '1'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '6.5'),
#               ('start_measure', '2'),
#               ('start_beat', '3.5'),
#               ('note_length', '1'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '7.5'),
#               ('start_measure', '2'),
#               ('start_beat', '4.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '4'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '8'),
#               ('start_measure', '3'),
#               ('start_beat', '1'),
#               ('note_length', '0.5'),
#               ('scale_degree', '1'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '8.5'),
#               ('start_measure', '3'),
#               ('start_beat', '1.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '9'),
#               ('start_measure', '3'),
#               ('start_beat', '2'),
#               ('note_length', '0.5'),
#               ('scale_degree', '4'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '9.5'),
#               ('start_measure', '3'),
#               ('start_beat', '2.5'),
#               ('note_length', '1'),
#               ('scale_degree', '1'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '10.5'),
#               ('start_measure', '3'),
#               ('start_beat', '3.5'),
#               ('note_length', '1'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '11.5'),
#               ('start_measure', '3'),
#               ('start_beat', '4.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '4'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '12'),
#               ('start_measure', '4'),
#               ('start_beat', '1'),
#               ('note_length', '2'),
#               ('scale_degree', '7'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '14'),
#               ('start_measure', '4'),
#               ('start_beat', '3'),
#               ('note_length', '2'),
#               ('scale_degree', '6'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '16'),
#               ('start_measure', '5'),
#               ('start_beat', '1'),
#               ('note_length', '0.5'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '16.5'),
#               ('start_measure', '5'),
#               ('start_beat', '1.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '17'),
#               ('start_measure', '5'),
#               ('start_beat', '2'),
#               ('note_length', '0.5'),
#               ('scale_degree', '5'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '17.5'),
#               ('start_measure', '5'),
#               ('start_beat', '2.5'),
#               ('note_length', '1'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '18.5'),
#               ('start_measure', '5'),
#               ('start_beat', '3.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '19'),
#               ('start_measure', '5'),
#               ('start_beat', '4'),
#               ('note_length', '1'),
#               ('scale_degree', 'rest'),
#               ('octave', '0'),
#               ('isRest', '1')]),
#  OrderedDict([('start_beat_abs', '20'),
#               ('start_measure', '6'),
#               ('start_beat', '1'),
#               ('note_length', '0.5'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '20.5'),
#               ('start_measure', '6'),
#               ('start_beat', '1.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '21'),
#               ('start_measure', '6'),
#               ('start_beat', '2'),
#               ('note_length', '0.5'),
#               ('scale_degree', '5'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '21.5'),
#               ('start_measure', '6'),
#               ('start_beat', '2.5'),
#               ('note_length', '1'),
#               ('scale_degree', '3'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '22.5'),
#               ('start_measure', '6'),
#               ('start_beat', '3.5'),
#               ('note_length', '1'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '23.5'),
#               ('start_measure', '6'),
#               ('start_beat', '4.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '4'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '24'),
#               ('start_measure', '7'),
#               ('start_beat', '1'),
#               ('note_length', '0.5'),
#               ('scale_degree', '1'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '24.5'),
#               ('start_measure', '7'),
#               ('start_beat', '1.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '25'),
#               ('start_measure', '7'),
#               ('start_beat', '2'),
#               ('note_length', '0.5'),
#               ('scale_degree', '4'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '25.5'),
#               ('start_measure', '7'),
#               ('start_beat', '2.5'),
#               ('note_length', '1'),
#               ('scale_degree', '1'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '26.5'),
#               ('start_measure', '7'),
#               ('start_beat', '3.5'),
#               ('note_length', '1'),
#               ('scale_degree', '2'),
#               ('octave', '1'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '27.5'),
#               ('start_measure', '7'),
#               ('start_beat', '4.5'),
#               ('note_length', '0.5'),
#               ('scale_degree', '4'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '28'),
#               ('start_measure', '8'),
#               ('start_beat', '1'),
#               ('note_length', '2'),
#               ('scale_degree', '7'),
#               ('octave', '0'),
#               ('isRest', '0')]),
#  OrderedDict([('start_beat_abs', '30'),
#               ('start_measure', '8'),
#               ('start_beat', '3'),
#               ('note_length', '2'),
#               ('scale_degree', '6s'),
#               ('octave', '0'),
#               ('isRest', '0')])]

# %%
parsed_p = [roman_to_symbol.hnote_parser(c, metadata['mode'], key_offset) for c in segments[0]['notes']]

# %%
[p['pitch'] for p in parsed_p if p is not None]
# Out:
# [23.0,
#  24.0,
#  16.0,
#  23.0,
#  24.0,
#  23.0,
#  24.0,
#  16.0,
#  24.0,
#  23.0,
#  14.0,
#  21.0,
#  23.0,
#  14.0,
#  21.0,
#  23.0,
#  14.0,
#  19.0,
#  17.0,
#  23.0,
#  24.0,
#  16.0,
#  23.0,
#  24.0,
#  24.0,
#  23.0,
#  16.0,
#  24.0,
#  23.0,
#  14.0,
#  21.0,
#  23.0,
#  14.0,
#  21.0,
#  23.0,
#  14.0,
#  19.0,
#  18.0]

# %%
parsed_c['comp_vec']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-eb3cf1077806> in <module>
# ----> 1 parsed_c['comp_vec']
#
# NameError: name 'parsed_c' is not defined

# %%
parsed_c['composition']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-328f599b5abc> in <module>
# ----> 1 parsed_c['composition']
#
# NameError: name 'parsed_c' is not defined

# %%
music21.chord.Chord([0,4,7,11])
# Out:
# <music21.chord.Chord C E G B>

# %%
out = parsed_c['composition'].astype(int).tolist()

music21.chord.Chord(out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-b8c12b76849d> in <module>
# ----> 1 out = parsed_c['composition'].astype(int).tolist()
#
# NameError: name 'parsed_c' is not defined

# %%
comp = to_pianoroll.to_chromagram(parsed_c['composition'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-b4d083a6b98f> in <module>
# ----> 1 comp = to_pianoroll.to_chromagram(parsed_c['composition'])
#
# NameError: name 'parsed_c' is not defined

# %%
comp
# Out:
# array([2, 5, 9, 0], dtype=object)

# %%
music21.chord.composition
