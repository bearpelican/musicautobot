# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from encode_data import *
from midi_data import *

# %%
from tqdm import tqdm
import pandas as pd
from data_sources import process_parallel

# %%
from collections import Counter

# %%
import scipy.sparse

# %% [markdown]
# ## Encode music21 stream to text representation
#
# This notebook uses a full component format
# - measure separators, instruments, and separated octaves
# - Format: note, octave, action type, instrument
# - note repr: nG# o4 t1 i0

# %% [markdown]
# ### Load midi data

# %%
path = Path('data/midi')

# %%
source_dir = 'midi_transform_v2'
out_dir = 'midi_npz_v2'
source_csv = path/source_dir/f'{source_dir}.csv'
out_csv = path/out_dir/f'{out_dir}.csv'

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2,10,11,16,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        source                title             midi_title  inferred_offset  \
# 0  hooktheory  yu-gi-oh-theme-song              yu-gi-oh3              0.0
# 1  hooktheory        beverly-hills            My New Song              NaN
# 2  hooktheory      falling-for-you  falling for you intro             -3.0
# 3  hooktheory          buddy-holly            Buddy Holly              4.0
# 4  hooktheory   dreams-of-grandeur     dreams of grandeur             -2.0
#
#   inferred_key  ht_offset  ht_mode        artist    seconds    bpm  \
# 0      C major        0.0      1.0  wayne-sharpe  15.000000  128.0
# 1          NaN        0.0      NaN        weezer        NaN    NaN
# 2     E- major       -3.0      1.0        weezer  11.111111  108.0
# 3     A- major        4.0      1.0        weezer  43.388430  121.0
# 4      B minor        3.0      1.0        wavves  21.333333  180.0
#
#                          ...                         ht_key  instruments  \
# 0                        ...                              C  Piano,Piano
# 1                        ...                              C          NaN
# 2                        ...                             Eb  Piano,Piano
# 3                        ...                             Ab  Piano,Piano
# 4                        ...                              A  Piano,Piano
#
#   time_signature ht_time_signature  ht_bpm  \
# 0            4/4               4.0   128.0
# 1            NaN               4.0   128.0
# 2            4/4               4.0   108.0
# 3            4/4               4.0   121.0
# 4            4/4               4.0   180.0
#
#                                             song_url  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...
# 1  https://www.hooktheory.com/theorytab/view/weez...
# 2  https://www.hooktheory.com/theorytab/view/weez...
# 3  https://www.hooktheory.com/theorytab/view/weez...
# 4  https://www.hooktheory.com/theorytab/view/wavv...
#
#                                                 midi  \
# 0  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 1  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 2  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 3  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 4  data/midi/midi_sources/hooktheory/pianoroll/w/...
#
#                                  parts    genres  \
# 0                         intro,chorus       NaN
# 1                      intro-and-verse       NaN
# 2              intro,verse,chorus,solo       NaN
# 3  verse,pre-chorus,chorus,bridge,solo  Pop,Rock
# 4                                verse       NaN
#
#                                    midi_transform_v2
# 0  data/midi/midi_transform_v2/hooktheory/pianoro...
# 1                                                NaN
# 2  data/midi/midi_transform_v2/hooktheory/pianoro...
# 3  data/midi/midi_transform_v2/hooktheory/pianoro...
# 4  data/midi/midi_transform_v2/hooktheory/pianoro...
#
# [5 rows x 21 columns]

# %%
df_filtered = df.loc[df['time_signature'] == '4/4']; df_filtered.shape
# Out:
# (30201, 21)

# %%
def transcribe_file(idxrow):
    idx,row = idxrow
    midi_file = row[source_dir]
    if not isinstance(midi_file, str) or not Path(midi_file).exists(): return idx,None
    out_file = Path(midi_file.replace(f'/{source_dir}/', f'/{out_dir}/')).with_suffix('.npz')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): return idx,str(out_file)
    try:
        stream = file2stream(midi_file) # 1.
        chordarr = stream2chordarr(stream) # 2.
        if row.source != 'hooktheory': # keep hooktheory
            chord_short = compress_chordarr(chordarr)
            delta_trim = chordarr.shape[0] - chord_short.shape[0]
            if delta_trim > 100: print(f'Removed {delta_trim} rests from {midi_file}')
            chordarr = chord_short
        save_chordarr(out_file, chordarr)
        return idx,str(out_file)
    except Exception as e:
        print('Error converting midi to sequence', e)
    return idx,None

# %%
# for r in df_filtered.iterrows():
#     transcribe_file(r)

# %%
transcribed_files = process_parallel(transcribe_file, df_filtered.iterrows(), total=df_filtered.shape[0])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='30201' class='' max='30201', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [30201/30201 00:08<00:00]
#     </div>

# %%
tdf = pd.DataFrame(data={out_dir: list(transcribed_files.values())}, index=list(transcribed_files.keys()))

# %%
merged_df = df.join(tdf, how='outer'); tdf.shape, df.shape, merged_df.shape
# Out:
# ((30201, 1), (33746, 21), (33746, 22))

# %%
merged_df.to_csv(out_csv, index=False); merged_df.head()
# Out:
#        source                title             midi_title  inferred_offset  \
# 0  hooktheory  yu-gi-oh-theme-song              yu-gi-oh3              0.0
# 1  hooktheory        beverly-hills            My New Song              NaN
# 2  hooktheory      falling-for-you  falling for you intro             -3.0
# 3  hooktheory          buddy-holly            Buddy Holly              4.0
# 4  hooktheory   dreams-of-grandeur     dreams of grandeur             -2.0
#
#   inferred_key  ht_offset  ht_mode        artist    seconds    bpm  \
# 0      C major        0.0      1.0  wayne-sharpe  15.000000  128.0
# 1          NaN        0.0      NaN        weezer        NaN    NaN
# 2     E- major       -3.0      1.0        weezer  11.111111  108.0
# 3     A- major        4.0      1.0        weezer  43.388430  121.0
# 4      B minor        3.0      1.0        wavves  21.333333  180.0
#
#                          ...                          instruments  \
# 0                        ...                          Piano,Piano
# 1                        ...                                  NaN
# 2                        ...                          Piano,Piano
# 3                        ...                          Piano,Piano
# 4                        ...                          Piano,Piano
#
#   time_signature ht_time_signature ht_bpm  \
# 0            4/4               4.0  128.0
# 1            NaN               4.0  128.0
# 2            4/4               4.0  108.0
# 3            4/4               4.0  121.0
# 4            4/4               4.0  180.0
#
#                                             song_url  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...
# 1  https://www.hooktheory.com/theorytab/view/weez...
# 2  https://www.hooktheory.com/theorytab/view/weez...
# 3  https://www.hooktheory.com/theorytab/view/weez...
# 4  https://www.hooktheory.com/theorytab/view/wavv...
#
#                                                 midi  \
# 0  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 1  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 2  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 3  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 4  data/midi/midi_sources/hooktheory/pianoroll/w/...
#
#                                  parts    genres  \
# 0                         intro,chorus       NaN
# 1                      intro-and-verse       NaN
# 2              intro,verse,chorus,solo       NaN
# 3  verse,pre-chorus,chorus,bridge,solo  Pop,Rock
# 4                                verse       NaN
#
#                                    midi_transform_v2  \
# 0  data/midi/midi_transform_v2/hooktheory/pianoro...
# 1                                                NaN
# 2  data/midi/midi_transform_v2/hooktheory/pianoro...
# 3  data/midi/midi_transform_v2/hooktheory/pianoro...
# 4  data/midi/midi_transform_v2/hooktheory/pianoro...
#
#                                          midi_npz_v2
# 0  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...
# 1                                                NaN
# 2  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...
# 3  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...
# 4  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Calculate timesteps

# %%
merged_df = pd.read_csv(out_csv)

# %%
def calc_timesteps(idxrow):
    idx,row = idxrow
    np_file = row[out_dir]
    if not isinstance(np_file, str) or not Path(np_file).exists(): return idx,None
    try:
#         timesteps = scipy.sparse.load_npz(np_file).shape[0]
        timesteps = load_chordarr(np_file).shape[0]
        return idx,timesteps
    except Exception as e:
        print('Error reading text', e, np_file)
    return idx, None

# %%
# for r in merged_df.iterrows():
#     calc_timesteps(r)

# %%
file2steps = process_parallel(calc_timesteps, merged_df.iterrows(), total=merged_df.shape[0])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='33746' class='' max='33746', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [33746/33746 00:27<00:00]
#     </div>
# Error reading text 'data is not a file in the archive'

# %%
len_df = pd.DataFrame(data={f'{out_dir}_timesteps': list(file2steps.values())}, index=list(file2steps.keys()))
merged_len_df = merged_df.join(len_df, how='outer');
len_df.shape, merged_df.shape, merged_len_df.shape
# Out:
# ((33746, 1), (33746, 22), (33746, 23))

# %%
merged_len_df.to_csv(out_csv, index=False); merged_len_df.head()
# Out:
#        source                title             midi_title  inferred_offset  \
# 0  hooktheory  yu-gi-oh-theme-song              yu-gi-oh3              0.0
# 1  hooktheory        beverly-hills            My New Song              NaN
# 2  hooktheory      falling-for-you  falling for you intro             -3.0
# 3  hooktheory          buddy-holly            Buddy Holly              4.0
# 4  hooktheory   dreams-of-grandeur     dreams of grandeur             -2.0
#
#   inferred_key  ht_offset  ht_mode        artist    seconds    bpm  \
# 0      C major        0.0      1.0  wayne-sharpe  15.000000  128.0
# 1          NaN        0.0      NaN        weezer        NaN    NaN
# 2     E- major       -3.0      1.0        weezer  11.111111  108.0
# 3     A- major        4.0      1.0        weezer  43.388430  121.0
# 4      B minor        3.0      1.0        wavves  21.333333  180.0
#
#            ...          time_signature ht_time_signature ht_bpm  \
# 0          ...                     4/4               4.0  128.0
# 1          ...                     NaN               4.0  128.0
# 2          ...                     4/4               4.0  108.0
# 3          ...                     4/4               4.0  121.0
# 4          ...                     4/4               4.0  180.0
#
#                                             song_url  \
# 0  https://www.hooktheory.com/theorytab/view/wayn...
# 1  https://www.hooktheory.com/theorytab/view/weez...
# 2  https://www.hooktheory.com/theorytab/view/weez...
# 3  https://www.hooktheory.com/theorytab/view/weez...
# 4  https://www.hooktheory.com/theorytab/view/wavv...
#
#                                                 midi  \
# 0  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 1  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 2  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 3  data/midi/midi_sources/hooktheory/pianoroll/w/...
# 4  data/midi/midi_sources/hooktheory/pianoroll/w/...
#
#                                  parts    genres  \
# 0                         intro,chorus       NaN
# 1                      intro-and-verse       NaN
# 2              intro,verse,chorus,solo       NaN
# 3  verse,pre-chorus,chorus,bridge,solo  Pop,Rock
# 4                                verse       NaN
#
#                                    midi_transform_v2  \
# 0  data/midi/midi_transform_v2/hooktheory/pianoro...
# 1                                                NaN
# 2  data/midi/midi_transform_v2/hooktheory/pianoro...
# 3  data/midi/midi_transform_v2/hooktheory/pianoro...
# 4  data/midi/midi_transform_v2/hooktheory/pianoro...
#
#                                          midi_npz_v2 midi_npz_v2_timesteps
# 0  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...                 129.0
# 1                                                NaN                   NaN
# 2  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...                  81.0
# 3  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...                 351.0
# 4  data/midi/midi_npz_v2/hooktheory/pianoroll/w/w...                 257.0
#
# [5 rows x 23 columns]
