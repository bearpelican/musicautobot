# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from encode_data import *
from midi_data import *

# %%
from tqdm import tqdm
import pandas as pd
from data_sources import process_parallel

# %%
from collections import Counter

# %%
import scipy.sparse

# %% [markdown]
# ## Encode music21 stream to text representation
#
# This notebook uses a full component format
# - measure separators, instruments, and separated octaves
# - Format: note, octave, action type, instrument
# - note repr: nG# o4 t1 i0

# %% [markdown]
# ### Load midi data

# %%
path = Path('data/midi')

# %%
source_dir = 'midi_transform_v3'
out_dir = 'midi_npz_v3'
source_csv = path/source_dir/f'{source_dir}.csv'
out_csv = path/out_dir/f'{out_dir}.csv'

# %%
df = pd.read_csv(source_csv); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,4,12,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        source         artist                title ht_key               parts  \
# 0  hooktheory         weezer        beverly-hills      C     intro-and-verse
# 1  hooktheory  willie-nelson    on-the-road-again      E        verse,bridge
# 2  hooktheory          weebl              donkeys      B         intro,verse
# 3  hooktheory   wayne-sharpe  yu-gi-oh-theme-song      C        intro,chorus
# 4  hooktheory           wham       last-christmas     Db  intro,verse,chorus
#
#    ht_offset  ht_bpm                                               midi  \
# 0        0.0   128.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 1       -4.0   112.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 2        1.0   140.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 3        0.0   128.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 4       -1.0   108.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
#
#     genres time_signature                        ...                          \
# 0      NaN            NaN                        ...
# 1      NaN            4/4                        ...
# 2      NaN            4/4                        ...
# 3      NaN            4/4                        ...
# 4  Holiday            4/4                        ...
#
#      seconds             midi_title  \
# 0        NaN            My New Song
# 1  15.000000      On The Road Again
# 2  13.714286          Donkeys Intro
# 3  15.000000              yu-gi-oh3
# 4  17.777778  Last Christmas Chorus
#
#                                             song_url  ht_mode  instruments  \
# 0  https://www.hooktheory.com/theorytab/view/weez...      NaN          NaN
# 1  https://www.hooktheory.com/theorytab/view/will...      1.0        Piano
# 2  https://www.hooktheory.com/theorytab/view/weeb...      1.0        Piano
# 3  https://www.hooktheory.com/theorytab/view/wayn...      1.0  Piano,Piano
# 4  https://www.hooktheory.com/theorytab/view/wham...      1.0  Piano,Piano
#
#      bpm  ht_time_signature inferred_key  mxl  \
# 0    NaN                4.0          NaN  NaN
# 1  112.0                4.0      E major  NaN
# 2  140.0                4.0     F# major  NaN
# 3  128.0                4.0      C major  NaN
# 4  108.0                4.0     B- minor  NaN
#
#                                    midi_transform_v3
# 0                                                NaN
# 1  data/midi/midi_transform_v3/hooktheory/pianoro...
# 2  data/midi/midi_transform_v3/hooktheory/pianoro...
# 3  data/midi/midi_transform_v3/hooktheory/pianoro...
# 4  data/midi/midi_transform_v3/hooktheory/pianoro...
#
# [5 rows x 23 columns]

# %%
df_filtered = df.loc[df['time_signature'] == '4/4']; df_filtered.shape
# Out:
# (33262, 23)

# %%
def transcribe_file(idxrow):
    idx,row = idxrow
    midi_file = row[source_dir]
    if not isinstance(midi_file, str) or not Path(midi_file).exists(): return idx,None
    out_file = Path(midi_file.replace(f'/{source_dir}/', f'/{out_dir}/')).with_suffix('.npz')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): return idx,str(out_file)
    try:
        stream = file2stream(midi_file) # 1.
        chordarr = stream2chordarr(stream) # 2.
        if row.source != 'hooktheory': # keep hooktheory
            chord_short = compress_chordarr(chordarr)
            delta_trim = chordarr.shape[0] - chord_short.shape[0]
            if delta_trim > 100: print(f'Removed {delta_trim} rests from {midi_file}')
            chordarr = chord_short
        save_chordarr(out_file, chordarr)
        return idx,str(out_file)
    except Exception as e:
        print('Error converting midi to sequence', e)
    return idx,None

# %%
# for r in df_filtered.iterrows():
#     transcribe_file(r)

# %%
transcribed_files = process_parallel(transcribe_file, df_filtered.iterrows(), total=df_filtered.shape[0])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='33262' class='' max='33262', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [33262/33262 18:47<00:00]
#     </div>
# Compressing rests: 112 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 166 -> 34
# Compressing rests: 142 -> 34
# Removed 392 rests from data/midi/midi_transform_v3/midiworld/named_midi/Veruca_Salt_-_Volcana_Girls.mid
# Error converting midi to sequence
# Error converting midi to sequence index 127 is out of bounds for axis 2 with size 127
# Compressing rests: 48 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 64 -> 32
# Error converting midi to sequence index 127 is out of bounds for axis 2 with size 127
# Error converting midi to sequence index 127 is out of bounds for axis 2 with size 127
# Error converting midi to sequence index 127 is out of bounds for axis 2 with size 127
# Compressing rests: 64 -> 32
# Compressing rests: 78 -> 34
# Compressing rests: 64 -> 32
# Compressing rests: 112 -> 32
# Compressing rests: 80 -> 32
# Removed 144 rests from data/midi/midi_transform_v3/ecomp/2006/Schmitt03.mid
# Compressing rests: 92 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 76 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 100 -> 32
# Compressing rests: 39 -> 35
# Compressing rests: 389 -> 33
# Removed 356 rests from data/midi/midi_transform_v3/ecomp/2009/Erice01.mid
# Compressing rests: 43 -> 35
# Compressing rests: 72 -> 32
# Compressing rests: 108 -> 32
# Compressing rests: 143 -> 35
# Removed 184 rests from data/midi/midi_transform_v3/ecomp/2009/Kunz02.mid
# Compressing rests: 50 -> 34
# Compressing rests: 56 -> 32
# Compressing rests: 139 -> 35
# Removed 104 rests from data/midi/midi_transform_v3/ecomp/2015/ChenW01.mid
# Compressing rests: 56 -> 32
# Compressing rests: 44 -> 32
# Compressing rests: 68 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 56 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 81 -> 33
# Compressing rests: 40 -> 32
# Compressing rests: 100 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 44 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 59 -> 35
# Compressing rests: 60 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 68 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 44 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 37 -> 33
# Compressing rests: 40 -> 32
# Removed 160 rests from data/midi/midi_transform_v3/ecomp/2015/LuoJ11.mid
# Compressing rests: 38 -> 34
# Compressing rests: 52 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 364 -> 32
# Removed 332 rests from data/midi/midi_transform_v3/ecomp/2015/LeeN05.mid
# Compressing rests: 52 -> 32
# Removed 224 rests from data/midi/midi_transform_v3/ecomp/2002/victoria07.mid
# Compressing rests: 82 -> 34
# Compressing rests: 44 -> 32
# Compressing rests: 122 -> 34
# Compressing rests: 40 -> 32
# Compressing rests: 39 -> 35
# Compressing rests: 74 -> 34
# Compressing rests: 384 -> 32
# Compressing rests: 52 -> 32
# Compressing rests: 56 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 52 -> 32
# Compressing rests: 56 -> 32
# Compressing rests: 56 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 52 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 56 -> 32
# Compressing rests: 60 -> 32
# Removed 652 rests from data/midi/midi_transform_v3/ecomp/2015/MiyashitaM02.mid
# Compressing rests: 440 -> 32
# Compressing rests: 76 -> 32
# Removed 452 rests from data/midi/midi_transform_v3/ecomp/2015/MunA02.mid
# Compressing rests: 44 -> 32
# Removed 320 rests from data/midi/midi_transform_v3/ecomp/2002/huang02.mid
# Compressing rests: 56 -> 32
# Compressing rests: 144 -> 32
# Compressing rests: 47 -> 35
# Removed 156 rests from data/midi/midi_transform_v3/ecomp/2002/mamriev03.mid
# Compressing rests: 48 -> 32
# Compressing rests: 44 -> 32
# Compressing rests: 120 -> 32
# Compressing rests: 106 -> 34
# Removed 136 rests from data/midi/midi_transform_v3/wikifonia/Taylor Swift - You Belong With Me.mid
# Compressing rests: 107 -> 35
# Compressing rests: 54 -> 34
# Compressing rests: 90 -> 34
# Compressing rests: 44 -> 32
# Compressing rests: 68 -> 32
# Compressing rests: 50 -> 34
# Compressing rests: 68 -> 32
# Compressing rests: 76 -> 32
# Compressing rests: 39 -> 35
# Error converting midi to sequence index 127 is out of bounds for axis 2 with size 127
# Compressing rests: 76 -> 32
# Compressing rests: 130 -> 34
# Removed 288 rests from data/midi/midi_transform_v3/wikifonia/Bon Jovi - Livin' on a Prayer.mid
# Removed 128 rests from data/midi/midi_transform_v3/wikifonia/Arr. H. Laukens - IK HOU DR ZO VAN.mid
# Compressing rests: 48 -> 32
# Compressing rests: 76 -> 32
# Compressing rests: 84 -> 32
# Compressing rests: 134 -> 34
# Compressing rests: 60 -> 32
# Removed 128 rests from data/midi/midi_transform_v3/wikifonia/Taylor Swift - Sparks Fly.mid
# Compressing rests: 68 -> 32
# Compressing rests: 196 -> 32
# Removed 164 rests from data/midi/midi_transform_v3/wikifonia/Bon Jovi - Something for the Pain.mid
# Compressing rests: 42 -> 34
# Compressing rests: 72 -> 32
# Compressing rests: 60 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 54 -> 34
# Compressing rests: 60 -> 32
# Compressing rests: 63 -> 35
# Compressing rests: 46 -> 34
# Compressing rests: 58 -> 34
# Compressing rests: 108 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 68 -> 32
# Removed 128 rests from data/midi/midi_transform_v3/wikifonia/Elton John, Bernie Taupin - Nikita.mid
# Compressing rests: 120 -> 32
# Compressing rests: 44 -> 32
# Compressing rests: 88 -> 32
# Removed 220 rests from data/midi/midi_transform_v3/wikifonia/Billie Joe Armstrong - Wake Me Up When September Ends.mid
# Compressing rests: 44 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 58 -> 34
# Compressing rests: 116 -> 32
# Removed 172 rests from data/midi/midi_transform_v3/wikifonia/Bon Jovi - It's My Life.mid
# Compressing rests: 68 -> 32
# Removed 116 rests from data/midi/midi_transform_v3/wikifonia/ Stephen Schwartz - Defying Gravity.mid
# Compressing rests: 40 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 136 -> 32
# Removed 104 rests from data/midi/midi_transform_v3/wikifonia/They might be Giants - Experimental Film.mid
# Compressing rests: 84 -> 32
# Removed 372 rests from data/midi/midi_transform_v3/wikifonia/Stevie Wonder - Superstition.mid
# Compressing rests: 50 -> 34
# Compressing rests: 49 -> 33
# Compressing rests: 49 -> 33

# %%
tdf = pd.DataFrame(data={out_dir: list(transcribed_files.values())}, index=list(transcribed_files.keys()))

# %%
merged_df = df.join(tdf, how='outer'); tdf.shape, df.shape, merged_df.shape
# Out:
# ((33262, 1), (39929, 23), (39929, 24))

# %%
merged_df.to_csv(out_csv, index=False); merged_df.head()
# Out:
#        source         artist                title ht_key               parts  \
# 0  hooktheory         weezer        beverly-hills      C     intro-and-verse
# 1  hooktheory  willie-nelson    on-the-road-again      E        verse,bridge
# 2  hooktheory          weebl              donkeys      B         intro,verse
# 3  hooktheory   wayne-sharpe  yu-gi-oh-theme-song      C        intro,chorus
# 4  hooktheory           wham       last-christmas     Db  intro,verse,chorus
#
#    ht_offset  ht_bpm                                               midi  \
# 0        0.0   128.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 1       -4.0   112.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 2        1.0   140.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 3        0.0   128.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 4       -1.0   108.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
#
#     genres time_signature                        ...                          \
# 0      NaN            NaN                        ...
# 1      NaN            4/4                        ...
# 2      NaN            4/4                        ...
# 3      NaN            4/4                        ...
# 4  Holiday            4/4                        ...
#
#               midi_title                                           song_url  \
# 0            My New Song  https://www.hooktheory.com/theorytab/view/weez...
# 1      On The Road Again  https://www.hooktheory.com/theorytab/view/will...
# 2          Donkeys Intro  https://www.hooktheory.com/theorytab/view/weeb...
# 3              yu-gi-oh3  https://www.hooktheory.com/theorytab/view/wayn...
# 4  Last Christmas Chorus  https://www.hooktheory.com/theorytab/view/wham...
#
#   ht_mode  instruments    bpm ht_time_signature  inferred_key  mxl  \
# 0     NaN          NaN    NaN               4.0           NaN  NaN
# 1     1.0        Piano  112.0               4.0       E major  NaN
# 2     1.0        Piano  140.0               4.0      F# major  NaN
# 3     1.0  Piano,Piano  128.0               4.0       C major  NaN
# 4     1.0  Piano,Piano  108.0               4.0      B- minor  NaN
#
#                                    midi_transform_v3  \
# 0                                                NaN
# 1  data/midi/midi_transform_v3/hooktheory/pianoro...
# 2  data/midi/midi_transform_v3/hooktheory/pianoro...
# 3  data/midi/midi_transform_v3/hooktheory/pianoro...
# 4  data/midi/midi_transform_v3/hooktheory/pianoro...
#
#                                          midi_npz_v3
# 0                                                NaN
# 1  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...
# 2  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...
# 3  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...
# 4  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Calculate timesteps

# %%
merged_df = pd.read_csv(out_csv)

# %%
def calc_timesteps(idxrow):
    idx,row = idxrow
    np_file = row[out_dir]
    if not isinstance(np_file, str) or not Path(np_file).exists(): return idx,None
    try:
#         timesteps = scipy.sparse.load_npz(np_file).shape[0]
        timesteps = load_chordarr(np_file).shape[0]
        return idx,timesteps
    except Exception as e:
        print('Error reading text', e, np_file)
    return idx, None

# %%
# for r in merged_df.iterrows():
#     calc_timesteps(r)

# %%
file2steps = process_parallel(calc_timesteps, merged_df.iterrows(), total=merged_df.shape[0])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='39929' class='' max='39929', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [39929/39929 00:42<00:00]
#     </div>
# Error reading text 'data is not a file in the archive' data/midi/midi_npz_v3/freemidi/genre-pop/Genesis - Another Record.npz

# %%
len_df = pd.DataFrame(data={f'{out_dir}_timesteps': list(file2steps.values())}, index=list(file2steps.keys()))
merged_len_df = merged_df.join(len_df, how='outer');
len_df.shape, merged_df.shape, merged_len_df.shape
# Out:
# ((39929, 1), (39929, 24), (39929, 25))

# %%
merged_len_df.to_csv(out_csv, index=False); merged_len_df.head()
# Out:
#        source         artist                title ht_key               parts  \
# 0  hooktheory         weezer        beverly-hills      C     intro-and-verse
# 1  hooktheory  willie-nelson    on-the-road-again      E        verse,bridge
# 2  hooktheory          weebl              donkeys      B         intro,verse
# 3  hooktheory   wayne-sharpe  yu-gi-oh-theme-song      C        intro,chorus
# 4  hooktheory           wham       last-christmas     Db  intro,verse,chorus
#
#    ht_offset  ht_bpm                                               midi  \
# 0        0.0   128.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 1       -4.0   112.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 2        1.0   140.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 3        0.0   128.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
# 4       -1.0   108.0  data/midi/midi_sources_v3/hooktheory/pianoroll...
#
#     genres time_signature          ...            \
# 0      NaN            NaN          ...
# 1      NaN            4/4          ...
# 2      NaN            4/4          ...
# 3      NaN            4/4          ...
# 4  Holiday            4/4          ...
#
#                                             song_url  ht_mode  instruments  \
# 0  https://www.hooktheory.com/theorytab/view/weez...      NaN          NaN
# 1  https://www.hooktheory.com/theorytab/view/will...      1.0        Piano
# 2  https://www.hooktheory.com/theorytab/view/weeb...      1.0        Piano
# 3  https://www.hooktheory.com/theorytab/view/wayn...      1.0  Piano,Piano
# 4  https://www.hooktheory.com/theorytab/view/wham...      1.0  Piano,Piano
#
#      bpm ht_time_signature inferred_key  mxl  \
# 0    NaN               4.0          NaN  NaN
# 1  112.0               4.0      E major  NaN
# 2  140.0               4.0     F# major  NaN
# 3  128.0               4.0      C major  NaN
# 4  108.0               4.0     B- minor  NaN
#
#                                    midi_transform_v3  \
# 0                                                NaN
# 1  data/midi/midi_transform_v3/hooktheory/pianoro...
# 2  data/midi/midi_transform_v3/hooktheory/pianoro...
# 3  data/midi/midi_transform_v3/hooktheory/pianoro...
# 4  data/midi/midi_transform_v3/hooktheory/pianoro...
#
#                                          midi_npz_v3  midi_npz_v3_timesteps
# 0                                                NaN                    NaN
# 1  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...                  113.0
# 2  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...                  129.0
# 3  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...                  129.0
# 4  data/midi/midi_npz_v3/hooktheory/pianoroll/w/w...                  129.0
#
# [5 rows x 25 columns]
