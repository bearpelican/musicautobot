# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from encode_data import *
from midi_data import *

# %%
from tqdm import tqdm
import pandas as pd
from data_sources import process_parallel

# %%
from collections import Counter

# %% [markdown]
# ## Encode music21 stream to text representation
#
# This notebook uses a full component format
# - measure separators, instruments, and separated octaves
# - Format: note, octave, action type, instrument
# - note repr: nG# o4 t1 i0

# %% [markdown]
# ### Load midi data

# %%
path = Path('data/midi')

# %%
source_dir = 'midi_transform_v2'
out_dir = 'midi_pickle_v2'
source_csv = path/source_dir/f'{source_dir}.csv'
out_csv = path/out_dir/f'{out_dir}.csv'

# %%
df = pd.read_csv(source_csv, index_col=0); df.head()
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5,13,14,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              artist    bpm    genres  ht_bpm ht_key  ht_mode  ht_offset  \
# index
# 0      wayne-sharpe  128.0       NaN   128.0      C      1.0        0.0
# 1            weezer    NaN       NaN   128.0      C      NaN        0.0
# 2            weezer  108.0       NaN   108.0     Eb      1.0       -3.0
# 3            weezer  121.0  Pop,Rock   121.0     Ab      1.0        4.0
# 4            wavves  180.0       NaN   180.0      A      1.0        3.0
#
#        ht_time_signature inferred_key  inferred_offset  \
# index
# 0                    4.0      C major              0.0
# 1                    4.0          NaN              NaN
# 2                    4.0     E- major             -3.0
# 3                    4.0     A- major              4.0
# 4                    4.0      B minor             -2.0
#
#                              ...                          \
# index                        ...
# 0                            ...
# 1                            ...
# 2                            ...
# 3                            ...
# 4                            ...
#
#                                                     midi  \
# index
# 0      data/midi/midi_sources/hooktheory/pianoroll/w/...
# 1      data/midi/midi_sources/hooktheory/pianoroll/w/...
# 2      data/midi/midi_sources/hooktheory/pianoroll/w/...
# 3      data/midi/midi_sources/hooktheory/pianoroll/w/...
# 4      data/midi/midi_sources/hooktheory/pianoroll/w/...
#
#                   midi_title                                parts    seconds  \
# index
# 0                  yu-gi-oh3                         intro,chorus  15.000000
# 1                My New Song                      intro-and-verse        NaN
# 2      falling for you intro              intro,verse,chorus,solo  11.111111
# 3                Buddy Holly  verse,pre-chorus,chorus,bridge,solo  43.388430
# 4         dreams of grandeur                                verse  21.333333
#
#                section                                           song_url  \
# index
# 0               chorus  https://www.hooktheory.com/theorytab/view/wayn...
# 1      intro-and-verse  https://www.hooktheory.com/theorytab/view/weez...
# 2                intro  https://www.hooktheory.com/theorytab/view/weez...
# 3                 solo  https://www.hooktheory.com/theorytab/view/weez...
# 4                verse  https://www.hooktheory.com/theorytab/view/wavv...
#
#            source time_signature                title  \
# index
# 0      hooktheory            4/4  yu-gi-oh-theme-song
# 1      hooktheory            NaN        beverly-hills
# 2      hooktheory            4/4      falling-for-you
# 3      hooktheory            4/4          buddy-holly
# 4      hooktheory            4/4   dreams-of-grandeur
#
#                                        midi_transform_v2
# index
# 0      data/midi/midi_transform_v2/hooktheory/pianoro...
# 1                                                    NaN
# 2      data/midi/midi_transform_v2/hooktheory/pianoro...
# 3      data/midi/midi_transform_v2/hooktheory/pianoro...
# 4      data/midi/midi_transform_v2/hooktheory/pianoro...
#
# [5 rows x 21 columns]

# %%
df_filtered = df.loc[df['time_signature'] == '4/4']; df_filtered.shape
# Out:
# (30201, 21)

# %%
import pickle

# %%
def transcribe_file(idxrow):
    idx,row = idxrow
    midi_file = row[source_dir]
    if not isinstance(midi_file, str) or not Path(midi_file).exists(): return idx,None
    out_file = Path(midi_file.replace(f'/{source_dir}/', f'/{out_dir}/')).with_suffix('.npy')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): return idx,str(out_file)
    try:
        stream = file2stream(midi_file) # 1.
        chordarr = stream2chordarr(stream) # 2.
        if row.source != 'hooktheory': # keep hooktheory
            chord_short = remove_chordarr_rests(trim_chordarr_rests(chordarr))
            delta_trim = chordarr.shape[0] - chord_short.shape[0]
            if delta_trim > 100: print(f'Removed {delta_trim} rests from {midi_file}')
            chordarr = chord_short
        seq = chordarr2seq(chordarr)
        with open(out_file, 'wb') as f:
            pickle.dump(seq, f, pickle.HIGHEST_PROTOCOL)
#         np.save(out_file, chordarr)
    except Exception as e:
        print('Error converting midi to sequence', e)
        return idx,None
    return idx,str(out_file)

# %%
# for r in df_filtered.iterrows():
#     transcribe_file(r)

# %%
transcribed_files = process_parallel(transcribe_file, df_filtered.iterrows(), total=df_filtered.shape[0])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18466' class='' max='30201', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       61.14% [18466/30201 01:27<00:55]
#     </div>
# Compressing rests: 64 -> 32
# Compressing rests: 64 -> 32
# Compressing rests: 128 -> 32
# Removed 176 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Ariana Grande - Problem.mid
# Compressing rests: 39 -> 35
# Compressing rests: 48 -> 32
# Removed 272 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Frozen.mid
# Compressing rests: 52 -> 32
# Compressing rests: 58 -> 34
# Compressing rests: 64 -> 32
# Removed 204 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Fatboy Slim - Praise You.mid
# Compressing rests: 128 -> 32
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Revival.mid
# Compressing rests: 318 -> 34
# Compressing rests: 66 -> 34
# Compressing rests: 192 -> 32
# Removed 492 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Beautiful Stranger.mid
# Removed 144 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cher - Believe.mid
# Compressing rests: 89 -> 33
# Removed 120 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Pitbull - I Know You Want Me.mid
# Compressing rests: 64 -> 32
# Compressing rests: 126 -> 34
# Removed 124 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Control Freak.mid
# Compressing rests: 134 -> 34
# Compressing rests: 60 -> 32
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - American Pie.mid
# Compressing rests: 129 -> 33
# Compressing rests: 63 -> 35
# Compressing rests: 66 -> 34
# Compressing rests: 47 -> 35
# Compressing rests: 55 -> 35
# Compressing rests: 323 -> 35
# Compressing rests: 307 -> 35
# Compressing rests: 333 -> 33
# Compressing rests: 319 -> 35
# Compressing rests: 305 -> 33
# Compressing rests: 329 -> 33
# Compressing rests: 326 -> 34
# Compressing rests: 169 -> 33
# Compressing rests: 142 -> 34
# Compressing rests: 185 -> 33
# Compressing rests: 128 -> 32
# Compressing rests: 184 -> 32
# Compressing rests: 158 -> 34
# Compressing rests: 129 -> 33
# Compressing rests: 198 -> 34
# Compressing rests: 137 -> 33
# Compressing rests: 197 -> 33
# Compressing rests: 118 -> 34
# Compressing rests: 182 -> 34
# Compressing rests: 124 -> 32
# Compressing rests: 175 -> 35
# Compressing rests: 275 -> 35
# Compressing rests: 37 -> 33
# Compressing rests: 298 -> 34
# Compressing rests: 300 -> 32
# Compressing rests: 302 -> 34
# Compressing rests: 302 -> 34
# Compressing rests: 310 -> 34
# Compressing rests: 332 -> 32
# Compressing rests: 317 -> 33
# Compressing rests: 318 -> 34
# Compressing rests: 320 -> 32
# Compressing rests: 306 -> 34
# Compressing rests: 308 -> 32
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 352 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 336 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 344 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 366 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 334 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 336 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 336 -> 32
# Compressing rests: 358 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 334 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 359 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 336 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 336 -> 32
# Compressing rests: 342 -> 34
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 368 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 334 -> 34
# Compressing rests: 368 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 336 -> 32
# Compressing rests: 350 -> 34
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 360 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 335 -> 35
# Compressing rests: 344 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 334 -> 34
# Compressing rests: 352 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 350 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 359 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 343 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 344 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 336 -> 32
# Compressing rests: 334 -> 34
# Compressing rests: 368 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 366 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 334 -> 34
# Compressing rests: 336 -> 32
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 367 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 351 -> 35
# Compressing rests: 335 -> 35
# Compressing rests: 335 -> 35
# Removed 80076 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cascada - What Hurts The Most.mid
# Compressing rests: 286 -> 34
# Removed 252 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Vanishing Point.mid
# Compressing rests: 445 -> 33
# Removed 1772 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/No Mercy - Please Dont Go.mid
# Compressing rests: 128 -> 32
# Compressing rests: 62 -> 34
# Removed 284 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Real McCoy - Run Away.mid
# Removed 160 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yellow Magic Orchestra - Ongaku.mid
# Compressing rests: 112 -> 32
# Compressing rests: 64 -> 32
# Removed 240 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Blue Monday.mid
# Compressing rests: 128 -> 32
# Compressing rests: 52 -> 32
# Compressing rests: 52 -> 32
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yaz - Don't Go 99.mid
# Compressing rests: 248 -> 32
# Removed 216 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Fatboy Slim - Going Out Of My Head.mid
# Removed 112 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Pitbull - We Are One (Ole Ola).mid
# Removed 144 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Boys Say Go.mid
# Compressing rests: 48 -> 32
# Compressing rests: 48 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 40 -> 32
# Compressing rests: 128 -> 32
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Christmas Island.mid
# Compressing rests: 56 -> 32
# Removed 200 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Causing A Commotion.mid
# Compressing rests: 64 -> 32
# Compressing rests: 384 -> 32
# Removed 384 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Smack My Bitch Up (2).mid
# Compressing rests: 64 -> 32
# Removed 192 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Toni Basil - Mickey.mid
# Compressing rests: 124 -> 32
# Removed 108 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Pitbull - Give Me Everything.mid
# Compressing rests: 48 -> 32
# Compressing rests: 124 -> 32
# Removed 108 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Maximum Overdrive.mid
# Compressing rests: 39 -> 35
# Compressing rests: 39 -> 35
# Removed 144 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Do Whats Good For Me.mid
# Compressing rests: 128 -> 32
# Compressing rests: 64 -> 32
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Four Tops - Walk Away Renee.mid
# Compressing rests: 322 -> 34
# Compressing rests: 137 -> 33
# Removed 424 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Wind It Up.mid
# Compressing rests: 112 -> 32
# Compressing rests: 81 -> 33
# Removed 144 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Tribal Dance.mid
# Compressing rests: 44 -> 32
# Compressing rests: 80 -> 32
# Compressing rests: 256 -> 32
# Removed 224 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Aerodynamic (2).mid
# Compressing rests: 48 -> 32
# Compressing rests: 129 -> 33
# Compressing rests: 124 -> 32
# Compressing rests: 192 -> 32
# Removed 272 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Bizarre Love Triangle.mid
# Compressing rests: 412 -> 32
# Removed 504 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Breathe.mid
# Compressing rests: 64 -> 32
# Compressing rests: 644 -> 32
# Compressing rests: 260 -> 32
# Removed 1032 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Behind The Wheel.mid
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Playboy Mommy.mid
# Compressing rests: 42 -> 34
# Compressing rests: 42 -> 34
# Compressing rests: 102 -> 34
# Compressing rests: 64 -> 32
# Compressing rests: 65 -> 33
# Removed 132 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/David Guetta - Love Is Gone.mid
# Compressing rests: 1024 -> 32
# Compressing rests: 915 -> 35
# Removed 1904 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Antiloop - This Is The Night.mid
# Compressing rests: 268 -> 32
# Compressing rests: 284 -> 32
# Removed 488 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/DJ Bobo - Shadows Of The Night.mid
# Compressing rests: 244 -> 32
# Removed 212 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Around The World (2).mid
# Compressing rests: 61 -> 33
# Compressing rests: 64 -> 32
# Compressing rests: 58 -> 34

# %%
tdf = pd.DataFrame(data={out_dir: list(transcribed_files.values())}, index=list(transcribed_files.keys()))

# %%
merged_df = df.join(tdf, how='outer'); tdf.shape, df.shape, merged_df.shape

# %%
merged_df.to_csv(out_csv, index=False); merged_df.head()

# %% [markdown]
# ### Calculate timesteps

# %%
merged_df = pd.read_csv(out_csv)

# %%
def calc_timesteps(idxrow):
    idx,row = idxrow
    np_file = row[out_dir]
    if not isinstance(np_file, str) or not Path(np_file).exists(): return idx,None
    try:
        np.load(np_file)
        timesteps = np.load(np_file).shape[0]
        return idx,timesteps
    except Exception as e:
        print('Error reading text', e)
    return idx, None

# %%
file2steps = process_parallel(calc_timesteps, merged_df.iterrows(), total=merged_df.shape[0])

# %%
len_df = pd.DataFrame(data={f'{out_dir}_timesteps': list(file2steps.values())}, index=list(file2steps.keys()))
merged_len_df = merged_df.join(len_df, how='outer');
len_df.shape, merged_df.shape, merged_len_df.shape

# %%
merged_len_df.to_csv(out_csv, index=False); merged_len_df.head()
