# %% [markdown]
# # Attention Architecture

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import music21

# %%
from fastai.text import *
from transformer_xl.default_txl import get_default_model
from enum import Enum
import torch
from fastai.text.models.awd_lstm import *
from fastai.text.models.transformer import *
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
from fastai_data import *
# Out:
# Failed to load FluidSynth. Must install if you want to convert to wav files.

# %%
import numpy as np
import torch.nn as nn

# %%
from ht_encode import *
import ht_encode

# %%
# bs=4
# bptt=64

bs=8
bptt=256

# %%
import fastai_data
fastai_data.Y_OFFSET=1

# %%
path = Path('data/midi/v7/midi_encode/np/hook_dur/')
ht_encode.config.continuous=False
data = LMNPDataBunch.load(path, bs=bs, bptt=bptt, cache_name='tmp/all')

# %%
# loss_func = CrossEntropy with parts

# %%
class TransformerEmbed(nn.Module):
    def __init__(self, vocab_map, vocab_sizes, d_model, emb_dim=100, embed_p:float=0.1, **kwargs):
        super().__init__()
        # note, octave, duration, instrument
#         assert(sum(emb_dims) == d_model)
        self.vocab_map = vocab_map
        embeddings = []
        
        out_d = 100
        for in_d in vocab_sizes:
            embeddings.append(nn.Embedding(in_d, out_d, padding_idx=PAD_IDX))
        self.embeddings = nn.ModuleList(embeddings[:-2])
        self.positions = nn.ModuleList(embeddings[-2:])
        self.drop_emb = nn.Dropout(embed_p)
        
    def forward(self, x):
        # batch x bptt x (n,o,d,i)
        embs = []
        pos = self.positions[0](x[:,:,iB]) + self.positions[1](x[:,:,iM])
        for i in range(x.shape[-1]-2):
            emb_idx = self.vocab_map[i]
            ex = self.embeddings[emb_idx](x[:,:,i])
            embs.append(ex+pos)
        emb = torch.cat(embs, dim=-1)
        return self.drop_emb(emb)

# %%
class TXLLinearDecoder(nn.Module):
    "To go on top of a RNNCore module and create a Language Model."
    initrange=0.1

    def __init__(self, n_out:int, n_hid:int, tie_encoder:nn.Module=None, bias:bool=True):
        super().__init__()
        self.decoder = nn.Linear(n_hid, n_out, bias=bias)
        self.decoder.weight.data.uniform_(-self.initrange, self.initrange)
        if bias: self.decoder.bias.data.zero_()
        if tie_encoder: self.decoder.weight = tie_encoder.weight

    def forward(self, input):
        return self.decoder(input)

# %%
class TransformerDec(nn.Module):
    def __init__(self, txl_emb, vocab_map, output_p=0.0, out_bias=True, **kwargs):
        super().__init__()
        self.output_dp = RNNDropout(output_p)
        
        start_range = 0
        self.ranges = []
        decoders = []
        for i in range(len(vocab_map)-2):
            emb = txl_emb.embeddings[vocab_map[i]]
            decoder = TXLLinearDecoder(emb.num_embeddings, emb.embedding_dim, tie_encoder=emb, bias=out_bias)
            decoders.append(decoder)
            end_range = start_range+emb.embedding_dim
            self.ranges.append([start_range, end_range])
            start_range = end_range
            
        self.decoders = nn.ModuleList(decoders)
        
    def forward(self, input):
        raw_outputs, outputs = input
        output = self.output_dp(outputs[-1])
        res = []
        for dec,(start,end) in zip(self.decoders, self.ranges):
            res.append(dec(output[:,:,start:end]))
        return res, raw_outputs, outputs

# %%
class LMNPTransformerXL(nn.Module):
    "TransformerXL model: https://arxiv.org/abs/1901.02860."
    def __init__(self, encoder, ctx_len:int, n_layers:int, n_heads:int, d_model:int, d_head:int, d_inner:int, 
                 resid_p:float=0., attn_p:float=0., ff_p:float=0., embed_p:float=0., bias:bool=False, scale:bool=True,
                 act:Activation=Activation.ReLU, double_drop:bool=True, attn_cls:Callable=MultiHeadRelativeAttention,
                 learned_pos_enc:bool=False, mask:bool=True, mem_len:int=0, **kwargs):
        super().__init__()
        self.encoder = encoder
        self.pos_enc = nn.Embedding(ctx_len, d_model) if learned_pos_enc else PositionalEncoding(d_model)
        self.u = nn.Parameter(torch.Tensor(n_heads, 1, d_head)) #Remove 1 for einsum implementation of attention
        self.v = nn.Parameter(torch.Tensor(n_heads, 1, d_head)) #Remove 1 for einsum implementation of attention
        self.mem_len,self.n_layers,self.d_model,self.mask = mem_len,n_layers,d_model,mask
        if self.mem_len > 0: self.reset()
        self.layers = nn.ModuleList([DecoderLayer(n_heads, d_model, d_head, d_inner, resid_p=resid_p, attn_p=attn_p,
                      ff_p=ff_p, bias=bias, scale=scale, act=act, double_drop=double_drop, 
                      attn_cls=attn_cls) for k in range(n_layers)])
    
    def reset(self):
        "Reset the internal memory."
        self.hidden = [next(self.parameters()).data.new(0) for i in range(self.n_layers+1)]
#         self.hidden = [next(self.parameters()).data.new(0).cuda() for i in range(self.n_layers+1)]

    def _update_mems(self, hids):
        if not getattr(self, 'hidden', False): return None
        assert len(hids) == len(self.hidden), 'len(hids) != len(self.hidden)'
        with torch.no_grad():
            for i in range(len(hids)):
                cat = torch.cat([self.hidden[i], hids[i]], dim=1)
                self.hidden[i] = cat[:,-self.mem_len:].detach()
    
    def select_hidden(self, idxs): self.hidden = [h[idxs] for h in self.hidden]
    
    def forward(self, x):
        bs,x_len,_ = x.size()
        inp = self.encoder(x)
        m_len = self.hidden[0].size(1) if hasattr(self, 'hidden') and len(self.hidden[0].size()) > 1 else 0
        seq_len = m_len + x_len
        mask = torch.triu(x.new_ones(x_len, seq_len), diagonal=1+m_len).byte()[None,None] if self.mask else None
        #[None,:,:None] for einsum implementation of attention
        hids = []
        pos = torch.arange(seq_len-1, -1, -1, device=inp.device, dtype=inp.dtype)
        pos_enc = self.pos_enc(pos)
        hids.append(inp)
        for i, layer in enumerate(self.layers):
            mem = self.hidden[i] if self.mem_len > 0 else None
            inp = layer(inp, r=pos_enc, u=self.u, v=self.v, mask=mask, mem=mem)
            hids.append(inp)
        core_out = inp[:,-x_len:]
        if self.mem_len > 0 : self._update_mems(hids)
        return (self.hidden if self.mem_len > 0 else [core_out]),[core_out]

# %%
config = tfmerXL_lm_config

# %%
PAD_IDX=ht_encode.config.pad_idx+ht_encode.config.enc_offset
# must remember to add 1 to tensors

# %%
train_ids_file = path/'tmp/all/train_ids.npy'
all_ids = np.load(train_ids_file)
id_cat = np.concatenate(all_ids); id_cat.shape
max_vocab = id_cat.max(axis=0)
max_vocab = (max_vocab+1).tolist(); max_vocab
# Out:
# [15, 13, 132, 15, 15, 15, 15, 132, 7, 12]

# %%
idx2embidx = {
    0:0,1:1,2:2,
    3:0,4:0,5:0,6:0,7:2,
    8:3,
    9:4
}

# %%
idx_cat = [0,1,2,0,0,0,0,2,3,4]

# %%
max_vocab_sizes = [max_vocab[i] for i in [0,1,2,8,9]]

# %%
max_vocab_sizes
# Out:
# [15, 13, 132, 7, 12]

# %%
emb_dims = [100,100,100,100,100]

# %%
idx2dims = {k:(max_vocab_sizes[v],emb_dims[v]) for k,v in idx2embidx.items()}; idx2dims
# Out:
# {0: (15, 100),
#  1: (13, 100),
#  2: (132, 100),
#  3: (15, 100),
#  4: (15, 100),
#  5: (15, 100),
#  6: (15, 100),
#  7: (132, 100),
#  8: (7, 100),
#  9: (12, 100)}

# %%
config['vocab_sizes'] = max_vocab_sizes
config['vocab_map'] = idx2embidx

# %%
config['emb_dims'] = emb_dims
# total_embs = sum([i[1] for i in idx2dims.values()])
# config['d_model'] = total_embs
config['d_model'] = 800

# %%
config['ctx_len'] = 0
config['mem_len'] = 256
config['d_inner'] = 1024

# %%
# config['mem_len'] = 0
# config['d_inner'] = 512

# %%
config
# Out:
# {'ctx_len': 0,
#  'n_layers': 12,
#  'n_heads': 10,
#  'd_model': 800,
#  'd_head': 41,
#  'd_inner': 1024,
#  'resid_p': 0.1,
#  'attn_p': 0.1,
#  'ff_p': 0.1,
#  'embed_p': 0.1,
#  'output_p': 0.1,
#  'bias': False,
#  'scale': True,
#  'act': <Activation.ReLU: 1>,
#  'double_drop': True,
#  'tie_weights': True,
#  'out_bias': True,
#  'init': <function fastai.text.models.transformer.init_transformer(m)>,
#  'mem_len': 256,
#  'mask': True,
#  'vocab_sizes': [15, 13, 132, 7, 12],
#  'vocab_map': {0: 0, 1: 1, 2: 2, 3: 0, 4: 0, 5: 0, 6: 0, 7: 2, 8: 3, 9: 4},
#  'emb_dims': [100, 100, 100, 100, 100]}

# %%
def get_language_model(config:dict=None, drop_mult:float=1.):
    "Create a language model from `arch` and its `config`, maybe `pretrained`."
    for k in config.keys(): 
        if k.endswith('_p'): config[k] *= drop_mult
    init = config.pop('init') if 'init' in config else None
    
    embed = TransformerEmbed(**config)
    txl = LMNPTransformerXL(embed, **config)
    decoder = TransformerDec(embed, **config)
    model = SequentialRNN(txl, decoder).cuda()
    
    return model if init is None else model.apply(init)


def language_model_learner(data:DataBunch, config:dict=None, drop_mult:float=1., pretrained:bool=True,
                           **learn_kwargs) -> 'LanguageLearner':
    "Create a `Learner` with a language model from `data` and `arch`."
    model = get_language_model(config=config, drop_mult=drop_mult)
    learn = LanguageLearner(data, model, split_func=tfmer_lm_split, **learn_kwargs)
    return learn

# %%
class LMNPLoss(nn.Module):
    "Same as `func`, but flattens input and target."
    def __init__(self):
        super().__init__()
        self.fn = nn.CrossEntropyLoss(ignore_index=PAD_IDX) 
        # not using func otherwise _loss_func_name2activ uses this attribute to get cross entropy loss

    def __repr__(self): return f"numpyenc loss of {self.fn}"

    def forward(self, inputs:Tensor, target:Tensor, **kwargs)->Rank0Tensor:
        losses = []
        for idx,input in enumerate(inputs):
            if idx in BIDX_ALL: continue
            t = target[:,:,idx]
            input = input.view(-1,input.shape[-1])
            losses.append(self.fn(input, t.view(-1)))
        return sum(losses)

# %%
import pdb

# %%
def lmnp_accuracy(inputs:Tensor, target:Tensor)->Rank0Tensor:
    "Compute accuracy with `targs` when `input` is bs * n_classes."
    target = target[:,:,:-2]
    inputs = [i.argmax(dim=-1).unsqueeze(dim=-1) for i in inputs]
    input_cat = torch.cat(inputs, dim=-1).cpu().numpy()
    target = target.cpu().numpy()
    acc = (input_cat==target).astype(float)
    acc[target==PAD_IDX] = np.nan
    return torch.tensor(np.nanmean(acc, dtype=float))

# %%
learn = language_model_learner(data, config, clip=0.25, loss_func=LMNPLoss(), metrics=[lmnp_accuracy])

# %%
learn.validate()
# Out:
# [135.32268, tensor(0.3754)]

# %%
x,y = data.one_batch(cpu=False)
# emb = learn.model[0]
# a = torch.ones_like(x)
# emb.encoder(x)

# out = x[0].cpu().numpy()
# song = dec_arr(out)
# song.to_stream().show()

# %%
learn.model.cuda()
learn.model[0].reset()
out = learn.model(x)

# %%
# # clip = 0.5
# learn.lr_find(num_it=300)
# learn.recorder.plot()

# %%
learn.fit_one_cycle(10, 4e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.00% [7/10 27:40<11:51]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>lmnp_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>13.227628</td>
#       <td>12.115812</td>
#       <td>0.748762</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>10.386578</td>
#       <td>10.137149</td>
#       <td>0.780244</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>9.491807</td>
#       <td>9.473890</td>
#       <td>0.779867</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>9.210784</td>
#       <td>9.242332</td>
#       <td>0.789214</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>9.157971</td>
#       <td>8.925190</td>
#       <td>0.793230</td>
#       <td>03:56</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8.676299</td>
#       <td>8.686626</td>
#       <td>0.797475</td>
#       <td>03:56</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>8.382814</td>
#       <td>8.568770</td>
#       <td>0.801655</td>
#       <td>03:56</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='1556', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-a926fa8ae004> in <module>
# ----> 1 learn.fit_one_cycle(10, 4e-4)
#
# ~/fastai/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      21                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# ~/fastai/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     179         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
#     180         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 181             callbacks=self.callbacks+callbacks)
#     182
#     183     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/fastai/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      89             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      90                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 91                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      92                 if cb_handler.on_batch_end(loss): break
#      93
#
# ~/fastai/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      22     if not is_listy(xb): xb = [xb]
#      23     if not is_listy(yb): yb = [yb]
# ---> 24     out = model(*xb)
#      25     out = cb_handler.on_loss_begin(out)
#      26
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-14-859cfa1607f0> in forward(self, x)
#      45         for i, layer in enumerate(self.layers):
#      46             mem = self.hidden[i] if self.mem_len > 0 else None
# ---> 47             inp = layer(inp, r=pos_enc, u=self.u, v=self.v, mask=mask, mem=mem)
#      48             hids.append(inp)
#      49         core_out = inp[:,-x_len:]
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/fastai/fastai/text/models/transformer.py in forward(self, x, mask, **kwargs)
#     150         self.ff   = feed_forward(d_model, d_inner, ff_p=ff_p, act=act, double_drop=double_drop)
#     151
# --> 152     def forward(self, x:Tensor, mask:Tensor=None, **kwargs): return self.ff(self.mhra(x, mask=mask, **kwargs))
#     153
#     154 class Transformer(nn.Module):
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/fastai/fastai/text/models/transformer.py in forward(self, x, mask, **kwargs)
#      47
#      48     def forward(self, x:Tensor, mask:Tensor=None, **kwargs):
# ---> 49         return self.ln(x + self.drop_res(self.out(self._apply_attention(x, mask=mask, **kwargs))))
#      50
#      51     def _apply_attention(self, x:Tensor, mask:Tensor=None):
#
# ~/fastai/fastai/text/models/transformer.py in _apply_attention(self, x, r, u, v, mask, mem)
#     113         #### compute attention score (AC is (a) + (c) and BS is (b) + (d) in the paper)
#     114         AC = torch.matmul(wq+u,wk)
# --> 115         BD = _line_shift(torch.matmul(wq+v, wkr))
#     116         if self.scale: attn_score = (AC + BD).mul_(1/(self.d_head ** 0.5))
#     117         if mask is not None:
#
# KeyboardInterrupt:

# %%
learn.save('first_run')

# %%
from fastai import basic_train

# %%
def predict_func(parts): return [F.softmax(p, dim=-1) for p in parts]

# %%
loss_func_name = camel2snake(learn.loss_func.__class__.__name__)
basic_train.loss_func_name2activ[loss_func_name] = predict_func
basic_train._loss_func2activ(learn.loss_func)
# Out:
# <function __main__.predict_func(parts)>

# %%
def predict(self, xb, n_words:int=1, no_unk:bool=True, temperature:float=1., min_p:float=None, sep:str=' ',
            decoder=decode_spec_tokens):
    "Return the `n_words` that come after `text`."
    ds = self.data.single_dl.dataset
    self.model.reset()
    if xb.shape[0] > 1: xb = xb[0][None]
    yb = torch.ones_like(xb)
    new_idx = []
    for _ in range(n_words): #progress_bar(range(n_words), leave=False):
        timestep = []
        outputs = learn.pred_batch(batch=(xb,yb))
        for item in outputs: #progress_bar(range(n_words), leave=False):
            res = item[0][-1]
            if min_p is not None: 
                if (res >= min_p).float().sum() == 0:
                    warn(f"There is no item with probability >= {min_p}, try a lower value.")
                else: res[res < min_p] = 0.
            if temperature != 1.: res.pow_(1 / temperature)
            idx = torch.multinomial(res, 1).item()
            timestep.append(idx)
        new_idx.append(timestep)
        xb = xb.new_tensor(timestep).view(1,1,-1)
    return new_idx

# %%
xb,yb = learn.data.one_batch(cpu=False)

# %%
xb.shape
# Out:
# torch.Size([8, 256, 10])

# %%
out = predict(learn, xb, n_words=60)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-c4f541b600c7> in <module>
# ----> 1 out = predict(learn, xb, n_words=60)
#
# <ipython-input-51-d2a5ed423535> in predict(self, xb, n_words, no_unk, temperature, min_p, sep, decoder)
#       9     for _ in range(n_words): #progress_bar(range(n_words), leave=False):
#      10         timestep = []
# ---> 11         outputs = learn.pred_batch(batch=(xb,yb))
#      12         for item in outputs: #progress_bar(range(n_words), leave=False):
#      13             res = item[0][-1]
#
# ~/fastai/fastai/basic_train.py in pred_batch(self, ds_type, batch, reconstruct)
#     315         cb_handler = CallbackHandler(self.callbacks)
#     316         xb,yb = cb_handler.on_batch_begin(xb,yb, train=False)
# --> 317         preds = loss_batch(self.model.eval(), xb, yb, cb_handler=cb_handler)
#     318         res = _loss_func2activ(self.loss_func)(preds[0])
#     319         if not reconstruct: return res
#
# ~/fastai/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      22     if not is_listy(xb): xb = [xb]
#      23     if not is_listy(yb): yb = [yb]
# ---> 24     out = model(*xb)
#      25     out = cb_handler.on_loss_begin(out)
#      26
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-14-859cfa1607f0> in forward(self, x)
#      34     def forward(self, x):
#      35         bs,x_len,_ = x.size()
# ---> 36         inp = self.encoder(x)
#      37         m_len = self.hidden[0].size(1) if hasattr(self, 'hidden') and len(self.hidden[0].size()) > 1 else 0
#      38         seq_len = m_len + x_len
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-11-dc9a024d6261> in forward(self, x)
#      17         # batch x bptt x (n,o,d,i)
#      18         embs = []
# ---> 19         pos = self.positions[0](x[:,:,iB]) + self.positions[1](x[:,:,iM])
#      20         for i in range(x.shape[-1]-2):
#      21             emb_idx = self.vocab_map[i]
#
# IndexError: index 8 is out of bounds for dimension 2 with size 8

# %%
np.array(out)[:,iND]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-b43e131ea8e5> in <module>
# ----> 1 np.array(out)[:,iND]
#
# NameError: name 'out' is not defined

# %%
xb.cpu().numpy().shape
# Out:
# (8, 256, 10)

# %%
song = dec_arr(np.array(out)); song
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-eeaae5b6d69e> in <module>
# ----> 1 song = dec_arr(np.array(out)); song
#
# NameError: name 'out' is not defined

# %%
stream = song.to_stream()

# %%
stream.show('text')
# Out:
# {0.0} <music21.instrument.Piano Piano>
# {0.0} <music21.stream.Part 0x7fe9db7b2748>
#     {0.0} <music21.stream.Part 0x7fe9db7b26a0>
#         {1.0} <music21.note.Note D>
#         {1.5} <music21.note.Note D>
#         {2.25} <music21.note.Note C>
#         {2.5} <music21.note.Note C>
#         {3.25} <music21.note.Note G>
#         {3.5} <music21.note.Note C>
#         {3.75} <music21.note.Note C>
#         {4.25} <music21.note.Note C>
#         {4.5} <music21.note.Note G>
#         {4.75} <music21.note.Note C>
#         {5.0} <music21.note.Note F>
#         {5.25} <music21.note.Note C>
#         {5.75} <music21.note.Note G>
#         {6.25} <music21.note.Note C>
#         {6.5} <music21.note.Note B>
#         {6.75} <music21.note.Note C>
#         {7.0} <music21.note.Note A>
#         {7.25} <music21.note.Note C>
#         {7.5} <music21.note.Note D>
#         {7.75} <music21.note.Note B>
#         {8.25} <music21.note.Note B>
#         {8.5} <music21.note.Note E>
#         {9.0} <music21.note.Note B>
#         {9.5} <music21.note.Note B>
#         {10.0} <music21.note.Note C>
#         {10.5} <music21.note.Note C>
#         {11.0} <music21.note.Note B>
#         {11.25} <music21.note.Note B->
#         {11.5} <music21.note.Note G>
#         {11.75} <music21.note.Note C>
#         {12.0} <music21.note.Note G>
#         {12.25} <music21.note.Note C>
#         {12.75} <music21.note.Note E>
#         {13.0} <music21.note.Note G>
#         {13.25} <music21.note.Note C>
#         {13.5} <music21.note.Note A>
#         {13.75} <music21.note.Note G>
#         {14.0} <music21.note.Note E->
#         {14.25} <music21.note.Note C>
#         {14.5} <music21.note.Note D>
#         {14.75} <music21.note.Note C>
# {0.0} <music21.stream.Part 0x7fe9db7b2710>
#     {0.0} <music21.stream.Part 0x7fe9db626128>
#         {3.5} <music21.chord.Chord C2 E2 G2 E3>
#         {11.25} <music21.chord.Chord A2 B2 E-3 A3>
#         {11.5} <music21.chord.Chord C2 G#2 B2 B2>
#         {11.75} <music21.chord.Chord C2 F2 G2 C3>
#         {12.0} <music21.chord.Chord G2 F3 E-4 B4>
#         {12.25} <music21.chord.Chord B-2 A3 G4 E5>
#         {12.5} <music21.chord.Chord C2 F#2 A2 E3>
#         {12.75} <music21.chord.Chord E2 A2 E-3 B3>
#         {13.0} <music21.chord.Chord G#2 G#2 F#3 B3>
#         {13.25} <music21.chord.Chord G2 G2 B2 B2>
#         {13.5} <music21.chord.Chord D2 G#2 B-2 C#3>
#         {14.0} <music21.chord.Chord E-2 A2 B2 E-3>
#         {14.25} <music21.chord.Chord E2 D3 C4 E-4>
# {0.0} <music21.tempo.MetronomeMark animato Quarter=120>
# {0.0} <music21.key.Key of C major>
# {0.0} <music21.meter.TimeSignature 4/4>

# %%
stream.show()
# Out:
# ---------------------------------------------------------------------------
# SubConverterFileIOException               Traceback (most recent call last)
# <ipython-input-49-f8d2cd6a80d7> in <module>
# ----> 1 stream.show()
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/stream/__init__.py in show(self, *args, **kwargs)
#     256         if self.isSorted is False and self.autoSort:
#     257             self.sort()
# --> 258         return super().show(*args, **kwargs)
#     259
#     260     #---------------------------------------------------------------------------
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/base.py in show(self, fmt, app, **keywords)
#    2578                                  app=app,
#    2579                                  subformats=subformats,
# -> 2580                                  **keywords)
#    2581
#    2582     #--------------------------------------------------------------------------
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/converter/subConverters.py in show(self, obj, fmt, app, subformats, **keywords)
#     358             for s in scores:
#     359                 fp = helperSubConverter.write(s, helperFormat,
# --> 360                                               subformats=helperSubformats, **keywords)
#     361
#     362                 if helperSubformats[0] == 'png':
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/converter/subConverters.py in write(self, obj, fmt, fp, subformats, **keywords)
#     936                 and ('png' in subformats or 'pdf' in subformats)
#     937                 and not str(environLocal['musescoreDirectPNGPath']).startswith('/skip')):
# --> 938             fp = self.runThroughMusescore(fp, subformats, **keywords)
#     939
#     940         return fp
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/converter/subConverters.py in runThroughMusescore(self, fp, subformats, **keywords)
#     893
#     894         if subformatExtension == 'png':
# --> 895             return self.findPNGfpFromXMLfp(fpOut)
#     896         else:
#     897             return fpOut
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/music21/converter/subConverters.py in findPNGfpFromXMLfp(self, xmlFilePath)
#     805         else:
#     806             raise SubConverterFileIOException(
# --> 807                 "png file of xml not found. Or file >999 pages?")
#     808         return pngfp
#     809
#
# SubConverterFileIOException: png file of xml not found. Or file >999 pages?

# %%
stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv1862'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1862');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
