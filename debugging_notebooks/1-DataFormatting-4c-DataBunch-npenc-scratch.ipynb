# %% [markdown]
# # Tokenize and save data

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *

# %%
import pandas as pd
from fastai_data import *

# %% [markdown]
# ## Preparing the data

# %%
version = 'v7'
data_path = Path('data/midi')
version_path = data_path/version

# %%
source_dir = 'midi_encode/np/dur'
out_path = version_path/source_dir
csv_path = out_path/f'midi_encode.csv'
version_path.ls()
# Out:
# [PosixPath('data/midi/v7/metadata'),
#  PosixPath('data/midi/v7/midi_sources'),
#  PosixPath('data/midi/v7/midi_encode'),
#  PosixPath('data/midi/v7/midi_npz'),
#  PosixPath('data/midi/v7/midi_transform')]

# %%
csv = pd.read_csv(csv_path)
csv = csv.loc[csv[source_dir].notna()];
# Out:
# /home/ubuntu/anaconda3/envs/midi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,9,16,17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# def create_databunch(files, cache_name, vocab=None, batch_size=32, load_cached=False):
#     if load_cached and (out_path/f'{cache_name}/itos.pkl').exists():
#         data = TextLMDataBunch.load(out_path, bs=batch_size, cache_name=cache_name)
#         data.valid_ds.x.processor[0] = TokenizeProcessor(tokenizer=MusicTokenizer())
#     else:
#         ps = [LMOpenFileProcessor(), 
#              LMTokenizeProcessor(tokenizer=MusicTokenizer(), chunksize=num_cpus()*20),
#              LMNumericalizeProcessor(vocab=vocab, max_vocab=500)]

#         data = (TextList(items=files, path=out_path, processor=ps)
#                 .random_split_by_pct(0.01, seed=6)
#                 .label_for_lm()
#                 .databunch(bs=batch_size))
#         data.save(cache_name)
#     vocab = data.train_ds.vocab
#     return data, vocab

# %%
def get_files(csv):
    files = csv[source_dir]
    flist = [Path(version_path/f) for f in files.values]
    flist = [f for f in flist if f.exists()]
    return flist

# %%
all_files = get_files(csv)

# %%
subset = all_files[:10]

# %%
class OpenNPFileProcessor(PreProcessor):
    "`PreProcessor` that opens the filenames and read the texts."
    def process_one(self,item):
        return np.load(item) if isinstance(item, Path) else item

# %%
data = (ItemList(items=subset, path=out_path, processor=[OpenNPFileProcessor(), ])
        .random_split_by_pct(0.01, seed=6))

# %%
class LMPreloader(Callback):
    "Transforms the tokens in `dataset` to a stream of contiguous batches for language modelling."
    
    class CircularIndex():
        "Handles shuffle, direction of indexing, wraps around to head tail in the ragged array as needed"
        def __init__(self, length:int, forward:bool): self.idx, self.forward = np.arange(length), forward
        def __getitem__(self, i): 
            return self.idx[ i%len(self.idx) if self.forward else len(self.idx)-1-i%len(self.idx)]
        def __len__(self) -> int: return len(self.idx)
        def shuffle(self): np.random.shuffle(self.idx)

    def __init__(self, dataset:LabelList, lengths:Collection[int]=None, bs:int=32, bptt:int=70, backwards:bool=False, 
                 shuffle:bool=False):
        self.dataset,self.bs,self.bptt,self.shuffle,self.backwards,self.lengths = dataset,bs,bptt,shuffle,backwards,lengths
        self.totalToks,self.ite_len,self.idx = int(0),None,None

    def __len__(self): 
        if self.ite_len is None:
            if self.lengths is None: self.lengths = np.array([len(item) for item in self.dataset.x.items])
            self.totalToks = self.lengths.sum()
            self.ite_len   = self.bs*int( math.ceil( self.totalToks/(self.bptt*self.bs) )) if self.item is None else 1
        return self.ite_len

    def __getattr__(self,k:str)->Any: return getattr(self.dataset, k)
   
    def allocate_buffers(self):
        "Create the ragged array that will be filled when we ask for items."
        if self.ite_len is None: len(self)
        self.idx   = LMPreloader.CircularIndex(len(self.dataset.x.items), not self.backwards)
        self.batch = np.zeros((self.bs, self.bptt+1, self.dataset.x.items[0].shape[1]), dtype=np.int64)
        self.batch_x, self.batch_y = self.batch[:,0:self.bptt], self.batch[:,1:self.bptt+1] 
        #ro: index of the text we're at inside our datasets for the various batches
        self.ro    = np.zeros(self.bs, dtype=np.int64)
        #ri: index of the token we're at inside our current text for the various batches
        self.ri    = np.zeros(self.bs, dtype=np.int)

    def on_epoch_begin(self, **kwargs):
        if self.idx is None: self.allocate_buffers()
        elif self.shuffle:   self.idx.shuffle()
        self.idx.forward = not self.backwards 

        step = self.totalToks / self.bs
        ln_rag, countTokens, i_rag = 0, 0, -1
        for i in range(0,self.bs):
            #Compute the initial values for ro and ri 
            while ln_rag + countTokens <= int(step * i):
                countTokens += ln_rag
                i_rag       += 1
                ln_rag       = self.lengths[self.idx[i_rag]]
            self.ro[i] = i_rag
            self.ri[i] = ( ln_rag - int(step * i - countTokens) ) if self.backwards else int(step * i - countTokens)
        
    #Training dl gets on_epoch_begin called, val_dl, on_epoch_end
    def on_epoch_end(self, **kwargs): self.on_epoch_begin()

    def __getitem__(self, k:int):
        j = k % self.bs
        if j==0:
            if self.item is not None: return self.dataset[0]
            if self.idx is None: self.on_epoch_begin()
        self.ro[j],self.ri[j] = self.fill_row(not self.backwards, self.dataset.x.items, self.idx, self.batch[j], 
                                              self.ro[j], self.ri[j], overlap=1, lengths=self.lengths)
        return self.batch_x[j], self.batch_y[j]

    def fill_row(self, forward, items, idx, row, ro, ri, overlap,lengths):
        "Fill the row with tokens from the ragged array. --OBS-- overlap != 1 has not been implemented"
        ibuf = n = 0 
        ro  -= 1
        while ibuf < row.shape[0]:  
            ro   += 1 
            ix    = idx[ro]
            rag   = items[ix]
            if forward:
                ri = 0 if ibuf else ri
                n  = min(lengths[ix] - ri, row.shape[0] - ibuf)
                row[ibuf:ibuf+n] = rag[ri:ri+n]
            else:    
                ri = lengths[ix] if ibuf else ri
                n  = min(ri, row.size - ibuf) 
                row[ibuf:ibuf+n] = rag[ri-n:ri][::-1]
            ibuf += n
        return ro, ri + ((n-overlap) if forward else -(n-overlap))

# %%
class LMDataBunch(DataBunch):
    "Create a `TextDataBunch` suitable for training a language model."
    @classmethod
    def create(cls, train_ds, valid_ds, test_ds=None, path:PathOrStr='.', no_check:bool=False, bs=64, val_bs:int=None, 
               num_workers:int=0, device:torch.device=None, collate_fn:Callable=data_collate, 
               dl_tfms:Optional[Collection[Callable]]=None, bptt:int=70, backwards:bool=False) -> DataBunch:
        "Create a `TextDataBunch` in `path` from the `datasets` for language modelling."
        datasets = cls._init_ds(train_ds, valid_ds, test_ds)
        val_bs = ifnone(val_bs, bs)
        datasets = [LMPreloader(ds, shuffle=(i==0), bs=(bs if i==0 else val_bs), bptt=bptt, backwards=backwards) 
                    for i,ds in enumerate(datasets)]
        val_bs = bs
        dls = [DataLoader(d, b, shuffle=False) for d,b in zip(datasets, (bs,val_bs,val_bs,val_bs)) if d is not None]
        return cls(*dls, path=path, device=device, dl_tfms=dl_tfms, collate_fn=collate_fn, no_check=no_check)
    
    def save(self, cache_name:PathOrStr='tmp'):
        "Save the `DataBunch` in `self.path/cache_name` folder."
        os.makedirs(self.path/cache_name, exist_ok=True)
        cache_path = self.path/cache_name
        np.save(cache_path/f'train_ids.npy', self.train_ds.x.items)
        np.save(cache_path/f'train_lbl.npy', self.train_ds.y.items)
        np.save(cache_path/f'valid_ids.npy', self.valid_ds.x.items)
        np.save(cache_path/f'valid_lbl.npy', self.valid_ds.y.items)
        if self.test_dl is not None: np.save(cache_path/f'test_ids.npy', self.test_ds.x.items)
        if hasattr(self.train_ds, 'classes'): save_texts(cache_path/'classes.txt', self.train_ds.classes)

    @classmethod
    def load(cls, path:PathOrStr, cache_name:PathOrStr='tmp', processor:PreProcessor=None, **kwargs):
        "Load a `TextDataBunch` from `path/cache_name`. `kwargs` are passed to the dataloader creation."
        cache_path = Path(path)/cache_name
        train_ids,train_lbls = np.load(cache_path/f'train_ids.npy'), np.load(cache_path/f'train_lbl.npy')
        valid_ids,valid_lbls = np.load(cache_path/f'valid_ids.npy'), np.load(cache_path/f'valid_lbl.npy')
        test_ids = np.load(cache_path/f'test_ids.npy') if os.path.isfile(cache_path/f'test_ids.npy') else None
        classes = loadtxt_str(cache_path/'classes.txt') if os.path.isfile(cache_path/'classes.txt') else None
        return cls.from_ids(path, vocab, train_ids, valid_ids, test_ids, train_lbls, valid_lbls, classes, processor, **kwargs)

# %%
data._bunch = LMDataBunch

# %%
data._bunch
# Out:
# __main__.LMDataBunch

# %%
data.x

# %%
data
# Out:
# ItemLists;
#
# Train: ItemList (10 items)
# [PosixPath('data/midi/v7/midi_encode/np/dur/hooktheory/pianoroll/w/wayne-sharpe/yu-gi-oh-theme-song/chorus_key.npy'), PosixPath('data/midi/v7/midi_encode/np/dur/hooktheory/pianoroll/w/what-a-day/kiefer/chorus_key.npy'), PosixPath('data/midi/v7/midi_encode/np/dur/hooktheory/pianoroll/w/whiteflame/senbonzakura/verse_key.npy'), PosixPath('data/midi/v7/midi_encode/np/dur/hooktheory/pianoroll/w/wham/last-christmas/intro_key.npy'), PosixPath('data/midi/v7/midi_encode/np/dur/hooktheory/pianoroll/w/whiteflame/senbonzakura/pre-chorus_key.npy')]...
# Path: data/midi/v7/midi_encode/np/dur;
#
# Valid: ItemList (0 items)
# []...
# Path: data/midi/v7/midi_encode/np/dur;
#
# Test: None

# %%
class LMLabelList(EmptyLabelList):
    "Basic `ItemList` for dummy labels."
    def __init__(self, items:Iterator, **kwargs):
        super().__init__(items, **kwargs)
        self.loss_func = CrossEntropyFlat()

# %%
data = data.label_const(label_cls=LMLabelList)

# %%
data.x._bunch = LMDataBunch

# %%
data = data.databunch(bs=2)

# %%
data.train_dl.dl.dataset
# Out:
# LMPreloader
# dataset: LabelList
# y: LMLabelList (10 items)
# [EmptyLabel , EmptyLabel , EmptyLabel , EmptyLabel , EmptyLabel ]...
# Path: data/midi/v7/midi_encode/np/dur
# x: ItemList (10 items)
# [array([[12, -1,  1, -1],
#        [ 7,  3,  1,  0],
#        [12, -1,  0, -1],
#        [ 6,  3,  1,  0],
#        ...,
#        [12, -1,  0, -1],
#        [ 3,  3, -2,  1],
#        [ 6,  3, -2,  1],
#        [10,  3, -2,  1]]), array([[12, -1,  0, -1],
#        [ 0,  3,  6,  1],
#        [ 4,  3,  6,  1],
#        [10,  3,  6,  1],
#        ...,
#        [ 2,  3, -2,  1],
#        [ 6,  3, -2,  1],
#        [ 9,  3, -2,  1],
#        [ 1,  4, -2,  1]]), array([[12, -1,  0, -1],
#        [ 2,  3, 16,  1],
#        [ 5,  3, 16,  1],
#        [ 9,  3, 16,  1],
#        ...,
#        [ 0,  3, -2,  1],
#        [ 4,  3, -2,  1],
#        [ 7,  3, -2,  1],
#        [ 2,  4, -2,  0]]), array([[12, -1,  0, -1],
#        [ 1,  3, 32,  1],
#        [ 5,  3, 32,  1],
#        [ 8,  3, 32,  1],
#        ...,
#        [ 8,  2, -2,  1],
#        [ 0,  3, -2,  1],
#        [ 3,  3, -2,  1],
#        [ 8,  4, -2,  0]]), array([[12, -1,  0, -1],
#        [10,  2, 16,  1],
#        [ 2,  3, 16,  1],
#        [ 5,  3, 16,  1],
#        ...,
#        [12, -1,  0, -1],
#        [ 5,  4,  2,  0],
#        [12, -1,  0, -1],
#        [ 5,  4, -2,  0]])]...
# Path: data/midi/v7/midi_encode/np/dur
# lengths: [ 502  399  640  640  654  448  632  464 1276 1255]
# bs: 2
# bptt: 70
# backwards: False
# shuffle: True

# %%
data.save(cache_name='tmp_test')

# %%
next(iter(data.train_dl))[0].shape
# Out:
# torch.Size([2, 70, 4])

# %%
len(data.train_ds)
# Out:
# 10

# %%
data.train_ds.x.items[0].shape[1]
# Out:
# 4

# %%
a = LanguageModelPreLoader(data.train_ds, shuffle=True, bs=4, bptt=20, backwards=False)

# %%
a.on_epoch_begin()

# %%
a.batch.shape
# Out:
# (4, 21, 4)

# %%
t = a[0]

# %%
t[1]
# Out:
# array([[ 7,  3, -2,  1],
#        [12, -1,  0, -1],
#        [ 0,  3, -2,  1],
#        [ 3,  3, -2,  1],
#        ...,
#        [ 7,  3, -2,  1],
#        [12, -1,  0, -1],
#        [ 0,  3, -2,  1],
#        [ 3,  3, -2,  1]])

# %%
t[0]
# Out:
# array([[ 3,  3, -2,  1],
#        [ 7,  3, -2,  1],
#        [12, -1,  0, -1],
#        [ 0,  3, -2,  1],
#        ...,
#        [ 3,  3, -2,  1],
#        [ 7,  3, -2,  1],
#        [12, -1,  0, -1],
#        [ 0,  3, -2,  1]])

# %%
# %debug
# Out:
# > <ipython-input-46-65c956137e5f>(77)fill_row()
#      75                 ri = 0 if ibuf else ri
#      76                 n  = min(lengths[ix] - ri, row.size - ibuf)
# ---> 77                 row[ibuf:ibuf+n] = rag[ri:ri+n]
#      78             else:
#      79                 ri = lengths[ix] if ibuf else ri
#
# ipdb> ri
# 0
# ipdb> row.shape
# (11, 4)
# ipdb> rag.shape
# (502, 4)
# ipdb> !n
# 44
# ipdb> quit

# %%
csv
# Out:
#                                                 song_url  \
# 1      https://www.hooktheory.com/theorytab/view/wayn...
# 2      https://www.hooktheory.com/theorytab/view/what...
# 3      https://www.hooktheory.com/theorytab/view/whit...
# 4      https://www.hooktheory.com/theorytab/view/wham...
# 5      https://www.hooktheory.com/theorytab/view/whit...
# 6      https://www.hooktheory.com/theorytab/view/will...
# 7      https://www.hooktheory.com/theorytab/view/wham...
# 8      https://www.hooktheory.com/theorytab/view/will...
# 10     https://www.hooktheory.com/theorytab/view/whit...
# 11     https://www.hooktheory.com/theorytab/view/wham...
# 12     https://www.hooktheory.com/theorytab/view/wham...
# 13     https://www.hooktheory.com/theorytab/view/will...
# 14     https://www.hooktheory.com/theorytab/view/we-l...
# 15     https://www.hooktheory.com/theorytab/view/will...
# 16     https://www.hooktheory.com/theorytab/view/wavv...
# 17     https://www.hooktheory.com/theorytab/view/weez...
# 18     https://www.hooktheory.com/theorytab/view/walt...
# 19     https://www.hooktheory.com/theorytab/view/wg-s...
# 20     https://www.hooktheory.com/theorytab/view/weeb...
# 21     https://www.hooktheory.com/theorytab/view/wood...
# 22     https://www.hooktheory.com/theorytab/view/wood...
# 23     https://www.hooktheory.com/theorytab/view/wavv...
# 24     https://www.hooktheory.com/theorytab/view/wavv...
# 25     https://www.hooktheory.com/theorytab/view/weeb...
# 26     https://www.hooktheory.com/theorytab/view/walt...
# 27     https://www.hooktheory.com/theorytab/view/weez...
# 28     https://www.hooktheory.com/theorytab/view/wavv...
# 29     https://www.hooktheory.com/theorytab/view/wavv...
# 30     https://www.hooktheory.com/theorytab/view/walt...
# 31     https://www.hooktheory.com/theorytab/view/walt...
# ...                                                  ...
# 39911                                                NaN
# 39912                                                NaN
# 39913                                                NaN
# 39914                                                NaN
# 39915                                                NaN
# 39917                                                NaN
# 39918                                                NaN
# 39919                                                NaN
# 39920                                                NaN
# 39921                                                NaN
# 39922                                                NaN
# 39923                                                NaN
# 39924                                                NaN
# 39925                                                NaN
# 39926                                                NaN
# 39927                                                NaN
# 39928                                                NaN
# 39929                                                NaN
# 39930                                                NaN
# 39931                                                NaN
# 39932                                                NaN
# 39933                                                NaN
# 39934                                                NaN
# 39935                                                NaN
# 39936                                                NaN
# 39937                                                NaN
# 39938                                                NaN
# 39939                                                NaN
# 39940                                                NaN
# 39941                                                NaN
#
#                 instruments  ht_offset time_signature  \
# 1               Piano,Piano        0.0            4/4
# 2               Piano,Piano       -5.0            4/4
# 3               Piano,Piano       -5.0            4/4
# 4               Piano,Piano       -1.0            4/4
# 5               Piano,Piano       -5.0            4/4
# 6                     Piano       -4.0            4/4
# 7               Piano,Piano       -1.0            4/4
# 8                     Piano       -4.0            4/4
# 10              Piano,Piano       -5.0            4/4
# 11              Piano,Piano       -1.0            4/4
# 12              Piano,Piano        0.0            4/4
# 13              Piano,Piano       -2.0            4/4
# 14              Piano,Piano        1.0            4/4
# 15              Piano,Piano       -4.0            4/4
# 16                    Piano        2.0            4/4
# 17              Piano,Piano       -3.0            4/4
# 18              Piano,Piano        0.0            4/4
# 19              Piano,Piano        5.0            4/4
# 20              Piano,Piano        3.0            4/4
# 21              Piano,Piano        3.0            4/4
# 22              Piano,Piano        3.0            4/4
# 23              Piano,Piano       -1.0            4/4
# 24              Piano,Piano       -4.0            4/4
# 25                    Piano        1.0            4/4
# 26              Piano,Piano        0.0            4/4
# 27              Piano,Piano        6.0            4/4
# 28              Piano,Piano        3.0            4/4
# 29              Piano,Piano        3.0            4/4
# 30              Piano,Piano       -5.0            4/4
# 31              Piano,Piano       -5.0            4/4
# ...                     ...        ...            ...
# 39911                   NaN        NaN            3/4
# 39912           Grand Piano        NaN            4/4
# 39913                 Piano        NaN            4/4
# 39914                   NaN        NaN            4/4
# 39915        Electric Piano        NaN            4/4
# 39917        Electric Piano        NaN            4/4
# 39918                   NaN        NaN            4/4
# 39919                 Voice        NaN            3/4
# 39920                   NaN        NaN            2/2
# 39921                 Voice        NaN            4/4
# 39922                   NaN        NaN            4/4
# 39923                   NaN        NaN            4/4
# 39924                   NaN        NaN            4/4
# 39925                   NaN        NaN            4/4
# 39926           Grand Piano        NaN            4/4
# 39927           Grand Piano        NaN            4/4
# 39928          Instrument 1        NaN            4/4
# 39929                MELODY        NaN            2/4
# 39930                 Piano        NaN            2/2
# 39931        Alto Saxophone        NaN            4/4
# 39932                   NaN        NaN            4/4
# 39933        Alto Saxophone        NaN            4/4
# 39934                   NaN        NaN            4/4
# 39935                   NaN        NaN            2/2
# 39936                   NaN        NaN            4/4
# 39937                   NaN        NaN            4/4
# 39938         MusicXML Part        NaN            4/4
# 39939  Acoustic Grand Piano        NaN            4/4
# 39940                 Piano        NaN            3/4
# 39941           Grand Piano        NaN            4/4
#
#                                             title quarter_length  ht_mode  \
# 1                             yu-gi-oh-theme-song           32.0      1.0
# 2                                          kiefer           16.0      6.0
# 3                                    senbonzakura           32.0      6.0
# 4                                  last-christmas           32.0      1.0
# 5                                    senbonzakura           32.0      6.0
# 6                               on-the-road-again           28.0      1.0
# 7                                  last-christmas           32.0      1.0
# 8                               on-the-road-again           28.0      1.0
# 10                                   senbonzakura           64.0      6.0
# 11                                 last-christmas           64.0      1.0
# 12                                        freedom           32.0      1.0
# 13                     you-were-always-on-my-mind           48.0      1.0
# 14                                       bogatyri           63.0      6.0
# 15                                blue-eyes-cryin           28.0      NaN
# 16                                   way-too-much           31.5      1.0
# 17                                falling-for-you           20.0      1.0
# 18                               the-freaking-fcc           36.0      1.0
# 19                                west-wing-suite           56.0      1.0
# 20                                  amazing-horse           36.0      6.0
# 21                                rainbow-factory           32.0      6.0
# 22                                rainbow-factory           32.0      6.0
# 23                                    nine-is-god           28.0      5.0
# 24                                    nine-is-god           68.0      1.0
# 25                                        donkeys           32.0      1.0
# 26                               the-freaking-fcc           48.0      1.0
# 27                      undone---the-sweater-song           64.0      1.0
# 28                                           pony           64.0      1.0
# 29                                           pony           36.0      1.0
# 30                        family-guy---theme-song           69.5      1.0
# 31                          family-guy-theme-song           69.5      1.0
# ...                                           ...            ...      ...
# 39911   Sous le ciel de Paris (under Paris skies)          357.0      NaN
# 39912                                   Pannonica          100.0      NaN
# 39913                Lo, How A Rose E'er Blooming           68.0      NaN
# 39914                                     Used To          226.0      NaN
# 39915                  It might as well be Spring          164.0      NaN
# 39917                 Give My Regards To Broadway          128.0      NaN
# 39918                                 I'm Walkin'          156.0      NaN
# 39919                      I Find No Fault In Him          144.0      NaN
# 39920                                     My Ship          161.0      NaN
# 39921                              Don't Blame Me          132.0      NaN
# 39922                 Hold Me, Thrill Me, Kiss Me          108.0      NaN
# 39923                           This Is All I Ask          193.0      NaN
# 39924          Supercalifragilisticexpialidocious          144.0      NaN
# 39925                  You Make Me Feel Brand New          192.0      NaN
# 39926                      KARNAVALSPOTPOURRI 124          303.0      NaN
# 39927                                  Desafinado          276.0      NaN
# 39928                  I JUST DON'T KNOW IF I CAN          156.0      NaN
# 39929  I'm Gonna Be A Wheel Someday (Transcribed)          274.0      NaN
# 39930           I Wonder Where My Baby Is Tonight          268.0      NaN
# 39931                               Groovin' High           88.0      NaN
# 39932                                 Cest si bon          156.0      NaN
# 39933                         With or without you          256.0      NaN
# 39934                                Como la Flor          344.0      NaN
# 39935              Gonna Get Along Without Ya Now          248.0      NaN
# 39936                              Stolen Moments           84.0      NaN
# 39937                            The Music Played          116.0      NaN
# 39938                                 Exodus Test           89.0      NaN
# 39939           JA, JA, SO BLAUW BLUHT DER ENZIAN          518.0      NaN
# 39940        The Blood Will Never Lose It's Power          118.0      NaN
# 39941                               Too Fat Polka          392.0      NaN
#
#            source                                           artist ht_key  \
# 1      hooktheory                                     wayne-sharpe      C
# 2      hooktheory                                       what-a-day      D
# 3      hooktheory                                       whiteflame      D
# 4      hooktheory                                             wham     Db
# 5      hooktheory                                       whiteflame      D
# 6      hooktheory                                    willie-nelson      E
# 7      hooktheory                                             wham     Db
# 8      hooktheory                                    willie-nelson      E
# 10     hooktheory                                       whiteflame      D
# 11     hooktheory                                             wham     Db
# 12     hooktheory                                             wham      C
# 13     hooktheory                                    willie-nelson      D
# 14     hooktheory                                  we-lost-the-sea     G#
# 15     hooktheory                                    willie-nelson      E
# 16     hooktheory                                           wavves     Bb
# 17     hooktheory                                           weezer     Eb
# 18     hooktheory                                    walter-murphy      C
# 19     hooktheory                                 wg-snuffy-walden      G
# 20     hooktheory                                            weebl     F#
# 21     hooktheory                                    woodentoaster     F#
# 22     hooktheory                                    woodentoaster     F#
# 23     hooktheory                                           wavves     Ab
# 24     hooktheory                                           wavves      E
# 25     hooktheory                                            weebl      B
# 26     hooktheory                                    walter-murphy      C
# 27     hooktheory                                           weezer     F#
# 28     hooktheory                                           wavves      A
# 29     hooktheory                                           wavves      A
# 30     hooktheory                                    walter-murphy      F
# 31     hooktheory                                    walter-murphy      F
# ...           ...                                              ...    ...
# 39911   wikifonia           Hubert Giraud, Jaen Drejac, Kim Gannon    NaN
# 39912   wikifonia                                  Thelonious Monk    NaN
# 39913   wikifonia                               Michael Praetorius    NaN
# 39914   wikifonia         Zac Maloy, Chris Daughtry, Howard Benson    NaN
# 39915   wikifonia            Richard Rodgers, Oscar Hammerstein II    NaN
# 39917   wikifonia                                  George M. Cohan    NaN
# 39918   wikifonia                Antoine Domino & Dave Bartholomew    NaN
# 39919   wikifonia                                    Andrae Crouch    NaN
# 39920   wikifonia                         Kurt Weill, Ira Gershwin    NaN
# 39921   wikifonia                     Jimmy McHugh, Dorothy Fields    NaN
# 39922   wikifonia                                      Harry Noble    NaN
# 39923   wikifonia                                   Gordon Jenkins    NaN
# 39924   wikifonia                  Richard Sherman, Robert Sherman    NaN
# 39925   wikifonia                        Thom Bell and Linda Creed    NaN
# 39926   wikifonia                                           Unknow    NaN
# 39927   wikifonia                          Antonio Carlos Jobim, .    NaN
# 39928   wikifonia                                Carol Bayer Sager    NaN
# 39929   wikifonia  David Bartholomew, Antoine Domino and Roy Hayes    NaN
# 39930   wikifonia                       Walter Donaldson, Gus Kahn    NaN
# 39931   wikifonia                  Charlie Parker, Dizzy Gillespie    NaN
# 39932   wikifonia                                      Henri Betti    NaN
# 39933   wikifonia                                               U2    NaN
# 39934   wikifonia                   A.B. Quintanilla, Pete Astudio    NaN
# 39935   wikifonia                                    Milton Kellem    NaN
# 39936   wikifonia                                    Oliver Nelson    NaN
# 39937   wikifonia                        Mike Hawker & Udo Jurgens    NaN
# 39938   wikifonia                                      Ernest Gold    NaN
# 39939   wikifonia                                      Traditional    NaN
# 39940   wikifonia                                    Andrae Crouch    NaN
# 39941   wikifonia                  Ross MacLean, Arthur Richardson    NaN
#
#                              ...                                  section  \
# 1                            ...                                   chorus
# 2                            ...                                   chorus
# 3                            ...                                    verse
# 4                            ...                                    intro
# 5                            ...                               pre-chorus
# 6                            ...                                   bridge
# 7                            ...                                   chorus
# 8                            ...                                    verse
# 10                           ...                                   chorus
# 11                           ...                                    verse
# 12                           ...                                   chorus
# 13                           ...                                    verse
# 14                           ...                                    intro
# 15                           ...                                   chorus
# 16                           ...                                    intro
# 17                           ...                                    intro
# 18                           ...                                   bridge
# 19                           ...                             instrumental
# 20                           ...                                   bridge
# 21                           ...                                    intro
# 22                           ...                                   bridge
# 23                           ...                                    verse
# 24                           ...                                   chorus
# 25                           ...                                    intro
# 26                           ...                          intro-and-verse
# 27                           ...                                   chorus
# 28                           ...                                    verse
# 29                           ...                                   chorus
# 30                           ...                                   chorus
# 31                           ...                                    verse
# ...                          ...                                      ...
# 39911                        ...                                      NaN
# 39912                        ...                                      NaN
# 39913                        ...                                      NaN
# 39914                        ...                                      NaN
# 39915                        ...                                      NaN
# 39917                        ...                                      NaN
# 39918                        ...                                      NaN
# 39919                        ...                                      NaN
# 39920                        ...                                      NaN
# 39921                        ...                                      NaN
# 39922                        ...                                      NaN
# 39923                        ...                                      NaN
# 39924                        ...                                      NaN
# 39925                        ...                                      NaN
# 39926                        ...                                      NaN
# 39927                        ...                                      NaN
# 39928                        ...                                      NaN
# 39929                        ...                                      NaN
# 39930                        ...                                      NaN
# 39931                        ...                                      NaN
# 39932                        ...                                      NaN
# 39933                        ...                                      NaN
# 39934                        ...                                      NaN
# 39935                        ...                                      NaN
# 39936                        ...                                      NaN
# 39937                        ...                                      NaN
# 39938                        ...                                      NaN
# 39939                        ...                                      NaN
# 39940                        ...                                      NaN
# 39941                        ...                                      NaN
#
#                                          parts ht_time_signature ht_bpm  \
# 1                                 intro,chorus               4.0  128.0
# 2                                       chorus               4.0   96.0
# 3                      verse,pre-chorus,chorus               4.0  152.0
# 4                           intro,verse,chorus               4.0  108.0
# 5                      verse,pre-chorus,chorus               4.0  152.0
# 6                                 verse,bridge               4.0  112.0
# 7                           intro,verse,chorus               4.0  108.0
# 8                                 verse,bridge               4.0  112.0
# 10                     verse,pre-chorus,chorus               4.0  152.0
# 11                          intro,verse,chorus               4.0  108.0
# 12                                      chorus               4.0  128.0
# 13                                       verse               4.0   68.0
# 14                                       intro               4.0  123.0
# 15                                      chorus               4.0   58.0
# 16                   intro,verse,chorus,bridge               4.0  128.0
# 17                     intro,verse,chorus,solo               4.0  108.0
# 18                      intro-and-verse,bridge               4.0  126.0
# 19                                instrumental               4.0   86.0
# 20                               chorus,bridge               4.0  149.0
# 21                                intro,bridge               4.0  148.0
# 22                                intro,bridge               4.0  148.0
# 23                                verse,chorus               4.0  110.0
# 24                                verse,chorus               4.0  122.0
# 25                                 intro,verse               4.0  140.0
# 26                      intro-and-verse,bridge               4.0  126.0
# 27                      intro-and-verse,chorus               4.0  160.0
# 28     verse,pre-chorus,chorus,chorus-lead-out               4.0  170.0
# 29     verse,pre-chorus,chorus,chorus-lead-out               4.0  165.0
# 30                                      chorus               4.0  128.0
# 31                                       verse               4.0  128.0
# ...                                        ...               ...    ...
# 39911                                      NaN               NaN    NaN
# 39912                                      NaN               NaN    NaN
# 39913                                      NaN               NaN    NaN
# 39914                                      NaN               NaN    NaN
# 39915                                      NaN               NaN    NaN
# 39917                                      NaN               NaN    NaN
# 39918                                      NaN               NaN    NaN
# 39919                                      NaN               NaN    NaN
# 39920                                      NaN               NaN    NaN
# 39921                                      NaN               NaN    NaN
# 39922                                      NaN               NaN    NaN
# 39923                                      NaN               NaN    NaN
# 39924                                      NaN               NaN    NaN
# 39925                                      NaN               NaN    NaN
# 39926                                      NaN               NaN    NaN
# 39927                                      NaN               NaN    NaN
# 39928                                      NaN               NaN    NaN
# 39929                                      NaN               NaN    NaN
# 39930                                      NaN               NaN    NaN
# 39931                                      NaN               NaN    NaN
# 39932                                      NaN               NaN    NaN
# 39933                                      NaN               NaN    NaN
# 39934                                      NaN               NaN    NaN
# 39935                                      NaN               NaN    NaN
# 39936                                      NaN               NaN    NaN
# 39937                                      NaN               NaN    NaN
# 39938                                      NaN               NaN    NaN
# 39939                                      NaN               NaN    NaN
# 39940                                      NaN               NaN    NaN
# 39941                                      NaN               NaN    NaN
#
#                           midi_title  \
# 1                          yu-gi-oh3
# 2                             kiefer
# 3                       Senbonzakura
# 4               Last Christmas Intro
# 5      senbonzakura - pre-Pre-Chorus
# 6                  On The Road Again
# 7              Last Christmas Chorus
# 8                  On The Road Again
# 10                      Senbonzakura
# 11              Last Christmas Verse
# 12                    Freedom Chorus
# 13        You Were Always On My Mind
# 14                          bogatyri
# 15                   Blue Eyes Cryin
# 16                      Way Too Much
# 17             falling for you intro
# 18                Freakin FCC Bridge
# 19                            snuffy
# 20            Amazing Horse - Bridge
# 21                   Rainbow Factory
# 22                   Rainbow Factory
# 23                    nineisgodverse
# 24                       Nine is God
# 25                     Donkeys Intro
# 26                  The Freaking FCC
# 27                destroy my sweater
# 28                        pony verse
# 29                       pony chorus
# 30           Family Guy - Theme Song
# 31           Family Guy - Theme Song
# ...                              ...
# 39911                            NaN
# 39912                            NaN
# 39913                            NaN
# 39914                            NaN
# 39915                            NaN
# 39917                            NaN
# 39918                            NaN
# 39919                            NaN
# 39920                            NaN
# 39921                            NaN
# 39922                            NaN
# 39923                            NaN
# 39924                            NaN
# 39925                            NaN
# 39926                            NaN
# 39927                            NaN
# 39928                            NaN
# 39929                            NaN
# 39930                            NaN
# 39931                            NaN
# 39932                            NaN
# 39933                            NaN
# 39934                            NaN
# 39935                            NaN
# 39936                            NaN
# 39937                            NaN
# 39938                            NaN
# 39939                            NaN
# 39940                            NaN
# 39941                            NaN
#
#                                                      mxl  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# 30                                                   NaN
# 31                                                   NaN
# ...                                                  ...
# 39911  midi_sources/wikifonia/Hubert Giraud, Jaen Dre...
# 39912  midi_sources/wikifonia/Thelonious Monk - Panno...
# 39913  midi_sources/wikifonia/Michael Praetorius - Lo...
# 39914  midi_sources/wikifonia/ Zac Maloy, Chris Daugh...
# 39915  midi_sources/wikifonia/Richard Rodgers, Oscar ...
# 39917  midi_sources/wikifonia/George M. Cohan - Give ...
# 39918  midi_sources/wikifonia/Antoine Domino & Dave B...
# 39919  midi_sources/wikifonia/Andrae Crouch - I Find ...
# 39920  midi_sources/wikifonia/Kurt Weill, Ira Gershwi...
# 39921  midi_sources/wikifonia/Jimmy McHugh, Dorothy F...
# 39922  midi_sources/wikifonia/Harry Noble - Hold Me, ...
# 39923  midi_sources/wikifonia/Gordon Jenkins - This I...
# 39924  midi_sources/wikifonia/Richard Sherman, Robert...
# 39925  midi_sources/wikifonia/Thom Bell and Linda Cre...
# 39926  midi_sources/wikifonia/Unknow - KARNAVALSPOTPO...
# 39927  midi_sources/wikifonia/Antonio Carlos Jobim, ....
# 39928  midi_sources/wikifonia/Carol Bayer Sager - Les...
# 39929  midi_sources/wikifonia/David Bartholomew, Anto...
# 39930  midi_sources/wikifonia/Walter Donaldson, Gus K...
# 39931  midi_sources/wikifonia/Charlie Parker, Dizzy G...
# 39932  midi_sources/wikifonia/Henri Betti - Cest si b...
# 39933  midi_sources/wikifonia/U2 - With or without yo...
# 39934  midi_sources/wikifonia/A.B. Quintanilla, Pete ...
# 39935  midi_sources/wikifonia/Milton Kellem - Gonna G...
# 39936  midi_sources/wikifonia/Oliver Nelson - Stolen ...
# 39937  midi_sources/wikifonia/Mike Hawker & Udo Jurge...
# 39938  midi_sources/wikifonia/Ernest Gold - Exodus Te...
# 39939  midi_sources/wikifonia/Traditional - JA, JA, S...
# 39940  midi_sources/wikifonia/Andrae Crouch - The Blo...
# 39941  midi_sources/wikifonia/Ross MacLean, Arthur Ri...
#
#                                           midi_transform  \
# 1      midi_transform/hooktheory/pianoroll/w/wayne-sh...
# 2      midi_transform/hooktheory/pianoroll/w/what-a-d...
# 3      midi_transform/hooktheory/pianoroll/w/whitefla...
# 4      midi_transform/hooktheory/pianoroll/w/wham/las...
# 5      midi_transform/hooktheory/pianoroll/w/whitefla...
# 6      midi_transform/hooktheory/pianoroll/w/willie-n...
# 7      midi_transform/hooktheory/pianoroll/w/wham/las...
# 8      midi_transform/hooktheory/pianoroll/w/willie-n...
# 10     midi_transform/hooktheory/pianoroll/w/whitefla...
# 11     midi_transform/hooktheory/pianoroll/w/wham/las...
# 12     midi_transform/hooktheory/pianoroll/w/wham/fre...
# 13     midi_transform/hooktheory/pianoroll/w/willie-n...
# 14     midi_transform/hooktheory/pianoroll/w/we-lost-...
# 15     midi_transform/hooktheory/pianoroll/w/willie-n...
# 16     midi_transform/hooktheory/pianoroll/w/wavves/w...
# 17     midi_transform/hooktheory/pianoroll/w/weezer/f...
# 18     midi_transform/hooktheory/pianoroll/w/walter-m...
# 19     midi_transform/hooktheory/pianoroll/w/wg-snuff...
# 20     midi_transform/hooktheory/pianoroll/w/weebl/am...
# 21     midi_transform/hooktheory/pianoroll/w/woodento...
# 22     midi_transform/hooktheory/pianoroll/w/woodento...
# 23     midi_transform/hooktheory/pianoroll/w/wavves/n...
# 24     midi_transform/hooktheory/pianoroll/w/wavves/n...
# 25     midi_transform/hooktheory/pianoroll/w/weebl/do...
# 26     midi_transform/hooktheory/pianoroll/w/walter-m...
# 27     midi_transform/hooktheory/pianoroll/w/weezer/u...
# 28     midi_transform/hooktheory/pianoroll/w/wavves/p...
# 29     midi_transform/hooktheory/pianoroll/w/wavves/p...
# 30     midi_transform/hooktheory/pianoroll/w/walter-m...
# 31     midi_transform/hooktheory/pianoroll/w/walter-m...
# ...                                                  ...
# 39911  midi_transform/from_mxl/wikifonia/Hubert Girau...
# 39912  midi_transform/from_mxl/wikifonia/Thelonious M...
# 39913  midi_transform/from_mxl/wikifonia/Michael Prae...
# 39914  midi_transform/from_mxl/wikifonia/ Zac Maloy, ...
# 39915  midi_transform/from_mxl/wikifonia/Richard Rodg...
# 39917  midi_transform/from_mxl/wikifonia/George M. Co...
# 39918  midi_transform/from_mxl/wikifonia/Antoine Domi...
# 39919  midi_transform/from_mxl/wikifonia/Andrae Crouc...
# 39920  midi_transform/from_mxl/wikifonia/Kurt Weill, ...
# 39921  midi_transform/from_mxl/wikifonia/Jimmy McHugh...
# 39922  midi_transform/from_mxl/wikifonia/Harry Noble ...
# 39923  midi_transform/from_mxl/wikifonia/Gordon Jenki...
# 39924  midi_transform/from_mxl/wikifonia/Richard Sher...
# 39925  midi_transform/from_mxl/wikifonia/Thom Bell an...
# 39926  midi_transform/from_mxl/wikifonia/Unknow - KAR...
# 39927  midi_transform/from_mxl/wikifonia/Antonio Carl...
# 39928  midi_transform/from_mxl/wikifonia/Carol Bayer ...
# 39929  midi_transform/from_mxl/wikifonia/David Bartho...
# 39930  midi_transform/from_mxl/wikifonia/Walter Donal...
# 39931  midi_transform/from_mxl/wikifonia/Charlie Park...
# 39932  midi_transform/from_mxl/wikifonia/Henri Betti ...
# 39933  midi_transform/from_mxl/wikifonia/U2 - With or...
# 39934  midi_transform/from_mxl/wikifonia/A.B. Quintan...
# 39935  midi_transform/from_mxl/wikifonia/Milton Kelle...
# 39936  midi_transform/from_mxl/wikifonia/Oliver Nelso...
# 39937  midi_transform/from_mxl/wikifonia/Mike Hawker ...
# 39938  midi_transform/from_mxl/wikifonia/Ernest Gold ...
# 39939  midi_transform/from_mxl/wikifonia/Traditional ...
# 39940  midi_transform/from_mxl/wikifonia/Andrae Crouc...
# 39941  midi_transform/from_mxl/wikifonia/Ross MacLean...
#
#                                                 midi_npz  midi_npz_timesteps  \
# 1      midi_npz/hooktheory/pianoroll/w/wayne-sharpe/y...               129.0
# 2      midi_npz/hooktheory/pianoroll/w/what-a-day/kie...                65.0
# 3      midi_npz/hooktheory/pianoroll/w/whiteflame/sen...               129.0
# 4      midi_npz/hooktheory/pianoroll/w/wham/last-chri...               129.0
# 5      midi_npz/hooktheory/pianoroll/w/whiteflame/sen...               129.0
# 6      midi_npz/hooktheory/pianoroll/w/willie-nelson/...               113.0
# 7      midi_npz/hooktheory/pianoroll/w/wham/last-chri...               129.0
# 8      midi_npz/hooktheory/pianoroll/w/willie-nelson/...               113.0
# 10     midi_npz/hooktheory/pianoroll/w/whiteflame/sen...               257.0
# 11     midi_npz/hooktheory/pianoroll/w/wham/last-chri...               257.0
# 12     midi_npz/hooktheory/pianoroll/w/wham/freedom/c...               129.0
# 13     midi_npz/hooktheory/pianoroll/w/willie-nelson/...               193.0
# 14     midi_npz/hooktheory/pianoroll/w/we-lost-the-se...               253.0
# 15     midi_npz/hooktheory/pianoroll/w/willie-nelson/...               113.0
# 16     midi_npz/hooktheory/pianoroll/w/wavves/way-too...               127.0
# 17     midi_npz/hooktheory/pianoroll/w/weezer/falling...                81.0
# 18     midi_npz/hooktheory/pianoroll/w/walter-murphy/...               145.0
# 19     midi_npz/hooktheory/pianoroll/w/wg-snuffy-wald...               225.0
# 20     midi_npz/hooktheory/pianoroll/w/weebl/amazing-...               145.0
# 21     midi_npz/hooktheory/pianoroll/w/woodentoaster/...               129.0
# 22     midi_npz/hooktheory/pianoroll/w/woodentoaster/...               129.0
# 23     midi_npz/hooktheory/pianoroll/w/wavves/nine-is...               113.0
# 24     midi_npz/hooktheory/pianoroll/w/wavves/nine-is...               273.0
# 25     midi_npz/hooktheory/pianoroll/w/weebl/donkeys/...               129.0
# 26     midi_npz/hooktheory/pianoroll/w/walter-murphy/...               193.0
# 27     midi_npz/hooktheory/pianoroll/w/weezer/undone-...               257.0
# 28     midi_npz/hooktheory/pianoroll/w/wavves/pony/ve...               257.0
# 29     midi_npz/hooktheory/pianoroll/w/wavves/pony/ch...               145.0
# 30     midi_npz/hooktheory/pianoroll/w/walter-murphy/...               279.0
# 31     midi_npz/hooktheory/pianoroll/w/walter-murphy/...               279.0
# ...                                                  ...                 ...
# 39911  midi_npz/from_mxl/wikifonia/Hubert Giraud, Jae...              1421.0
# 39912  midi_npz/from_mxl/wikifonia/Thelonious Monk - ...               401.0
# 39913  midi_npz/from_mxl/wikifonia/Michael Praetorius...               273.0
# 39914  midi_npz/from_mxl/wikifonia/ Zac Maloy, Chris ...               861.0
# 39915  midi_npz/from_mxl/wikifonia/Richard Rodgers, O...               653.0
# 39917  midi_npz/from_mxl/wikifonia/George M. Cohan - ...               509.0
# 39918  midi_npz/from_mxl/wikifonia/Antoine Domino & D...               621.0
# 39919  midi_npz/from_mxl/wikifonia/Andrae Crouch - I ...               573.0
# 39920  midi_npz/from_mxl/wikifonia/Kurt Weill, Ira Ge...               633.0
# 39921  midi_npz/from_mxl/wikifonia/Jimmy McHugh, Doro...               529.0
# 39922  midi_npz/from_mxl/wikifonia/Harry Noble - Hold...               421.0
# 39923  midi_npz/from_mxl/wikifonia/Gordon Jenkins - T...               773.0
# 39924  midi_npz/from_mxl/wikifonia/Richard Sherman, R...               577.0
# 39925  midi_npz/from_mxl/wikifonia/Thom Bell and Lind...               769.0
# 39926  midi_npz/from_mxl/wikifonia/Unknow - KARNAVALS...              1207.0
# 39927  midi_npz/from_mxl/wikifonia/Antonio Carlos Job...              1101.0
# 39928  midi_npz/from_mxl/wikifonia/Carol Bayer Sager ...               625.0
# 39929  midi_npz/from_mxl/wikifonia/David Bartholomew,...              1097.0
# 39930  midi_npz/from_mxl/wikifonia/Walter Donaldson, ...              1065.0
# 39931  midi_npz/from_mxl/wikifonia/Charlie Parker, Di...               337.0
# 39932  midi_npz/from_mxl/wikifonia/Henri Betti - Cest...               609.0
# 39933  midi_npz/from_mxl/wikifonia/U2 - With or witho...              1025.0
# 39934  midi_npz/from_mxl/wikifonia/A.B. Quintanilla, ...              1377.0
# 39935  midi_npz/from_mxl/wikifonia/Milton Kellem - Go...               989.0
# 39936  midi_npz/from_mxl/wikifonia/Oliver Nelson - St...               337.0
# 39937  midi_npz/from_mxl/wikifonia/Mike Hawker & Udo ...               457.0
# 39938  midi_npz/from_mxl/wikifonia/Ernest Gold - Exod...               357.0
# 39939  midi_npz/from_mxl/wikifonia/Traditional - JA, ...              2061.0
# 39940  midi_npz/from_mxl/wikifonia/Andrae Crouch - Th...               469.0
# 39941  midi_npz/from_mxl/wikifonia/Ross MacLean, Arth...              1569.0
#
#                                    midi_encode/npenc/dur
# 1      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 2      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 3      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 4      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 5      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 6      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 7      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 8      midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 10     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 11     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 12     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 13     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 14     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 15     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 16     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 17     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 18     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 19     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 20     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 21     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 22     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 23     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 24     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 25     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 26     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 27     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 28     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 29     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 30     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# 31     midi_encode/npenc/dur/hooktheory/pianoroll/w/w...
# ...                                                  ...
# 39911  midi_encode/npenc/dur/from_mxl/wikifonia/Huber...
# 39912  midi_encode/npenc/dur/from_mxl/wikifonia/Thelo...
# 39913  midi_encode/npenc/dur/from_mxl/wikifonia/Micha...
# 39914  midi_encode/npenc/dur/from_mxl/wikifonia/ Zac ...
# 39915  midi_encode/npenc/dur/from_mxl/wikifonia/Richa...
# 39917  midi_encode/npenc/dur/from_mxl/wikifonia/Georg...
# 39918  midi_encode/npenc/dur/from_mxl/wikifonia/Antoi...
# 39919  midi_encode/npenc/dur/from_mxl/wikifonia/Andra...
# 39920  midi_encode/npenc/dur/from_mxl/wikifonia/Kurt ...
# 39921  midi_encode/npenc/dur/from_mxl/wikifonia/Jimmy...
# 39922  midi_encode/npenc/dur/from_mxl/wikifonia/Harry...
# 39923  midi_encode/npenc/dur/from_mxl/wikifonia/Gordo...
# 39924  midi_encode/npenc/dur/from_mxl/wikifonia/Richa...
# 39925  midi_encode/npenc/dur/from_mxl/wikifonia/Thom ...
# 39926  midi_encode/npenc/dur/from_mxl/wikifonia/Unkno...
# 39927  midi_encode/npenc/dur/from_mxl/wikifonia/Anton...
# 39928  midi_encode/npenc/dur/from_mxl/wikifonia/Carol...
# 39929  midi_encode/npenc/dur/from_mxl/wikifonia/David...
# 39930  midi_encode/npenc/dur/from_mxl/wikifonia/Walte...
# 39931  midi_encode/npenc/dur/from_mxl/wikifonia/Charl...
# 39932  midi_encode/npenc/dur/from_mxl/wikifonia/Henri...
# 39933  midi_encode/npenc/dur/from_mxl/wikifonia/U2 - ...
# 39934  midi_encode/npenc/dur/from_mxl/wikifonia/A.B. ...
# 39935  midi_encode/npenc/dur/from_mxl/wikifonia/Milto...
# 39936  midi_encode/npenc/dur/from_mxl/wikifonia/Olive...
# 39937  midi_encode/npenc/dur/from_mxl/wikifonia/Mike ...
# 39938  midi_encode/npenc/dur/from_mxl/wikifonia/Ernes...
# 39939  midi_encode/npenc/dur/from_mxl/wikifonia/Tradi...
# 39940  midi_encode/npenc/dur/from_mxl/wikifonia/Andra...
# 39941  midi_encode/npenc/dur/from_mxl/wikifonia/Ross ...
#
# [37035 rows x 26 columns]

# %%
all_files
# Out:
# []

# %%
all_files[:10]
# Out:
# []

# %% [markdown]
# ### Create All Dataset

# %%
all_files = get_files(csv)
all_data, all_vocab = create_databunch(all_files, cache_name='tmp/all', load_cached=True)

# %% [markdown]
# Note: we are reusing all_vocab for the following datasets

# %% [markdown]
# ### Create Hooktheory Dataset

# %%
hook_csv = csv.loc[csv.source.isin(['hooktheory', 'cprato'])]
hook_files = get_files(hook_csv)

# %%
hook_data, hook_vocab = create_databunch(hook_files, cache_name='tmp/hook', vocab=all_vocab)
# Out:
# Numericalizing

# %% [markdown]
# ### Create Pop Dataset

# %%
pop_csv = csv.loc[csv.source.isin(['midiworld', 'freemidi', 'wikifonia'])]
pop_files = get_files(pop_csv)

# %%
pop_data, pop_vocab = create_databunch(pop_files, cache_name='tmp/pop', vocab=all_vocab)
# Out:
# Numericalizing

# %% [markdown]
# ## Create Classical Dataset

# %%
# csv_filter = csv.loc[csv[f'{source_dir}_timesteps'] < 20000]
clc_csv = csv.loc[csv.source.isin(['classical_piano', 'ecomp'])]
clc_files = get_files(clc_csv)

# %%
clc_data, clc_vocab = create_databunch(clc_files, cache_name='tmp/clc', vocab=all_vocab)
# Out:
# Numericalizing

# %%
len(clc_files)
# Out:
# 2857

# %% [markdown]
# ### Testing

# %%
data = pop_data

# %%
data.show_batch()
# Out:
# <table>  <col width='5%'>  <col width='95%'>  <tr>
#     <th>idx</th>
#     <th>text</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>t2 || t1 nB o3 t4 nD o4 t4 nC o5 t4 || t3 nD o4 t4 || t3 nE- o4 t4 || t3 nD o4 t4 || t3 nE- o4 t2 || t1 nD o4 t2 || t1 nE- o4 t2 || t1 nD o4 t2 || t1 nB o3 t4 nD o4 t4 || t0 nC o5 t3 || t2 nD o4 t4 || t3 nE- o4 t4</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>t1 nC# o2 t2 nF# o2 t1 || t0 nF# o2 t1 || t0 nB o1 t4 nE o2 t4 nF# o2 t6 nE o3 t1 nG# o5 t1 || t1 nG# o2 t4 nE o3 t1 nE o5 t1 || t1 nB o1 t4 nE o3 t1 nB o4 t1 || t1 nE o2 t2 nF# o2 t1 nE o3 t1 nE o5 t1 || t0 nF# o2 t1</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>o3 t8 nA o3 t8 nE o4 t4 || t0 nG# o1 t1 nB- o4 t3 || t0 nG# o1 t2 nA o1 t4 nB o1 t1 nF# o2 t2 || t0 nE- o1 t3 nB o1 t4 || t0 nG# o1 t3 nC# o2 t2 nE o2 t8 nF# o2 t2 nC o4 t3 nE o4 t4 nA o4 t4 nB- o4 t3 || t1 nE- o1 t3 nA</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>|| t0 nF# o2 t2 nC o4 t1 || t0 nE- o4 t4 nG# o5 t5 || t0 nC o2 t4 nF# o2 t2 nE- o4 t1 nF o4 t1 nC o7 t1 || t0 nC o7 t7 || t0 nE o2 t8 nF# o2 t2 nB- o3 t1 nF# o4 t8 || t0 nA o3 t4 nB- o3 t1 nE- o4 t1 nF o4 t1 || t0 nC o2</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>o3 t2 nC o4 t2 || t1 nC o2 t2 nF# o2 t2 nC o3 t1 nB o4 t2 || t1 nC o2 t2 nD o2 t2 nF# o2 t2 nC o3 t1 nG o3 t2 nC o4 t2 || t1 nC o2 t2 nF# o2 t2 nC o3 t1 || t1 nB o1 t2 nD o2 t2 nF# o2 t2 nC o3 t1 nG o3 t2 nC o4 t2</th>
#   </tr>
# </table>

# %%
ob = data.one_batch()

# %%
txt_out = data.vocab.textify(ob[0][0]).replace('xxbos ', ''); txt_out
# Out:
# 't-2 || nB3 t-2 nD4 t-2 nC5 t-2 || nD4 t-1 || nD4 t-2 || nD4 t-2 || nD4 t-2 || nE-4 t-1 || nE-4 t-2 || nE-4 t-2 || nE-4 t-2 || nD4 t-1 || nD4 t-2 || nD4 t-2 || nD4 t-2 || nE-4 t-1 || nE-4 t-2 || nD4 t-1 || nD4 t-2 || nE-4 t-1 || nE-4 t-2 || nD4 t-1 || nD4 t-2 || nB3'

# %%
from encode_data import *

# %%
one_text = data.train_ds[0][0].text

# %%
seq = str2seq(one_text); seq
# Out:
# [[E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D5t-1],
#  [D5t-2],
#  [C5t-1],
#  [C5t-2],
#  [C5t-2],
#  [C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [G3t-1],
#  [G3t-2],
#  [C5t-1],
#  [C5t-2],
#  [B3t-1, D4t-1, C5t-1],
#  [B3t-2, D4t-2, C5t-2],
#  [B3t-2, D4t-2, C5t-2],
#  [B3t-2, D4t-2, C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [B3t-1, D4t-1],
#  [B3t-2, D4t-2, C5t-1],
#  [B3t-2, D4t-2, C5t-2],
#  [B3t-2, D4t-2, C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [C4t-1, E-4t-1],
#  [C4t-2, E-4t-2, C5t-1],
#  [C4t-2, E-4t-2, C5t-2],
#  [C4t-2, E-4t-2, C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D5t-1],
#  [D5t-2],
#  [B3t-1, C5t-1],
#  [B3t-2, C5t-2],
#  [B3t-2, C5t-2],
#  [B3t-2, C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [G3t-1, B3t-1, D4t-1, C5t-1],
#  [G3t-2, B3t-2, D4t-2, C5t-2],
#  [G3t-2, B3t-2, D4t-2, C5t-2],
#  [G3t-2, B3t-2, D4t-2, C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [A3t-1, E4t-1, C5t-1],
#  [A3t-2, E4t-2, C5t-2],
#  [A3t-2, E4t-2, C5t-2],
#  [A3t-2, E4t-2, C5t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [F4t-2],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [D5t-1],
#  [D5t-2],
#  [A3t-1, E4t-1, C5t-1],
#  [A3t-2, E4t-2, C5t-2],
#  [A3t-2, E4t-2, C5t-2],
#  [A3t-2, E4t-2, C5t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [F4t-2],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [C5t-1],
#  [C5t-2],
#  [B3t-1, D4t-1, B4t-1],
#  [B3t-2, D4t-2, B4t-2],
#  [B3t-2, D4t-2, B4t-2],
#  [B3t-2, D4t-2, B4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [C5t-1],
#  [C5t-2],
#  [B3t-1, D4t-1, B4t-1],
#  [B3t-2, D4t-2, B4t-2],
#  [B3t-2, D4t-2, B4t-2],
#  [B3t-2, D4t-2, B4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [F4t-1],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [B3t-1, D4t-1, C5t-1],
#  [B3t-2, D4t-2, C5t-2],
#  [B3t-2, D4t-2, C5t-2],
#  [B3t-2, D4t-2, C5t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [F4t-2],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [C5t-1],
#  [C5t-2],
#  [B3t-1, D4t-1, C5t-1],
#  [B3t-2, D4t-2, C5t-2],
#  [B3t-2, D4t-2, C5t-2],
#  [B3t-2, D4t-2, C5t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [F4t-2],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [C5t-1],
#  [C5t-2],
#  [B4t-1],
#  [B4t-2],
#  [B4t-2],
#  [B4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E4t-1],
#  [F4t-1],
#  [],
#  [E4t-1],
#  [],
#  [D4t-1],
#  [],
#  [C5t-1],
#  [A3t-1, E4t-1, A4t-1, C5t-1],
#  [A3t-2, E4t-2, A4t-2, C5t-2],
#  [A3t-2, E4t-2, A4t-2, C5t-2],
#  [A3t-2, E4t-2, A4t-2, C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [E4t-2],
#  [E4t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E4t-1],
#  [E4t-2],
#  [F4t-1],
#  [F4t-2],
#  [E4t-1],
#  [E4t-2],
#  [D4t-1],
#  [D4t-2],
#  [C4t-1, E-4t-1, G4t-1, C5t-1],
#  [C4t-2, E-4t-2, G4t-2, C5t-2],
#  [C4t-2, E-4t-2, G4t-2, C5t-2],
#  [C4t-2, E-4t-2, G4t-2, C5t-2],
#  [D4t-1],
#  [D4t-2],
#  [D4t-2],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [E-4t-2],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [G3t-1],
#  [G3t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D4t-1],
#  [D4t-2],
#  [E-4t-1],
#  [E-4t-2],
#  [D5t-1],
#  [D5t-2],
#  [E-4t-1, C5t-1],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  [E-4t-2, C5t-2],
#  []]

# %%
seq2numpy(seq).shape
# Out:
# (129, 1, 127)

# %%
s = str2stream(one_text)

# %%
s.show('midi')
# Out:
#                 <div id='midiPlayerDiv215'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv215');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
s.show('text')
# Out:
# {0.0} <music21.stream.Part 0x7f0626bf9b70>
#     {0.0} <music21.instrument.Piano Piano>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.tempo.MetronomeMark animato Quarter=120>
#     {0.0} <music21.key.KeySignature of no sharps or flats>
#     {0.25} <music21.chord.Chord G3>
#     {0.5} <music21.chord.Chord F#3>
#     {0.75} <music21.chord.Chord A2>
#     {1.0} <music21.chord.Chord F3>
#     {1.25} <music21.chord.Chord E3>
#     {1.5} <music21.chord.Chord A2>
#     {1.75} <music21.chord.Chord F3>
#     {2.0} <music21.chord.Chord E3>
#     {2.25} <music21.chord.Chord A2>
#     {3.0} <music21.chord.Chord G3>
#     {3.25} <music21.chord.Chord F#3>
#     {3.5} <music21.chord.Chord G3>
#     {3.75} <music21.chord.Chord C#4>
#     {4.0} <music21.chord.Chord E3 G3 B3>
#     {8.0} <music21.chord.Chord E3 G3 A3 C4>
#     {10.0} <music21.chord.Chord E3 G3 B3>
#     {12.0} <music21.chord.Chord G2 B-2 D3>
#     {18.0} <music21.chord.Chord G2 A2 C3 E3>
#     {19.0} <music21.chord.Chord A2 B2 D3 F#3>
#     {20.0} <music21.chord.Chord C3 E-3 G3>
#     {24.0} <music21.chord.Chord F3 G#3 C4 D4>
#     {26.0} <music21.chord.Chord C3 E-3 G3>
#     {28.0} <music21.chord.Chord E-3 F#3 B-3>
