# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from encode_data import *
from midi_data import *

# %%
from tqdm import tqdm
import pandas as pd
from data_sources import process_parallel

# %%
from collections import Counter

# %% [markdown]
# ## Encode music21 stream to text representation
#
# This notebook uses a full component format
# - measure separators, instruments, and separated octaves
# - Format: note, octave, action type, instrument
# - note repr: nG# o4 t1 i0

# %% [markdown]
# ### Load midi data

# %%
path = Path('data/midi')

# %%
source_dir = 'midi_numpy_v2'
out_dir = 'midi_transcribe_v2'
source_csv = path/source_dir/f'{source_dir}.csv'
out_csv = path/out_dir/f'{out_dir}.csv'

# %%
df = pd.read_csv(source_csv, index_col=0); df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-f5a6bc7de17e> in <module>
# ----> 1 df = pd.read_csv(source_csv, index_col=0); df.head()
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'data/midi/midi_numpy_v2/midi_numpy_v2.csv' does not exist

# %%
df_filtered = df.loc[df['time_signature'] == '4/4']; df_filtered.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9e44a1d383be> in <module>
# ----> 1 df_filtered = df.loc[df['time_signature'] == '4/4']; df_filtered.shape
#
# NameError: name 'df' is not defined

# %%
def transcribe_file(idxrow):
    idx,row = idxrow
    midi_file = row[source_dir]
    if not isinstance(midi_file, str) or not Path(midi_file).exists(): return idx,None
    out_file = Path(midi_file.replace(f'/{source_dir}/', f'/{out_dir}/')).with_suffix('.txt')
    out_file.parent.mkdir(parents=True, exist_ok=True)
    if out_file.exists(): return idx,str(out_file)
    try:
        chordarr = numpy.load(midi_file)
        seq = chordarr2seq(chordarr)
        string_repr = seq2str(seq, lambda x: x.short_bin())
        with open(out_file, 'w') as tf:
            tf.write(string_repr)
    except Exception as e:
        print('Error converting midi to sequence', e)
        return idx,None
    return idx,str(out_file)

# %%
# for r in df_filtered.iterrows():
#     transcribe_file(r)

# %%
transcribed_files = process_parallel(transcribe_file, df_filtered.iterrows(), total=df_filtered.shape[0])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='30201', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Removed 130 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/j/jacob-mann/kogi/intro_key.mid
# Removed 101 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/j/john-williams/the-raiders-march---indiana-jones-theme/intro-and-verse_key.mid
# Compressing rests: 32 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 52 -> 16
# Removed 129 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/b/boyinaband/lets-summon-the-devil/instrumental_key.mid
# Removed 136 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/b/bruno-mars/uptown-funk/intro-and-verse_key.mid
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Removed 151 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/d/dawid-podsiadlo/trojkaty-i-kwadraty/verse_key.mid
# Removed 129 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/x/xxanaxx/story/intro-and-verse_key.mid
# Compressing rests: 28 -> 16
# Removed 103 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/s/savant/sledgehammer/chorus-lead-out_key.mid
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 30 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Removed 108 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/n/nigel-tufnel/nigels-top-of-the-heap-1959-gibson-les-paul/instrumental_key.mid
# Compressing rests: 28 -> 16
# Removed 127 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/n/naoto-ishida/big-blue---f-zero/intro_key.mid
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 32 -> 16
# Compressing rests: 32 -> 16
# Compressing rests: 36 -> 16
# Compressing rests: 22 -> 18
# Removed 641 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/t/the-wailers/roots-rock-reggae/intro-and-verse_key.mid
# Compressing rests: 32 -> 16
# Removed 137 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/t/the-wrecks/favorite-liar/bridge_key.mid
# Compressing rests: 34 -> 18
# Removed 101 rests from data/midi/midi_transform_v2/hooktheory/pianoroll/m/mstrkrft/easy-love/intro_key.mid
# Compressing rests: 28 -> 16
# Compressing rests: 32 -> 16
# Compressing rests: 26 -> 18
# Compressing rests: 24 -> 16
# Removed 141 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Spitfire.mid
# Compressing rests: 64 -> 16
# Compressing rests: 64 -> 16
# Compressing rests: 128 -> 16
# Removed 574 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Ariana Grande - Problem.mid
# Compressing rests: 26 -> 18
# Compressing rests: 24 -> 16
# Removed 144 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Soft Cell - Tainted Love.mid
# Removed 118 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Come To Me.mid
# Removed 207 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Atomic Kitten - Love Doesnt Have To Hurt.mid
# Removed 133 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gary Numan - Down In The Park.mid
# Compressing rests: 32 -> 16
# Removed 318 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Frozen.mid
# Removed 105 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Enigma - Remorse.mid
# Removed 193 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Ting Tings - Shut Up And Let Me Go.mid
# Compressing rests: 39 -> 19
# Removed 750 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Faithless - Insomnia.mid
# Compressing rests: 28 -> 16
# Removed 247 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Beauty Queen Horses.mid
# Removed 136 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yellow Magic Orchestra - Computer Games.mid
# Removed 197 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Breathe Carolina - I Have To Return Some Video Tapes.mid
# Removed 152 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - South Of The Border.mid
# Compressing rests: 52 -> 16
# Compressing rests: 58 -> 18
# Compressing rests: 64 -> 16
# Removed 375 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Fatboy Slim - Praise You.mid
# Compressing rests: 48 -> 16
# Removed 123 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Buenos Aires.mid
# Removed 344 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Little Mix - Black Magic.mid
# Removed 185 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - Lovelight.mid
# Removed 102 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Garbage - Stupid Girl.mid
# Removed 201 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Ciara - Goodies.mid
# Removed 496 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Fever.mid
# Removed 355 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - Clean.mid
# Compressing rests: 318 -> 18
# Compressing rests: 66 -> 18
# Compressing rests: 192 -> 16
# Removed 791 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Beautiful Stranger.mid
# Compressing rests: 128 -> 16
# Removed 406 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Revival.mid
# Removed 190 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Five - Everybody.mid
# Removed 127 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - One Of Gods Better People.mid
# Removed 185 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Whitney Houston - I'm Every Woman.mid
# Removed 321 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gala - Free From Desire.mid
# Compressing rests: 36 -> 16
# Removed 136 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/S Club 7 - Never Felt This Way.mid
# Removed 268 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/C And C Music Factory - Everybody Dance Now.mid
# Removed 415 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Breathe Carolina - Wooly.mid
# Removed 121 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/ATB - Dont stop.mid
# Removed 107 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/ATB - Till I Come.mid
# Removed 409 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cher - Believe.mid
# Removed 580 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yaz - Situation.mid
# Compressing rests: 25 -> 17
# Removed 344 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Little Mix - Little Mix.mid
# Removed 181 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Atlantic.mid
# Compressing rests: 134 -> 18
# Compressing rests: 60 -> 16
# Removed 410 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - American Pie.mid
# Compressing rests: 64 -> 16
# Compressing rests: 126 -> 18
# Removed 167 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Control Freak.mid
# Compressing rests: 89 -> 17
# Removed 415 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Pitbull - I Know You Want Me.mid
# Removed 110 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gabrielle - When A Woman.mid
# Compressing rests: 129 -> 17
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Removed 225 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Digital Love (2).mid
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Removed 138 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Kylie Minogue - Did It Again.mid
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Removed 326 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Edge To Life.mid
# Removed 150 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Walking On Broken Glasses.mid
# Removed 116 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - Killing Me.mid
# Compressing rests: 32 -> 16
# Compressing rests: 66 -> 18
# Removed 287 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Happiest Girl.mid
# Compressing rests: 63 -> 19
# Compressing rests: 47 -> 19
# Compressing rests: 55 -> 19
# Removed 116 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Dont Tell Me.mid
# Removed 107 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/ATB - 9 PM.mid
# Removed 104 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gloria Estefan - Everlasting Love.mid
# Removed 164 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Love Song For A Vampire.mid
# Compressing rests: 26 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 286 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 30 -> 18
# Removed 1215 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Vanishing Point.mid
# Compressing rests: 323 -> 19
# Compressing rests: 307 -> 19
# Compressing rests: 333 -> 17
# Compressing rests: 319 -> 19
# Compressing rests: 305 -> 17
# Compressing rests: 28 -> 16
# Compressing rests: 329 -> 17
# Compressing rests: 326 -> 18
# Compressing rests: 169 -> 17
# Compressing rests: 142 -> 18
# Compressing rests: 185 -> 17
# Compressing rests: 128 -> 16
# Compressing rests: 21 -> 17
# Compressing rests: 184 -> 16
# Compressing rests: 158 -> 18
# Compressing rests: 129 -> 17
# Compressing rests: 198 -> 18
# Compressing rests: 137 -> 17
# Compressing rests: 197 -> 17
# Compressing rests: 118 -> 18
# Compressing rests: 182 -> 18
# Compressing rests: 124 -> 16
# Compressing rests: 175 -> 19
# Compressing rests: 35 -> 19
# Compressing rests: 275 -> 19
# Compressing rests: 37 -> 17
# Compressing rests: 298 -> 18
# Compressing rests: 35 -> 19
# Compressing rests: 300 -> 16
# Compressing rests: 33 -> 17
# Compressing rests: 302 -> 18
# Compressing rests: 33 -> 17
# Compressing rests: 302 -> 18
# Compressing rests: 25 -> 17
# Compressing rests: 310 -> 18
# Compressing rests: 332 -> 16
# Compressing rests: 317 -> 17
# Compressing rests: 318 -> 18
# Compressing rests: 320 -> 16
# Compressing rests: 29 -> 17
# Compressing rests: 306 -> 18
# Compressing rests: 27 -> 19
# Compressing rests: 308 -> 16
# Compressing rests: 25 -> 17
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 24 -> 16
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 24 -> 16
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 352 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 336 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 344 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 366 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 334 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 445 -> 17
# Removed 1789 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/No Mercy - Please Dont Go.mid
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 336 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 336 -> 16
# Compressing rests: 358 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 334 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 359 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Removed 137 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alanis Morissette - That I Would Be Good.mid
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 336 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 336 -> 16
# Compressing rests: 342 -> 18
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 368 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 334 -> 18
# Compressing rests: 368 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 336 -> 16
# Compressing rests: 350 -> 18
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 360 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 335 -> 19
# Compressing rests: 344 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 334 -> 18
# Compressing rests: 352 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 350 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 359 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 343 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 344 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 336 -> 16
# Compressing rests: 334 -> 18
# Compressing rests: 368 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 366 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 334 -> 18
# Compressing rests: 336 -> 16
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 367 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 351 -> 19
# Compressing rests: 335 -> 19
# Compressing rests: 335 -> 19
# Removed 84691 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cascada - What Hurts The Most.mid
# Removed 121 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Garbage - #1 Crush.mid
# Compressing rests: 128 -> 16
# Removed 113 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Subculture.mid
# Removed 133 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/S Club 7 - Walkin On Sunshine.mid
# Removed 272 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yellow Magic Orchestra - Ongaku.mid
# Compressing rests: 62 -> 18
# Removed 301 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Real McCoy - Run Away.mid
# Removed 217 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Poison.mid
# Removed 225 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Avicii - Sunshine.mid
# Compressing rests: 32 -> 16
# Compressing rests: 112 -> 16
# Compressing rests: 32 -> 16
# Compressing rests: 64 -> 16
# Compressing rests: 32 -> 16
# Removed 534 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Blue Monday.mid
# Compressing rests: 28 -> 16
# Removed 182 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/U96 - Das Boot.mid
# Removed 159 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - I'll Be Surprisingly Good For You.mid
# Compressing rests: 52 -> 16
# Compressing rests: 52 -> 16
# Removed 333 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Apollo 440 - Stop The Rock.mid
# Compressing rests: 128 -> 16
# Removed 594 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Harder Better Faster Stronger.mid
# Removed 132 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Ultra Nate - If You Could Read My Mind.mid
# Removed 272 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Whos That Girl.mid
# Removed 429 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yaz - Don't Go 99.mid
# Removed 179 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Pitbull - We Are One (Ole Ola).mid
# Compressing rests: 248 -> 16
# Removed 595 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Fatboy Slim - Going Out Of My Head.mid
# Removed 498 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eiffel 65 - Console.mid
# Compressing rests: 48 -> 16
# Compressing rests: 48 -> 16
# Compressing rests: 40 -> 16
# Compressing rests: 32 -> 16
# Compressing rests: 40 -> 16
# Removed 200 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Justify My Love.mid
# Removed 538 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Boys Say Go.mid
# Removed 353 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Television Rules The Nation.mid
# Removed 566 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Everything Counts.mid
# Removed 101 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Aqua - My Oh My.mid
# Removed 599 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Robot Rock.mid
# Compressing rests: 128 -> 16
# Removed 178 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Christmas Island.mid
# Removed 101 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/David Guetta - Love Don't Let Me Go.mid
# Compressing rests: 56 -> 16
# Removed 229 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Causing A Commotion.mid
# Compressing rests: 64 -> 16
# Compressing rests: 64 -> 16
# Compressing rests: 384 -> 16
# Removed 421 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Smack My Bitch Up (2).mid
# Removed 432 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tatu - How Soon Is Now.mid
# Removed 329 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Toni Basil - Mickey.mid
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Craig David - 7 Days.mid
# Compressing rests: 124 -> 16
# Removed 602 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Pitbull - Give Me Everything.mid
# Removed 139 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Modern Talking - Heaven Will Know.mid
# Compressing rests: 39 -> 19
# Compressing rests: 39 -> 19
# Removed 146 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/DJ Bobo - Let The Dream Come True.mid
# Removed 121 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Five - Closer To Me.mid
# Compressing rests: 81 -> 17
# Removed 358 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Tribal Dance.mid
# Removed 289 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Dont Let It Bring You Down.mid
# Compressing rests: 48 -> 16
# Compressing rests: 124 -> 16
# Removed 247 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Maximum Overdrive.mid
# Removed 379 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Do Whats Good For Me.mid
# Compressing rests: 30 -> 18
# Compressing rests: 29 -> 17
# Compressing rests: 128 -> 16
# Compressing rests: 64 -> 16
# Removed 161 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Four Tops - Walk Away Renee.mid
# Compressing rests: 34 -> 18
# Compressing rests: 112 -> 16
# Removed 109 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Faces.mid
# Removed 117 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Enrique Iglesias - Tonight im lovin you.mid
# Removed 101 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Army of Lovers - Obsession.mid
# Compressing rests: 321 -> 17
# Compressing rests: 137 -> 17
# Removed 606 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Wind It Up.mid
# Compressing rests: 44 -> 16
# Compressing rests: 28 -> 16
# Removed 332 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Girls.mid
# Removed 138 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Chemical Brothers - Loops Of Furry.mid
# Removed 116 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Scooter - I Am Raving.mid
# Compressing rests: 256 -> 16
# Removed 373 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Aerodynamic (2).mid
# Compressing rests: 80 -> 16
# Removed 133 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/S Club 7 - S Club Party.mid
# Removed 167 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Four Tops - Same Old Song (2).mid
# Compressing rests: 33 -> 17
# Removed 181 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Faithless - God Is A DJ.mid
# Removed 262 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Modern Talking - Do You Wanna.mid
# Compressing rests: 48 -> 16
# Compressing rests: 129 -> 17
# Compressing rests: 192 -> 16
# Removed 401 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Bizarre Love Triangle.mid
# Compressing rests: 64 -> 16
# Removed 108 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - A Question Of Lust.mid
# Compressing rests: 124 -> 16
# Compressing rests: 412 -> 16
# Removed 536 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Breathe.mid
# Removed 498 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eiffel 65 - My Console.mid
# Removed 152 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daniel Bedingfield - If You Are Not The One.mid
# Compressing rests: 644 -> 16
# Compressing rests: 260 -> 16
# Removed 1257 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Behind The Wheel.mid
# Removed 148 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Enrique Iglesias - I like it feat. Pitbull.mid
# Removed 250 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Playboy Mommy.mid
# Removed 303 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yaz - Don't Go.mid
# Compressing rests: 42 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 42 -> 18
# Compressing rests: 30 -> 18
# Compressing rests: 28 -> 16
# Removed 193 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/No Mercy - When I Die.mid
# Removed 223 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Aqua - Lollipop.mid
# Compressing rests: 64 -> 16
# Removed 305 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Real McCoy - Another Night.mid
# Compressing rests: 102 -> 18
# Compressing rests: 65 -> 17
# Removed 173 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/David Guetta - Love Is Gone.mid
# Compressing rests: 32 -> 16
# Removed 118 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Four Tops - Bernadette.mid
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Removed 117 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Big Time Sinsuality.mid
# Removed 196 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - 1963.mid
# Removed 867 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Any Second Now.mid
# Removed 137 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/David Guetta - Without You.mid
# Removed 178 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cher - Half Breed.mid
# Removed 113 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alanis Morissette - You Oughta Know.mid
# Removed 102 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Enrique Iglesias - Bailamos.mid
# Compressing rests: 1024 -> 16
# Compressing rests: 912 -> 16
# Removed 2153 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Antiloop - This Is The Night.mid
# Compressing rests: 244 -> 16
# Removed 1284 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Around The World (2).mid
# Compressing rests: 24 -> 16
# Compressing rests: 268 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 284 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 24 -> 16
# Removed 1104 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/DJ Bobo - Shadows Of The Night.mid
# Compressing rests: 61 -> 17
# Compressing rests: 64 -> 16
# Removed 148 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - You Love.mid
# Removed 438 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alex Party - Don't Give Me Your Life.mid
# Removed 245 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - No Limits.mid
# Compressing rests: 32 -> 16
# Removed 319 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Love Vigilantes.mid
# Removed 118 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Come To Me Remix.mid
# Compressing rests: 58 -> 18
# Removed 105 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gloria Estefan - 1-2-3.mid
# Compressing rests: 280 -> 16
# Compressing rests: 154 -> 18
# Removed 809 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Clean Bandit - Rather Be.mid
# Compressing rests: 125 -> 17
# Removed 121 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Garbage - The World Is Not Enough.mid
# Compressing rests: 39 -> 19
# Removed 272 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Another Suitecase In Another Hall.mid
# Removed 258 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Express Yourself.mid
# Removed 114 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Flexible.mid
# Compressing rests: 58 -> 18
# Removed 144 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Anastacia - Love Is Alive.mid
# Removed 274 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Muhammed My Friend.mid
# Compressing rests: 81 -> 17
# Removed 358 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Workaholic.mid
# Compressing rests: 176 -> 16
# Compressing rests: 24 -> 16
# Removed 195 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - A Photograph Of You.mid
# Compressing rests: 44 -> 16
# Removed 122 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Kylie Minogue - Chocolate.mid
# Removed 113 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Enigma - Mea Culpa.mid
# Removed 227 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Girl Gone Wild.mid
# Removed 341 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Modern Talking - Run To You.mid
# Compressing rests: 48 -> 16
# Compressing rests: 66 -> 18
# Removed 119 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Breathe Carolina - Put Some Clothes On.mid
# Compressing rests: 248 -> 16
# Compressing rests: 252 -> 16
# Compressing rests: 21 -> 17
# Removed 794 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Fatboy Slim - Rockafella Skank.mid
# Compressing rests: 29 -> 17
# Compressing rests: 29 -> 17
# Compressing rests: 35 -> 19
# Compressing rests: 258 -> 18
# Compressing rests: 31 -> 19
# Compressing rests: 39 -> 19
# Compressing rests: 34 -> 18
# Compressing rests: 264 -> 16
# Removed 1244 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Real Thing.mid
# Removed 136 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Amii Stewart - Knock On Wood.mid
# Removed 154 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Kylie Minogue - Spinning Around.mid
# Removed 217 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Possibly Maybe.mid
# Removed 248 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Twilight Zone.mid
# Removed 431 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - A Question Of Time.mid
# Removed 365 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cher - If I Could Turn Back Time.mid
# Removed 181 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Edward Maya - Stereo Love.mid
# Removed 113 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alanis Morissette - One.mid
# Compressing rests: 142 -> 18
# Compressing rests: 24 -> 16
# Compressing rests: 25 -> 17
# Compressing rests: 30 -> 18
# Compressing rests: 88 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 25 -> 17
# Removed 414 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Aqua - Calling You.mid
# Removed 129 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - The Miracle Of Love.mid
# Removed 285 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Sweet Dreams.mid
# Removed 317 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gary Numan - Cars.mid
# Removed 142 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alanis Morissette - Uninvited.mid
# Compressing rests: 128 -> 16
# Removed 669 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alice Deejay - Better Off Alone.mid
# Removed 160 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/DJ Bobo - What A Feeling.mid
# Removed 532 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Anastacia - Love Is A Crime.mid
# Compressing rests: 96 -> 16
# Compressing rests: 96 -> 16
# Removed 277 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Bachelorette.mid
# Compressing rests: 240 -> 16
# Compressing rests: 256 -> 16
# Removed 579 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Antiloop - In My Mind.mid
# Removed 133 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alanis Morissette - Joining You.mid
# Removed 339 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - Old Before I Die.mid
# Compressing rests: 640 -> 16
# Removed 1190 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Perfect Kiss.mid
# Removed 402 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Adamski - Killer.mid
# Removed 114 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Keep It Together.mid
# Removed 105 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eiffel 65 - Too Much Of Heaven.mid
# Compressing rests: 80 -> 16
# Removed 471 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - But Not Tonight.mid
# Removed 312 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Underworld - Moaner Beach Remix.mid
# Removed 467 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - And Then.mid
# Compressing rests: 65 -> 17
# Compressing rests: 65 -> 17
# Compressing rests: 65 -> 17
# Removed 417 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Real McCoy - Its On You.mid
# Compressing rests: 32 -> 16
# Compressing rests: 128 -> 16
# Removed 137 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Deeper Andy Deeper.mid
# Removed 480 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Darude - Sandstorm.mid
# Removed 239 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Enjoy.mid
# Removed 241 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Doughnut Song.mid
# Removed 591 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Vengaboys - Kiss.mid
# Removed 284 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - I Saved The World Today.mid
# Removed 465 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Here Is The House.mid
# Removed 230 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - In The Springtime Of His Voodoo.mid
# Removed 123 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Donna Summer - Last Dance.mid
# Compressing rests: 48 -> 16
# Removed 305 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Home.mid
# Compressing rests: 28 -> 16
# Compressing rests: 113 -> 17
# Removed 207 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Whitney Houston - I'm Your Baby Tonight.mid
# Compressing rests: 256 -> 16
# Removed 481 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - One Love.mid
# Compressing rests: 64 -> 16
# Removed 366 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/2 Unlimited - Megamix.mid
# Removed 149 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Air - Surfing On A Rocket.mid
# Removed 117 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Scooter - Break It Up.mid
# Compressing rests: 26 -> 18
# Removed 131 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Radiohead - Climbing Up the Walls.mid
# Removed 1337 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Human League - Don't You Want Me.mid
# Compressing rests: 28 -> 16
# Compressing rests: 32 -> 16
# Removed 146 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alanis Morissette - Cant Not.mid
# Removed 165 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cher - Dark Lady.mid
# Compressing rests: 129 -> 17
# Removed 342 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daft Punk - Da Funk.mid
# Removed 264 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Liquid Diamonds.mid
# Compressing rests: 131 -> 19
# Compressing rests: 64 -> 16
# Removed 631 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Faith Healer.mid
# Compressing rests: 22 -> 18
# Removed 104 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Vengaboys - Ibiza.mid
# Removed 152 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Further Excerpts From My Secret Garden.mid
# Removed 141 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/DJ Bobo - Freedom.mid
# Compressing rests: 62 -> 18
# Compressing rests: 62 -> 18
# Removed 105 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Company B - Fascinated.mid
# Removed 282 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/David Guetta - Sexy Bitch.mid
# Compressing rests: 112 -> 16
# Compressing rests: 52 -> 16
# Compressing rests: 52 -> 16
# Removed 236 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Temptation.mid
# Removed 407 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eurythmics - Thorn In My Side.mid
# Compressing rests: 118 -> 18
# Removed 601 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Scooter - Back In The UK.mid
# Compressing rests: 54 -> 18
# Compressing rests: 27 -> 19
# Compressing rests: 256 -> 16
# Compressing rests: 256 -> 16
# Removed 618 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Vanishing Point (2).mid
# Removed 134 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Aqua - Good Morning Sunshine.mid
# Compressing rests: 23 -> 19
# Removed 235 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Dear Jessie.mid
# Compressing rests: 108 -> 16
# Compressing rests: 112 -> 16
# Removed 302 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tatu - Nas Ne Dogonyat.mid
# Removed 387 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/No Mercy - Where Do You Go.mid
# Removed 293 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Ciara - 1 2 Step.mid
# Removed 136 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Modern Talking - Dont Take Away My Heart.mid
# Removed 129 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Alan Walker - All Falls Down.mid
# Removed 168 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Father Lucifer.mid
# Compressing rests: 22 -> 18
# Compressing rests: 128 -> 16
# Compressing rests: 22 -> 18
# Compressing rests: 40 -> 16
# Compressing rests: 48 -> 16
# Compressing rests: 32 -> 16
# Removed 1024 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Moby - Porcelain.mid
# Removed 289 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Eiffel 65 - Blue.mid
# Compressing rests: 64 -> 16
# Compressing rests: 64 -> 16
# Compressing rests: 128 -> 16
# Compressing rests: 32 -> 16
# Removed 521 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Ariana Grande - Ariana Grande feat. Iggy Azalea - Problem.mid
# Removed 116 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Aqua - Barbie Girl.mid
# Compressing rests: 32 -> 16
# Removed 478 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/LMFAO - Party Rock Anthem.mid
# Compressing rests: 22 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 28 -> 16
# Compressing rests: 24 -> 16
# Removed 155 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Like A Prayer (2).mid
# Compressing rests: 30 -> 18
# Compressing rests: 72 -> 16
# Removed 582 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Fly On The Windscreen.mid
# Removed 328 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tori Amos - Iieee.mid
# Removed 248 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Prodigy - Cowboy From Hell.mid
# Removed 169 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Hyper Ballad.mid
# Removed 273 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Get The Balance Right.mid
# Compressing rests: 136 -> 16
# Compressing rests: 76 -> 16
# Removed 404 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Kylie Minogue - Fever - Megamix.mid
# Compressing rests: 64 -> 16
# Removed 117 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/DJ Bobo - Take Control.mid
# Removed 176 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Vengaboys - Forever As One.mid
# Removed 214 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Cher - We All Sleep Alone.mid
# Removed 129 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Calvin Harris - Feel So Close.mid
# Removed 246 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - Ego A Go Go.mid
# Removed 128 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Get Right With Me.mid
# Compressing rests: 30 -> 18
# Compressing rests: 28 -> 16
# Compressing rests: 28 -> 16
# Removed 127 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Robbie Williams - Advertising Space.mid
# Removed 380 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Daniel Bedingfield - James Dean.mid
# Removed 158 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Yellow Magic Orchestra - 1000 Knives.mid
# Compressing rests: 35 -> 19
# Removed 211 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Madonna - Don't Cry For Me Argentina.mid
# Compressing rests: 128 -> 16
# Compressing rests: 24 -> 16
# Removed 593 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Whitney Houston - Free Your Mind.mid
# Removed 254 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gwen Stefani - Rich Girl.mid
# Compressing rests: 126 -> 18
# Compressing rests: 126 -> 18
# Removed 358 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Bjork - Crying.mid
# Compressing rests: 46 -> 18
# Removed 346 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Five - Dont Wanna Let You Go.mid
# Removed 322 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Gloria Estefan - Bad Boy.mid
# Removed 127 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/S Club 7 - You Are Everything.mid
# Removed 188 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Condemnation.mid
# Compressing rests: 50 -> 18
# Compressing rests: 254 -> 18
# Compressing rests: 124 -> 16
# Compressing rests: 200 -> 16
# Removed 935 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/New Order - Bizarre Love Triangle (Dance Mix).mid
# Compressing rests: 26 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 22 -> 18
# Removed 337 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Human League - Electric Dreams.mid
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 130 -> 18
# Removed 296 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Depeche Mode - Halo.mid
# Compressing rests: 130 -> 18
# Compressing rests: 1600 -> 16
# Removed 2282 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/808 State - Lift.mid
# Compressing rests: 128 -> 16
# Compressing rests: 129 -> 17
# Removed 512 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Fatboy Slim - Right Here Right Now.mid
# Removed 285 rests from data/midi/midi_transform_v2/freemidi/genre-dance-eletric/Tatu - Malchik gey.mid
# Compressing rests: 241 -> 17
# Compressing rests: 241 -> 17
# Compressing rests: 64 -> 16
# Compressing rests: 51 -> 19
# ...
# Compressing rests: 28 -> 16
# Compressing rests: 22 -> 18
# Removed 113 rests from data/midi/midi_transform_v2/ecomp/2011/Colafelice06.MID
# Removed 337 rests from data/midi/midi_transform_v2/ecomp/2018/KimSY15.MID
# Compressing rests: 24 -> 16
# Removed 141 rests from data/midi/midi_transform_v2/ecomp/2018/AndreevI01.MID
# Compressing rests: 23 -> 19
# Removed 596 rests from data/midi/midi_transform_v2/ecomp/2018/ChowK04.MID
# Removed 252 rests from data/midi/midi_transform_v2/ecomp/2018/ChowK11.MID
# Removed 105 rests from data/midi/midi_transform_v2/ecomp/2002/guttman05.mid
# Compressing rests: 31 -> 19
# Removed 174 rests from data/midi/midi_transform_v2/ecomp/2018/AbdelmoulaJS07.MID
# Removed 350 rests from data/midi/midi_transform_v2/ecomp/2018/AndreevI10.MID
# Removed 203 rests from data/midi/midi_transform_v2/ecomp/2018/TanakaM08.MID
# Removed 266 rests from data/midi/midi_transform_v2/ecomp/2018/MaslovV04.MID
# Removed 131 rests from data/midi/midi_transform_v2/ecomp/2009/Gryaznov03.MID
# Compressing rests: 29 -> 17
# Compressing rests: 29 -> 17
# Removed 111 rests from data/midi/midi_transform_v2/ecomp/2018/KanM10.MID
# Removed 179 rests from data/midi/midi_transform_v2/ecomp/2002/lin05.mid
# Compressing rests: 32 -> 16
# Compressing rests: 21 -> 17
# Compressing rests: 52 -> 16
# Compressing rests: 21 -> 17
# Compressing rests: 38 -> 18
# Compressing rests: 28 -> 16
# Compressing rests: 47 -> 19
# Compressing rests: 22 -> 18
# Compressing rests: 34 -> 18
# Compressing rests: 67 -> 19
# Compressing rests: 31 -> 19
# Removed 3442 rests from data/midi/midi_transform_v2/ecomp/2015/ZhaoK05.MID
# Compressing rests: 50 -> 18
# Compressing rests: 241 -> 17
# Compressing rests: 24 -> 16
# Compressing rests: 23 -> 19
# Compressing rests: 32 -> 16
# Compressing rests: 34 -> 18
# Compressing rests: 51 -> 19
# Compressing rests: 43 -> 19
# Compressing rests: 25 -> 17
# Compressing rests: 24 -> 16
# Compressing rests: 30 -> 18
# Compressing rests: 25 -> 17
# Compressing rests: 45 -> 17
# Compressing rests: 32 -> 16
# Compressing rests: 25 -> 17
# Compressing rests: 37 -> 17
# Compressing rests: 40 -> 16
# Compressing rests: 163 -> 19
# Compressing rests: 26 -> 18
# Removed 4064 rests from data/midi/midi_transform_v2/ecomp/2015/MunA11.MID
# Compressing rests: 32 -> 16
# Compressing rests: 38 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 26 -> 18
# Compressing rests: 24 -> 16
# Compressing rests: 21 -> 17
# Compressing rests: 37 -> 17
# Compressing rests: 25 -> 17
# Compressing rests: 23 -> 19
# Compressing rests: 27 -> 19
# Removed 3188 rests from data/midi/midi_transform_v2/ecomp/2015/YoungS08.MID
# Compressing rests: 22 -> 18
# Compressing rests: 27 -> 19
# Compressing rests: 22 -> 18
# Compressing rests: 32 -> 16
# Compressing rests: 29 -> 17
# Compressing rests: 78 -> 18
# Compressing rests: 70 -> 18
# Compressing rests: 32 -> 16
# Compressing rests: 35 -> 19
# Compressing rests: 30 -> 18
# Compressing rests: 25 -> 17
# Compressing rests: 24 -> 16
# Compressing rests: 23 -> 19
# Compressing rests: 35 -> 19
# Compressing rests: 21 -> 17
# Compressing rests: 38 -> 18
# Compressing rests: 50 -> 18
# Compressing rests: 35 -> 19
# Compressing rests: 41 -> 17
# Compressing rests: 23 -> 19
# Compressing rests: 33 -> 17
# Removed 3761 rests from data/midi/midi_transform_v2/ecomp/2015/ZhaoK11.MID
# Removed 109 rests from data/midi/midi_transform_v2/ecomp/2009/Zuber04.MID
# Removed 265 rests from data/midi/midi_transform_v2/ecomp/2014/DupreeF04.MID
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Removed 181 rests from data/midi/midi_transform_v2/ecomp/2006/Tysman01.mid
# Removed 112 rests from data/midi/midi_transform_v2/ecomp/2006/Shybayeva03.mid
# Compressing rests: 26 -> 18
# Compressing rests: 73 -> 17
# Compressing rests: 71 -> 19
# Compressing rests: 28 -> 16
# Compressing rests: 26 -> 18
# Compressing rests: 31 -> 19
# Compressing rests: 21 -> 17
# Removed 4254 rests from data/midi/midi_transform_v2/ecomp/2015/WuuE12.MID
# Compressing rests: 35 -> 19
# Compressing rests: 29 -> 17
# Removed 176 rests from data/midi/midi_transform_v2/ecomp/2009/Zhdanov05.MID
# Compressing rests: 26 -> 18
# Compressing rests: 21 -> 17
# Compressing rests: 23 -> 19
# Compressing rests: 79 -> 19
# Compressing rests: 61 -> 17
# Compressing rests: 25 -> 17
# Compressing rests: 23 -> 19
# Removed 3866 rests from data/midi/midi_transform_v2/ecomp/2015/HuNY09.MID
# Compressing rests: 27 -> 19
# Compressing rests: 27 -> 19
# Compressing rests: 25 -> 17
# Compressing rests: 22 -> 18
# Compressing rests: 22 -> 18
# Compressing rests: 25 -> 17
# Compressing rests: 32 -> 16
# Compressing rests: 32 -> 16
# Compressing rests: 26 -> 18
# Compressing rests: 21 -> 17
# Compressing rests: 29 -> 17
# Compressing rests: 139 -> 19
# Compressing rests: 23 -> 19
# Compressing rests: 23 -> 19
# Removed 3493 rests from data/midi/midi_transform_v2/ecomp/2015/RichardsonC04.MID
# Compressing rests: 638 -> 18
# Removed 644 rests from data/midi/midi_transform_v2/ecomp/2009/Yeletskiy06.MID
# Compressing rests: 24 -> 16
# Compressing rests: 64 -> 16
# Compressing rests: 28 -> 16
# Compressing rests: 31 -> 19
# Compressing rests: 23 -> 19
# Compressing rests: 25 -> 17
# Compressing rests: 46 -> 18
# Compressing rests: 32 -> 16
# Compressing rests: 22 -> 18
# Compressing rests: 31 -> 19
# Compressing rests: 110 -> 18
# Compressing rests: 29 -> 17
# Compressing rests: 40 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 54 -> 18
# Compressing rests: 24 -> 16
# Compressing rests: 32 -> 16
# Compressing rests: 24 -> 16
# Removed 3396 rests from data/midi/midi_transform_v2/ecomp/2015/JeonH08.MID
# Removed 257 rests from data/midi/midi_transform_v2/ecomp/2018/HouY05.MID
# Removed 131 rests from data/midi/midi_transform_v2/ecomp/2014/HuangSW07.MID
# Removed 127 rests from data/midi/midi_transform_v2/ecomp/2009/Taverna04.MID
# Compressing rests: 21 -> 17
# Compressing rests: 46 -> 18
# Removed 241 rests from data/midi/midi_transform_v2/ecomp/2002/mamriev03.mid
# Compressing rests: 28 -> 16
# Removed 101 rests from data/midi/midi_transform_v2/ecomp/2014/JohannsonP20.MID
# Removed 239 rests from data/midi/midi_transform_v2/ecomp/2002/vital01.mid
# Removed 195 rests from data/midi/midi_transform_v2/ecomp/2006/WongDoe05.MID
# Compressing rests: 36 -> 16
# Compressing rests: 32 -> 16
# Compressing rests: 32 -> 16
# Removed 152 rests from data/midi/midi_transform_v2/ecomp/2014/JohannsonP16.MID
# Removed 105 rests from data/midi/midi_transform_v2/ecomp/2002/savitski01.mid
# Removed 198 rests from data/midi/midi_transform_v2/ecomp/2006/Larionova07.MID
# Compressing rests: 21 -> 17
# Compressing rests: 23 -> 19
# Compressing rests: 39 -> 19
# Compressing rests: 35 -> 19
# Compressing rests: 32 -> 16
# Compressing rests: 24 -> 16
# Compressing rests: 40 -> 16
# Compressing rests: 34 -> 18
# Compressing rests: 34 -> 18
# Compressing rests: 33 -> 17
# Compressing rests: 36 -> 16
# Compressing rests: 241 -> 17
# Compressing rests: 59 -> 19
# Compressing rests: 63 -> 19
# Removed 4998 rests from data/midi/midi_transform_v2/ecomp/2015/LuoJ02.MID
# Compressing rests: 30 -> 18
# Compressing rests: 25 -> 17
# Compressing rests: 21 -> 17
# Removed 178 rests from data/midi/midi_transform_v2/ecomp/2006/Larionova03.mid
# Compressing rests: 102 -> 18
# Removed 296 rests from data/midi/midi_transform_v2/ecomp/2006/Larionova04.MID
# Removed 133 rests from data/midi/midi_transform_v2/ecomp/2002/mamriev01.mid
# Compressing rests: 70 -> 18
# Compressing rests: 82 -> 18
# Removed 355 rests from data/midi/midi_transform_v2/ecomp/2009/Rozanski05.MID
# Compressing rests: 185 -> 17
# Compressing rests: 36 -> 16
# Compressing rests: 22 -> 18
# Compressing rests: 34 -> 18
# Compressing rests: 68 -> 16
# Compressing rests: 337 -> 17
# Compressing rests: 31 -> 19
# Compressing rests: 32 -> 16
# Compressing rests: 33 -> 17
# Compressing rests: 28 -> 16
# Compressing rests: 27 -> 19
# Compressing rests: 25 -> 17
# Compressing rests: 21 -> 17
# Compressing rests: 21 -> 17
# Compressing rests: 30 -> 18
# Compressing rests: 27 -> 19
# Compressing rests: 34 -> 18
# Compressing rests: 45 -> 17
# Compressing rests: 418 -> 18
# Compressing rests: 104 -> 16
# Compressing rests: 112 -> 16
# Compressing rests: 42 -> 18
# Compressing rests: 41 -> 17
# Compressing rests: 32 -> 16
# Compressing rests: 34 -> 18
# Compressing rests: 35 -> 19
# Removed 7182 rests from data/midi/midi_transform_v2/ecomp/2015/LiYZ07.MID
# Removed 415 rests from data/midi/midi_transform_v2/ecomp/2002/huang02.mid
# Removed 116 rests from data/midi/midi_transform_v2/cprato/Rustie - Surph  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 129 rests from data/midi/midi_transform_v2/cprato/deadmau5 - Deus Ex Machina  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 197 rests from data/midi/midi_transform_v2/cprato/Rogue - From The Dust  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 105 rests from data/midi/midi_transform_v2/cprato/EDX - High On You (Original Mix) (midi by Carlo Prato) (www.cprato.com).mid
# Removed 114 rests from data/midi/midi_transform_v2/cprato/Chrome Sparks - Ride The White Lightning  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 115 rests from data/midi/midi_transform_v2/cprato/Headhunterz & KSHMR - Dharma  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 176 rests from data/midi/midi_transform_v2/cprato/My Nu Leng & FineArt - Set It  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 256 rests from data/midi/midi_transform_v2/cprato/Clean Bandit - Symphony  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 147 rests from data/midi/midi_transform_v2/cprato/Tujamo - Drop That Low  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 107 rests from data/midi/midi_transform_v2/cprato/Aether & Enzalla - Elysia's Heart  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 129 rests from data/midi/midi_transform_v2/cprato/Aly & Fila Meets Roger Shah & Susana - Unbreakable  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 102 rests from data/midi/midi_transform_v2/cprato/Shawn Mendes - There's Nothing Holdin' Me Back  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 176 rests from data/midi/midi_transform_v2/cprato/REZZ - Selector (Original Mix) (midi by Carlo Prato) (www.cprato.com).mid
# Removed 101 rests from data/midi/midi_transform_v2/cprato/Sam Gellaitry - Dreamscapes  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 121 rests from data/midi/midi_transform_v2/cprato/False Alarm - Matoma  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 152 rests from data/midi/midi_transform_v2/cprato/Blank Banshee - Frozen Flame  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 107 rests from data/midi/midi_transform_v2/cprato/Wax Motif & Vindata - Crazy  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 131 rests from data/midi/midi_transform_v2/cprato/Futuristic Polar Bears, Qulinez - Kali (Original Mix) (midi by Carlo Prato) (www.cprato.com).mid
# Removed 151 rests from data/midi/midi_transform_v2/cprato/Jonas Blue - Mama  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 113 rests from data/midi/midi_transform_v2/cprato/Moby - Go (Hardwell Remix) (midi by Carlo Prato) (www.cprato.com).mid
# Compressing rests: 22 -> 18
# Removed 211 rests from data/midi/midi_transform_v2/cprato/Kaaris - Chargé (Mr. Carmack Remix) (midi by Carlo Prato) (www.cprato.com).mid
# Removed 140 rests from data/midi/midi_transform_v2/cprato/Fehrplay - Everywhere You Go  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 105 rests from data/midi/midi_transform_v2/cprato/Alan Walker - Tired  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 130 rests from data/midi/midi_transform_v2/cprato/Rhythim Is Rhythim - String of Life  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 107 rests from data/midi/midi_transform_v2/cprato/Au5 ft. Cristina Soto - Freefall  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 378 rests from data/midi/midi_transform_v2/cprato/Marshmello - Alone (Original Mix) (midi by Carlo Prato) (www.cprato.com).mid
# Removed 211 rests from data/midi/midi_transform_v2/cprato/Jonas Blue - Perfect Strangers  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 170 rests from data/midi/midi_transform_v2/cprato/Mura Masa - What If I Go  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 147 rests from data/midi/midi_transform_v2/cprato/Axwell & Ingrosso - More Than You Know  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 128 rests from data/midi/midi_transform_v2/cprato/Showtek vs. Technoboy & Tuneboy - Mellow  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 127 rests from data/midi/midi_transform_v2/cprato/Ed Sheeran - Shape of You  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 457 rests from data/midi/midi_transform_v2/classic_piano/bor_ps1_format0.mid
# Removed 117 rests from data/midi/midi_transform_v2/classic_piano/clementi_opus36_1_1_format0.mid
# Removed 413 rests from data/midi/midi_transform_v2/cprato/Sonic Battle - Emerald Beach  (midi by Carlo Prato) (www.cprato.com).mid
# Removed 296 rests from data/midi/midi_transform_v2/cprato/Two Steps From Hell - Blackheart  (midi by Carlo Prato) (www.cprato.com).mid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/midi_generator/data_sources.py in process_parallel(func, arr, total, max_workers, timeout)
#      38         futures = [ex.submit(func,o) for i,o in enumerate(arr)]
# ---> 39         for f in progress_bar(concurrent.futures.as_completed(futures, timeout=timeout), total=total):
#      40             k,v = f.result()
#
# ~/anaconda3/envs/midi/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      64         try:
# ---> 65             for i,o in enumerate(self._gen):
#      66                 yield o
#
# ~/anaconda3/envs/midi/lib/python3.7/concurrent/futures/_base.py in as_completed(fs, timeout)
#     239
# --> 240             waiter.event.wait(wait_timeout)
#     241
#
# ~/anaconda3/envs/midi/lib/python3.7/threading.py in wait(self, timeout)
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#
# ~/anaconda3/envs/midi/lib/python3.7/threading.py in wait(self, timeout)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-b3c60639b637> in <module>
# ----> 1 transcribed_files = process_parallel(transcribe_file, df_filtered.iterrows(), total=df_filtered.shape[0])
#
# ~/midi_generator/data_sources.py in process_parallel(func, arr, total, max_workers, timeout)
#      39         for f in progress_bar(concurrent.futures.as_completed(futures, timeout=timeout), total=total):
#      40             k,v = f.result()
# ---> 41             results[k] = v
#      42     return results
#      43
#
# ~/anaconda3/envs/midi/lib/python3.7/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     609
#     610     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 611         self.shutdown(wait=True)
#     612         return False
#     613
#
# ~/anaconda3/envs/midi/lib/python3.7/concurrent/futures/process.py in shutdown(self, wait)
#     653             self._queue_management_thread_wakeup.wakeup()
#     654             if wait:
# --> 655                 self._queue_management_thread.join()
#     656         # To reduce the risk of opening too many files, remove references to
#     657         # objects that use file descriptors.
#
# ~/anaconda3/envs/midi/lib/python3.7/threading.py in join(self, timeout)
#    1030
#    1031         if timeout is None:
# -> 1032             self._wait_for_tstate_lock()
#    1033         else:
#    1034             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/envs/midi/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1046         if lock is None:  # already determined that the C code is done
#    1047             assert self._is_stopped
# -> 1048         elif lock.acquire(block, timeout):
#    1049             lock.release()
#    1050             self._stop()
#
# KeyboardInterrupt:
# Removed 186 rests from data/midi/midi_transform_v2/classic_piano/chpn_op25_e4_format0.mid

# %%
tdf = pd.DataFrame(data={out_dir: list(transcribed_files.values())}, index=list(transcribed_files.keys()))

# %%
merged_df = df.join(tdf, how='outer'); tdf.shape, df.shape, merged_df.shape

# %%
merged_df.to_csv(out_csv, index=False); merged_df.head()

# %% [markdown]
# ### Calculate timesteps

# %%
merged_df = pd.read_csv(out_csv)

# %%
def calc_timesteps(idxrow):
    idx,row = idxrow
    text_file = row[out_dir]
    if not isinstance(text_file, str) or not Path(text_file).exists(): return idx,None
    try:
        with open(text_file, 'r') as f:
            text = f.read()
        vocab_count = Counter(text.split(' '))
        timesteps = vocab_count[TSEP]
        return idx,timesteps
    except Exception as e:
        print('Error reading text', e)
    return idx, None

# %%
file2steps = process_parallel(calc_timesteps, merged_df.iterrows(), total=merged_df.shape[0])

# %%
len_df = pd.DataFrame(data={f'{out_dir}_timesteps': list(file2steps.values())}, index=list(file2steps.keys()))
merged_len_df = merged_df.join(len_df, how='outer');
len_df.shape, merged_df.shape, merged_len_df.shape

# %%
merged_len_df.to_csv(out_csv, index=False); merged_len_df.head()
