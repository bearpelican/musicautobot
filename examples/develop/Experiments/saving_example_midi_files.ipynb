# %% [markdown]
# ## Building flask api

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
os.chdir('../../../')

# %%
import numpy as np
from pathlib import Path
import pandas as pd
import hashlib
import shutil
import json

# %%
np.set_printoptions(edgeitems=10, threshold=40, linewidth=200)

# %%
data_dir = Path('data/midi/v20/')
path = data_dir/'piano_duet'

# %%
encoded_path = Path('data/midi/examples')

# %% [markdown]
# ## Creating Subset

# %%
song_ids = [
    '99c5db9ce936b7a1c5faab57cc3f160c',
    'aeee134e4034e5f98bb630c56d2f7f8c',
    'b4c62f3d11f448db69c4fa15e27e9e8e',
    '8f10995e036c5f590ca616dee0c9c7d7',
    '58890c433f173ba77220274017b8af92',
    '19762ebd7059dd5f8809f98b2575d8c1',
    'c4d9e72a92f931b2c72e84b6efee4b51',
    'de1fa62a9c209491d4fd81f1d1ceb55e',
    'f8b65d3624d9a68e417792ec27de9296',
    '2ad86f3ecd71b058eac9cc5ceba11db8',
    '999e8169b01f59fa28e63b142f35feda',
    '7f0f162d111f880cf77ff9bed15acd5d',
    '077b40997776b84366ee18056948ae38',
    '065b1c94fe8545bbe8eeec2f1bf4efa2',
    'f2062929514d3084f73a1ad81bbbe01f',
    '68ce7fc929f395291507cc47510cd82c',
    '6ae7e284e78824ee4c17dc6e6bda361c',
    '73b2b8e7db746b7e4b6fc3fa4658671b',
    '3cc8e692016fb1d8c8f097e259ea1ea5',
    
    'b51d911631b67babe1612dae455600e3',
    '81efc618ff11aa17d4e96219380c115e',
    '583aee3ac9d91125102096d28926702b',
    'e250d1faf9b3265f23c049d113f8a773',
    'e8820e3b81d2429d684c986ce2f57071',
    '83ee71fe7fef0bd1fd15a49740cfc967',
    '1b341ae44d35a6c8d21f6ba3af65dd97',
    '4296f489066d02db3491bcde78667746',
    '8c0b6ff7e893dca13edd90a4d9ebb892',
    'c8bcf08c8d31c98c61a91b2d90a9cdde',
    '50b4cbff1b6c2886c31332e5fb1a5f56',
    'bb3324a9068db739eff1b2fc1cc0670b',
    
]

# song_ids = [sid[::-1] for sid in song_ids]

# %%
df = pd.read_csv(path/'piano_duet.csv')
df = df.loc[df['numpy'].notna()]
df = df.loc[df.source == 'hooktheory_c']
df = df.where((pd.notnull(df)), None) # nan values break json
df.shape
# Out:
# /home/ubuntu/anaconda3/envs/musicautobot/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,3,4,7,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (20028, 16)

# %%
subset = df.loc[df.md5.isin(song_ids)]; subset
# Out:
#                                                     parts  ht_time_signature  \
# 177357                                              verse                4.0
# 178513                                 intro,verse,chorus                4.0
# 178716                            intro,pre-chorus,chorus                4.0
# 179774                                         intro,solo                4.0
# 179918                           verse,chorus,bridge,solo                3.0
# 180059                verse,chorus,chorus-lead-out,bridge                4.0
# 180184                       pre-chorus-and-chorus,chorus                4.0
# 180907                  intro,verse-and-pre-chorus,chorus                4.0
# 182159                                             chorus                4.0
# 182319                  intro-and-verse,pre-chorus,chorus                4.0
# 182576                            verse,pre-chorus,chorus                4.0
# 182759                                         pre-chorus                4.0
# 184146                                       intro,chorus                4.0
# 185994                                         pre-chorus                4.0
# 186799                                             chorus                4.0
# 187197                                       intro,bridge                4.0
# 187410                                 intro,verse,chorus                4.0
# 188500                                              verse                4.0
# 188950  intro,intro-and-verse,verse,pre-chorus,chorus,...                4.0
# 190136                      intro,verse,pre-chorus,chorus                4.0
# 192063                            verse,pre-chorus,chorus                4.0
# 192556                                 verse,chorus,outro                4.0
# 193633                                 verse,chorus,outro                4.0
# 193875                                verse,chorus,bridge                4.0
# 194473                                             chorus                4.0
# 195365                        verse-and-pre-chorus,chorus                4.0
# 195602                  intro,verse,pre-chorus-and-chorus                4.0
# 196640                            intro,solo,instrumental                4.0
# 197138                                       verse,chorus                4.0
# 197169                                        intro,verse                4.0
# 197627                            verse,pre-chorus,chorus                4.0
#
#                                                      midi  \
# 177357  midi_sources/hooktheory/pianoroll/w/wolfgang-a...
# 178513  midi_sources/hooktheory/pianoroll/j/jackson-5/...
# 178716  midi_sources/hooktheory/pianoroll/j/johann-pac...
# 179774  midi_sources/hooktheory/pianoroll/l/led-zeppel...
# 179918  midi_sources/hooktheory/pianoroll/l/ludwig-van...
# 180059  midi_sources/hooktheory/pianoroll/l/lady-gaga/...
# 180184  midi_sources/hooktheory/pianoroll/l/linkin-par...
# 180907  midi_sources/hooktheory/pianoroll/v/vanessa-ca...
# 182159  midi_sources/hooktheory/pianoroll/b/black-eyed...
# 182319  midi_sources/hooktheory/pianoroll/b/bruno-mars...
# 182576  midi_sources/hooktheory/pianoroll/b/britney-sp...
# 182759  midi_sources/hooktheory/pianoroll/z/zedd/middl...
# 184146  midi_sources/hooktheory/pianoroll/d/disney/col...
# 185994  midi_sources/hooktheory/pianoroll/s/skrillex/s...
# 186799  midi_sources/hooktheory/pianoroll/c/carly-rae-...
# 187197  midi_sources/hooktheory/pianoroll/e/edvard-gri...
# 187410  midi_sources/hooktheory/pianoroll/e/elton-john...
# 188500  midi_sources/hooktheory/pianoroll/n/nintendo/l...
# 188950  midi_sources/hooktheory/pianoroll/i/idina-menz...
# 190136  midi_sources/hooktheory/pianoroll/p/pink/just-...
# 192063  midi_sources/hooktheory/pianoroll/t/the-chains...
# 192556  midi_sources/hooktheory/pianoroll/t/the-beatle...
# 193633  midi_sources/hooktheory/pianoroll/k/kanye-west...
# 193875  midi_sources/hooktheory/pianoroll/k/katy-perry...
# 194473  midi_sources/hooktheory/pianoroll/r/ritchie-va...
# 195365  midi_sources/hooktheory/pianoroll/m/michelle-b...
# 195602  midi_sources/hooktheory/pianoroll/m/mariah-car...
# 196640  midi_sources/hooktheory/pianoroll/a/antonio-vi...
# 197138  midi_sources/hooktheory/pianoroll/a/aerosmith/...
# 197169  midi_sources/hooktheory/pianoroll/a/avicii/lev...
# 197627  midi_sources/hooktheory/pianoroll/a/avril-lavi...
#
#                       section                            midi_title  \
# 177357                  verse         Symphony no 40 in G minor - I
# 178513                  intro                       I Want You Back
# 178716                 chorus                Pachelbel Canon Chorus
# 179774                  intro                    Stairway to Heaven
# 179918                  verse                            Fuer Elise
# 180059                 chorus                           Bad Romance
# 180184                 chorus                            In The End
# 180907   verse-and-pre-chorus  A thousand miles verse and prechorus
# 182159                 chorus              Where is the Love Chorus
# 182319                 chorus                              Locked C
# 182576                 chorus                   Oops I Did It Again
# 182759             pre-chorus                                Middle
# 184146                 chorus                    Colors Of The Wind
# 185994             pre-chorus       Scary Monsters And Nice Sprites
# 186799                 chorus                         Call Me Maybe
# 187197                  intro      In The Hall Of The Mountain King
# 187410                  verse         Can You Feel the Love Tonight
# 188500                  verse            Legend of Zelda Main Theme
# 188950                 chorus                             Let It Go
# 190136                 chorus                 Just Give Me A Reason
# 192063                 chorus                        Roses ft ROZES
# 192556                 chorus                              Hey Jude
# 193633                 chorus                              Stronger
# 193875                 chorus                       I Kissed A Girl
# 194473                 chorus                              La Bamba
# 195365                 chorus                            Everywhere
# 195602  pre-chorus-and-chorus       All I Want For Christmas Is You
# 196640           instrumental                                Winter
# 197138                 chorus          I Don't Want To Miss A Thing
# 197169                  verse                                Levels
# 197627                 chorus                    Complicated Chorus
#
#                                         title  \
# 177357          symphony-no-40-in-g-minor---i
# 178513                        i-want-you-back
# 178716                       canon-in-d-major
# 179774                     stairway-to-heaven
# 179918                             fuer-elise
# 180059                            bad-romance
# 180184                             in-the-end
# 180907                       a-thousand-miles
# 182159                      where-is-the-love
# 182319                   locked-out-of-heaven
# 182576                    oops-i-did-it-again
# 182759                                 middle
# 184146                     colors-of-the-wind
# 185994        scary-monsters-and-nice-sprites
# 186799                          call-me-maybe
# 187197       in-the-hall-of-the-mountain-king
# 187410          can-you-feel-the-love-tonight
# 188500             legend-of-zelda-main-theme
# 188950                              let-it-go
# 190136                  just-give-me-a-reason
# 192063                         roses-ft-rozes
# 192556                               hey-jude
# 193633                               stronger
# 193875                        i-kissed-a-girl
# 194473                               la-bamba
# 195365                             everywhere
# 195602        all-i-want-for-christmas-is-you
# 196640  the-four-seasons-concerto-no-4-winter
# 197138            i-dont-want-to-miss-a-thing
# 197169                                 levels
# 197627                            complicated
#
#                                                     numpy   mxl  ht_bpm  \
# 177357  piano_duet/hooktheory/pianoroll/w/wolfgang-ama...  None   115.0
# 178513  piano_duet/hooktheory/pianoroll/j/jackson-5/i-...  None    98.0
# 178716  piano_duet/hooktheory/pianoroll/j/johann-pache...  None   138.0
# 179774  piano_duet/hooktheory/pianoroll/l/led-zeppelin...  None    74.0
# 179918  piano_duet/hooktheory/pianoroll/l/ludwig-van-b...  None   139.0
# 180059  piano_duet/hooktheory/pianoroll/l/lady-gaga/ba...  None   119.0
# 180184  piano_duet/hooktheory/pianoroll/l/linkin-park/...  None   107.0
# 180907  piano_duet/hooktheory/pianoroll/v/vanessa-carl...  None    96.0
# 182159  piano_duet/hooktheory/pianoroll/b/black-eyed-p...  None    93.0
# 182319  piano_duet/hooktheory/pianoroll/b/bruno-mars/l...  None   147.0
# 182576  piano_duet/hooktheory/pianoroll/b/britney-spea...  None    94.0
# 182759  piano_duet/hooktheory/pianoroll/z/zedd/middle/...  None   107.0
# 184146  piano_duet/hooktheory/pianoroll/d/disney/color...  None   107.0
# 185994  piano_duet/hooktheory/pianoroll/s/skrillex/sca...  None   140.0
# 186799  piano_duet/hooktheory/pianoroll/c/carly-rae-je...  None   120.0
# 187197  piano_duet/hooktheory/pianoroll/e/edvard-grieg...  None   116.0
# 187410  piano_duet/hooktheory/pianoroll/e/elton-john/c...  None    62.0
# 188500  piano_duet/hooktheory/pianoroll/n/nintendo/leg...  None    92.0
# 188950  piano_duet/hooktheory/pianoroll/i/idina-menzel...  None   137.0
# 190136  piano_duet/hooktheory/pianoroll/p/pink/just-gi...  None    94.0
# 192063  piano_duet/hooktheory/pianoroll/t/the-chainsmo...  None   101.0
# 192556  piano_duet/hooktheory/pianoroll/t/the-beatles/...  None    75.0
# 193633  piano_duet/hooktheory/pianoroll/k/kanye-west/s...  None   102.0
# 193875  piano_duet/hooktheory/pianoroll/k/katy-perry/i...  None   130.0
# 194473  piano_duet/hooktheory/pianoroll/r/ritchie-vale...  None   144.0
# 195365  piano_duet/hooktheory/pianoroll/m/michelle-bra...  None    95.0
# 195602  piano_duet/hooktheory/pianoroll/m/mariah-carey...  None   151.0
# 196640  piano_duet/hooktheory/pianoroll/a/antonio-viva...  None    84.0
# 197138  piano_duet/hooktheory/pianoroll/a/aerosmith/i-...  None    60.0
# 197169  piano_duet/hooktheory/pianoroll/a/avicii/level...  None   126.0
# 197627  piano_duet/hooktheory/pianoroll/a/avril-lavign...  None    76.0
#
#                                      md5        source  \
# 177357  4296f489066d02db3491bcde78667746  hooktheory_c
# 178513  2ad86f3ecd71b058eac9cc5ceba11db8  hooktheory_c
# 178716  c4d9e72a92f931b2c72e84b6efee4b51  hooktheory_c
# 179774  8c0b6ff7e893dca13edd90a4d9ebb892  hooktheory_c
# 179918  6ae7e284e78824ee4c17dc6e6bda361c  hooktheory_c
# 180059  bb3324a9068db739eff1b2fc1cc0670b  hooktheory_c
# 180184  b51d911631b67babe1612dae455600e3  hooktheory_c
# 180907  58890c433f173ba77220274017b8af92  hooktheory_c
# 182159  68ce7fc929f395291507cc47510cd82c  hooktheory_c
# 182319  077b40997776b84366ee18056948ae38  hooktheory_c
# 182576  583aee3ac9d91125102096d28926702b  hooktheory_c
# 182759  7f0f162d111f880cf77ff9bed15acd5d  hooktheory_c
# 184146  8f10995e036c5f590ca616dee0c9c7d7  hooktheory_c
# 185994  f8b65d3624d9a68e417792ec27de9296  hooktheory_c
# 186799  99c5db9ce936b7a1c5faab57cc3f160c  hooktheory_c
# 187197  de1fa62a9c209491d4fd81f1d1ceb55e  hooktheory_c
# 187410  b4c62f3d11f448db69c4fa15e27e9e8e  hooktheory_c
# 188500  e250d1faf9b3265f23c049d113f8a773  hooktheory_c
# 188950  f2062929514d3084f73a1ad81bbbe01f  hooktheory_c
# 190136  065b1c94fe8545bbe8eeec2f1bf4efa2  hooktheory_c
# 192063  3cc8e692016fb1d8c8f097e259ea1ea5  hooktheory_c
# 192556  81efc618ff11aa17d4e96219380c115e  hooktheory_c
# 193633  50b4cbff1b6c2886c31332e5fb1a5f56  hooktheory_c
# 193875  1b341ae44d35a6c8d21f6ba3af65dd97  hooktheory_c
# 194473  aeee134e4034e5f98bb630c56d2f7f8c  hooktheory_c
# 195365  83ee71fe7fef0bd1fd15a49740cfc967  hooktheory_c
# 195602  999e8169b01f59fa28e63b142f35feda  hooktheory_c
# 196640  73b2b8e7db746b7e4b6fc3fa4658671b  hooktheory_c
# 197138  e8820e3b81d2429d684c986ce2f57071  hooktheory_c
# 197169  19762ebd7059dd5f8809f98b2575d8c1  hooktheory_c
# 197627  c8bcf08c8d31c98c61a91b2d90a9cdde  hooktheory_c
#
#                          artist ht_key  ht_mode  \
# 177357  wolfgang-amadeus-mozart      C      1.0
# 178513                jackson-5      C      1.0
# 178716         johann-pachelbel      C      1.0
# 179774             led-zeppelin      C      1.0
# 179918     ludwig-van-beethoven      C      1.0
# 180059                lady-gaga      C      1.0
# 180184              linkin-park      C      1.0
# 180907          vanessa-carlton      C      1.0
# 182159          black-eyed-peas      C      1.0
# 182319               bruno-mars      C      1.0
# 182576           britney-spears      C      1.0
# 182759                     zedd      C      1.0
# 184146                   disney      C      1.0
# 185994                 skrillex      C      1.0
# 186799         carly-rae-jepsen      C      1.0
# 187197             edvard-grieg      C      1.0
# 187410               elton-john      C      1.0
# 188500                 nintendo      C      1.0
# 188950             idina-menzel      C      1.0
# 190136                     pink      C      1.0
# 192063         the-chainsmokers      C      1.0
# 192556              the-beatles      C      1.0
# 193633               kanye-west      C      1.0
# 193875               katy-perry      C      1.0
# 194473            ritchie-valen      C      1.0
# 195365          michelle-branch      C      1.0
# 195602             mariah-carey      C      1.0
# 196640          antonio-vivaldi      C      1.0
# 197138                aerosmith      C      1.0
# 197169                   avicii      C      1.0
# 197627            avril-lavigne      C      1.0
#
#                                         genres  \
# 177357                               Classical
# 178513                                    None
# 178716                               Classical
# 179774                                   Blues
# 179918                               Classical
# 180059                                     Pop
# 180184                                   Blues
# 180907                   Pop,Singer-Songwriter
# 182159                                    None
# 182319                                     Pop
# 182576                                    None
# 182759                                    None
# 184146                                  Disney
# 185994                  Dance,Electronic,House
# 186799                                     Pop
# 187197                               Classical
# 187410                         Disney,Pop,Rock
# 188500                              Video Game
# 188950  Dance,Disney,Electronic,Pop,Soundtrack
# 190136                                     Pop
# 192063                          Electronic,Pop
# 192556                                    Rock
# 193633                  Electronic,Hip-Hop/Rap
# 193875                                Pop,Rock
# 194473                                Pop,Rock
# 195365                                    None
# 195602                                    None
# 196640                               Classical
# 197138                                    Rock
# 197169                        Electronic,House
# 197627                    Alternative,Pop,Soul
#
#                                                  song_url
# 177357  https://www.hooktheory.com/theorytab/view/wolf...
# 178513  https://www.hooktheory.com/theorytab/view/jack...
# 178716  https://www.hooktheory.com/theorytab/view/joha...
# 179774  https://www.hooktheory.com/theorytab/view/led-...
# 179918  https://www.hooktheory.com/theorytab/view/ludw...
# 180059  https://www.hooktheory.com/theorytab/view/lady...
# 180184  https://www.hooktheory.com/theorytab/view/link...
# 180907  https://www.hooktheory.com/theorytab/view/vane...
# 182159  https://www.hooktheory.com/theorytab/view/blac...
# 182319  https://www.hooktheory.com/theorytab/view/brun...
# 182576  https://www.hooktheory.com/theorytab/view/brit...
# 182759  https://www.hooktheory.com/theorytab/view/zedd...
# 184146  https://www.hooktheory.com/theorytab/view/disn...
# 185994  https://www.hooktheory.com/theorytab/view/skri...
# 186799  https://www.hooktheory.com/theorytab/view/carl...
# 187197  https://www.hooktheory.com/theorytab/view/edva...
# 187410  https://www.hooktheory.com/theorytab/view/elto...
# 188500  https://www.hooktheory.com/theorytab/view/nint...
# 188950  https://www.hooktheory.com/theorytab/view/idin...
# 190136  https://www.hooktheory.com/theorytab/view/pink...
# 192063  https://www.hooktheory.com/theorytab/view/the-...
# 192556  https://www.hooktheory.com/theorytab/view/the-...
# 193633  https://www.hooktheory.com/theorytab/view/kany...
# 193875  https://www.hooktheory.com/theorytab/view/katy...
# 194473  https://www.hooktheory.com/theorytab/view/ritc...
# 195365  https://www.hooktheory.com/theorytab/view/mich...
# 195602  https://www.hooktheory.com/theorytab/view/mari...
# 196640  https://www.hooktheory.com/theorytab/view/anto...
# 197138  https://www.hooktheory.com/theorytab/view/aero...
# 197169  https://www.hooktheory.com/theorytab/view/avic...
# 197627  https://www.hooktheory.com/theorytab/view/avri...

# %%
recordlist = subset.to_dict('records')

# %%
recordlist
# Out:
# [{'parts': 'verse',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/w/wolfgang-amadeus-mozart/symphony-no-40-in-g-minor---i/verse_key_cmajor.mid',
#   'section': 'verse',
#   'midi_title': 'Symphony no 40 in G minor - I',
#   'title': 'symphony-no-40-in-g-minor---i',
#   'numpy': 'piano_duet/hooktheory/pianoroll/w/wolfgang-amadeus-mozart/symphony-no-40-in-g-minor---i/verse_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 115.0,
#   'md5': '4296f489066d02db3491bcde78667746',
#   'source': 'hooktheory_c',
#   'artist': 'wolfgang-amadeus-mozart',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Classical',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/wolfgang-amadeus-mozart/symphony-no-40-in-g-minor---i'},
#  {'parts': 'intro,verse,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/j/jackson-5/i-want-you-back/intro_key_cmajor.mid',
#   'section': 'intro',
#   'midi_title': 'I Want You Back',
#   'title': 'i-want-you-back',
#   'numpy': 'piano_duet/hooktheory/pianoroll/j/jackson-5/i-want-you-back/intro_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 98.0,
#   'md5': '2ad86f3ecd71b058eac9cc5ceba11db8',
#   'source': 'hooktheory_c',
#   'artist': 'jackson-5',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': None,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/jackson-5/i-want-you-back'},
#  {'parts': 'intro,pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/j/johann-pachelbel/canon-in-d-major/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Pachelbel Canon Chorus',
#   'title': 'canon-in-d-major',
#   'numpy': 'piano_duet/hooktheory/pianoroll/j/johann-pachelbel/canon-in-d-major/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 138.0,
#   'md5': 'c4d9e72a92f931b2c72e84b6efee4b51',
#   'source': 'hooktheory_c',
#   'artist': 'johann-pachelbel',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Classical',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/johann-pachelbel/canon-in-d-major'},
#  {'parts': 'intro,solo',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/l/led-zeppelin/stairway-to-heaven/intro_key_cmajor.mid',
#   'section': 'intro',
#   'midi_title': 'Stairway to Heaven',
#   'title': 'stairway-to-heaven',
#   'numpy': 'piano_duet/hooktheory/pianoroll/l/led-zeppelin/stairway-to-heaven/intro_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 74.0,
#   'md5': '8c0b6ff7e893dca13edd90a4d9ebb892',
#   'source': 'hooktheory_c',
#   'artist': 'led-zeppelin',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Blues',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/led-zeppelin/stairway-to-heaven'},
#  {'parts': 'verse,chorus,bridge,solo',
#   'ht_time_signature': 3.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/l/ludwig-van-beethoven/fuer-elise/verse_key_cmajor.mid',
#   'section': 'verse',
#   'midi_title': 'Fuer Elise',
#   'title': 'fuer-elise',
#   'numpy': 'piano_duet/hooktheory/pianoroll/l/ludwig-van-beethoven/fuer-elise/verse_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 139.0,
#   'md5': '6ae7e284e78824ee4c17dc6e6bda361c',
#   'source': 'hooktheory_c',
#   'artist': 'ludwig-van-beethoven',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Classical',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/ludwig-van-beethoven/fuer-elise'},
#  {'parts': 'verse,chorus,chorus-lead-out,bridge',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/l/lady-gaga/bad-romance/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Bad Romance',
#   'title': 'bad-romance',
#   'numpy': 'piano_duet/hooktheory/pianoroll/l/lady-gaga/bad-romance/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 119.0,
#   'md5': 'bb3324a9068db739eff1b2fc1cc0670b',
#   'source': 'hooktheory_c',
#   'artist': 'lady-gaga',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Pop',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/lady-gaga/bad-romance'},
#  {'parts': 'pre-chorus-and-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/l/linkin-park/in-the-end/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'In The End',
#   'title': 'in-the-end',
#   'numpy': 'piano_duet/hooktheory/pianoroll/l/linkin-park/in-the-end/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 107.0,
#   'md5': 'b51d911631b67babe1612dae455600e3',
#   'source': 'hooktheory_c',
#   'artist': 'linkin-park',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Blues',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/linkin-park/in-the-end'},
#  {'parts': 'intro,verse-and-pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/v/vanessa-carlton/a-thousand-miles/verse-and-pre-chorus_key_cmajor.mid',
#   'section': 'verse-and-pre-chorus',
#   'midi_title': 'A thousand miles verse and prechorus',
#   'title': 'a-thousand-miles',
#   'numpy': 'piano_duet/hooktheory/pianoroll/v/vanessa-carlton/a-thousand-miles/verse-and-pre-chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 96.0,
#   'md5': '58890c433f173ba77220274017b8af92',
#   'source': 'hooktheory_c',
#   'artist': 'vanessa-carlton',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Pop,Singer-Songwriter',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/vanessa-carlton/a-thousand-miles'},
#  {'parts': 'chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/b/black-eyed-peas/where-is-the-love/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Where is the Love Chorus',
#   'title': 'where-is-the-love',
#   'numpy': 'piano_duet/hooktheory/pianoroll/b/black-eyed-peas/where-is-the-love/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 93.0,
#   'md5': '68ce7fc929f395291507cc47510cd82c',
#   'source': 'hooktheory_c',
#   'artist': 'black-eyed-peas',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': None,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/black-eyed-peas/where-is-the-love'},
#  {'parts': 'intro-and-verse,pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/b/bruno-mars/locked-out-of-heaven/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Locked C',
#   'title': 'locked-out-of-heaven',
#   'numpy': 'piano_duet/hooktheory/pianoroll/b/bruno-mars/locked-out-of-heaven/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 147.0,
#   'md5': '077b40997776b84366ee18056948ae38',
#   'source': 'hooktheory_c',
#   'artist': 'bruno-mars',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Pop',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/bruno-mars/locked-out-of-heaven'},
#  {'parts': 'verse,pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/b/britney-spears/oops-i-did-it-again/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Oops I Did It Again',
#   'title': 'oops-i-did-it-again',
#   'numpy': 'piano_duet/hooktheory/pianoroll/b/britney-spears/oops-i-did-it-again/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 94.0,
#   'md5': '583aee3ac9d91125102096d28926702b',
#   'source': 'hooktheory_c',
#   'artist': 'britney-spears',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': None,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/britney-spears/oops-i-did-it-again'},
#  {'parts': 'pre-chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/z/zedd/middle/pre-chorus_key_cmajor.mid',
#   'section': 'pre-chorus',
#   'midi_title': 'Middle',
#   'title': 'middle',
#   'numpy': 'piano_duet/hooktheory/pianoroll/z/zedd/middle/pre-chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 107.0,
#   'md5': '7f0f162d111f880cf77ff9bed15acd5d',
#   'source': 'hooktheory_c',
#   'artist': 'zedd',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': None,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/zedd/middle'},
#  {'parts': 'intro,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/d/disney/colors-of-the-wind/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Colors Of The Wind',
#   'title': 'colors-of-the-wind',
#   'numpy': 'piano_duet/hooktheory/pianoroll/d/disney/colors-of-the-wind/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 107.0,
#   'md5': '8f10995e036c5f590ca616dee0c9c7d7',
#   'source': 'hooktheory_c',
#   'artist': 'disney',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Disney',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/disney/colors-of-the-wind'},
#  {'parts': 'pre-chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/s/skrillex/scary-monsters-and-nice-sprites/pre-chorus_key_cmajor.mid',
#   'section': 'pre-chorus',
#   'midi_title': 'Scary Monsters And Nice Sprites',
#   'title': 'scary-monsters-and-nice-sprites',
#   'numpy': 'piano_duet/hooktheory/pianoroll/s/skrillex/scary-monsters-and-nice-sprites/pre-chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 140.0,
#   'md5': 'f8b65d3624d9a68e417792ec27de9296',
#   'source': 'hooktheory_c',
#   'artist': 'skrillex',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Dance,Electronic,House',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/skrillex/scary-monsters-and-nice-sprites'},
#  {'parts': 'chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/c/carly-rae-jepsen/call-me-maybe/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Call Me Maybe',
#   'title': 'call-me-maybe',
#   'numpy': 'piano_duet/hooktheory/pianoroll/c/carly-rae-jepsen/call-me-maybe/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 120.0,
#   'md5': '99c5db9ce936b7a1c5faab57cc3f160c',
#   'source': 'hooktheory_c',
#   'artist': 'carly-rae-jepsen',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Pop',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/carly-rae-jepsen/call-me-maybe'},
#  {'parts': 'intro,bridge',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/e/edvard-grieg/in-the-hall-of-the-mountain-king/intro_key_cmajor.mid',
#   'section': 'intro',
#   'midi_title': 'In The Hall Of The Mountain King',
#   'title': 'in-the-hall-of-the-mountain-king',
#   'numpy': 'piano_duet/hooktheory/pianoroll/e/edvard-grieg/in-the-hall-of-the-mountain-king/intro_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 116.0,
#   'md5': 'de1fa62a9c209491d4fd81f1d1ceb55e',
#   'source': 'hooktheory_c',
#   'artist': 'edvard-grieg',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Classical',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/edvard-grieg/in-the-hall-of-the-mountain-king'},
#  {'parts': 'intro,verse,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/e/elton-john/can-you-feel-the-love-tonight/verse_key_cmajor.mid',
#   'section': 'verse',
#   'midi_title': 'Can You Feel the Love Tonight',
#   'title': 'can-you-feel-the-love-tonight',
#   'numpy': 'piano_duet/hooktheory/pianoroll/e/elton-john/can-you-feel-the-love-tonight/verse_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 62.0,
#   'md5': 'b4c62f3d11f448db69c4fa15e27e9e8e',
#   'source': 'hooktheory_c',
#   'artist': 'elton-john',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Disney,Pop,Rock',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/elton-john/can-you-feel-the-love-tonight'},
#  {'parts': 'verse',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/n/nintendo/legend-of-zelda-main-theme/verse_key_cmajor.mid',
#   'section': 'verse',
#   'midi_title': 'Legend of Zelda Main Theme',
#   'title': 'legend-of-zelda-main-theme',
#   'numpy': 'piano_duet/hooktheory/pianoroll/n/nintendo/legend-of-zelda-main-theme/verse_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 92.0,
#   'md5': 'e250d1faf9b3265f23c049d113f8a773',
#   'source': 'hooktheory_c',
#   'artist': 'nintendo',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Video Game',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/nintendo/legend-of-zelda-main-theme'},
#  {'parts': 'intro,intro-and-verse,verse,pre-chorus,chorus,bridge,instrumental',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/i/idina-menzel/let-it-go/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Let It Go',
#   'title': 'let-it-go',
#   'numpy': 'piano_duet/hooktheory/pianoroll/i/idina-menzel/let-it-go/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 137.0,
#   'md5': 'f2062929514d3084f73a1ad81bbbe01f',
#   'source': 'hooktheory_c',
#   'artist': 'idina-menzel',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Dance,Disney,Electronic,Pop,Soundtrack',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/idina-menzel/let-it-go'},
#  {'parts': 'intro,verse,pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/p/pink/just-give-me-a-reason/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Just Give Me A Reason',
#   'title': 'just-give-me-a-reason',
#   'numpy': 'piano_duet/hooktheory/pianoroll/p/pink/just-give-me-a-reason/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 94.0,
#   'md5': '065b1c94fe8545bbe8eeec2f1bf4efa2',
#   'source': 'hooktheory_c',
#   'artist': 'pink',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Pop',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/pink/just-give-me-a-reason'},
#  {'parts': 'verse,pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/t/the-chainsmokers/roses-ft-rozes/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Roses ft ROZES',
#   'title': 'roses-ft-rozes',
#   'numpy': 'piano_duet/hooktheory/pianoroll/t/the-chainsmokers/roses-ft-rozes/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 101.0,
#   'md5': '3cc8e692016fb1d8c8f097e259ea1ea5',
#   'source': 'hooktheory_c',
#   'artist': 'the-chainsmokers',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Electronic,Pop',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/the-chainsmokers/roses-ft-rozes'},
#  {'parts': 'verse,chorus,outro',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/t/the-beatles/hey-jude/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Hey Jude',
#   'title': 'hey-jude',
#   'numpy': 'piano_duet/hooktheory/pianoroll/t/the-beatles/hey-jude/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 75.0,
#   'md5': '81efc618ff11aa17d4e96219380c115e',
#   'source': 'hooktheory_c',
#   'artist': 'the-beatles',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Rock',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/the-beatles/hey-jude'},
#  {'parts': 'verse,chorus,outro',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/k/kanye-west/stronger/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Stronger',
#   'title': 'stronger',
#   'numpy': 'piano_duet/hooktheory/pianoroll/k/kanye-west/stronger/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 102.0,
#   'md5': '50b4cbff1b6c2886c31332e5fb1a5f56',
#   'source': 'hooktheory_c',
#   'artist': 'kanye-west',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Electronic,Hip-Hop/Rap',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/kanye-west/stronger'},
#  {'parts': 'verse,chorus,bridge',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/k/katy-perry/i-kissed-a-girl/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'I Kissed A Girl',
#   'title': 'i-kissed-a-girl',
#   'numpy': 'piano_duet/hooktheory/pianoroll/k/katy-perry/i-kissed-a-girl/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 130.0,
#   'md5': '1b341ae44d35a6c8d21f6ba3af65dd97',
#   'source': 'hooktheory_c',
#   'artist': 'katy-perry',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Pop,Rock',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/katy-perry/i-kissed-a-girl'},
#  {'parts': 'chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/r/ritchie-valen/la-bamba/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'La Bamba',
#   'title': 'la-bamba',
#   'numpy': 'piano_duet/hooktheory/pianoroll/r/ritchie-valen/la-bamba/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 144.0,
#   'md5': 'aeee134e4034e5f98bb630c56d2f7f8c',
#   'source': 'hooktheory_c',
#   'artist': 'ritchie-valen',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Pop,Rock',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/ritchie-valen/la-bamba'},
#  {'parts': 'verse-and-pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/m/michelle-branch/everywhere/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Everywhere',
#   'title': 'everywhere',
#   'numpy': 'piano_duet/hooktheory/pianoroll/m/michelle-branch/everywhere/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 95.0,
#   'md5': '83ee71fe7fef0bd1fd15a49740cfc967',
#   'source': 'hooktheory_c',
#   'artist': 'michelle-branch',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': None,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/michelle-branch/everywhere'},
#  {'parts': 'intro,verse,pre-chorus-and-chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/m/mariah-carey/all-i-want-for-christmas-is-you/pre-chorus-and-chorus_key_cmajor.mid',
#   'section': 'pre-chorus-and-chorus',
#   'midi_title': 'All I Want For Christmas Is You',
#   'title': 'all-i-want-for-christmas-is-you',
#   'numpy': 'piano_duet/hooktheory/pianoroll/m/mariah-carey/all-i-want-for-christmas-is-you/pre-chorus-and-chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 151.0,
#   'md5': '999e8169b01f59fa28e63b142f35feda',
#   'source': 'hooktheory_c',
#   'artist': 'mariah-carey',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': None,
#   'song_url': 'https://www.hooktheory.com/theorytab/view/mariah-carey/all-i-want-for-christmas-is-you'},
#  {'parts': 'intro,solo,instrumental',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/antonio-vivaldi/the-four-seasons-concerto-no-4-winter/instrumental_key_cmajor.mid',
#   'section': 'instrumental',
#   'midi_title': 'Winter',
#   'title': 'the-four-seasons-concerto-no-4-winter',
#   'numpy': 'piano_duet/hooktheory/pianoroll/a/antonio-vivaldi/the-four-seasons-concerto-no-4-winter/instrumental_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 84.0,
#   'md5': '73b2b8e7db746b7e4b6fc3fa4658671b',
#   'source': 'hooktheory_c',
#   'artist': 'antonio-vivaldi',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Classical',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/antonio-vivaldi/the-four-seasons-concerto-no-4-winter'},
#  {'parts': 'verse,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/aerosmith/i-dont-want-to-miss-a-thing/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': "I Don't Want To Miss A Thing",
#   'title': 'i-dont-want-to-miss-a-thing',
#   'numpy': 'piano_duet/hooktheory/pianoroll/a/aerosmith/i-dont-want-to-miss-a-thing/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 60.0,
#   'md5': 'e8820e3b81d2429d684c986ce2f57071',
#   'source': 'hooktheory_c',
#   'artist': 'aerosmith',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Rock',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/aerosmith/i-dont-want-to-miss-a-thing'},
#  {'parts': 'intro,verse',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/avicii/levels/verse_key_cmajor.mid',
#   'section': 'verse',
#   'midi_title': 'Levels',
#   'title': 'levels',
#   'numpy': 'piano_duet/hooktheory/pianoroll/a/avicii/levels/verse_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 126.0,
#   'md5': '19762ebd7059dd5f8809f98b2575d8c1',
#   'source': 'hooktheory_c',
#   'artist': 'avicii',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Electronic,House',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/avicii/levels'},
#  {'parts': 'verse,pre-chorus,chorus',
#   'ht_time_signature': 4.0,
#   'midi': 'midi_sources/hooktheory/pianoroll/a/avril-lavigne/complicated/chorus_key_cmajor.mid',
#   'section': 'chorus',
#   'midi_title': 'Complicated Chorus',
#   'title': 'complicated',
#   'numpy': 'piano_duet/hooktheory/pianoroll/a/avril-lavigne/complicated/chorus_key_cmajor.npy',
#   'mxl': None,
#   'ht_bpm': 76.0,
#   'md5': 'c8bcf08c8d31c98c61a91b2d90a9cdde',
#   'source': 'hooktheory_c',
#   'artist': 'avril-lavigne',
#   'ht_key': 'C',
#   'ht_mode': 1.0,
#   'genres': 'Alternative,Pop,Soul',
#   'song_url': 'https://www.hooktheory.com/theorytab/view/avril-lavigne/complicated'}]

# %% [markdown]
# ## Saving to example Folder

# %%
def format_meta(s):
    title = s['title'].title().replace('-', ' ')
    artist = s['artist'].title().replace('-', ' ')
    display = ' - '.join([title, artist])
    if s.get('section'): display += ' - ' + s['section'].title()
        
    key_file = data_dir/s['midi']
    to_file = encoded_path/f'{display}.mid'
    if not to_file.exists():
        to_file.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy(str(key_file), str(to_file))
    return to_file

# %%
[format_meta(s) for s in recordlist]
# Out:
# [PosixPath('data/midi/examples/Symphony No 40 In G Minor   I - Wolfgang Amadeus Mozart - Verse.mid'),
#  PosixPath('data/midi/examples/I Want You Back - Jackson 5 - Intro.mid'),
#  PosixPath('data/midi/examples/Canon In D Major - Johann Pachelbel - Chorus.mid'),
#  PosixPath('data/midi/examples/Stairway To Heaven - Led Zeppelin - Intro.mid'),
#  PosixPath('data/midi/examples/Fuer Elise - Ludwig Van Beethoven - Verse.mid'),
#  PosixPath('data/midi/examples/Bad Romance - Lady Gaga - Chorus.mid'),
#  PosixPath('data/midi/examples/In The End - Linkin Park - Chorus.mid'),
#  PosixPath('data/midi/examples/A Thousand Miles - Vanessa Carlton - Verse-And-Pre-Chorus.mid'),
#  PosixPath('data/midi/examples/Where Is The Love - Black Eyed Peas - Chorus.mid'),
#  PosixPath('data/midi/examples/Locked Out Of Heaven - Bruno Mars - Chorus.mid'),
#  PosixPath('data/midi/examples/Oops I Did It Again - Britney Spears - Chorus.mid'),
#  PosixPath('data/midi/examples/Middle - Zedd - Pre-Chorus.mid'),
#  PosixPath('data/midi/examples/Colors Of The Wind - Disney - Chorus.mid'),
#  PosixPath('data/midi/examples/Scary Monsters And Nice Sprites - Skrillex - Pre-Chorus.mid'),
#  PosixPath('data/midi/examples/Call Me Maybe - Carly Rae Jepsen - Chorus.mid'),
#  PosixPath('data/midi/examples/In The Hall Of The Mountain King - Edvard Grieg - Intro.mid'),
#  PosixPath('data/midi/examples/Can You Feel The Love Tonight - Elton John - Verse.mid'),
#  PosixPath('data/midi/examples/Legend Of Zelda Main Theme - Nintendo - Verse.mid'),
#  PosixPath('data/midi/examples/Let It Go - Idina Menzel - Chorus.mid'),
#  PosixPath('data/midi/examples/Just Give Me A Reason - Pink - Chorus.mid'),
#  PosixPath('data/midi/examples/Roses Ft Rozes - The Chainsmokers - Chorus.mid'),
#  PosixPath('data/midi/examples/Hey Jude - The Beatles - Chorus.mid'),
#  PosixPath('data/midi/examples/Stronger - Kanye West - Chorus.mid'),
#  PosixPath('data/midi/examples/I Kissed A Girl - Katy Perry - Chorus.mid'),
#  PosixPath('data/midi/examples/La Bamba - Ritchie Valen - Chorus.mid'),
#  PosixPath('data/midi/examples/Everywhere - Michelle Branch - Chorus.mid'),
#  PosixPath('data/midi/examples/All I Want For Christmas Is You - Mariah Carey - Pre-Chorus-And-Chorus.mid'),
#  PosixPath('data/midi/examples/The Four Seasons Concerto No 4 Winter - Antonio Vivaldi - Instrumental.mid'),
#  PosixPath('data/midi/examples/I Dont Want To Miss A Thing - Aerosmith - Chorus.mid'),
#  PosixPath('data/midi/examples/Levels - Avicii - Verse.mid'),
#  PosixPath('data/midi/examples/Complicated - Avril Lavigne - Chorus.mid')]

# %%
p = Path('../../data/midi/examples/Levels - Avicii - Verse.mid').absolute()
p, p.exists()
# Out:
# (PosixPath('/home/ubuntu/musicautobot/../../data/midi/examples/Levels - Avicii - Verse.mid'),
#  False)

# %% [markdown]
# ## Creating Asset Folder

# %%
asset_path = Path('data/assets/examples/seed')

# %%
def save_to_path(s):
    title = s['title'].title().replace('-', ' ')
    artist = s['artist'].title().replace('-', ' ')
    display = ' - '.join([title, artist])
    if s.get('section'): display += ' - ' + s['section'].title()
    sid = s['md5']
    
    json_data = {
        'title': title,
        'artist': artist,
        'bpm': s['ht_bpm'],
        'display': display,
        'section': s['section'],
        'genres': s['genres'],
        'sid': sid
    }
    source_file = data_dir/s['midi']
#     key_file = str(source_file).replace('cmajor', 'original')
    key_file = source_file
    to_file = asset_path/f'{sid[::-1]}.mid'
    to_json = asset_path/f'{sid[::-1]}.json'
    if not to_file.exists():
        to_file.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy(str(key_file), str(to_file))
        with open(to_json, 'w') as jp:
            json.dump(json_data, jp)
    
    return json_data

# %%
htlist = [save_to_path(s) for s in recordlist]
json_path = asset_path.parent/'json/htlist.json'
json_path.parent.mkdir(parents=True, exist_ok=True)
with open(json_path, 'w') as fp:
    json.dump(htlist, fp, separators=(',', ':'))

# %%
htlist
# Out:
# [{'title': 'Symphony No 40 In G Minor   I',
#   'artist': 'Wolfgang Amadeus Mozart',
#   'bpm': 115.0,
#   'display': 'Symphony No 40 In G Minor   I - Wolfgang Amadeus Mozart - Verse',
#   'section': 'verse',
#   'genres': 'Classical',
#   'sid': '4296f489066d02db3491bcde78667746'},
#  {'title': 'I Want You Back',
#   'artist': 'Jackson 5',
#   'bpm': 98.0,
#   'display': 'I Want You Back - Jackson 5 - Intro',
#   'section': 'intro',
#   'genres': None,
#   'sid': '2ad86f3ecd71b058eac9cc5ceba11db8'},
#  {'title': 'Canon In D Major',
#   'artist': 'Johann Pachelbel',
#   'bpm': 138.0,
#   'display': 'Canon In D Major - Johann Pachelbel - Chorus',
#   'section': 'chorus',
#   'genres': 'Classical',
#   'sid': 'c4d9e72a92f931b2c72e84b6efee4b51'},
#  {'title': 'Stairway To Heaven',
#   'artist': 'Led Zeppelin',
#   'bpm': 74.0,
#   'display': 'Stairway To Heaven - Led Zeppelin - Intro',
#   'section': 'intro',
#   'genres': 'Blues',
#   'sid': '8c0b6ff7e893dca13edd90a4d9ebb892'},
#  {'title': 'Fuer Elise',
#   'artist': 'Ludwig Van Beethoven',
#   'bpm': 139.0,
#   'display': 'Fuer Elise - Ludwig Van Beethoven - Verse',
#   'section': 'verse',
#   'genres': 'Classical',
#   'sid': '6ae7e284e78824ee4c17dc6e6bda361c'},
#  {'title': 'Bad Romance',
#   'artist': 'Lady Gaga',
#   'bpm': 119.0,
#   'display': 'Bad Romance - Lady Gaga - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop',
#   'sid': 'bb3324a9068db739eff1b2fc1cc0670b'},
#  {'title': 'In The End',
#   'artist': 'Linkin Park',
#   'bpm': 107.0,
#   'display': 'In The End - Linkin Park - Chorus',
#   'section': 'chorus',
#   'genres': 'Blues',
#   'sid': 'b51d911631b67babe1612dae455600e3'},
#  {'title': 'A Thousand Miles',
#   'artist': 'Vanessa Carlton',
#   'bpm': 96.0,
#   'display': 'A Thousand Miles - Vanessa Carlton - Verse-And-Pre-Chorus',
#   'section': 'verse-and-pre-chorus',
#   'genres': 'Pop,Singer-Songwriter',
#   'sid': '58890c433f173ba77220274017b8af92'},
#  {'title': 'Where Is The Love',
#   'artist': 'Black Eyed Peas',
#   'bpm': 93.0,
#   'display': 'Where Is The Love - Black Eyed Peas - Chorus',
#   'section': 'chorus',
#   'genres': None,
#   'sid': '68ce7fc929f395291507cc47510cd82c'},
#  {'title': 'Locked Out Of Heaven',
#   'artist': 'Bruno Mars',
#   'bpm': 147.0,
#   'display': 'Locked Out Of Heaven - Bruno Mars - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop',
#   'sid': '077b40997776b84366ee18056948ae38'},
#  {'title': 'Oops I Did It Again',
#   'artist': 'Britney Spears',
#   'bpm': 94.0,
#   'display': 'Oops I Did It Again - Britney Spears - Chorus',
#   'section': 'chorus',
#   'genres': None,
#   'sid': '583aee3ac9d91125102096d28926702b'},
#  {'title': 'Middle',
#   'artist': 'Zedd',
#   'bpm': 107.0,
#   'display': 'Middle - Zedd - Pre-Chorus',
#   'section': 'pre-chorus',
#   'genres': None,
#   'sid': '7f0f162d111f880cf77ff9bed15acd5d'},
#  {'title': 'Colors Of The Wind',
#   'artist': 'Disney',
#   'bpm': 107.0,
#   'display': 'Colors Of The Wind - Disney - Chorus',
#   'section': 'chorus',
#   'genres': 'Disney',
#   'sid': '8f10995e036c5f590ca616dee0c9c7d7'},
#  {'title': 'Scary Monsters And Nice Sprites',
#   'artist': 'Skrillex',
#   'bpm': 140.0,
#   'display': 'Scary Monsters And Nice Sprites - Skrillex - Pre-Chorus',
#   'section': 'pre-chorus',
#   'genres': 'Dance,Electronic,House',
#   'sid': 'f8b65d3624d9a68e417792ec27de9296'},
#  {'title': 'Call Me Maybe',
#   'artist': 'Carly Rae Jepsen',
#   'bpm': 120.0,
#   'display': 'Call Me Maybe - Carly Rae Jepsen - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop',
#   'sid': '99c5db9ce936b7a1c5faab57cc3f160c'},
#  {'title': 'In The Hall Of The Mountain King',
#   'artist': 'Edvard Grieg',
#   'bpm': 116.0,
#   'display': 'In The Hall Of The Mountain King - Edvard Grieg - Intro',
#   'section': 'intro',
#   'genres': 'Classical',
#   'sid': 'de1fa62a9c209491d4fd81f1d1ceb55e'},
#  {'title': 'Can You Feel The Love Tonight',
#   'artist': 'Elton John',
#   'bpm': 62.0,
#   'display': 'Can You Feel The Love Tonight - Elton John - Verse',
#   'section': 'verse',
#   'genres': 'Disney,Pop,Rock',
#   'sid': 'b4c62f3d11f448db69c4fa15e27e9e8e'},
#  {'title': 'Legend Of Zelda Main Theme',
#   'artist': 'Nintendo',
#   'bpm': 92.0,
#   'display': 'Legend Of Zelda Main Theme - Nintendo - Verse',
#   'section': 'verse',
#   'genres': 'Video Game',
#   'sid': 'e250d1faf9b3265f23c049d113f8a773'},
#  {'title': 'Let It Go',
#   'artist': 'Idina Menzel',
#   'bpm': 137.0,
#   'display': 'Let It Go - Idina Menzel - Chorus',
#   'section': 'chorus',
#   'genres': 'Dance,Disney,Electronic,Pop,Soundtrack',
#   'sid': 'f2062929514d3084f73a1ad81bbbe01f'},
#  {'title': 'Just Give Me A Reason',
#   'artist': 'Pink',
#   'bpm': 94.0,
#   'display': 'Just Give Me A Reason - Pink - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop',
#   'sid': '065b1c94fe8545bbe8eeec2f1bf4efa2'},
#  {'title': 'Roses Ft Rozes',
#   'artist': 'The Chainsmokers',
#   'bpm': 101.0,
#   'display': 'Roses Ft Rozes - The Chainsmokers - Chorus',
#   'section': 'chorus',
#   'genres': 'Electronic,Pop',
#   'sid': '3cc8e692016fb1d8c8f097e259ea1ea5'},
#  {'title': 'Hey Jude',
#   'artist': 'The Beatles',
#   'bpm': 75.0,
#   'display': 'Hey Jude - The Beatles - Chorus',
#   'section': 'chorus',
#   'genres': 'Rock',
#   'sid': '81efc618ff11aa17d4e96219380c115e'},
#  {'title': 'Stronger',
#   'artist': 'Kanye West',
#   'bpm': 102.0,
#   'display': 'Stronger - Kanye West - Chorus',
#   'section': 'chorus',
#   'genres': 'Electronic,Hip-Hop/Rap',
#   'sid': '50b4cbff1b6c2886c31332e5fb1a5f56'},
#  {'title': 'I Kissed A Girl',
#   'artist': 'Katy Perry',
#   'bpm': 130.0,
#   'display': 'I Kissed A Girl - Katy Perry - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop,Rock',
#   'sid': '1b341ae44d35a6c8d21f6ba3af65dd97'},
#  {'title': 'La Bamba',
#   'artist': 'Ritchie Valen',
#   'bpm': 144.0,
#   'display': 'La Bamba - Ritchie Valen - Chorus',
#   'section': 'chorus',
#   'genres': 'Pop,Rock',
#   'sid': 'aeee134e4034e5f98bb630c56d2f7f8c'},
#  {'title': 'Everywhere',
#   'artist': 'Michelle Branch',
#   'bpm': 95.0,
#   'display': 'Everywhere - Michelle Branch - Chorus',
#   'section': 'chorus',
#   'genres': None,
#   'sid': '83ee71fe7fef0bd1fd15a49740cfc967'},
#  {'title': 'All I Want For Christmas Is You',
#   'artist': 'Mariah Carey',
#   'bpm': 151.0,
#   'display': 'All I Want For Christmas Is You - Mariah Carey - Pre-Chorus-And-Chorus',
#   'section': 'pre-chorus-and-chorus',
#   'genres': None,
#   'sid': '999e8169b01f59fa28e63b142f35feda'},
#  {'title': 'The Four Seasons Concerto No 4 Winter',
#   'artist': 'Antonio Vivaldi',
#   'bpm': 84.0,
#   'display': 'The Four Seasons Concerto No 4 Winter - Antonio Vivaldi - Instrumental',
#   'section': 'instrumental',
#   'genres': 'Classical',
#   'sid': '73b2b8e7db746b7e4b6fc3fa4658671b'},
#  {'title': 'I Dont Want To Miss A Thing',
#   'artist': 'Aerosmith',
#   'bpm': 60.0,
#   'display': 'I Dont Want To Miss A Thing - Aerosmith - Chorus',
#   'section': 'chorus',
#   'genres': 'Rock',
#   'sid': 'e8820e3b81d2429d684c986ce2f57071'},
#  {'title': 'Levels',
#   'artist': 'Avicii',
#   'bpm': 126.0,
#   'display': 'Levels - Avicii - Verse',
#   'section': 'verse',
#   'genres': 'Electronic,House',
#   'sid': '19762ebd7059dd5f8809f98b2575d8c1'},
#  {'title': 'Complicated',
#   'artist': 'Avril Lavigne',
#   'bpm': 76.0,
#   'display': 'Complicated - Avril Lavigne - Chorus',
#   'section': 'chorus',
#   'genres': 'Alternative,Pop,Soul',
#   'sid': 'c8bcf08c8d31c98c61a91b2d90a9cdde'}]
